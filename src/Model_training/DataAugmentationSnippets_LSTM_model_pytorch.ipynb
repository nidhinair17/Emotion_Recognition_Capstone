# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import precision_recall_fscore_support

# %%
features = pd.read_csv("C:/Nini/Capstone/CSV_Files/DataAugmentationSnippets_ravdess_extracted_features.csv")
features = features.drop(features.columns[0], axis=1)
temp = shuffle(features)
df = np.random.rand(len(temp)) < 0.8
train = temp[df]
test = temp[~df]

# %%
X_train = np.array(train.iloc[:,:-1])
y_train = np.array(train.iloc[:,-1])
X_test = np.array(test.iloc[:,:-1])
y_test = np.array(test.iloc[:,-1])

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
batch_size = 256
train_loader = DataLoader(TensorDataset(X_train,y_train), batch_size=batch_size,shuffle=True)
test_loader = DataLoader(TensorDataset(X_test,y_test), batch_size=batch_size, shuffle=False)

# %%
class LSTMPyTorch(nn.Module):
    def __init__(self, input_size, hidden_sizes=[256, 256, 128], output_size=8, dropout=0.2, l2_reg=1e-5):
        super(LSTMPyTorch, self).__init__()
        
        self.lstm1 = nn.LSTM(input_size, hidden_sizes[0], batch_first=True)
        self.lstm2 = nn.LSTM(hidden_sizes[0], hidden_sizes[1], batch_first=True)
        self.lstm3 = nn.LSTM(hidden_sizes[1], hidden_sizes[2], batch_first=True)
        
        self.bn1 = nn.BatchNorm1d(hidden_sizes[0])
        self.bn2 = nn.BatchNorm1d(hidden_sizes[1])
        self.bn3 = nn.BatchNorm1d(hidden_sizes[2])

        self.fc1 = nn.Linear(hidden_sizes[2], 256)
        self.fc2 = nn.Linear(256, output_size)
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.bn1(x.transpose(1,2)).transpose(1,2)

        x, _ = self.lstm2(x)
        x = self.bn2(x.transpose(1,2)).transpose(1,2)

        x, _ = self.lstm3(x)
        x = self.bn3(x.transpose(1,2)).transpose(1,2)
        
        x = self.relu(self.fc1(x[:, -1, :])) 
        x = self.dropout(x)
        x = self.softmax(self.fc2(x))
        return x

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: torch.Size([8389, 1, 128])

# %%
input_size = 128
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMPyTorch(input_size).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

# %%
epochs = 1500
for epoch in range(epochs):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    # Training loop
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)
    
    train_accuracy = correct / total
    avg_train_loss = running_loss / len(train_loader)

    # Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for val_inputs, val_labels in test_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()
            _, val_predicted = torch.max(val_outputs, 1)

            val_correct += (val_predicted == val_labels).sum().item()
            val_total += val_labels.size(0)

            # Store predictions and labels for evaluation
            all_preds.extend(val_predicted.cpu().numpy())
            all_labels.extend(val_labels.cpu().numpy())

    val_accuracy = val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)

    # Compute Precision, Recall, F1-score
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted',zero_division=1)

    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}")
    print("-" * 50)
# Out:
# Epoch [1/1500]
# Train Loss: 1.9821, Train Acc: 0.2801
# Val Loss: 2.0091, Val Acc: 0.2777
# Precision: 0.4003, Recall: 0.2777, F1-score: 0.2609
# --------------------------------------------------
# Epoch [2/1500]
# Train Loss: 1.9065, Train Acc: 0.3552
# Val Loss: 1.8792, Val Acc: 0.3616
# Precision: 0.4517, Recall: 0.3616, F1-score: 0.3490
# --------------------------------------------------
# Epoch [3/1500]
# Train Loss: 1.8662, Train Acc: 0.3987
# Val Loss: 1.8717, Val Acc: 0.3635
# Precision: 0.4112, Recall: 0.3635, F1-score: 0.3495
# --------------------------------------------------
# Epoch [4/1500]
# Train Loss: 1.8456, Train Acc: 0.4210
# Val Loss: 1.8537, Val Acc: 0.3842
# Precision: 0.4310, Recall: 0.3842, F1-score: 0.3652
# --------------------------------------------------
# Epoch [5/1500]
# Train Loss: 1.8221, Train Acc: 0.4442
# Val Loss: 1.8337, Val Acc: 0.4125
# Precision: 0.4689, Recall: 0.4125, F1-score: 0.4001
# --------------------------------------------------
# Epoch [6/1500]
# Train Loss: 1.8081, Train Acc: 0.4567
# Val Loss: 1.8374, Val Acc: 0.4019
# Precision: 0.4658, Recall: 0.4019, F1-score: 0.3936
# --------------------------------------------------
# Epoch [7/1500]
# Train Loss: 1.7984, Train Acc: 0.4726
# Val Loss: 1.8308, Val Acc: 0.4134
# Precision: 0.5079, Recall: 0.4134, F1-score: 0.4000
# --------------------------------------------------
# Epoch [8/1500]
# Train Loss: 1.7819, Train Acc: 0.4884
# Val Loss: 1.8280, Val Acc: 0.4273
# Precision: 0.4868, Recall: 0.4273, F1-score: 0.4192
# --------------------------------------------------
# Epoch [9/1500]
# Train Loss: 1.7749, Train Acc: 0.4934
# Val Loss: 1.7822, Val Acc: 0.4595
# Precision: 0.4969, Recall: 0.4595, F1-score: 0.4479
# --------------------------------------------------
# Epoch [10/1500]
# Train Loss: 1.7548, Train Acc: 0.5175
# Val Loss: 1.8204, Val Acc: 0.4245
# Precision: 0.4561, Recall: 0.4245, F1-score: 0.4114
# --------------------------------------------------
# Epoch [11/1500]
# Train Loss: 1.7507, Train Acc: 0.5185
# Val Loss: 1.7717, Val Acc: 0.4767
# Precision: 0.5185, Recall: 0.4767, F1-score: 0.4587
# --------------------------------------------------
# Epoch [12/1500]
# Train Loss: 1.7320, Train Acc: 0.5344
# Val Loss: 1.7811, Val Acc: 0.4556
# Precision: 0.5073, Recall: 0.4556, F1-score: 0.4481
# --------------------------------------------------
# Epoch [13/1500]
# Train Loss: 1.7228, Train Acc: 0.5476
# Val Loss: 1.7578, Val Acc: 0.4849
# Precision: 0.5534, Recall: 0.4849, F1-score: 0.4714
# --------------------------------------------------
# Epoch [14/1500]
# Train Loss: 1.7171, Train Acc: 0.5537
# Val Loss: 1.7680, Val Acc: 0.4748
# Precision: 0.5322, Recall: 0.4748, F1-score: 0.4610
# --------------------------------------------------
# Epoch [15/1500]
# Train Loss: 1.7168, Train Acc: 0.5537
# Val Loss: 1.7677, Val Acc: 0.4811
# Precision: 0.5190, Recall: 0.4811, F1-score: 0.4672
# --------------------------------------------------
# Epoch [16/1500]
# Train Loss: 1.7055, Train Acc: 0.5651
# Val Loss: 1.7388, Val Acc: 0.5132
# Precision: 0.5514, Recall: 0.5132, F1-score: 0.4979
# --------------------------------------------------
# Epoch [17/1500]
# Train Loss: 1.7049, Train Acc: 0.5648
# Val Loss: 1.7324, Val Acc: 0.5151
# Precision: 0.5475, Recall: 0.5151, F1-score: 0.4981
# --------------------------------------------------
# Epoch [18/1500]
# Train Loss: 1.6859, Train Acc: 0.5837
# Val Loss: 1.7206, Val Acc: 0.5266
# Precision: 0.5594, Recall: 0.5266, F1-score: 0.5154
# --------------------------------------------------
# Epoch [19/1500]
# Train Loss: 1.6727, Train Acc: 0.5994
# Val Loss: 1.7485, Val Acc: 0.4916
# Precision: 0.5324, Recall: 0.4916, F1-score: 0.4758
# --------------------------------------------------
# Epoch [20/1500]
# Train Loss: 1.6707, Train Acc: 0.5973
# Val Loss: 1.7143, Val Acc: 0.5324
# Precision: 0.5487, Recall: 0.5324, F1-score: 0.5208
# --------------------------------------------------
# Epoch [21/1500]
# Train Loss: 1.6514, Train Acc: 0.6194
# Val Loss: 1.7273, Val Acc: 0.5180
# Precision: 0.5343, Recall: 0.5180, F1-score: 0.5166
# --------------------------------------------------
# Epoch [22/1500]
# Train Loss: 1.6496, Train Acc: 0.6193
# Val Loss: 1.7114, Val Acc: 0.5329
# Precision: 0.5478, Recall: 0.5329, F1-score: 0.5249
# --------------------------------------------------
# Epoch [23/1500]
# Train Loss: 1.6356, Train Acc: 0.6395
# Val Loss: 1.7084, Val Acc: 0.5429
# Precision: 0.5652, Recall: 0.5429, F1-score: 0.5421
# --------------------------------------------------
# Epoch [24/1500]
# Train Loss: 1.6333, Train Acc: 0.6408
# Val Loss: 1.6916, Val Acc: 0.5544
# Precision: 0.5772, Recall: 0.5544, F1-score: 0.5498
# --------------------------------------------------
# Epoch [25/1500]
# Train Loss: 1.6168, Train Acc: 0.6536
# Val Loss: 1.6953, Val Acc: 0.5511
# Precision: 0.5652, Recall: 0.5511, F1-score: 0.5506
# --------------------------------------------------
# Epoch [26/1500]
# Train Loss: 1.6138, Train Acc: 0.6604
# Val Loss: 1.6994, Val Acc: 0.5501
# Precision: 0.5755, Recall: 0.5501, F1-score: 0.5504
# --------------------------------------------------
# Epoch [27/1500]
# Train Loss: 1.6073, Train Acc: 0.6659
# Val Loss: 1.6960, Val Acc: 0.5525
# Precision: 0.5886, Recall: 0.5525, F1-score: 0.5551
# --------------------------------------------------
# Epoch [28/1500]
# Train Loss: 1.5913, Train Acc: 0.6817
# Val Loss: 1.6901, Val Acc: 0.5679
# Precision: 0.5960, Recall: 0.5679, F1-score: 0.5680
# --------------------------------------------------
# Epoch [29/1500]
# Train Loss: 1.5931, Train Acc: 0.6784
# Val Loss: 1.6959, Val Acc: 0.5616
# Precision: 0.5823, Recall: 0.5616, F1-score: 0.5568
# --------------------------------------------------
# Epoch [30/1500]
# Train Loss: 1.5852, Train Acc: 0.6880
# Val Loss: 1.6650, Val Acc: 0.5799
# Precision: 0.5837, Recall: 0.5799, F1-score: 0.5787
# --------------------------------------------------
# Epoch [31/1500]
# Train Loss: 1.5851, Train Acc: 0.6879
# Val Loss: 1.6686, Val Acc: 0.5851
# Precision: 0.6060, Recall: 0.5851, F1-score: 0.5862
# --------------------------------------------------
# Epoch [32/1500]
# Train Loss: 1.5777, Train Acc: 0.6934
# Val Loss: 1.6654, Val Acc: 0.5923
# Precision: 0.6196, Recall: 0.5923, F1-score: 0.5962
# --------------------------------------------------
# Epoch [33/1500]
# Train Loss: 1.5785, Train Acc: 0.6944
# Val Loss: 1.6810, Val Acc: 0.5650
# Precision: 0.5919, Recall: 0.5650, F1-score: 0.5639
# --------------------------------------------------
# Epoch [34/1500]
# Train Loss: 1.5764, Train Acc: 0.6964
# Val Loss: 1.6731, Val Acc: 0.5751
# Precision: 0.6018, Recall: 0.5751, F1-score: 0.5738
# --------------------------------------------------
# Epoch [35/1500]
# Train Loss: 1.5739, Train Acc: 0.6987
# Val Loss: 1.6990, Val Acc: 0.5544
# Precision: 0.5913, Recall: 0.5544, F1-score: 0.5619
# --------------------------------------------------
# Epoch [36/1500]
# Train Loss: 1.5693, Train Acc: 0.7014
# Val Loss: 1.6613, Val Acc: 0.5914
# Precision: 0.6330, Recall: 0.5914, F1-score: 0.5943
# --------------------------------------------------
# Epoch [37/1500]
# Train Loss: 1.5585, Train Acc: 0.7136
# Val Loss: 1.6472, Val Acc: 0.6038
# Precision: 0.6180, Recall: 0.6038, F1-score: 0.6020
# --------------------------------------------------
# Epoch [38/1500]
# Train Loss: 1.5483, Train Acc: 0.7236
# Val Loss: 1.6575, Val Acc: 0.5947
# Precision: 0.6041, Recall: 0.5947, F1-score: 0.5914
# --------------------------------------------------
# Epoch [39/1500]
# Train Loss: 1.5485, Train Acc: 0.7240
# Val Loss: 1.6400, Val Acc: 0.6024
# Precision: 0.6124, Recall: 0.6024, F1-score: 0.6003
# --------------------------------------------------
# Epoch [40/1500]
# Train Loss: 1.5412, Train Acc: 0.7329
# Val Loss: 1.6326, Val Acc: 0.6240
# Precision: 0.6318, Recall: 0.6240, F1-score: 0.6254
# --------------------------------------------------
# Epoch [41/1500]
# Train Loss: 1.5343, Train Acc: 0.7389
# Val Loss: 1.6427, Val Acc: 0.6110
# Precision: 0.6172, Recall: 0.6110, F1-score: 0.6099
# --------------------------------------------------
# Epoch [42/1500]
# Train Loss: 1.5448, Train Acc: 0.7255
# Val Loss: 1.6552, Val Acc: 0.5923
# Precision: 0.6252, Recall: 0.5923, F1-score: 0.5948
# --------------------------------------------------
# Epoch [43/1500]
# Train Loss: 1.5280, Train Acc: 0.7451
# Val Loss: 1.6329, Val Acc: 0.6153
# Precision: 0.6249, Recall: 0.6153, F1-score: 0.6161
# --------------------------------------------------
# Epoch [44/1500]
# Train Loss: 1.5230, Train Acc: 0.7503
# Val Loss: 1.6562, Val Acc: 0.5885
# Precision: 0.5979, Recall: 0.5885, F1-score: 0.5865
# --------------------------------------------------
# Epoch [45/1500]
# Train Loss: 1.5188, Train Acc: 0.7540
# Val Loss: 1.6243, Val Acc: 0.6273
# Precision: 0.6443, Recall: 0.6273, F1-score: 0.6299
# --------------------------------------------------
# Epoch [46/1500]
# Train Loss: 1.5161, Train Acc: 0.7575
# Val Loss: 1.6576, Val Acc: 0.5962
# Precision: 0.6123, Recall: 0.5962, F1-score: 0.5987
# --------------------------------------------------
# Epoch [47/1500]
# Train Loss: 1.5159, Train Acc: 0.7575
# Val Loss: 1.6151, Val Acc: 0.6369
# Precision: 0.6503, Recall: 0.6369, F1-score: 0.6395
# --------------------------------------------------
# Epoch [48/1500]
# Train Loss: 1.5083, Train Acc: 0.7649
# Val Loss: 1.6400, Val Acc: 0.6249
# Precision: 0.6378, Recall: 0.6249, F1-score: 0.6230
# --------------------------------------------------
# Epoch [49/1500]
# Train Loss: 1.5083, Train Acc: 0.7635
# Val Loss: 1.6181, Val Acc: 0.6331
# Precision: 0.6478, Recall: 0.6331, F1-score: 0.6337
# --------------------------------------------------
# Epoch [50/1500]
# Train Loss: 1.5045, Train Acc: 0.7687
# Val Loss: 1.6218, Val Acc: 0.6345
# Precision: 0.6448, Recall: 0.6345, F1-score: 0.6371
# --------------------------------------------------
# Epoch [51/1500]
# Train Loss: 1.5059, Train Acc: 0.7674
# Val Loss: 1.6327, Val Acc: 0.6173
# Precision: 0.6221, Recall: 0.6173, F1-score: 0.6173
# --------------------------------------------------
# Epoch [52/1500]
# Train Loss: 1.5072, Train Acc: 0.7667
# Val Loss: 1.6414, Val Acc: 0.6168
# Precision: 0.6476, Recall: 0.6168, F1-score: 0.6182
# --------------------------------------------------
# Epoch [53/1500]
# Train Loss: 1.5082, Train Acc: 0.7658
# Val Loss: 1.6271, Val Acc: 0.6278
# Precision: 0.6431, Recall: 0.6278, F1-score: 0.6277
# --------------------------------------------------
# Epoch [54/1500]
# Train Loss: 1.5037, Train Acc: 0.7689
# Val Loss: 1.6295, Val Acc: 0.6230
# Precision: 0.6489, Recall: 0.6230, F1-score: 0.6295
# --------------------------------------------------
# Epoch [55/1500]
# Train Loss: 1.5129, Train Acc: 0.7583
# Val Loss: 1.6389, Val Acc: 0.6106
# Precision: 0.6230, Recall: 0.6106, F1-score: 0.6110
# --------------------------------------------------
# Epoch [56/1500]
# Train Loss: 1.5014, Train Acc: 0.7708
# Val Loss: 1.6271, Val Acc: 0.6321
# Precision: 0.6808, Recall: 0.6321, F1-score: 0.6428
# --------------------------------------------------
# Epoch [57/1500]
# Train Loss: 1.4915, Train Acc: 0.7803
# Val Loss: 1.6225, Val Acc: 0.6398
# Precision: 0.6517, Recall: 0.6398, F1-score: 0.6432
# --------------------------------------------------
# Epoch [58/1500]
# Train Loss: 1.4870, Train Acc: 0.7852
# Val Loss: 1.6282, Val Acc: 0.6288
# Precision: 0.6526, Recall: 0.6288, F1-score: 0.6346
# --------------------------------------------------
# Epoch [59/1500]
# Train Loss: 1.4882, Train Acc: 0.7839
# Val Loss: 1.6154, Val Acc: 0.6528
# Precision: 0.6760, Recall: 0.6528, F1-score: 0.6564
# --------------------------------------------------
# Epoch [60/1500]
# Train Loss: 1.4852, Train Acc: 0.7879
# Val Loss: 1.6044, Val Acc: 0.6465
# Precision: 0.6626, Recall: 0.6465, F1-score: 0.6469
# --------------------------------------------------
# Epoch [61/1500]
# Train Loss: 1.4868, Train Acc: 0.7863
# Val Loss: 1.6310, Val Acc: 0.6293
# Precision: 0.6367, Recall: 0.6293, F1-score: 0.6296
# --------------------------------------------------
# Epoch [62/1500]
# Train Loss: 1.4910, Train Acc: 0.7808
# Val Loss: 1.6241, Val Acc: 0.6331
# Precision: 0.6620, Recall: 0.6331, F1-score: 0.6391
# --------------------------------------------------
# Epoch [63/1500]
# Train Loss: 1.4896, Train Acc: 0.7839
# Val Loss: 1.6452, Val Acc: 0.6120
# Precision: 0.6539, Recall: 0.6120, F1-score: 0.6150
# --------------------------------------------------
# Epoch [64/1500]
# Train Loss: 1.4876, Train Acc: 0.7841
# Val Loss: 1.6171, Val Acc: 0.6446
# Precision: 0.6629, Recall: 0.6446, F1-score: 0.6477
# --------------------------------------------------
# Epoch [65/1500]
# Train Loss: 1.4766, Train Acc: 0.7969
# Val Loss: 1.6021, Val Acc: 0.6552
# Precision: 0.6672, Recall: 0.6552, F1-score: 0.6577
# --------------------------------------------------
# Epoch [66/1500]
# Train Loss: 1.4852, Train Acc: 0.7889
# Val Loss: 1.6291, Val Acc: 0.6297
# Precision: 0.6663, Recall: 0.6297, F1-score: 0.6354
# --------------------------------------------------
# Epoch [67/1500]
# Train Loss: 1.4778, Train Acc: 0.7941
# Val Loss: 1.6109, Val Acc: 0.6393
# Precision: 0.6521, Recall: 0.6393, F1-score: 0.6403
# --------------------------------------------------
# Epoch [68/1500]
# Train Loss: 1.4776, Train Acc: 0.7939
# Val Loss: 1.6151, Val Acc: 0.6393
# Precision: 0.6705, Recall: 0.6393, F1-score: 0.6478
# --------------------------------------------------
# Epoch [69/1500]
# Train Loss: 1.4746, Train Acc: 0.7981
# Val Loss: 1.6204, Val Acc: 0.6398
# Precision: 0.6502, Recall: 0.6398, F1-score: 0.6405
# --------------------------------------------------
# Epoch [70/1500]
# Train Loss: 1.4790, Train Acc: 0.7949
# Val Loss: 1.6100, Val Acc: 0.6532
# Precision: 0.6728, Recall: 0.6532, F1-score: 0.6529
# --------------------------------------------------
# Epoch [71/1500]
# Train Loss: 1.4749, Train Acc: 0.7983
# Val Loss: 1.5893, Val Acc: 0.6647
# Precision: 0.6770, Recall: 0.6647, F1-score: 0.6645
# --------------------------------------------------
# Epoch [72/1500]
# Train Loss: 1.4699, Train Acc: 0.8028
# Val Loss: 1.6037, Val Acc: 0.6619
# Precision: 0.6734, Recall: 0.6619, F1-score: 0.6626
# --------------------------------------------------
# Epoch [73/1500]
# Train Loss: 1.4675, Train Acc: 0.8025
# Val Loss: 1.6182, Val Acc: 0.6384
# Precision: 0.6592, Recall: 0.6384, F1-score: 0.6409
# --------------------------------------------------
# Epoch [74/1500]
# Train Loss: 1.4725, Train Acc: 0.8001
# Val Loss: 1.6082, Val Acc: 0.6460
# Precision: 0.6584, Recall: 0.6460, F1-score: 0.6490
# --------------------------------------------------
# Epoch [75/1500]
# Train Loss: 1.4655, Train Acc: 0.8072
# Val Loss: 1.6136, Val Acc: 0.6451
# Precision: 0.6614, Recall: 0.6451, F1-score: 0.6458
# --------------------------------------------------
# Epoch [76/1500]
# Train Loss: 1.4668, Train Acc: 0.8061
# Val Loss: 1.5890, Val Acc: 0.6700
# Precision: 0.6890, Recall: 0.6700, F1-score: 0.6725
# --------------------------------------------------
# Epoch [77/1500]
# Train Loss: 1.4627, Train Acc: 0.8107
# Val Loss: 1.6367, Val Acc: 0.6249
# Precision: 0.6881, Recall: 0.6249, F1-score: 0.6376
# --------------------------------------------------
# Epoch [78/1500]
# Train Loss: 1.4596, Train Acc: 0.8123
# Val Loss: 1.6021, Val Acc: 0.6585
# Precision: 0.6835, Recall: 0.6585, F1-score: 0.6613
# --------------------------------------------------
# Epoch [79/1500]
# Train Loss: 1.4639, Train Acc: 0.8088
# Val Loss: 1.6093, Val Acc: 0.6451
# Precision: 0.6864, Recall: 0.6451, F1-score: 0.6563
# --------------------------------------------------
# Epoch [80/1500]
# Train Loss: 1.4566, Train Acc: 0.8167
# Val Loss: 1.6049, Val Acc: 0.6513
# Precision: 0.6802, Recall: 0.6513, F1-score: 0.6547
# --------------------------------------------------
# Epoch [81/1500]
# Train Loss: 1.4593, Train Acc: 0.8143
# Val Loss: 1.5893, Val Acc: 0.6715
# Precision: 0.6893, Recall: 0.6715, F1-score: 0.6731
# --------------------------------------------------
# Epoch [82/1500]
# Train Loss: 1.4674, Train Acc: 0.8045
# Val Loss: 1.6021, Val Acc: 0.6571
# Precision: 0.6728, Recall: 0.6571, F1-score: 0.6558
# --------------------------------------------------
# Epoch [83/1500]
# Train Loss: 1.4623, Train Acc: 0.8107
# Val Loss: 1.6112, Val Acc: 0.6532
# Precision: 0.6669, Recall: 0.6532, F1-score: 0.6560
# --------------------------------------------------
# Epoch [84/1500]
# Train Loss: 1.4559, Train Acc: 0.8168
# Val Loss: 1.5991, Val Acc: 0.6652
# Precision: 0.6928, Recall: 0.6652, F1-score: 0.6725
# --------------------------------------------------
# Epoch [85/1500]
# Train Loss: 1.4589, Train Acc: 0.8134
# Val Loss: 1.6192, Val Acc: 0.6369
# Precision: 0.6764, Recall: 0.6369, F1-score: 0.6397
# --------------------------------------------------
# Epoch [86/1500]
# Train Loss: 1.4575, Train Acc: 0.8148
# Val Loss: 1.5695, Val Acc: 0.6882
# Precision: 0.6933, Recall: 0.6882, F1-score: 0.6871
# --------------------------------------------------
# Epoch [87/1500]
# Train Loss: 1.4557, Train Acc: 0.8189
# Val Loss: 1.6251, Val Acc: 0.6470
# Precision: 0.6689, Recall: 0.6470, F1-score: 0.6510
# --------------------------------------------------
# Epoch [88/1500]
# Train Loss: 1.4588, Train Acc: 0.8133
# Val Loss: 1.5978, Val Acc: 0.6566
# Precision: 0.6712, Recall: 0.6566, F1-score: 0.6579
# --------------------------------------------------
# Epoch [89/1500]
# Train Loss: 1.4621, Train Acc: 0.8100
# Val Loss: 1.5821, Val Acc: 0.6686
# Precision: 0.6859, Recall: 0.6686, F1-score: 0.6703
# --------------------------------------------------
# Epoch [90/1500]
# Train Loss: 1.4540, Train Acc: 0.8180
# Val Loss: 1.5867, Val Acc: 0.6691
# Precision: 0.6741, Recall: 0.6691, F1-score: 0.6691
# --------------------------------------------------
# Epoch [91/1500]
# Train Loss: 1.4449, Train Acc: 0.8300
# Val Loss: 1.5964, Val Acc: 0.6494
# Precision: 0.6637, Recall: 0.6494, F1-score: 0.6516
# --------------------------------------------------
# Epoch [92/1500]
# Train Loss: 1.4599, Train Acc: 0.8138
# Val Loss: 1.5996, Val Acc: 0.6600
# Precision: 0.6732, Recall: 0.6600, F1-score: 0.6625
# --------------------------------------------------
# Epoch [93/1500]
# Train Loss: 1.4605, Train Acc: 0.8115
# Val Loss: 1.5828, Val Acc: 0.6715
# Precision: 0.6920, Recall: 0.6715, F1-score: 0.6744
# --------------------------------------------------
# Epoch [94/1500]
# Train Loss: 1.4479, Train Acc: 0.8236
# Val Loss: 1.6053, Val Acc: 0.6523
# Precision: 0.6879, Recall: 0.6523, F1-score: 0.6568
# --------------------------------------------------
# Epoch [95/1500]
# Train Loss: 1.4499, Train Acc: 0.8212
# Val Loss: 1.6069, Val Acc: 0.6504
# Precision: 0.6809, Recall: 0.6504, F1-score: 0.6554
# --------------------------------------------------
# Epoch [96/1500]
# Train Loss: 1.4618, Train Acc: 0.8111
# Val Loss: 1.5983, Val Acc: 0.6628
# Precision: 0.6719, Recall: 0.6628, F1-score: 0.6648
# --------------------------------------------------
# Epoch [97/1500]
# Train Loss: 1.4469, Train Acc: 0.8250
# Val Loss: 1.5949, Val Acc: 0.6676
# Precision: 0.6851, Recall: 0.6676, F1-score: 0.6652
# --------------------------------------------------
# Epoch [98/1500]
# Train Loss: 1.4443, Train Acc: 0.8297
# Val Loss: 1.5884, Val Acc: 0.6691
# Precision: 0.6873, Recall: 0.6691, F1-score: 0.6707
# --------------------------------------------------
# Epoch [99/1500]
# Train Loss: 1.4446, Train Acc: 0.8275
# Val Loss: 1.5833, Val Acc: 0.6801
# Precision: 0.7058, Recall: 0.6801, F1-score: 0.6816
# --------------------------------------------------
# Epoch [100/1500]
# Train Loss: 1.4497, Train Acc: 0.8229
# Val Loss: 1.5975, Val Acc: 0.6576
# Precision: 0.6713, Recall: 0.6576, F1-score: 0.6588
# --------------------------------------------------
# Epoch [101/1500]
# Train Loss: 1.4477, Train Acc: 0.8244
# Val Loss: 1.5841, Val Acc: 0.6686
# Precision: 0.6816, Recall: 0.6686, F1-score: 0.6716
# --------------------------------------------------
# Epoch [102/1500]
# Train Loss: 1.4469, Train Acc: 0.8244
# Val Loss: 1.5718, Val Acc: 0.6897
# Precision: 0.7014, Recall: 0.6897, F1-score: 0.6892
# --------------------------------------------------
# Epoch [103/1500]
# Train Loss: 1.4514, Train Acc: 0.8223
# Val Loss: 1.5828, Val Acc: 0.6710
# Precision: 0.6795, Recall: 0.6710, F1-score: 0.6729
# --------------------------------------------------
# Epoch [104/1500]
# Train Loss: 1.4405, Train Acc: 0.8330
# Val Loss: 1.5755, Val Acc: 0.6801
# Precision: 0.6903, Recall: 0.6801, F1-score: 0.6816
# --------------------------------------------------
# Epoch [105/1500]
# Train Loss: 1.4349, Train Acc: 0.8374
# Val Loss: 1.5793, Val Acc: 0.6739
# Precision: 0.6873, Recall: 0.6739, F1-score: 0.6745
# --------------------------------------------------
# Epoch [106/1500]
# Train Loss: 1.4342, Train Acc: 0.8388
# Val Loss: 1.5742, Val Acc: 0.6820
# Precision: 0.6922, Recall: 0.6820, F1-score: 0.6842
# --------------------------------------------------
# Epoch [107/1500]
# Train Loss: 1.4382, Train Acc: 0.8331
# Val Loss: 1.5954, Val Acc: 0.6710
# Precision: 0.6984, Recall: 0.6710, F1-score: 0.6752
# --------------------------------------------------
# Epoch [108/1500]
# Train Loss: 1.4304, Train Acc: 0.8432
# Val Loss: 1.5534, Val Acc: 0.6969
# Precision: 0.7079, Recall: 0.6969, F1-score: 0.6980
# --------------------------------------------------
# Epoch [109/1500]
# Train Loss: 1.4353, Train Acc: 0.8392
# Val Loss: 1.5885, Val Acc: 0.6628
# Precision: 0.6877, Recall: 0.6628, F1-score: 0.6630
# --------------------------------------------------
# Epoch [110/1500]
# Train Loss: 1.4435, Train Acc: 0.8282
# Val Loss: 1.5833, Val Acc: 0.6791
# Precision: 0.6992, Recall: 0.6791, F1-score: 0.6809
# --------------------------------------------------
# Epoch [111/1500]
# Train Loss: 1.4440, Train Acc: 0.8288
# Val Loss: 1.5849, Val Acc: 0.6777
# Precision: 0.6915, Recall: 0.6777, F1-score: 0.6796
# --------------------------------------------------
# Epoch [112/1500]
# Train Loss: 1.4383, Train Acc: 0.8351
# Val Loss: 1.5885, Val Acc: 0.6724
# Precision: 0.6903, Recall: 0.6724, F1-score: 0.6768
# --------------------------------------------------
# Epoch [113/1500]
# Train Loss: 1.4437, Train Acc: 0.8291
# Val Loss: 1.5777, Val Acc: 0.6791
# Precision: 0.6961, Recall: 0.6791, F1-score: 0.6834
# --------------------------------------------------
# Epoch [114/1500]
# Train Loss: 1.4402, Train Acc: 0.8317
# Val Loss: 1.5828, Val Acc: 0.6835
# Precision: 0.7053, Recall: 0.6835, F1-score: 0.6849
# --------------------------------------------------
# Epoch [115/1500]
# Train Loss: 1.4452, Train Acc: 0.8278
# Val Loss: 1.5918, Val Acc: 0.6652
# Precision: 0.6767, Recall: 0.6652, F1-score: 0.6661
# --------------------------------------------------
# Epoch [116/1500]
# Train Loss: 1.4395, Train Acc: 0.8325
# Val Loss: 1.5762, Val Acc: 0.6839
# Precision: 0.7103, Recall: 0.6839, F1-score: 0.6877
# --------------------------------------------------
# Epoch [117/1500]
# Train Loss: 1.4373, Train Acc: 0.8355
# Val Loss: 1.5779, Val Acc: 0.6782
# Precision: 0.7003, Recall: 0.6782, F1-score: 0.6815
# --------------------------------------------------
# Epoch [118/1500]
# Train Loss: 1.4354, Train Acc: 0.8382
# Val Loss: 1.5956, Val Acc: 0.6628
# Precision: 0.6778, Recall: 0.6628, F1-score: 0.6641
# --------------------------------------------------
# Epoch [119/1500]
# Train Loss: 1.4369, Train Acc: 0.8360
# Val Loss: 1.5714, Val Acc: 0.6854
# Precision: 0.6987, Recall: 0.6854, F1-score: 0.6876
# --------------------------------------------------
# Epoch [120/1500]
# Train Loss: 1.4268, Train Acc: 0.8472
# Val Loss: 1.5569, Val Acc: 0.6954
# Precision: 0.7157, Recall: 0.6954, F1-score: 0.6960
# --------------------------------------------------
# Epoch [121/1500]
# Train Loss: 1.4365, Train Acc: 0.8373
# Val Loss: 1.5720, Val Acc: 0.6839
# Precision: 0.6938, Recall: 0.6839, F1-score: 0.6868
# --------------------------------------------------
# Epoch [122/1500]
# Train Loss: 1.4334, Train Acc: 0.8392
# Val Loss: 1.5547, Val Acc: 0.7070
# Precision: 0.7325, Recall: 0.7070, F1-score: 0.7126
# --------------------------------------------------
# Epoch [123/1500]
# Train Loss: 1.4281, Train Acc: 0.8459
# Val Loss: 1.5576, Val Acc: 0.6964
# Precision: 0.7114, Recall: 0.6964, F1-score: 0.6992
# --------------------------------------------------
# Epoch [124/1500]
# Train Loss: 1.4365, Train Acc: 0.8357
# Val Loss: 1.5787, Val Acc: 0.6767
# Precision: 0.7038, Recall: 0.6767, F1-score: 0.6806
# --------------------------------------------------
# Epoch [125/1500]
# Train Loss: 1.4272, Train Acc: 0.8469
# Val Loss: 1.5550, Val Acc: 0.6978
# Precision: 0.7032, Recall: 0.6978, F1-score: 0.6980
# --------------------------------------------------
# Epoch [126/1500]
# Train Loss: 1.4209, Train Acc: 0.8522
# Val Loss: 1.5620, Val Acc: 0.6954
# Precision: 0.7240, Recall: 0.6954, F1-score: 0.6997
# --------------------------------------------------
# Epoch [127/1500]
# Train Loss: 1.4208, Train Acc: 0.8522
# Val Loss: 1.5750, Val Acc: 0.6868
# Precision: 0.7053, Recall: 0.6868, F1-score: 0.6880
# --------------------------------------------------
# Epoch [128/1500]
# Train Loss: 1.4245, Train Acc: 0.8497
# Val Loss: 1.5891, Val Acc: 0.6772
# Precision: 0.7148, Recall: 0.6772, F1-score: 0.6808
# --------------------------------------------------
# Epoch [129/1500]
# Train Loss: 1.4300, Train Acc: 0.8423
# Val Loss: 1.6016, Val Acc: 0.6719
# Precision: 0.6986, Recall: 0.6719, F1-score: 0.6745
# --------------------------------------------------
# Epoch [130/1500]
# Train Loss: 1.4329, Train Acc: 0.8396
# Val Loss: 1.5940, Val Acc: 0.6753
# Precision: 0.6846, Recall: 0.6753, F1-score: 0.6756
# --------------------------------------------------
# Epoch [131/1500]
# Train Loss: 1.4334, Train Acc: 0.8392
# Val Loss: 1.5981, Val Acc: 0.6767
# Precision: 0.6831, Recall: 0.6767, F1-score: 0.6775
# --------------------------------------------------
# Epoch [132/1500]
# Train Loss: 1.4334, Train Acc: 0.8406
# Val Loss: 1.5859, Val Acc: 0.6739
# Precision: 0.6903, Recall: 0.6739, F1-score: 0.6775
# --------------------------------------------------
# Epoch [133/1500]
# Train Loss: 1.4296, Train Acc: 0.8429
# Val Loss: 1.6039, Val Acc: 0.6624
# Precision: 0.6912, Recall: 0.6624, F1-score: 0.6676
# --------------------------------------------------
# Epoch [134/1500]
# Train Loss: 1.4292, Train Acc: 0.8436
# Val Loss: 1.5966, Val Acc: 0.6763
# Precision: 0.6900, Recall: 0.6763, F1-score: 0.6786
# --------------------------------------------------
# Epoch [135/1500]
# Train Loss: 1.4250, Train Acc: 0.8480
# Val Loss: 1.5861, Val Acc: 0.6734
# Precision: 0.6820, Recall: 0.6734, F1-score: 0.6737
# --------------------------------------------------
# Epoch [136/1500]
# Train Loss: 1.4280, Train Acc: 0.8443
# Val Loss: 1.5602, Val Acc: 0.6950
# Precision: 0.7013, Recall: 0.6950, F1-score: 0.6963
# --------------------------------------------------
# Epoch [137/1500]
# Train Loss: 1.4161, Train Acc: 0.8564
# Val Loss: 1.5569, Val Acc: 0.7036
# Precision: 0.7166, Recall: 0.7036, F1-score: 0.7052
# --------------------------------------------------
# Epoch [138/1500]
# Train Loss: 1.4164, Train Acc: 0.8577
# Val Loss: 1.5707, Val Acc: 0.6993
# Precision: 0.7263, Recall: 0.6993, F1-score: 0.7042
# --------------------------------------------------
# Epoch [139/1500]
# Train Loss: 1.4177, Train Acc: 0.8546
# Val Loss: 1.5735, Val Acc: 0.6892
# Precision: 0.7046, Recall: 0.6892, F1-score: 0.6902
# --------------------------------------------------
# Epoch [140/1500]
# Train Loss: 1.4287, Train Acc: 0.8438
# Val Loss: 1.5630, Val Acc: 0.7046
# Precision: 0.7154, Recall: 0.7046, F1-score: 0.7066
# --------------------------------------------------
# Epoch [141/1500]
# Train Loss: 1.4186, Train Acc: 0.8554
# Val Loss: 1.5466, Val Acc: 0.7084
# Precision: 0.7205, Recall: 0.7084, F1-score: 0.7121
# --------------------------------------------------
# Epoch [142/1500]
# Train Loss: 1.4133, Train Acc: 0.8602
# Val Loss: 1.5677, Val Acc: 0.6887
# Precision: 0.6999, Recall: 0.6887, F1-score: 0.6912
# --------------------------------------------------
# Epoch [143/1500]
# Train Loss: 1.4192, Train Acc: 0.8537
# Val Loss: 1.5641, Val Acc: 0.6988
# Precision: 0.7056, Recall: 0.6988, F1-score: 0.6989
# --------------------------------------------------
# Epoch [144/1500]
# Train Loss: 1.4080, Train Acc: 0.8648
# Val Loss: 1.5662, Val Acc: 0.6950
# Precision: 0.7181, Recall: 0.6950, F1-score: 0.6976
# --------------------------------------------------
# Epoch [145/1500]
# Train Loss: 1.4114, Train Acc: 0.8618
# Val Loss: 1.5566, Val Acc: 0.7022
# Precision: 0.7143, Recall: 0.7022, F1-score: 0.7046
# --------------------------------------------------
# Epoch [146/1500]
# Train Loss: 1.4177, Train Acc: 0.8549
# Val Loss: 1.5563, Val Acc: 0.7108
# Precision: 0.7260, Recall: 0.7108, F1-score: 0.7129
# --------------------------------------------------
# Epoch [147/1500]
# Train Loss: 1.4062, Train Acc: 0.8682
# Val Loss: 1.5562, Val Acc: 0.7108
# Precision: 0.7295, Recall: 0.7108, F1-score: 0.7128
# --------------------------------------------------
# Epoch [148/1500]
# Train Loss: 1.4168, Train Acc: 0.8565
# Val Loss: 1.5439, Val Acc: 0.7122
# Precision: 0.7308, Recall: 0.7122, F1-score: 0.7143
# --------------------------------------------------
# Epoch [149/1500]
# Train Loss: 1.4187, Train Acc: 0.8533
# Val Loss: 1.5609, Val Acc: 0.6993
# Precision: 0.7100, Recall: 0.6993, F1-score: 0.6999
# --------------------------------------------------
# Epoch [150/1500]
# Train Loss: 1.4110, Train Acc: 0.8626
# Val Loss: 1.5426, Val Acc: 0.7194
# Precision: 0.7381, Recall: 0.7194, F1-score: 0.7224
# --------------------------------------------------
# Epoch [151/1500]
# Train Loss: 1.4135, Train Acc: 0.8608
# Val Loss: 1.5501, Val Acc: 0.7132
# Precision: 0.7218, Recall: 0.7132, F1-score: 0.7145
# --------------------------------------------------
# Epoch [152/1500]
# Train Loss: 1.4211, Train Acc: 0.8515
# Val Loss: 1.5964, Val Acc: 0.6652
# Precision: 0.6944, Recall: 0.6652, F1-score: 0.6696
# --------------------------------------------------
# Epoch [153/1500]
# Train Loss: 1.4221, Train Acc: 0.8491
# Val Loss: 1.5614, Val Acc: 0.6954
# Precision: 0.7018, Recall: 0.6954, F1-score: 0.6963
# --------------------------------------------------
# Epoch [154/1500]
# Train Loss: 1.4209, Train Acc: 0.8521
# Val Loss: 1.5645, Val Acc: 0.6945
# Precision: 0.6989, Recall: 0.6945, F1-score: 0.6948
# --------------------------------------------------
# Epoch [155/1500]
# Train Loss: 1.4230, Train Acc: 0.8505
# Val Loss: 1.5707, Val Acc: 0.6983
# Precision: 0.7045, Recall: 0.6983, F1-score: 0.6977
# --------------------------------------------------
# Epoch [156/1500]
# Train Loss: 1.4253, Train Acc: 0.8458
# Val Loss: 1.5733, Val Acc: 0.6796
# Precision: 0.6992, Recall: 0.6796, F1-score: 0.6842
# --------------------------------------------------
# Epoch [157/1500]
# Train Loss: 1.4209, Train Acc: 0.8522
# Val Loss: 1.5570, Val Acc: 0.6969
# Precision: 0.7156, Recall: 0.6969, F1-score: 0.7008
# --------------------------------------------------
# Epoch [158/1500]
# Train Loss: 1.4112, Train Acc: 0.8618
# Val Loss: 1.5598, Val Acc: 0.6959
# Precision: 0.7076, Recall: 0.6959, F1-score: 0.6980
# --------------------------------------------------
# Epoch [159/1500]
# Train Loss: 1.4108, Train Acc: 0.8620
# Val Loss: 1.5545, Val Acc: 0.7070
# Precision: 0.7171, Recall: 0.7070, F1-score: 0.7092
# --------------------------------------------------
# Epoch [160/1500]
# Train Loss: 1.4083, Train Acc: 0.8652
# Val Loss: 1.5553, Val Acc: 0.7094
# Precision: 0.7285, Recall: 0.7094, F1-score: 0.7109
# --------------------------------------------------
# Epoch [161/1500]
# Train Loss: 1.4104, Train Acc: 0.8636
# Val Loss: 1.5556, Val Acc: 0.7103
# Precision: 0.7261, Recall: 0.7103, F1-score: 0.7123
# --------------------------------------------------
# Epoch [162/1500]
# Train Loss: 1.4092, Train Acc: 0.8643
# Val Loss: 1.5591, Val Acc: 0.7031
# Precision: 0.7111, Recall: 0.7031, F1-score: 0.7026
# --------------------------------------------------
# Epoch [163/1500]
# Train Loss: 1.4082, Train Acc: 0.8647
# Val Loss: 1.5776, Val Acc: 0.6811
# Precision: 0.6970, Recall: 0.6811, F1-score: 0.6833
# --------------------------------------------------
# Epoch [164/1500]
# Train Loss: 1.4215, Train Acc: 0.8514
# Val Loss: 1.5794, Val Acc: 0.6873
# Precision: 0.7337, Recall: 0.6873, F1-score: 0.6962
# --------------------------------------------------
# Epoch [165/1500]
# Train Loss: 1.4166, Train Acc: 0.8556
# Val Loss: 1.5699, Val Acc: 0.6897
# Precision: 0.7040, Recall: 0.6897, F1-score: 0.6919
# --------------------------------------------------
# Epoch [166/1500]
# Train Loss: 1.4032, Train Acc: 0.8701
# Val Loss: 1.5430, Val Acc: 0.7113
# Precision: 0.7265, Recall: 0.7113, F1-score: 0.7129
# --------------------------------------------------
# Epoch [167/1500]
# Train Loss: 1.4011, Train Acc: 0.8719
# Val Loss: 1.5431, Val Acc: 0.7180
# Precision: 0.7237, Recall: 0.7180, F1-score: 0.7171
# --------------------------------------------------
# Epoch [168/1500]
# Train Loss: 1.4005, Train Acc: 0.8730
# Val Loss: 1.5577, Val Acc: 0.7161
# Precision: 0.7335, Recall: 0.7161, F1-score: 0.7191
# --------------------------------------------------
# Epoch [169/1500]
# Train Loss: 1.4076, Train Acc: 0.8655
# Val Loss: 1.5516, Val Acc: 0.7046
# Precision: 0.7183, Recall: 0.7046, F1-score: 0.7079
# --------------------------------------------------
# Epoch [170/1500]
# Train Loss: 1.4071, Train Acc: 0.8658
# Val Loss: 1.5689, Val Acc: 0.6844
# Precision: 0.6952, Recall: 0.6844, F1-score: 0.6862
# --------------------------------------------------
# Epoch [171/1500]
# Train Loss: 1.4010, Train Acc: 0.8720
# Val Loss: 1.5529, Val Acc: 0.7065
# Precision: 0.7222, Recall: 0.7065, F1-score: 0.7086
# --------------------------------------------------
# Epoch [172/1500]
# Train Loss: 1.3970, Train Acc: 0.8764
# Val Loss: 1.5493, Val Acc: 0.7132
# Precision: 0.7272, Recall: 0.7132, F1-score: 0.7154
# --------------------------------------------------
# Epoch [173/1500]
# Train Loss: 1.4003, Train Acc: 0.8745
# Val Loss: 1.5612, Val Acc: 0.7041
# Precision: 0.7212, Recall: 0.7041, F1-score: 0.7078
# --------------------------------------------------
# Epoch [174/1500]
# Train Loss: 1.4037, Train Acc: 0.8697
# Val Loss: 1.5482, Val Acc: 0.7103
# Precision: 0.7146, Recall: 0.7103, F1-score: 0.7110
# --------------------------------------------------
# Epoch [175/1500]
# Train Loss: 1.4066, Train Acc: 0.8674
# Val Loss: 1.5517, Val Acc: 0.7065
# Precision: 0.7189, Recall: 0.7065, F1-score: 0.7096
# --------------------------------------------------
# Epoch [176/1500]
# Train Loss: 1.4019, Train Acc: 0.8716
# Val Loss: 1.5401, Val Acc: 0.7194
# Precision: 0.7236, Recall: 0.7194, F1-score: 0.7201
# --------------------------------------------------
# Epoch [177/1500]
# Train Loss: 1.4002, Train Acc: 0.8730
# Val Loss: 1.5268, Val Acc: 0.7247
# Precision: 0.7296, Recall: 0.7247, F1-score: 0.7251
# --------------------------------------------------
# Epoch [178/1500]
# Train Loss: 1.4024, Train Acc: 0.8710
# Val Loss: 1.5322, Val Acc: 0.7209
# Precision: 0.7274, Recall: 0.7209, F1-score: 0.7220
# --------------------------------------------------
# Epoch [179/1500]
# Train Loss: 1.4021, Train Acc: 0.8702
# Val Loss: 1.5465, Val Acc: 0.7089
# Precision: 0.7157, Recall: 0.7089, F1-score: 0.7097
# --------------------------------------------------
# Epoch [180/1500]
# Train Loss: 1.4060, Train Acc: 0.8672
# Val Loss: 1.5383, Val Acc: 0.7122
# Precision: 0.7273, Recall: 0.7122, F1-score: 0.7157
# --------------------------------------------------
# Epoch [181/1500]
# Train Loss: 1.4077, Train Acc: 0.8657
# Val Loss: 1.5368, Val Acc: 0.7199
# Precision: 0.7308, Recall: 0.7199, F1-score: 0.7219
# --------------------------------------------------
# Epoch [182/1500]
# Train Loss: 1.4043, Train Acc: 0.8692
# Val Loss: 1.5459, Val Acc: 0.7122
# Precision: 0.7167, Recall: 0.7122, F1-score: 0.7130
# --------------------------------------------------
# Epoch [183/1500]
# Train Loss: 1.4102, Train Acc: 0.8622
# Val Loss: 1.5271, Val Acc: 0.7242
# Precision: 0.7320, Recall: 0.7242, F1-score: 0.7259
# --------------------------------------------------
# Epoch [184/1500]
# Train Loss: 1.4091, Train Acc: 0.8633
# Val Loss: 1.5731, Val Acc: 0.6950
# Precision: 0.7032, Recall: 0.6950, F1-score: 0.6945
# --------------------------------------------------
# Epoch [185/1500]
# Train Loss: 1.4124, Train Acc: 0.8610
# Val Loss: 1.5662, Val Acc: 0.6868
# Precision: 0.7005, Recall: 0.6868, F1-score: 0.6872
# --------------------------------------------------
# Epoch [186/1500]
# Train Loss: 1.3984, Train Acc: 0.8753
# Val Loss: 1.5348, Val Acc: 0.7271
# Precision: 0.7344, Recall: 0.7271, F1-score: 0.7294
# --------------------------------------------------
# Epoch [187/1500]
# Train Loss: 1.3985, Train Acc: 0.8746
# Val Loss: 1.5460, Val Acc: 0.7189
# Precision: 0.7319, Recall: 0.7189, F1-score: 0.7222
# --------------------------------------------------
# Epoch [188/1500]
# Train Loss: 1.4004, Train Acc: 0.8735
# Val Loss: 1.5491, Val Acc: 0.7084
# Precision: 0.7209, Recall: 0.7084, F1-score: 0.7096
# --------------------------------------------------
# Epoch [189/1500]
# Train Loss: 1.4008, Train Acc: 0.8715
# Val Loss: 1.5450, Val Acc: 0.7161
# Precision: 0.7208, Recall: 0.7161, F1-score: 0.7171
# --------------------------------------------------
# Epoch [190/1500]
# Train Loss: 1.3986, Train Acc: 0.8747
# Val Loss: 1.5450, Val Acc: 0.7089
# Precision: 0.7119, Recall: 0.7089, F1-score: 0.7094
# --------------------------------------------------
# Epoch [191/1500]
# Train Loss: 1.3989, Train Acc: 0.8747
# Val Loss: 1.5645, Val Acc: 0.6959
# Precision: 0.7120, Recall: 0.6959, F1-score: 0.6984
# --------------------------------------------------
# Epoch [192/1500]
# Train Loss: 1.3975, Train Acc: 0.8758
# Val Loss: 1.5407, Val Acc: 0.7185
# Precision: 0.7360, Recall: 0.7185, F1-score: 0.7220
# --------------------------------------------------
# Epoch [193/1500]
# Train Loss: 1.3972, Train Acc: 0.8759
# Val Loss: 1.5616, Val Acc: 0.7026
# Precision: 0.7096, Recall: 0.7026, F1-score: 0.7019
# --------------------------------------------------
# Epoch [194/1500]
# Train Loss: 1.4009, Train Acc: 0.8721
# Val Loss: 1.5489, Val Acc: 0.7209
# Precision: 0.7329, Recall: 0.7209, F1-score: 0.7228
# --------------------------------------------------
# Epoch [195/1500]
# Train Loss: 1.4076, Train Acc: 0.8654
# Val Loss: 1.5860, Val Acc: 0.6796
# Precision: 0.7005, Recall: 0.6796, F1-score: 0.6836
# --------------------------------------------------
# Epoch [196/1500]
# Train Loss: 1.4048, Train Acc: 0.8683
# Val Loss: 1.5641, Val Acc: 0.7055
# Precision: 0.7130, Recall: 0.7055, F1-score: 0.7066
# --------------------------------------------------
# Epoch [197/1500]
# Train Loss: 1.3993, Train Acc: 0.8753
# Val Loss: 1.5510, Val Acc: 0.7151
# Precision: 0.7420, Recall: 0.7151, F1-score: 0.7200
# --------------------------------------------------
# Epoch [198/1500]
# Train Loss: 1.3954, Train Acc: 0.8773
# Val Loss: 1.5347, Val Acc: 0.7276
# Precision: 0.7350, Recall: 0.7276, F1-score: 0.7296
# --------------------------------------------------
# Epoch [199/1500]
# Train Loss: 1.3952, Train Acc: 0.8782
# Val Loss: 1.5462, Val Acc: 0.7094
# Precision: 0.7110, Recall: 0.7094, F1-score: 0.7090
# --------------------------------------------------
# Epoch [200/1500]
# Train Loss: 1.3897, Train Acc: 0.8838
# Val Loss: 1.5472, Val Acc: 0.7108
# Precision: 0.7233, Recall: 0.7108, F1-score: 0.7117
# --------------------------------------------------
# Epoch [201/1500]
# Train Loss: 1.3885, Train Acc: 0.8851
# Val Loss: 1.5476, Val Acc: 0.7118
# Precision: 0.7277, Recall: 0.7118, F1-score: 0.7155
# --------------------------------------------------
# Epoch [202/1500]
# Train Loss: 1.3886, Train Acc: 0.8853
# Val Loss: 1.5385, Val Acc: 0.7233
# Precision: 0.7306, Recall: 0.7233, F1-score: 0.7226
# --------------------------------------------------
# Epoch [203/1500]
# Train Loss: 1.3996, Train Acc: 0.8735
# Val Loss: 1.5215, Val Acc: 0.7381
# Precision: 0.7413, Recall: 0.7381, F1-score: 0.7388
# --------------------------------------------------
# Epoch [204/1500]
# Train Loss: 1.3861, Train Acc: 0.8883
# Val Loss: 1.5462, Val Acc: 0.7118
# Precision: 0.7151, Recall: 0.7118, F1-score: 0.7125
# --------------------------------------------------
# Epoch [205/1500]
# Train Loss: 1.3964, Train Acc: 0.8765
# Val Loss: 1.5440, Val Acc: 0.7242
# Precision: 0.7357, Recall: 0.7242, F1-score: 0.7260
# --------------------------------------------------
# Epoch [206/1500]
# Train Loss: 1.4000, Train Acc: 0.8735
# Val Loss: 1.5588, Val Acc: 0.6969
# Precision: 0.7026, Recall: 0.6969, F1-score: 0.6978
# --------------------------------------------------
# Epoch [207/1500]
# Train Loss: 1.4042, Train Acc: 0.8684
# Val Loss: 1.5714, Val Acc: 0.6964
# Precision: 0.7110, Recall: 0.6964, F1-score: 0.6958
# --------------------------------------------------
# Epoch [208/1500]
# Train Loss: 1.4009, Train Acc: 0.8717
# Val Loss: 1.5454, Val Acc: 0.7132
# Precision: 0.7269, Recall: 0.7132, F1-score: 0.7133
# --------------------------------------------------
# Epoch [209/1500]
# Train Loss: 1.3965, Train Acc: 0.8769
# Val Loss: 1.5312, Val Acc: 0.7261
# Precision: 0.7334, Recall: 0.7261, F1-score: 0.7273
# --------------------------------------------------
# Epoch [210/1500]
# Train Loss: 1.3888, Train Acc: 0.8847
# Val Loss: 1.5349, Val Acc: 0.7218
# Precision: 0.7268, Recall: 0.7218, F1-score: 0.7222
# --------------------------------------------------
# Epoch [211/1500]
# Train Loss: 1.3872, Train Acc: 0.8860
# Val Loss: 1.5356, Val Acc: 0.7185
# Precision: 0.7210, Recall: 0.7185, F1-score: 0.7186
# --------------------------------------------------
# Epoch [212/1500]
# Train Loss: 1.3911, Train Acc: 0.8820
# Val Loss: 1.5387, Val Acc: 0.7132
# Precision: 0.7295, Recall: 0.7132, F1-score: 0.7167
# --------------------------------------------------
# Epoch [213/1500]
# Train Loss: 1.3936, Train Acc: 0.8788
# Val Loss: 1.5409, Val Acc: 0.7194
# Precision: 0.7260, Recall: 0.7194, F1-score: 0.7194
# --------------------------------------------------
# Epoch [214/1500]
# Train Loss: 1.3967, Train Acc: 0.8763
# Val Loss: 1.5459, Val Acc: 0.7151
# Precision: 0.7200, Recall: 0.7151, F1-score: 0.7159
# --------------------------------------------------
# Epoch [215/1500]
# Train Loss: 1.4066, Train Acc: 0.8670
# Val Loss: 1.5803, Val Acc: 0.6772
# Precision: 0.6928, Recall: 0.6772, F1-score: 0.6790
# --------------------------------------------------
# Epoch [216/1500]
# Train Loss: 1.4012, Train Acc: 0.8710
# Val Loss: 1.5694, Val Acc: 0.6926
# Precision: 0.7157, Recall: 0.6926, F1-score: 0.6935
# --------------------------------------------------
# Epoch [217/1500]
# Train Loss: 1.3925, Train Acc: 0.8812
# Val Loss: 1.5642, Val Acc: 0.6983
# Precision: 0.7147, Recall: 0.6983, F1-score: 0.7011
# --------------------------------------------------
# Epoch [218/1500]
# Train Loss: 1.3951, Train Acc: 0.8765
# Val Loss: 1.5650, Val Acc: 0.6926
# Precision: 0.7061, Recall: 0.6926, F1-score: 0.6942
# --------------------------------------------------
# Epoch [219/1500]
# Train Loss: 1.3896, Train Acc: 0.8843
# Val Loss: 1.5403, Val Acc: 0.7170
# Precision: 0.7338, Recall: 0.7170, F1-score: 0.7181
# --------------------------------------------------
# Epoch [220/1500]
# Train Loss: 1.3896, Train Acc: 0.8837
# Val Loss: 1.5325, Val Acc: 0.7237
# Precision: 0.7305, Recall: 0.7237, F1-score: 0.7255
# --------------------------------------------------
# Epoch [221/1500]
# Train Loss: 1.3966, Train Acc: 0.8760
# Val Loss: 1.5556, Val Acc: 0.6988
# Precision: 0.7038, Recall: 0.6988, F1-score: 0.6999
# --------------------------------------------------
# Epoch [222/1500]
# Train Loss: 1.3943, Train Acc: 0.8794
# Val Loss: 1.5472, Val Acc: 0.7137
# Precision: 0.7287, Recall: 0.7137, F1-score: 0.7150
# --------------------------------------------------
# Epoch [223/1500]
# Train Loss: 1.3878, Train Acc: 0.8853
# Val Loss: 1.5251, Val Acc: 0.7281
# Precision: 0.7325, Recall: 0.7281, F1-score: 0.7279
# --------------------------------------------------
# Epoch [224/1500]
# Train Loss: 1.3845, Train Acc: 0.8897
# Val Loss: 1.5481, Val Acc: 0.7041
# Precision: 0.7090, Recall: 0.7041, F1-score: 0.7042
# --------------------------------------------------
# Epoch [225/1500]
# Train Loss: 1.3911, Train Acc: 0.8821
# Val Loss: 1.5384, Val Acc: 0.7141
# Precision: 0.7256, Recall: 0.7141, F1-score: 0.7168
# --------------------------------------------------
# Epoch [226/1500]
# Train Loss: 1.3928, Train Acc: 0.8804
# Val Loss: 1.5990, Val Acc: 0.6657
# Precision: 0.7000, Recall: 0.6657, F1-score: 0.6702
# --------------------------------------------------
# Epoch [227/1500]
# Train Loss: 1.3925, Train Acc: 0.8815
# Val Loss: 1.5320, Val Acc: 0.7257
# Precision: 0.7285, Recall: 0.7257, F1-score: 0.7262
# --------------------------------------------------
# Epoch [228/1500]
# Train Loss: 1.3874, Train Acc: 0.8863
# Val Loss: 1.5293, Val Acc: 0.7305
# Precision: 0.7387, Recall: 0.7305, F1-score: 0.7316
# --------------------------------------------------
# Epoch [229/1500]
# Train Loss: 1.3824, Train Acc: 0.8915
# Val Loss: 1.5247, Val Acc: 0.7290
# Precision: 0.7427, Recall: 0.7290, F1-score: 0.7311
# --------------------------------------------------
# Epoch [230/1500]
# Train Loss: 1.3803, Train Acc: 0.8928
# Val Loss: 1.5315, Val Acc: 0.7271
# Precision: 0.7428, Recall: 0.7271, F1-score: 0.7311
# --------------------------------------------------
# Epoch [231/1500]
# Train Loss: 1.3868, Train Acc: 0.8858
# Val Loss: 1.5428, Val Acc: 0.7141
# Precision: 0.7323, Recall: 0.7141, F1-score: 0.7176
# --------------------------------------------------
# Epoch [232/1500]
# Train Loss: 1.3877, Train Acc: 0.8856
# Val Loss: 1.5533, Val Acc: 0.7055
# Precision: 0.7176, Recall: 0.7055, F1-score: 0.7089
# --------------------------------------------------
# Epoch [233/1500]
# Train Loss: 1.3885, Train Acc: 0.8844
# Val Loss: 1.5456, Val Acc: 0.7156
# Precision: 0.7324, Recall: 0.7156, F1-score: 0.7181
# --------------------------------------------------
# Epoch [234/1500]
# Train Loss: 1.3867, Train Acc: 0.8874
# Val Loss: 1.5610, Val Acc: 0.7031
# Precision: 0.7109, Recall: 0.7031, F1-score: 0.7045
# --------------------------------------------------
# Epoch [235/1500]
# Train Loss: 1.3920, Train Acc: 0.8815
# Val Loss: 1.5441, Val Acc: 0.7209
# Precision: 0.7311, Recall: 0.7209, F1-score: 0.7230
# --------------------------------------------------
# Epoch [236/1500]
# Train Loss: 1.3805, Train Acc: 0.8926
# Val Loss: 1.5347, Val Acc: 0.7247
# Precision: 0.7318, Recall: 0.7247, F1-score: 0.7258
# --------------------------------------------------
# Epoch [237/1500]
# Train Loss: 1.3798, Train Acc: 0.8943
# Val Loss: 1.5396, Val Acc: 0.7237
# Precision: 0.7285, Recall: 0.7237, F1-score: 0.7237
# --------------------------------------------------
# Epoch [238/1500]
# Train Loss: 1.3809, Train Acc: 0.8932
# Val Loss: 1.5619, Val Acc: 0.6916
# Precision: 0.7056, Recall: 0.6916, F1-score: 0.6935
# --------------------------------------------------
# Epoch [239/1500]
# Train Loss: 1.3848, Train Acc: 0.8878
# Val Loss: 1.5294, Val Acc: 0.7204
# Precision: 0.7248, Recall: 0.7204, F1-score: 0.7205
# --------------------------------------------------
# Epoch [240/1500]
# Train Loss: 1.3868, Train Acc: 0.8868
# Val Loss: 1.5444, Val Acc: 0.7089
# Precision: 0.7191, Recall: 0.7089, F1-score: 0.7110
# --------------------------------------------------
# Epoch [241/1500]
# Train Loss: 1.3852, Train Acc: 0.8879
# Val Loss: 1.5337, Val Acc: 0.7189
# Precision: 0.7248, Recall: 0.7189, F1-score: 0.7193
# --------------------------------------------------
# Epoch [242/1500]
# Train Loss: 1.3799, Train Acc: 0.8941
# Val Loss: 1.5306, Val Acc: 0.7242
# Precision: 0.7337, Recall: 0.7242, F1-score: 0.7255
# --------------------------------------------------
# Epoch [243/1500]
# Train Loss: 1.3875, Train Acc: 0.8858
# Val Loss: 1.5341, Val Acc: 0.7257
# Precision: 0.7376, Recall: 0.7257, F1-score: 0.7285
# --------------------------------------------------
# Epoch [244/1500]
# Train Loss: 1.3780, Train Acc: 0.8957
# Val Loss: 1.5173, Val Acc: 0.7463
# Precision: 0.7557, Recall: 0.7463, F1-score: 0.7473
# --------------------------------------------------
# Epoch [245/1500]
# Train Loss: 1.3805, Train Acc: 0.8931
# Val Loss: 1.5495, Val Acc: 0.7055
# Precision: 0.7303, Recall: 0.7055, F1-score: 0.7107
# --------------------------------------------------
# Epoch [246/1500]
# Train Loss: 1.3835, Train Acc: 0.8912
# Val Loss: 1.5457, Val Acc: 0.7141
# Precision: 0.7346, Recall: 0.7141, F1-score: 0.7158
# --------------------------------------------------
# Epoch [247/1500]
# Train Loss: 1.3891, Train Acc: 0.8843
# Val Loss: 1.5385, Val Acc: 0.7175
# Precision: 0.7315, Recall: 0.7175, F1-score: 0.7197
# --------------------------------------------------
# Epoch [248/1500]
# Train Loss: 1.3892, Train Acc: 0.8838
# Val Loss: 1.5601, Val Acc: 0.6950
# Precision: 0.7141, Recall: 0.6950, F1-score: 0.6967
# --------------------------------------------------
# Epoch [249/1500]
# Train Loss: 1.3895, Train Acc: 0.8841
# Val Loss: 1.5427, Val Acc: 0.7165
# Precision: 0.7331, Recall: 0.7165, F1-score: 0.7189
# --------------------------------------------------
# Epoch [250/1500]
# Train Loss: 1.3992, Train Acc: 0.8735
# Val Loss: 1.5217, Val Acc: 0.7305
# Precision: 0.7372, Recall: 0.7305, F1-score: 0.7313
# --------------------------------------------------
# Epoch [251/1500]
# Train Loss: 1.3948, Train Acc: 0.8773
# Val Loss: 1.5337, Val Acc: 0.7247
# ...
# Val Loss: 1.4953, Val Acc: 0.7640
# Precision: 0.7665, Recall: 0.7640, F1-score: 0.7643
# --------------------------------------------------
# Epoch [1419/1500]
# Train Loss: 1.2962, Train Acc: 0.9777
# Val Loss: 1.4951, Val Acc: 0.7669
# Precision: 0.7681, Recall: 0.7669, F1-score: 0.7664
# --------------------------------------------------
# Epoch [1420/1500]
# Train Loss: 1.3004, Train Acc: 0.9737
# Val Loss: 1.5128, Val Acc: 0.7415
# Precision: 0.7485, Recall: 0.7415, F1-score: 0.7418
# --------------------------------------------------
# Epoch [1421/1500]
# Train Loss: 1.3036, Train Acc: 0.9708
# Val Loss: 1.5128, Val Acc: 0.7496
# Precision: 0.7528, Recall: 0.7496, F1-score: 0.7497
# --------------------------------------------------
# Epoch [1422/1500]
# Train Loss: 1.3055, Train Acc: 0.9685
# Val Loss: 1.5230, Val Acc: 0.7376
# Precision: 0.7473, Recall: 0.7376, F1-score: 0.7394
# --------------------------------------------------
# Epoch [1423/1500]
# Train Loss: 1.2993, Train Acc: 0.9754
# Val Loss: 1.5098, Val Acc: 0.7492
# Precision: 0.7514, Recall: 0.7492, F1-score: 0.7487
# --------------------------------------------------
# Epoch [1424/1500]
# Train Loss: 1.3023, Train Acc: 0.9719
# Val Loss: 1.5092, Val Acc: 0.7530
# Precision: 0.7589, Recall: 0.7530, F1-score: 0.7541
# --------------------------------------------------
# Epoch [1425/1500]
# Train Loss: 1.3026, Train Acc: 0.9712
# Val Loss: 1.5220, Val Acc: 0.7429
# Precision: 0.7468, Recall: 0.7429, F1-score: 0.7438
# --------------------------------------------------
# Epoch [1426/1500]
# Train Loss: 1.3026, Train Acc: 0.9710
# Val Loss: 1.4899, Val Acc: 0.7722
# Precision: 0.7749, Recall: 0.7722, F1-score: 0.7716
# --------------------------------------------------
# Epoch [1427/1500]
# Train Loss: 1.2999, Train Acc: 0.9745
# Val Loss: 1.4972, Val Acc: 0.7635
# Precision: 0.7704, Recall: 0.7635, F1-score: 0.7646
# --------------------------------------------------
# Epoch [1428/1500]
# Train Loss: 1.3026, Train Acc: 0.9720
# Val Loss: 1.5118, Val Acc: 0.7492
# Precision: 0.7502, Recall: 0.7492, F1-score: 0.7486
# --------------------------------------------------
# Epoch [1429/1500]
# Train Loss: 1.2991, Train Acc: 0.9748
# Val Loss: 1.4968, Val Acc: 0.7698
# Precision: 0.7714, Recall: 0.7698, F1-score: 0.7698
# --------------------------------------------------
# Epoch [1430/1500]
# Train Loss: 1.3046, Train Acc: 0.9698
# Val Loss: 1.5176, Val Acc: 0.7487
# Precision: 0.7499, Recall: 0.7487, F1-score: 0.7483
# --------------------------------------------------
# Epoch [1431/1500]
# Train Loss: 1.3009, Train Acc: 0.9732
# Val Loss: 1.5049, Val Acc: 0.7554
# Precision: 0.7560, Recall: 0.7554, F1-score: 0.7550
# --------------------------------------------------
# Epoch [1432/1500]
# Train Loss: 1.3048, Train Acc: 0.9695
# Val Loss: 1.5046, Val Acc: 0.7612
# Precision: 0.7669, Recall: 0.7612, F1-score: 0.7622
# --------------------------------------------------
# Epoch [1433/1500]
# Train Loss: 1.2976, Train Acc: 0.9766
# Val Loss: 1.4934, Val Acc: 0.7698
# Precision: 0.7715, Recall: 0.7698, F1-score: 0.7693
# --------------------------------------------------
# Epoch [1434/1500]
# Train Loss: 1.2955, Train Acc: 0.9783
# Val Loss: 1.4914, Val Acc: 0.7803
# Precision: 0.7817, Recall: 0.7803, F1-score: 0.7801
# --------------------------------------------------
# Epoch [1435/1500]
# Train Loss: 1.2938, Train Acc: 0.9803
# Val Loss: 1.4913, Val Acc: 0.7736
# Precision: 0.7758, Recall: 0.7736, F1-score: 0.7737
# --------------------------------------------------
# Epoch [1436/1500]
# Train Loss: 1.3003, Train Acc: 0.9739
# Val Loss: 1.4941, Val Acc: 0.7578
# Precision: 0.7625, Recall: 0.7578, F1-score: 0.7575
# --------------------------------------------------
# Epoch [1437/1500]
# Train Loss: 1.3001, Train Acc: 0.9735
# Val Loss: 1.5024, Val Acc: 0.7607
# Precision: 0.7618, Recall: 0.7607, F1-score: 0.7604
# --------------------------------------------------
# Epoch [1438/1500]
# Train Loss: 1.2988, Train Acc: 0.9753
# Val Loss: 1.4992, Val Acc: 0.7607
# Precision: 0.7648, Recall: 0.7607, F1-score: 0.7614
# --------------------------------------------------
# Epoch [1439/1500]
# Train Loss: 1.2946, Train Acc: 0.9799
# Val Loss: 1.4690, Val Acc: 0.7938
# Precision: 0.7980, Recall: 0.7938, F1-score: 0.7946
# --------------------------------------------------
# Epoch [1440/1500]
# Train Loss: 1.2963, Train Acc: 0.9778
# Val Loss: 1.4828, Val Acc: 0.7832
# Precision: 0.7845, Recall: 0.7832, F1-score: 0.7833
# --------------------------------------------------
# Epoch [1441/1500]
# Train Loss: 1.2968, Train Acc: 0.9774
# Val Loss: 1.4817, Val Acc: 0.7789
# Precision: 0.7794, Recall: 0.7789, F1-score: 0.7786
# --------------------------------------------------
# Epoch [1442/1500]
# Train Loss: 1.2983, Train Acc: 0.9762
# Val Loss: 1.5106, Val Acc: 0.7482
# Precision: 0.7511, Recall: 0.7482, F1-score: 0.7484
# --------------------------------------------------
# Epoch [1443/1500]
# Train Loss: 1.3000, Train Acc: 0.9740
# Val Loss: 1.4831, Val Acc: 0.7770
# Precision: 0.7793, Recall: 0.7770, F1-score: 0.7776
# --------------------------------------------------
# Epoch [1444/1500]
# Train Loss: 1.2955, Train Acc: 0.9784
# Val Loss: 1.4989, Val Acc: 0.7693
# Precision: 0.7722, Recall: 0.7693, F1-score: 0.7699
# --------------------------------------------------
# Epoch [1445/1500]
# Train Loss: 1.2982, Train Acc: 0.9757
# Val Loss: 1.5066, Val Acc: 0.7540
# Precision: 0.7584, Recall: 0.7540, F1-score: 0.7543
# --------------------------------------------------
# Epoch [1446/1500]
# Train Loss: 1.2974, Train Acc: 0.9763
# Val Loss: 1.4979, Val Acc: 0.7650
# Precision: 0.7674, Recall: 0.7650, F1-score: 0.7644
# --------------------------------------------------
# Epoch [1447/1500]
# Train Loss: 1.2995, Train Acc: 0.9746
# Val Loss: 1.5186, Val Acc: 0.7453
# Precision: 0.7501, Recall: 0.7453, F1-score: 0.7460
# --------------------------------------------------
# Epoch [1448/1500]
# Train Loss: 1.3002, Train Acc: 0.9738
# Val Loss: 1.5226, Val Acc: 0.7386
# Precision: 0.7485, Recall: 0.7386, F1-score: 0.7390
# --------------------------------------------------
# Epoch [1449/1500]
# Train Loss: 1.2990, Train Acc: 0.9743
# Val Loss: 1.5084, Val Acc: 0.7578
# Precision: 0.7593, Recall: 0.7578, F1-score: 0.7582
# --------------------------------------------------
# Epoch [1450/1500]
# Train Loss: 1.3035, Train Acc: 0.9707
# Val Loss: 1.5060, Val Acc: 0.7573
# Precision: 0.7633, Recall: 0.7573, F1-score: 0.7584
# --------------------------------------------------
# Epoch [1451/1500]
# Train Loss: 1.3057, Train Acc: 0.9684
# Val Loss: 1.5024, Val Acc: 0.7626
# Precision: 0.7682, Recall: 0.7626, F1-score: 0.7625
# --------------------------------------------------
# Epoch [1452/1500]
# Train Loss: 1.2994, Train Acc: 0.9747
# Val Loss: 1.5184, Val Acc: 0.7420
# Precision: 0.7442, Recall: 0.7420, F1-score: 0.7418
# --------------------------------------------------
# Epoch [1453/1500]
# Train Loss: 1.3039, Train Acc: 0.9695
# Val Loss: 1.5200, Val Acc: 0.7453
# Precision: 0.7496, Recall: 0.7453, F1-score: 0.7458
# --------------------------------------------------
# Epoch [1454/1500]
# Train Loss: 1.3044, Train Acc: 0.9694
# Val Loss: 1.5239, Val Acc: 0.7458
# Precision: 0.7487, Recall: 0.7458, F1-score: 0.7453
# --------------------------------------------------
# Epoch [1455/1500]
# Train Loss: 1.2997, Train Acc: 0.9748
# Val Loss: 1.4995, Val Acc: 0.7722
# Precision: 0.7726, Recall: 0.7722, F1-score: 0.7714
# --------------------------------------------------
# Epoch [1456/1500]
# Train Loss: 1.2953, Train Acc: 0.9793
# Val Loss: 1.4938, Val Acc: 0.7770
# Precision: 0.7788, Recall: 0.7770, F1-score: 0.7768
# --------------------------------------------------
# Epoch [1457/1500]
# Train Loss: 1.2970, Train Acc: 0.9766
# Val Loss: 1.4975, Val Acc: 0.7621
# Precision: 0.7628, Recall: 0.7621, F1-score: 0.7616
# --------------------------------------------------
# Epoch [1458/1500]
# Train Loss: 1.2974, Train Acc: 0.9768
# Val Loss: 1.5008, Val Acc: 0.7664
# Precision: 0.7681, Recall: 0.7664, F1-score: 0.7664
# --------------------------------------------------
# Epoch [1459/1500]
# Train Loss: 1.2966, Train Acc: 0.9775
# Val Loss: 1.5031, Val Acc: 0.7612
# Precision: 0.7634, Recall: 0.7612, F1-score: 0.7610
# --------------------------------------------------
# Epoch [1460/1500]
# Train Loss: 1.2976, Train Acc: 0.9763
# Val Loss: 1.5033, Val Acc: 0.7621
# Precision: 0.7631, Recall: 0.7621, F1-score: 0.7615
# --------------------------------------------------
# Epoch [1461/1500]
# Train Loss: 1.2989, Train Acc: 0.9750
# Val Loss: 1.5054, Val Acc: 0.7588
# Precision: 0.7597, Recall: 0.7588, F1-score: 0.7585
# --------------------------------------------------
# Epoch [1462/1500]
# Train Loss: 1.2966, Train Acc: 0.9781
# Val Loss: 1.5079, Val Acc: 0.7588
# Precision: 0.7672, Recall: 0.7588, F1-score: 0.7603
# --------------------------------------------------
# Epoch [1463/1500]
# Train Loss: 1.2942, Train Acc: 0.9802
# Val Loss: 1.4816, Val Acc: 0.7813
# Precision: 0.7835, Recall: 0.7813, F1-score: 0.7814
# --------------------------------------------------
# Epoch [1464/1500]
# Train Loss: 1.2957, Train Acc: 0.9784
# Val Loss: 1.5133, Val Acc: 0.7468
# Precision: 0.7554, Recall: 0.7468, F1-score: 0.7485
# --------------------------------------------------
# Epoch [1465/1500]
# Train Loss: 1.3014, Train Acc: 0.9727
# Val Loss: 1.5104, Val Acc: 0.7530
# Precision: 0.7574, Recall: 0.7530, F1-score: 0.7534
# --------------------------------------------------
# Epoch [1466/1500]
# Train Loss: 1.2997, Train Acc: 0.9746
# Val Loss: 1.4875, Val Acc: 0.7731
# Precision: 0.7768, Recall: 0.7731, F1-score: 0.7739
# --------------------------------------------------
# Epoch [1467/1500]
# Train Loss: 1.2964, Train Acc: 0.9779
# Val Loss: 1.4914, Val Acc: 0.7679
# Precision: 0.7684, Recall: 0.7679, F1-score: 0.7677
# --------------------------------------------------
# Epoch [1468/1500]
# Train Loss: 1.2985, Train Acc: 0.9754
# Val Loss: 1.5068, Val Acc: 0.7607
# Precision: 0.7644, Recall: 0.7607, F1-score: 0.7610
# --------------------------------------------------
# Epoch [1469/1500]
# Train Loss: 1.2983, Train Acc: 0.9759
# Val Loss: 1.4934, Val Acc: 0.7679
# Precision: 0.7704, Recall: 0.7679, F1-score: 0.7683
# --------------------------------------------------
# Epoch [1470/1500]
# Train Loss: 1.2971, Train Acc: 0.9765
# Val Loss: 1.4944, Val Acc: 0.7669
# Precision: 0.7703, Recall: 0.7669, F1-score: 0.7673
# --------------------------------------------------
# Epoch [1471/1500]
# Train Loss: 1.3022, Train Acc: 0.9719
# Val Loss: 1.4987, Val Acc: 0.7592
# Precision: 0.7672, Recall: 0.7592, F1-score: 0.7607
# --------------------------------------------------
# Epoch [1472/1500]
# Train Loss: 1.2957, Train Acc: 0.9788
# Val Loss: 1.5035, Val Acc: 0.7583
# Precision: 0.7603, Recall: 0.7583, F1-score: 0.7580
# --------------------------------------------------
# Epoch [1473/1500]
# Train Loss: 1.2972, Train Acc: 0.9768
# Val Loss: 1.5206, Val Acc: 0.7386
# Precision: 0.7399, Recall: 0.7386, F1-score: 0.7381
# --------------------------------------------------
# Epoch [1474/1500]
# Train Loss: 1.2980, Train Acc: 0.9759
# Val Loss: 1.4953, Val Acc: 0.7659
# Precision: 0.7663, Recall: 0.7659, F1-score: 0.7651
# --------------------------------------------------
# Epoch [1475/1500]
# Train Loss: 1.2959, Train Acc: 0.9779
# Val Loss: 1.4841, Val Acc: 0.7794
# Precision: 0.7811, Recall: 0.7794, F1-score: 0.7795
# --------------------------------------------------
# Epoch [1476/1500]
# Train Loss: 1.2917, Train Acc: 0.9828
# Val Loss: 1.4881, Val Acc: 0.7789
# Precision: 0.7804, Recall: 0.7789, F1-score: 0.7789
# --------------------------------------------------
# Epoch [1477/1500]
# Train Loss: 1.2944, Train Acc: 0.9801
# Val Loss: 1.4902, Val Acc: 0.7698
# Precision: 0.7733, Recall: 0.7698, F1-score: 0.7705
# --------------------------------------------------
# Epoch [1478/1500]
# Train Loss: 1.2953, Train Acc: 0.9790
# Val Loss: 1.4783, Val Acc: 0.7823
# Precision: 0.7838, Recall: 0.7823, F1-score: 0.7817
# --------------------------------------------------
# Epoch [1479/1500]
# Train Loss: 1.2952, Train Acc: 0.9789
# Val Loss: 1.4992, Val Acc: 0.7712
# Precision: 0.7773, Recall: 0.7712, F1-score: 0.7715
# --------------------------------------------------
# Epoch [1480/1500]
# Train Loss: 1.2921, Train Acc: 0.9820
# Val Loss: 1.4953, Val Acc: 0.7664
# Precision: 0.7678, Recall: 0.7664, F1-score: 0.7667
# --------------------------------------------------
# Epoch [1481/1500]
# Train Loss: 1.2935, Train Acc: 0.9805
# Val Loss: 1.4912, Val Acc: 0.7722
# Precision: 0.7761, Recall: 0.7722, F1-score: 0.7728
# --------------------------------------------------
# Epoch [1482/1500]
# Train Loss: 1.2926, Train Acc: 0.9816
# Val Loss: 1.4855, Val Acc: 0.7818
# Precision: 0.7871, Recall: 0.7818, F1-score: 0.7827
# --------------------------------------------------
# Epoch [1483/1500]
# Train Loss: 1.2933, Train Acc: 0.9808
# Val Loss: 1.5178, Val Acc: 0.7463
# Precision: 0.7550, Recall: 0.7463, F1-score: 0.7469
# --------------------------------------------------
# Epoch [1484/1500]
# Train Loss: 1.2959, Train Acc: 0.9782
# Val Loss: 1.4967, Val Acc: 0.7640
# Precision: 0.7698, Recall: 0.7640, F1-score: 0.7646
# --------------------------------------------------
# Epoch [1485/1500]
# Train Loss: 1.2973, Train Acc: 0.9768
# Val Loss: 1.5038, Val Acc: 0.7592
# Precision: 0.7597, Recall: 0.7592, F1-score: 0.7586
# --------------------------------------------------
# Epoch [1486/1500]
# Train Loss: 1.2977, Train Acc: 0.9766
# Val Loss: 1.5012, Val Acc: 0.7635
# Precision: 0.7654, Recall: 0.7635, F1-score: 0.7637
# --------------------------------------------------
# Epoch [1487/1500]
# Train Loss: 1.2995, Train Acc: 0.9750
# Val Loss: 1.4904, Val Acc: 0.7784
# Precision: 0.7787, Recall: 0.7784, F1-score: 0.7781
# --------------------------------------------------
# Epoch [1488/1500]
# Train Loss: 1.2947, Train Acc: 0.9800
# Val Loss: 1.5088, Val Acc: 0.7578
# Precision: 0.7615, Recall: 0.7578, F1-score: 0.7584
# --------------------------------------------------
# Epoch [1489/1500]
# Train Loss: 1.3030, Train Acc: 0.9703
# Val Loss: 1.5459, Val Acc: 0.7204
# Precision: 0.7386, Recall: 0.7204, F1-score: 0.7222
# --------------------------------------------------
# Epoch [1490/1500]
# Train Loss: 1.2967, Train Acc: 0.9781
# Val Loss: 1.4961, Val Acc: 0.7645
# Precision: 0.7689, Recall: 0.7645, F1-score: 0.7645
# --------------------------------------------------
# Epoch [1491/1500]
# Train Loss: 1.3000, Train Acc: 0.9748
# Val Loss: 1.5018, Val Acc: 0.7583
# Precision: 0.7633, Recall: 0.7583, F1-score: 0.7584
# --------------------------------------------------
# Epoch [1492/1500]
# Train Loss: 1.3023, Train Acc: 0.9717
# Val Loss: 1.5113, Val Acc: 0.7487
# Precision: 0.7511, Recall: 0.7487, F1-score: 0.7486
# --------------------------------------------------
# Epoch [1493/1500]
# Train Loss: 1.3009, Train Acc: 0.9728
# Val Loss: 1.5045, Val Acc: 0.7583
# Precision: 0.7622, Recall: 0.7583, F1-score: 0.7588
# --------------------------------------------------
# Epoch [1494/1500]
# Train Loss: 1.2969, Train Acc: 0.9774
# Val Loss: 1.4972, Val Acc: 0.7674
# Precision: 0.7684, Recall: 0.7674, F1-score: 0.7674
# --------------------------------------------------
# Epoch [1495/1500]
# Train Loss: 1.2934, Train Acc: 0.9808
# Val Loss: 1.4863, Val Acc: 0.7823
# Precision: 0.7823, Recall: 0.7823, F1-score: 0.7820
# --------------------------------------------------
# Epoch [1496/1500]
# Train Loss: 1.2932, Train Acc: 0.9807
# Val Loss: 1.4976, Val Acc: 0.7669
# Precision: 0.7679, Recall: 0.7669, F1-score: 0.7665
# --------------------------------------------------
# Epoch [1497/1500]
# Train Loss: 1.2926, Train Acc: 0.9816
# Val Loss: 1.5058, Val Acc: 0.7597
# Precision: 0.7639, Recall: 0.7597, F1-score: 0.7591
# --------------------------------------------------
# Epoch [1498/1500]
# Train Loss: 1.2958, Train Acc: 0.9789
# Val Loss: 1.5068, Val Acc: 0.7568
# Precision: 0.7655, Recall: 0.7568, F1-score: 0.7591
# --------------------------------------------------
# Epoch [1499/1500]
# Train Loss: 1.2980, Train Acc: 0.9763
# Val Loss: 1.5065, Val Acc: 0.7544
# Precision: 0.7579, Recall: 0.7544, F1-score: 0.7543
# --------------------------------------------------
# Epoch [1500/1500]
# Train Loss: 1.3009, Train Acc: 0.9729
# Val Loss: 1.4958, Val Acc: 0.7640
# Precision: 0.7685, Recall: 0.7640, F1-score: 0.7648
# --------------------------------------------------

# %%
torch.save(model.state_dict(), "C:/Nini/Capstone/Models/DataAugmentationSnippets_LSTM_model.pth")
