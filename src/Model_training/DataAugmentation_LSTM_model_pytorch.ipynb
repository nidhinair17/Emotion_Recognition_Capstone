# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import precision_recall_fscore_support

# %%
features = pd.read_csv("C:/Nini/Capstone/CSV_Files/DataAugmentation_ravdess_extracted_features.csv")
features = features.drop(features.columns[0], axis=1)
temp = shuffle(features)
df = np.random.rand(len(temp)) < 0.8
train = temp[df]
test = temp[~df]

# %%
X_train = np.array(train.iloc[:,:-1])
y_train = np.array(train.iloc[:,-1])
X_test = np.array(test.iloc[:,:-1])
y_test = np.array(test.iloc[:,-1])

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
batch_size = 256
train_loader = DataLoader(TensorDataset(X_train,y_train), batch_size=batch_size,shuffle=True)
test_loader = DataLoader(TensorDataset(X_test,y_test), batch_size=batch_size, shuffle=False)

# %%
class LSTMPyTorch(nn.Module):
    def __init__(self, input_size, hidden_sizes=[256, 256, 128], output_size=8, dropout=0.2, l2_reg=1e-5):
        super(LSTMPyTorch, self).__init__()
        
        self.lstm1 = nn.LSTM(input_size, hidden_sizes[0], batch_first=True)
        self.lstm2 = nn.LSTM(hidden_sizes[0], hidden_sizes[1], batch_first=True)
        self.lstm3 = nn.LSTM(hidden_sizes[1], hidden_sizes[2], batch_first=True)
        
        self.bn1 = nn.BatchNorm1d(hidden_sizes[0])
        self.bn2 = nn.BatchNorm1d(hidden_sizes[1])
        self.bn3 = nn.BatchNorm1d(hidden_sizes[2])

        self.fc1 = nn.Linear(hidden_sizes[2], 256)
        self.fc2 = nn.Linear(256, output_size)
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.bn1(x.transpose(1,2)).transpose(1,2)

        x, _ = self.lstm2(x)
        x = self.bn2(x.transpose(1,2)).transpose(1,2)

        x, _ = self.lstm3(x)
        x = self.bn3(x.transpose(1,2)).transpose(1,2)
        
        x = self.relu(self.fc1(x[:, -1, :])) 
        x = self.dropout(x)
        x = self.softmax(self.fc2(x))
        return x

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: torch.Size([2287, 1, 128])

# %%
input_size = 128
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMPyTorch(input_size).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

# %%
epochs = 1500
for epoch in range(epochs):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    # Training loop
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)
    
    train_accuracy = correct / total
    avg_train_loss = running_loss / len(train_loader)

    # Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for val_inputs, val_labels in test_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()
            _, val_predicted = torch.max(val_outputs, 1)

            val_correct += (val_predicted == val_labels).sum().item()
            val_total += val_labels.size(0)

            # Store predictions and labels for evaluation
            all_preds.extend(val_predicted.cpu().numpy())
            all_labels.extend(val_labels.cpu().numpy())

    val_accuracy = val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)

    # Compute Precision, Recall, F1-score
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted',zero_division=1)

    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}")
    print("-" * 50)
# Out:
# Epoch [1/1500]
# Train Loss: 2.0048, Train Acc: 0.2925
# Val Loss: 2.0748, Val Acc: 0.2698
# Precision: 0.6378, Recall: 0.2698, F1-score: 0.1916
# --------------------------------------------------
# Epoch [2/1500]
# Train Loss: 1.8887, Train Acc: 0.4154
# Val Loss: 2.0553, Val Acc: 0.2631
# Precision: 0.3888, Recall: 0.2631, F1-score: 0.2132
# --------------------------------------------------
# Epoch [3/1500]
# Train Loss: 1.8008, Train Acc: 0.4902
# Val Loss: 2.0059, Val Acc: 0.3086
# Precision: 0.5180, Recall: 0.3086, F1-score: 0.2803
# --------------------------------------------------
# Epoch [4/1500]
# Train Loss: 1.7439, Train Acc: 0.5426
# Val Loss: 1.8968, Val Acc: 0.4300
# Precision: 0.4928, Recall: 0.4300, F1-score: 0.4126
# --------------------------------------------------
# Epoch [5/1500]
# Train Loss: 1.6965, Train Acc: 0.5920
# Val Loss: 1.8326, Val Acc: 0.4452
# Precision: 0.5411, Recall: 0.4452, F1-score: 0.4418
# --------------------------------------------------
# Epoch [6/1500]
# Train Loss: 1.6626, Train Acc: 0.6196
# Val Loss: 1.8113, Val Acc: 0.4637
# Precision: 0.5480, Recall: 0.4637, F1-score: 0.4497
# --------------------------------------------------
# Epoch [7/1500]
# Train Loss: 1.6331, Train Acc: 0.6511
# Val Loss: 1.7619, Val Acc: 0.5110
# Precision: 0.5753, Recall: 0.5110, F1-score: 0.5021
# --------------------------------------------------
# Epoch [8/1500]
# Train Loss: 1.6094, Train Acc: 0.6729
# Val Loss: 1.7575, Val Acc: 0.5160
# Precision: 0.5936, Recall: 0.5160, F1-score: 0.5018
# --------------------------------------------------
# Epoch [9/1500]
# Train Loss: 1.5957, Train Acc: 0.6821
# Val Loss: 1.7012, Val Acc: 0.5767
# Precision: 0.6191, Recall: 0.5767, F1-score: 0.5569
# --------------------------------------------------
# Epoch [10/1500]
# Train Loss: 1.5758, Train Acc: 0.7097
# Val Loss: 1.7484, Val Acc: 0.5194
# Precision: 0.6431, Recall: 0.5194, F1-score: 0.5214
# --------------------------------------------------
# Epoch [11/1500]
# Train Loss: 1.5580, Train Acc: 0.7149
# Val Loss: 1.6923, Val Acc: 0.5953
# Precision: 0.6468, Recall: 0.5953, F1-score: 0.5777
# --------------------------------------------------
# Epoch [12/1500]
# Train Loss: 1.5418, Train Acc: 0.7407
# Val Loss: 1.7177, Val Acc: 0.5750
# Precision: 0.6347, Recall: 0.5750, F1-score: 0.5569
# --------------------------------------------------
# Epoch [13/1500]
# Train Loss: 1.5385, Train Acc: 0.7385
# Val Loss: 1.6936, Val Acc: 0.5919
# Precision: 0.6324, Recall: 0.5919, F1-score: 0.5830
# --------------------------------------------------
# Epoch [14/1500]
# Train Loss: 1.5236, Train Acc: 0.7556
# Val Loss: 1.6893, Val Acc: 0.6020
# Precision: 0.6328, Recall: 0.6020, F1-score: 0.5937
# --------------------------------------------------
# Epoch [15/1500]
# Train Loss: 1.5131, Train Acc: 0.7661
# Val Loss: 1.7220, Val Acc: 0.5717
# Precision: 0.6597, Recall: 0.5717, F1-score: 0.5730
# --------------------------------------------------
# Epoch [16/1500]
# Train Loss: 1.5032, Train Acc: 0.7792
# Val Loss: 1.6301, Val Acc: 0.6560
# Precision: 0.6601, Recall: 0.6560, F1-score: 0.6511
# --------------------------------------------------
# Epoch [17/1500]
# Train Loss: 1.4796, Train Acc: 0.8072
# Val Loss: 1.6272, Val Acc: 0.6526
# Precision: 0.6840, Recall: 0.6526, F1-score: 0.6500
# --------------------------------------------------
# Epoch [18/1500]
# Train Loss: 1.4729, Train Acc: 0.8146
# Val Loss: 1.6382, Val Acc: 0.6543
# Precision: 0.6654, Recall: 0.6543, F1-score: 0.6540
# --------------------------------------------------
# Epoch [19/1500]
# Train Loss: 1.4470, Train Acc: 0.8347
# Val Loss: 1.5886, Val Acc: 0.7218
# Precision: 0.7315, Recall: 0.7218, F1-score: 0.7223
# --------------------------------------------------
# Epoch [20/1500]
# Train Loss: 1.4463, Train Acc: 0.8360
# Val Loss: 1.6441, Val Acc: 0.6594
# Precision: 0.6728, Recall: 0.6594, F1-score: 0.6503
# --------------------------------------------------
# Epoch [21/1500]
# Train Loss: 1.4488, Train Acc: 0.8303
# Val Loss: 1.6239, Val Acc: 0.6509
# Precision: 0.6680, Recall: 0.6509, F1-score: 0.6460
# --------------------------------------------------
# Epoch [22/1500]
# Train Loss: 1.4253, Train Acc: 0.8540
# Val Loss: 1.5681, Val Acc: 0.7184
# Precision: 0.7262, Recall: 0.7184, F1-score: 0.7199
# --------------------------------------------------
# Epoch [23/1500]
# Train Loss: 1.4121, Train Acc: 0.8710
# Val Loss: 1.5839, Val Acc: 0.7201
# Precision: 0.7443, Recall: 0.7201, F1-score: 0.7230
# --------------------------------------------------
# Epoch [24/1500]
# Train Loss: 1.4142, Train Acc: 0.8684
# Val Loss: 1.5726, Val Acc: 0.7083
# Precision: 0.7073, Recall: 0.7083, F1-score: 0.7057
# --------------------------------------------------
# Epoch [25/1500]
# Train Loss: 1.3982, Train Acc: 0.8815
# Val Loss: 1.5564, Val Acc: 0.7234
# Precision: 0.7299, Recall: 0.7234, F1-score: 0.7225
# --------------------------------------------------
# Epoch [26/1500]
# Train Loss: 1.3954, Train Acc: 0.8828
# Val Loss: 1.5339, Val Acc: 0.7470
# Precision: 0.7557, Recall: 0.7470, F1-score: 0.7473
# --------------------------------------------------
# Epoch [27/1500]
# Train Loss: 1.3890, Train Acc: 0.8937
# Val Loss: 1.5603, Val Acc: 0.7336
# Precision: 0.7394, Recall: 0.7336, F1-score: 0.7301
# --------------------------------------------------
# Epoch [28/1500]
# Train Loss: 1.3907, Train Acc: 0.8881
# Val Loss: 1.5720, Val Acc: 0.7083
# Precision: 0.7241, Recall: 0.7083, F1-score: 0.7046
# --------------------------------------------------
# Epoch [29/1500]
# Train Loss: 1.3857, Train Acc: 0.8959
# Val Loss: 1.5496, Val Acc: 0.7251
# Precision: 0.7300, Recall: 0.7251, F1-score: 0.7214
# --------------------------------------------------
# Epoch [30/1500]
# Train Loss: 1.3822, Train Acc: 0.8951
# Val Loss: 1.5224, Val Acc: 0.7555
# Precision: 0.7669, Recall: 0.7555, F1-score: 0.7556
# --------------------------------------------------
# Epoch [31/1500]
# Train Loss: 1.3758, Train Acc: 0.9038
# Val Loss: 1.5579, Val Acc: 0.7234
# Precision: 0.7517, Recall: 0.7234, F1-score: 0.7180
# --------------------------------------------------
# Epoch [32/1500]
# Train Loss: 1.3721, Train Acc: 0.9056
# Val Loss: 1.5807, Val Acc: 0.6965
# Precision: 0.7226, Recall: 0.6965, F1-score: 0.6972
# --------------------------------------------------
# Epoch [33/1500]
# Train Loss: 1.3629, Train Acc: 0.9174
# Val Loss: 1.5248, Val Acc: 0.7470
# Precision: 0.7708, Recall: 0.7470, F1-score: 0.7470
# --------------------------------------------------
# Epoch [34/1500]
# Train Loss: 1.3664, Train Acc: 0.9125
# Val Loss: 1.5133, Val Acc: 0.7555
# Precision: 0.7629, Recall: 0.7555, F1-score: 0.7541
# --------------------------------------------------
# Epoch [35/1500]
# Train Loss: 1.3664, Train Acc: 0.9104
# Val Loss: 1.5547, Val Acc: 0.7352
# Precision: 0.7541, Recall: 0.7352, F1-score: 0.7345
# --------------------------------------------------
# Epoch [36/1500]
# Train Loss: 1.3571, Train Acc: 0.9195
# Val Loss: 1.5147, Val Acc: 0.7521
# Precision: 0.7717, Recall: 0.7521, F1-score: 0.7533
# --------------------------------------------------
# Epoch [37/1500]
# Train Loss: 1.3532, Train Acc: 0.9274
# Val Loss: 1.5228, Val Acc: 0.7555
# Precision: 0.7646, Recall: 0.7555, F1-score: 0.7568
# --------------------------------------------------
# Epoch [38/1500]
# Train Loss: 1.3536, Train Acc: 0.9248
# Val Loss: 1.5165, Val Acc: 0.7605
# Precision: 0.7705, Recall: 0.7605, F1-score: 0.7592
# --------------------------------------------------
# Epoch [39/1500]
# Train Loss: 1.3473, Train Acc: 0.9318
# Val Loss: 1.5147, Val Acc: 0.7656
# Precision: 0.7767, Recall: 0.7656, F1-score: 0.7674
# --------------------------------------------------
# Epoch [40/1500]
# Train Loss: 1.3608, Train Acc: 0.9156
# Val Loss: 1.5255, Val Acc: 0.7487
# Precision: 0.7679, Recall: 0.7487, F1-score: 0.7504
# --------------------------------------------------
# Epoch [41/1500]
# Train Loss: 1.3724, Train Acc: 0.9029
# Val Loss: 1.5789, Val Acc: 0.6931
# Precision: 0.7042, Recall: 0.6931, F1-score: 0.6895
# --------------------------------------------------
# Epoch [42/1500]
# Train Loss: 1.3647, Train Acc: 0.9130
# Val Loss: 1.5366, Val Acc: 0.7336
# Precision: 0.7644, Recall: 0.7336, F1-score: 0.7349
# --------------------------------------------------
# Epoch [43/1500]
# Train Loss: 1.3609, Train Acc: 0.9160
# Val Loss: 1.4993, Val Acc: 0.7825
# Precision: 0.7821, Recall: 0.7825, F1-score: 0.7819
# --------------------------------------------------
# Epoch [44/1500]
# Train Loss: 1.3478, Train Acc: 0.9287
# Val Loss: 1.4975, Val Acc: 0.7740
# Precision: 0.7770, Recall: 0.7740, F1-score: 0.7734
# --------------------------------------------------
# Epoch [45/1500]
# Train Loss: 1.3561, Train Acc: 0.9235
# Val Loss: 1.4936, Val Acc: 0.7757
# Precision: 0.7765, Recall: 0.7757, F1-score: 0.7701
# --------------------------------------------------
# Epoch [46/1500]
# Train Loss: 1.3674, Train Acc: 0.9077
# Val Loss: 1.5246, Val Acc: 0.7302
# Precision: 0.7460, Recall: 0.7302, F1-score: 0.7311
# --------------------------------------------------
# Epoch [47/1500]
# Train Loss: 1.3547, Train Acc: 0.9217
# Val Loss: 1.5229, Val Acc: 0.7487
# Precision: 0.7534, Recall: 0.7487, F1-score: 0.7435
# --------------------------------------------------
# Epoch [48/1500]
# Train Loss: 1.3604, Train Acc: 0.9165
# Val Loss: 1.5112, Val Acc: 0.7690
# Precision: 0.7756, Recall: 0.7690, F1-score: 0.7665
# --------------------------------------------------
# Epoch [49/1500]
# Train Loss: 1.3464, Train Acc: 0.9340
# Val Loss: 1.5253, Val Acc: 0.7437
# Precision: 0.7584, Recall: 0.7437, F1-score: 0.7477
# --------------------------------------------------
# Epoch [50/1500]
# Train Loss: 1.3476, Train Acc: 0.9296
# Val Loss: 1.5375, Val Acc: 0.7386
# Precision: 0.7523, Recall: 0.7386, F1-score: 0.7345
# --------------------------------------------------
# Epoch [51/1500]
# Train Loss: 1.3544, Train Acc: 0.9217
# Val Loss: 1.5146, Val Acc: 0.7487
# Precision: 0.7578, Recall: 0.7487, F1-score: 0.7486
# --------------------------------------------------
# Epoch [52/1500]
# Train Loss: 1.3471, Train Acc: 0.9292
# Val Loss: 1.5013, Val Acc: 0.7622
# Precision: 0.7689, Recall: 0.7622, F1-score: 0.7627
# --------------------------------------------------
# Epoch [53/1500]
# Train Loss: 1.3417, Train Acc: 0.9348
# Val Loss: 1.4864, Val Acc: 0.7976
# Precision: 0.8015, Recall: 0.7976, F1-score: 0.7982
# --------------------------------------------------
# Epoch [54/1500]
# Train Loss: 1.3374, Train Acc: 0.9392
# Val Loss: 1.4906, Val Acc: 0.7774
# Precision: 0.7789, Recall: 0.7774, F1-score: 0.7756
# --------------------------------------------------
# Epoch [55/1500]
# Train Loss: 1.3353, Train Acc: 0.9414
# Val Loss: 1.5288, Val Acc: 0.7437
# Precision: 0.7626, Recall: 0.7437, F1-score: 0.7455
# --------------------------------------------------
# Epoch [56/1500]
# Train Loss: 1.3359, Train Acc: 0.9397
# Val Loss: 1.4912, Val Acc: 0.7892
# Precision: 0.7967, Recall: 0.7892, F1-score: 0.7847
# --------------------------------------------------
# Epoch [57/1500]
# Train Loss: 1.3332, Train Acc: 0.9423
# Val Loss: 1.4818, Val Acc: 0.7976
# Precision: 0.8087, Recall: 0.7976, F1-score: 0.7996
# --------------------------------------------------
# Epoch [58/1500]
# Train Loss: 1.3290, Train Acc: 0.9488
# Val Loss: 1.4739, Val Acc: 0.7892
# Precision: 0.7914, Recall: 0.7892, F1-score: 0.7867
# --------------------------------------------------
# Epoch [59/1500]
# Train Loss: 1.3307, Train Acc: 0.9458
# Val Loss: 1.4735, Val Acc: 0.8010
# Precision: 0.8055, Recall: 0.8010, F1-score: 0.7993
# --------------------------------------------------
# Epoch [60/1500]
# Train Loss: 1.3305, Train Acc: 0.9453
# Val Loss: 1.5083, Val Acc: 0.7656
# Precision: 0.7836, Recall: 0.7656, F1-score: 0.7667
# --------------------------------------------------
# Epoch [61/1500]
# Train Loss: 1.3351, Train Acc: 0.9397
# Val Loss: 1.5243, Val Acc: 0.7437
# Precision: 0.7545, Recall: 0.7437, F1-score: 0.7388
# --------------------------------------------------
# Epoch [62/1500]
# Train Loss: 1.3369, Train Acc: 0.9383
# Val Loss: 1.4993, Val Acc: 0.7791
# Precision: 0.7943, Recall: 0.7791, F1-score: 0.7786
# --------------------------------------------------
# Epoch [63/1500]
# Train Loss: 1.3336, Train Acc: 0.9418
# Val Loss: 1.4611, Val Acc: 0.8010
# Precision: 0.8115, Recall: 0.8010, F1-score: 0.8002
# --------------------------------------------------
# Epoch [64/1500]
# Train Loss: 1.3307, Train Acc: 0.9453
# Val Loss: 1.4989, Val Acc: 0.7791
# Precision: 0.7839, Recall: 0.7791, F1-score: 0.7754
# --------------------------------------------------
# Epoch [65/1500]
# Train Loss: 1.3279, Train Acc: 0.9484
# Val Loss: 1.5066, Val Acc: 0.7740
# Precision: 0.7916, Recall: 0.7740, F1-score: 0.7768
# --------------------------------------------------
# Epoch [66/1500]
# Train Loss: 1.3323, Train Acc: 0.9440
# Val Loss: 1.4993, Val Acc: 0.7757
# Precision: 0.7821, Recall: 0.7757, F1-score: 0.7702
# --------------------------------------------------
# Epoch [67/1500]
# Train Loss: 1.3300, Train Acc: 0.9445
# Val Loss: 1.4978, Val Acc: 0.7673
# Precision: 0.7877, Recall: 0.7673, F1-score: 0.7689
# --------------------------------------------------
# Epoch [68/1500]
# Train Loss: 1.3220, Train Acc: 0.9545
# Val Loss: 1.4477, Val Acc: 0.8263
# Precision: 0.8275, Recall: 0.8263, F1-score: 0.8255
# --------------------------------------------------
# Epoch [69/1500]
# Train Loss: 1.3060, Train Acc: 0.9690
# Val Loss: 1.4560, Val Acc: 0.8196
# Precision: 0.8185, Recall: 0.8196, F1-score: 0.8174
# --------------------------------------------------
# Epoch [70/1500]
# Train Loss: 1.3109, Train Acc: 0.9655
# Val Loss: 1.4758, Val Acc: 0.7943
# Precision: 0.8013, Recall: 0.7943, F1-score: 0.7932
# --------------------------------------------------
# Epoch [71/1500]
# Train Loss: 1.3111, Train Acc: 0.9641
# Val Loss: 1.4266, Val Acc: 0.8465
# Precision: 0.8479, Recall: 0.8465, F1-score: 0.8463
# --------------------------------------------------
# Epoch [72/1500]
# Train Loss: 1.3140, Train Acc: 0.9598
# Val Loss: 1.4483, Val Acc: 0.8246
# Precision: 0.8340, Recall: 0.8246, F1-score: 0.8249
# --------------------------------------------------
# Epoch [73/1500]
# Train Loss: 1.3116, Train Acc: 0.9641
# Val Loss: 1.4654, Val Acc: 0.8044
# Precision: 0.8153, Recall: 0.8044, F1-score: 0.8042
# --------------------------------------------------
# Epoch [74/1500]
# Train Loss: 1.3092, Train Acc: 0.9672
# Val Loss: 1.4826, Val Acc: 0.7774
# Precision: 0.7928, Recall: 0.7774, F1-score: 0.7767
# --------------------------------------------------
# Epoch [75/1500]
# Train Loss: 1.3114, Train Acc: 0.9633
# Val Loss: 1.4288, Val Acc: 0.8398
# Precision: 0.8533, Recall: 0.8398, F1-score: 0.8419
# --------------------------------------------------
# Epoch [76/1500]
# Train Loss: 1.3038, Train Acc: 0.9716
# Val Loss: 1.4252, Val Acc: 0.8482
# Precision: 0.8486, Recall: 0.8482, F1-score: 0.8474
# --------------------------------------------------
# Epoch [77/1500]
# Train Loss: 1.3066, Train Acc: 0.9685
# Val Loss: 1.4561, Val Acc: 0.8111
# Precision: 0.8143, Recall: 0.8111, F1-score: 0.8101
# --------------------------------------------------
# Epoch [78/1500]
# Train Loss: 1.3147, Train Acc: 0.9593
# Val Loss: 1.4857, Val Acc: 0.7808
# Precision: 0.7861, Recall: 0.7808, F1-score: 0.7745
# --------------------------------------------------
# Epoch [79/1500]
# Train Loss: 1.3212, Train Acc: 0.9554
# Val Loss: 1.4760, Val Acc: 0.8010
# Precision: 0.8073, Recall: 0.8010, F1-score: 0.7994
# --------------------------------------------------
# Epoch [80/1500]
# Train Loss: 1.3082, Train Acc: 0.9690
# Val Loss: 1.4696, Val Acc: 0.7976
# Precision: 0.8131, Recall: 0.7976, F1-score: 0.7991
# --------------------------------------------------
# Epoch [81/1500]
# Train Loss: 1.3095, Train Acc: 0.9659
# Val Loss: 1.4534, Val Acc: 0.8381
# Precision: 0.8490, Recall: 0.8381, F1-score: 0.8406
# --------------------------------------------------
# Epoch [82/1500]
# Train Loss: 1.3145, Train Acc: 0.9602
# Val Loss: 1.4641, Val Acc: 0.8078
# Precision: 0.8194, Recall: 0.8078, F1-score: 0.8066
# --------------------------------------------------
# Epoch [83/1500]
# Train Loss: 1.3168, Train Acc: 0.9567
# Val Loss: 1.4409, Val Acc: 0.8280
# Precision: 0.8284, Recall: 0.8280, F1-score: 0.8244
# --------------------------------------------------
# Epoch [84/1500]
# Train Loss: 1.3146, Train Acc: 0.9611
# Val Loss: 1.4602, Val Acc: 0.7993
# Precision: 0.8110, Recall: 0.7993, F1-score: 0.8014
# --------------------------------------------------
# Epoch [85/1500]
# Train Loss: 1.3143, Train Acc: 0.9598
# Val Loss: 1.4725, Val Acc: 0.8027
# Precision: 0.8112, Recall: 0.8027, F1-score: 0.8030
# --------------------------------------------------
# Epoch [86/1500]
# Train Loss: 1.3227, Train Acc: 0.9532
# Val Loss: 1.4489, Val Acc: 0.8297
# Precision: 0.8461, Recall: 0.8297, F1-score: 0.8321
# --------------------------------------------------
# Epoch [87/1500]
# Train Loss: 1.3134, Train Acc: 0.9602
# Val Loss: 1.4316, Val Acc: 0.8415
# Precision: 0.8434, Recall: 0.8415, F1-score: 0.8415
# --------------------------------------------------
# Epoch [88/1500]
# Train Loss: 1.3065, Train Acc: 0.9694
# Val Loss: 1.4502, Val Acc: 0.8280
# Precision: 0.8358, Recall: 0.8280, F1-score: 0.8298
# --------------------------------------------------
# Epoch [89/1500]
# Train Loss: 1.3065, Train Acc: 0.9690
# Val Loss: 1.4708, Val Acc: 0.8061
# Precision: 0.8244, Recall: 0.8061, F1-score: 0.8052
# --------------------------------------------------
# Epoch [90/1500]
# Train Loss: 1.3123, Train Acc: 0.9624
# Val Loss: 1.4193, Val Acc: 0.8516
# Precision: 0.8561, Recall: 0.8516, F1-score: 0.8519
# --------------------------------------------------
# Epoch [91/1500]
# Train Loss: 1.3071, Train Acc: 0.9685
# Val Loss: 1.4351, Val Acc: 0.8432
# Precision: 0.8529, Recall: 0.8432, F1-score: 0.8444
# --------------------------------------------------
# Epoch [92/1500]
# Train Loss: 1.3058, Train Acc: 0.9676
# Val Loss: 1.4168, Val Acc: 0.8533
# Precision: 0.8533, Recall: 0.8533, F1-score: 0.8526
# --------------------------------------------------
# Epoch [93/1500]
# Train Loss: 1.3125, Train Acc: 0.9637
# Val Loss: 1.4432, Val Acc: 0.8145
# Precision: 0.8159, Recall: 0.8145, F1-score: 0.8125
# --------------------------------------------------
# Epoch [94/1500]
# Train Loss: 1.3127, Train Acc: 0.9637
# Val Loss: 1.4412, Val Acc: 0.8314
# Precision: 0.8508, Recall: 0.8314, F1-score: 0.8343
# --------------------------------------------------
# Epoch [95/1500]
# Train Loss: 1.3105, Train Acc: 0.9659
# Val Loss: 1.4528, Val Acc: 0.8145
# Precision: 0.8195, Recall: 0.8145, F1-score: 0.8154
# --------------------------------------------------
# Epoch [96/1500]
# Train Loss: 1.3150, Train Acc: 0.9585
# Val Loss: 1.4430, Val Acc: 0.8381
# Precision: 0.8447, Recall: 0.8381, F1-score: 0.8384
# --------------------------------------------------
# Epoch [97/1500]
# Train Loss: 1.3123, Train Acc: 0.9633
# Val Loss: 1.4791, Val Acc: 0.7875
# Precision: 0.8123, Recall: 0.7875, F1-score: 0.7880
# --------------------------------------------------
# Epoch [98/1500]
# Train Loss: 1.3115, Train Acc: 0.9633
# Val Loss: 1.4272, Val Acc: 0.8432
# Precision: 0.8475, Recall: 0.8432, F1-score: 0.8431
# --------------------------------------------------
# Epoch [99/1500]
# Train Loss: 1.3118, Train Acc: 0.9633
# Val Loss: 1.4408, Val Acc: 0.8415
# Precision: 0.8491, Recall: 0.8415, F1-score: 0.8424
# --------------------------------------------------
# Epoch [100/1500]
# Train Loss: 1.3061, Train Acc: 0.9681
# Val Loss: 1.3983, Val Acc: 0.8718
# Precision: 0.8747, Recall: 0.8718, F1-score: 0.8716
# --------------------------------------------------
# Epoch [101/1500]
# Train Loss: 1.2989, Train Acc: 0.9755
# Val Loss: 1.4214, Val Acc: 0.8533
# Precision: 0.8543, Recall: 0.8533, F1-score: 0.8526
# --------------------------------------------------
# Epoch [102/1500]
# Train Loss: 1.3025, Train Acc: 0.9742
# Val Loss: 1.4511, Val Acc: 0.8263
# Precision: 0.8362, Recall: 0.8263, F1-score: 0.8246
# --------------------------------------------------
# Epoch [103/1500]
# Train Loss: 1.3040, Train Acc: 0.9703
# Val Loss: 1.5037, Val Acc: 0.7707
# Precision: 0.7899, Recall: 0.7707, F1-score: 0.7720
# --------------------------------------------------
# Epoch [104/1500]
# Train Loss: 1.3145, Train Acc: 0.9611
# Val Loss: 1.4503, Val Acc: 0.8196
# Precision: 0.8248, Recall: 0.8196, F1-score: 0.8196
# --------------------------------------------------
# Epoch [105/1500]
# Train Loss: 1.3090, Train Acc: 0.9655
# Val Loss: 1.4729, Val Acc: 0.7858
# Precision: 0.8072, Recall: 0.7858, F1-score: 0.7863
# --------------------------------------------------
# Epoch [106/1500]
# Train Loss: 1.3060, Train Acc: 0.9698
# Val Loss: 1.4902, Val Acc: 0.7976
# Precision: 0.8163, Recall: 0.7976, F1-score: 0.7980
# --------------------------------------------------
# Epoch [107/1500]
# Train Loss: 1.3161, Train Acc: 0.9585
# Val Loss: 1.4700, Val Acc: 0.8061
# Precision: 0.8127, Recall: 0.8061, F1-score: 0.8037
# --------------------------------------------------
# Epoch [108/1500]
# Train Loss: 1.3072, Train Acc: 0.9685
# Val Loss: 1.4513, Val Acc: 0.8162
# Precision: 0.8369, Recall: 0.8162, F1-score: 0.8184
# --------------------------------------------------
# Epoch [109/1500]
# Train Loss: 1.3091, Train Acc: 0.9650
# Val Loss: 1.4221, Val Acc: 0.8415
# Precision: 0.8485, Recall: 0.8415, F1-score: 0.8417
# --------------------------------------------------
# Epoch [110/1500]
# Train Loss: 1.3040, Train Acc: 0.9711
# Val Loss: 1.4169, Val Acc: 0.8465
# Precision: 0.8487, Recall: 0.8465, F1-score: 0.8470
# --------------------------------------------------
# Epoch [111/1500]
# Train Loss: 1.3039, Train Acc: 0.9707
# Val Loss: 1.4304, Val Acc: 0.8516
# Precision: 0.8572, Recall: 0.8516, F1-score: 0.8523
# --------------------------------------------------
# Epoch [112/1500]
# Train Loss: 1.3105, Train Acc: 0.9659
# Val Loss: 1.4078, Val Acc: 0.8567
# Precision: 0.8589, Recall: 0.8567, F1-score: 0.8568
# --------------------------------------------------
# Epoch [113/1500]
# Train Loss: 1.3083, Train Acc: 0.9655
# Val Loss: 1.4416, Val Acc: 0.8331
# Precision: 0.8443, Recall: 0.8331, F1-score: 0.8353
# --------------------------------------------------
# Epoch [114/1500]
# Train Loss: 1.3116, Train Acc: 0.9633
# Val Loss: 1.4521, Val Acc: 0.8128
# Precision: 0.8210, Recall: 0.8128, F1-score: 0.8131
# --------------------------------------------------
# Epoch [115/1500]
# Train Loss: 1.3160, Train Acc: 0.9567
# Val Loss: 1.4687, Val Acc: 0.7909
# Precision: 0.8017, Recall: 0.7909, F1-score: 0.7920
# --------------------------------------------------
# Epoch [116/1500]
# Train Loss: 1.3087, Train Acc: 0.9681
# Val Loss: 1.5007, Val Acc: 0.7757
# Precision: 0.7942, Recall: 0.7757, F1-score: 0.7764
# --------------------------------------------------
# Epoch [117/1500]
# Train Loss: 1.3097, Train Acc: 0.9663
# Val Loss: 1.4416, Val Acc: 0.8415
# Precision: 0.8576, Recall: 0.8415, F1-score: 0.8436
# --------------------------------------------------
# Epoch [118/1500]
# Train Loss: 1.3142, Train Acc: 0.9589
# Val Loss: 1.4925, Val Acc: 0.7841
# Precision: 0.7917, Recall: 0.7841, F1-score: 0.7839
# --------------------------------------------------
# Epoch [119/1500]
# Train Loss: 1.3213, Train Acc: 0.9541
# Val Loss: 1.4773, Val Acc: 0.7993
# Precision: 0.8039, Recall: 0.7993, F1-score: 0.7995
# --------------------------------------------------
# Epoch [120/1500]
# Train Loss: 1.3184, Train Acc: 0.9576
# Val Loss: 1.4958, Val Acc: 0.7774
# Precision: 0.7870, Recall: 0.7774, F1-score: 0.7772
# --------------------------------------------------
# Epoch [121/1500]
# Train Loss: 1.3161, Train Acc: 0.9589
# Val Loss: 1.4507, Val Acc: 0.8179
# Precision: 0.8236, Recall: 0.8179, F1-score: 0.8181
# --------------------------------------------------
# Epoch [122/1500]
# Train Loss: 1.3043, Train Acc: 0.9725
# Val Loss: 1.4556, Val Acc: 0.8094
# Precision: 0.8188, Recall: 0.8094, F1-score: 0.8074
# --------------------------------------------------
# Epoch [123/1500]
# Train Loss: 1.3194, Train Acc: 0.9563
# Val Loss: 1.4692, Val Acc: 0.8061
# Precision: 0.8201, Recall: 0.8061, F1-score: 0.8035
# --------------------------------------------------
# Epoch [124/1500]
# Train Loss: 1.3176, Train Acc: 0.9576
# Val Loss: 1.4888, Val Acc: 0.7841
# Precision: 0.7865, Recall: 0.7841, F1-score: 0.7829
# --------------------------------------------------
# Epoch [125/1500]
# Train Loss: 1.3154, Train Acc: 0.9593
# Val Loss: 1.4468, Val Acc: 0.8246
# Precision: 0.8399, Recall: 0.8246, F1-score: 0.8262
# --------------------------------------------------
# Epoch [126/1500]
# Train Loss: 1.3081, Train Acc: 0.9685
# Val Loss: 1.4082, Val Acc: 0.8600
# Precision: 0.8698, Recall: 0.8600, F1-score: 0.8604
# --------------------------------------------------
# Epoch [127/1500]
# Train Loss: 1.3078, Train Acc: 0.9668
# Val Loss: 1.4420, Val Acc: 0.8196
# Precision: 0.8247, Recall: 0.8196, F1-score: 0.8190
# --------------------------------------------------
# Epoch [128/1500]
# Train Loss: 1.3072, Train Acc: 0.9694
# Val Loss: 1.4308, Val Acc: 0.8331
# Precision: 0.8452, Recall: 0.8331, F1-score: 0.8352
# --------------------------------------------------
# Epoch [129/1500]
# Train Loss: 1.3134, Train Acc: 0.9611
# Val Loss: 1.4361, Val Acc: 0.8297
# Precision: 0.8367, Recall: 0.8297, F1-score: 0.8312
# --------------------------------------------------
# Epoch [130/1500]
# Train Loss: 1.3221, Train Acc: 0.9519
# Val Loss: 1.4819, Val Acc: 0.7791
# Precision: 0.8086, Recall: 0.7791, F1-score: 0.7831
# --------------------------------------------------
# Epoch [131/1500]
# Train Loss: 1.3133, Train Acc: 0.9641
# Val Loss: 1.4772, Val Acc: 0.8044
# Precision: 0.8391, Recall: 0.8044, F1-score: 0.8104
# --------------------------------------------------
# Epoch [132/1500]
# Train Loss: 1.3126, Train Acc: 0.9633
# Val Loss: 1.4172, Val Acc: 0.8449
# Precision: 0.8541, Recall: 0.8449, F1-score: 0.8468
# --------------------------------------------------
# Epoch [133/1500]
# Train Loss: 1.3046, Train Acc: 0.9694
# Val Loss: 1.4307, Val Acc: 0.8347
# Precision: 0.8459, Recall: 0.8347, F1-score: 0.8355
# --------------------------------------------------
# Epoch [134/1500]
# Train Loss: 1.3099, Train Acc: 0.9650
# Val Loss: 1.4448, Val Acc: 0.8111
# Precision: 0.8185, Recall: 0.8111, F1-score: 0.8125
# --------------------------------------------------
# Epoch [135/1500]
# Train Loss: 1.3094, Train Acc: 0.9650
# Val Loss: 1.4243, Val Acc: 0.8415
# Precision: 0.8482, Recall: 0.8415, F1-score: 0.8421
# --------------------------------------------------
# Epoch [136/1500]
# Train Loss: 1.3084, Train Acc: 0.9650
# Val Loss: 1.4425, Val Acc: 0.8246
# Precision: 0.8427, Recall: 0.8246, F1-score: 0.8273
# --------------------------------------------------
# Epoch [137/1500]
# Train Loss: 1.3058, Train Acc: 0.9690
# Val Loss: 1.4569, Val Acc: 0.8196
# Precision: 0.8264, Recall: 0.8196, F1-score: 0.8182
# --------------------------------------------------
# Epoch [138/1500]
# Train Loss: 1.3082, Train Acc: 0.9668
# Val Loss: 1.4286, Val Acc: 0.8567
# Precision: 0.8684, Recall: 0.8567, F1-score: 0.8579
# --------------------------------------------------
# Epoch [139/1500]
# Train Loss: 1.3197, Train Acc: 0.9537
# Val Loss: 1.4941, Val Acc: 0.7690
# Precision: 0.7877, Recall: 0.7690, F1-score: 0.7705
# --------------------------------------------------
# Epoch [140/1500]
# Train Loss: 1.3153, Train Acc: 0.9589
# Val Loss: 1.4548, Val Acc: 0.8094
# Precision: 0.8240, Recall: 0.8094, F1-score: 0.8082
# --------------------------------------------------
# Epoch [141/1500]
# Train Loss: 1.3126, Train Acc: 0.9641
# Val Loss: 1.4432, Val Acc: 0.8162
# Precision: 0.8333, Recall: 0.8162, F1-score: 0.8190
# --------------------------------------------------
# Epoch [142/1500]
# Train Loss: 1.3080, Train Acc: 0.9672
# Val Loss: 1.4538, Val Acc: 0.8145
# Precision: 0.8293, Recall: 0.8145, F1-score: 0.8170
# --------------------------------------------------
# Epoch [143/1500]
# Train Loss: 1.3087, Train Acc: 0.9659
# Val Loss: 1.4897, Val Acc: 0.7757
# Precision: 0.7808, Recall: 0.7757, F1-score: 0.7736
# --------------------------------------------------
# Epoch [144/1500]
# Train Loss: 1.3161, Train Acc: 0.9580
# Val Loss: 1.4189, Val Acc: 0.8482
# Precision: 0.8505, Recall: 0.8482, F1-score: 0.8482
# --------------------------------------------------
# Epoch [145/1500]
# Train Loss: 1.3141, Train Acc: 0.9602
# Val Loss: 1.4915, Val Acc: 0.7943
# Precision: 0.8055, Recall: 0.7943, F1-score: 0.7935
# --------------------------------------------------
# Epoch [146/1500]
# Train Loss: 1.3125, Train Acc: 0.9628
# Val Loss: 1.5061, Val Acc: 0.7538
# Precision: 0.7693, Recall: 0.7538, F1-score: 0.7534
# --------------------------------------------------
# Epoch [147/1500]
# Train Loss: 1.3122, Train Acc: 0.9620
# Val Loss: 1.4451, Val Acc: 0.8297
# Precision: 0.8372, Recall: 0.8297, F1-score: 0.8307
# --------------------------------------------------
# Epoch [148/1500]
# Train Loss: 1.3073, Train Acc: 0.9668
# Val Loss: 1.4652, Val Acc: 0.8162
# Precision: 0.8205, Recall: 0.8162, F1-score: 0.8151
# --------------------------------------------------
# Epoch [149/1500]
# Train Loss: 1.3075, Train Acc: 0.9672
# Val Loss: 1.4188, Val Acc: 0.8449
# Precision: 0.8466, Recall: 0.8449, F1-score: 0.8442
# --------------------------------------------------
# Epoch [150/1500]
# Train Loss: 1.3099, Train Acc: 0.9655
# Val Loss: 1.4673, Val Acc: 0.8061
# Precision: 0.8162, Recall: 0.8061, F1-score: 0.8076
# --------------------------------------------------
# Epoch [151/1500]
# Train Loss: 1.3081, Train Acc: 0.9668
# Val Loss: 1.4531, Val Acc: 0.8061
# Precision: 0.8236, Recall: 0.8061, F1-score: 0.8089
# --------------------------------------------------
# Epoch [152/1500]
# Train Loss: 1.3068, Train Acc: 0.9676
# Val Loss: 1.4503, Val Acc: 0.8263
# Precision: 0.8359, Recall: 0.8263, F1-score: 0.8280
# --------------------------------------------------
# Epoch [153/1500]
# Train Loss: 1.3080, Train Acc: 0.9676
# Val Loss: 1.4454, Val Acc: 0.8314
# Precision: 0.8427, Recall: 0.8314, F1-score: 0.8323
# --------------------------------------------------
# Epoch [154/1500]
# Train Loss: 1.3056, Train Acc: 0.9681
# Val Loss: 1.4299, Val Acc: 0.8499
# Precision: 0.8519, Recall: 0.8499, F1-score: 0.8486
# --------------------------------------------------
# Epoch [155/1500]
# Train Loss: 1.3030, Train Acc: 0.9716
# Val Loss: 1.4205, Val Acc: 0.8533
# Precision: 0.8568, Recall: 0.8533, F1-score: 0.8538
# --------------------------------------------------
# Epoch [156/1500]
# Train Loss: 1.3025, Train Acc: 0.9720
# Val Loss: 1.4668, Val Acc: 0.8078
# Precision: 0.8148, Recall: 0.8078, F1-score: 0.8041
# --------------------------------------------------
# Epoch [157/1500]
# Train Loss: 1.3080, Train Acc: 0.9676
# Val Loss: 1.4159, Val Acc: 0.8499
# Precision: 0.8566, Recall: 0.8499, F1-score: 0.8507
# --------------------------------------------------
# Epoch [158/1500]
# Train Loss: 1.3034, Train Acc: 0.9716
# Val Loss: 1.4203, Val Acc: 0.8499
# Precision: 0.8538, Recall: 0.8499, F1-score: 0.8492
# --------------------------------------------------
# Epoch [159/1500]
# Train Loss: 1.3012, Train Acc: 0.9725
# Val Loss: 1.4287, Val Acc: 0.8398
# Precision: 0.8533, Recall: 0.8398, F1-score: 0.8410
# --------------------------------------------------
# Epoch [160/1500]
# Train Loss: 1.3006, Train Acc: 0.9751
# Val Loss: 1.4267, Val Acc: 0.8482
# Precision: 0.8519, Recall: 0.8482, F1-score: 0.8473
# --------------------------------------------------
# Epoch [161/1500]
# Train Loss: 1.3023, Train Acc: 0.9711
# Val Loss: 1.4178, Val Acc: 0.8499
# Precision: 0.8554, Recall: 0.8499, F1-score: 0.8503
# --------------------------------------------------
# Epoch [162/1500]
# Train Loss: 1.3024, Train Acc: 0.9733
# Val Loss: 1.4823, Val Acc: 0.7774
# Precision: 0.7921, Recall: 0.7774, F1-score: 0.7793
# --------------------------------------------------
# Epoch [163/1500]
# Train Loss: 1.3081, Train Acc: 0.9668
# Val Loss: 1.4579, Val Acc: 0.8111
# Precision: 0.8126, Recall: 0.8111, F1-score: 0.8101
# --------------------------------------------------
# Epoch [164/1500]
# Train Loss: 1.3071, Train Acc: 0.9676
# Val Loss: 1.4545, Val Acc: 0.8212
# Precision: 0.8491, Recall: 0.8212, F1-score: 0.8261
# --------------------------------------------------
# Epoch [165/1500]
# Train Loss: 1.3061, Train Acc: 0.9685
# Val Loss: 1.4444, Val Acc: 0.8128
# Precision: 0.8180, Recall: 0.8128, F1-score: 0.8110
# --------------------------------------------------
# Epoch [166/1500]
# Train Loss: 1.3037, Train Acc: 0.9716
# Val Loss: 1.4084, Val Acc: 0.8617
# Precision: 0.8709, Recall: 0.8617, F1-score: 0.8629
# --------------------------------------------------
# Epoch [167/1500]
# Train Loss: 1.2993, Train Acc: 0.9760
# Val Loss: 1.4660, Val Acc: 0.8128
# Precision: 0.8254, Recall: 0.8128, F1-score: 0.8135
# --------------------------------------------------
# Epoch [168/1500]
# Train Loss: 1.2993, Train Acc: 0.9751
# Val Loss: 1.4396, Val Acc: 0.8297
# Precision: 0.8342, Recall: 0.8297, F1-score: 0.8279
# --------------------------------------------------
# Epoch [169/1500]
# Train Loss: 1.3097, Train Acc: 0.9650
# Val Loss: 1.4501, Val Acc: 0.8094
# Precision: 0.8255, Recall: 0.8094, F1-score: 0.8118
# --------------------------------------------------
# Epoch [170/1500]
# Train Loss: 1.3074, Train Acc: 0.9668
# Val Loss: 1.4508, Val Acc: 0.8128
# Precision: 0.8196, Recall: 0.8128, F1-score: 0.8116
# --------------------------------------------------
# Epoch [171/1500]
# Train Loss: 1.3025, Train Acc: 0.9729
# Val Loss: 1.4290, Val Acc: 0.8347
# Precision: 0.8333, Recall: 0.8347, F1-score: 0.8332
# --------------------------------------------------
# Epoch [172/1500]
# Train Loss: 1.2954, Train Acc: 0.9799
# Val Loss: 1.4334, Val Acc: 0.8398
# Precision: 0.8504, Recall: 0.8398, F1-score: 0.8408
# --------------------------------------------------
# Epoch [173/1500]
# Train Loss: 1.2956, Train Acc: 0.9803
# Val Loss: 1.4175, Val Acc: 0.8600
# Precision: 0.8617, Recall: 0.8600, F1-score: 0.8584
# --------------------------------------------------
# Epoch [174/1500]
# Train Loss: 1.3041, Train Acc: 0.9711
# Val Loss: 1.4445, Val Acc: 0.8314
# Precision: 0.8355, Recall: 0.8314, F1-score: 0.8318
# --------------------------------------------------
# Epoch [175/1500]
# Train Loss: 1.3040, Train Acc: 0.9698
# Val Loss: 1.4503, Val Acc: 0.8196
# Precision: 0.8266, Recall: 0.8196, F1-score: 0.8191
# --------------------------------------------------
# Epoch [176/1500]
# Train Loss: 1.3031, Train Acc: 0.9720
# Val Loss: 1.4417, Val Acc: 0.8331
# Precision: 0.8434, Recall: 0.8331, F1-score: 0.8342
# --------------------------------------------------
# Epoch [177/1500]
# Train Loss: 1.3074, Train Acc: 0.9672
# Val Loss: 1.4471, Val Acc: 0.8229
# Precision: 0.8257, Recall: 0.8229, F1-score: 0.8217
# --------------------------------------------------
# Epoch [178/1500]
# Train Loss: 1.3042, Train Acc: 0.9707
# Val Loss: 1.4405, Val Acc: 0.8280
# Precision: 0.8390, Recall: 0.8280, F1-score: 0.8297
# --------------------------------------------------
# Epoch [179/1500]
# Train Loss: 1.2972, Train Acc: 0.9773
# Val Loss: 1.4405, Val Acc: 0.8347
# Precision: 0.8405, Recall: 0.8347, F1-score: 0.8351
# --------------------------------------------------
# Epoch [180/1500]
# Train Loss: 1.2943, Train Acc: 0.9799
# Val Loss: 1.4279, Val Acc: 0.8432
# Precision: 0.8484, Recall: 0.8432, F1-score: 0.8422
# --------------------------------------------------
# Epoch [181/1500]
# Train Loss: 1.3028, Train Acc: 0.9711
# Val Loss: 1.4747, Val Acc: 0.7960
# Precision: 0.8165, Recall: 0.7960, F1-score: 0.7957
# --------------------------------------------------
# Epoch [182/1500]
# Train Loss: 1.3126, Train Acc: 0.9606
# Val Loss: 1.4908, Val Acc: 0.8010
# Precision: 0.8456, Recall: 0.8010, F1-score: 0.8070
# --------------------------------------------------
# Epoch [183/1500]
# Train Loss: 1.3138, Train Acc: 0.9611
# Val Loss: 1.4913, Val Acc: 0.7976
# Precision: 0.8036, Recall: 0.7976, F1-score: 0.7971
# --------------------------------------------------
# Epoch [184/1500]
# Train Loss: 1.3118, Train Acc: 0.9637
# Val Loss: 1.4690, Val Acc: 0.7926
# Precision: 0.8068, Recall: 0.7926, F1-score: 0.7918
# --------------------------------------------------
# Epoch [185/1500]
# Train Loss: 1.3014, Train Acc: 0.9729
# Val Loss: 1.4546, Val Acc: 0.8280
# Precision: 0.8299, Recall: 0.8280, F1-score: 0.8280
# --------------------------------------------------
# Epoch [186/1500]
# Train Loss: 1.2968, Train Acc: 0.9768
# Val Loss: 1.4270, Val Acc: 0.8398
# Precision: 0.8475, Recall: 0.8398, F1-score: 0.8401
# --------------------------------------------------
# Epoch [187/1500]
# Train Loss: 1.3002, Train Acc: 0.9746
# Val Loss: 1.4353, Val Acc: 0.8364
# Precision: 0.8375, Recall: 0.8364, F1-score: 0.8355
# --------------------------------------------------
# Epoch [188/1500]
# Train Loss: 1.2983, Train Acc: 0.9755
# Val Loss: 1.4223, Val Acc: 0.8465
# Precision: 0.8479, Recall: 0.8465, F1-score: 0.8461
# --------------------------------------------------
# Epoch [189/1500]
# Train Loss: 1.2967, Train Acc: 0.9777
# Val Loss: 1.4389, Val Acc: 0.8246
# Precision: 0.8285, Recall: 0.8246, F1-score: 0.8232
# --------------------------------------------------
# Epoch [190/1500]
# Train Loss: 1.2961, Train Acc: 0.9773
# Val Loss: 1.4147, Val Acc: 0.8499
# Precision: 0.8523, Recall: 0.8499, F1-score: 0.8496
# --------------------------------------------------
# Epoch [191/1500]
# Train Loss: 1.2973, Train Acc: 0.9768
# Val Loss: 1.4456, Val Acc: 0.8196
# Precision: 0.8225, Recall: 0.8196, F1-score: 0.8184
# --------------------------------------------------
# Epoch [192/1500]
# Train Loss: 1.2947, Train Acc: 0.9803
# Val Loss: 1.4279, Val Acc: 0.8381
# Precision: 0.8434, Recall: 0.8381, F1-score: 0.8379
# --------------------------------------------------
# Epoch [193/1500]
# Train Loss: 1.3013, Train Acc: 0.9720
# Val Loss: 1.4827, Val Acc: 0.7926
# Precision: 0.8107, Recall: 0.7926, F1-score: 0.7926
# --------------------------------------------------
# Epoch [194/1500]
# Train Loss: 1.2959, Train Acc: 0.9790
# Val Loss: 1.4399, Val Acc: 0.8297
# Precision: 0.8313, Recall: 0.8297, F1-score: 0.8289
# --------------------------------------------------
# Epoch [195/1500]
# Train Loss: 1.2932, Train Acc: 0.9803
# Val Loss: 1.4293, Val Acc: 0.8415
# Precision: 0.8491, Recall: 0.8415, F1-score: 0.8430
# --------------------------------------------------
# Epoch [196/1500]
# Train Loss: 1.2952, Train Acc: 0.9799
# Val Loss: 1.4352, Val Acc: 0.8432
# Precision: 0.8472, Recall: 0.8432, F1-score: 0.8435
# --------------------------------------------------
# Epoch [197/1500]
# Train Loss: 1.2934, Train Acc: 0.9812
# Val Loss: 1.4131, Val Acc: 0.8600
# Precision: 0.8649, Recall: 0.8600, F1-score: 0.8610
# --------------------------------------------------
# Epoch [198/1500]
# Train Loss: 1.2997, Train Acc: 0.9751
# Val Loss: 1.4121, Val Acc: 0.8533
# Precision: 0.8542, Recall: 0.8533, F1-score: 0.8529
# --------------------------------------------------
# Epoch [199/1500]
# Train Loss: 1.3025, Train Acc: 0.9720
# Val Loss: 1.4363, Val Acc: 0.8331
# Precision: 0.8454, Recall: 0.8331, F1-score: 0.8346
# --------------------------------------------------
# Epoch [200/1500]
# Train Loss: 1.3054, Train Acc: 0.9694
# Val Loss: 1.4831, Val Acc: 0.7960
# Precision: 0.8112, Recall: 0.7960, F1-score: 0.7976
# --------------------------------------------------
# Epoch [201/1500]
# Train Loss: 1.3041, Train Acc: 0.9694
# Val Loss: 1.4058, Val Acc: 0.8651
# Precision: 0.8675, Recall: 0.8651, F1-score: 0.8638
# --------------------------------------------------
# Epoch [202/1500]
# Train Loss: 1.2990, Train Acc: 0.9751
# Val Loss: 1.4336, Val Acc: 0.8229
# Precision: 0.8376, Recall: 0.8229, F1-score: 0.8247
# --------------------------------------------------
# Epoch [203/1500]
# Train Loss: 1.2966, Train Acc: 0.9773
# Val Loss: 1.4142, Val Acc: 0.8550
# Precision: 0.8639, Recall: 0.8550, F1-score: 0.8557
# --------------------------------------------------
# Epoch [204/1500]
# Train Loss: 1.3023, Train Acc: 0.9711
# Val Loss: 1.4109, Val Acc: 0.8432
# Precision: 0.8518, Recall: 0.8432, F1-score: 0.8449
# --------------------------------------------------
# Epoch [205/1500]
# Train Loss: 1.2982, Train Acc: 0.9764
# Val Loss: 1.4468, Val Acc: 0.8162
# Precision: 0.8293, Recall: 0.8162, F1-score: 0.8123
# --------------------------------------------------
# Epoch [206/1500]
# Train Loss: 1.3042, Train Acc: 0.9694
# Val Loss: 1.4618, Val Acc: 0.8145
# Precision: 0.8336, Recall: 0.8145, F1-score: 0.8159
# --------------------------------------------------
# Epoch [207/1500]
# Train Loss: 1.3092, Train Acc: 0.9646
# Val Loss: 1.4988, Val Acc: 0.7841
# Precision: 0.7923, Recall: 0.7841, F1-score: 0.7831
# --------------------------------------------------
# Epoch [208/1500]
# Train Loss: 1.3084, Train Acc: 0.9672
# Val Loss: 1.4837, Val Acc: 0.7960
# Precision: 0.8077, Recall: 0.7960, F1-score: 0.7962
# --------------------------------------------------
# Epoch [209/1500]
# Train Loss: 1.3065, Train Acc: 0.9681
# Val Loss: 1.4451, Val Acc: 0.8229
# Precision: 0.8348, Recall: 0.8229, F1-score: 0.8222
# --------------------------------------------------
# Epoch [210/1500]
# Train Loss: 1.2980, Train Acc: 0.9773
# Val Loss: 1.4512, Val Acc: 0.8229
# Precision: 0.8305, Recall: 0.8229, F1-score: 0.8212
# --------------------------------------------------
# Epoch [211/1500]
# Train Loss: 1.3016, Train Acc: 0.9725
# Val Loss: 1.4492, Val Acc: 0.8364
# Precision: 0.8518, Recall: 0.8364, F1-score: 0.8363
# --------------------------------------------------
# Epoch [212/1500]
# Train Loss: 1.2995, Train Acc: 0.9755
# Val Loss: 1.4305, Val Acc: 0.8415
# Precision: 0.8487, Recall: 0.8415, F1-score: 0.8402
# --------------------------------------------------
# Epoch [213/1500]
# Train Loss: 1.3083, Train Acc: 0.9659
# Val Loss: 1.4162, Val Acc: 0.8516
# Precision: 0.8578, Recall: 0.8516, F1-score: 0.8510
# --------------------------------------------------
# Epoch [214/1500]
# Train Loss: 1.3015, Train Acc: 0.9729
# Val Loss: 1.4629, Val Acc: 0.8162
# Precision: 0.8192, Recall: 0.8162, F1-score: 0.8158
# --------------------------------------------------
# Epoch [215/1500]
# Train Loss: 1.3064, Train Acc: 0.9685
# Val Loss: 1.4182, Val Acc: 0.8533
# Precision: 0.8561, Recall: 0.8533, F1-score: 0.8522
# --------------------------------------------------
# Epoch [216/1500]
# Train Loss: 1.3025, Train Acc: 0.9711
# Val Loss: 1.4100, Val Acc: 0.8499
# Precision: 0.8523, Recall: 0.8499, F1-score: 0.8494
# --------------------------------------------------
# Epoch [217/1500]
# Train Loss: 1.3011, Train Acc: 0.9725
# Val Loss: 1.4765, Val Acc: 0.7960
# Precision: 0.8054, Recall: 0.7960, F1-score: 0.7965
# --------------------------------------------------
# Epoch [218/1500]
# Train Loss: 1.3022, Train Acc: 0.9725
# Val Loss: 1.4754, Val Acc: 0.8027
# Precision: 0.8144, Recall: 0.8027, F1-score: 0.8026
# --------------------------------------------------
# Epoch [219/1500]
# Train Loss: 1.3045, Train Acc: 0.9694
# Val Loss: 1.4809, Val Acc: 0.7757
# Precision: 0.7799, Recall: 0.7757, F1-score: 0.7705
# --------------------------------------------------
# Epoch [220/1500]
# Train Loss: 1.3043, Train Acc: 0.9711
# Val Loss: 1.4437, Val Acc: 0.8415
# Precision: 0.8601, Recall: 0.8415, F1-score: 0.8433
# --------------------------------------------------
# Epoch [221/1500]
# Train Loss: 1.2946, Train Acc: 0.9794
# Val Loss: 1.4632, Val Acc: 0.8044
# Precision: 0.8114, Recall: 0.8044, F1-score: 0.8018
# --------------------------------------------------
# Epoch [222/1500]
# Train Loss: 1.2880, Train Acc: 0.9860
# Val Loss: 1.4275, Val Acc: 0.8550
# Precision: 0.8622, Recall: 0.8550, F1-score: 0.8555
# --------------------------------------------------
# Epoch [223/1500]
# Train Loss: 1.2969, Train Acc: 0.9768
# Val Loss: 1.4291, Val Acc: 0.8499
# Precision: 0.8537, Recall: 0.8499, F1-score: 0.8491
# --------------------------------------------------
# Epoch [224/1500]
# Train Loss: 1.2960, Train Acc: 0.9773
# Val Loss: 1.4270, Val Acc: 0.8432
# Precision: 0.8483, Recall: 0.8432, F1-score: 0.8431
# --------------------------------------------------
# Epoch [225/1500]
# Train Loss: 1.2955, Train Acc: 0.9799
# Val Loss: 1.4309, Val Acc: 0.8364
# Precision: 0.8447, Recall: 0.8364, F1-score: 0.8364
# --------------------------------------------------
# Epoch [226/1500]
# Train Loss: 1.2957, Train Acc: 0.9794
# Val Loss: 1.4677, Val Acc: 0.7993
# Precision: 0.8233, Recall: 0.7993, F1-score: 0.7994
# --------------------------------------------------
# Epoch [227/1500]
# Train Loss: 1.3026, Train Acc: 0.9720
# Val Loss: 1.4227, Val Acc: 0.8567
# Precision: 0.8608, Recall: 0.8567, F1-score: 0.8569
# --------------------------------------------------
# Epoch [228/1500]
# Train Loss: 1.2956, Train Acc: 0.9786
# Val Loss: 1.4243, Val Acc: 0.8331
# Precision: 0.8459, Recall: 0.8331, F1-score: 0.8325
# --------------------------------------------------
# Epoch [229/1500]
# Train Loss: 1.2965, Train Acc: 0.9786
# Val Loss: 1.3998, Val Acc: 0.8651
# Precision: 0.8684, Recall: 0.8651, F1-score: 0.8653
# --------------------------------------------------
# Epoch [230/1500]
# Train Loss: 1.2911, Train Acc: 0.9838
# Val Loss: 1.4206, Val Acc: 0.8449
# Precision: 0.8457, Recall: 0.8449, F1-score: 0.8445
# --------------------------------------------------
# Epoch [231/1500]
# Train Loss: 1.2876, Train Acc: 0.9869
# Val Loss: 1.4149, Val Acc: 0.8583
# Precision: 0.8704, Recall: 0.8583, F1-score: 0.8582
# --------------------------------------------------
# Epoch [232/1500]
# Train Loss: 1.2947, Train Acc: 0.9781
# Val Loss: 1.4161, Val Acc: 0.8482
# Precision: 0.8567, Recall: 0.8482, F1-score: 0.8495
# --------------------------------------------------
# Epoch [233/1500]
# Train Loss: 1.2987, Train Acc: 0.9764
# Val Loss: 1.4494, Val Acc: 0.8398
# Precision: 0.8532, Recall: 0.8398, F1-score: 0.8408
# --------------------------------------------------
# Epoch [234/1500]
# Train Loss: 1.2967, Train Acc: 0.9786
# Val Loss: 1.3954, Val Acc: 0.8685
# Precision: 0.8705, Recall: 0.8685, F1-score: 0.8688
# --------------------------------------------------
# Epoch [235/1500]
# Train Loss: 1.2925, Train Acc: 0.9834
# Val Loss: 1.4050, Val Acc: 0.8685
# Precision: 0.8741, Recall: 0.8685, F1-score: 0.8692
# --------------------------------------------------
# Epoch [236/1500]
# Train Loss: 1.3058, Train Acc: 0.9681
# Val Loss: 1.4374, Val Acc: 0.8297
# Precision: 0.8343, Recall: 0.8297, F1-score: 0.8301
# --------------------------------------------------
# Epoch [237/1500]
# Train Loss: 1.3041, Train Acc: 0.9690
# Val Loss: 1.4454, Val Acc: 0.8280
# Precision: 0.8571, Recall: 0.8280, F1-score: 0.8336
# --------------------------------------------------
# Epoch [238/1500]
# Train Loss: 1.3076, Train Acc: 0.9668
# Val Loss: 1.4812, Val Acc: 0.7875
# Precision: 0.8159, Recall: 0.7875, F1-score: 0.7869
# --------------------------------------------------
# Epoch [239/1500]
# Train Loss: 1.3183, Train Acc: 0.9550
# Val Loss: 1.4711, Val Acc: 0.7960
# Precision: 0.8117, Recall: 0.7960, F1-score: 0.7934
# --------------------------------------------------
# Epoch [240/1500]
# Train Loss: 1.3115, Train Acc: 0.9624
# Val Loss: 1.4229, Val Acc: 0.8381
# Precision: 0.8517, Recall: 0.8381, F1-score: 0.8399
# --------------------------------------------------
# Epoch [241/1500]
# Train Loss: 1.2993, Train Acc: 0.9755
# Val Loss: 1.4243, Val Acc: 0.8331
# Precision: 0.8466, Recall: 0.8331, F1-score: 0.8338
# --------------------------------------------------
# Epoch [242/1500]
# Train Loss: 1.3051, Train Acc: 0.9703
# Val Loss: 1.4500, Val Acc: 0.8179
# Precision: 0.8227, Recall: 0.8179, F1-score: 0.8182
# --------------------------------------------------
# Epoch [243/1500]
# Train Loss: 1.2968, Train Acc: 0.9786
# Val Loss: 1.4720, Val Acc: 0.8145
# Precision: 0.8358, Recall: 0.8145, F1-score: 0.8167
# --------------------------------------------------
# Epoch [244/1500]
# Train Loss: 1.3017, Train Acc: 0.9725
# Val Loss: 1.4170, Val Acc: 0.8583
# Precision: 0.8617, Recall: 0.8583, F1-score: 0.8576
# --------------------------------------------------
# Epoch [245/1500]
# Train Loss: 1.2994, Train Acc: 0.9764
# Val Loss: 1.4106, Val Acc: 0.8550
# Precision: 0.8594, Recall: 0.8550, F1-score: 0.8547
# --------------------------------------------------
# Epoch [246/1500]
# Train Loss: 1.3013, Train Acc: 0.9738
# Val Loss: 1.4171, Val Acc: 0.8651
# Precision: 0.8722, Recall: 0.8651, F1-score: 0.8647
# --------------------------------------------------
# Epoch [247/1500]
# Train Loss: 1.2969, Train Acc: 0.9781
# Val Loss: 1.4635, Val Acc: 0.8078
# Precision: 0.8252, Recall: 0.8078, F1-score: 0.8079
# --------------------------------------------------
# Epoch [248/1500]
# Train Loss: 1.2949, Train Acc: 0.9781
# Val Loss: 1.4407, Val Acc: 0.8415
# Precision: 0.8421, Recall: 0.8415, F1-score: 0.8402
# --------------------------------------------------
# Epoch [249/1500]
# Train Loss: 1.3059, Train Acc: 0.9681
# Val Loss: 1.4266, Val Acc: 0.8415
# Precision: 0.8457, Recall: 0.8415, F1-score: 0.8401
# --------------------------------------------------
# Epoch [250/1500]
# Train Loss: 1.2981, Train Acc: 0.9768
# Val Loss: 1.4204, Val Acc: 0.8432
# Precision: 0.8496, Recall: 0.8432, F1-score: 0.8440
# --------------------------------------------------
# Epoch [251/1500]
# Train Loss: 1.2999, Train Acc: 0.9733
# Val Loss: 1.4289, Val Acc: 0.8331
# ...
# Val Loss: 1.3885, Val Acc: 0.8752
# Precision: 0.8802, Recall: 0.8752, F1-score: 0.8753
# --------------------------------------------------
# Epoch [1419/1500]
# Train Loss: 1.2804, Train Acc: 0.9934
# Val Loss: 1.3922, Val Acc: 0.8752
# Precision: 0.8787, Recall: 0.8752, F1-score: 0.8756
# --------------------------------------------------
# Epoch [1420/1500]
# Train Loss: 1.2765, Train Acc: 0.9978
# Val Loss: 1.3862, Val Acc: 0.8836
# Precision: 0.8857, Recall: 0.8836, F1-score: 0.8838
# --------------------------------------------------
# Epoch [1421/1500]
# Train Loss: 1.2763, Train Acc: 0.9978
# Val Loss: 1.3818, Val Acc: 0.8887
# Precision: 0.8909, Recall: 0.8887, F1-score: 0.8887
# --------------------------------------------------
# Epoch [1422/1500]
# Train Loss: 1.2764, Train Acc: 0.9978
# Val Loss: 1.3754, Val Acc: 0.8938
# Precision: 0.8965, Recall: 0.8938, F1-score: 0.8938
# --------------------------------------------------
# Epoch [1423/1500]
# Train Loss: 1.2767, Train Acc: 0.9974
# Val Loss: 1.3726, Val Acc: 0.8988
# Precision: 0.9021, Recall: 0.8988, F1-score: 0.8988
# --------------------------------------------------
# Epoch [1424/1500]
# Train Loss: 1.2762, Train Acc: 0.9978
# Val Loss: 1.3740, Val Acc: 0.8938
# Precision: 0.8970, Recall: 0.8938, F1-score: 0.8940
# --------------------------------------------------
# Epoch [1425/1500]
# Train Loss: 1.2767, Train Acc: 0.9974
# Val Loss: 1.3752, Val Acc: 0.8921
# Precision: 0.8950, Recall: 0.8921, F1-score: 0.8924
# --------------------------------------------------
# Epoch [1426/1500]
# Train Loss: 1.2777, Train Acc: 0.9965
# Val Loss: 1.3696, Val Acc: 0.8988
# Precision: 0.9026, Recall: 0.8988, F1-score: 0.8993
# --------------------------------------------------
# Epoch [1427/1500]
# Train Loss: 1.2764, Train Acc: 0.9978
# Val Loss: 1.3717, Val Acc: 0.8954
# Precision: 0.8995, Recall: 0.8954, F1-score: 0.8961
# --------------------------------------------------
# Epoch [1428/1500]
# Train Loss: 1.2770, Train Acc: 0.9969
# Val Loss: 1.3673, Val Acc: 0.9005
# Precision: 0.9019, Recall: 0.9005, F1-score: 0.9002
# --------------------------------------------------
# Epoch [1429/1500]
# Train Loss: 1.2789, Train Acc: 0.9948
# Val Loss: 1.4329, Val Acc: 0.8347
# Precision: 0.8429, Recall: 0.8347, F1-score: 0.8337
# --------------------------------------------------
# Epoch [1430/1500]
# Train Loss: 1.2812, Train Acc: 0.9930
# Val Loss: 1.3889, Val Acc: 0.8752
# Precision: 0.8798, Recall: 0.8752, F1-score: 0.8762
# --------------------------------------------------
# Epoch [1431/1500]
# Train Loss: 1.2784, Train Acc: 0.9956
# Val Loss: 1.3877, Val Acc: 0.8786
# Precision: 0.8863, Recall: 0.8786, F1-score: 0.8798
# --------------------------------------------------
# Epoch [1432/1500]
# Train Loss: 1.2797, Train Acc: 0.9943
# Val Loss: 1.3951, Val Acc: 0.8786
# Precision: 0.8802, Recall: 0.8786, F1-score: 0.8788
# --------------------------------------------------
# Epoch [1433/1500]
# Train Loss: 1.2822, Train Acc: 0.9917
# Val Loss: 1.3981, Val Acc: 0.8668
# Precision: 0.8693, Recall: 0.8668, F1-score: 0.8662
# --------------------------------------------------
# Epoch [1434/1500]
# Train Loss: 1.2803, Train Acc: 0.9939
# Val Loss: 1.3853, Val Acc: 0.8803
# Precision: 0.8834, Recall: 0.8803, F1-score: 0.8800
# --------------------------------------------------
# Epoch [1435/1500]
# Train Loss: 1.2784, Train Acc: 0.9952
# Val Loss: 1.4180, Val Acc: 0.8550
# Precision: 0.8627, Recall: 0.8550, F1-score: 0.8560
# --------------------------------------------------
# Epoch [1436/1500]
# Train Loss: 1.2848, Train Acc: 0.9891
# Val Loss: 1.4059, Val Acc: 0.8735
# Precision: 0.8783, Recall: 0.8735, F1-score: 0.8735
# --------------------------------------------------
# Epoch [1437/1500]
# Train Loss: 1.2792, Train Acc: 0.9948
# Val Loss: 1.3797, Val Acc: 0.8904
# Precision: 0.8930, Recall: 0.8904, F1-score: 0.8905
# --------------------------------------------------
# Epoch [1438/1500]
# Train Loss: 1.2798, Train Acc: 0.9948
# Val Loss: 1.3777, Val Acc: 0.8954
# Precision: 0.8966, Recall: 0.8954, F1-score: 0.8954
# --------------------------------------------------
# Epoch [1439/1500]
# Train Loss: 1.2794, Train Acc: 0.9948
# Val Loss: 1.4039, Val Acc: 0.8735
# Precision: 0.8777, Recall: 0.8735, F1-score: 0.8740
# --------------------------------------------------
# Epoch [1440/1500]
# Train Loss: 1.2816, Train Acc: 0.9921
# Val Loss: 1.3982, Val Acc: 0.8735
# Precision: 0.8752, Recall: 0.8735, F1-score: 0.8734
# --------------------------------------------------
# Epoch [1441/1500]
# Train Loss: 1.2804, Train Acc: 0.9934
# Val Loss: 1.3913, Val Acc: 0.8853
# Precision: 0.8904, Recall: 0.8853, F1-score: 0.8859
# --------------------------------------------------
# Epoch [1442/1500]
# Train Loss: 1.2860, Train Acc: 0.9878
# Val Loss: 1.4143, Val Acc: 0.8583
# Precision: 0.8643, Recall: 0.8583, F1-score: 0.8584
# --------------------------------------------------
# Epoch [1443/1500]
# Train Loss: 1.2981, Train Acc: 0.9764
# Val Loss: 1.4264, Val Acc: 0.8347
# Precision: 0.8383, Recall: 0.8347, F1-score: 0.8346
# --------------------------------------------------
# Epoch [1444/1500]
# Train Loss: 1.3017, Train Acc: 0.9720
# Val Loss: 1.5041, Val Acc: 0.7589
# Precision: 0.7908, Recall: 0.7589, F1-score: 0.7558
# --------------------------------------------------
# Epoch [1445/1500]
# Train Loss: 1.3030, Train Acc: 0.9711
# Val Loss: 1.4170, Val Acc: 0.8516
# Precision: 0.8627, Recall: 0.8516, F1-score: 0.8522
# --------------------------------------------------
# Epoch [1446/1500]
# Train Loss: 1.2970, Train Acc: 0.9773
# Val Loss: 1.4549, Val Acc: 0.8246
# Precision: 0.8404, Recall: 0.8246, F1-score: 0.8247
# --------------------------------------------------
# Epoch [1447/1500]
# Train Loss: 1.3048, Train Acc: 0.9690
# Val Loss: 1.4555, Val Acc: 0.8145
# Precision: 0.8244, Recall: 0.8145, F1-score: 0.8127
# --------------------------------------------------
# Epoch [1448/1500]
# Train Loss: 1.2893, Train Acc: 0.9860
# Val Loss: 1.4436, Val Acc: 0.8280
# Precision: 0.8327, Recall: 0.8280, F1-score: 0.8278
# --------------------------------------------------
# Epoch [1449/1500]
# Train Loss: 1.2941, Train Acc: 0.9803
# Val Loss: 1.4686, Val Acc: 0.7993
# Precision: 0.8052, Recall: 0.7993, F1-score: 0.7977
# --------------------------------------------------
# Epoch [1450/1500]
# Train Loss: 1.2901, Train Acc: 0.9834
# Val Loss: 1.4354, Val Acc: 0.8331
# Precision: 0.8365, Recall: 0.8331, F1-score: 0.8332
# --------------------------------------------------
# Epoch [1451/1500]
# Train Loss: 1.2937, Train Acc: 0.9825
# Val Loss: 1.4154, Val Acc: 0.8482
# Precision: 0.8599, Recall: 0.8482, F1-score: 0.8487
# --------------------------------------------------
# Epoch [1452/1500]
# Train Loss: 1.2858, Train Acc: 0.9882
# Val Loss: 1.4499, Val Acc: 0.8212
# Precision: 0.8264, Recall: 0.8212, F1-score: 0.8199
# --------------------------------------------------
# Epoch [1453/1500]
# Train Loss: 1.2956, Train Acc: 0.9786
# Val Loss: 1.4894, Val Acc: 0.7892
# Precision: 0.8082, Recall: 0.7892, F1-score: 0.7909
# --------------------------------------------------
# Epoch [1454/1500]
# Train Loss: 1.2997, Train Acc: 0.9742
# Val Loss: 1.4697, Val Acc: 0.7943
# Precision: 0.8023, Recall: 0.7943, F1-score: 0.7916
# --------------------------------------------------
# Epoch [1455/1500]
# Train Loss: 1.3074, Train Acc: 0.9668
# Val Loss: 1.4155, Val Acc: 0.8533
# Precision: 0.8545, Recall: 0.8533, F1-score: 0.8529
# --------------------------------------------------
# Epoch [1456/1500]
# Train Loss: 1.2960, Train Acc: 0.9790
# Val Loss: 1.3957, Val Acc: 0.8752
# Precision: 0.8784, Recall: 0.8752, F1-score: 0.8742
# --------------------------------------------------
# Epoch [1457/1500]
# Train Loss: 1.2996, Train Acc: 0.9746
# Val Loss: 1.4413, Val Acc: 0.8280
# Precision: 0.8344, Recall: 0.8280, F1-score: 0.8280
# --------------------------------------------------
# Epoch [1458/1500]
# Train Loss: 1.2914, Train Acc: 0.9825
# Val Loss: 1.4589, Val Acc: 0.8128
# Precision: 0.8349, Recall: 0.8128, F1-score: 0.8150
# --------------------------------------------------
# Epoch [1459/1500]
# Train Loss: 1.2966, Train Acc: 0.9777
# Val Loss: 1.4539, Val Acc: 0.8162
# Precision: 0.8253, Recall: 0.8162, F1-score: 0.8161
# --------------------------------------------------
# Epoch [1460/1500]
# Train Loss: 1.2931, Train Acc: 0.9816
# Val Loss: 1.4167, Val Acc: 0.8516
# Precision: 0.8572, Recall: 0.8516, F1-score: 0.8519
# --------------------------------------------------
# Epoch [1461/1500]
# Train Loss: 1.2891, Train Acc: 0.9847
# Val Loss: 1.3964, Val Acc: 0.8668
# Precision: 0.8674, Recall: 0.8668, F1-score: 0.8665
# --------------------------------------------------
# Epoch [1462/1500]
# Train Loss: 1.2863, Train Acc: 0.9878
# Val Loss: 1.3746, Val Acc: 0.8887
# Precision: 0.8910, Recall: 0.8887, F1-score: 0.8889
# --------------------------------------------------
# Epoch [1463/1500]
# Train Loss: 1.2873, Train Acc: 0.9869
# Val Loss: 1.3713, Val Acc: 0.8921
# Precision: 0.8959, Recall: 0.8921, F1-score: 0.8927
# --------------------------------------------------
# Epoch [1464/1500]
# Train Loss: 1.2820, Train Acc: 0.9917
# Val Loss: 1.3822, Val Acc: 0.8887
# Precision: 0.8905, Recall: 0.8887, F1-score: 0.8880
# --------------------------------------------------
# Epoch [1465/1500]
# Train Loss: 1.2898, Train Acc: 0.9834
# Val Loss: 1.4125, Val Acc: 0.8600
# Precision: 0.8764, Recall: 0.8600, F1-score: 0.8613
# --------------------------------------------------
# Epoch [1466/1500]
# Train Loss: 1.2904, Train Acc: 0.9834
# Val Loss: 1.3909, Val Acc: 0.8752
# Precision: 0.8782, Recall: 0.8752, F1-score: 0.8749
# --------------------------------------------------
# Epoch [1467/1500]
# Train Loss: 1.2863, Train Acc: 0.9878
# Val Loss: 1.3942, Val Acc: 0.8718
# Precision: 0.8723, Recall: 0.8718, F1-score: 0.8713
# --------------------------------------------------
# Epoch [1468/1500]
# Train Loss: 1.2861, Train Acc: 0.9878
# Val Loss: 1.3722, Val Acc: 0.8836
# Precision: 0.8843, Recall: 0.8836, F1-score: 0.8837
# --------------------------------------------------
# Epoch [1469/1500]
# Train Loss: 1.2830, Train Acc: 0.9913
# Val Loss: 1.3713, Val Acc: 0.8904
# Precision: 0.8905, Recall: 0.8904, F1-score: 0.8902
# --------------------------------------------------
# Epoch [1470/1500]
# Train Loss: 1.2813, Train Acc: 0.9930
# Val Loss: 1.3769, Val Acc: 0.8904
# Precision: 0.8920, Recall: 0.8904, F1-score: 0.8906
# --------------------------------------------------
# Epoch [1471/1500]
# Train Loss: 1.2806, Train Acc: 0.9930
# Val Loss: 1.3883, Val Acc: 0.8685
# Precision: 0.8729, Recall: 0.8685, F1-score: 0.8693
# --------------------------------------------------
# Epoch [1472/1500]
# Train Loss: 1.2836, Train Acc: 0.9899
# Val Loss: 1.3930, Val Acc: 0.8668
# Precision: 0.8698, Recall: 0.8668, F1-score: 0.8670
# --------------------------------------------------
# Epoch [1473/1500]
# Train Loss: 1.2829, Train Acc: 0.9908
# Val Loss: 1.3852, Val Acc: 0.8752
# Precision: 0.8772, Recall: 0.8752, F1-score: 0.8756
# --------------------------------------------------
# Epoch [1474/1500]
# Train Loss: 1.2811, Train Acc: 0.9930
# Val Loss: 1.4083, Val Acc: 0.8634
# Precision: 0.8656, Recall: 0.8634, F1-score: 0.8633
# --------------------------------------------------
# Epoch [1475/1500]
# Train Loss: 1.2855, Train Acc: 0.9882
# Val Loss: 1.4253, Val Acc: 0.8516
# Precision: 0.8529, Recall: 0.8516, F1-score: 0.8506
# --------------------------------------------------
# Epoch [1476/1500]
# Train Loss: 1.2895, Train Acc: 0.9851
# Val Loss: 1.4445, Val Acc: 0.8246
# Precision: 0.8373, Recall: 0.8246, F1-score: 0.8245
# --------------------------------------------------
# Epoch [1477/1500]
# Train Loss: 1.2848, Train Acc: 0.9904
# Val Loss: 1.4664, Val Acc: 0.8044
# Precision: 0.8349, Recall: 0.8044, F1-score: 0.8090
# --------------------------------------------------
# Epoch [1478/1500]
# Train Loss: 1.2894, Train Acc: 0.9847
# Val Loss: 1.3834, Val Acc: 0.8735
# Precision: 0.8763, Recall: 0.8735, F1-score: 0.8731
# --------------------------------------------------
# Epoch [1479/1500]
# Train Loss: 1.2832, Train Acc: 0.9913
# Val Loss: 1.3803, Val Acc: 0.8853
# Precision: 0.8865, Recall: 0.8853, F1-score: 0.8852
# --------------------------------------------------
# Epoch [1480/1500]
# Train Loss: 1.2895, Train Acc: 0.9843
# Val Loss: 1.4092, Val Acc: 0.8634
# Precision: 0.8666, Recall: 0.8634, F1-score: 0.8636
# --------------------------------------------------
# Epoch [1481/1500]
# Train Loss: 1.2885, Train Acc: 0.9856
# Val Loss: 1.3896, Val Acc: 0.8769
# Precision: 0.8799, Recall: 0.8769, F1-score: 0.8772
# --------------------------------------------------
# Epoch [1482/1500]
# Train Loss: 1.2927, Train Acc: 0.9816
# Val Loss: 1.3765, Val Acc: 0.8954
# Precision: 0.8969, Recall: 0.8954, F1-score: 0.8953
# --------------------------------------------------
# Epoch [1483/1500]
# Train Loss: 1.2829, Train Acc: 0.9913
# Val Loss: 1.4049, Val Acc: 0.8651
# Precision: 0.8667, Recall: 0.8651, F1-score: 0.8646
# --------------------------------------------------
# Epoch [1484/1500]
# Train Loss: 1.2818, Train Acc: 0.9926
# Val Loss: 1.4051, Val Acc: 0.8651
# Precision: 0.8725, Recall: 0.8651, F1-score: 0.8658
# --------------------------------------------------
# Epoch [1485/1500]
# Train Loss: 1.2822, Train Acc: 0.9913
# Val Loss: 1.3970, Val Acc: 0.8718
# Precision: 0.8769, Recall: 0.8718, F1-score: 0.8721
# --------------------------------------------------
# Epoch [1486/1500]
# Train Loss: 1.2836, Train Acc: 0.9904
# Val Loss: 1.4035, Val Acc: 0.8651
# Precision: 0.8704, Recall: 0.8651, F1-score: 0.8657
# --------------------------------------------------
# Epoch [1487/1500]
# Train Loss: 1.2869, Train Acc: 0.9873
# Val Loss: 1.3863, Val Acc: 0.8769
# Precision: 0.8784, Recall: 0.8769, F1-score: 0.8766
# --------------------------------------------------
# Epoch [1488/1500]
# Train Loss: 1.2805, Train Acc: 0.9934
# Val Loss: 1.3930, Val Acc: 0.8836
# Precision: 0.8882, Recall: 0.8836, F1-score: 0.8838
# --------------------------------------------------
# Epoch [1489/1500]
# Train Loss: 1.2843, Train Acc: 0.9899
# Val Loss: 1.3949, Val Acc: 0.8735
# Precision: 0.8764, Recall: 0.8735, F1-score: 0.8732
# --------------------------------------------------
# Epoch [1490/1500]
# Train Loss: 1.2877, Train Acc: 0.9860
# Val Loss: 1.4078, Val Acc: 0.8533
# Precision: 0.8574, Recall: 0.8533, F1-score: 0.8528
# --------------------------------------------------
# Epoch [1491/1500]
# Train Loss: 1.2863, Train Acc: 0.9878
# Val Loss: 1.4124, Val Acc: 0.8516
# Precision: 0.8528, Recall: 0.8516, F1-score: 0.8513
# --------------------------------------------------
# Epoch [1492/1500]
# Train Loss: 1.2876, Train Acc: 0.9856
# Val Loss: 1.4229, Val Acc: 0.8364
# Precision: 0.8393, Recall: 0.8364, F1-score: 0.8363
# --------------------------------------------------
# Epoch [1493/1500]
# Train Loss: 1.2846, Train Acc: 0.9895
# Val Loss: 1.4017, Val Acc: 0.8702
# Precision: 0.8700, Recall: 0.8702, F1-score: 0.8694
# --------------------------------------------------
# Epoch [1494/1500]
# Train Loss: 1.2918, Train Acc: 0.9821
# Val Loss: 1.4079, Val Acc: 0.8634
# Precision: 0.8698, Recall: 0.8634, F1-score: 0.8641
# --------------------------------------------------
# Epoch [1495/1500]
# Train Loss: 1.2836, Train Acc: 0.9904
# Val Loss: 1.3863, Val Acc: 0.8836
# Precision: 0.8870, Recall: 0.8836, F1-score: 0.8842
# --------------------------------------------------
# Epoch [1496/1500]
# Train Loss: 1.2822, Train Acc: 0.9917
# Val Loss: 1.3788, Val Acc: 0.8921
# Precision: 0.8934, Recall: 0.8921, F1-score: 0.8920
# --------------------------------------------------
# Epoch [1497/1500]
# Train Loss: 1.2803, Train Acc: 0.9939
# Val Loss: 1.3885, Val Acc: 0.8820
# Precision: 0.8851, Recall: 0.8820, F1-score: 0.8825
# --------------------------------------------------
# Epoch [1498/1500]
# Train Loss: 1.2793, Train Acc: 0.9948
# Val Loss: 1.3804, Val Acc: 0.8836
# Precision: 0.8871, Recall: 0.8836, F1-score: 0.8844
# --------------------------------------------------
# Epoch [1499/1500]
# Train Loss: 1.2845, Train Acc: 0.9891
# Val Loss: 1.3989, Val Acc: 0.8702
# Precision: 0.8759, Recall: 0.8702, F1-score: 0.8703
# --------------------------------------------------
# Epoch [1500/1500]
# Train Loss: 1.2863, Train Acc: 0.9873
# Val Loss: 1.3924, Val Acc: 0.8651
# Precision: 0.8686, Recall: 0.8651, F1-score: 0.8648
# --------------------------------------------------

# %%
torch.save(model.state_dict(), "C:/Nini/Capstone/Models/DataAugmentation_LSTM_model.pth")
