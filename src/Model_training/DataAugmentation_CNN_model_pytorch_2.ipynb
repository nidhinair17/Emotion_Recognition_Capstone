# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import precision_recall_fscore_support
import joblib

# %%
features = pd.read_csv("C:/Nini/Capstone/CSV_Files/DataAugmentation_ravdess_extracted_features.csv")
features = features.drop(features.columns[0], axis=1)
temp = shuffle(features)
df = np.random.rand(len(temp)) < 0.8
train = temp[df]
test = temp[~df]

# %%
X_train = np.array(train.iloc[:,:-1])
y_train = np.array(train.iloc[:,-1])
X_test = np.array(test.iloc[:,:-1])
y_test = np.array(test.iloc[:,-1])

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
joblib.dump(lb, "label_encoder.pkl")
print("Label Encoder saved successfully!")
# Out:
# Label Encoder saved successfully!

# %%
batch_size = 256
train_loader = DataLoader(TensorDataset(X_train,y_train), batch_size=batch_size,shuffle=True)
test_loader = DataLoader(TensorDataset(X_test,y_test), batch_size=batch_size, shuffle=False)

# %% [markdown]
# Test 1

# %%
class CNNModel(nn.Module):
    def __init__(self, input_size, num_classes):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=8)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=8)
        self.bn2 = nn.BatchNorm1d(128)
        self.pool1 = nn.MaxPool1d(kernel_size=4, padding=2)
        self.dropout1 = nn.Dropout(0.5)
        self.conv3 = nn.Conv1d(128, 128, kernel_size=8)
        self.bn3 = nn.BatchNorm1d(128)
        self.pool2 = nn.MaxPool1d(kernel_size=4, padding=2)
        self.dropout2 = nn.Dropout(0.5)
        self.conv4 = nn.Conv1d(128, 64, kernel_size=3, padding=2)
        self.bn4 = nn.BatchNorm1d(64)
        self.fc1 = nn.Linear(512, 256)
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, num_classes)

    # def _compute_flattened_size(self, input_size):
    #     with torch.no_grad():
    #         x = torch.randn(1, 1, input_size)  # Create a dummy input
    #         x = self.conv1(x)
    #         x = F.relu(x)
    #         x = self.conv2(x)
    #         x = F.relu(x)
    #         x = self.pool1(x)
    #         x = self.dropout1(x)
    #         x = self.conv3(x)
    #         x = F.relu(x)
    #         x = self.pool2(x)
    #         x = self.dropout2(x)
    #         x = self.conv4(x)
    #         x = F.relu(x)
    #         x = x.view(1, -1)  # Flatten
    #         self._to_linear = x.shape[1]

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# Test 2

# %%
# class CNNModel(nn.Module):
#     def __init__(self, input_size, num_classes):
#         super(CNNModel, self).__init__()
#         self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=8)
#         self.bn1 = nn.BatchNorm1d(64)
#         self.conv2 = nn.Conv1d(64, 128, kernel_size=8)
#         self.bn2 = nn.BatchNorm1d(128)
#         self.pool1 = nn.MaxPool1d(kernel_size=6, padding=2)
#         self.dropout1 = nn.Dropout(0.5)
#         self.conv3 = nn.Conv1d(128, 128, kernel_size=8)
#         self.bn3 = nn.BatchNorm1d(128)
#         self.pool2 = nn.MaxPool1d(kernel_size=6, padding=2)
#         self.dropout2 = nn.Dropout(0.5)
#         # self.conv4 = nn.Conv1d(128, 64, kernel_size=4, padding=2)
#         # self.bn4 = nn.BatchNorm1d(64)
#         self.fc1 = nn.Linear(384, 256)
#         self.dropout3 = nn.Dropout(0.5)
#         self.fc2 = nn.Linear(256, num_classes)

#     # def _compute_flattened_size(self, input_size):
#     #     with torch.no_grad():
#     #         x = torch.randn(1, 1, input_size)  # Create a dummy input
#     #         x = self.conv1(x)
#     #         x = F.relu(x)
#     #         x = self.conv2(x)
#     #         x = F.relu(x)
#     #         x = self.pool1(x)
#     #         x = self.dropout1(x)
#     #         x = self.conv3(x)
#     #         x = F.relu(x)
#     #         x = self.pool2(x)
#     #         x = self.dropout2(x)
#     #         x = self.conv4(x)
#     #         x = F.relu(x)
#     #         x = x.view(1, -1)  # Flatten
#     #         self._to_linear = x.shape[1]

#     def forward(self, x):
#         x = F.relu(self.bn1(self.conv1(x)))
#         x = F.relu(self.bn2(self.conv2(x)))
#         x = self.pool1(x)
#         x = self.dropout1(x)
#         x = F.relu(self.bn3(self.conv3(x)))
#         x = self.pool2(x)
#         x = self.dropout2(x)
#         # x = F.relu(self.bn4(self.conv4(x)))
#         x = x.view(x.size(0), -1)
#         x = F.relu(self.fc1(x))
#         x = self.dropout3(x)
#         x = self.fc2(x)
#         return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNModel(input_size=X_train.shape[1], num_classes=8).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=1e-4)

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: torch.Size([2317, 1, 128])

# %%
# epochs = 1500
# for epoch in range(epochs):
#     model.train()
#     running_loss = 0
#     total_loss = 0
#     total = 0
#     correct = 0
#     for X_batch, y_batch in train_loader:
#         X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#         optimizer.zero_grad()
#         outputs = model(X_batch)
#         loss = criterion(outputs, y_batch)
#         loss.backward()
#         optimizer.step()
#         running_loss += loss.item()
#         _, predicted = torch.max(outputs, 1)  # Get predicted class
#         correct += (predicted == y_batch).sum().item()
#         total += y_batch.size(0)
#     train_accuracy = correct / total
#     avg_train_loss = running_loss / len(train_loader)
#         # total_loss += loss.item()
#         # correct += (outputs.argmax(dim=1) == y_batch).sum().item()
#     model.eval()  # Set model to evaluation mode
#     val_correct = 0
#     val_total = 0
#     val_loss = 0.0

#     with torch.no_grad():  # Disable gradient computation for validation
#         for val_inputs, val_labels in test_loader:
#             val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)

#             val_outputs = model(val_inputs)
#             loss = criterion(val_outputs, val_labels)
#             val_loss += loss.item()

#             _, val_predicted = torch.max(val_outputs, 1)
#             val_correct += (val_predicted == val_labels).sum().item()
#             val_total += val_labels.size(0)
    
#     val_accuracy = val_correct / val_total
#     avg_val_loss = val_loss / len(test_loader)
#     # accuracy = correct / len(train_loader.dataset)
#     print(f"Epoch [{epoch+1}/{epochs}]")
#     print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
#     print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
#     print("-" * 50)

# %% [markdown]
# With Precision, recall and f1-score

# %%
epochs = 1500
for epoch in range(epochs):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    # Training loop
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)
    
    train_accuracy = correct / total
    avg_train_loss = running_loss / len(train_loader)

    # Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for val_inputs, val_labels in test_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()
            _, val_predicted = torch.max(val_outputs, 1)

            val_correct += (val_predicted == val_labels).sum().item()
            val_total += val_labels.size(0)

            # Store predictions and labels for evaluation
            all_preds.extend(val_predicted.cpu().numpy())
            all_labels.extend(val_labels.cpu().numpy())

    val_accuracy = val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)

    # Compute Precision, Recall, F1-score
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted',zero_division=1)

    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}")
    print("-" * 50)
# Out:
# Epoch [1/1500]
# Train Loss: 2.0381, Train Acc: 0.1972
# Val Loss: 1.9939, Val Acc: 0.2398
# Precision: 0.6007, Recall: 0.2398, F1-score: 0.1480
# --------------------------------------------------
# Epoch [2/1500]
# Train Loss: 1.8265, Train Acc: 0.2836
# Val Loss: 1.8986, Val Acc: 0.2487
# Precision: 0.4873, Recall: 0.2487, F1-score: 0.1828
# --------------------------------------------------
# Epoch [3/1500]
# Train Loss: 1.7933, Train Acc: 0.2866
# Val Loss: 1.8591, Val Acc: 0.2416
# Precision: 0.5091, Recall: 0.2416, F1-score: 0.1943
# --------------------------------------------------
# Epoch [4/1500]
# Train Loss: 1.7343, Train Acc: 0.3060
# Val Loss: 1.8060, Val Acc: 0.2948
# Precision: 0.3651, Recall: 0.2948, F1-score: 0.2352
# --------------------------------------------------
# Epoch [5/1500]
# Train Loss: 1.7033, Train Acc: 0.3457
# Val Loss: 1.7928, Val Acc: 0.3108
# Precision: 0.4397, Recall: 0.3108, F1-score: 0.2797
# --------------------------------------------------
# Epoch [6/1500]
# Train Loss: 1.6920, Train Acc: 0.3470
# Val Loss: 1.6768, Val Acc: 0.3268
# Precision: 0.3927, Recall: 0.3268, F1-score: 0.2744
# --------------------------------------------------
# Epoch [7/1500]
# Train Loss: 1.6783, Train Acc: 0.3345
# Val Loss: 1.6813, Val Acc: 0.3499
# Precision: 0.5101, Recall: 0.3499, F1-score: 0.3070
# --------------------------------------------------
# Epoch [8/1500]
# Train Loss: 1.6212, Train Acc: 0.3539
# Val Loss: 1.6676, Val Acc: 0.3659
# Precision: 0.3668, Recall: 0.3659, F1-score: 0.3136
# --------------------------------------------------
# Epoch [9/1500]
# Train Loss: 1.6745, Train Acc: 0.3660
# Val Loss: 1.6156, Val Acc: 0.3801
# Precision: 0.4113, Recall: 0.3801, F1-score: 0.3476
# --------------------------------------------------
# Epoch [10/1500]
# Train Loss: 1.6094, Train Acc: 0.3867
# Val Loss: 1.6003, Val Acc: 0.3677
# Precision: 0.4239, Recall: 0.3677, F1-score: 0.3188
# --------------------------------------------------
# Epoch [11/1500]
# Train Loss: 1.6196, Train Acc: 0.3923
# Val Loss: 1.5736, Val Acc: 0.4032
# Precision: 0.4589, Recall: 0.4032, F1-score: 0.3687
# --------------------------------------------------
# Epoch [12/1500]
# Train Loss: 1.5934, Train Acc: 0.4048
# Val Loss: 1.5741, Val Acc: 0.4210
# Precision: 0.4962, Recall: 0.4210, F1-score: 0.3856
# --------------------------------------------------
# Epoch [13/1500]
# Train Loss: 1.5671, Train Acc: 0.4087
# Val Loss: 1.5535, Val Acc: 0.4174
# Precision: 0.5240, Recall: 0.4174, F1-score: 0.3747
# --------------------------------------------------
# Epoch [14/1500]
# Train Loss: 1.5474, Train Acc: 0.4178
# Val Loss: 1.5111, Val Acc: 0.4103
# Precision: 0.4926, Recall: 0.4103, F1-score: 0.3671
# --------------------------------------------------
# Epoch [15/1500]
# Train Loss: 1.5034, Train Acc: 0.4195
# Val Loss: 1.5718, Val Acc: 0.3837
# Precision: 0.4363, Recall: 0.3837, F1-score: 0.3546
# --------------------------------------------------
# Epoch [16/1500]
# Train Loss: 1.5276, Train Acc: 0.4329
# Val Loss: 1.5200, Val Acc: 0.4121
# Precision: 0.4291, Recall: 0.4121, F1-score: 0.3883
# --------------------------------------------------
# Epoch [17/1500]
# Train Loss: 1.5085, Train Acc: 0.4156
# Val Loss: 1.4919, Val Acc: 0.4316
# Precision: 0.4580, Recall: 0.4316, F1-score: 0.4193
# --------------------------------------------------
# Epoch [18/1500]
# Train Loss: 1.4676, Train Acc: 0.4575
# Val Loss: 1.4444, Val Acc: 0.4707
# Precision: 0.4628, Recall: 0.4707, F1-score: 0.4347
# --------------------------------------------------
# Epoch [19/1500]
# Train Loss: 1.4153, Train Acc: 0.4428
# Val Loss: 1.4047, Val Acc: 0.4583
# Precision: 0.4710, Recall: 0.4583, F1-score: 0.4394
# --------------------------------------------------
# Epoch [20/1500]
# Train Loss: 1.4138, Train Acc: 0.4596
# Val Loss: 1.4730, Val Acc: 0.4494
# Precision: 0.4374, Recall: 0.4494, F1-score: 0.4252
# --------------------------------------------------
# Epoch [21/1500]
# Train Loss: 1.4307, Train Acc: 0.4765
# Val Loss: 1.4111, Val Acc: 0.4583
# Precision: 0.4536, Recall: 0.4583, F1-score: 0.4356
# --------------------------------------------------
# Epoch [22/1500]
# Train Loss: 1.4351, Train Acc: 0.4691
# Val Loss: 1.3618, Val Acc: 0.4920
# Precision: 0.5043, Recall: 0.4920, F1-score: 0.4666
# --------------------------------------------------
# Epoch [23/1500]
# Train Loss: 1.4328, Train Acc: 0.4687
# Val Loss: 1.3565, Val Acc: 0.4973
# Precision: 0.4737, Recall: 0.4973, F1-score: 0.4711
# --------------------------------------------------
# Epoch [24/1500]
# Train Loss: 1.3790, Train Acc: 0.4886
# Val Loss: 1.3854, Val Acc: 0.4813
# Precision: 0.4836, Recall: 0.4813, F1-score: 0.4625
# --------------------------------------------------
# Epoch [25/1500]
# Train Loss: 1.3270, Train Acc: 0.5011
# Val Loss: 1.3386, Val Acc: 0.4778
# Precision: 0.4934, Recall: 0.4778, F1-score: 0.4607
# --------------------------------------------------
# Epoch [26/1500]
# Train Loss: 1.3314, Train Acc: 0.4886
# Val Loss: 1.3220, Val Acc: 0.4796
# Precision: 0.4641, Recall: 0.4796, F1-score: 0.4553
# --------------------------------------------------
# Epoch [27/1500]
# Train Loss: 1.3640, Train Acc: 0.4985
# Val Loss: 1.3503, Val Acc: 0.5009
# Precision: 0.5171, Recall: 0.5009, F1-score: 0.4769
# --------------------------------------------------
# Epoch [28/1500]
# Train Loss: 1.4302, Train Acc: 0.4933
# Val Loss: 1.3126, Val Acc: 0.4938
# Precision: 0.4710, Recall: 0.4938, F1-score: 0.4626
# --------------------------------------------------
# Epoch [29/1500]
# Train Loss: 1.3389, Train Acc: 0.4847
# Val Loss: 1.2822, Val Acc: 0.5169
# Precision: 0.5107, Recall: 0.5169, F1-score: 0.5009
# --------------------------------------------------
# Epoch [30/1500]
# Train Loss: 1.3581, Train Acc: 0.4847
# Val Loss: 1.2857, Val Acc: 0.4956
# Precision: 0.4792, Recall: 0.4956, F1-score: 0.4737
# --------------------------------------------------
# Epoch [31/1500]
# Train Loss: 1.3459, Train Acc: 0.4972
# Val Loss: 1.3528, Val Acc: 0.4902
# Precision: 0.4947, Recall: 0.4902, F1-score: 0.4676
# --------------------------------------------------
# Epoch [32/1500]
# Train Loss: 1.3102, Train Acc: 0.4937
# Val Loss: 1.2572, Val Acc: 0.5311
# Precision: 0.5358, Recall: 0.5311, F1-score: 0.5214
# --------------------------------------------------
# Epoch [33/1500]
# Train Loss: 1.2723, Train Acc: 0.5145
# Val Loss: 1.2593, Val Acc: 0.5169
# Precision: 0.5264, Recall: 0.5169, F1-score: 0.4964
# --------------------------------------------------
# Epoch [34/1500]
# Train Loss: 1.3301, Train Acc: 0.5188
# Val Loss: 1.2693, Val Acc: 0.5364
# Precision: 0.5511, Recall: 0.5364, F1-score: 0.5236
# --------------------------------------------------
# Epoch [35/1500]
# Train Loss: 1.2278, Train Acc: 0.5196
# Val Loss: 1.2662, Val Acc: 0.5169
# Precision: 0.5190, Recall: 0.5169, F1-score: 0.4997
# --------------------------------------------------
# Epoch [36/1500]
# Train Loss: 1.2721, Train Acc: 0.5231
# Val Loss: 1.2186, Val Acc: 0.5453
# Precision: 0.5521, Recall: 0.5453, F1-score: 0.5341
# --------------------------------------------------
# Epoch [37/1500]
# Train Loss: 1.3038, Train Acc: 0.5339
# Val Loss: 1.2221, Val Acc: 0.5151
# Precision: 0.5161, Recall: 0.5151, F1-score: 0.5030
# --------------------------------------------------
# Epoch [38/1500]
# Train Loss: 1.2409, Train Acc: 0.5309
# Val Loss: 1.1876, Val Acc: 0.5222
# Precision: 0.5363, Recall: 0.5222, F1-score: 0.5083
# --------------------------------------------------
# Epoch [39/1500]
# Train Loss: 1.1648, Train Acc: 0.5473
# Val Loss: 1.1781, Val Acc: 0.5382
# Precision: 0.5377, Recall: 0.5382, F1-score: 0.5184
# --------------------------------------------------
# Epoch [40/1500]
# Train Loss: 1.1647, Train Acc: 0.5611
# Val Loss: 1.1792, Val Acc: 0.5631
# Precision: 0.5676, Recall: 0.5631, F1-score: 0.5535
# --------------------------------------------------
# Epoch [41/1500]
# Train Loss: 1.2290, Train Acc: 0.5602
# Val Loss: 1.1762, Val Acc: 0.5417
# Precision: 0.5408, Recall: 0.5417, F1-score: 0.5192
# --------------------------------------------------
# Epoch [42/1500]
# Train Loss: 1.1879, Train Acc: 0.5503
# Val Loss: 1.1728, Val Acc: 0.5382
# Precision: 0.5472, Recall: 0.5382, F1-score: 0.5200
# --------------------------------------------------
# Epoch [43/1500]
# Train Loss: 1.2185, Train Acc: 0.5675
# Val Loss: 1.1576, Val Acc: 0.5506
# Precision: 0.5453, Recall: 0.5506, F1-score: 0.5347
# --------------------------------------------------
# Epoch [44/1500]
# Train Loss: 1.1505, Train Acc: 0.5624
# Val Loss: 1.1366, Val Acc: 0.5577
# Precision: 0.5612, Recall: 0.5577, F1-score: 0.5464
# --------------------------------------------------
# Epoch [45/1500]
# Train Loss: 1.1524, Train Acc: 0.5580
# Val Loss: 1.1182, Val Acc: 0.5826
# Precision: 0.5877, Recall: 0.5826, F1-score: 0.5666
# --------------------------------------------------
# Epoch [46/1500]
# Train Loss: 1.1427, Train Acc: 0.5805
# Val Loss: 1.1546, Val Acc: 0.5382
# Precision: 0.5450, Recall: 0.5382, F1-score: 0.5268
# --------------------------------------------------
# Epoch [47/1500]
# Train Loss: 1.1993, Train Acc: 0.5805
# Val Loss: 1.1202, Val Acc: 0.5719
# Precision: 0.5904, Recall: 0.5719, F1-score: 0.5691
# --------------------------------------------------
# Epoch [48/1500]
# Train Loss: 1.1496, Train Acc: 0.5477
# Val Loss: 1.1165, Val Acc: 0.5844
# Precision: 0.5980, Recall: 0.5844, F1-score: 0.5687
# --------------------------------------------------
# Epoch [49/1500]
# Train Loss: 1.2187, Train Acc: 0.5706
# Val Loss: 1.1299, Val Acc: 0.5684
# Precision: 0.5656, Recall: 0.5684, F1-score: 0.5516
# --------------------------------------------------
# Epoch [50/1500]
# Train Loss: 1.1841, Train Acc: 0.5589
# Val Loss: 1.1240, Val Acc: 0.5826
# Precision: 0.5895, Recall: 0.5826, F1-score: 0.5738
# --------------------------------------------------
# Epoch [51/1500]
# Train Loss: 1.1015, Train Acc: 0.5857
# Val Loss: 1.0974, Val Acc: 0.5808
# Precision: 0.5776, Recall: 0.5808, F1-score: 0.5586
# --------------------------------------------------
# Epoch [52/1500]
# Train Loss: 1.0937, Train Acc: 0.5978
# Val Loss: 1.0777, Val Acc: 0.5915
# Precision: 0.5929, Recall: 0.5915, F1-score: 0.5813
# --------------------------------------------------
# Epoch [53/1500]
# Train Loss: 1.0947, Train Acc: 0.5826
# Val Loss: 1.0790, Val Acc: 0.5879
# Precision: 0.6063, Recall: 0.5879, F1-score: 0.5817
# --------------------------------------------------
# Epoch [54/1500]
# Train Loss: 1.0703, Train Acc: 0.5947
# Val Loss: 1.0615, Val Acc: 0.6004
# Precision: 0.6054, Recall: 0.6004, F1-score: 0.5904
# --------------------------------------------------
# Epoch [55/1500]
# Train Loss: 1.0771, Train Acc: 0.6103
# Val Loss: 1.0596, Val Acc: 0.6181
# Precision: 0.6241, Recall: 0.6181, F1-score: 0.6132
# --------------------------------------------------
# Epoch [56/1500]
# Train Loss: 1.0587, Train Acc: 0.5986
# Val Loss: 1.0474, Val Acc: 0.6075
# Precision: 0.6069, Recall: 0.6075, F1-score: 0.5922
# --------------------------------------------------
# Epoch [57/1500]
# Train Loss: 1.0323, Train Acc: 0.6103
# Val Loss: 1.0141, Val Acc: 0.6270
# Precision: 0.6284, Recall: 0.6270, F1-score: 0.6204
# --------------------------------------------------
# Epoch [58/1500]
# Train Loss: 1.0321, Train Acc: 0.6060
# Val Loss: 1.0884, Val Acc: 0.6039
# Precision: 0.5955, Recall: 0.6039, F1-score: 0.5862
# --------------------------------------------------
# Epoch [59/1500]
# Train Loss: 1.0799, Train Acc: 0.6107
# Val Loss: 1.0225, Val Acc: 0.6146
# Precision: 0.6222, Recall: 0.6146, F1-score: 0.6112
# --------------------------------------------------
# Epoch [60/1500]
# Train Loss: 1.0359, Train Acc: 0.6280
# Val Loss: 1.0181, Val Acc: 0.6128
# Precision: 0.6089, Recall: 0.6128, F1-score: 0.6021
# --------------------------------------------------
# Epoch [61/1500]
# Train Loss: 1.0283, Train Acc: 0.6098
# Val Loss: 1.0852, Val Acc: 0.5790
# Precision: 0.5871, Recall: 0.5790, F1-score: 0.5692
# --------------------------------------------------
# Epoch [62/1500]
# Train Loss: 1.0087, Train Acc: 0.6228
# Val Loss: 1.0146, Val Acc: 0.6306
# Precision: 0.6343, Recall: 0.6306, F1-score: 0.6265
# --------------------------------------------------
# Epoch [63/1500]
# Train Loss: 1.0270, Train Acc: 0.6129
# Val Loss: 0.9924, Val Acc: 0.6483
# Precision: 0.6519, Recall: 0.6483, F1-score: 0.6407
# --------------------------------------------------
# Epoch [64/1500]
# Train Loss: 0.9803, Train Acc: 0.6267
# Val Loss: 0.9661, Val Acc: 0.6590
# Precision: 0.6571, Recall: 0.6590, F1-score: 0.6543
# --------------------------------------------------
# Epoch [65/1500]
# Train Loss: 0.9521, Train Acc: 0.6413
# Val Loss: 0.9753, Val Acc: 0.6394
# Precision: 0.6366, Recall: 0.6394, F1-score: 0.6320
# --------------------------------------------------
# Epoch [66/1500]
# Train Loss: 0.9517, Train Acc: 0.6310
# Val Loss: 1.0738, Val Acc: 0.5808
# Precision: 0.6021, Recall: 0.5808, F1-score: 0.5694
# --------------------------------------------------
# Epoch [67/1500]
# Train Loss: 0.9874, Train Acc: 0.6124
# Val Loss: 1.0303, Val Acc: 0.5950
# Precision: 0.6064, Recall: 0.5950, F1-score: 0.5874
# --------------------------------------------------
# Epoch [68/1500]
# Train Loss: 0.9804, Train Acc: 0.6504
# Val Loss: 0.9537, Val Acc: 0.6448
# Precision: 0.6503, Recall: 0.6448, F1-score: 0.6450
# --------------------------------------------------
# Epoch [69/1500]
# Train Loss: 1.0236, Train Acc: 0.6383
# Val Loss: 0.9801, Val Acc: 0.6234
# Precision: 0.6173, Recall: 0.6234, F1-score: 0.6082
# --------------------------------------------------
# Epoch [70/1500]
# Train Loss: 0.9280, Train Acc: 0.6478
# Val Loss: 0.9322, Val Acc: 0.6590
# Precision: 0.6580, Recall: 0.6590, F1-score: 0.6574
# --------------------------------------------------
# Epoch [71/1500]
# Train Loss: 0.9684, Train Acc: 0.6457
# Val Loss: 0.9252, Val Acc: 0.6661
# Precision: 0.6729, Recall: 0.6661, F1-score: 0.6651
# --------------------------------------------------
# Epoch [72/1500]
# Train Loss: 0.9932, Train Acc: 0.6599
# Val Loss: 0.9346, Val Acc: 0.6607
# Precision: 0.6687, Recall: 0.6607, F1-score: 0.6562
# --------------------------------------------------
# Epoch [73/1500]
# Train Loss: 1.0024, Train Acc: 0.6401
# Val Loss: 0.9153, Val Acc: 0.6625
# Precision: 0.6646, Recall: 0.6625, F1-score: 0.6525
# --------------------------------------------------
# Epoch [74/1500]
# Train Loss: 0.9601, Train Acc: 0.6452
# Val Loss: 0.9126, Val Acc: 0.6590
# Precision: 0.6666, Recall: 0.6590, F1-score: 0.6530
# --------------------------------------------------
# Epoch [75/1500]
# Train Loss: 0.9309, Train Acc: 0.6521
# Val Loss: 0.9239, Val Acc: 0.6519
# Precision: 0.6641, Recall: 0.6519, F1-score: 0.6461
# --------------------------------------------------
# Epoch [76/1500]
# Train Loss: 0.9177, Train Acc: 0.6500
# Val Loss: 0.9011, Val Acc: 0.6696
# Precision: 0.6680, Recall: 0.6696, F1-score: 0.6646
# --------------------------------------------------
# Epoch [77/1500]
# Train Loss: 0.9648, Train Acc: 0.6672
# Val Loss: 0.8842, Val Acc: 0.6732
# Precision: 0.6744, Recall: 0.6732, F1-score: 0.6688
# --------------------------------------------------
# Epoch [78/1500]
# Train Loss: 0.9734, Train Acc: 0.6823
# Val Loss: 0.8659, Val Acc: 0.6874
# Precision: 0.6896, Recall: 0.6874, F1-score: 0.6846
# --------------------------------------------------
# Epoch [79/1500]
# Train Loss: 0.9145, Train Acc: 0.6603
# Val Loss: 0.8617, Val Acc: 0.6821
# Precision: 0.6863, Recall: 0.6821, F1-score: 0.6741
# --------------------------------------------------
# Epoch [80/1500]
# Train Loss: 0.9323, Train Acc: 0.6534
# Val Loss: 0.8745, Val Acc: 0.6785
# Precision: 0.6826, Recall: 0.6785, F1-score: 0.6729
# --------------------------------------------------
# Epoch [81/1500]
# Train Loss: 0.9133, Train Acc: 0.6668
# Val Loss: 0.8816, Val Acc: 0.6838
# Precision: 0.6901, Recall: 0.6838, F1-score: 0.6776
# --------------------------------------------------
# Epoch [82/1500]
# Train Loss: 0.9655, Train Acc: 0.6651
# Val Loss: 0.8657, Val Acc: 0.6963
# Precision: 0.6995, Recall: 0.6963, F1-score: 0.6932
# --------------------------------------------------
# Epoch [83/1500]
# Train Loss: 0.8674, Train Acc: 0.6703
# Val Loss: 0.8805, Val Acc: 0.6838
# Precision: 0.6967, Recall: 0.6838, F1-score: 0.6791
# --------------------------------------------------
# Epoch [84/1500]
# Train Loss: 0.9036, Train Acc: 0.6590
# Val Loss: 0.8314, Val Acc: 0.7158
# Precision: 0.7202, Recall: 0.7158, F1-score: 0.7132
# --------------------------------------------------
# Epoch [85/1500]
# Train Loss: 0.9046, Train Acc: 0.6681
# Val Loss: 0.8515, Val Acc: 0.6945
# Precision: 0.7001, Recall: 0.6945, F1-score: 0.6904
# --------------------------------------------------
# Epoch [86/1500]
# Train Loss: 0.8794, Train Acc: 0.6780
# Val Loss: 0.8901, Val Acc: 0.6892
# Precision: 0.6986, Recall: 0.6892, F1-score: 0.6850
# --------------------------------------------------
# Epoch [87/1500]
# Train Loss: 0.8233, Train Acc: 0.6918
# Val Loss: 0.8592, Val Acc: 0.6714
# Precision: 0.6811, Recall: 0.6714, F1-score: 0.6618
# --------------------------------------------------
# Epoch [88/1500]
# Train Loss: 0.8522, Train Acc: 0.6763
# Val Loss: 0.8334, Val Acc: 0.6874
# Precision: 0.6961, Recall: 0.6874, F1-score: 0.6880
# --------------------------------------------------
# Epoch [89/1500]
# Train Loss: 0.8879, Train Acc: 0.6729
# Val Loss: 0.8639, Val Acc: 0.6696
# Precision: 0.6682, Recall: 0.6696, F1-score: 0.6626
# --------------------------------------------------
# Epoch [90/1500]
# Train Loss: 0.8331, Train Acc: 0.6970
# Val Loss: 0.8261, Val Acc: 0.6963
# Precision: 0.6989, Recall: 0.6963, F1-score: 0.6951
# --------------------------------------------------
# Epoch [91/1500]
# Train Loss: 0.8827, Train Acc: 0.6875
# Val Loss: 0.8394, Val Acc: 0.6892
# Precision: 0.6976, Recall: 0.6892, F1-score: 0.6849
# --------------------------------------------------
# Epoch [92/1500]
# Train Loss: 0.8396, Train Acc: 0.6836
# Val Loss: 0.8094, Val Acc: 0.7158
# Precision: 0.7163, Recall: 0.7158, F1-score: 0.7141
# --------------------------------------------------
# Epoch [93/1500]
# Train Loss: 0.8127, Train Acc: 0.7013
# Val Loss: 0.7999, Val Acc: 0.7069
# Precision: 0.7058, Recall: 0.7069, F1-score: 0.7007
# --------------------------------------------------
# Epoch [94/1500]
# Train Loss: 0.8341, Train Acc: 0.7130
# Val Loss: 0.8072, Val Acc: 0.6909
# Precision: 0.6936, Recall: 0.6909, F1-score: 0.6848
# --------------------------------------------------
# Epoch [95/1500]
# Train Loss: 0.8198, Train Acc: 0.7009
# Val Loss: 0.8186, Val Acc: 0.6821
# Precision: 0.6883, Recall: 0.6821, F1-score: 0.6817
# --------------------------------------------------
# Epoch [96/1500]
# Train Loss: 0.8418, Train Acc: 0.7022
# Val Loss: 0.8053, Val Acc: 0.6927
# Precision: 0.6930, Recall: 0.6927, F1-score: 0.6886
# --------------------------------------------------
# Epoch [97/1500]
# Train Loss: 0.9125, Train Acc: 0.7005
# Val Loss: 0.7982, Val Acc: 0.6874
# Precision: 0.6895, Recall: 0.6874, F1-score: 0.6826
# --------------------------------------------------
# Epoch [98/1500]
# Train Loss: 0.8877, Train Acc: 0.6970
# Val Loss: 0.7963, Val Acc: 0.6838
# Precision: 0.6841, Recall: 0.6838, F1-score: 0.6769
# --------------------------------------------------
# Epoch [99/1500]
# Train Loss: 0.8859, Train Acc: 0.6983
# Val Loss: 0.7752, Val Acc: 0.7229
# Precision: 0.7235, Recall: 0.7229, F1-score: 0.7207
# --------------------------------------------------
# Epoch [100/1500]
# Train Loss: 0.8074, Train Acc: 0.7057
# Val Loss: 0.7649, Val Acc: 0.7265
# Precision: 0.7319, Recall: 0.7265, F1-score: 0.7275
# --------------------------------------------------
# Epoch [101/1500]
# Train Loss: 0.8088, Train Acc: 0.7018
# Val Loss: 0.8583, Val Acc: 0.6803
# Precision: 0.6896, Recall: 0.6803, F1-score: 0.6771
# --------------------------------------------------
# Epoch [102/1500]
# Train Loss: 0.8746, Train Acc: 0.7078
# Val Loss: 0.8330, Val Acc: 0.6998
# Precision: 0.7069, Recall: 0.6998, F1-score: 0.6928
# --------------------------------------------------
# Epoch [103/1500]
# Train Loss: 0.8921, Train Acc: 0.7057
# Val Loss: 0.7901, Val Acc: 0.7016
# Precision: 0.7111, Recall: 0.7016, F1-score: 0.7021
# --------------------------------------------------
# Epoch [104/1500]
# Train Loss: 0.8471, Train Acc: 0.6957
# Val Loss: 0.7899, Val Acc: 0.7087
# Precision: 0.7213, Recall: 0.7087, F1-score: 0.7110
# --------------------------------------------------
# Epoch [105/1500]
# Train Loss: 0.7614, Train Acc: 0.7277
# Val Loss: 0.8074, Val Acc: 0.7016
# Precision: 0.7052, Recall: 0.7016, F1-score: 0.6985
# --------------------------------------------------
# Epoch [106/1500]
# Train Loss: 0.7873, Train Acc: 0.7216
# Val Loss: 0.7644, Val Acc: 0.7140
# Precision: 0.7241, Recall: 0.7140, F1-score: 0.7141
# --------------------------------------------------
# Epoch [107/1500]
# Train Loss: 0.7848, Train Acc: 0.7190
# Val Loss: 0.7597, Val Acc: 0.7140
# Precision: 0.7165, Recall: 0.7140, F1-score: 0.7120
# --------------------------------------------------
# Epoch [108/1500]
# Train Loss: 0.7857, Train Acc: 0.7177
# Val Loss: 0.7437, Val Acc: 0.7389
# Precision: 0.7424, Recall: 0.7389, F1-score: 0.7381
# --------------------------------------------------
# Epoch [109/1500]
# Train Loss: 0.7458, Train Acc: 0.7346
# Val Loss: 0.7499, Val Acc: 0.7265
# Precision: 0.7257, Recall: 0.7265, F1-score: 0.7226
# --------------------------------------------------
# Epoch [110/1500]
# Train Loss: 0.7186, Train Acc: 0.7458
# Val Loss: 0.7419, Val Acc: 0.7087
# Precision: 0.7133, Recall: 0.7087, F1-score: 0.7060
# --------------------------------------------------
# Epoch [111/1500]
# Train Loss: 0.7141, Train Acc: 0.7501
# Val Loss: 0.7710, Val Acc: 0.7087
# Precision: 0.7100, Recall: 0.7087, F1-score: 0.7024
# --------------------------------------------------
# Epoch [112/1500]
# Train Loss: 0.7621, Train Acc: 0.7164
# Val Loss: 0.7400, Val Acc: 0.7442
# Precision: 0.7601, Recall: 0.7442, F1-score: 0.7463
# --------------------------------------------------
# Epoch [113/1500]
# Train Loss: 0.7197, Train Acc: 0.7346
# Val Loss: 0.6958, Val Acc: 0.7425
# Precision: 0.7461, Recall: 0.7425, F1-score: 0.7395
# --------------------------------------------------
# Epoch [114/1500]
# Train Loss: 0.7013, Train Acc: 0.7346
# Val Loss: 0.7344, Val Acc: 0.7336
# Precision: 0.7343, Recall: 0.7336, F1-score: 0.7285
# --------------------------------------------------
# Epoch [115/1500]
# Train Loss: 0.6902, Train Acc: 0.7402
# Val Loss: 0.7131, Val Acc: 0.7229
# Precision: 0.7279, Recall: 0.7229, F1-score: 0.7215
# --------------------------------------------------
# Epoch [116/1500]
# Train Loss: 0.6724, Train Acc: 0.7544
# Val Loss: 0.6840, Val Acc: 0.7478
# Precision: 0.7504, Recall: 0.7478, F1-score: 0.7473
# --------------------------------------------------
# Epoch [117/1500]
# Train Loss: 0.7030, Train Acc: 0.7497
# Val Loss: 0.6816, Val Acc: 0.7425
# Precision: 0.7458, Recall: 0.7425, F1-score: 0.7413
# --------------------------------------------------
# Epoch [118/1500]
# Train Loss: 0.7188, Train Acc: 0.7544
# Val Loss: 0.7077, Val Acc: 0.7513
# Precision: 0.7557, Recall: 0.7513, F1-score: 0.7496
# --------------------------------------------------
# Epoch [119/1500]
# Train Loss: 0.7123, Train Acc: 0.7501
# Val Loss: 0.7608, Val Acc: 0.7265
# Precision: 0.7394, Recall: 0.7265, F1-score: 0.7249
# --------------------------------------------------
# Epoch [120/1500]
# Train Loss: 0.7449, Train Acc: 0.7415
# Val Loss: 0.7054, Val Acc: 0.7407
# Precision: 0.7530, Recall: 0.7407, F1-score: 0.7419
# --------------------------------------------------
# Epoch [121/1500]
# Train Loss: 0.7199, Train Acc: 0.7372
# Val Loss: 0.7168, Val Acc: 0.7496
# Precision: 0.7504, Recall: 0.7496, F1-score: 0.7457
# --------------------------------------------------
# Epoch [122/1500]
# Train Loss: 0.6824, Train Acc: 0.7445
# Val Loss: 0.6880, Val Acc: 0.7584
# Precision: 0.7658, Recall: 0.7584, F1-score: 0.7572
# --------------------------------------------------
# Epoch [123/1500]
# Train Loss: 0.7485, Train Acc: 0.7596
# Val Loss: 0.6768, Val Acc: 0.7602
# Precision: 0.7642, Recall: 0.7602, F1-score: 0.7599
# --------------------------------------------------
# Epoch [124/1500]
# Train Loss: 0.7061, Train Acc: 0.7501
# Val Loss: 0.6890, Val Acc: 0.7744
# Precision: 0.7842, Recall: 0.7744, F1-score: 0.7741
# --------------------------------------------------
# Epoch [125/1500]
# Train Loss: 0.6716, Train Acc: 0.7441
# Val Loss: 0.6837, Val Acc: 0.7442
# Precision: 0.7481, Recall: 0.7442, F1-score: 0.7426
# --------------------------------------------------
# Epoch [126/1500]
# Train Loss: 0.6513, Train Acc: 0.7639
# Val Loss: 0.6571, Val Acc: 0.7620
# Precision: 0.7641, Recall: 0.7620, F1-score: 0.7615
# --------------------------------------------------
# Epoch [127/1500]
# Train Loss: 0.6583, Train Acc: 0.7505
# Val Loss: 0.6639, Val Acc: 0.7673
# Precision: 0.7702, Recall: 0.7673, F1-score: 0.7664
# --------------------------------------------------
# Epoch [128/1500]
# Train Loss: 0.6367, Train Acc: 0.7626
# Val Loss: 0.6625, Val Acc: 0.7442
# Precision: 0.7479, Recall: 0.7442, F1-score: 0.7431
# --------------------------------------------------
# Epoch [129/1500]
# Train Loss: 0.6519, Train Acc: 0.7730
# Val Loss: 0.6413, Val Acc: 0.7513
# Precision: 0.7600, Recall: 0.7513, F1-score: 0.7517
# --------------------------------------------------
# Epoch [130/1500]
# Train Loss: 0.6357, Train Acc: 0.7682
# Val Loss: 0.6975, Val Acc: 0.7425
# Precision: 0.7442, Recall: 0.7425, F1-score: 0.7376
# --------------------------------------------------
# Epoch [131/1500]
# Train Loss: 0.6498, Train Acc: 0.7600
# Val Loss: 0.6655, Val Acc: 0.7513
# Precision: 0.7645, Recall: 0.7513, F1-score: 0.7512
# --------------------------------------------------
# Epoch [132/1500]
# Train Loss: 0.6840, Train Acc: 0.7661
# Val Loss: 0.6734, Val Acc: 0.7531
# Precision: 0.7599, Recall: 0.7531, F1-score: 0.7508
# --------------------------------------------------
# Epoch [133/1500]
# Train Loss: 0.6391, Train Acc: 0.7605
# Val Loss: 0.6224, Val Acc: 0.7726
# Precision: 0.7798, Recall: 0.7726, F1-score: 0.7717
# --------------------------------------------------
# Epoch [134/1500]
# Train Loss: 0.6918, Train Acc: 0.7484
# Val Loss: 0.6141, Val Acc: 0.7673
# Precision: 0.7708, Recall: 0.7673, F1-score: 0.7663
# --------------------------------------------------
# Epoch [135/1500]
# Train Loss: 0.6584, Train Acc: 0.7661
# Val Loss: 0.6990, Val Acc: 0.7407
# Precision: 0.7480, Recall: 0.7407, F1-score: 0.7371
# --------------------------------------------------
# Epoch [136/1500]
# Train Loss: 0.6594, Train Acc: 0.7687
# Val Loss: 0.6428, Val Acc: 0.7726
# Precision: 0.7783, Recall: 0.7726, F1-score: 0.7721
# --------------------------------------------------
# Epoch [137/1500]
# Train Loss: 0.6302, Train Acc: 0.7669
# Val Loss: 0.6408, Val Acc: 0.7620
# Precision: 0.7670, Recall: 0.7620, F1-score: 0.7583
# --------------------------------------------------
# Epoch [138/1500]
# Train Loss: 0.6425, Train Acc: 0.7713
# Val Loss: 0.6057, Val Acc: 0.7815
# Precision: 0.7880, Recall: 0.7815, F1-score: 0.7816
# --------------------------------------------------
# Epoch [139/1500]
# Train Loss: 0.5962, Train Acc: 0.7678
# Val Loss: 0.6042, Val Acc: 0.7815
# Precision: 0.7867, Recall: 0.7815, F1-score: 0.7813
# --------------------------------------------------
# Epoch [140/1500]
# Train Loss: 0.6722, Train Acc: 0.7687
# Val Loss: 0.6103, Val Acc: 0.7869
# Precision: 0.7925, Recall: 0.7869, F1-score: 0.7859
# --------------------------------------------------
# Epoch [141/1500]
# Train Loss: 0.6456, Train Acc: 0.7756
# Val Loss: 0.6348, Val Acc: 0.7726
# Precision: 0.7793, Recall: 0.7726, F1-score: 0.7727
# --------------------------------------------------
# Epoch [142/1500]
# Train Loss: 0.6271, Train Acc: 0.7700
# Val Loss: 0.6330, Val Acc: 0.7567
# Precision: 0.7668, Recall: 0.7567, F1-score: 0.7557
# --------------------------------------------------
# Epoch [143/1500]
# Train Loss: 0.6162, Train Acc: 0.7726
# Val Loss: 0.6186, Val Acc: 0.7638
# Precision: 0.7675, Recall: 0.7638, F1-score: 0.7611
# --------------------------------------------------
# Epoch [144/1500]
# Train Loss: 0.6899, Train Acc: 0.7795
# Val Loss: 0.6046, Val Acc: 0.7886
# Precision: 0.7991, Recall: 0.7886, F1-score: 0.7888
# --------------------------------------------------
# Epoch [145/1500]
# Train Loss: 0.6760, Train Acc: 0.7587
# Val Loss: 0.6419, Val Acc: 0.7638
# Precision: 0.7794, Recall: 0.7638, F1-score: 0.7643
# --------------------------------------------------
# Epoch [146/1500]
# Train Loss: 0.7516, Train Acc: 0.7734
# Val Loss: 0.6437, Val Acc: 0.7460
# Precision: 0.7473, Recall: 0.7460, F1-score: 0.7434
# --------------------------------------------------
# Epoch [147/1500]
# Train Loss: 0.6326, Train Acc: 0.7583
# Val Loss: 0.6470, Val Acc: 0.7638
# Precision: 0.7690, Recall: 0.7638, F1-score: 0.7623
# --------------------------------------------------
# Epoch [148/1500]
# Train Loss: 0.6189, Train Acc: 0.7730
# Val Loss: 0.6452, Val Acc: 0.7549
# Precision: 0.7628, Recall: 0.7549, F1-score: 0.7545
# --------------------------------------------------
# Epoch [149/1500]
# Train Loss: 0.6282, Train Acc: 0.7808
# Val Loss: 0.6128, Val Acc: 0.7673
# Precision: 0.7733, Recall: 0.7673, F1-score: 0.7657
# --------------------------------------------------
# Epoch [150/1500]
# Train Loss: 0.5867, Train Acc: 0.7769
# Val Loss: 0.5846, Val Acc: 0.7957
# Precision: 0.8040, Recall: 0.7957, F1-score: 0.7967
# --------------------------------------------------
# Epoch [151/1500]
# Train Loss: 0.6309, Train Acc: 0.7911
# Val Loss: 0.6332, Val Acc: 0.7567
# Precision: 0.7680, Recall: 0.7567, F1-score: 0.7567
# --------------------------------------------------
# Epoch [152/1500]
# Train Loss: 0.5590, Train Acc: 0.7838
# Val Loss: 0.6398, Val Acc: 0.7620
# Precision: 0.7811, Recall: 0.7620, F1-score: 0.7631
# --------------------------------------------------
# Epoch [153/1500]
# Train Loss: 0.5459, Train Acc: 0.8049
# Val Loss: 0.5935, Val Acc: 0.7780
# Precision: 0.7803, Recall: 0.7780, F1-score: 0.7767
# --------------------------------------------------
# Epoch [154/1500]
# Train Loss: 0.5528, Train Acc: 0.7920
# Val Loss: 0.5824, Val Acc: 0.7869
# Precision: 0.7920, Recall: 0.7869, F1-score: 0.7868
# --------------------------------------------------
# Epoch [155/1500]
# Train Loss: 0.5480, Train Acc: 0.8161
# Val Loss: 0.5853, Val Acc: 0.7691
# Precision: 0.7793, Recall: 0.7691, F1-score: 0.7689
# --------------------------------------------------
# Epoch [156/1500]
# Train Loss: 0.6268, Train Acc: 0.7907
# Val Loss: 0.5596, Val Acc: 0.7851
# Precision: 0.7869, Recall: 0.7851, F1-score: 0.7840
# --------------------------------------------------
# Epoch [157/1500]
# Train Loss: 0.5792, Train Acc: 0.7898
# Val Loss: 0.5589, Val Acc: 0.7975
# Precision: 0.7973, Recall: 0.7975, F1-score: 0.7965
# --------------------------------------------------
# Epoch [158/1500]
# Train Loss: 0.5726, Train Acc: 0.7915
# Val Loss: 0.5952, Val Acc: 0.7851
# Precision: 0.7930, Recall: 0.7851, F1-score: 0.7849
# --------------------------------------------------
# Epoch [159/1500]
# Train Loss: 0.5688, Train Acc: 0.7989
# Val Loss: 0.5910, Val Acc: 0.7886
# Precision: 0.7983, Recall: 0.7886, F1-score: 0.7885
# --------------------------------------------------
# Epoch [160/1500]
# Train Loss: 0.5373, Train Acc: 0.8054
# Val Loss: 0.5858, Val Acc: 0.7869
# Precision: 0.7932, Recall: 0.7869, F1-score: 0.7854
# --------------------------------------------------
# Epoch [161/1500]
# Train Loss: 0.5352, Train Acc: 0.8114
# Val Loss: 0.5522, Val Acc: 0.8082
# Precision: 0.8119, Recall: 0.8082, F1-score: 0.8072
# --------------------------------------------------
# Epoch [162/1500]
# Train Loss: 0.5496, Train Acc: 0.8002
# Val Loss: 0.5595, Val Acc: 0.7851
# Precision: 0.7889, Recall: 0.7851, F1-score: 0.7842
# --------------------------------------------------
# Epoch [163/1500]
# Train Loss: 0.5866, Train Acc: 0.8105
# Val Loss: 0.5661, Val Acc: 0.7993
# Precision: 0.8072, Recall: 0.7993, F1-score: 0.7978
# --------------------------------------------------
# Epoch [164/1500]
# Train Loss: 0.5129, Train Acc: 0.8041
# Val Loss: 0.5365, Val Acc: 0.8135
# Precision: 0.8200, Recall: 0.8135, F1-score: 0.8129
# --------------------------------------------------
# Epoch [165/1500]
# Train Loss: 0.5159, Train Acc: 0.8187
# Val Loss: 0.5397, Val Acc: 0.8082
# Precision: 0.8097, Recall: 0.8082, F1-score: 0.8071
# --------------------------------------------------
# Epoch [166/1500]
# Train Loss: 0.4959, Train Acc: 0.8127
# Val Loss: 0.5418, Val Acc: 0.7993
# Precision: 0.8031, Recall: 0.7993, F1-score: 0.7979
# --------------------------------------------------
# Epoch [167/1500]
# Train Loss: 0.5481, Train Acc: 0.8200
# Val Loss: 0.5350, Val Acc: 0.8028
# Precision: 0.8107, Recall: 0.8028, F1-score: 0.8022
# --------------------------------------------------
# Epoch [168/1500]
# Train Loss: 0.5466, Train Acc: 0.8045
# Val Loss: 0.5448, Val Acc: 0.7869
# Precision: 0.7983, Recall: 0.7869, F1-score: 0.7876
# --------------------------------------------------
# Epoch [169/1500]
# Train Loss: 0.5431, Train Acc: 0.7959
# Val Loss: 0.5358, Val Acc: 0.8028
# Precision: 0.8059, Recall: 0.8028, F1-score: 0.8017
# --------------------------------------------------
# Epoch [170/1500]
# Train Loss: 0.5214, Train Acc: 0.8205
# Val Loss: 0.5205, Val Acc: 0.8028
# Precision: 0.8066, Recall: 0.8028, F1-score: 0.8030
# --------------------------------------------------
# Epoch [171/1500]
# Train Loss: 0.4882, Train Acc: 0.8127
# Val Loss: 0.5618, Val Acc: 0.7922
# Precision: 0.8013, Recall: 0.7922, F1-score: 0.7914
# --------------------------------------------------
# Epoch [172/1500]
# Train Loss: 0.5358, Train Acc: 0.8196
# Val Loss: 0.5323, Val Acc: 0.7957
# Precision: 0.7999, Recall: 0.7957, F1-score: 0.7945
# --------------------------------------------------
# Epoch [173/1500]
# Train Loss: 0.5190, Train Acc: 0.8265
# Val Loss: 0.5357, Val Acc: 0.7975
# Precision: 0.8058, Recall: 0.7975, F1-score: 0.7972
# --------------------------------------------------
# Epoch [174/1500]
# Train Loss: 0.5071, Train Acc: 0.8243
# Val Loss: 0.5909, Val Acc: 0.7833
# Precision: 0.7951, Recall: 0.7833, F1-score: 0.7831
# --------------------------------------------------
# Epoch [175/1500]
# Train Loss: 0.5413, Train Acc: 0.7989
# Val Loss: 0.5451, Val Acc: 0.8117
# Precision: 0.8210, Recall: 0.8117, F1-score: 0.8119
# --------------------------------------------------
# Epoch [176/1500]
# Train Loss: 0.4884, Train Acc: 0.8187
# Val Loss: 0.4983, Val Acc: 0.8171
# Precision: 0.8200, Recall: 0.8171, F1-score: 0.8168
# --------------------------------------------------
# Epoch [177/1500]
# Train Loss: 0.5262, Train Acc: 0.8295
# Val Loss: 0.5133, Val Acc: 0.8011
# Precision: 0.8061, Recall: 0.8011, F1-score: 0.7999
# --------------------------------------------------
# Epoch [178/1500]
# Train Loss: 0.5822, Train Acc: 0.8118
# Val Loss: 0.5208, Val Acc: 0.8011
# Precision: 0.8125, Recall: 0.8011, F1-score: 0.8021
# --------------------------------------------------
# Epoch [179/1500]
# Train Loss: 0.5773, Train Acc: 0.8002
# Val Loss: 0.5354, Val Acc: 0.7940
# Precision: 0.8009, Recall: 0.7940, F1-score: 0.7912
# --------------------------------------------------
# Epoch [180/1500]
# Train Loss: 0.5460, Train Acc: 0.8015
# Val Loss: 0.5416, Val Acc: 0.7922
# Precision: 0.8052, Recall: 0.7922, F1-score: 0.7924
# --------------------------------------------------
# Epoch [181/1500]
# Train Loss: 0.5212, Train Acc: 0.8157
# Val Loss: 0.4917, Val Acc: 0.8224
# Precision: 0.8258, Recall: 0.8224, F1-score: 0.8218
# --------------------------------------------------
# Epoch [182/1500]
# Train Loss: 0.5278, Train Acc: 0.8144
# Val Loss: 0.5131, Val Acc: 0.8028
# Precision: 0.8100, Recall: 0.8028, F1-score: 0.8027
# --------------------------------------------------
# Epoch [183/1500]
# Train Loss: 0.5043, Train Acc: 0.8205
# Val Loss: 0.5108, Val Acc: 0.8046
# Precision: 0.8180, Recall: 0.8046, F1-score: 0.8049
# --------------------------------------------------
# Epoch [184/1500]
# Train Loss: 0.4742, Train Acc: 0.8282
# Val Loss: 0.5083, Val Acc: 0.8188
# Precision: 0.8250, Recall: 0.8188, F1-score: 0.8185
# --------------------------------------------------
# Epoch [185/1500]
# Train Loss: 0.4981, Train Acc: 0.8136
# Val Loss: 0.4882, Val Acc: 0.8064
# Precision: 0.8142, Recall: 0.8064, F1-score: 0.8064
# --------------------------------------------------
# Epoch [186/1500]
# Train Loss: 0.4910, Train Acc: 0.8213
# Val Loss: 0.5017, Val Acc: 0.8064
# Precision: 0.8141, Recall: 0.8064, F1-score: 0.8064
# --------------------------------------------------
# Epoch [187/1500]
# Train Loss: 0.4572, Train Acc: 0.8252
# Val Loss: 0.4952, Val Acc: 0.8188
# Precision: 0.8263, Recall: 0.8188, F1-score: 0.8190
# --------------------------------------------------
# Epoch [188/1500]
# Train Loss: 0.4676, Train Acc: 0.8295
# Val Loss: 0.4868, Val Acc: 0.8171
# Precision: 0.8208, Recall: 0.8171, F1-score: 0.8167
# --------------------------------------------------
# Epoch [189/1500]
# Train Loss: 0.4847, Train Acc: 0.8382
# Val Loss: 0.4986, Val Acc: 0.8171
# Precision: 0.8240, Recall: 0.8171, F1-score: 0.8170
# --------------------------------------------------
# Epoch [190/1500]
# Train Loss: 0.4680, Train Acc: 0.8148
# Val Loss: 0.5157, Val Acc: 0.7957
# Precision: 0.8119, Recall: 0.7957, F1-score: 0.7969
# --------------------------------------------------
# Epoch [191/1500]
# Train Loss: 0.4345, Train Acc: 0.8356
# Val Loss: 0.4528, Val Acc: 0.8348
# Precision: 0.8381, Recall: 0.8348, F1-score: 0.8345
# --------------------------------------------------
# Epoch [192/1500]
# Train Loss: 0.4569, Train Acc: 0.8459
# Val Loss: 0.4606, Val Acc: 0.8313
# Precision: 0.8364, Recall: 0.8313, F1-score: 0.8309
# --------------------------------------------------
# Epoch [193/1500]
# Train Loss: 0.4534, Train Acc: 0.8433
# Val Loss: 0.4791, Val Acc: 0.8242
# Precision: 0.8305, Recall: 0.8242, F1-score: 0.8236
# --------------------------------------------------
# Epoch [194/1500]
# Train Loss: 0.4298, Train Acc: 0.8528
# Val Loss: 0.4509, Val Acc: 0.8366
# Precision: 0.8422, Recall: 0.8366, F1-score: 0.8364
# --------------------------------------------------
# Epoch [195/1500]
# Train Loss: 0.4452, Train Acc: 0.8403
# Val Loss: 0.4724, Val Acc: 0.8242
# Precision: 0.8304, Recall: 0.8242, F1-score: 0.8237
# --------------------------------------------------
# Epoch [196/1500]
# Train Loss: 0.4686, Train Acc: 0.8282
# Val Loss: 0.4578, Val Acc: 0.8313
# Precision: 0.8378, Recall: 0.8313, F1-score: 0.8312
# --------------------------------------------------
# Epoch [197/1500]
# Train Loss: 0.4384, Train Acc: 0.8369
# Val Loss: 0.4580, Val Acc: 0.8401
# Precision: 0.8469, Recall: 0.8401, F1-score: 0.8399
# --------------------------------------------------
# Epoch [198/1500]
# Train Loss: 0.4054, Train Acc: 0.8476
# Val Loss: 0.4423, Val Acc: 0.8366
# Precision: 0.8444, Recall: 0.8366, F1-score: 0.8362
# --------------------------------------------------
# Epoch [199/1500]
# Train Loss: 0.4301, Train Acc: 0.8498
# Val Loss: 0.4221, Val Acc: 0.8437
# Precision: 0.8493, Recall: 0.8437, F1-score: 0.8437
# --------------------------------------------------
# Epoch [200/1500]
# Train Loss: 0.4396, Train Acc: 0.8558
# Val Loss: 0.4378, Val Acc: 0.8313
# Precision: 0.8373, Recall: 0.8313, F1-score: 0.8307
# --------------------------------------------------
# Epoch [201/1500]
# Train Loss: 0.4397, Train Acc: 0.8451
# Val Loss: 0.4786, Val Acc: 0.8135
# Precision: 0.8273, Recall: 0.8135, F1-score: 0.8141
# --------------------------------------------------
# Epoch [202/1500]
# Train Loss: 0.4303, Train Acc: 0.8287
# Val Loss: 0.4630, Val Acc: 0.8171
# Precision: 0.8205, Recall: 0.8171, F1-score: 0.8162
# --------------------------------------------------
# Epoch [203/1500]
# Train Loss: 0.3873, Train Acc: 0.8502
# Val Loss: 0.4496, Val Acc: 0.8366
# Precision: 0.8416, Recall: 0.8366, F1-score: 0.8366
# --------------------------------------------------
# Epoch [204/1500]
# Train Loss: 0.4349, Train Acc: 0.8481
# Val Loss: 0.4415, Val Acc: 0.8401
# Precision: 0.8461, Recall: 0.8401, F1-score: 0.8400
# --------------------------------------------------
# Epoch [205/1500]
# Train Loss: 0.4421, Train Acc: 0.8442
# Val Loss: 0.4749, Val Acc: 0.8295
# Precision: 0.8356, Recall: 0.8295, F1-score: 0.8289
# --------------------------------------------------
# Epoch [206/1500]
# Train Loss: 0.4028, Train Acc: 0.8438
# Val Loss: 0.4453, Val Acc: 0.8242
# Precision: 0.8317, Recall: 0.8242, F1-score: 0.8243
# --------------------------------------------------
# Epoch [207/1500]
# Train Loss: 0.4626, Train Acc: 0.8476
# Val Loss: 0.4358, Val Acc: 0.8437
# Precision: 0.8502, Recall: 0.8437, F1-score: 0.8439
# --------------------------------------------------
# Epoch [208/1500]
# Train Loss: 0.4786, Train Acc: 0.8338
# Val Loss: 0.4500, Val Acc: 0.8419
# Precision: 0.8460, Recall: 0.8419, F1-score: 0.8415
# --------------------------------------------------
# Epoch [209/1500]
# Train Loss: 0.4595, Train Acc: 0.8541
# Val Loss: 0.4582, Val Acc: 0.8313
# Precision: 0.8409, Recall: 0.8313, F1-score: 0.8323
# --------------------------------------------------
# Epoch [210/1500]
# Train Loss: 0.4766, Train Acc: 0.8386
# Val Loss: 0.4877, Val Acc: 0.8188
# Precision: 0.8262, Recall: 0.8188, F1-score: 0.8184
# --------------------------------------------------
# Epoch [211/1500]
# Train Loss: 0.4547, Train Acc: 0.8399
# Val Loss: 0.4871, Val Acc: 0.7993
# Precision: 0.8072, Recall: 0.7993, F1-score: 0.7981
# --------------------------------------------------
# Epoch [212/1500]
# Train Loss: 0.4330, Train Acc: 0.8356
# Val Loss: 0.4538, Val Acc: 0.8277
# Precision: 0.8373, Recall: 0.8277, F1-score: 0.8277
# --------------------------------------------------
# Epoch [213/1500]
# Train Loss: 0.4472, Train Acc: 0.8558
# Val Loss: 0.4422, Val Acc: 0.8295
# Precision: 0.8359, Recall: 0.8295, F1-score: 0.8299
# --------------------------------------------------
# Epoch [214/1500]
# Train Loss: 0.4289, Train Acc: 0.8364
# Val Loss: 0.4564, Val Acc: 0.8295
# Precision: 0.8334, Recall: 0.8295, F1-score: 0.8290
# --------------------------------------------------
# Epoch [215/1500]
# Train Loss: 0.4245, Train Acc: 0.8571
# Val Loss: 0.4384, Val Acc: 0.8437
# Precision: 0.8511, Recall: 0.8437, F1-score: 0.8442
# --------------------------------------------------
# Epoch [216/1500]
# Train Loss: 0.4724, Train Acc: 0.8451
# Val Loss: 0.5009, Val Acc: 0.8242
# Precision: 0.8351, Recall: 0.8242, F1-score: 0.8244
# --------------------------------------------------
# Epoch [217/1500]
# Train Loss: 0.4421, Train Acc: 0.8330
# Val Loss: 0.4857, Val Acc: 0.8277
# Precision: 0.8318, Recall: 0.8277, F1-score: 0.8261
# --------------------------------------------------
# Epoch [218/1500]
# Train Loss: 0.4386, Train Acc: 0.8511
# Val Loss: 0.4587, Val Acc: 0.8401
# Precision: 0.8488, Recall: 0.8401, F1-score: 0.8408
# --------------------------------------------------
# Epoch [219/1500]
# Train Loss: 0.4342, Train Acc: 0.8511
# Val Loss: 0.4415, Val Acc: 0.8313
# Precision: 0.8358, Recall: 0.8313, F1-score: 0.8289
# --------------------------------------------------
# Epoch [220/1500]
# Train Loss: 0.4536, Train Acc: 0.8446
# Val Loss: 0.4231, Val Acc: 0.8437
# Precision: 0.8516, Recall: 0.8437, F1-score: 0.8440
# --------------------------------------------------
# Epoch [221/1500]
# Train Loss: 0.3907, Train Acc: 0.8597
# Val Loss: 0.4176, Val Acc: 0.8490
# Precision: 0.8555, Recall: 0.8490, F1-score: 0.8492
# --------------------------------------------------
# Epoch [222/1500]
# Train Loss: 0.3795, Train Acc: 0.8558
# Val Loss: 0.4138, Val Acc: 0.8401
# Precision: 0.8482, Recall: 0.8401, F1-score: 0.8406
# --------------------------------------------------
# Epoch [223/1500]
# Train Loss: 0.3856, Train Acc: 0.8619
# Val Loss: 0.4305, Val Acc: 0.8472
# Precision: 0.8570, Recall: 0.8472, F1-score: 0.8481
# --------------------------------------------------
# Epoch [224/1500]
# Train Loss: 0.3808, Train Acc: 0.8705
# Val Loss: 0.4069, Val Acc: 0.8561
# Precision: 0.8612, Recall: 0.8561, F1-score: 0.8560
# --------------------------------------------------
# Epoch [225/1500]
# Train Loss: 0.4133, Train Acc: 0.8649
# Val Loss: 0.4420, Val Acc: 0.8366
# Precision: 0.8411, Recall: 0.8366, F1-score: 0.8365
# --------------------------------------------------
# Epoch [226/1500]
# Train Loss: 0.4074, Train Acc: 0.8528
# Val Loss: 0.4844, Val Acc: 0.8242
# Precision: 0.8280, Recall: 0.8242, F1-score: 0.8231
# --------------------------------------------------
# Epoch [227/1500]
# Train Loss: 0.4582, Train Acc: 0.8558
# Val Loss: 0.4655, Val Acc: 0.8313
# Precision: 0.8328, Recall: 0.8313, F1-score: 0.8313
# --------------------------------------------------
# Epoch [228/1500]
# Train Loss: 0.4294, Train Acc: 0.8416
# Val Loss: 0.4862, Val Acc: 0.8242
# Precision: 0.8296, Recall: 0.8242, F1-score: 0.8223
# --------------------------------------------------
# Epoch [229/1500]
# Train Loss: 0.4247, Train Acc: 0.8429
# Val Loss: 0.4094, Val Acc: 0.8437
# Precision: 0.8502, Recall: 0.8437, F1-score: 0.8441
# --------------------------------------------------
# Epoch [230/1500]
# Train Loss: 0.4237, Train Acc: 0.8537
# Val Loss: 0.4202, Val Acc: 0.8313
# Precision: 0.8406, Recall: 0.8313, F1-score: 0.8313
# --------------------------------------------------
# Epoch [231/1500]
# Train Loss: 0.4000, Train Acc: 0.8597
# Val Loss: 0.4391, Val Acc: 0.8348
# Precision: 0.8465, Recall: 0.8348, F1-score: 0.8357
# --------------------------------------------------
# Epoch [232/1500]
# Train Loss: 0.4087, Train Acc: 0.8610
# Val Loss: 0.4103, Val Acc: 0.8455
# Precision: 0.8534, Recall: 0.8455, F1-score: 0.8454
# --------------------------------------------------
# Epoch [233/1500]
# Train Loss: 0.4497, Train Acc: 0.8597
# Val Loss: 0.4183, Val Acc: 0.8419
# Precision: 0.8513, Recall: 0.8419, F1-score: 0.8423
# --------------------------------------------------
# Epoch [234/1500]
# Train Loss: 0.4311, Train Acc: 0.8615
# Val Loss: 0.4170, Val Acc: 0.8508
# Precision: 0.8618, Recall: 0.8508, F1-score: 0.8517
# --------------------------------------------------
# Epoch [235/1500]
# Train Loss: 0.4522, Train Acc: 0.8537
# Val Loss: 0.4475, Val Acc: 0.8384
# Precision: 0.8482, Recall: 0.8384, F1-score: 0.8392
# --------------------------------------------------
# Epoch [236/1500]
# Train Loss: 0.4125, Train Acc: 0.8640
# Val Loss: 0.4219, Val Acc: 0.8615
# Precision: 0.8669, Recall: 0.8615, F1-score: 0.8623
# --------------------------------------------------
# Epoch [237/1500]
# Train Loss: 0.3798, Train Acc: 0.8554
# Val Loss: 0.3967, Val Acc: 0.8579
# Precision: 0.8615, Recall: 0.8579, F1-score: 0.8575
# --------------------------------------------------
# Epoch [238/1500]
# Train Loss: 0.3714, Train Acc: 0.8580
# Val Loss: 0.3771, Val Acc: 0.8632
# Precision: 0.8666, Recall: 0.8632, F1-score: 0.8634
# --------------------------------------------------
# Epoch [239/1500]
# Train Loss: 0.3455, Train Acc: 0.8779
# Val Loss: 0.3761, Val Acc: 0.8508
# Precision: 0.8598, Recall: 0.8508, F1-score: 0.8518
# --------------------------------------------------
# Epoch [240/1500]
# Train Loss: 0.4318, Train Acc: 0.8705
# Val Loss: 0.3889, Val Acc: 0.8650
# Precision: 0.8727, Recall: 0.8650, F1-score: 0.8653
# --------------------------------------------------
# Epoch [241/1500]
# Train Loss: 0.4278, Train Acc: 0.8615
# Val Loss: 0.4010, Val Acc: 0.8597
# Precision: 0.8666, Recall: 0.8597, F1-score: 0.8599
# --------------------------------------------------
# Epoch [242/1500]
# Train Loss: 0.4483, Train Acc: 0.8606
# Val Loss: 0.4499, Val Acc: 0.8419
# Precision: 0.8500, Recall: 0.8419, F1-score: 0.8425
# --------------------------------------------------
# Epoch [243/1500]
# Train Loss: 0.4156, Train Acc: 0.8580
# Val Loss: 0.4094, Val Acc: 0.8561
# Precision: 0.8599, Recall: 0.8561, F1-score: 0.8562
# --------------------------------------------------
# Epoch [244/1500]
# Train Loss: 0.4122, Train Acc: 0.8645
# Val Loss: 0.4151, Val Acc: 0.8561
# Precision: 0.8612, Recall: 0.8561, F1-score: 0.8562
# --------------------------------------------------
# Epoch [245/1500]
# Train Loss: 0.3595, Train Acc: 0.8636
# Val Loss: 0.4020, Val Acc: 0.8544
# Precision: 0.8621, Recall: 0.8544, F1-score: 0.8551
# --------------------------------------------------
# Epoch [246/1500]
# Train Loss: 0.3664, Train Acc: 0.8753
# Val Loss: 0.4068, Val Acc: 0.8561
# Precision: 0.8603, Recall: 0.8561, F1-score: 0.8559
# --------------------------------------------------
# Epoch [247/1500]
# Train Loss: 0.3383, Train Acc: 0.8800
# Val Loss: 0.3936, Val Acc: 0.8544
# Precision: 0.8592, Recall: 0.8544, F1-score: 0.8546
# --------------------------------------------------
# Epoch [248/1500]
# Train Loss: 0.3398, Train Acc: 0.8813
# Val Loss: 0.3847, Val Acc: 0.8632
# Precision: 0.8691, Recall: 0.8632, F1-score: 0.8637
# --------------------------------------------------
# Epoch [249/1500]
# Train Loss: 0.3255, Train Acc: 0.8917
# Val Loss: 0.3806, Val Acc: 0.8632
# Precision: 0.8662, Recall: 0.8632, F1-score: 0.8630
# --------------------------------------------------
# Epoch [250/1500]
# Train Loss: 0.4110, Train Acc: 0.8688
# Val Loss: 0.3723, Val Acc: 0.8668
# Precision: 0.8686, Recall: 0.8668, F1-score: 0.8668
# --------------------------------------------------
# Epoch [251/1500]
# Train Loss: 0.3592, Train Acc: 0.8753
# Val Loss: 0.4088, Val Acc: 0.8544
# ...
# Val Loss: 0.2805, Val Acc: 0.9272
# Precision: 0.9289, Recall: 0.9272, F1-score: 0.9271
# --------------------------------------------------
# Epoch [1419/1500]
# Train Loss: 0.0638, Train Acc: 0.9776
# Val Loss: 0.2726, Val Acc: 0.9307
# Precision: 0.9325, Recall: 0.9307, F1-score: 0.9307
# --------------------------------------------------
# Epoch [1420/1500]
# Train Loss: 0.0708, Train Acc: 0.9745
# Val Loss: 0.2741, Val Acc: 0.9378
# Precision: 0.9389, Recall: 0.9378, F1-score: 0.9376
# --------------------------------------------------
# Epoch [1421/1500]
# Train Loss: 0.0731, Train Acc: 0.9806
# Val Loss: 0.2746, Val Acc: 0.9414
# Precision: 0.9425, Recall: 0.9414, F1-score: 0.9412
# --------------------------------------------------
# Epoch [1422/1500]
# Train Loss: 0.0582, Train Acc: 0.9758
# Val Loss: 0.2705, Val Acc: 0.9361
# Precision: 0.9368, Recall: 0.9361, F1-score: 0.9360
# --------------------------------------------------
# Epoch [1423/1500]
# Train Loss: 0.0773, Train Acc: 0.9801
# Val Loss: 0.2801, Val Acc: 0.9325
# Precision: 0.9333, Recall: 0.9325, F1-score: 0.9323
# --------------------------------------------------
# Epoch [1424/1500]
# Train Loss: 0.0606, Train Acc: 0.9814
# Val Loss: 0.3131, Val Acc: 0.9272
# Precision: 0.9281, Recall: 0.9272, F1-score: 0.9270
# --------------------------------------------------
# Epoch [1425/1500]
# Train Loss: 0.0812, Train Acc: 0.9745
# Val Loss: 0.3201, Val Acc: 0.9254
# Precision: 0.9265, Recall: 0.9254, F1-score: 0.9252
# --------------------------------------------------
# Epoch [1426/1500]
# Train Loss: 0.0650, Train Acc: 0.9780
# Val Loss: 0.3319, Val Acc: 0.9236
# Precision: 0.9244, Recall: 0.9236, F1-score: 0.9233
# --------------------------------------------------
# Epoch [1427/1500]
# Train Loss: 0.0509, Train Acc: 0.9810
# Val Loss: 0.3400, Val Acc: 0.9254
# Precision: 0.9261, Recall: 0.9254, F1-score: 0.9251
# --------------------------------------------------
# Epoch [1428/1500]
# Train Loss: 0.0752, Train Acc: 0.9771
# Val Loss: 0.3244, Val Acc: 0.9254
# Precision: 0.9266, Recall: 0.9254, F1-score: 0.9252
# --------------------------------------------------
# Epoch [1429/1500]
# Train Loss: 0.0727, Train Acc: 0.9776
# Val Loss: 0.3112, Val Acc: 0.9307
# Precision: 0.9324, Recall: 0.9307, F1-score: 0.9304
# --------------------------------------------------
# Epoch [1430/1500]
# Train Loss: 0.0647, Train Acc: 0.9763
# Val Loss: 0.3027, Val Acc: 0.9290
# Precision: 0.9299, Recall: 0.9290, F1-score: 0.9288
# --------------------------------------------------
# Epoch [1431/1500]
# Train Loss: 0.0572, Train Acc: 0.9797
# Val Loss: 0.2882, Val Acc: 0.9290
# Precision: 0.9295, Recall: 0.9290, F1-score: 0.9287
# --------------------------------------------------
# Epoch [1432/1500]
# Train Loss: 0.0661, Train Acc: 0.9797
# Val Loss: 0.2959, Val Acc: 0.9325
# Precision: 0.9333, Recall: 0.9325, F1-score: 0.9324
# --------------------------------------------------
# Epoch [1433/1500]
# Train Loss: 0.1707, Train Acc: 0.9741
# Val Loss: 0.3426, Val Acc: 0.9272
# Precision: 0.9283, Recall: 0.9272, F1-score: 0.9270
# --------------------------------------------------
# Epoch [1434/1500]
# Train Loss: 0.1076, Train Acc: 0.9672
# Val Loss: 0.3447, Val Acc: 0.9236
# Precision: 0.9252, Recall: 0.9236, F1-score: 0.9233
# --------------------------------------------------
# Epoch [1435/1500]
# Train Loss: 0.0676, Train Acc: 0.9763
# Val Loss: 0.3682, Val Acc: 0.9236
# Precision: 0.9250, Recall: 0.9236, F1-score: 0.9234
# --------------------------------------------------
# Epoch [1436/1500]
# Train Loss: 0.0898, Train Acc: 0.9849
# Val Loss: 0.3425, Val Acc: 0.9290
# Precision: 0.9296, Recall: 0.9290, F1-score: 0.9287
# --------------------------------------------------
# Epoch [1437/1500]
# Train Loss: 0.0701, Train Acc: 0.9776
# Val Loss: 0.2892, Val Acc: 0.9361
# Precision: 0.9364, Recall: 0.9361, F1-score: 0.9358
# --------------------------------------------------
# Epoch [1438/1500]
# Train Loss: 0.0969, Train Acc: 0.9801
# Val Loss: 0.2789, Val Acc: 0.9325
# Precision: 0.9336, Recall: 0.9325, F1-score: 0.9322
# --------------------------------------------------
# Epoch [1439/1500]
# Train Loss: 0.0606, Train Acc: 0.9771
# Val Loss: 0.2968, Val Acc: 0.9290
# Precision: 0.9298, Recall: 0.9290, F1-score: 0.9287
# --------------------------------------------------
# Epoch [1440/1500]
# Train Loss: 0.0610, Train Acc: 0.9767
# Val Loss: 0.3045, Val Acc: 0.9218
# Precision: 0.9227, Recall: 0.9218, F1-score: 0.9212
# --------------------------------------------------
# Epoch [1441/1500]
# Train Loss: 0.0635, Train Acc: 0.9754
# Val Loss: 0.3105, Val Acc: 0.9272
# Precision: 0.9279, Recall: 0.9272, F1-score: 0.9267
# --------------------------------------------------
# Epoch [1442/1500]
# Train Loss: 0.0809, Train Acc: 0.9806
# Val Loss: 0.3127, Val Acc: 0.9343
# Precision: 0.9352, Recall: 0.9343, F1-score: 0.9341
# --------------------------------------------------
# Epoch [1443/1500]
# Train Loss: 0.1087, Train Acc: 0.9737
# Val Loss: 0.3587, Val Acc: 0.9272
# Precision: 0.9283, Recall: 0.9272, F1-score: 0.9269
# --------------------------------------------------
# Epoch [1444/1500]
# Train Loss: 0.1309, Train Acc: 0.9629
# Val Loss: 0.3611, Val Acc: 0.9307
# Precision: 0.9319, Recall: 0.9307, F1-score: 0.9304
# --------------------------------------------------
# Epoch [1445/1500]
# Train Loss: 0.1110, Train Acc: 0.9637
# Val Loss: 0.3222, Val Acc: 0.9218
# Precision: 0.9225, Recall: 0.9218, F1-score: 0.9214
# --------------------------------------------------
# Epoch [1446/1500]
# Train Loss: 0.1976, Train Acc: 0.9698
# Val Loss: 0.3011, Val Acc: 0.9361
# Precision: 0.9364, Recall: 0.9361, F1-score: 0.9356
# --------------------------------------------------
# Epoch [1447/1500]
# Train Loss: 0.1057, Train Acc: 0.9625
# Val Loss: 0.3034, Val Acc: 0.9254
# Precision: 0.9265, Recall: 0.9254, F1-score: 0.9250
# --------------------------------------------------
# Epoch [1448/1500]
# Train Loss: 0.1461, Train Acc: 0.9547
# Val Loss: 0.3082, Val Acc: 0.9236
# Precision: 0.9249, Recall: 0.9236, F1-score: 0.9228
# --------------------------------------------------
# Epoch [1449/1500]
# Train Loss: 0.1254, Train Acc: 0.9607
# Val Loss: 0.3160, Val Acc: 0.9272
# Precision: 0.9282, Recall: 0.9272, F1-score: 0.9264
# --------------------------------------------------
# Epoch [1450/1500]
# Train Loss: 0.1081, Train Acc: 0.9646
# Val Loss: 0.2872, Val Acc: 0.9254
# Precision: 0.9263, Recall: 0.9254, F1-score: 0.9251
# --------------------------------------------------
# Epoch [1451/1500]
# Train Loss: 0.0741, Train Acc: 0.9719
# Val Loss: 0.2874, Val Acc: 0.9307
# Precision: 0.9321, Recall: 0.9307, F1-score: 0.9307
# --------------------------------------------------
# Epoch [1452/1500]
# Train Loss: 0.1153, Train Acc: 0.9745
# Val Loss: 0.2943, Val Acc: 0.9396
# Precision: 0.9404, Recall: 0.9396, F1-score: 0.9394
# --------------------------------------------------
# Epoch [1453/1500]
# Train Loss: 0.1185, Train Acc: 0.9659
# Val Loss: 0.2787, Val Acc: 0.9343
# Precision: 0.9346, Recall: 0.9343, F1-score: 0.9341
# --------------------------------------------------
# Epoch [1454/1500]
# Train Loss: 0.0972, Train Acc: 0.9629
# Val Loss: 0.2656, Val Acc: 0.9343
# Precision: 0.9347, Recall: 0.9343, F1-score: 0.9340
# --------------------------------------------------
# Epoch [1455/1500]
# Train Loss: 0.0644, Train Acc: 0.9797
# Val Loss: 0.2678, Val Acc: 0.9361
# Precision: 0.9367, Recall: 0.9361, F1-score: 0.9358
# --------------------------------------------------
# Epoch [1456/1500]
# Train Loss: 0.1145, Train Acc: 0.9728
# Val Loss: 0.2999, Val Acc: 0.9325
# Precision: 0.9328, Recall: 0.9325, F1-score: 0.9320
# --------------------------------------------------
# Epoch [1457/1500]
# Train Loss: 0.0778, Train Acc: 0.9789
# Val Loss: 0.3543, Val Acc: 0.9272
# Precision: 0.9284, Recall: 0.9272, F1-score: 0.9267
# --------------------------------------------------
# Epoch [1458/1500]
# Train Loss: 0.1391, Train Acc: 0.9694
# Val Loss: 0.3310, Val Acc: 0.9272
# Precision: 0.9279, Recall: 0.9272, F1-score: 0.9269
# --------------------------------------------------
# Epoch [1459/1500]
# Train Loss: 0.0980, Train Acc: 0.9754
# Val Loss: 0.3531, Val Acc: 0.9272
# Precision: 0.9288, Recall: 0.9272, F1-score: 0.9272
# --------------------------------------------------
# Epoch [1460/1500]
# Train Loss: 0.0765, Train Acc: 0.9724
# Val Loss: 0.3289, Val Acc: 0.9307
# Precision: 0.9316, Recall: 0.9307, F1-score: 0.9306
# --------------------------------------------------
# Epoch [1461/1500]
# Train Loss: 0.0715, Train Acc: 0.9780
# Val Loss: 0.3149, Val Acc: 0.9272
# Precision: 0.9278, Recall: 0.9272, F1-score: 0.9269
# --------------------------------------------------
# Epoch [1462/1500]
# Train Loss: 0.0731, Train Acc: 0.9780
# Val Loss: 0.2948, Val Acc: 0.9325
# Precision: 0.9332, Recall: 0.9325, F1-score: 0.9323
# --------------------------------------------------
# Epoch [1463/1500]
# Train Loss: 0.0955, Train Acc: 0.9741
# Val Loss: 0.3105, Val Acc: 0.9343
# Precision: 0.9347, Recall: 0.9343, F1-score: 0.9340
# --------------------------------------------------
# Epoch [1464/1500]
# Train Loss: 0.0581, Train Acc: 0.9784
# Val Loss: 0.3110, Val Acc: 0.9343
# Precision: 0.9347, Recall: 0.9343, F1-score: 0.9340
# --------------------------------------------------
# Epoch [1465/1500]
# Train Loss: 0.0655, Train Acc: 0.9750
# Val Loss: 0.3097, Val Acc: 0.9325
# Precision: 0.9330, Recall: 0.9325, F1-score: 0.9323
# --------------------------------------------------
# Epoch [1466/1500]
# Train Loss: 0.0834, Train Acc: 0.9737
# Val Loss: 0.3113, Val Acc: 0.9361
# Precision: 0.9365, Recall: 0.9361, F1-score: 0.9359
# --------------------------------------------------
# Epoch [1467/1500]
# Train Loss: 0.0934, Train Acc: 0.9758
# Val Loss: 0.2944, Val Acc: 0.9378
# Precision: 0.9385, Recall: 0.9378, F1-score: 0.9377
# --------------------------------------------------
# Epoch [1468/1500]
# Train Loss: 0.0644, Train Acc: 0.9771
# Val Loss: 0.3029, Val Acc: 0.9361
# Precision: 0.9367, Recall: 0.9361, F1-score: 0.9357
# --------------------------------------------------
# Epoch [1469/1500]
# Train Loss: 0.0758, Train Acc: 0.9763
# Val Loss: 0.3082, Val Acc: 0.9325
# Precision: 0.9330, Recall: 0.9325, F1-score: 0.9320
# --------------------------------------------------
# Epoch [1470/1500]
# Train Loss: 0.0571, Train Acc: 0.9776
# Val Loss: 0.3113, Val Acc: 0.9307
# Precision: 0.9312, Recall: 0.9307, F1-score: 0.9305
# --------------------------------------------------
# Epoch [1471/1500]
# Train Loss: 0.1037, Train Acc: 0.9819
# Val Loss: 0.3211, Val Acc: 0.9254
# Precision: 0.9257, Recall: 0.9254, F1-score: 0.9251
# --------------------------------------------------
# Epoch [1472/1500]
# Train Loss: 0.0655, Train Acc: 0.9789
# Val Loss: 0.3071, Val Acc: 0.9325
# Precision: 0.9326, Recall: 0.9325, F1-score: 0.9322
# --------------------------------------------------
# Epoch [1473/1500]
# Train Loss: 0.0756, Train Acc: 0.9754
# Val Loss: 0.3034, Val Acc: 0.9325
# Precision: 0.9327, Recall: 0.9325, F1-score: 0.9322
# --------------------------------------------------
# Epoch [1474/1500]
# Train Loss: 0.0563, Train Acc: 0.9814
# Val Loss: 0.2947, Val Acc: 0.9325
# Precision: 0.9326, Recall: 0.9325, F1-score: 0.9323
# --------------------------------------------------
# Epoch [1475/1500]
# Train Loss: 0.1200, Train Acc: 0.9793
# Val Loss: 0.3036, Val Acc: 0.9236
# Precision: 0.9239, Recall: 0.9236, F1-score: 0.9233
# --------------------------------------------------
# Epoch [1476/1500]
# Train Loss: 0.0964, Train Acc: 0.9853
# Val Loss: 0.3264, Val Acc: 0.9236
# Precision: 0.9245, Recall: 0.9236, F1-score: 0.9234
# --------------------------------------------------
# Epoch [1477/1500]
# Train Loss: 0.0694, Train Acc: 0.9758
# Val Loss: 0.3270, Val Acc: 0.9183
# Precision: 0.9200, Recall: 0.9183, F1-score: 0.9181
# --------------------------------------------------
# Epoch [1478/1500]
# Train Loss: 0.0928, Train Acc: 0.9711
# Val Loss: 0.3074, Val Acc: 0.9236
# Precision: 0.9240, Recall: 0.9236, F1-score: 0.9234
# --------------------------------------------------
# Epoch [1479/1500]
# Train Loss: 0.0659, Train Acc: 0.9771
# Val Loss: 0.3049, Val Acc: 0.9325
# Precision: 0.9330, Recall: 0.9325, F1-score: 0.9323
# --------------------------------------------------
# Epoch [1480/1500]
# Train Loss: 0.0938, Train Acc: 0.9741
# Val Loss: 0.3149, Val Acc: 0.9343
# Precision: 0.9351, Recall: 0.9343, F1-score: 0.9342
# --------------------------------------------------
# Epoch [1481/1500]
# Train Loss: 0.0699, Train Acc: 0.9801
# Val Loss: 0.3246, Val Acc: 0.9272
# Precision: 0.9281, Recall: 0.9272, F1-score: 0.9270
# --------------------------------------------------
# Epoch [1482/1500]
# Train Loss: 0.0548, Train Acc: 0.9845
# Val Loss: 0.3319, Val Acc: 0.9307
# Precision: 0.9319, Recall: 0.9307, F1-score: 0.9303
# --------------------------------------------------
# Epoch [1483/1500]
# Train Loss: 0.0987, Train Acc: 0.9801
# Val Loss: 0.3345, Val Acc: 0.9307
# Precision: 0.9318, Recall: 0.9307, F1-score: 0.9305
# --------------------------------------------------
# Epoch [1484/1500]
# Train Loss: 0.0724, Train Acc: 0.9737
# Val Loss: 0.3644, Val Acc: 0.9290
# Precision: 0.9293, Recall: 0.9290, F1-score: 0.9287
# --------------------------------------------------
# Epoch [1485/1500]
# Train Loss: 0.0883, Train Acc: 0.9715
# Val Loss: 0.3337, Val Acc: 0.9343
# Precision: 0.9351, Recall: 0.9343, F1-score: 0.9341
# --------------------------------------------------
# Epoch [1486/1500]
# Train Loss: 0.1118, Train Acc: 0.9758
# Val Loss: 0.3254, Val Acc: 0.9307
# Precision: 0.9318, Recall: 0.9307, F1-score: 0.9306
# --------------------------------------------------
# Epoch [1487/1500]
# Train Loss: 0.0717, Train Acc: 0.9776
# Val Loss: 0.3366, Val Acc: 0.9272
# Precision: 0.9288, Recall: 0.9272, F1-score: 0.9272
# --------------------------------------------------
# Epoch [1488/1500]
# Train Loss: 0.0643, Train Acc: 0.9758
# Val Loss: 0.3251, Val Acc: 0.9272
# Precision: 0.9284, Recall: 0.9272, F1-score: 0.9271
# --------------------------------------------------
# Epoch [1489/1500]
# Train Loss: 0.0998, Train Acc: 0.9771
# Val Loss: 0.3204, Val Acc: 0.9290
# Precision: 0.9303, Recall: 0.9290, F1-score: 0.9290
# --------------------------------------------------
# Epoch [1490/1500]
# Train Loss: 0.0898, Train Acc: 0.9793
# Val Loss: 0.3452, Val Acc: 0.9201
# Precision: 0.9224, Recall: 0.9201, F1-score: 0.9199
# --------------------------------------------------
# Epoch [1491/1500]
# Train Loss: 0.1135, Train Acc: 0.9689
# Val Loss: 0.3198, Val Acc: 0.9254
# Precision: 0.9269, Recall: 0.9254, F1-score: 0.9252
# --------------------------------------------------
# Epoch [1492/1500]
# Train Loss: 0.0701, Train Acc: 0.9719
# Val Loss: 0.3022, Val Acc: 0.9272
# Precision: 0.9278, Recall: 0.9272, F1-score: 0.9271
# --------------------------------------------------
# Epoch [1493/1500]
# Train Loss: 0.0929, Train Acc: 0.9711
# Val Loss: 0.3102, Val Acc: 0.9272
# Precision: 0.9281, Recall: 0.9272, F1-score: 0.9271
# --------------------------------------------------
# Epoch [1494/1500]
# Train Loss: 0.0567, Train Acc: 0.9806
# Val Loss: 0.3063, Val Acc: 0.9272
# Precision: 0.9281, Recall: 0.9272, F1-score: 0.9271
# --------------------------------------------------
# Epoch [1495/1500]
# Train Loss: 0.0743, Train Acc: 0.9767
# Val Loss: 0.2934, Val Acc: 0.9290
# Precision: 0.9297, Recall: 0.9290, F1-score: 0.9289
# --------------------------------------------------
# Epoch [1496/1500]
# Train Loss: 0.0616, Train Acc: 0.9741
# Val Loss: 0.2826, Val Acc: 0.9325
# Precision: 0.9329, Recall: 0.9325, F1-score: 0.9323
# --------------------------------------------------
# Epoch [1497/1500]
# Train Loss: 0.0849, Train Acc: 0.9780
# Val Loss: 0.2813, Val Acc: 0.9343
# Precision: 0.9346, Recall: 0.9343, F1-score: 0.9341
# --------------------------------------------------
# Epoch [1498/1500]
# Train Loss: 0.0538, Train Acc: 0.9801
# Val Loss: 0.3038, Val Acc: 0.9307
# Precision: 0.9317, Recall: 0.9307, F1-score: 0.9305
# --------------------------------------------------
# Epoch [1499/1500]
# Train Loss: 0.0981, Train Acc: 0.9801
# Val Loss: 0.3136, Val Acc: 0.9290
# Precision: 0.9303, Recall: 0.9290, F1-score: 0.9287
# --------------------------------------------------
# Epoch [1500/1500]
# Train Loss: 0.0610, Train Acc: 0.9758
# Val Loss: 0.3101, Val Acc: 0.9272
# Precision: 0.9286, Recall: 0.9272, F1-score: 0.9270
# --------------------------------------------------

# %%
torch.save(model.state_dict(), "C:/Nini/Capstone/Models/DataAugmentation_cnn_model2.pth")

# %% [markdown]
# Inference on test set

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
num_classes = 8  # Update this based on your dataset
model = CNNModel(input_size=128, num_classes=num_classes)  # Update input_size accordingly
model.load_state_dict(torch.load("C:/Nini/Capstone/Models/DataAugmentation_cnn_model2.pth", map_location=device))  # Load saved weights
model.to(device)
model.eval()  # Set to evaluation mode
print("Model Loaded Successfully")
# Out:
# Model Loaded Successfully

# %%
print(model)
# Out:
# CNNModel(
#   (conv1): Conv1d(1, 64, kernel_size=(8,), stride=(1,))
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(64, 128, kernel_size=(8,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool1d(kernel_size=4, stride=4, padding=2, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (conv3): Conv1d(128, 128, kernel_size=(8,), stride=(1,))
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool1d(kernel_size=4, stride=4, padding=2, dilation=1, ceil_mode=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (conv4): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(2,))
#   (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=512, out_features=256, bias=True)
#   (dropout3): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=256, out_features=8, bias=True)
# )

# %%
def predict(model, input_tensor, device):
    model.eval()  # Set model to evaluation mode
    input_tensor = input_tensor.to(device)
    
    with torch.no_grad():  # Disable gradient calculations for inference
        output = model(input_tensor)
        predicted_class = torch.argmax(output, dim=1)  # Get predicted class
        
    return predicted_class.cpu().numpy()  # Convert to numpy array for easy handling

# Example usage:
sample_input = X_test[:5].to(device)  # Take a few samples for inference
predictions = predict(model, sample_input, device)
print("Predicted Labels:", predictions)
# Out:
# Predicted Labels: [0 3 0 5 1]

# %%
actual_labels = y_test[:5].cpu().numpy()
for i in range(len(predictions)):
    print(f"Sample {i+1}: Predicted = {predictions[i]}, Actual = {actual_labels[i]}")
# Out:
# Sample 1: Predicted = 0, Actual = 0
# Sample 2: Predicted = 3, Actual = 3
# Sample 3: Predicted = 0, Actual = 0
# Sample 4: Predicted = 5, Actual = 5
# Sample 5: Predicted = 1, Actual = 1

# %%
lb = joblib.load("label_encoder.pkl")
decoded_predictions = lb.inverse_transform(predictions)
decoded_actual_labels = lb.inverse_transform(actual_labels)

# %%
for i in range(len(predictions)):
    print(f"Sample {i+1}: Predicted = {decoded_predictions[i]}, Actual = {decoded_actual_labels[i]}")
# Out:
# Sample 1: Predicted = angry, Actual = angry
# Sample 2: Predicted = fearful, Actual = fearful
# Sample 3: Predicted = angry, Actual = angry
# Sample 4: Predicted = neutral, Actual = neutral
# Sample 5: Predicted = calm, Actual = calm

# %% [markdown]
# Inference on unseen audio

# %%
import numpy as np
import librosa
import torch
import joblib
import soxr

# %%
mean = np.load("C:/Nini/Capstone/src/Data Preprocessing/mean.npy")[:,None]  # Load mean array
std = np.load("C:/Nini/Capstone/src/Data Preprocessing/std.npy") [:,None]

# %%
lb = joblib.load("label_encoder.pkl")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNNModel(input_size=128, num_classes=8)  # Ensure the architecture matches
model.load_state_dict(torch.load("C:/Nini/Capstone/Models/DataAugmentation_cnn_model.pth", map_location=device))
model.to(device)
model.eval()
# Out:
# CNNModel(
#   (conv1): Conv1d(1, 64, kernel_size=(8,), stride=(1,))
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv1d(64, 128, kernel_size=(8,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool1d(kernel_size=4, stride=4, padding=2, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (conv3): Conv1d(128, 128, kernel_size=(8,), stride=(1,))
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool1d(kernel_size=4, stride=4, padding=2, dilation=1, ceil_mode=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (conv4): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(2,))
#   (bn4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=512, out_features=256, bias=True)
#   (dropout3): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=256, out_features=8, bias=True)
# )

# %%
def preprocess_audio(file_path):
    X, sample_rate = librosa.load(file_path,res_type='kaiser_fast',duration=3,sr=44100,offset=0.5)
    audio_resampled = soxr.resample(X, sample_rate, 16000)
    spectrogram = librosa.feature.melspectrogram(y=audio_resampled,sr=16000,n_mels=128,fmax=8000)
    db_spec = librosa.power_to_db(spectrogram)
    mel_spectrogram = (db_spec - mean) / std
    log_spectrogram = np.mean(mel_spectrogram,axis=1)
    mel_spectrogram_tensor = torch.tensor(log_spectrogram, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
    return mel_spectrogram_tensor

# %%
def predict_audio(file_path):
    input_tensor = preprocess_audio(file_path).to(device)
    print(input_tensor)
    
    with torch.no_grad():  # Disable gradients for inference
        output = model(input_tensor)
        predicted_class = torch.argmax(output, dim=1).cpu().numpy()[0]  # Convert to NumPy
        
    # Decode the label
    predicted_label = lb.inverse_transform([predicted_class])[0]
    return predicted_label

# %%
audio_file = "C:/Nini/Capstone/Test/01-01-06-02-01-02-01.wav"
prediction = predict_audio(audio_file)
print(f"Predicted Emotion: {prediction}")
# Out:
# tensor([[[-39.0506, -39.5870, -39.7154, -40.9100, -42.6148, -36.2505, -30.1936,
#           -24.8767, -18.0850, -14.5041, -12.3833, -11.8852, -16.1793, -22.7990,
#           -25.9747, -25.2175, -22.4984, -21.3819, -20.2342, -17.6569, -17.4210,
#           -18.9434, -18.0588, -18.8115, -20.8730, -23.4603, -26.8653, -29.2984,
#           -27.1497, -27.5133, -28.2432, -27.1207, -29.3671, -29.7387, -27.8602,
#           -25.9646, -24.4105, -25.4388, -27.0234, -27.4708, -27.9303, -28.8141,
#           -30.0984, -29.2751, -27.1728, -26.0809, -24.6129, -21.5107, -22.5599,
#           -25.7683, -27.6894, -28.2929, -25.8600, -24.5037, -21.5814, -18.7496,
#           -19.2529, -20.6802, -21.8183, -22.2989, -22.7439, -22.5519, -21.2937,
#           -20.5533, -24.2446, -27.4240, -27.9722, -28.1946, -29.2111, -28.8527,
#           -28.7333, -28.0296, -27.9280, -29.4251, -28.7732, -26.7698, -24.6226,
#           -24.7869, -26.9146, -28.3228, -29.1971, -29.8335, -29.6409, -30.9195,
#           -32.9055, -32.5348, -31.9851, -32.1705, -31.6121, -29.6714, -29.8379,
#           -29.9459, -28.0392, -27.6132, -29.5741, -31.0570, -33.3314, -35.0770,
#           -35.9323, -36.7817, -36.4167, -37.2252, -36.4538, -36.9768, -36.4685,
#           -36.5099, -37.5971, -37.9870, -37.4363, -36.2958, -35.3716, -33.6664,
#           -33.4812, -34.1328, -34.1864, -35.7883, -36.3919, -36.9855, -36.5910,
#           -37.0749, -38.0191, -38.5513, -38.3785, -37.6802, -37.5153, -38.3946,
#           -42.0269, -49.1377]]], device='cuda:0')
# Predicted Emotion: sad
