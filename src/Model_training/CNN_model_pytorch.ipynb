# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle

# %%
features = pd.read_csv("C:/Nini/Capstone/CSV_Files/ravdess_extracted_features.csv")
features = features.drop(features.columns[0], axis=1)
temp = shuffle(features)
df = np.random.rand(len(temp)) < 0.8
train = temp[df]
test = temp[~df]

# %%
X_train = np.array(train.iloc[:,:-1])
y_train = np.array(train.iloc[:,-1])
X_test = np.array(test.iloc[:,:-1])
y_test = np.array(test.iloc[:,-1])

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
batch_size = 256
train_loader = DataLoader(TensorDataset(X_train,y_train), batch_size=batch_size,shuffle=True)
test_loader = DataLoader(TensorDataset(X_test,y_test), batch_size=batch_size, shuffle=False)

# %%
class CNNModel(nn.Module):
    def __init__(self, input_size, num_classes):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=8)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=8)
        self.bn2 = nn.BatchNorm1d(128)
        self.pool1 = nn.MaxPool1d(kernel_size=4, padding=2)
        self.dropout1 = nn.Dropout(0.5)
        self.conv3 = nn.Conv1d(128, 128, kernel_size=8)
        self.bn3 = nn.BatchNorm1d(128)
        self.pool2 = nn.MaxPool1d(kernel_size=4, padding=2)
        self.dropout2 = nn.Dropout(0.5)
        self.conv4 = nn.Conv1d(128, 64, kernel_size=3, padding=2)
        self.bn4 = nn.BatchNorm1d(64)
        self.fc1 = nn.Linear(512, 256)
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, num_classes)

    # def _compute_flattened_size(self, input_size):
    #     with torch.no_grad():
    #         x = torch.randn(1, 1, input_size)  # Create a dummy input
    #         x = self.conv1(x)
    #         x = F.relu(x)
    #         x = self.conv2(x)
    #         x = F.relu(x)
    #         x = self.pool1(x)
    #         x = self.dropout1(x)
    #         x = self.conv3(x)
    #         x = F.relu(x)
    #         x = self.pool2(x)
    #         x = self.dropout2(x)
    #         x = self.conv4(x)
    #         x = F.relu(x)
    #         x = x.view(1, -1)  # Flatten
    #         self._to_linear = x.shape[1]

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNModel(input_size=X_train.shape[1], num_classes=8).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=1e-4)

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: torch.Size([1132, 1, 128])

# %%
epochs = 1500
for epoch in range(epochs):
    model.train()
    running_loss = 0
    total_loss = 0
    total = 0
    correct = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)
    train_accuracy = correct / total
    avg_train_loss = running_loss / len(train_loader)
        # total_loss += loss.item()
        # correct += (outputs.argmax(dim=1) == y_batch).sum().item()
    model.eval()  # Set model to evaluation mode
    val_correct = 0
    val_total = 0
    val_loss = 0.0

    with torch.no_grad():  # Disable gradient computation for validation
        for val_inputs, val_labels in test_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)

            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()

            _, val_predicted = torch.max(val_outputs, 1)
            val_correct += (val_predicted == val_labels).sum().item()
            val_total += val_labels.size(0)
    
    val_accuracy = val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)
    # accuracy = correct / len(train_loader.dataset)
    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    print("-" * 50)
# Out:
# Epoch [1/1500]
# Train Loss: 2.0363, Train Acc: 0.1528
# Val Loss: 2.0635, Val Acc: 0.2078
# --------------------------------------------------
# Epoch [2/1500]
# Train Loss: 1.9213, Train Acc: 0.2261
# Val Loss: 1.9986, Val Acc: 0.2273
# --------------------------------------------------
# Epoch [3/1500]
# Train Loss: 1.8505, Train Acc: 0.2580
# Val Loss: 1.9187, Val Acc: 0.2727
# --------------------------------------------------
# Epoch [4/1500]
# Train Loss: 1.8250, Train Acc: 0.2553
# Val Loss: 1.8698, Val Acc: 0.2630
# --------------------------------------------------
# Epoch [5/1500]
# Train Loss: 1.7990, Train Acc: 0.2712
# Val Loss: 1.8410, Val Acc: 0.2532
# --------------------------------------------------
# Epoch [6/1500]
# Train Loss: 1.7828, Train Acc: 0.2906
# Val Loss: 1.8280, Val Acc: 0.2987
# --------------------------------------------------
# Epoch [7/1500]
# Train Loss: 1.7452, Train Acc: 0.2889
# Val Loss: 1.8155, Val Acc: 0.2987
# --------------------------------------------------
# Epoch [8/1500]
# Train Loss: 1.7452, Train Acc: 0.2995
# Val Loss: 1.7745, Val Acc: 0.3312
# --------------------------------------------------
# Epoch [9/1500]
# Train Loss: 1.7371, Train Acc: 0.3057
# Val Loss: 1.7295, Val Acc: 0.3344
# --------------------------------------------------
# Epoch [10/1500]
# Train Loss: 1.7130, Train Acc: 0.3180
# Val Loss: 1.6946, Val Acc: 0.3636
# --------------------------------------------------
# Epoch [11/1500]
# Train Loss: 1.6746, Train Acc: 0.3463
# Val Loss: 1.6807, Val Acc: 0.3604
# --------------------------------------------------
# Epoch [12/1500]
# Train Loss: 1.6712, Train Acc: 0.3242
# Val Loss: 1.6697, Val Acc: 0.3701
# --------------------------------------------------
# Epoch [13/1500]
# Train Loss: 1.6412, Train Acc: 0.3428
# Val Loss: 1.5975, Val Acc: 0.3831
# --------------------------------------------------
# Epoch [14/1500]
# Train Loss: 1.6602, Train Acc: 0.3269
# Val Loss: 1.5581, Val Acc: 0.3864
# --------------------------------------------------
# Epoch [15/1500]
# Train Loss: 1.6269, Train Acc: 0.3578
# Val Loss: 1.5722, Val Acc: 0.3734
# --------------------------------------------------
# Epoch [16/1500]
# Train Loss: 1.6247, Train Acc: 0.3657
# Val Loss: 1.5220, Val Acc: 0.3994
# --------------------------------------------------
# Epoch [17/1500]
# Train Loss: 1.6014, Train Acc: 0.3675
# Val Loss: 1.5531, Val Acc: 0.3669
# --------------------------------------------------
# Epoch [18/1500]
# Train Loss: 1.5801, Train Acc: 0.3860
# Val Loss: 1.4937, Val Acc: 0.4188
# --------------------------------------------------
# Epoch [19/1500]
# Train Loss: 1.5804, Train Acc: 0.3790
# Val Loss: 1.4963, Val Acc: 0.3994
# --------------------------------------------------
# Epoch [20/1500]
# Train Loss: 1.5746, Train Acc: 0.3887
# Val Loss: 1.4740, Val Acc: 0.4253
# --------------------------------------------------
# Epoch [21/1500]
# Train Loss: 1.5655, Train Acc: 0.3684
# Val Loss: 1.4816, Val Acc: 0.4253
# --------------------------------------------------
# Epoch [22/1500]
# Train Loss: 1.5357, Train Acc: 0.3958
# Val Loss: 1.4791, Val Acc: 0.4416
# --------------------------------------------------
# Epoch [23/1500]
# Train Loss: 1.5211, Train Acc: 0.4117
# Val Loss: 1.4973, Val Acc: 0.4188
# --------------------------------------------------
# Epoch [24/1500]
# Train Loss: 1.5159, Train Acc: 0.4196
# Val Loss: 1.4565, Val Acc: 0.4545
# --------------------------------------------------
# Epoch [25/1500]
# Train Loss: 1.5061, Train Acc: 0.4072
# Val Loss: 1.4520, Val Acc: 0.4416
# --------------------------------------------------
# Epoch [26/1500]
# Train Loss: 1.4963, Train Acc: 0.4178
# Val Loss: 1.4438, Val Acc: 0.4286
# --------------------------------------------------
# Epoch [27/1500]
# Train Loss: 1.5108, Train Acc: 0.4258
# Val Loss: 1.4247, Val Acc: 0.4481
# --------------------------------------------------
# Epoch [28/1500]
# Train Loss: 1.4594, Train Acc: 0.4108
# Val Loss: 1.4293, Val Acc: 0.4643
# --------------------------------------------------
# Epoch [29/1500]
# Train Loss: 1.4419, Train Acc: 0.4470
# Val Loss: 1.4605, Val Acc: 0.4578
# --------------------------------------------------
# Epoch [30/1500]
# Train Loss: 1.4577, Train Acc: 0.4337
# Val Loss: 1.4482, Val Acc: 0.4513
# --------------------------------------------------
# Epoch [31/1500]
# Train Loss: 1.4192, Train Acc: 0.4558
# Val Loss: 1.3872, Val Acc: 0.4903
# --------------------------------------------------
# Epoch [32/1500]
# Train Loss: 1.4146, Train Acc: 0.4664
# Val Loss: 1.3838, Val Acc: 0.4708
# --------------------------------------------------
# Epoch [33/1500]
# Train Loss: 1.3862, Train Acc: 0.4682
# Val Loss: 1.3729, Val Acc: 0.4903
# --------------------------------------------------
# Epoch [34/1500]
# Train Loss: 1.3715, Train Acc: 0.4744
# Val Loss: 1.3587, Val Acc: 0.4903
# --------------------------------------------------
# Epoch [35/1500]
# Train Loss: 1.3544, Train Acc: 0.4629
# Val Loss: 1.3709, Val Acc: 0.4838
# --------------------------------------------------
# Epoch [36/1500]
# Train Loss: 1.3563, Train Acc: 0.4867
# Val Loss: 1.3464, Val Acc: 0.5000
# --------------------------------------------------
# Epoch [37/1500]
# Train Loss: 1.3893, Train Acc: 0.4726
# Val Loss: 1.3556, Val Acc: 0.4968
# --------------------------------------------------
# Epoch [38/1500]
# Train Loss: 1.3415, Train Acc: 0.4850
# Val Loss: 1.3507, Val Acc: 0.4903
# --------------------------------------------------
# Epoch [39/1500]
# Train Loss: 1.3273, Train Acc: 0.5097
# Val Loss: 1.3430, Val Acc: 0.5227
# --------------------------------------------------
# Epoch [40/1500]
# Train Loss: 1.3030, Train Acc: 0.5053
# Val Loss: 1.2860, Val Acc: 0.5195
# --------------------------------------------------
# Epoch [41/1500]
# Train Loss: 1.3172, Train Acc: 0.4991
# Val Loss: 1.3256, Val Acc: 0.5130
# --------------------------------------------------
# Epoch [42/1500]
# Train Loss: 1.2904, Train Acc: 0.5062
# Val Loss: 1.2861, Val Acc: 0.5260
# --------------------------------------------------
# Epoch [43/1500]
# Train Loss: 1.2939, Train Acc: 0.5053
# Val Loss: 1.3267, Val Acc: 0.5000
# --------------------------------------------------
# Epoch [44/1500]
# Train Loss: 1.2587, Train Acc: 0.5292
# Val Loss: 1.2525, Val Acc: 0.5390
# --------------------------------------------------
# Epoch [45/1500]
# Train Loss: 1.2730, Train Acc: 0.5239
# Val Loss: 1.3157, Val Acc: 0.5032
# --------------------------------------------------
# Epoch [46/1500]
# Train Loss: 1.2473, Train Acc: 0.5477
# Val Loss: 1.2948, Val Acc: 0.5292
# --------------------------------------------------
# Epoch [47/1500]
# Train Loss: 1.2777, Train Acc: 0.5318
# Val Loss: 1.2812, Val Acc: 0.5097
# --------------------------------------------------
# Epoch [48/1500]
# Train Loss: 1.2367, Train Acc: 0.5318
# Val Loss: 1.2590, Val Acc: 0.5455
# --------------------------------------------------
# Epoch [49/1500]
# Train Loss: 1.2427, Train Acc: 0.5274
# Val Loss: 1.2514, Val Acc: 0.5325
# --------------------------------------------------
# Epoch [50/1500]
# Train Loss: 1.2122, Train Acc: 0.5239
# Val Loss: 1.2452, Val Acc: 0.5455
# --------------------------------------------------
# Epoch [51/1500]
# Train Loss: 1.2210, Train Acc: 0.5283
# Val Loss: 1.2502, Val Acc: 0.5422
# --------------------------------------------------
# Epoch [52/1500]
# Train Loss: 1.1562, Train Acc: 0.5592
# Val Loss: 1.2502, Val Acc: 0.5357
# --------------------------------------------------
# Epoch [53/1500]
# Train Loss: 1.1667, Train Acc: 0.5654
# Val Loss: 1.1924, Val Acc: 0.5519
# --------------------------------------------------
# Epoch [54/1500]
# Train Loss: 1.1865, Train Acc: 0.5424
# Val Loss: 1.2417, Val Acc: 0.5260
# --------------------------------------------------
# Epoch [55/1500]
# Train Loss: 1.1937, Train Acc: 0.5671
# Val Loss: 1.2456, Val Acc: 0.5487
# --------------------------------------------------
# Epoch [56/1500]
# Train Loss: 1.1346, Train Acc: 0.5610
# Val Loss: 1.2407, Val Acc: 0.5357
# --------------------------------------------------
# Epoch [57/1500]
# Train Loss: 1.1563, Train Acc: 0.5654
# Val Loss: 1.2080, Val Acc: 0.5487
# --------------------------------------------------
# Epoch [58/1500]
# Train Loss: 1.1455, Train Acc: 0.5627
# Val Loss: 1.2735, Val Acc: 0.5227
# --------------------------------------------------
# Epoch [59/1500]
# Train Loss: 1.1440, Train Acc: 0.5636
# Val Loss: 1.2545, Val Acc: 0.5292
# --------------------------------------------------
# Epoch [60/1500]
# Train Loss: 1.0862, Train Acc: 0.5910
# Val Loss: 1.2344, Val Acc: 0.5455
# --------------------------------------------------
# Epoch [61/1500]
# Train Loss: 1.1173, Train Acc: 0.5875
# Val Loss: 1.1955, Val Acc: 0.5519
# --------------------------------------------------
# Epoch [62/1500]
# Train Loss: 1.1317, Train Acc: 0.5760
# Val Loss: 1.2119, Val Acc: 0.5584
# --------------------------------------------------
# Epoch [63/1500]
# Train Loss: 1.1264, Train Acc: 0.5892
# Val Loss: 1.2019, Val Acc: 0.5487
# --------------------------------------------------
# Epoch [64/1500]
# Train Loss: 1.1343, Train Acc: 0.5777
# Val Loss: 1.2258, Val Acc: 0.5487
# --------------------------------------------------
# Epoch [65/1500]
# Train Loss: 1.0824, Train Acc: 0.6051
# Val Loss: 1.2315, Val Acc: 0.5390
# --------------------------------------------------
# Epoch [66/1500]
# Train Loss: 1.0969, Train Acc: 0.6007
# Val Loss: 1.1573, Val Acc: 0.5682
# --------------------------------------------------
# Epoch [67/1500]
# Train Loss: 1.0596, Train Acc: 0.6069
# Val Loss: 1.2025, Val Acc: 0.5455
# --------------------------------------------------
# Epoch [68/1500]
# Train Loss: 1.0813, Train Acc: 0.5707
# Val Loss: 1.1883, Val Acc: 0.5584
# --------------------------------------------------
# Epoch [69/1500]
# Train Loss: 1.0092, Train Acc: 0.6281
# Val Loss: 1.1614, Val Acc: 0.5682
# --------------------------------------------------
# Epoch [70/1500]
# Train Loss: 1.0662, Train Acc: 0.6140
# Val Loss: 1.1667, Val Acc: 0.5747
# --------------------------------------------------
# Epoch [71/1500]
# Train Loss: 1.0599, Train Acc: 0.6060
# Val Loss: 1.1753, Val Acc: 0.5552
# --------------------------------------------------
# Epoch [72/1500]
# Train Loss: 1.0038, Train Acc: 0.6343
# Val Loss: 1.1685, Val Acc: 0.5422
# --------------------------------------------------
# Epoch [73/1500]
# Train Loss: 0.9936, Train Acc: 0.6307
# Val Loss: 1.1602, Val Acc: 0.5682
# --------------------------------------------------
# Epoch [74/1500]
# Train Loss: 1.0014, Train Acc: 0.6184
# Val Loss: 1.1347, Val Acc: 0.5617
# --------------------------------------------------
# Epoch [75/1500]
# Train Loss: 0.9931, Train Acc: 0.6201
# Val Loss: 1.1554, Val Acc: 0.5649
# --------------------------------------------------
# Epoch [76/1500]
# Train Loss: 0.9971, Train Acc: 0.6157
# Val Loss: 1.1066, Val Acc: 0.5812
# --------------------------------------------------
# Epoch [77/1500]
# Train Loss: 0.9330, Train Acc: 0.6590
# Val Loss: 1.1452, Val Acc: 0.5942
# --------------------------------------------------
# Epoch [78/1500]
# Train Loss: 1.0016, Train Acc: 0.6148
# Val Loss: 1.1293, Val Acc: 0.6039
# --------------------------------------------------
# Epoch [79/1500]
# Train Loss: 1.0063, Train Acc: 0.6201
# Val Loss: 1.2016, Val Acc: 0.5552
# --------------------------------------------------
# Epoch [80/1500]
# Train Loss: 0.9544, Train Acc: 0.6519
# Val Loss: 1.1962, Val Acc: 0.5714
# --------------------------------------------------
# Epoch [81/1500]
# Train Loss: 0.9294, Train Acc: 0.6502
# Val Loss: 1.1055, Val Acc: 0.5812
# --------------------------------------------------
# Epoch [82/1500]
# Train Loss: 0.9378, Train Acc: 0.6343
# Val Loss: 1.1095, Val Acc: 0.5747
# --------------------------------------------------
# Epoch [83/1500]
# Train Loss: 0.9651, Train Acc: 0.6387
# Val Loss: 1.2095, Val Acc: 0.5682
# --------------------------------------------------
# Epoch [84/1500]
# Train Loss: 0.9286, Train Acc: 0.6502
# Val Loss: 1.1605, Val Acc: 0.5617
# --------------------------------------------------
# Epoch [85/1500]
# Train Loss: 0.9096, Train Acc: 0.6599
# Val Loss: 1.1470, Val Acc: 0.5714
# --------------------------------------------------
# Epoch [86/1500]
# Train Loss: 0.9087, Train Acc: 0.6590
# Val Loss: 1.1459, Val Acc: 0.5877
# --------------------------------------------------
# Epoch [87/1500]
# Train Loss: 0.9064, Train Acc: 0.6608
# Val Loss: 1.1506, Val Acc: 0.5714
# --------------------------------------------------
# Epoch [88/1500]
# Train Loss: 0.8677, Train Acc: 0.6731
# Val Loss: 1.1145, Val Acc: 0.5974
# --------------------------------------------------
# Epoch [89/1500]
# Train Loss: 0.9371, Train Acc: 0.6484
# Val Loss: 1.1526, Val Acc: 0.6104
# --------------------------------------------------
# Epoch [90/1500]
# Train Loss: 0.9055, Train Acc: 0.6696
# Val Loss: 1.1099, Val Acc: 0.5812
# --------------------------------------------------
# Epoch [91/1500]
# Train Loss: 0.9075, Train Acc: 0.6625
# Val Loss: 1.1085, Val Acc: 0.5974
# --------------------------------------------------
# Epoch [92/1500]
# Train Loss: 0.8781, Train Acc: 0.6776
# Val Loss: 1.1086, Val Acc: 0.5974
# --------------------------------------------------
# Epoch [93/1500]
# Train Loss: 0.8861, Train Acc: 0.6608
# Val Loss: 1.1132, Val Acc: 0.5942
# --------------------------------------------------
# Epoch [94/1500]
# Train Loss: 0.8941, Train Acc: 0.6873
# Val Loss: 1.1068, Val Acc: 0.6201
# --------------------------------------------------
# Epoch [95/1500]
# Train Loss: 0.8818, Train Acc: 0.6802
# Val Loss: 1.0803, Val Acc: 0.6006
# --------------------------------------------------
# Epoch [96/1500]
# Train Loss: 0.8455, Train Acc: 0.6820
# Val Loss: 1.0665, Val Acc: 0.6104
# --------------------------------------------------
# Epoch [97/1500]
# Train Loss: 0.8545, Train Acc: 0.6864
# Val Loss: 1.0650, Val Acc: 0.6201
# --------------------------------------------------
# Epoch [98/1500]
# Train Loss: 0.8722, Train Acc: 0.6740
# Val Loss: 1.1047, Val Acc: 0.5974
# --------------------------------------------------
# Epoch [99/1500]
# Train Loss: 0.7885, Train Acc: 0.7005
# Val Loss: 1.1529, Val Acc: 0.5812
# --------------------------------------------------
# Epoch [100/1500]
# Train Loss: 0.8401, Train Acc: 0.6864
# Val Loss: 1.1008, Val Acc: 0.6071
# --------------------------------------------------
# Epoch [101/1500]
# Train Loss: 0.8009, Train Acc: 0.7102
# Val Loss: 1.0666, Val Acc: 0.6429
# --------------------------------------------------
# Epoch [102/1500]
# Train Loss: 0.8242, Train Acc: 0.6846
# Val Loss: 1.0617, Val Acc: 0.6234
# --------------------------------------------------
# Epoch [103/1500]
# Train Loss: 0.7825, Train Acc: 0.7129
# Val Loss: 1.1024, Val Acc: 0.6136
# --------------------------------------------------
# Epoch [104/1500]
# Train Loss: 0.7789, Train Acc: 0.7182
# Val Loss: 1.0258, Val Acc: 0.6396
# --------------------------------------------------
# Epoch [105/1500]
# Train Loss: 0.7887, Train Acc: 0.7067
# Val Loss: 1.1089, Val Acc: 0.6169
# --------------------------------------------------
# Epoch [106/1500]
# Train Loss: 0.7706, Train Acc: 0.7147
# Val Loss: 1.1009, Val Acc: 0.6201
# --------------------------------------------------
# Epoch [107/1500]
# Train Loss: 0.7590, Train Acc: 0.7297
# Val Loss: 1.0860, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [108/1500]
# Train Loss: 0.7463, Train Acc: 0.7049
# Val Loss: 1.1038, Val Acc: 0.6234
# --------------------------------------------------
# Epoch [109/1500]
# Train Loss: 0.7229, Train Acc: 0.7359
# Val Loss: 1.0479, Val Acc: 0.6234
# --------------------------------------------------
# Epoch [110/1500]
# Train Loss: 0.7602, Train Acc: 0.7147
# Val Loss: 1.0875, Val Acc: 0.6234
# --------------------------------------------------
# Epoch [111/1500]
# Train Loss: 0.7786, Train Acc: 0.7279
# Val Loss: 1.0701, Val Acc: 0.6234
# --------------------------------------------------
# Epoch [112/1500]
# Train Loss: 0.7465, Train Acc: 0.7306
# Val Loss: 1.0904, Val Acc: 0.6071
# --------------------------------------------------
# Epoch [113/1500]
# Train Loss: 0.7492, Train Acc: 0.7191
# Val Loss: 1.0857, Val Acc: 0.6169
# --------------------------------------------------
# Epoch [114/1500]
# Train Loss: 0.7480, Train Acc: 0.7341
# Val Loss: 1.0489, Val Acc: 0.6623
# --------------------------------------------------
# Epoch [115/1500]
# Train Loss: 0.7089, Train Acc: 0.7253
# Val Loss: 1.0553, Val Acc: 0.6266
# --------------------------------------------------
# Epoch [116/1500]
# Train Loss: 0.7301, Train Acc: 0.7297
# Val Loss: 1.1027, Val Acc: 0.6364
# --------------------------------------------------
# Epoch [117/1500]
# Train Loss: 0.7493, Train Acc: 0.7191
# Val Loss: 1.0843, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [118/1500]
# Train Loss: 0.7192, Train Acc: 0.7394
# Val Loss: 1.1029, Val Acc: 0.6169
# --------------------------------------------------
# Epoch [119/1500]
# Train Loss: 0.6944, Train Acc: 0.7544
# Val Loss: 1.0244, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [120/1500]
# Train Loss: 0.7219, Train Acc: 0.7297
# Val Loss: 1.0419, Val Acc: 0.6364
# --------------------------------------------------
# Epoch [121/1500]
# Train Loss: 0.6654, Train Acc: 0.7588
# Val Loss: 1.0389, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [122/1500]
# Train Loss: 0.7218, Train Acc: 0.7350
# Val Loss: 1.0903, Val Acc: 0.6299
# --------------------------------------------------
# Epoch [123/1500]
# Train Loss: 0.6993, Train Acc: 0.7456
# Val Loss: 1.0389, Val Acc: 0.6461
# --------------------------------------------------
# Epoch [124/1500]
# Train Loss: 0.6841, Train Acc: 0.7403
# Val Loss: 1.0174, Val Acc: 0.6558
# --------------------------------------------------
# Epoch [125/1500]
# Train Loss: 0.6401, Train Acc: 0.7703
# Val Loss: 1.0657, Val Acc: 0.6364
# --------------------------------------------------
# Epoch [126/1500]
# Train Loss: 0.6618, Train Acc: 0.7509
# Val Loss: 1.0727, Val Acc: 0.6364
# --------------------------------------------------
# Epoch [127/1500]
# Train Loss: 0.6075, Train Acc: 0.7845
# Val Loss: 1.0680, Val Acc: 0.6461
# --------------------------------------------------
# Epoch [128/1500]
# Train Loss: 0.6288, Train Acc: 0.7650
# Val Loss: 1.0593, Val Acc: 0.6494
# --------------------------------------------------
# Epoch [129/1500]
# Train Loss: 0.6305, Train Acc: 0.7527
# Val Loss: 1.0459, Val Acc: 0.6558
# --------------------------------------------------
# Epoch [130/1500]
# Train Loss: 0.6152, Train Acc: 0.7580
# Val Loss: 1.1066, Val Acc: 0.6396
# --------------------------------------------------
# Epoch [131/1500]
# Train Loss: 0.6319, Train Acc: 0.7562
# Val Loss: 1.0491, Val Acc: 0.6494
# --------------------------------------------------
# Epoch [132/1500]
# Train Loss: 0.6435, Train Acc: 0.7544
# Val Loss: 1.0131, Val Acc: 0.6591
# --------------------------------------------------
# Epoch [133/1500]
# Train Loss: 0.6078, Train Acc: 0.7712
# Val Loss: 1.0393, Val Acc: 0.6429
# --------------------------------------------------
# Epoch [134/1500]
# Train Loss: 0.5898, Train Acc: 0.7995
# Val Loss: 1.0720, Val Acc: 0.6201
# --------------------------------------------------
# Epoch [135/1500]
# Train Loss: 0.6255, Train Acc: 0.7756
# Val Loss: 1.0423, Val Acc: 0.6429
# --------------------------------------------------
# Epoch [136/1500]
# Train Loss: 0.6445, Train Acc: 0.7633
# Val Loss: 1.0019, Val Acc: 0.6461
# --------------------------------------------------
# Epoch [137/1500]
# Train Loss: 0.6102, Train Acc: 0.7818
# Val Loss: 0.9984, Val Acc: 0.6396
# --------------------------------------------------
# Epoch [138/1500]
# Train Loss: 0.6356, Train Acc: 0.7880
# Val Loss: 1.0030, Val Acc: 0.6429
# --------------------------------------------------
# Epoch [139/1500]
# Train Loss: 0.6010, Train Acc: 0.7906
# Val Loss: 1.0083, Val Acc: 0.6461
# --------------------------------------------------
# Epoch [140/1500]
# Train Loss: 0.6365, Train Acc: 0.7668
# Val Loss: 1.0335, Val Acc: 0.6688
# --------------------------------------------------
# Epoch [141/1500]
# Train Loss: 0.6434, Train Acc: 0.7721
# Val Loss: 1.0107, Val Acc: 0.6494
# --------------------------------------------------
# Epoch [142/1500]
# Train Loss: 0.6152, Train Acc: 0.7800
# Val Loss: 1.0282, Val Acc: 0.6623
# --------------------------------------------------
# Epoch [143/1500]
# Train Loss: 0.5553, Train Acc: 0.8030
# Val Loss: 1.0749, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [144/1500]
# Train Loss: 0.6168, Train Acc: 0.7703
# Val Loss: 0.9948, Val Acc: 0.6558
# --------------------------------------------------
# Epoch [145/1500]
# Train Loss: 0.6174, Train Acc: 0.7756
# Val Loss: 0.9822, Val Acc: 0.6688
# --------------------------------------------------
# Epoch [146/1500]
# Train Loss: 0.6070, Train Acc: 0.7747
# Val Loss: 1.0861, Val Acc: 0.6558
# --------------------------------------------------
# Epoch [147/1500]
# Train Loss: 0.6013, Train Acc: 0.7721
# Val Loss: 0.9905, Val Acc: 0.6526
# --------------------------------------------------
# Epoch [148/1500]
# Train Loss: 0.5837, Train Acc: 0.7880
# Val Loss: 0.9754, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [149/1500]
# Train Loss: 0.5732, Train Acc: 0.7898
# Val Loss: 1.0028, Val Acc: 0.6623
# --------------------------------------------------
# Epoch [150/1500]
# Train Loss: 0.5703, Train Acc: 0.7986
# Val Loss: 1.0565, Val Acc: 0.6494
# --------------------------------------------------
# Epoch [151/1500]
# Train Loss: 0.5614, Train Acc: 0.8012
# Val Loss: 1.0220, Val Acc: 0.6623
# --------------------------------------------------
# Epoch [152/1500]
# Train Loss: 0.5612, Train Acc: 0.8101
# Val Loss: 1.0186, Val Acc: 0.6721
# --------------------------------------------------
# Epoch [153/1500]
# Train Loss: 0.5376, Train Acc: 0.8145
# Val Loss: 1.0248, Val Acc: 0.6786
# --------------------------------------------------
# Epoch [154/1500]
# Train Loss: 0.5302, Train Acc: 0.8207
# Val Loss: 1.0321, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [155/1500]
# Train Loss: 0.5243, Train Acc: 0.8145
# Val Loss: 1.0008, Val Acc: 0.6721
# --------------------------------------------------
# Epoch [156/1500]
# Train Loss: 0.5723, Train Acc: 0.7739
# Val Loss: 1.0249, Val Acc: 0.6786
# --------------------------------------------------
# Epoch [157/1500]
# Train Loss: 0.5134, Train Acc: 0.8101
# Val Loss: 1.0455, Val Acc: 0.6786
# --------------------------------------------------
# Epoch [158/1500]
# Train Loss: 0.5118, Train Acc: 0.8163
# Val Loss: 1.0246, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [159/1500]
# Train Loss: 0.5048, Train Acc: 0.8251
# Val Loss: 1.0057, Val Acc: 0.6786
# --------------------------------------------------
# Epoch [160/1500]
# Train Loss: 0.5450, Train Acc: 0.8110
# Val Loss: 0.9967, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [161/1500]
# Train Loss: 0.5600, Train Acc: 0.8083
# Val Loss: 1.0080, Val Acc: 0.6688
# --------------------------------------------------
# Epoch [162/1500]
# Train Loss: 0.5041, Train Acc: 0.8224
# Val Loss: 1.0204, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [163/1500]
# Train Loss: 0.5337, Train Acc: 0.7995
# Val Loss: 1.0341, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [164/1500]
# Train Loss: 0.5058, Train Acc: 0.8118
# Val Loss: 1.0106, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [165/1500]
# Train Loss: 0.5163, Train Acc: 0.8216
# Val Loss: 1.0010, Val Acc: 0.6851
# --------------------------------------------------
# Epoch [166/1500]
# Train Loss: 0.4638, Train Acc: 0.8410
# Val Loss: 0.9909, Val Acc: 0.6786
# --------------------------------------------------
# Epoch [167/1500]
# Train Loss: 0.4827, Train Acc: 0.8295
# Val Loss: 1.0093, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [168/1500]
# Train Loss: 0.4937, Train Acc: 0.8295
# Val Loss: 1.0441, Val Acc: 0.6688
# --------------------------------------------------
# Epoch [169/1500]
# Train Loss: 0.4524, Train Acc: 0.8286
# Val Loss: 1.0677, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [170/1500]
# Train Loss: 0.4427, Train Acc: 0.8330
# Val Loss: 1.0545, Val Acc: 0.6851
# --------------------------------------------------
# Epoch [171/1500]
# Train Loss: 0.4841, Train Acc: 0.8313
# Val Loss: 1.0626, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [172/1500]
# Train Loss: 0.4445, Train Acc: 0.8392
# Val Loss: 1.0622, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [173/1500]
# Train Loss: 0.4829, Train Acc: 0.8339
# Val Loss: 1.0718, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [174/1500]
# Train Loss: 0.4561, Train Acc: 0.8348
# Val Loss: 1.0528, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [175/1500]
# Train Loss: 0.4575, Train Acc: 0.8348
# Val Loss: 1.0309, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [176/1500]
# Train Loss: 0.5021, Train Acc: 0.8171
# Val Loss: 1.0190, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [177/1500]
# Train Loss: 0.4446, Train Acc: 0.8322
# Val Loss: 1.0091, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [178/1500]
# Train Loss: 0.4470, Train Acc: 0.8322
# Val Loss: 0.9934, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [179/1500]
# Train Loss: 0.4395, Train Acc: 0.8348
# Val Loss: 1.0386, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [180/1500]
# Train Loss: 0.4249, Train Acc: 0.8569
# Val Loss: 1.0009, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [181/1500]
# Train Loss: 0.4505, Train Acc: 0.8322
# Val Loss: 0.9636, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [182/1500]
# Train Loss: 0.4181, Train Acc: 0.8472
# Val Loss: 0.9977, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [183/1500]
# Train Loss: 0.4362, Train Acc: 0.8401
# Val Loss: 1.0330, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [184/1500]
# Train Loss: 0.4254, Train Acc: 0.8578
# Val Loss: 1.0312, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [185/1500]
# Train Loss: 0.4336, Train Acc: 0.8375
# Val Loss: 1.0242, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [186/1500]
# Train Loss: 0.3996, Train Acc: 0.8551
# Val Loss: 1.0637, Val Acc: 0.6786
# --------------------------------------------------
# Epoch [187/1500]
# Train Loss: 0.4755, Train Acc: 0.8242
# Val Loss: 1.0648, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [188/1500]
# Train Loss: 0.4563, Train Acc: 0.8392
# Val Loss: 1.0375, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [189/1500]
# Train Loss: 0.4255, Train Acc: 0.8322
# Val Loss: 1.0214, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [190/1500]
# Train Loss: 0.4802, Train Acc: 0.8313
# Val Loss: 1.0484, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [191/1500]
# Train Loss: 0.4226, Train Acc: 0.8436
# Val Loss: 1.0172, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [192/1500]
# Train Loss: 0.4381, Train Acc: 0.8401
# Val Loss: 0.9753, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [193/1500]
# Train Loss: 0.3947, Train Acc: 0.8534
# Val Loss: 1.0057, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [194/1500]
# Train Loss: 0.4485, Train Acc: 0.8542
# Val Loss: 1.0086, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [195/1500]
# Train Loss: 0.3728, Train Acc: 0.8631
# Val Loss: 1.0150, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [196/1500]
# Train Loss: 0.4018, Train Acc: 0.8595
# Val Loss: 1.0148, Val Acc: 0.6721
# --------------------------------------------------
# Epoch [197/1500]
# Train Loss: 0.3996, Train Acc: 0.8578
# Val Loss: 1.0407, Val Acc: 0.6786
# --------------------------------------------------
# Epoch [198/1500]
# Train Loss: 0.4272, Train Acc: 0.8516
# Val Loss: 1.0192, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [199/1500]
# Train Loss: 0.4047, Train Acc: 0.8701
# Val Loss: 1.0132, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [200/1500]
# Train Loss: 0.3839, Train Acc: 0.8657
# Val Loss: 0.9840, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [201/1500]
# Train Loss: 0.3691, Train Acc: 0.8781
# Val Loss: 0.9983, Val Acc: 0.6786
# --------------------------------------------------
# Epoch [202/1500]
# Train Loss: 0.3840, Train Acc: 0.8604
# Val Loss: 1.0323, Val Acc: 0.6688
# --------------------------------------------------
# Epoch [203/1500]
# Train Loss: 0.3720, Train Acc: 0.8675
# Val Loss: 1.0170, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [204/1500]
# Train Loss: 0.3906, Train Acc: 0.8542
# Val Loss: 1.0707, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [205/1500]
# Train Loss: 0.3726, Train Acc: 0.8693
# Val Loss: 1.0887, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [206/1500]
# Train Loss: 0.4051, Train Acc: 0.8560
# Val Loss: 1.0423, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [207/1500]
# Train Loss: 0.4057, Train Acc: 0.8604
# Val Loss: 1.0203, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [208/1500]
# Train Loss: 0.3918, Train Acc: 0.8587
# Val Loss: 0.9962, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [209/1500]
# Train Loss: 0.4130, Train Acc: 0.8481
# Val Loss: 1.0051, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [210/1500]
# Train Loss: 0.3849, Train Acc: 0.8489
# Val Loss: 1.0780, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [211/1500]
# Train Loss: 0.3852, Train Acc: 0.8640
# Val Loss: 1.0694, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [212/1500]
# Train Loss: 0.3440, Train Acc: 0.8790
# Val Loss: 1.0258, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [213/1500]
# Train Loss: 0.3916, Train Acc: 0.8693
# Val Loss: 1.0588, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [214/1500]
# Train Loss: 0.3810, Train Acc: 0.8604
# Val Loss: 1.0404, Val Acc: 0.6851
# --------------------------------------------------
# Epoch [215/1500]
# Train Loss: 0.3631, Train Acc: 0.8772
# Val Loss: 1.0301, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [216/1500]
# Train Loss: 0.3477, Train Acc: 0.8640
# Val Loss: 1.0785, Val Acc: 0.6851
# --------------------------------------------------
# Epoch [217/1500]
# Train Loss: 0.3580, Train Acc: 0.8781
# Val Loss: 1.0535, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [218/1500]
# Train Loss: 0.3605, Train Acc: 0.8825
# Val Loss: 1.0469, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [219/1500]
# Train Loss: 0.3928, Train Acc: 0.8701
# Val Loss: 1.1112, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [220/1500]
# Train Loss: 0.3327, Train Acc: 0.8887
# Val Loss: 1.0528, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [221/1500]
# Train Loss: 0.3830, Train Acc: 0.8728
# Val Loss: 1.0502, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [222/1500]
# Train Loss: 0.3330, Train Acc: 0.8905
# Val Loss: 1.0720, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [223/1500]
# Train Loss: 0.3437, Train Acc: 0.8640
# Val Loss: 1.0925, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [224/1500]
# Train Loss: 0.3323, Train Acc: 0.8737
# Val Loss: 1.1488, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [225/1500]
# Train Loss: 0.3190, Train Acc: 0.8905
# Val Loss: 1.0440, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [226/1500]
# Train Loss: 0.3475, Train Acc: 0.8719
# Val Loss: 0.9869, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [227/1500]
# Train Loss: 0.3232, Train Acc: 0.8931
# Val Loss: 1.0269, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [228/1500]
# Train Loss: 0.3109, Train Acc: 0.8931
# Val Loss: 1.0634, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [229/1500]
# Train Loss: 0.3350, Train Acc: 0.8896
# Val Loss: 1.0737, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [230/1500]
# Train Loss: 0.3460, Train Acc: 0.8790
# Val Loss: 1.0302, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [231/1500]
# Train Loss: 0.3214, Train Acc: 0.8878
# Val Loss: 0.9861, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [232/1500]
# Train Loss: 0.3105, Train Acc: 0.8896
# Val Loss: 0.9857, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [233/1500]
# Train Loss: 0.3328, Train Acc: 0.8816
# Val Loss: 1.0401, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [234/1500]
# Train Loss: 0.3191, Train Acc: 0.8878
# Val Loss: 1.1247, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [235/1500]
# Train Loss: 0.3291, Train Acc: 0.8975
# Val Loss: 1.0640, Val Acc: 0.6851
# --------------------------------------------------
# Epoch [236/1500]
# Train Loss: 0.3132, Train Acc: 0.8843
# Val Loss: 1.0426, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [237/1500]
# Train Loss: 0.3509, Train Acc: 0.8781
# Val Loss: 1.0454, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [238/1500]
# Train Loss: 0.3021, Train Acc: 0.8922
# Val Loss: 1.0253, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [239/1500]
# Train Loss: 0.2844, Train Acc: 0.8993
# Val Loss: 1.0271, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [240/1500]
# Train Loss: 0.3269, Train Acc: 0.8966
# Val Loss: 1.0373, Val Acc: 0.6688
# --------------------------------------------------
# Epoch [241/1500]
# Train Loss: 0.2645, Train Acc: 0.9072
# Val Loss: 1.0355, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [242/1500]
# Train Loss: 0.2678, Train Acc: 0.9055
# Val Loss: 1.0450, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [243/1500]
# Train Loss: 0.2647, Train Acc: 0.9099
# Val Loss: 1.0308, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [244/1500]
# Train Loss: 0.2929, Train Acc: 0.8993
# Val Loss: 1.0052, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [245/1500]
# Train Loss: 0.3086, Train Acc: 0.8825
# Val Loss: 1.0552, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [246/1500]
# Train Loss: 0.3090, Train Acc: 0.8896
# Val Loss: 1.1206, Val Acc: 0.6429
# --------------------------------------------------
# Epoch [247/1500]
# Train Loss: 0.3175, Train Acc: 0.8852
# Val Loss: 1.0782, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [248/1500]
# Train Loss: 0.3175, Train Acc: 0.8896
# Val Loss: 1.0969, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [249/1500]
# Train Loss: 0.2884, Train Acc: 0.9081
# Val Loss: 1.1119, Val Acc: 0.6688
# --------------------------------------------------
# Epoch [250/1500]
# Train Loss: 0.3109, Train Acc: 0.8993
# Val Loss: 1.0890, Val Acc: 0.6688
# --------------------------------------------------
# Epoch [251/1500]
# Train Loss: 0.3374, Train Acc: 0.8878
# Val Loss: 1.1002, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [252/1500]
# Train Loss: 0.3079, Train Acc: 0.8958
# Val Loss: 1.1035, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [253/1500]
# Train Loss: 0.2724, Train Acc: 0.9046
# Val Loss: 1.0843, Val Acc: 0.6721
# --------------------------------------------------
# Epoch [254/1500]
# Train Loss: 0.2698, Train Acc: 0.9019
# Val Loss: 0.9965, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [255/1500]
# Train Loss: 0.2909, Train Acc: 0.8887
# Val Loss: 1.0077, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [256/1500]
# Train Loss: 0.2948, Train Acc: 0.9037
# Val Loss: 1.0467, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [257/1500]
# Train Loss: 0.2705, Train Acc: 0.9055
# Val Loss: 1.0898, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [258/1500]
# Train Loss: 0.2947, Train Acc: 0.9099
# Val Loss: 1.0316, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [259/1500]
# Train Loss: 0.2855, Train Acc: 0.8993
# Val Loss: 1.0481, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [260/1500]
# Train Loss: 0.2693, Train Acc: 0.9037
# Val Loss: 1.0548, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [261/1500]
# Train Loss: 0.2780, Train Acc: 0.9108
# Val Loss: 1.0467, Val Acc: 0.6851
# --------------------------------------------------
# Epoch [262/1500]
# Train Loss: 0.2467, Train Acc: 0.9249
# Val Loss: 1.0351, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [263/1500]
# Train Loss: 0.2931, Train Acc: 0.9019
# Val Loss: 1.0806, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [264/1500]
# Train Loss: 0.2726, Train Acc: 0.9108
# Val Loss: 1.1062, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [265/1500]
# Train Loss: 0.2357, Train Acc: 0.9284
# Val Loss: 1.0664, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [266/1500]
# Train Loss: 0.2934, Train Acc: 0.8922
# Val Loss: 1.0621, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [267/1500]
# Train Loss: 0.2988, Train Acc: 0.9072
# Val Loss: 1.0424, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [268/1500]
# Train Loss: 0.2846, Train Acc: 0.9019
# Val Loss: 1.0569, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [269/1500]
# Train Loss: 0.2623, Train Acc: 0.9117
# Val Loss: 1.0995, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [270/1500]
# Train Loss: 0.2640, Train Acc: 0.9064
# Val Loss: 1.0426, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [271/1500]
# Train Loss: 0.2520, Train Acc: 0.9108
# Val Loss: 1.0135, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [272/1500]
# Train Loss: 0.2638, Train Acc: 0.9117
# Val Loss: 1.0833, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [273/1500]
# Train Loss: 0.2468, Train Acc: 0.9125
# Val Loss: 1.0844, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [274/1500]
# Train Loss: 0.2219, Train Acc: 0.9178
# Val Loss: 1.1166, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [275/1500]
# Train Loss: 0.2376, Train Acc: 0.9143
# Val Loss: 1.1420, Val Acc: 0.6818
# --------------------------------------------------
# Epoch [276/1500]
# Train Loss: 0.2291, Train Acc: 0.9143
# Val Loss: 1.1618, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [277/1500]
# Train Loss: 0.2354, Train Acc: 0.9108
# Val Loss: 1.1188, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [278/1500]
# Train Loss: 0.2321, Train Acc: 0.9249
# Val Loss: 1.0548, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [279/1500]
# Train Loss: 0.2461, Train Acc: 0.9170
# Val Loss: 1.0543, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [280/1500]
# Train Loss: 0.2743, Train Acc: 0.9019
# Val Loss: 1.0598, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [281/1500]
# Train Loss: 0.2607, Train Acc: 0.9152
# Val Loss: 1.0957, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [282/1500]
# Train Loss: 0.2126, Train Acc: 0.9302
# Val Loss: 1.0707, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [283/1500]
# Train Loss: 0.2413, Train Acc: 0.9178
# Val Loss: 1.0643, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [284/1500]
# Train Loss: 0.2670, Train Acc: 0.9046
# Val Loss: 1.0546, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [285/1500]
# Train Loss: 0.2744, Train Acc: 0.9117
# Val Loss: 1.1103, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [286/1500]
# Train Loss: 0.2278, Train Acc: 0.9161
# Val Loss: 1.1087, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [287/1500]
# Train Loss: 0.2472, Train Acc: 0.9134
# Val Loss: 1.0972, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [288/1500]
# Train Loss: 0.2509, Train Acc: 0.9134
# Val Loss: 1.0816, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [289/1500]
# Train Loss: 0.2394, Train Acc: 0.9187
# Val Loss: 1.0336, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [290/1500]
# Train Loss: 0.2391, Train Acc: 0.9187
# Val Loss: 1.0290, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [291/1500]
# Train Loss: 0.2414, Train Acc: 0.9214
# Val Loss: 1.0667, Val Acc: 0.6851
# --------------------------------------------------
# Epoch [292/1500]
# Train Loss: 0.2345, Train Acc: 0.9143
# Val Loss: 1.0542, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [293/1500]
# Train Loss: 0.2369, Train Acc: 0.9178
# Val Loss: 1.0715, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [294/1500]
# Train Loss: 0.2296, Train Acc: 0.9258
# Val Loss: 1.0840, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [295/1500]
# Train Loss: 0.2449, Train Acc: 0.9090
# Val Loss: 1.0704, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [296/1500]
# Train Loss: 0.2117, Train Acc: 0.9187
# Val Loss: 1.0760, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [297/1500]
# Train Loss: 0.2130, Train Acc: 0.9205
# Val Loss: 1.1007, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [298/1500]
# Train Loss: 0.2160, Train Acc: 0.9258
# Val Loss: 1.0877, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [299/1500]
# Train Loss: 0.1979, Train Acc: 0.9364
# Val Loss: 1.0657, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [300/1500]
# Train Loss: 0.1907, Train Acc: 0.9382
# Val Loss: 1.1476, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [301/1500]
# Train Loss: 0.2203, Train Acc: 0.9293
# Val Loss: 1.1730, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [302/1500]
# Train Loss: 0.2166, Train Acc: 0.9382
# Val Loss: 1.1131, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [303/1500]
# Train Loss: 0.2124, Train Acc: 0.9267
# Val Loss: 1.1267, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [304/1500]
# Train Loss: 0.2241, Train Acc: 0.9223
# Val Loss: 1.1718, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [305/1500]
# Train Loss: 0.2092, Train Acc: 0.9293
# Val Loss: 1.1958, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [306/1500]
# Train Loss: 0.2429, Train Acc: 0.9231
# Val Loss: 1.1596, Val Acc: 0.6851
# --------------------------------------------------
# Epoch [307/1500]
# Train Loss: 0.2187, Train Acc: 0.9205
# Val Loss: 1.1303, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [308/1500]
# Train Loss: 0.2046, Train Acc: 0.9284
# Val Loss: 1.0938, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [309/1500]
# Train Loss: 0.2152, Train Acc: 0.9170
# Val Loss: 1.0583, Val Acc: 0.7305
# --------------------------------------------------
# Epoch [310/1500]
# Train Loss: 0.1920, Train Acc: 0.9364
# Val Loss: 1.0793, Val Acc: 0.7273
# --------------------------------------------------
# Epoch [311/1500]
# Train Loss: 0.2152, Train Acc: 0.9249
# Val Loss: 1.1343, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [312/1500]
# Train Loss: 0.2203, Train Acc: 0.9267
# Val Loss: 1.1263, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [313/1500]
# Train Loss: 0.2060, Train Acc: 0.9337
# Val Loss: 1.0904, Val Acc: 0.7370
# --------------------------------------------------
# Epoch [314/1500]
# Train Loss: 0.2263, Train Acc: 0.9205
# Val Loss: 1.1317, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [315/1500]
# Train Loss: 0.2039, Train Acc: 0.9337
# Val Loss: 1.0966, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [316/1500]
# Train Loss: 0.2125, Train Acc: 0.9170
# Val Loss: 1.0302, Val Acc: 0.7305
# --------------------------------------------------
# Epoch [317/1500]
# Train Loss: 0.2110, Train Acc: 0.9205
# Val Loss: 1.0408, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [318/1500]
# Train Loss: 0.1943, Train Acc: 0.9426
# Val Loss: 1.0528, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [319/1500]
# Train Loss: 0.2045, Train Acc: 0.9276
# Val Loss: 1.1186, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [320/1500]
# Train Loss: 0.1976, Train Acc: 0.9337
# Val Loss: 1.1023, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [321/1500]
# Train Loss: 0.1876, Train Acc: 0.9443
# Val Loss: 1.0703, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [322/1500]
# Train Loss: 0.1938, Train Acc: 0.9426
# Val Loss: 1.0942, Val Acc: 0.7273
# --------------------------------------------------
# Epoch [323/1500]
# Train Loss: 0.2097, Train Acc: 0.9223
# Val Loss: 1.1431, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [324/1500]
# Train Loss: 0.2121, Train Acc: 0.9293
# Val Loss: 1.1702, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [325/1500]
# Train Loss: 0.2087, Train Acc: 0.9276
# Val Loss: 1.2213, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [326/1500]
# Train Loss: 0.1894, Train Acc: 0.9355
# Val Loss: 1.1920, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [327/1500]
# Train Loss: 0.1907, Train Acc: 0.9355
# Val Loss: 1.1241, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [328/1500]
# Train Loss: 0.2061, Train Acc: 0.9293
# Val Loss: 1.0814, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [329/1500]
# Train Loss: 0.2165, Train Acc: 0.9284
# Val Loss: 1.1546, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [330/1500]
# Train Loss: 0.2192, Train Acc: 0.9408
# Val Loss: 1.1798, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [331/1500]
# Train Loss: 0.1555, Train Acc: 0.9549
# Val Loss: 1.1223, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [332/1500]
# Train Loss: 0.2081, Train Acc: 0.9337
# Val Loss: 1.1205, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [333/1500]
# Train Loss: 0.2175, Train Acc: 0.9249
# Val Loss: 1.0767, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [334/1500]
# Train Loss: 0.2118, Train Acc: 0.9267
# Val Loss: 1.1055, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [335/1500]
# Train Loss: 0.2309, Train Acc: 0.9161
# Val Loss: 1.0616, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [336/1500]
# Train Loss: 0.2099, Train Acc: 0.9417
# Val Loss: 1.1155, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [337/1500]
# Train Loss: 0.2210, Train Acc: 0.9223
# Val Loss: 1.1605, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [338/1500]
# Train Loss: 0.2000, Train Acc: 0.9311
# Val Loss: 1.1770, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [339/1500]
# Train Loss: 0.2066, Train Acc: 0.9293
# Val Loss: 1.1981, Val Acc: 0.6948
# --------------------------------------------------
# Epoch [340/1500]
# Train Loss: 0.2022, Train Acc: 0.9249
# Val Loss: 1.1313, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [341/1500]
# Train Loss: 0.1755, Train Acc: 0.9390
# Val Loss: 1.1202, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [342/1500]
# Train Loss: 0.2035, Train Acc: 0.9311
# Val Loss: 1.1591, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [343/1500]
# Train Loss: 0.1905, Train Acc: 0.9302
# Val Loss: 1.1695, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [344/1500]
# Train Loss: 0.1759, Train Acc: 0.9346
# ...
# --------------------------------------------------
# Epoch [1388/1500]
# Train Loss: 0.0334, Train Acc: 0.9867
# Val Loss: 1.5875, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [1389/1500]
# Train Loss: 0.0323, Train Acc: 0.9903
# Val Loss: 1.5770, Val Acc: 0.7013
# --------------------------------------------------
# Epoch [1390/1500]
# Train Loss: 0.0282, Train Acc: 0.9885
# Val Loss: 1.5526, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1391/1500]
# Train Loss: 0.0222, Train Acc: 0.9903
# Val Loss: 1.5622, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1392/1500]
# Train Loss: 0.0268, Train Acc: 0.9947
# Val Loss: 1.5152, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [1393/1500]
# Train Loss: 0.0261, Train Acc: 0.9912
# Val Loss: 1.4581, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [1394/1500]
# Train Loss: 0.0270, Train Acc: 0.9920
# Val Loss: 1.5102, Val Acc: 0.6688
# --------------------------------------------------
# Epoch [1395/1500]
# Train Loss: 0.0575, Train Acc: 0.9814
# Val Loss: 1.4948, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [1396/1500]
# Train Loss: 0.0271, Train Acc: 0.9903
# Val Loss: 1.5259, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [1397/1500]
# Train Loss: 0.0317, Train Acc: 0.9903
# Val Loss: 1.5151, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [1398/1500]
# Train Loss: 0.0397, Train Acc: 0.9867
# Val Loss: 1.5090, Val Acc: 0.7305
# --------------------------------------------------
# Epoch [1399/1500]
# Train Loss: 0.0305, Train Acc: 0.9859
# Val Loss: 1.4722, Val Acc: 0.7370
# --------------------------------------------------
# Epoch [1400/1500]
# Train Loss: 0.0323, Train Acc: 0.9876
# Val Loss: 1.4505, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [1401/1500]
# Train Loss: 0.0300, Train Acc: 0.9903
# Val Loss: 1.5025, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [1402/1500]
# Train Loss: 0.0357, Train Acc: 0.9885
# Val Loss: 1.5444, Val Acc: 0.7273
# --------------------------------------------------
# Epoch [1403/1500]
# Train Loss: 0.0442, Train Acc: 0.9867
# Val Loss: 1.5272, Val Acc: 0.7305
# --------------------------------------------------
# Epoch [1404/1500]
# Train Loss: 0.0219, Train Acc: 0.9912
# Val Loss: 1.5384, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [1405/1500]
# Train Loss: 0.0333, Train Acc: 0.9929
# Val Loss: 1.5908, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [1406/1500]
# Train Loss: 0.0273, Train Acc: 0.9920
# Val Loss: 1.6293, Val Acc: 0.6883
# --------------------------------------------------
# Epoch [1407/1500]
# Train Loss: 0.0262, Train Acc: 0.9912
# Val Loss: 1.5841, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [1408/1500]
# Train Loss: 0.0353, Train Acc: 0.9859
# Val Loss: 1.5358, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [1409/1500]
# Train Loss: 0.0379, Train Acc: 0.9876
# Val Loss: 1.4934, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [1410/1500]
# Train Loss: 0.0331, Train Acc: 0.9894
# Val Loss: 1.4484, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [1411/1500]
# Train Loss: 0.0397, Train Acc: 0.9850
# Val Loss: 1.4044, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [1412/1500]
# Train Loss: 0.0400, Train Acc: 0.9867
# Val Loss: 1.4031, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [1413/1500]
# Train Loss: 0.0268, Train Acc: 0.9920
# Val Loss: 1.4200, Val Acc: 0.7370
# --------------------------------------------------
# Epoch [1414/1500]
# Train Loss: 0.0272, Train Acc: 0.9903
# Val Loss: 1.4355, Val Acc: 0.7305
# --------------------------------------------------
# Epoch [1415/1500]
# Train Loss: 0.0209, Train Acc: 0.9956
# Val Loss: 1.4106, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1416/1500]
# Train Loss: 0.0282, Train Acc: 0.9885
# Val Loss: 1.4087, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [1417/1500]
# Train Loss: 0.0351, Train Acc: 0.9885
# Val Loss: 1.4320, Val Acc: 0.7273
# --------------------------------------------------
# Epoch [1418/1500]
# Train Loss: 0.0371, Train Acc: 0.9876
# Val Loss: 1.4343, Val Acc: 0.7370
# --------------------------------------------------
# Epoch [1419/1500]
# Train Loss: 0.0438, Train Acc: 0.9867
# Val Loss: 1.4413, Val Acc: 0.7273
# --------------------------------------------------
# Epoch [1420/1500]
# Train Loss: 0.0284, Train Acc: 0.9885
# Val Loss: 1.5154, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1421/1500]
# Train Loss: 0.0315, Train Acc: 0.9929
# Val Loss: 1.5252, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [1422/1500]
# Train Loss: 0.0539, Train Acc: 0.9867
# Val Loss: 1.5635, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [1423/1500]
# Train Loss: 0.0345, Train Acc: 0.9859
# Val Loss: 1.5412, Val Acc: 0.6851
# --------------------------------------------------
# Epoch [1424/1500]
# Train Loss: 0.0370, Train Acc: 0.9859
# Val Loss: 1.4182, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [1425/1500]
# Train Loss: 0.0454, Train Acc: 0.9841
# Val Loss: 1.3985, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [1426/1500]
# Train Loss: 0.0386, Train Acc: 0.9903
# Val Loss: 1.3644, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [1427/1500]
# Train Loss: 0.0519, Train Acc: 0.9859
# Val Loss: 1.3669, Val Acc: 0.7338
# --------------------------------------------------
# Epoch [1428/1500]
# Train Loss: 0.0374, Train Acc: 0.9885
# Val Loss: 1.4155, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [1429/1500]
# Train Loss: 0.0489, Train Acc: 0.9841
# Val Loss: 1.4024, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [1430/1500]
# Train Loss: 0.0354, Train Acc: 0.9903
# Val Loss: 1.4208, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [1431/1500]
# Train Loss: 0.0366, Train Acc: 0.9859
# Val Loss: 1.3622, Val Acc: 0.7305
# --------------------------------------------------
# Epoch [1432/1500]
# Train Loss: 0.0315, Train Acc: 0.9912
# Val Loss: 1.3221, Val Acc: 0.7305
# --------------------------------------------------
# Epoch [1433/1500]
# Train Loss: 0.0375, Train Acc: 0.9876
# Val Loss: 1.3387, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [1434/1500]
# Train Loss: 0.0521, Train Acc: 0.9797
# Val Loss: 1.3651, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [1435/1500]
# Train Loss: 0.0385, Train Acc: 0.9876
# Val Loss: 1.3784, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [1436/1500]
# Train Loss: 0.0249, Train Acc: 0.9938
# Val Loss: 1.3753, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [1437/1500]
# Train Loss: 0.0426, Train Acc: 0.9867
# Val Loss: 1.4095, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [1438/1500]
# Train Loss: 0.0207, Train Acc: 0.9947
# Val Loss: 1.4723, Val Acc: 0.6916
# --------------------------------------------------
# Epoch [1439/1500]
# Train Loss: 0.0241, Train Acc: 0.9894
# Val Loss: 1.5052, Val Acc: 0.7370
# --------------------------------------------------
# Epoch [1440/1500]
# Train Loss: 0.0322, Train Acc: 0.9912
# Val Loss: 1.5239, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1441/1500]
# Train Loss: 0.0181, Train Acc: 0.9956
# Val Loss: 1.5037, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [1442/1500]
# Train Loss: 0.0307, Train Acc: 0.9912
# Val Loss: 1.4660, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1443/1500]
# Train Loss: 0.0320, Train Acc: 0.9938
# Val Loss: 1.4599, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [1444/1500]
# Train Loss: 0.0200, Train Acc: 0.9912
# Val Loss: 1.4915, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [1445/1500]
# Train Loss: 0.0281, Train Acc: 0.9859
# Val Loss: 1.4812, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [1446/1500]
# Train Loss: 0.0234, Train Acc: 0.9912
# Val Loss: 1.4424, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [1447/1500]
# Train Loss: 0.0292, Train Acc: 0.9920
# Val Loss: 1.4461, Val Acc: 0.7370
# --------------------------------------------------
# Epoch [1448/1500]
# Train Loss: 0.0222, Train Acc: 0.9938
# Val Loss: 1.4241, Val Acc: 0.7273
# --------------------------------------------------
# Epoch [1449/1500]
# Train Loss: 0.0198, Train Acc: 0.9929
# Val Loss: 1.4183, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1450/1500]
# Train Loss: 0.0321, Train Acc: 0.9859
# Val Loss: 1.4143, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [1451/1500]
# Train Loss: 0.0309, Train Acc: 0.9885
# Val Loss: 1.4571, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [1452/1500]
# Train Loss: 0.0246, Train Acc: 0.9903
# Val Loss: 1.4901, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [1453/1500]
# Train Loss: 0.0249, Train Acc: 0.9912
# Val Loss: 1.5136, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [1454/1500]
# Train Loss: 0.0356, Train Acc: 0.9867
# Val Loss: 1.5159, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [1455/1500]
# Train Loss: 0.0432, Train Acc: 0.9876
# Val Loss: 1.4884, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [1456/1500]
# Train Loss: 0.0218, Train Acc: 0.9947
# Val Loss: 1.4723, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1457/1500]
# Train Loss: 0.0319, Train Acc: 0.9885
# Val Loss: 1.4332, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1458/1500]
# Train Loss: 0.0367, Train Acc: 0.9885
# Val Loss: 1.3860, Val Acc: 0.7338
# --------------------------------------------------
# Epoch [1459/1500]
# Train Loss: 0.0413, Train Acc: 0.9859
# Val Loss: 1.3334, Val Acc: 0.7370
# --------------------------------------------------
# Epoch [1460/1500]
# Train Loss: 0.0357, Train Acc: 0.9876
# Val Loss: 1.3834, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1461/1500]
# Train Loss: 0.0316, Train Acc: 0.9920
# Val Loss: 1.4267, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1462/1500]
# Train Loss: 0.0393, Train Acc: 0.9903
# Val Loss: 1.4786, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [1463/1500]
# Train Loss: 0.0390, Train Acc: 0.9867
# Val Loss: 1.5558, Val Acc: 0.6981
# --------------------------------------------------
# Epoch [1464/1500]
# Train Loss: 0.0277, Train Acc: 0.9903
# Val Loss: 1.5367, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [1465/1500]
# Train Loss: 0.0240, Train Acc: 0.9938
# Val Loss: 1.4671, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1466/1500]
# Train Loss: 0.0417, Train Acc: 0.9894
# Val Loss: 1.4095, Val Acc: 0.7273
# --------------------------------------------------
# Epoch [1467/1500]
# Train Loss: 0.0316, Train Acc: 0.9903
# Val Loss: 1.3886, Val Acc: 0.7045
# --------------------------------------------------
# Epoch [1468/1500]
# Train Loss: 0.0396, Train Acc: 0.9885
# Val Loss: 1.4344, Val Acc: 0.7078
# --------------------------------------------------
# Epoch [1469/1500]
# Train Loss: 0.0482, Train Acc: 0.9876
# Val Loss: 1.3924, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1470/1500]
# Train Loss: 0.0475, Train Acc: 0.9841
# Val Loss: 1.3717, Val Acc: 0.7403
# --------------------------------------------------
# Epoch [1471/1500]
# Train Loss: 0.0498, Train Acc: 0.9867
# Val Loss: 1.3144, Val Acc: 0.7370
# --------------------------------------------------
# Epoch [1472/1500]
# Train Loss: 0.0355, Train Acc: 0.9850
# Val Loss: 1.2900, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1473/1500]
# Train Loss: 0.0342, Train Acc: 0.9894
# Val Loss: 1.3281, Val Acc: 0.7273
# --------------------------------------------------
# Epoch [1474/1500]
# Train Loss: 0.0374, Train Acc: 0.9912
# Val Loss: 1.3496, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [1475/1500]
# Train Loss: 0.0204, Train Acc: 0.9938
# Val Loss: 1.3922, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [1476/1500]
# Train Loss: 0.0335, Train Acc: 0.9876
# Val Loss: 1.4082, Val Acc: 0.7403
# --------------------------------------------------
# Epoch [1477/1500]
# Train Loss: 0.0228, Train Acc: 0.9929
# Val Loss: 1.4193, Val Acc: 0.7305
# --------------------------------------------------
# Epoch [1478/1500]
# Train Loss: 0.0477, Train Acc: 0.9841
# Val Loss: 1.4047, Val Acc: 0.7468
# --------------------------------------------------
# Epoch [1479/1500]
# Train Loss: 0.0338, Train Acc: 0.9867
# Val Loss: 1.4020, Val Acc: 0.7338
# --------------------------------------------------
# Epoch [1480/1500]
# Train Loss: 0.0342, Train Acc: 0.9903
# Val Loss: 1.3879, Val Acc: 0.7403
# --------------------------------------------------
# Epoch [1481/1500]
# Train Loss: 0.0342, Train Acc: 0.9850
# Val Loss: 1.4006, Val Acc: 0.7468
# --------------------------------------------------
# Epoch [1482/1500]
# Train Loss: 0.0364, Train Acc: 0.9876
# Val Loss: 1.4570, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [1483/1500]
# Train Loss: 0.0252, Train Acc: 0.9947
# Val Loss: 1.4833, Val Acc: 0.7305
# --------------------------------------------------
# Epoch [1484/1500]
# Train Loss: 0.0418, Train Acc: 0.9885
# Val Loss: 1.4790, Val Acc: 0.7338
# --------------------------------------------------
# Epoch [1485/1500]
# Train Loss: 0.0423, Train Acc: 0.9885
# Val Loss: 1.4265, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [1486/1500]
# Train Loss: 0.0364, Train Acc: 0.9894
# Val Loss: 1.4003, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [1487/1500]
# Train Loss: 0.0320, Train Acc: 0.9894
# Val Loss: 1.4136, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [1488/1500]
# Train Loss: 0.0487, Train Acc: 0.9876
# Val Loss: 1.3750, Val Acc: 0.7175
# --------------------------------------------------
# Epoch [1489/1500]
# Train Loss: 0.0293, Train Acc: 0.9929
# Val Loss: 1.3921, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [1490/1500]
# Train Loss: 0.0449, Train Acc: 0.9867
# Val Loss: 1.4015, Val Acc: 0.7143
# --------------------------------------------------
# Epoch [1491/1500]
# Train Loss: 0.0335, Train Acc: 0.9867
# Val Loss: 1.4157, Val Acc: 0.7273
# --------------------------------------------------
# Epoch [1492/1500]
# Train Loss: 0.0423, Train Acc: 0.9841
# Val Loss: 1.4225, Val Acc: 0.7208
# --------------------------------------------------
# Epoch [1493/1500]
# Train Loss: 0.0440, Train Acc: 0.9832
# Val Loss: 1.3414, Val Acc: 0.7403
# --------------------------------------------------
# Epoch [1494/1500]
# Train Loss: 0.0335, Train Acc: 0.9885
# Val Loss: 1.2536, Val Acc: 0.7403
# --------------------------------------------------
# Epoch [1495/1500]
# Train Loss: 0.0367, Train Acc: 0.9850
# Val Loss: 1.2388, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [1496/1500]
# Train Loss: 0.0424, Train Acc: 0.9894
# Val Loss: 1.2949, Val Acc: 0.7403
# --------------------------------------------------
# Epoch [1497/1500]
# Train Loss: 0.0334, Train Acc: 0.9894
# Val Loss: 1.4012, Val Acc: 0.7305
# --------------------------------------------------
# Epoch [1498/1500]
# Train Loss: 0.0371, Train Acc: 0.9894
# Val Loss: 1.4262, Val Acc: 0.7110
# --------------------------------------------------
# Epoch [1499/1500]
# Train Loss: 0.0298, Train Acc: 0.9876
# Val Loss: 1.3331, Val Acc: 0.7240
# --------------------------------------------------
# Epoch [1500/1500]
# Train Loss: 0.0418, Train Acc: 0.9841
# Val Loss: 1.2667, Val Acc: 0.7240
# --------------------------------------------------

# %%
torch.save(model.state_dict(), "C:/Nini/Capstone/Models/cnn_model_pytorch.pth")
