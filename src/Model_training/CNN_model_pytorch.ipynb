# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle

# %%
features = pd.read_csv("C:/Nini/Capstone/CSV_Files/ravdess_extracted_features_mel_mfcc_chroma.csv")
features = features.drop(features.columns[0], axis=1)
temp = shuffle(features)
df = np.random.rand(len(temp)) < 0.8
train = temp[df]
test = temp[~df]

# %%
X_train = np.array(train.iloc[:,:-1])
y_train = np.array(train.iloc[:,-1])
X_test = np.array(test.iloc[:,:-1])
y_test = np.array(test.iloc[:,-1])

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
batch_size = 256
train_loader = DataLoader(TensorDataset(X_train,y_train), batch_size=batch_size,shuffle=True)
test_loader = DataLoader(TensorDataset(X_test,y_test), batch_size=batch_size, shuffle=False)

# %%
class CNNModel(nn.Module):
    def __init__(self, input_size, num_classes):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=10)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=10)
        self.bn2 = nn.BatchNorm1d(128)
        self.pool1 = nn.MaxPool1d(kernel_size=8, padding=3)
        self.dropout1 = nn.Dropout(0.5)
        self.conv3 = nn.Conv1d(128, 128, kernel_size=10)
        self.bn3 = nn.BatchNorm1d(128)
        self.pool2 = nn.MaxPool1d(kernel_size=8, padding=3)
        self.dropout2 = nn.Dropout(0.5)
        self.conv4 = nn.Conv1d(128, 64, kernel_size=5, padding=2)
        self.bn4 = nn.BatchNorm1d(64)
        self.fc1 = nn.Linear(64, 256)
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, num_classes)

    # def _compute_flattened_size(self, input_size):
    #     with torch.no_grad():
    #         x = torch.randn(1, 1, input_size)  # Create a dummy input
    #         x = self.conv1(x)
    #         x = F.relu(x)
    #         x = self.conv2(x)
    #         x = F.relu(x)
    #         x = self.pool1(x)
    #         x = self.dropout1(x)
    #         x = self.conv3(x)
    #         x = F.relu(x)
    #         x = self.pool2(x)
    #         x = self.dropout2(x)
    #         x = self.conv4(x)
    #         x = F.relu(x)
    #         x = x.view(1, -1)  # Flatten
    #         self._to_linear = x.shape[1]

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNModel(input_size=X_train.shape[1], num_classes=8).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=1e-4)

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: torch.Size([1162, 1, 153])

# %%
epochs = 1500
for epoch in range(epochs):
    model.train()
    running_loss = 0
    total_loss = 0
    total = 0
    correct = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)
    train_accuracy = correct / total
    avg_train_loss = running_loss / len(train_loader)
        # total_loss += loss.item()
        # correct += (outputs.argmax(dim=1) == y_batch).sum().item()
    model.eval()  # Set model to evaluation mode
    val_correct = 0
    val_total = 0
    val_loss = 0.0

    with torch.no_grad():  # Disable gradient computation for validation
        for val_inputs, val_labels in test_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)

            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()

            _, val_predicted = torch.max(val_outputs, 1)
            val_correct += (val_predicted == val_labels).sum().item()
            val_total += val_labels.size(0)
    
    val_accuracy = val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)
    # accuracy = correct / len(train_loader.dataset)
    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    print("-" * 50)
# Out:
# Epoch [1/1500]
# Train Loss: 2.0596, Train Acc: 0.1661
# Val Loss: 2.0642, Val Acc: 0.1619
# --------------------------------------------------
# Epoch [2/1500]
# Train Loss: 1.9832, Train Acc: 0.2435
# Val Loss: 2.0425, Val Acc: 0.2302
# --------------------------------------------------
# Epoch [3/1500]
# Train Loss: 1.9380, Train Acc: 0.2642
# Val Loss: 2.0050, Val Acc: 0.2194
# --------------------------------------------------
# Epoch [4/1500]
# Train Loss: 1.9130, Train Acc: 0.2668
# Val Loss: 1.9719, Val Acc: 0.2194
# --------------------------------------------------
# Epoch [5/1500]
# Train Loss: 1.8843, Train Acc: 0.2745
# Val Loss: 1.9489, Val Acc: 0.2266
# --------------------------------------------------
# Epoch [6/1500]
# Train Loss: 1.8574, Train Acc: 0.2625
# Val Loss: 1.9333, Val Acc: 0.2410
# --------------------------------------------------
# Epoch [7/1500]
# Train Loss: 1.8528, Train Acc: 0.2685
# Val Loss: 1.9194, Val Acc: 0.2518
# --------------------------------------------------
# Epoch [8/1500]
# Train Loss: 1.8394, Train Acc: 0.2590
# Val Loss: 1.9066, Val Acc: 0.2662
# --------------------------------------------------
# Epoch [9/1500]
# Train Loss: 1.8149, Train Acc: 0.2685
# Val Loss: 1.8928, Val Acc: 0.2446
# --------------------------------------------------
# Epoch [10/1500]
# Train Loss: 1.7997, Train Acc: 0.2831
# Val Loss: 1.8757, Val Acc: 0.2626
# --------------------------------------------------
# Epoch [11/1500]
# Train Loss: 1.7778, Train Acc: 0.2926
# Val Loss: 1.8551, Val Acc: 0.2626
# --------------------------------------------------
# Epoch [12/1500]
# Train Loss: 1.7395, Train Acc: 0.3029
# Val Loss: 1.8579, Val Acc: 0.2662
# --------------------------------------------------
# Epoch [13/1500]
# Train Loss: 1.7426, Train Acc: 0.3021
# Val Loss: 1.8083, Val Acc: 0.2842
# --------------------------------------------------
# Epoch [14/1500]
# Train Loss: 1.7314, Train Acc: 0.3176
# Val Loss: 1.8325, Val Acc: 0.2950
# --------------------------------------------------
# Epoch [15/1500]
# Train Loss: 1.7103, Train Acc: 0.3176
# Val Loss: 1.7793, Val Acc: 0.3058
# --------------------------------------------------
# Epoch [16/1500]
# Train Loss: 1.7347, Train Acc: 0.3133
# Val Loss: 1.8048, Val Acc: 0.2986
# --------------------------------------------------
# Epoch [17/1500]
# Train Loss: 1.6945, Train Acc: 0.3158
# Val Loss: 1.7795, Val Acc: 0.3165
# --------------------------------------------------
# Epoch [18/1500]
# Train Loss: 1.6993, Train Acc: 0.3227
# Val Loss: 1.7685, Val Acc: 0.3058
# --------------------------------------------------
# Epoch [19/1500]
# Train Loss: 1.6743, Train Acc: 0.3348
# Val Loss: 1.7412, Val Acc: 0.3489
# --------------------------------------------------
# Epoch [20/1500]
# Train Loss: 1.6680, Train Acc: 0.3623
# Val Loss: 1.7655, Val Acc: 0.3201
# --------------------------------------------------
# Epoch [21/1500]
# Train Loss: 1.6333, Train Acc: 0.3442
# Val Loss: 1.7172, Val Acc: 0.3489
# --------------------------------------------------
# Epoch [22/1500]
# Train Loss: 1.6285, Train Acc: 0.3511
# Val Loss: 1.7574, Val Acc: 0.3561
# --------------------------------------------------
# Epoch [23/1500]
# Train Loss: 1.6362, Train Acc: 0.3632
# Val Loss: 1.7128, Val Acc: 0.3417
# --------------------------------------------------
# Epoch [24/1500]
# Train Loss: 1.6336, Train Acc: 0.3563
# Val Loss: 1.7269, Val Acc: 0.3381
# --------------------------------------------------
# Epoch [25/1500]
# Train Loss: 1.6350, Train Acc: 0.3752
# Val Loss: 1.7281, Val Acc: 0.3381
# --------------------------------------------------
# Epoch [26/1500]
# Train Loss: 1.6081, Train Acc: 0.3657
# Val Loss: 1.6893, Val Acc: 0.3669
# --------------------------------------------------
# Epoch [27/1500]
# Train Loss: 1.6091, Train Acc: 0.3554
# Val Loss: 1.7097, Val Acc: 0.3633
# --------------------------------------------------
# Epoch [28/1500]
# Train Loss: 1.6046, Train Acc: 0.3812
# Val Loss: 1.6930, Val Acc: 0.3597
# --------------------------------------------------
# Epoch [29/1500]
# Train Loss: 1.5968, Train Acc: 0.3761
# Val Loss: 1.6942, Val Acc: 0.3525
# --------------------------------------------------
# Epoch [30/1500]
# Train Loss: 1.5597, Train Acc: 0.3907
# Val Loss: 1.6765, Val Acc: 0.3561
# --------------------------------------------------
# Epoch [31/1500]
# Train Loss: 1.6009, Train Acc: 0.3795
# Val Loss: 1.6674, Val Acc: 0.3777
# --------------------------------------------------
# Epoch [32/1500]
# Train Loss: 1.5677, Train Acc: 0.3924
# Val Loss: 1.6881, Val Acc: 0.3705
# --------------------------------------------------
# Epoch [33/1500]
# Train Loss: 1.5676, Train Acc: 0.3985
# Val Loss: 1.6725, Val Acc: 0.3669
# --------------------------------------------------
# Epoch [34/1500]
# Train Loss: 1.5532, Train Acc: 0.3881
# Val Loss: 1.6318, Val Acc: 0.3849
# --------------------------------------------------
# Epoch [35/1500]
# Train Loss: 1.5194, Train Acc: 0.4053
# Val Loss: 1.6908, Val Acc: 0.3741
# --------------------------------------------------
# Epoch [36/1500]
# Train Loss: 1.5396, Train Acc: 0.4053
# Val Loss: 1.6681, Val Acc: 0.3921
# --------------------------------------------------
# Epoch [37/1500]
# Train Loss: 1.5468, Train Acc: 0.3890
# Val Loss: 1.6877, Val Acc: 0.4029
# --------------------------------------------------
# Epoch [38/1500]
# Train Loss: 1.5233, Train Acc: 0.4053
# Val Loss: 1.6530, Val Acc: 0.3957
# --------------------------------------------------
# Epoch [39/1500]
# Train Loss: 1.5307, Train Acc: 0.4079
# Val Loss: 1.6174, Val Acc: 0.4137
# --------------------------------------------------
# Epoch [40/1500]
# Train Loss: 1.4899, Train Acc: 0.4148
# Val Loss: 1.6609, Val Acc: 0.4029
# --------------------------------------------------
# Epoch [41/1500]
# Train Loss: 1.4847, Train Acc: 0.4148
# Val Loss: 1.6225, Val Acc: 0.3813
# --------------------------------------------------
# Epoch [42/1500]
# Train Loss: 1.4876, Train Acc: 0.4148
# Val Loss: 1.6343, Val Acc: 0.4029
# --------------------------------------------------
# Epoch [43/1500]
# Train Loss: 1.4748, Train Acc: 0.4208
# Val Loss: 1.6158, Val Acc: 0.4029
# --------------------------------------------------
# Epoch [44/1500]
# Train Loss: 1.4756, Train Acc: 0.4251
# Val Loss: 1.5904, Val Acc: 0.4209
# --------------------------------------------------
# Epoch [45/1500]
# Train Loss: 1.4603, Train Acc: 0.4389
# Val Loss: 1.5656, Val Acc: 0.4209
# --------------------------------------------------
# Epoch [46/1500]
# Train Loss: 1.4609, Train Acc: 0.4415
# Val Loss: 1.5659, Val Acc: 0.4209
# --------------------------------------------------
# Epoch [47/1500]
# Train Loss: 1.4654, Train Acc: 0.4363
# Val Loss: 1.5587, Val Acc: 0.4317
# --------------------------------------------------
# Epoch [48/1500]
# Train Loss: 1.4141, Train Acc: 0.4578
# Val Loss: 1.6046, Val Acc: 0.4496
# --------------------------------------------------
# Epoch [49/1500]
# Train Loss: 1.4379, Train Acc: 0.4380
# Val Loss: 1.6298, Val Acc: 0.4317
# --------------------------------------------------
# Epoch [50/1500]
# Train Loss: 1.4307, Train Acc: 0.4613
# Val Loss: 1.5452, Val Acc: 0.4353
# --------------------------------------------------
# Epoch [51/1500]
# Train Loss: 1.4080, Train Acc: 0.4527
# Val Loss: 1.5065, Val Acc: 0.4317
# --------------------------------------------------
# Epoch [52/1500]
# Train Loss: 1.4217, Train Acc: 0.4544
# Val Loss: 1.5173, Val Acc: 0.4209
# --------------------------------------------------
# Epoch [53/1500]
# Train Loss: 1.4098, Train Acc: 0.4604
# Val Loss: 1.4842, Val Acc: 0.4317
# --------------------------------------------------
# Epoch [54/1500]
# Train Loss: 1.4257, Train Acc: 0.4570
# Val Loss: 1.5318, Val Acc: 0.4604
# --------------------------------------------------
# Epoch [55/1500]
# Train Loss: 1.3744, Train Acc: 0.4621
# Val Loss: 1.4772, Val Acc: 0.4353
# --------------------------------------------------
# Epoch [56/1500]
# Train Loss: 1.3605, Train Acc: 0.4673
# Val Loss: 1.4994, Val Acc: 0.4424
# --------------------------------------------------
# Epoch [57/1500]
# Train Loss: 1.3512, Train Acc: 0.4983
# Val Loss: 1.5167, Val Acc: 0.4604
# --------------------------------------------------
# Epoch [58/1500]
# Train Loss: 1.3388, Train Acc: 0.4897
# Val Loss: 1.4760, Val Acc: 0.4424
# --------------------------------------------------
# Epoch [59/1500]
# Train Loss: 1.3298, Train Acc: 0.4819
# Val Loss: 1.4740, Val Acc: 0.4532
# --------------------------------------------------
# Epoch [60/1500]
# Train Loss: 1.3511, Train Acc: 0.4836
# Val Loss: 1.4811, Val Acc: 0.4460
# --------------------------------------------------
# Epoch [61/1500]
# Train Loss: 1.3190, Train Acc: 0.5112
# Val Loss: 1.4757, Val Acc: 0.4640
# --------------------------------------------------
# Epoch [62/1500]
# Train Loss: 1.3134, Train Acc: 0.4940
# Val Loss: 1.4456, Val Acc: 0.4604
# --------------------------------------------------
# Epoch [63/1500]
# Train Loss: 1.3301, Train Acc: 0.4905
# Val Loss: 1.4204, Val Acc: 0.4640
# --------------------------------------------------
# Epoch [64/1500]
# Train Loss: 1.3009, Train Acc: 0.5138
# Val Loss: 1.4316, Val Acc: 0.4388
# --------------------------------------------------
# Epoch [65/1500]
# Train Loss: 1.2690, Train Acc: 0.5026
# Val Loss: 1.4021, Val Acc: 0.4892
# --------------------------------------------------
# Epoch [66/1500]
# Train Loss: 1.2768, Train Acc: 0.5095
# Val Loss: 1.4481, Val Acc: 0.4712
# --------------------------------------------------
# Epoch [67/1500]
# Train Loss: 1.2615, Train Acc: 0.5207
# Val Loss: 1.3964, Val Acc: 0.4820
# --------------------------------------------------
# Epoch [68/1500]
# Train Loss: 1.2568, Train Acc: 0.5215
# Val Loss: 1.4089, Val Acc: 0.4928
# --------------------------------------------------
# Epoch [69/1500]
# Train Loss: 1.2841, Train Acc: 0.5164
# Val Loss: 1.4113, Val Acc: 0.4856
# --------------------------------------------------
# Epoch [70/1500]
# Train Loss: 1.2309, Train Acc: 0.5284
# Val Loss: 1.4133, Val Acc: 0.4676
# --------------------------------------------------
# Epoch [71/1500]
# Train Loss: 1.2654, Train Acc: 0.5310
# Val Loss: 1.4143, Val Acc: 0.4604
# --------------------------------------------------
# Epoch [72/1500]
# Train Loss: 1.2388, Train Acc: 0.5181
# Val Loss: 1.3600, Val Acc: 0.4568
# --------------------------------------------------
# Epoch [73/1500]
# Train Loss: 1.1909, Train Acc: 0.5551
# Val Loss: 1.3408, Val Acc: 0.5036
# --------------------------------------------------
# Epoch [74/1500]
# Train Loss: 1.2360, Train Acc: 0.5361
# Val Loss: 1.3263, Val Acc: 0.4964
# --------------------------------------------------
# Epoch [75/1500]
# Train Loss: 1.2046, Train Acc: 0.5404
# Val Loss: 1.3368, Val Acc: 0.4892
# --------------------------------------------------
# Epoch [76/1500]
# Train Loss: 1.1744, Train Acc: 0.5628
# Val Loss: 1.3383, Val Acc: 0.5288
# --------------------------------------------------
# Epoch [77/1500]
# Train Loss: 1.1740, Train Acc: 0.5542
# Val Loss: 1.3632, Val Acc: 0.5252
# --------------------------------------------------
# Epoch [78/1500]
# Train Loss: 1.1830, Train Acc: 0.5508
# Val Loss: 1.3114, Val Acc: 0.5216
# --------------------------------------------------
# Epoch [79/1500]
# Train Loss: 1.1481, Train Acc: 0.5645
# Val Loss: 1.3977, Val Acc: 0.5144
# --------------------------------------------------
# Epoch [80/1500]
# Train Loss: 1.2182, Train Acc: 0.5465
# Val Loss: 1.2765, Val Acc: 0.5108
# --------------------------------------------------
# Epoch [81/1500]
# Train Loss: 1.1871, Train Acc: 0.5448
# Val Loss: 1.3056, Val Acc: 0.5108
# --------------------------------------------------
# Epoch [82/1500]
# Train Loss: 1.1672, Train Acc: 0.5611
# Val Loss: 1.2995, Val Acc: 0.5252
# --------------------------------------------------
# Epoch [83/1500]
# Train Loss: 1.1711, Train Acc: 0.5551
# Val Loss: 1.2980, Val Acc: 0.4964
# --------------------------------------------------
# Epoch [84/1500]
# Train Loss: 1.1148, Train Acc: 0.5947
# Val Loss: 1.2860, Val Acc: 0.5252
# --------------------------------------------------
# Epoch [85/1500]
# Train Loss: 1.1313, Train Acc: 0.5809
# Val Loss: 1.2570, Val Acc: 0.5360
# --------------------------------------------------
# Epoch [86/1500]
# Train Loss: 1.1022, Train Acc: 0.5852
# Val Loss: 1.2519, Val Acc: 0.5540
# --------------------------------------------------
# Epoch [87/1500]
# Train Loss: 1.0994, Train Acc: 0.5981
# Val Loss: 1.2917, Val Acc: 0.5252
# --------------------------------------------------
# Epoch [88/1500]
# Train Loss: 1.1080, Train Acc: 0.5757
# Val Loss: 1.2505, Val Acc: 0.5036
# --------------------------------------------------
# Epoch [89/1500]
# Train Loss: 1.0941, Train Acc: 0.5792
# Val Loss: 1.2691, Val Acc: 0.5144
# --------------------------------------------------
# Epoch [90/1500]
# Train Loss: 1.1071, Train Acc: 0.6145
# Val Loss: 1.2739, Val Acc: 0.5288
# --------------------------------------------------
# Epoch [91/1500]
# Train Loss: 1.0602, Train Acc: 0.6119
# Val Loss: 1.2609, Val Acc: 0.5288
# --------------------------------------------------
# Epoch [92/1500]
# Train Loss: 1.0892, Train Acc: 0.5878
# Val Loss: 1.2921, Val Acc: 0.5360
# --------------------------------------------------
# Epoch [93/1500]
# Train Loss: 1.0944, Train Acc: 0.6015
# Val Loss: 1.2822, Val Acc: 0.5324
# --------------------------------------------------
# Epoch [94/1500]
# Train Loss: 1.0900, Train Acc: 0.6007
# Val Loss: 1.2684, Val Acc: 0.5252
# --------------------------------------------------
# Epoch [95/1500]
# Train Loss: 1.0762, Train Acc: 0.5938
# Val Loss: 1.2460, Val Acc: 0.5432
# --------------------------------------------------
# Epoch [96/1500]
# Train Loss: 1.0751, Train Acc: 0.5861
# Val Loss: 1.2855, Val Acc: 0.5432
# --------------------------------------------------
# Epoch [97/1500]
# Train Loss: 1.0521, Train Acc: 0.6033
# Val Loss: 1.2209, Val Acc: 0.5576
# --------------------------------------------------
# Epoch [98/1500]
# Train Loss: 1.0852, Train Acc: 0.5998
# Val Loss: 1.2572, Val Acc: 0.5540
# --------------------------------------------------
# Epoch [99/1500]
# Train Loss: 1.0377, Train Acc: 0.6093
# Val Loss: 1.2208, Val Acc: 0.5612
# --------------------------------------------------
# Epoch [100/1500]
# Train Loss: 1.0358, Train Acc: 0.6162
# Val Loss: 1.2674, Val Acc: 0.5540
# --------------------------------------------------
# Epoch [101/1500]
# Train Loss: 1.0415, Train Acc: 0.6127
# Val Loss: 1.1857, Val Acc: 0.5612
# --------------------------------------------------
# Epoch [102/1500]
# Train Loss: 1.0027, Train Acc: 0.6248
# Val Loss: 1.2266, Val Acc: 0.5504
# --------------------------------------------------
# Epoch [103/1500]
# Train Loss: 0.9568, Train Acc: 0.6368
# Val Loss: 1.1937, Val Acc: 0.5468
# --------------------------------------------------
# Epoch [104/1500]
# Train Loss: 0.9968, Train Acc: 0.6472
# Val Loss: 1.1743, Val Acc: 0.5576
# --------------------------------------------------
# Epoch [105/1500]
# Train Loss: 0.9569, Train Acc: 0.6403
# Val Loss: 1.1918, Val Acc: 0.5216
# --------------------------------------------------
# Epoch [106/1500]
# Train Loss: 0.9887, Train Acc: 0.6506
# Val Loss: 1.1926, Val Acc: 0.5396
# --------------------------------------------------
# Epoch [107/1500]
# Train Loss: 0.9296, Train Acc: 0.6592
# Val Loss: 1.2065, Val Acc: 0.5576
# --------------------------------------------------
# Epoch [108/1500]
# Train Loss: 0.9425, Train Acc: 0.6480
# Val Loss: 1.1479, Val Acc: 0.5432
# --------------------------------------------------
# Epoch [109/1500]
# Train Loss: 0.9762, Train Acc: 0.6472
# Val Loss: 1.2098, Val Acc: 0.5216
# --------------------------------------------------
# Epoch [110/1500]
# Train Loss: 0.9570, Train Acc: 0.6265
# Val Loss: 1.1955, Val Acc: 0.5288
# --------------------------------------------------
# Epoch [111/1500]
# Train Loss: 0.9450, Train Acc: 0.6601
# Val Loss: 1.3604, Val Acc: 0.5540
# --------------------------------------------------
# Epoch [112/1500]
# Train Loss: 0.9749, Train Acc: 0.6368
# Val Loss: 1.1553, Val Acc: 0.5504
# --------------------------------------------------
# Epoch [113/1500]
# Train Loss: 0.9257, Train Acc: 0.6592
# Val Loss: 1.1718, Val Acc: 0.5863
# --------------------------------------------------
# Epoch [114/1500]
# Train Loss: 0.9447, Train Acc: 0.6566
# Val Loss: 1.1675, Val Acc: 0.5863
# --------------------------------------------------
# Epoch [115/1500]
# Train Loss: 0.9190, Train Acc: 0.6781
# Val Loss: 1.1743, Val Acc: 0.5719
# --------------------------------------------------
# Epoch [116/1500]
# Train Loss: 0.8703, Train Acc: 0.6738
# Val Loss: 1.1992, Val Acc: 0.5576
# --------------------------------------------------
# Epoch [117/1500]
# Train Loss: 0.9070, Train Acc: 0.6583
# Val Loss: 1.1869, Val Acc: 0.5935
# --------------------------------------------------
# Epoch [118/1500]
# Train Loss: 0.8769, Train Acc: 0.6566
# Val Loss: 1.1422, Val Acc: 0.6079
# --------------------------------------------------
# Epoch [119/1500]
# Train Loss: 0.8655, Train Acc: 0.6790
# Val Loss: 1.1922, Val Acc: 0.5863
# --------------------------------------------------
# Epoch [120/1500]
# Train Loss: 0.8872, Train Acc: 0.6824
# Val Loss: 1.1552, Val Acc: 0.5935
# --------------------------------------------------
# Epoch [121/1500]
# Train Loss: 0.9116, Train Acc: 0.6523
# Val Loss: 1.1617, Val Acc: 0.5683
# --------------------------------------------------
# Epoch [122/1500]
# Train Loss: 0.8714, Train Acc: 0.6721
# Val Loss: 1.1083, Val Acc: 0.5612
# --------------------------------------------------
# Epoch [123/1500]
# Train Loss: 0.8790, Train Acc: 0.6661
# Val Loss: 1.1189, Val Acc: 0.5683
# --------------------------------------------------
# Epoch [124/1500]
# Train Loss: 0.9105, Train Acc: 0.6756
# Val Loss: 1.2616, Val Acc: 0.5612
# --------------------------------------------------
# Epoch [125/1500]
# Train Loss: 0.8839, Train Acc: 0.6730
# Val Loss: 1.1347, Val Acc: 0.5899
# --------------------------------------------------
# Epoch [126/1500]
# Train Loss: 0.8276, Train Acc: 0.6816
# Val Loss: 1.1837, Val Acc: 0.5827
# --------------------------------------------------
# Epoch [127/1500]
# Train Loss: 0.7929, Train Acc: 0.7108
# Val Loss: 1.1586, Val Acc: 0.5719
# --------------------------------------------------
# Epoch [128/1500]
# Train Loss: 0.8176, Train Acc: 0.7203
# Val Loss: 1.1468, Val Acc: 0.6007
# --------------------------------------------------
# Epoch [129/1500]
# Train Loss: 0.8356, Train Acc: 0.6730
# Val Loss: 1.1300, Val Acc: 0.5863
# --------------------------------------------------
# Epoch [130/1500]
# Train Loss: 0.8159, Train Acc: 0.6971
# Val Loss: 1.1145, Val Acc: 0.6115
# --------------------------------------------------
# Epoch [131/1500]
# Train Loss: 0.8172, Train Acc: 0.6893
# Val Loss: 1.0911, Val Acc: 0.5791
# --------------------------------------------------
# Epoch [132/1500]
# Train Loss: 0.8018, Train Acc: 0.7091
# Val Loss: 1.1283, Val Acc: 0.5935
# --------------------------------------------------
# Epoch [133/1500]
# Train Loss: 0.8212, Train Acc: 0.6919
# Val Loss: 1.1379, Val Acc: 0.5935
# --------------------------------------------------
# Epoch [134/1500]
# Train Loss: 0.8055, Train Acc: 0.7005
# Val Loss: 1.1705, Val Acc: 0.6187
# --------------------------------------------------
# Epoch [135/1500]
# Train Loss: 0.7949, Train Acc: 0.7203
# Val Loss: 1.1195, Val Acc: 0.5935
# --------------------------------------------------
# Epoch [136/1500]
# Train Loss: 0.8132, Train Acc: 0.7100
# Val Loss: 1.1609, Val Acc: 0.6115
# --------------------------------------------------
# Epoch [137/1500]
# Train Loss: 0.7856, Train Acc: 0.7048
# Val Loss: 1.0767, Val Acc: 0.5935
# --------------------------------------------------
# Epoch [138/1500]
# Train Loss: 0.7972, Train Acc: 0.7065
# Val Loss: 1.0879, Val Acc: 0.5935
# --------------------------------------------------
# Epoch [139/1500]
# Train Loss: 0.7778, Train Acc: 0.7151
# Val Loss: 1.1006, Val Acc: 0.6043
# --------------------------------------------------
# Epoch [140/1500]
# Train Loss: 0.7376, Train Acc: 0.7410
# Val Loss: 1.0864, Val Acc: 0.5971
# --------------------------------------------------
# Epoch [141/1500]
# Train Loss: 0.7807, Train Acc: 0.7169
# Val Loss: 1.0838, Val Acc: 0.6043
# --------------------------------------------------
# Epoch [142/1500]
# Train Loss: 0.7549, Train Acc: 0.7358
# Val Loss: 1.1066, Val Acc: 0.5899
# --------------------------------------------------
# Epoch [143/1500]
# Train Loss: 0.7688, Train Acc: 0.7255
# Val Loss: 1.0636, Val Acc: 0.6079
# --------------------------------------------------
# Epoch [144/1500]
# Train Loss: 0.7326, Train Acc: 0.7272
# Val Loss: 1.1711, Val Acc: 0.6079
# --------------------------------------------------
# Epoch [145/1500]
# Train Loss: 0.7425, Train Acc: 0.7212
# Val Loss: 1.0864, Val Acc: 0.5827
# --------------------------------------------------
# Epoch [146/1500]
# Train Loss: 0.7532, Train Acc: 0.7298
# Val Loss: 1.1224, Val Acc: 0.5827
# --------------------------------------------------
# Epoch [147/1500]
# Train Loss: 0.7337, Train Acc: 0.7349
# Val Loss: 1.1315, Val Acc: 0.6043
# --------------------------------------------------
# Epoch [148/1500]
# Train Loss: 0.7435, Train Acc: 0.7367
# Val Loss: 1.1175, Val Acc: 0.6007
# --------------------------------------------------
# Epoch [149/1500]
# Train Loss: 0.6897, Train Acc: 0.7341
# Val Loss: 1.0731, Val Acc: 0.6151
# --------------------------------------------------
# Epoch [150/1500]
# Train Loss: 0.7655, Train Acc: 0.7238
# Val Loss: 1.0956, Val Acc: 0.5935
# --------------------------------------------------
# Epoch [151/1500]
# Train Loss: 0.7650, Train Acc: 0.7143
# Val Loss: 1.1241, Val Acc: 0.5935
# --------------------------------------------------
# Epoch [152/1500]
# Train Loss: 0.6783, Train Acc: 0.7582
# Val Loss: 1.1473, Val Acc: 0.5719
# --------------------------------------------------
# Epoch [153/1500]
# Train Loss: 0.7477, Train Acc: 0.7246
# Val Loss: 1.0880, Val Acc: 0.6079
# --------------------------------------------------
# Epoch [154/1500]
# Train Loss: 0.6603, Train Acc: 0.7685
# Val Loss: 1.1394, Val Acc: 0.6115
# --------------------------------------------------
# Epoch [155/1500]
# Train Loss: 0.7365, Train Acc: 0.7367
# Val Loss: 1.0529, Val Acc: 0.6223
# --------------------------------------------------
# Epoch [156/1500]
# Train Loss: 0.7296, Train Acc: 0.7427
# Val Loss: 1.0743, Val Acc: 0.6259
# --------------------------------------------------
# Epoch [157/1500]
# Train Loss: 0.7156, Train Acc: 0.7427
# Val Loss: 1.1161, Val Acc: 0.5971
# --------------------------------------------------
# Epoch [158/1500]
# Train Loss: 0.6472, Train Acc: 0.7633
# Val Loss: 1.0393, Val Acc: 0.5935
# --------------------------------------------------
# Epoch [159/1500]
# Train Loss: 0.7069, Train Acc: 0.7341
# Val Loss: 1.1081, Val Acc: 0.6151
# --------------------------------------------------
# Epoch [160/1500]
# Train Loss: 0.6952, Train Acc: 0.7504
# Val Loss: 1.1081, Val Acc: 0.6079
# --------------------------------------------------
# Epoch [161/1500]
# Train Loss: 0.6775, Train Acc: 0.7599
# Val Loss: 1.1308, Val Acc: 0.6187
# --------------------------------------------------
# Epoch [162/1500]
# Train Loss: 0.6822, Train Acc: 0.7573
# Val Loss: 1.0847, Val Acc: 0.6187
# --------------------------------------------------
# Epoch [163/1500]
# Train Loss: 0.6446, Train Acc: 0.7702
# Val Loss: 1.1012, Val Acc: 0.6115
# --------------------------------------------------
# Epoch [164/1500]
# Train Loss: 0.6698, Train Acc: 0.7539
# Val Loss: 1.0553, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [165/1500]
# Train Loss: 0.6630, Train Acc: 0.7530
# Val Loss: 1.0878, Val Acc: 0.6403
# --------------------------------------------------
# Epoch [166/1500]
# Train Loss: 0.6328, Train Acc: 0.7642
# Val Loss: 1.0954, Val Acc: 0.6115
# --------------------------------------------------
# Epoch [167/1500]
# Train Loss: 0.6722, Train Acc: 0.7522
# Val Loss: 1.0979, Val Acc: 0.6079
# --------------------------------------------------
# Epoch [168/1500]
# Train Loss: 0.6568, Train Acc: 0.7590
# Val Loss: 1.0735, Val Acc: 0.6151
# --------------------------------------------------
# Epoch [169/1500]
# Train Loss: 0.6488, Train Acc: 0.7711
# Val Loss: 1.0514, Val Acc: 0.6223
# --------------------------------------------------
# Epoch [170/1500]
# Train Loss: 0.6447, Train Acc: 0.7719
# Val Loss: 1.0970, Val Acc: 0.6295
# --------------------------------------------------
# Epoch [171/1500]
# Train Loss: 0.6213, Train Acc: 0.7797
# Val Loss: 1.0438, Val Acc: 0.6511
# --------------------------------------------------
# Epoch [172/1500]
# Train Loss: 0.6065, Train Acc: 0.7694
# Val Loss: 1.1290, Val Acc: 0.6439
# --------------------------------------------------
# Epoch [173/1500]
# Train Loss: 0.6191, Train Acc: 0.7866
# Val Loss: 1.0586, Val Acc: 0.6439
# --------------------------------------------------
# Epoch [174/1500]
# Train Loss: 0.6148, Train Acc: 0.7892
# Val Loss: 1.0484, Val Acc: 0.6403
# --------------------------------------------------
# Epoch [175/1500]
# Train Loss: 0.6134, Train Acc: 0.7788
# Val Loss: 1.0512, Val Acc: 0.6367
# --------------------------------------------------
# Epoch [176/1500]
# Train Loss: 0.5925, Train Acc: 0.7900
# Val Loss: 1.0130, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [177/1500]
# Train Loss: 0.5961, Train Acc: 0.7960
# Val Loss: 1.0576, Val Acc: 0.6295
# --------------------------------------------------
# Epoch [178/1500]
# Train Loss: 0.5590, Train Acc: 0.7978
# Val Loss: 1.0535, Val Acc: 0.6367
# --------------------------------------------------
# Epoch [179/1500]
# Train Loss: 0.6305, Train Acc: 0.7788
# Val Loss: 1.1146, Val Acc: 0.6259
# --------------------------------------------------
# Epoch [180/1500]
# Train Loss: 0.5613, Train Acc: 0.8012
# Val Loss: 1.0846, Val Acc: 0.6223
# --------------------------------------------------
# Epoch [181/1500]
# Train Loss: 0.5633, Train Acc: 0.8003
# Val Loss: 1.1280, Val Acc: 0.6115
# --------------------------------------------------
# Epoch [182/1500]
# Train Loss: 0.5838, Train Acc: 0.7883
# Val Loss: 1.0332, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [183/1500]
# Train Loss: 0.5598, Train Acc: 0.8055
# Val Loss: 1.0870, Val Acc: 0.6367
# --------------------------------------------------
# Epoch [184/1500]
# Train Loss: 0.5798, Train Acc: 0.7849
# Val Loss: 1.0791, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [185/1500]
# Train Loss: 0.5895, Train Acc: 0.7797
# Val Loss: 1.1102, Val Acc: 0.6367
# --------------------------------------------------
# Epoch [186/1500]
# Train Loss: 0.5666, Train Acc: 0.8012
# Val Loss: 1.0702, Val Acc: 0.6367
# --------------------------------------------------
# Epoch [187/1500]
# Train Loss: 0.5649, Train Acc: 0.7909
# Val Loss: 1.0410, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [188/1500]
# Train Loss: 0.5889, Train Acc: 0.7831
# Val Loss: 1.1723, Val Acc: 0.6403
# --------------------------------------------------
# Epoch [189/1500]
# Train Loss: 0.6036, Train Acc: 0.7840
# Val Loss: 1.0231, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [190/1500]
# Train Loss: 0.5674, Train Acc: 0.7952
# Val Loss: 1.0525, Val Acc: 0.6403
# --------------------------------------------------
# Epoch [191/1500]
# Train Loss: 0.5673, Train Acc: 0.7995
# Val Loss: 1.0543, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [192/1500]
# Train Loss: 0.5441, Train Acc: 0.8055
# Val Loss: 1.1061, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [193/1500]
# Train Loss: 0.5951, Train Acc: 0.7917
# Val Loss: 0.9456, Val Acc: 0.6223
# --------------------------------------------------
# Epoch [194/1500]
# Train Loss: 0.5289, Train Acc: 0.8150
# Val Loss: 1.0544, Val Acc: 0.6223
# --------------------------------------------------
# Epoch [195/1500]
# Train Loss: 0.5631, Train Acc: 0.8046
# Val Loss: 1.0043, Val Acc: 0.6223
# --------------------------------------------------
# Epoch [196/1500]
# Train Loss: 0.5612, Train Acc: 0.8055
# Val Loss: 1.0791, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [197/1500]
# Train Loss: 0.5302, Train Acc: 0.8124
# Val Loss: 1.0801, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [198/1500]
# Train Loss: 0.4994, Train Acc: 0.8193
# Val Loss: 1.0572, Val Acc: 0.6259
# --------------------------------------------------
# Epoch [199/1500]
# Train Loss: 0.5471, Train Acc: 0.8107
# Val Loss: 1.1229, Val Acc: 0.6115
# --------------------------------------------------
# Epoch [200/1500]
# Train Loss: 0.5228, Train Acc: 0.8158
# Val Loss: 1.1325, Val Acc: 0.6403
# --------------------------------------------------
# Epoch [201/1500]
# Train Loss: 0.5121, Train Acc: 0.8072
# Val Loss: 1.1233, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [202/1500]
# Train Loss: 0.5212, Train Acc: 0.8046
# Val Loss: 1.0777, Val Acc: 0.6223
# --------------------------------------------------
# Epoch [203/1500]
# Train Loss: 0.5695, Train Acc: 0.8115
# Val Loss: 1.0855, Val Acc: 0.6079
# --------------------------------------------------
# Epoch [204/1500]
# Train Loss: 0.5223, Train Acc: 0.8081
# Val Loss: 1.0920, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [205/1500]
# Train Loss: 0.5387, Train Acc: 0.8107
# Val Loss: 1.1920, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [206/1500]
# Train Loss: 0.5218, Train Acc: 0.8107
# Val Loss: 1.1314, Val Acc: 0.6295
# --------------------------------------------------
# Epoch [207/1500]
# Train Loss: 0.5292, Train Acc: 0.8210
# Val Loss: 1.0871, Val Acc: 0.6151
# --------------------------------------------------
# Epoch [208/1500]
# Train Loss: 0.5388, Train Acc: 0.8124
# Val Loss: 1.0274, Val Acc: 0.6259
# --------------------------------------------------
# Epoch [209/1500]
# Train Loss: 0.4920, Train Acc: 0.8201
# Val Loss: 1.0470, Val Acc: 0.6403
# --------------------------------------------------
# Epoch [210/1500]
# Train Loss: 0.4997, Train Acc: 0.8167
# Val Loss: 1.0343, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [211/1500]
# Train Loss: 0.4905, Train Acc: 0.8270
# Val Loss: 1.0717, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [212/1500]
# Train Loss: 0.4766, Train Acc: 0.8227
# Val Loss: 0.9819, Val Acc: 0.6511
# --------------------------------------------------
# Epoch [213/1500]
# Train Loss: 0.4853, Train Acc: 0.8236
# Val Loss: 1.0760, Val Acc: 0.6583
# --------------------------------------------------
# Epoch [214/1500]
# Train Loss: 0.4874, Train Acc: 0.8262
# Val Loss: 1.0708, Val Acc: 0.6547
# --------------------------------------------------
# Epoch [215/1500]
# Train Loss: 0.5205, Train Acc: 0.8098
# Val Loss: 1.0289, Val Acc: 0.6547
# --------------------------------------------------
# Epoch [216/1500]
# Train Loss: 0.4926, Train Acc: 0.8339
# Val Loss: 1.1610, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [217/1500]
# Train Loss: 0.4628, Train Acc: 0.8408
# Val Loss: 1.0563, Val Acc: 0.6511
# --------------------------------------------------
# Epoch [218/1500]
# Train Loss: 0.5150, Train Acc: 0.8141
# Val Loss: 1.0644, Val Acc: 0.6439
# --------------------------------------------------
# Epoch [219/1500]
# Train Loss: 0.4855, Train Acc: 0.8373
# Val Loss: 1.0820, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [220/1500]
# Train Loss: 0.4869, Train Acc: 0.8270
# Val Loss: 0.9556, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [221/1500]
# Train Loss: 0.4417, Train Acc: 0.8399
# Val Loss: 1.0167, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [222/1500]
# Train Loss: 0.4590, Train Acc: 0.8339
# Val Loss: 1.0178, Val Acc: 0.6547
# --------------------------------------------------
# Epoch [223/1500]
# Train Loss: 0.4875, Train Acc: 0.8339
# Val Loss: 1.0142, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [224/1500]
# Train Loss: 0.5036, Train Acc: 0.8227
# Val Loss: 1.0934, Val Acc: 0.6439
# --------------------------------------------------
# Epoch [225/1500]
# Train Loss: 0.4410, Train Acc: 0.8511
# Val Loss: 1.0281, Val Acc: 0.6367
# --------------------------------------------------
# Epoch [226/1500]
# Train Loss: 0.4358, Train Acc: 0.8485
# Val Loss: 1.0626, Val Acc: 0.6367
# --------------------------------------------------
# Epoch [227/1500]
# Train Loss: 0.4314, Train Acc: 0.8460
# Val Loss: 1.0813, Val Acc: 0.6583
# --------------------------------------------------
# Epoch [228/1500]
# Train Loss: 0.4446, Train Acc: 0.8477
# Val Loss: 1.0387, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [229/1500]
# Train Loss: 0.4646, Train Acc: 0.8313
# Val Loss: 0.9417, Val Acc: 0.6295
# --------------------------------------------------
# Epoch [230/1500]
# Train Loss: 0.4666, Train Acc: 0.8537
# Val Loss: 1.2549, Val Acc: 0.6547
# --------------------------------------------------
# Epoch [231/1500]
# Train Loss: 0.4951, Train Acc: 0.8287
# Val Loss: 1.0019, Val Acc: 0.6295
# --------------------------------------------------
# Epoch [232/1500]
# Train Loss: 0.4618, Train Acc: 0.8305
# Val Loss: 1.0933, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [233/1500]
# Train Loss: 0.4190, Train Acc: 0.8623
# Val Loss: 1.1111, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [234/1500]
# Train Loss: 0.4279, Train Acc: 0.8494
# Val Loss: 0.9491, Val Acc: 0.6583
# --------------------------------------------------
# Epoch [235/1500]
# Train Loss: 0.4320, Train Acc: 0.8563
# Val Loss: 0.9920, Val Acc: 0.6583
# --------------------------------------------------
# Epoch [236/1500]
# Train Loss: 0.4236, Train Acc: 0.8528
# Val Loss: 0.9769, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [237/1500]
# Train Loss: 0.4061, Train Acc: 0.8528
# Val Loss: 1.1525, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [238/1500]
# Train Loss: 0.4474, Train Acc: 0.8451
# Val Loss: 0.9712, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [239/1500]
# Train Loss: 0.4292, Train Acc: 0.8563
# Val Loss: 1.0437, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [240/1500]
# Train Loss: 0.4238, Train Acc: 0.8451
# Val Loss: 0.9060, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [241/1500]
# Train Loss: 0.4276, Train Acc: 0.8468
# Val Loss: 0.9567, Val Acc: 0.6511
# --------------------------------------------------
# Epoch [242/1500]
# Train Loss: 0.4098, Train Acc: 0.8606
# Val Loss: 0.9274, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [243/1500]
# Train Loss: 0.4089, Train Acc: 0.8666
# Val Loss: 1.1267, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [244/1500]
# Train Loss: 0.4476, Train Acc: 0.8442
# Val Loss: 1.0034, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [245/1500]
# Train Loss: 0.3636, Train Acc: 0.8675
# Val Loss: 1.0215, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [246/1500]
# Train Loss: 0.4124, Train Acc: 0.8563
# Val Loss: 0.9797, Val Acc: 0.6511
# --------------------------------------------------
# Epoch [247/1500]
# Train Loss: 0.3820, Train Acc: 0.8640
# Val Loss: 0.9616, Val Acc: 0.6439
# --------------------------------------------------
# Epoch [248/1500]
# Train Loss: 0.3955, Train Acc: 0.8657
# Val Loss: 1.1072, Val Acc: 0.6403
# --------------------------------------------------
# Epoch [249/1500]
# Train Loss: 0.4240, Train Acc: 0.8589
# Val Loss: 1.0684, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [250/1500]
# Train Loss: 0.3706, Train Acc: 0.8640
# Val Loss: 1.0647, Val Acc: 0.6583
# --------------------------------------------------
# Epoch [251/1500]
# Train Loss: 0.4266, Train Acc: 0.8554
# Val Loss: 1.0128, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [252/1500]
# Train Loss: 0.4234, Train Acc: 0.8503
# Val Loss: 0.9950, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [253/1500]
# Train Loss: 0.4008, Train Acc: 0.8485
# Val Loss: 1.0269, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [254/1500]
# Train Loss: 0.4252, Train Acc: 0.8417
# Val Loss: 1.0226, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [255/1500]
# Train Loss: 0.4031, Train Acc: 0.8649
# Val Loss: 1.0337, Val Acc: 0.6367
# --------------------------------------------------
# Epoch [256/1500]
# Train Loss: 0.3988, Train Acc: 0.8537
# Val Loss: 1.0650, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [257/1500]
# Train Loss: 0.3857, Train Acc: 0.8623
# Val Loss: 1.1301, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [258/1500]
# Train Loss: 0.4010, Train Acc: 0.8546
# Val Loss: 1.0389, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [259/1500]
# Train Loss: 0.3732, Train Acc: 0.8718
# Val Loss: 1.0634, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [260/1500]
# Train Loss: 0.4245, Train Acc: 0.8520
# Val Loss: 0.9868, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [261/1500]
# Train Loss: 0.4143, Train Acc: 0.8571
# Val Loss: 1.0563, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [262/1500]
# Train Loss: 0.3667, Train Acc: 0.8614
# Val Loss: 0.9982, Val Acc: 0.6547
# --------------------------------------------------
# Epoch [263/1500]
# Train Loss: 0.4105, Train Acc: 0.8640
# Val Loss: 1.0266, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [264/1500]
# Train Loss: 0.4091, Train Acc: 0.8468
# Val Loss: 1.1291, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [265/1500]
# Train Loss: 0.3528, Train Acc: 0.8735
# Val Loss: 1.0821, Val Acc: 0.6547
# --------------------------------------------------
# Epoch [266/1500]
# Train Loss: 0.4099, Train Acc: 0.8554
# Val Loss: 1.0001, Val Acc: 0.6295
# --------------------------------------------------
# Epoch [267/1500]
# Train Loss: 0.3522, Train Acc: 0.8744
# Val Loss: 1.1652, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [268/1500]
# Train Loss: 0.3835, Train Acc: 0.8597
# Val Loss: 0.9548, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [269/1500]
# Train Loss: 0.3427, Train Acc: 0.8692
# Val Loss: 0.9346, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [270/1500]
# Train Loss: 0.3474, Train Acc: 0.8735
# Val Loss: 1.0540, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [271/1500]
# Train Loss: 0.3576, Train Acc: 0.8657
# Val Loss: 1.0572, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [272/1500]
# Train Loss: 0.3678, Train Acc: 0.8795
# Val Loss: 1.0718, Val Acc: 0.6403
# --------------------------------------------------
# Epoch [273/1500]
# Train Loss: 0.3662, Train Acc: 0.8838
# Val Loss: 1.0881, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [274/1500]
# Train Loss: 0.3911, Train Acc: 0.8640
# Val Loss: 1.0809, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [275/1500]
# Train Loss: 0.3855, Train Acc: 0.8735
# Val Loss: 0.9381, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [276/1500]
# Train Loss: 0.4124, Train Acc: 0.8546
# Val Loss: 1.0858, Val Acc: 0.6583
# --------------------------------------------------
# Epoch [277/1500]
# Train Loss: 0.3790, Train Acc: 0.8675
# Val Loss: 0.9116, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [278/1500]
# Train Loss: 0.3714, Train Acc: 0.8726
# Val Loss: 0.9223, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [279/1500]
# Train Loss: 0.3537, Train Acc: 0.8795
# Val Loss: 0.9222, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [280/1500]
# Train Loss: 0.3692, Train Acc: 0.8657
# Val Loss: 0.9548, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [281/1500]
# Train Loss: 0.3538, Train Acc: 0.8640
# Val Loss: 0.9987, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [282/1500]
# Train Loss: 0.3552, Train Acc: 0.8812
# Val Loss: 0.9584, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [283/1500]
# Train Loss: 0.3489, Train Acc: 0.8657
# Val Loss: 0.9304, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [284/1500]
# Train Loss: 0.3701, Train Acc: 0.8701
# Val Loss: 0.9408, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [285/1500]
# Train Loss: 0.3021, Train Acc: 0.8838
# Val Loss: 0.9403, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [286/1500]
# Train Loss: 0.3520, Train Acc: 0.8709
# Val Loss: 0.9460, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [287/1500]
# Train Loss: 0.3538, Train Acc: 0.8778
# Val Loss: 1.0355, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [288/1500]
# Train Loss: 0.3445, Train Acc: 0.8692
# Val Loss: 1.0433, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [289/1500]
# Train Loss: 0.3440, Train Acc: 0.8830
# Val Loss: 1.0948, Val Acc: 0.6583
# --------------------------------------------------
# Epoch [290/1500]
# Train Loss: 0.3282, Train Acc: 0.8804
# Val Loss: 0.9923, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [291/1500]
# Train Loss: 0.3243, Train Acc: 0.8864
# Val Loss: 1.0820, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [292/1500]
# Train Loss: 0.3670, Train Acc: 0.8778
# Val Loss: 1.0245, Val Acc: 0.6583
# --------------------------------------------------
# Epoch [293/1500]
# Train Loss: 0.3651, Train Acc: 0.8795
# Val Loss: 1.0490, Val Acc: 0.6547
# --------------------------------------------------
# Epoch [294/1500]
# Train Loss: 0.3694, Train Acc: 0.8718
# Val Loss: 1.2050, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [295/1500]
# Train Loss: 0.3418, Train Acc: 0.8838
# Val Loss: 1.0297, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [296/1500]
# Train Loss: 0.3431, Train Acc: 0.8830
# Val Loss: 1.0957, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [297/1500]
# Train Loss: 0.3215, Train Acc: 0.8924
# Val Loss: 1.0840, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [298/1500]
# Train Loss: 0.3316, Train Acc: 0.8752
# Val Loss: 0.9928, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [299/1500]
# Train Loss: 0.2998, Train Acc: 0.8976
# Val Loss: 0.9524, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [300/1500]
# Train Loss: 0.3333, Train Acc: 0.8744
# Val Loss: 1.0617, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [301/1500]
# Train Loss: 0.3032, Train Acc: 0.8941
# Val Loss: 1.0730, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [302/1500]
# Train Loss: 0.3567, Train Acc: 0.8761
# Val Loss: 1.0102, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [303/1500]
# Train Loss: 0.3216, Train Acc: 0.8881
# Val Loss: 1.0891, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [304/1500]
# Train Loss: 0.3078, Train Acc: 0.8924
# Val Loss: 1.0273, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [305/1500]
# Train Loss: 0.3102, Train Acc: 0.8873
# Val Loss: 1.0688, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [306/1500]
# Train Loss: 0.3216, Train Acc: 0.8821
# Val Loss: 1.0031, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [307/1500]
# Train Loss: 0.3418, Train Acc: 0.8855
# Val Loss: 1.0807, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [308/1500]
# Train Loss: 0.3307, Train Acc: 0.8821
# Val Loss: 1.0624, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [309/1500]
# Train Loss: 0.3087, Train Acc: 0.8976
# Val Loss: 0.9917, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [310/1500]
# Train Loss: 0.2896, Train Acc: 0.9002
# Val Loss: 1.1293, Val Acc: 0.6511
# --------------------------------------------------
# Epoch [311/1500]
# Train Loss: 0.2764, Train Acc: 0.8967
# Val Loss: 1.0760, Val Acc: 0.6511
# --------------------------------------------------
# Epoch [312/1500]
# Train Loss: 0.3173, Train Acc: 0.8881
# Val Loss: 1.2179, Val Acc: 0.6583
# --------------------------------------------------
# Epoch [313/1500]
# Train Loss: 0.3497, Train Acc: 0.8812
# Val Loss: 1.0428, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [314/1500]
# Train Loss: 0.3384, Train Acc: 0.8830
# Val Loss: 1.3126, Val Acc: 0.6331
# --------------------------------------------------
# Epoch [315/1500]
# Train Loss: 0.3801, Train Acc: 0.8649
# Val Loss: 1.0128, Val Acc: 0.6511
# --------------------------------------------------
# Epoch [316/1500]
# Train Loss: 0.3059, Train Acc: 0.8916
# Val Loss: 1.1216, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [317/1500]
# Train Loss: 0.2903, Train Acc: 0.8967
# Val Loss: 1.0919, Val Acc: 0.6511
# --------------------------------------------------
# Epoch [318/1500]
# Train Loss: 0.3053, Train Acc: 0.9019
# Val Loss: 0.9331, Val Acc: 0.6583
# --------------------------------------------------
# Epoch [319/1500]
# Train Loss: 0.3169, Train Acc: 0.8950
# Val Loss: 1.0122, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [320/1500]
# Train Loss: 0.3046, Train Acc: 0.8924
# Val Loss: 0.9891, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [321/1500]
# Train Loss: 0.2931, Train Acc: 0.9036
# Val Loss: 1.0078, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [322/1500]
# Train Loss: 0.3140, Train Acc: 0.8873
# Val Loss: 1.1482, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [323/1500]
# Train Loss: 0.2973, Train Acc: 0.8898
# Val Loss: 1.0582, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [324/1500]
# Train Loss: 0.2939, Train Acc: 0.9002
# Val Loss: 0.9968, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [325/1500]
# Train Loss: 0.3217, Train Acc: 0.8933
# Val Loss: 1.1392, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [326/1500]
# Train Loss: 0.3166, Train Acc: 0.8907
# Val Loss: 0.9705, Val Acc: 0.6511
# --------------------------------------------------
# Epoch [327/1500]
# Train Loss: 0.3177, Train Acc: 0.8795
# Val Loss: 1.1234, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [328/1500]
# Train Loss: 0.3023, Train Acc: 0.8907
# Val Loss: 1.0166, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [329/1500]
# Train Loss: 0.2967, Train Acc: 0.8967
# Val Loss: 0.9807, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [330/1500]
# Train Loss: 0.3177, Train Acc: 0.8924
# Val Loss: 1.0001, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [331/1500]
# Train Loss: 0.2750, Train Acc: 0.9088
# Val Loss: 1.0636, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [332/1500]
# Train Loss: 0.3100, Train Acc: 0.9010
# Val Loss: 1.0798, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [333/1500]
# Train Loss: 0.3059, Train Acc: 0.8838
# Val Loss: 1.0234, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [334/1500]
# Train Loss: 0.2891, Train Acc: 0.9036
# Val Loss: 1.0239, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [335/1500]
# Train Loss: 0.3256, Train Acc: 0.8950
# Val Loss: 1.1271, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [336/1500]
# Train Loss: 0.2664, Train Acc: 0.9071
# Val Loss: 0.9891, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [337/1500]
# Train Loss: 0.3111, Train Acc: 0.8976
# Val Loss: 1.0139, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [338/1500]
# Train Loss: 0.2693, Train Acc: 0.9096
# Val Loss: 1.0309, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [339/1500]
# Train Loss: 0.2783, Train Acc: 0.9062
# Val Loss: 1.0715, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [340/1500]
# Train Loss: 0.2754, Train Acc: 0.8898
# Val Loss: 1.0987, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [341/1500]
# Train Loss: 0.2819, Train Acc: 0.8959
# Val Loss: 0.9755, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [342/1500]
# Train Loss: 0.2577, Train Acc: 0.9131
# Val Loss: 1.0599, Val Acc: 0.6619
# --------------------------------------------------
# Epoch [343/1500]
# Train Loss: 0.2665, Train Acc: 0.8950
# Val Loss: 1.0735, Val Acc: 0.6583
# --------------------------------------------------
# Epoch [344/1500]
# Train Loss: 0.2860, Train Acc: 0.8967
# ...
# --------------------------------------------------
# Epoch [1388/1500]
# Train Loss: 0.0642, Train Acc: 0.9811
# Val Loss: 1.2122, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1389/1500]
# Train Loss: 0.0535, Train Acc: 0.9793
# Val Loss: 1.2145, Val Acc: 0.6978
# --------------------------------------------------
# Epoch [1390/1500]
# Train Loss: 0.0700, Train Acc: 0.9725
# Val Loss: 1.2093, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1391/1500]
# Train Loss: 0.0937, Train Acc: 0.9690
# Val Loss: 1.2117, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [1392/1500]
# Train Loss: 0.0699, Train Acc: 0.9785
# Val Loss: 1.2613, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [1393/1500]
# Train Loss: 0.0867, Train Acc: 0.9759
# Val Loss: 1.1987, Val Acc: 0.7050
# --------------------------------------------------
# Epoch [1394/1500]
# Train Loss: 0.0664, Train Acc: 0.9768
# Val Loss: 1.2983, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1395/1500]
# Train Loss: 0.0627, Train Acc: 0.9759
# Val Loss: 1.3631, Val Acc: 0.6727
# --------------------------------------------------
# Epoch [1396/1500]
# Train Loss: 0.0690, Train Acc: 0.9742
# Val Loss: 1.2933, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [1397/1500]
# Train Loss: 0.0792, Train Acc: 0.9707
# Val Loss: 1.3236, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1398/1500]
# Train Loss: 0.0675, Train Acc: 0.9759
# Val Loss: 1.3964, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1399/1500]
# Train Loss: 0.0803, Train Acc: 0.9742
# Val Loss: 1.3776, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1400/1500]
# Train Loss: 0.0745, Train Acc: 0.9768
# Val Loss: 1.3406, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1401/1500]
# Train Loss: 0.0619, Train Acc: 0.9802
# Val Loss: 1.3273, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1402/1500]
# Train Loss: 0.0789, Train Acc: 0.9690
# Val Loss: 1.3117, Val Acc: 0.6978
# --------------------------------------------------
# Epoch [1403/1500]
# Train Loss: 0.0917, Train Acc: 0.9750
# Val Loss: 1.3944, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1404/1500]
# Train Loss: 0.0882, Train Acc: 0.9707
# Val Loss: 1.3086, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1405/1500]
# Train Loss: 0.1349, Train Acc: 0.9639
# Val Loss: 1.1946, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1406/1500]
# Train Loss: 0.0804, Train Acc: 0.9811
# Val Loss: 1.2177, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [1407/1500]
# Train Loss: 0.0877, Train Acc: 0.9716
# Val Loss: 1.3055, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1408/1500]
# Train Loss: 0.0863, Train Acc: 0.9733
# Val Loss: 1.3712, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [1409/1500]
# Train Loss: 0.0661, Train Acc: 0.9802
# Val Loss: 1.3924, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [1410/1500]
# Train Loss: 0.0987, Train Acc: 0.9699
# Val Loss: 1.3919, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [1411/1500]
# Train Loss: 0.0701, Train Acc: 0.9776
# Val Loss: 1.2872, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [1412/1500]
# Train Loss: 0.0804, Train Acc: 0.9742
# Val Loss: 1.2364, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [1413/1500]
# Train Loss: 0.0726, Train Acc: 0.9768
# Val Loss: 1.2459, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [1414/1500]
# Train Loss: 0.0905, Train Acc: 0.9707
# Val Loss: 1.4173, Val Acc: 0.6655
# --------------------------------------------------
# Epoch [1415/1500]
# Train Loss: 0.0617, Train Acc: 0.9750
# Val Loss: 1.5356, Val Acc: 0.6475
# --------------------------------------------------
# Epoch [1416/1500]
# Train Loss: 0.0696, Train Acc: 0.9776
# Val Loss: 1.3295, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [1417/1500]
# Train Loss: 0.0789, Train Acc: 0.9733
# Val Loss: 1.3551, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [1418/1500]
# Train Loss: 0.1013, Train Acc: 0.9716
# Val Loss: 1.4573, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1419/1500]
# Train Loss: 0.0830, Train Acc: 0.9768
# Val Loss: 1.4674, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [1420/1500]
# Train Loss: 0.0793, Train Acc: 0.9733
# Val Loss: 1.4031, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1421/1500]
# Train Loss: 0.0663, Train Acc: 0.9750
# Val Loss: 1.2391, Val Acc: 0.6978
# --------------------------------------------------
# Epoch [1422/1500]
# Train Loss: 0.1050, Train Acc: 0.9699
# Val Loss: 1.2726, Val Acc: 0.7086
# --------------------------------------------------
# Epoch [1423/1500]
# Train Loss: 0.0740, Train Acc: 0.9768
# Val Loss: 1.4263, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1424/1500]
# Train Loss: 0.0767, Train Acc: 0.9776
# Val Loss: 1.3289, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1425/1500]
# Train Loss: 0.0844, Train Acc: 0.9656
# Val Loss: 1.3302, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1426/1500]
# Train Loss: 0.1026, Train Acc: 0.9604
# Val Loss: 1.3688, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1427/1500]
# Train Loss: 0.0628, Train Acc: 0.9793
# Val Loss: 1.2664, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1428/1500]
# Train Loss: 0.0726, Train Acc: 0.9750
# Val Loss: 1.2763, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1429/1500]
# Train Loss: 0.0936, Train Acc: 0.9699
# Val Loss: 1.3249, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1430/1500]
# Train Loss: 0.1298, Train Acc: 0.9613
# Val Loss: 1.3149, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1431/1500]
# Train Loss: 0.0759, Train Acc: 0.9699
# Val Loss: 1.2795, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1432/1500]
# Train Loss: 0.0839, Train Acc: 0.9707
# Val Loss: 1.2306, Val Acc: 0.7050
# --------------------------------------------------
# Epoch [1433/1500]
# Train Loss: 0.0845, Train Acc: 0.9656
# Val Loss: 1.2013, Val Acc: 0.7050
# --------------------------------------------------
# Epoch [1434/1500]
# Train Loss: 0.0784, Train Acc: 0.9750
# Val Loss: 1.1788, Val Acc: 0.7086
# --------------------------------------------------
# Epoch [1435/1500]
# Train Loss: 0.0752, Train Acc: 0.9785
# Val Loss: 1.0718, Val Acc: 0.6978
# --------------------------------------------------
# Epoch [1436/1500]
# Train Loss: 0.0837, Train Acc: 0.9733
# Val Loss: 1.2625, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [1437/1500]
# Train Loss: 0.0911, Train Acc: 0.9647
# Val Loss: 1.4447, Val Acc: 0.6547
# --------------------------------------------------
# Epoch [1438/1500]
# Train Loss: 0.0713, Train Acc: 0.9785
# Val Loss: 1.2224, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [1439/1500]
# Train Loss: 0.0653, Train Acc: 0.9793
# Val Loss: 1.1237, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1440/1500]
# Train Loss: 0.1185, Train Acc: 0.9570
# Val Loss: 1.2185, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1441/1500]
# Train Loss: 0.0643, Train Acc: 0.9854
# Val Loss: 1.2290, Val Acc: 0.6978
# --------------------------------------------------
# Epoch [1442/1500]
# Train Loss: 0.0827, Train Acc: 0.9690
# Val Loss: 1.2805, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1443/1500]
# Train Loss: 0.0569, Train Acc: 0.9785
# Val Loss: 1.4017, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [1444/1500]
# Train Loss: 0.0813, Train Acc: 0.9742
# Val Loss: 1.4171, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1445/1500]
# Train Loss: 0.0812, Train Acc: 0.9682
# Val Loss: 1.3497, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1446/1500]
# Train Loss: 0.1170, Train Acc: 0.9647
# Val Loss: 1.2764, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1447/1500]
# Train Loss: 0.0704, Train Acc: 0.9725
# Val Loss: 1.3071, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [1448/1500]
# Train Loss: 0.0736, Train Acc: 0.9742
# Val Loss: 1.3399, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [1449/1500]
# Train Loss: 0.0948, Train Acc: 0.9750
# Val Loss: 1.3738, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1450/1500]
# Train Loss: 0.0873, Train Acc: 0.9742
# Val Loss: 1.4563, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [1451/1500]
# Train Loss: 0.0770, Train Acc: 0.9759
# Val Loss: 1.3376, Val Acc: 0.7086
# --------------------------------------------------
# Epoch [1452/1500]
# Train Loss: 0.1034, Train Acc: 0.9699
# Val Loss: 1.3767, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1453/1500]
# Train Loss: 0.0924, Train Acc: 0.9699
# Val Loss: 1.3644, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1454/1500]
# Train Loss: 0.0850, Train Acc: 0.9707
# Val Loss: 1.3259, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1455/1500]
# Train Loss: 0.0931, Train Acc: 0.9690
# Val Loss: 1.3016, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1456/1500]
# Train Loss: 0.0893, Train Acc: 0.9699
# Val Loss: 1.2150, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1457/1500]
# Train Loss: 0.0925, Train Acc: 0.9716
# Val Loss: 1.4310, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1458/1500]
# Train Loss: 0.0723, Train Acc: 0.9733
# Val Loss: 1.5112, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [1459/1500]
# Train Loss: 0.0931, Train Acc: 0.9699
# Val Loss: 1.3463, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1460/1500]
# Train Loss: 0.0788, Train Acc: 0.9733
# Val Loss: 1.3083, Val Acc: 0.7050
# --------------------------------------------------
# Epoch [1461/1500]
# Train Loss: 0.0661, Train Acc: 0.9716
# Val Loss: 1.3754, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1462/1500]
# Train Loss: 0.0533, Train Acc: 0.9785
# Val Loss: 1.4350, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1463/1500]
# Train Loss: 0.0745, Train Acc: 0.9699
# Val Loss: 1.3013, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [1464/1500]
# Train Loss: 0.0564, Train Acc: 0.9845
# Val Loss: 1.1812, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [1465/1500]
# Train Loss: 0.0782, Train Acc: 0.9733
# Val Loss: 1.2246, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1466/1500]
# Train Loss: 0.0862, Train Acc: 0.9690
# Val Loss: 1.2947, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1467/1500]
# Train Loss: 0.0619, Train Acc: 0.9802
# Val Loss: 1.2216, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [1468/1500]
# Train Loss: 0.0822, Train Acc: 0.9664
# Val Loss: 1.2804, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [1469/1500]
# Train Loss: 0.0673, Train Acc: 0.9811
# Val Loss: 1.4453, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [1470/1500]
# Train Loss: 0.0677, Train Acc: 0.9785
# Val Loss: 1.3298, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1471/1500]
# Train Loss: 0.0726, Train Acc: 0.9742
# Val Loss: 1.2912, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1472/1500]
# Train Loss: 0.0795, Train Acc: 0.9707
# Val Loss: 1.2777, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1473/1500]
# Train Loss: 0.1091, Train Acc: 0.9725
# Val Loss: 1.2630, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1474/1500]
# Train Loss: 0.0584, Train Acc: 0.9750
# Val Loss: 1.2195, Val Acc: 0.6978
# --------------------------------------------------
# Epoch [1475/1500]
# Train Loss: 0.0724, Train Acc: 0.9793
# Val Loss: 1.0431, Val Acc: 0.7158
# --------------------------------------------------
# Epoch [1476/1500]
# Train Loss: 0.0789, Train Acc: 0.9725
# Val Loss: 1.0799, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1477/1500]
# Train Loss: 0.0719, Train Acc: 0.9785
# Val Loss: 1.2298, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [1478/1500]
# Train Loss: 0.0623, Train Acc: 0.9793
# Val Loss: 1.1896, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [1479/1500]
# Train Loss: 0.0728, Train Acc: 0.9742
# Val Loss: 1.1477, Val Acc: 0.6799
# --------------------------------------------------
# Epoch [1480/1500]
# Train Loss: 0.0697, Train Acc: 0.9793
# Val Loss: 1.1484, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1481/1500]
# Train Loss: 0.0849, Train Acc: 0.9742
# Val Loss: 1.2059, Val Acc: 0.6835
# --------------------------------------------------
# Epoch [1482/1500]
# Train Loss: 0.0668, Train Acc: 0.9742
# Val Loss: 1.2306, Val Acc: 0.6871
# --------------------------------------------------
# Epoch [1483/1500]
# Train Loss: 0.1130, Train Acc: 0.9664
# Val Loss: 1.2716, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1484/1500]
# Train Loss: 0.0635, Train Acc: 0.9768
# Val Loss: 1.1905, Val Acc: 0.7050
# --------------------------------------------------
# Epoch [1485/1500]
# Train Loss: 0.0728, Train Acc: 0.9725
# Val Loss: 1.1911, Val Acc: 0.6906
# --------------------------------------------------
# Epoch [1486/1500]
# Train Loss: 0.0735, Train Acc: 0.9759
# Val Loss: 1.2053, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1487/1500]
# Train Loss: 0.0916, Train Acc: 0.9716
# Val Loss: 1.1416, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1488/1500]
# Train Loss: 0.0637, Train Acc: 0.9768
# Val Loss: 1.0637, Val Acc: 0.6691
# --------------------------------------------------
# Epoch [1489/1500]
# Train Loss: 0.0512, Train Acc: 0.9845
# Val Loss: 1.1091, Val Acc: 0.6978
# --------------------------------------------------
# Epoch [1490/1500]
# Train Loss: 0.0772, Train Acc: 0.9733
# Val Loss: 1.1546, Val Acc: 0.7050
# --------------------------------------------------
# Epoch [1491/1500]
# Train Loss: 0.0959, Train Acc: 0.9621
# Val Loss: 1.1992, Val Acc: 0.7266
# --------------------------------------------------
# Epoch [1492/1500]
# Train Loss: 0.0599, Train Acc: 0.9828
# Val Loss: 1.1307, Val Acc: 0.7050
# --------------------------------------------------
# Epoch [1493/1500]
# Train Loss: 0.0893, Train Acc: 0.9725
# Val Loss: 1.1171, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1494/1500]
# Train Loss: 0.0947, Train Acc: 0.9707
# Val Loss: 1.1458, Val Acc: 0.6978
# --------------------------------------------------
# Epoch [1495/1500]
# Train Loss: 0.0707, Train Acc: 0.9759
# Val Loss: 1.1870, Val Acc: 0.7086
# --------------------------------------------------
# Epoch [1496/1500]
# Train Loss: 0.0919, Train Acc: 0.9690
# Val Loss: 1.1956, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1497/1500]
# Train Loss: 0.0878, Train Acc: 0.9742
# Val Loss: 1.1574, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1498/1500]
# Train Loss: 0.0634, Train Acc: 0.9759
# Val Loss: 1.2272, Val Acc: 0.6763
# --------------------------------------------------
# Epoch [1499/1500]
# Train Loss: 0.0729, Train Acc: 0.9742
# Val Loss: 1.1756, Val Acc: 0.6942
# --------------------------------------------------
# Epoch [1500/1500]
# Train Loss: 0.0798, Train Acc: 0.9733
# Val Loss: 1.1858, Val Acc: 0.7050
# --------------------------------------------------

# %%
torch.save(model.state_dict(), "C:/Nini/Capstone/Models/cnn_model_mel_mfcc_chroma_snippets.pth")
