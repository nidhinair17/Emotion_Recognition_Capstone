# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import precision_recall_fscore_support

# %%
features = pd.read_csv("C:/Nini/Capstone/CSV_Files/ravdess_extracted_features.csv")
features = features.drop(features.columns[0], axis=1)
temp = shuffle(features)
df = np.random.rand(len(temp)) < 0.8
train = temp[df]
test = temp[~df]

# %%
X_train = np.array(train.iloc[:,:-1])
y_train = np.array(train.iloc[:,-1])
X_test = np.array(test.iloc[:,:-1])
y_test = np.array(test.iloc[:,-1])

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
batch_size = 256
train_loader = DataLoader(TensorDataset(X_train,y_train), batch_size=batch_size,shuffle=True)
test_loader = DataLoader(TensorDataset(X_test,y_test), batch_size=batch_size, shuffle=False)

# %%
class LSTMPyTorch(nn.Module):
    def __init__(self, input_size, hidden_sizes=[256, 256, 128], output_size=8, dropout=0.2, l2_reg=1e-5):
        super(LSTMPyTorch, self).__init__()
        
        self.lstm1 = nn.LSTM(input_size, hidden_sizes[0], batch_first=True)
        self.lstm2 = nn.LSTM(hidden_sizes[0], hidden_sizes[1], batch_first=True)
        self.lstm3 = nn.LSTM(hidden_sizes[1], hidden_sizes[2], batch_first=True)
        
        self.bn1 = nn.BatchNorm1d(hidden_sizes[0])
        self.bn2 = nn.BatchNorm1d(hidden_sizes[1])
        self.bn3 = nn.BatchNorm1d(hidden_sizes[2])

        self.fc1 = nn.Linear(hidden_sizes[2], 256)
        self.fc2 = nn.Linear(256, output_size)
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.bn1(x.transpose(1,2)).transpose(1,2)

        x, _ = self.lstm2(x)
        x = self.bn2(x.transpose(1,2)).transpose(1,2)

        x, _ = self.lstm3(x)
        x = self.bn3(x.transpose(1,2)).transpose(1,2)
        
        x = self.relu(self.fc1(x[:, -1, :])) 
        x = self.dropout(x)
        x = self.softmax(self.fc2(x))
        return x

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: torch.Size([1162, 1, 128])

# %%
input_size = 128
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMPyTorch(input_size).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

# %%
epochs = 1500
for epoch in range(epochs):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    # Training loop
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)
    
    train_accuracy = correct / total
    avg_train_loss = running_loss / len(train_loader)

    # Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for val_inputs, val_labels in test_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()
            _, val_predicted = torch.max(val_outputs, 1)

            val_correct += (val_predicted == val_labels).sum().item()
            val_total += val_labels.size(0)

            # Store predictions and labels for evaluation
            all_preds.extend(val_predicted.cpu().numpy())
            all_labels.extend(val_labels.cpu().numpy())

    val_accuracy = val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)

    # Compute Precision, Recall, F1-score
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted',zero_division=1)

    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}")
    print("-" * 50)
# Out:
# Epoch [1/1500]
# Train Loss: 2.0391, Train Acc: 0.2496
# Val Loss: 2.0786, Val Acc: 0.1547
# Precision: 0.8692, Recall: 0.1547, F1-score: 0.0414
# --------------------------------------------------
# Epoch [2/1500]
# Train Loss: 1.9523, Train Acc: 0.3959
# Val Loss: 2.0758, Val Acc: 0.1978
# Precision: 0.6794, Recall: 0.1978, F1-score: 0.1067
# --------------------------------------------------
# Epoch [3/1500]
# Train Loss: 1.8838, Train Acc: 0.4174
# Val Loss: 2.0690, Val Acc: 0.2050
# Precision: 0.7022, Recall: 0.2050, F1-score: 0.1486
# --------------------------------------------------
# Epoch [4/1500]
# Train Loss: 1.8319, Train Acc: 0.4492
# Val Loss: 2.0523, Val Acc: 0.3417
# Precision: 0.4755, Recall: 0.3417, F1-score: 0.2930
# --------------------------------------------------
# Epoch [5/1500]
# Train Loss: 1.7840, Train Acc: 0.5060
# Val Loss: 2.0234, Val Acc: 0.3561
# Precision: 0.4639, Recall: 0.3561, F1-score: 0.3307
# --------------------------------------------------
# Epoch [6/1500]
# Train Loss: 1.7447, Train Acc: 0.5465
# Val Loss: 1.9802, Val Acc: 0.4065
# Precision: 0.5185, Recall: 0.4065, F1-score: 0.3909
# --------------------------------------------------
# Epoch [7/1500]
# Train Loss: 1.7050, Train Acc: 0.5783
# Val Loss: 1.9225, Val Acc: 0.4209
# Precision: 0.5509, Recall: 0.4209, F1-score: 0.3949
# --------------------------------------------------
# Epoch [8/1500]
# Train Loss: 1.6897, Train Acc: 0.6041
# Val Loss: 1.8653, Val Acc: 0.4460
# Precision: 0.5703, Recall: 0.4460, F1-score: 0.4256
# --------------------------------------------------
# Epoch [9/1500]
# Train Loss: 1.6587, Train Acc: 0.6317
# Val Loss: 1.8315, Val Acc: 0.4568
# Precision: 0.5497, Recall: 0.4568, F1-score: 0.4411
# --------------------------------------------------
# Epoch [10/1500]
# Train Loss: 1.6432, Train Acc: 0.6506
# Val Loss: 1.7692, Val Acc: 0.5108
# Precision: 0.6140, Recall: 0.5108, F1-score: 0.4937
# --------------------------------------------------
# Epoch [11/1500]
# Train Loss: 1.6207, Train Acc: 0.6618
# Val Loss: 1.7898, Val Acc: 0.4856
# Precision: 0.5408, Recall: 0.4856, F1-score: 0.4661
# --------------------------------------------------
# Epoch [12/1500]
# Train Loss: 1.6125, Train Acc: 0.6764
# Val Loss: 1.7300, Val Acc: 0.5360
# Precision: 0.6356, Recall: 0.5360, F1-score: 0.5132
# --------------------------------------------------
# Epoch [13/1500]
# Train Loss: 1.5772, Train Acc: 0.7057
# Val Loss: 1.7486, Val Acc: 0.5036
# Precision: 0.5514, Recall: 0.5036, F1-score: 0.4839
# --------------------------------------------------
# Epoch [14/1500]
# Train Loss: 1.5705, Train Acc: 0.7126
# Val Loss: 1.7471, Val Acc: 0.5324
# Precision: 0.5985, Recall: 0.5324, F1-score: 0.5167
# --------------------------------------------------
# Epoch [15/1500]
# Train Loss: 1.5681, Train Acc: 0.7186
# Val Loss: 1.7342, Val Acc: 0.5144
# Precision: 0.6280, Recall: 0.5144, F1-score: 0.4970
# --------------------------------------------------
# Epoch [16/1500]
# Train Loss: 1.5451, Train Acc: 0.7410
# Val Loss: 1.7093, Val Acc: 0.5324
# Precision: 0.6270, Recall: 0.5324, F1-score: 0.5178
# --------------------------------------------------
# Epoch [17/1500]
# Train Loss: 1.5561, Train Acc: 0.7332
# Val Loss: 1.6669, Val Acc: 0.5863
# Precision: 0.6348, Recall: 0.5863, F1-score: 0.5628
# --------------------------------------------------
# Epoch [18/1500]
# Train Loss: 1.5230, Train Acc: 0.7633
# Val Loss: 1.7098, Val Acc: 0.5252
# Precision: 0.6158, Recall: 0.5252, F1-score: 0.5040
# --------------------------------------------------
# Epoch [19/1500]
# Train Loss: 1.5142, Train Acc: 0.7668
# Val Loss: 1.7547, Val Acc: 0.5216
# Precision: 0.5623, Recall: 0.5216, F1-score: 0.5016
# --------------------------------------------------
# Epoch [20/1500]
# Train Loss: 1.4989, Train Acc: 0.7831
# Val Loss: 1.6875, Val Acc: 0.5647
# Precision: 0.6572, Recall: 0.5647, F1-score: 0.5412
# --------------------------------------------------
# Epoch [21/1500]
# Train Loss: 1.5049, Train Acc: 0.7840
# Val Loss: 1.7296, Val Acc: 0.5540
# Precision: 0.6037, Recall: 0.5540, F1-score: 0.5325
# --------------------------------------------------
# Epoch [22/1500]
# Train Loss: 1.4980, Train Acc: 0.7883
# Val Loss: 1.6827, Val Acc: 0.5827
# Precision: 0.6317, Recall: 0.5827, F1-score: 0.5559
# --------------------------------------------------
# Epoch [23/1500]
# Train Loss: 1.4837, Train Acc: 0.8003
# Val Loss: 1.6670, Val Acc: 0.5576
# Precision: 0.6280, Recall: 0.5576, F1-score: 0.5386
# --------------------------------------------------
# Epoch [24/1500]
# Train Loss: 1.4741, Train Acc: 0.8124
# Val Loss: 1.6454, Val Acc: 0.5647
# Precision: 0.6414, Recall: 0.5647, F1-score: 0.5449
# --------------------------------------------------
# Epoch [25/1500]
# Train Loss: 1.4876, Train Acc: 0.7935
# Val Loss: 1.7407, Val Acc: 0.5432
# Precision: 0.6167, Recall: 0.5432, F1-score: 0.5273
# --------------------------------------------------
# Epoch [26/1500]
# Train Loss: 1.4827, Train Acc: 0.8021
# Val Loss: 1.6606, Val Acc: 0.5540
# Precision: 0.6180, Recall: 0.5540, F1-score: 0.5342
# --------------------------------------------------
# Epoch [27/1500]
# Train Loss: 1.4775, Train Acc: 0.7978
# Val Loss: 1.7332, Val Acc: 0.5647
# Precision: 0.6106, Recall: 0.5647, F1-score: 0.5510
# --------------------------------------------------
# Epoch [28/1500]
# Train Loss: 1.4747, Train Acc: 0.8003
# Val Loss: 1.6986, Val Acc: 0.5504
# Precision: 0.6198, Recall: 0.5504, F1-score: 0.5316
# --------------------------------------------------
# Epoch [29/1500]
# Train Loss: 1.4698, Train Acc: 0.8081
# Val Loss: 1.7706, Val Acc: 0.4820
# Precision: 0.5047, Recall: 0.4820, F1-score: 0.4684
# --------------------------------------------------
# Epoch [30/1500]
# Train Loss: 1.4671, Train Acc: 0.8193
# Val Loss: 1.6967, Val Acc: 0.5252
# Precision: 0.5247, Recall: 0.5252, F1-score: 0.5099
# --------------------------------------------------
# Epoch [31/1500]
# Train Loss: 1.4482, Train Acc: 0.8313
# Val Loss: 1.7613, Val Acc: 0.5288
# Precision: 0.5367, Recall: 0.5288, F1-score: 0.5265
# --------------------------------------------------
# Epoch [32/1500]
# Train Loss: 1.4371, Train Acc: 0.8468
# Val Loss: 1.6667, Val Acc: 0.6079
# Precision: 0.6130, Recall: 0.6079, F1-score: 0.6037
# --------------------------------------------------
# Epoch [33/1500]
# Train Loss: 1.4355, Train Acc: 0.8468
# Val Loss: 1.7238, Val Acc: 0.5791
# Precision: 0.5826, Recall: 0.5791, F1-score: 0.5724
# --------------------------------------------------
# Epoch [34/1500]
# Train Loss: 1.4640, Train Acc: 0.8158
# Val Loss: 1.6559, Val Acc: 0.5863
# Precision: 0.6040, Recall: 0.5863, F1-score: 0.5788
# --------------------------------------------------
# Epoch [35/1500]
# Train Loss: 1.4479, Train Acc: 0.8313
# Val Loss: 1.6277, Val Acc: 0.6043
# Precision: 0.6401, Recall: 0.6043, F1-score: 0.5976
# --------------------------------------------------
# Epoch [36/1500]
# Train Loss: 1.4375, Train Acc: 0.8434
# Val Loss: 1.6830, Val Acc: 0.5432
# Precision: 0.6019, Recall: 0.5432, F1-score: 0.5325
# --------------------------------------------------
# Epoch [37/1500]
# Train Loss: 1.4457, Train Acc: 0.8348
# Val Loss: 1.6937, Val Acc: 0.5683
# Precision: 0.5777, Recall: 0.5683, F1-score: 0.5530
# --------------------------------------------------
# Epoch [38/1500]
# Train Loss: 1.4377, Train Acc: 0.8442
# Val Loss: 1.6702, Val Acc: 0.5612
# Precision: 0.5606, Recall: 0.5612, F1-score: 0.5580
# --------------------------------------------------
# Epoch [39/1500]
# Train Loss: 1.4234, Train Acc: 0.8589
# Val Loss: 1.7568, Val Acc: 0.5396
# Precision: 0.5481, Recall: 0.5396, F1-score: 0.5320
# --------------------------------------------------
# Epoch [40/1500]
# Train Loss: 1.4508, Train Acc: 0.8330
# Val Loss: 1.7204, Val Acc: 0.5432
# Precision: 0.5772, Recall: 0.5432, F1-score: 0.5362
# --------------------------------------------------
# Epoch [41/1500]
# Train Loss: 1.4248, Train Acc: 0.8520
# Val Loss: 1.6602, Val Acc: 0.5971
# Precision: 0.6052, Recall: 0.5971, F1-score: 0.5885
# --------------------------------------------------
# Epoch [42/1500]
# Train Loss: 1.4074, Train Acc: 0.8769
# Val Loss: 1.5852, Val Acc: 0.6151
# Precision: 0.6173, Recall: 0.6151, F1-score: 0.6089
# --------------------------------------------------
# Epoch [43/1500]
# Train Loss: 1.4063, Train Acc: 0.8804
# Val Loss: 1.6339, Val Acc: 0.6079
# Precision: 0.6197, Recall: 0.6079, F1-score: 0.6069
# --------------------------------------------------
# Epoch [44/1500]
# Train Loss: 1.3941, Train Acc: 0.8890
# Val Loss: 1.6657, Val Acc: 0.6223
# Precision: 0.6435, Recall: 0.6223, F1-score: 0.6207
# --------------------------------------------------
# Epoch [45/1500]
# Train Loss: 1.3870, Train Acc: 0.8916
# Val Loss: 1.6651, Val Acc: 0.5899
# Precision: 0.6174, Recall: 0.5899, F1-score: 0.5950
# --------------------------------------------------
# Epoch [46/1500]
# Train Loss: 1.3977, Train Acc: 0.8881
# Val Loss: 1.6432, Val Acc: 0.6331
# Precision: 0.6338, Recall: 0.6331, F1-score: 0.6234
# --------------------------------------------------
# Epoch [47/1500]
# Train Loss: 1.3948, Train Acc: 0.8847
# Val Loss: 1.6831, Val Acc: 0.5863
# Precision: 0.5853, Recall: 0.5863, F1-score: 0.5801
# --------------------------------------------------
# Epoch [48/1500]
# Train Loss: 1.4035, Train Acc: 0.8787
# Val Loss: 1.6830, Val Acc: 0.5899
# Precision: 0.5995, Recall: 0.5899, F1-score: 0.5819
# --------------------------------------------------
# Epoch [49/1500]
# Train Loss: 1.3993, Train Acc: 0.8761
# Val Loss: 1.6323, Val Acc: 0.6115
# Precision: 0.6197, Recall: 0.6115, F1-score: 0.6122
# --------------------------------------------------
# Epoch [50/1500]
# Train Loss: 1.3997, Train Acc: 0.8804
# Val Loss: 1.6536, Val Acc: 0.6115
# Precision: 0.6277, Recall: 0.6115, F1-score: 0.6062
# --------------------------------------------------
# Epoch [51/1500]
# Train Loss: 1.3953, Train Acc: 0.8821
# Val Loss: 1.6667, Val Acc: 0.6259
# Precision: 0.6318, Recall: 0.6259, F1-score: 0.6273
# --------------------------------------------------
# Epoch [52/1500]
# Train Loss: 1.3705, Train Acc: 0.9096
# Val Loss: 1.6000, Val Acc: 0.6655
# Precision: 0.6741, Recall: 0.6655, F1-score: 0.6634
# --------------------------------------------------
# Epoch [53/1500]
# Train Loss: 1.3657, Train Acc: 0.9148
# Val Loss: 1.6323, Val Acc: 0.6403
# Precision: 0.6668, Recall: 0.6403, F1-score: 0.6428
# --------------------------------------------------
# Epoch [54/1500]
# Train Loss: 1.3633, Train Acc: 0.9208
# Val Loss: 1.6169, Val Acc: 0.6439
# Precision: 0.6621, Recall: 0.6439, F1-score: 0.6411
# --------------------------------------------------
# Epoch [55/1500]
# Train Loss: 1.3755, Train Acc: 0.9088
# Val Loss: 1.6161, Val Acc: 0.6259
# Precision: 0.6471, Recall: 0.6259, F1-score: 0.6239
# --------------------------------------------------
# Epoch [56/1500]
# Train Loss: 1.3730, Train Acc: 0.9088
# Val Loss: 1.6647, Val Acc: 0.5971
# Precision: 0.6280, Recall: 0.5971, F1-score: 0.5963
# --------------------------------------------------
# Epoch [57/1500]
# Train Loss: 1.3763, Train Acc: 0.8993
# Val Loss: 1.6119, Val Acc: 0.6511
# Precision: 0.6725, Recall: 0.6511, F1-score: 0.6448
# --------------------------------------------------
# Epoch [58/1500]
# Train Loss: 1.3705, Train Acc: 0.9071
# Val Loss: 1.6122, Val Acc: 0.6619
# Precision: 0.6947, Recall: 0.6619, F1-score: 0.6627
# --------------------------------------------------
# Epoch [59/1500]
# Train Loss: 1.3826, Train Acc: 0.8976
# Val Loss: 1.6013, Val Acc: 0.6331
# Precision: 0.6697, Recall: 0.6331, F1-score: 0.6333
# --------------------------------------------------
# Epoch [60/1500]
# Train Loss: 1.3674, Train Acc: 0.9114
# Val Loss: 1.6716, Val Acc: 0.5755
# Precision: 0.5951, Recall: 0.5755, F1-score: 0.5726
# --------------------------------------------------
# Epoch [61/1500]
# Train Loss: 1.3797, Train Acc: 0.9019
# Val Loss: 1.6194, Val Acc: 0.6223
# Precision: 0.6500, Recall: 0.6223, F1-score: 0.6153
# --------------------------------------------------
# Epoch [62/1500]
# Train Loss: 1.3720, Train Acc: 0.9036
# Val Loss: 1.6147, Val Acc: 0.6295
# Precision: 0.6553, Recall: 0.6295, F1-score: 0.6297
# --------------------------------------------------
# Epoch [63/1500]
# Train Loss: 1.3641, Train Acc: 0.9114
# Val Loss: 1.5981, Val Acc: 0.6511
# Precision: 0.6829, Recall: 0.6511, F1-score: 0.6559
# --------------------------------------------------
# Epoch [64/1500]
# Train Loss: 1.3547, Train Acc: 0.9182
# Val Loss: 1.6015, Val Acc: 0.6511
# Precision: 0.6671, Recall: 0.6511, F1-score: 0.6503
# --------------------------------------------------
# Epoch [65/1500]
# Train Loss: 1.3621, Train Acc: 0.9157
# Val Loss: 1.6538, Val Acc: 0.5935
# Precision: 0.6053, Recall: 0.5935, F1-score: 0.5893
# --------------------------------------------------
# Epoch [66/1500]
# Train Loss: 1.3641, Train Acc: 0.9157
# Val Loss: 1.6297, Val Acc: 0.6367
# Precision: 0.6667, Recall: 0.6367, F1-score: 0.6383
# --------------------------------------------------
# Epoch [67/1500]
# Train Loss: 1.3596, Train Acc: 0.9217
# Val Loss: 1.6348, Val Acc: 0.6655
# Precision: 0.6768, Recall: 0.6655, F1-score: 0.6626
# --------------------------------------------------
# Epoch [68/1500]
# Train Loss: 1.3573, Train Acc: 0.9243
# Val Loss: 1.6140, Val Acc: 0.6691
# Precision: 0.6879, Recall: 0.6691, F1-score: 0.6704
# --------------------------------------------------
# Epoch [69/1500]
# Train Loss: 1.3460, Train Acc: 0.9312
# Val Loss: 1.6074, Val Acc: 0.6295
# Precision: 0.6449, Recall: 0.6295, F1-score: 0.6294
# --------------------------------------------------
# Epoch [70/1500]
# Train Loss: 1.3596, Train Acc: 0.9182
# Val Loss: 1.6933, Val Acc: 0.5971
# Precision: 0.6282, Recall: 0.5971, F1-score: 0.5940
# --------------------------------------------------
# Epoch [71/1500]
# Train Loss: 1.3588, Train Acc: 0.9174
# Val Loss: 1.6397, Val Acc: 0.6295
# Precision: 0.6649, Recall: 0.6295, F1-score: 0.6286
# --------------------------------------------------
# Epoch [72/1500]
# Train Loss: 1.3502, Train Acc: 0.9260
# Val Loss: 1.6447, Val Acc: 0.6187
# Precision: 0.6274, Recall: 0.6187, F1-score: 0.6120
# --------------------------------------------------
# Epoch [73/1500]
# Train Loss: 1.3543, Train Acc: 0.9260
# Val Loss: 1.6290, Val Acc: 0.6151
# Precision: 0.6168, Recall: 0.6151, F1-score: 0.6056
# --------------------------------------------------
# Epoch [74/1500]
# Train Loss: 1.3461, Train Acc: 0.9312
# Val Loss: 1.6996, Val Acc: 0.6295
# Precision: 0.6409, Recall: 0.6295, F1-score: 0.6282
# --------------------------------------------------
# Epoch [75/1500]
# Train Loss: 1.3415, Train Acc: 0.9363
# Val Loss: 1.6483, Val Acc: 0.6187
# Precision: 0.6384, Recall: 0.6187, F1-score: 0.6148
# --------------------------------------------------
# Epoch [76/1500]
# Train Loss: 1.3413, Train Acc: 0.9372
# Val Loss: 1.6552, Val Acc: 0.6115
# Precision: 0.6363, Recall: 0.6115, F1-score: 0.6102
# --------------------------------------------------
# Epoch [77/1500]
# Train Loss: 1.3272, Train Acc: 0.9501
# Val Loss: 1.6138, Val Acc: 0.6403
# Precision: 0.6710, Recall: 0.6403, F1-score: 0.6386
# --------------------------------------------------
# Epoch [78/1500]
# Train Loss: 1.3458, Train Acc: 0.9303
# Val Loss: 1.6403, Val Acc: 0.6043
# Precision: 0.6302, Recall: 0.6043, F1-score: 0.6041
# --------------------------------------------------
# Epoch [79/1500]
# Train Loss: 1.3481, Train Acc: 0.9260
# Val Loss: 1.6196, Val Acc: 0.6187
# Precision: 0.6527, Recall: 0.6187, F1-score: 0.6165
# --------------------------------------------------
# Epoch [80/1500]
# Train Loss: 1.3398, Train Acc: 0.9406
# Val Loss: 1.6279, Val Acc: 0.6403
# Precision: 0.6587, Recall: 0.6403, F1-score: 0.6403
# --------------------------------------------------
# Epoch [81/1500]
# Train Loss: 1.3417, Train Acc: 0.9337
# Val Loss: 1.6207, Val Acc: 0.6115
# Precision: 0.6685, Recall: 0.6115, F1-score: 0.6144
# --------------------------------------------------
# Epoch [82/1500]
# Train Loss: 1.3544, Train Acc: 0.9234
# Val Loss: 1.7112, Val Acc: 0.6007
# Precision: 0.6149, Recall: 0.6007, F1-score: 0.5975
# --------------------------------------------------
# Epoch [83/1500]
# Train Loss: 1.3532, Train Acc: 0.9225
# Val Loss: 1.5965, Val Acc: 0.6259
# Precision: 0.6554, Recall: 0.6259, F1-score: 0.6166
# --------------------------------------------------
# Epoch [84/1500]
# Train Loss: 1.3489, Train Acc: 0.9286
# Val Loss: 1.6007, Val Acc: 0.6475
# Precision: 0.6654, Recall: 0.6475, F1-score: 0.6507
# --------------------------------------------------
# Epoch [85/1500]
# Train Loss: 1.3377, Train Acc: 0.9398
# Val Loss: 1.5488, Val Acc: 0.6511
# Precision: 0.6797, Recall: 0.6511, F1-score: 0.6489
# --------------------------------------------------
# Epoch [86/1500]
# Train Loss: 1.3357, Train Acc: 0.9475
# Val Loss: 1.5602, Val Acc: 0.6475
# Precision: 0.6624, Recall: 0.6475, F1-score: 0.6491
# --------------------------------------------------
# Epoch [87/1500]
# Train Loss: 1.3327, Train Acc: 0.9415
# Val Loss: 1.6093, Val Acc: 0.6403
# Precision: 0.7003, Recall: 0.6403, F1-score: 0.6393
# --------------------------------------------------
# Epoch [88/1500]
# Train Loss: 1.3355, Train Acc: 0.9406
# Val Loss: 1.6646, Val Acc: 0.6295
# Precision: 0.6542, Recall: 0.6295, F1-score: 0.6307
# --------------------------------------------------
# Epoch [89/1500]
# Train Loss: 1.3383, Train Acc: 0.9372
# Val Loss: 1.5636, Val Acc: 0.6691
# Precision: 0.6797, Recall: 0.6691, F1-score: 0.6667
# --------------------------------------------------
# Epoch [90/1500]
# Train Loss: 1.3364, Train Acc: 0.9432
# Val Loss: 1.6314, Val Acc: 0.6367
# Precision: 0.6707, Recall: 0.6367, F1-score: 0.6322
# --------------------------------------------------
# Epoch [91/1500]
# Train Loss: 1.3374, Train Acc: 0.9380
# Val Loss: 1.6312, Val Acc: 0.6691
# Precision: 0.6783, Recall: 0.6691, F1-score: 0.6679
# --------------------------------------------------
# Epoch [92/1500]
# Train Loss: 1.3384, Train Acc: 0.9380
# Val Loss: 1.6079, Val Acc: 0.6439
# Precision: 0.6664, Recall: 0.6439, F1-score: 0.6380
# --------------------------------------------------
# Epoch [93/1500]
# Train Loss: 1.3333, Train Acc: 0.9406
# Val Loss: 1.6164, Val Acc: 0.6547
# Precision: 0.6675, Recall: 0.6547, F1-score: 0.6544
# --------------------------------------------------
# Epoch [94/1500]
# Train Loss: 1.3276, Train Acc: 0.9458
# Val Loss: 1.5746, Val Acc: 0.6511
# Precision: 0.6641, Recall: 0.6511, F1-score: 0.6502
# --------------------------------------------------
# Epoch [95/1500]
# Train Loss: 1.3261, Train Acc: 0.9509
# Val Loss: 1.5471, Val Acc: 0.6583
# Precision: 0.6934, Recall: 0.6583, F1-score: 0.6566
# --------------------------------------------------
# Epoch [96/1500]
# Train Loss: 1.3260, Train Acc: 0.9484
# Val Loss: 1.5408, Val Acc: 0.6763
# Precision: 0.6914, Recall: 0.6763, F1-score: 0.6728
# --------------------------------------------------
# Epoch [97/1500]
# Train Loss: 1.3277, Train Acc: 0.9458
# Val Loss: 1.6162, Val Acc: 0.6655
# Precision: 0.6702, Recall: 0.6655, F1-score: 0.6642
# --------------------------------------------------
# Epoch [98/1500]
# Train Loss: 1.3290, Train Acc: 0.9501
# Val Loss: 1.5188, Val Acc: 0.6727
# Precision: 0.6969, Recall: 0.6727, F1-score: 0.6680
# --------------------------------------------------
# Epoch [99/1500]
# Train Loss: 1.3175, Train Acc: 0.9561
# Val Loss: 1.5922, Val Acc: 0.6043
# Precision: 0.6286, Recall: 0.6043, F1-score: 0.5974
# --------------------------------------------------
# Epoch [100/1500]
# Train Loss: 1.3261, Train Acc: 0.9484
# Val Loss: 1.5637, Val Acc: 0.6799
# Precision: 0.6901, Recall: 0.6799, F1-score: 0.6774
# --------------------------------------------------
# Epoch [101/1500]
# Train Loss: 1.3281, Train Acc: 0.9509
# Val Loss: 1.6051, Val Acc: 0.6403
# Precision: 0.6542, Recall: 0.6403, F1-score: 0.6353
# --------------------------------------------------
# Epoch [102/1500]
# Train Loss: 1.3253, Train Acc: 0.9509
# Val Loss: 1.6054, Val Acc: 0.6403
# Precision: 0.6561, Recall: 0.6403, F1-score: 0.6363
# --------------------------------------------------
# Epoch [103/1500]
# Train Loss: 1.3443, Train Acc: 0.9303
# Val Loss: 1.6161, Val Acc: 0.6331
# Precision: 0.6385, Recall: 0.6331, F1-score: 0.6270
# --------------------------------------------------
# Epoch [104/1500]
# Train Loss: 1.3325, Train Acc: 0.9432
# Val Loss: 1.6095, Val Acc: 0.6403
# Precision: 0.6632, Recall: 0.6403, F1-score: 0.6363
# --------------------------------------------------
# Epoch [105/1500]
# Train Loss: 1.3256, Train Acc: 0.9501
# Val Loss: 1.6529, Val Acc: 0.6439
# Precision: 0.6532, Recall: 0.6439, F1-score: 0.6401
# --------------------------------------------------
# Epoch [106/1500]
# Train Loss: 1.3400, Train Acc: 0.9355
# Val Loss: 1.6163, Val Acc: 0.6799
# Precision: 0.6858, Recall: 0.6799, F1-score: 0.6794
# --------------------------------------------------
# Epoch [107/1500]
# Train Loss: 1.3290, Train Acc: 0.9458
# Val Loss: 1.6413, Val Acc: 0.6763
# Precision: 0.6803, Recall: 0.6763, F1-score: 0.6741
# --------------------------------------------------
# Epoch [108/1500]
# Train Loss: 1.3302, Train Acc: 0.9432
# Val Loss: 1.6156, Val Acc: 0.6655
# Precision: 0.6819, Recall: 0.6655, F1-score: 0.6645
# --------------------------------------------------
# Epoch [109/1500]
# Train Loss: 1.3254, Train Acc: 0.9475
# Val Loss: 1.5908, Val Acc: 0.6547
# Precision: 0.6801, Recall: 0.6547, F1-score: 0.6491
# --------------------------------------------------
# Epoch [110/1500]
# Train Loss: 1.3160, Train Acc: 0.9570
# Val Loss: 1.6189, Val Acc: 0.6403
# Precision: 0.6556, Recall: 0.6403, F1-score: 0.6417
# --------------------------------------------------
# Epoch [111/1500]
# Train Loss: 1.3215, Train Acc: 0.9587
# Val Loss: 1.6172, Val Acc: 0.6619
# Precision: 0.6756, Recall: 0.6619, F1-score: 0.6612
# --------------------------------------------------
# Epoch [112/1500]
# Train Loss: 1.3187, Train Acc: 0.9587
# Val Loss: 1.6102, Val Acc: 0.6439
# Precision: 0.6811, Recall: 0.6439, F1-score: 0.6418
# --------------------------------------------------
# Epoch [113/1500]
# Train Loss: 1.3203, Train Acc: 0.9570
# Val Loss: 1.6419, Val Acc: 0.6835
# Precision: 0.6859, Recall: 0.6835, F1-score: 0.6831
# --------------------------------------------------
# Epoch [114/1500]
# Train Loss: 1.3292, Train Acc: 0.9484
# Val Loss: 1.6141, Val Acc: 0.6511
# Precision: 0.6647, Recall: 0.6511, F1-score: 0.6518
# --------------------------------------------------
# Epoch [115/1500]
# Train Loss: 1.3326, Train Acc: 0.9423
# Val Loss: 1.6302, Val Acc: 0.6115
# Precision: 0.6215, Recall: 0.6115, F1-score: 0.6070
# --------------------------------------------------
# Epoch [116/1500]
# Train Loss: 1.3302, Train Acc: 0.9501
# Val Loss: 1.6802, Val Acc: 0.6187
# Precision: 0.6281, Recall: 0.6187, F1-score: 0.6152
# --------------------------------------------------
# Epoch [117/1500]
# Train Loss: 1.3299, Train Acc: 0.9466
# Val Loss: 1.6649, Val Acc: 0.6367
# Precision: 0.6401, Recall: 0.6367, F1-score: 0.6348
# --------------------------------------------------
# Epoch [118/1500]
# Train Loss: 1.3273, Train Acc: 0.9492
# Val Loss: 1.6402, Val Acc: 0.6115
# Precision: 0.6269, Recall: 0.6115, F1-score: 0.6104
# --------------------------------------------------
# Epoch [119/1500]
# Train Loss: 1.3364, Train Acc: 0.9398
# Val Loss: 1.6383, Val Acc: 0.6511
# Precision: 0.6856, Recall: 0.6511, F1-score: 0.6518
# --------------------------------------------------
# Epoch [120/1500]
# Train Loss: 1.3426, Train Acc: 0.9363
# Val Loss: 1.5909, Val Acc: 0.6403
# Precision: 0.6762, Recall: 0.6403, F1-score: 0.6420
# --------------------------------------------------
# Epoch [121/1500]
# Train Loss: 1.3255, Train Acc: 0.9458
# Val Loss: 1.5951, Val Acc: 0.6367
# Precision: 0.6513, Recall: 0.6367, F1-score: 0.6330
# --------------------------------------------------
# Epoch [122/1500]
# Train Loss: 1.3535, Train Acc: 0.9251
# Val Loss: 1.6452, Val Acc: 0.6655
# Precision: 0.6720, Recall: 0.6655, F1-score: 0.6544
# --------------------------------------------------
# Epoch [123/1500]
# Train Loss: 1.3404, Train Acc: 0.9346
# Val Loss: 1.6363, Val Acc: 0.6259
# Precision: 0.6445, Recall: 0.6259, F1-score: 0.6204
# --------------------------------------------------
# Epoch [124/1500]
# Train Loss: 1.3373, Train Acc: 0.9389
# Val Loss: 1.6037, Val Acc: 0.6403
# Precision: 0.6594, Recall: 0.6403, F1-score: 0.6340
# --------------------------------------------------
# Epoch [125/1500]
# Train Loss: 1.3356, Train Acc: 0.9432
# Val Loss: 1.6647, Val Acc: 0.6187
# Precision: 0.6262, Recall: 0.6187, F1-score: 0.6165
# --------------------------------------------------
# Epoch [126/1500]
# Train Loss: 1.3279, Train Acc: 0.9492
# Val Loss: 1.6020, Val Acc: 0.6079
# Precision: 0.6239, Recall: 0.6079, F1-score: 0.6057
# --------------------------------------------------
# Epoch [127/1500]
# Train Loss: 1.3366, Train Acc: 0.9372
# Val Loss: 1.6787, Val Acc: 0.6331
# Precision: 0.6354, Recall: 0.6331, F1-score: 0.6292
# --------------------------------------------------
# Epoch [128/1500]
# Train Loss: 1.3318, Train Acc: 0.9484
# Val Loss: 1.6339, Val Acc: 0.6259
# Precision: 0.6362, Recall: 0.6259, F1-score: 0.6218
# --------------------------------------------------
# Epoch [129/1500]
# Train Loss: 1.3294, Train Acc: 0.9458
# Val Loss: 1.6304, Val Acc: 0.6367
# Precision: 0.6499, Recall: 0.6367, F1-score: 0.6300
# --------------------------------------------------
# Epoch [130/1500]
# Train Loss: 1.3256, Train Acc: 0.9527
# Val Loss: 1.6160, Val Acc: 0.6367
# Precision: 0.6394, Recall: 0.6367, F1-score: 0.6336
# --------------------------------------------------
# Epoch [131/1500]
# Train Loss: 1.3284, Train Acc: 0.9501
# Val Loss: 1.6007, Val Acc: 0.6727
# Precision: 0.7034, Recall: 0.6727, F1-score: 0.6681
# --------------------------------------------------
# Epoch [132/1500]
# Train Loss: 1.3238, Train Acc: 0.9492
# Val Loss: 1.5799, Val Acc: 0.6871
# Precision: 0.7020, Recall: 0.6871, F1-score: 0.6820
# --------------------------------------------------
# Epoch [133/1500]
# Train Loss: 1.3208, Train Acc: 0.9552
# Val Loss: 1.5732, Val Acc: 0.6727
# Precision: 0.6715, Recall: 0.6727, F1-score: 0.6677
# --------------------------------------------------
# Epoch [134/1500]
# Train Loss: 1.3247, Train Acc: 0.9535
# Val Loss: 1.5472, Val Acc: 0.6547
# Precision: 0.6624, Recall: 0.6547, F1-score: 0.6526
# --------------------------------------------------
# Epoch [135/1500]
# Train Loss: 1.3324, Train Acc: 0.9423
# Val Loss: 1.6149, Val Acc: 0.6439
# Precision: 0.6458, Recall: 0.6439, F1-score: 0.6384
# --------------------------------------------------
# Epoch [136/1500]
# Train Loss: 1.3430, Train Acc: 0.9303
# Val Loss: 1.6723, Val Acc: 0.6475
# Precision: 0.6574, Recall: 0.6475, F1-score: 0.6469
# --------------------------------------------------
# Epoch [137/1500]
# Train Loss: 1.3325, Train Acc: 0.9406
# Val Loss: 1.6136, Val Acc: 0.6079
# Precision: 0.6413, Recall: 0.6079, F1-score: 0.6094
# --------------------------------------------------
# Epoch [138/1500]
# Train Loss: 1.3403, Train Acc: 0.9355
# Val Loss: 1.5798, Val Acc: 0.6475
# Precision: 0.6695, Recall: 0.6475, F1-score: 0.6459
# --------------------------------------------------
# Epoch [139/1500]
# Train Loss: 1.3249, Train Acc: 0.9544
# Val Loss: 1.6491, Val Acc: 0.6439
# Precision: 0.6712, Recall: 0.6439, F1-score: 0.6467
# --------------------------------------------------
# Epoch [140/1500]
# Train Loss: 1.3250, Train Acc: 0.9527
# Val Loss: 1.6843, Val Acc: 0.6403
# Precision: 0.6519, Recall: 0.6403, F1-score: 0.6361
# --------------------------------------------------
# Epoch [141/1500]
# Train Loss: 1.3286, Train Acc: 0.9484
# Val Loss: 1.5887, Val Acc: 0.6655
# Precision: 0.6750, Recall: 0.6655, F1-score: 0.6622
# --------------------------------------------------
# Epoch [142/1500]
# Train Loss: 1.3261, Train Acc: 0.9501
# Val Loss: 1.5257, Val Acc: 0.7086
# Precision: 0.7226, Recall: 0.7086, F1-score: 0.7069
# --------------------------------------------------
# Epoch [143/1500]
# Train Loss: 1.3156, Train Acc: 0.9596
# Val Loss: 1.6329, Val Acc: 0.6295
# Precision: 0.6445, Recall: 0.6295, F1-score: 0.6289
# --------------------------------------------------
# Epoch [144/1500]
# Train Loss: 1.3132, Train Acc: 0.9596
# Val Loss: 1.5869, Val Acc: 0.6978
# Precision: 0.7091, Recall: 0.6978, F1-score: 0.6977
# --------------------------------------------------
# Epoch [145/1500]
# Train Loss: 1.3262, Train Acc: 0.9518
# Val Loss: 1.6192, Val Acc: 0.6655
# Precision: 0.6938, Recall: 0.6655, F1-score: 0.6663
# --------------------------------------------------
# Epoch [146/1500]
# Train Loss: 1.3303, Train Acc: 0.9449
# Val Loss: 1.5802, Val Acc: 0.6475
# Precision: 0.6713, Recall: 0.6475, F1-score: 0.6431
# --------------------------------------------------
# Epoch [147/1500]
# Train Loss: 1.3480, Train Acc: 0.9294
# Val Loss: 1.5715, Val Acc: 0.6475
# Precision: 0.6553, Recall: 0.6475, F1-score: 0.6475
# --------------------------------------------------
# Epoch [148/1500]
# Train Loss: 1.3268, Train Acc: 0.9492
# Val Loss: 1.5921, Val Acc: 0.6223
# Precision: 0.6344, Recall: 0.6223, F1-score: 0.6187
# --------------------------------------------------
# Epoch [149/1500]
# Train Loss: 1.3261, Train Acc: 0.9475
# Val Loss: 1.6323, Val Acc: 0.6223
# Precision: 0.6416, Recall: 0.6223, F1-score: 0.6247
# --------------------------------------------------
# Epoch [150/1500]
# Train Loss: 1.3227, Train Acc: 0.9544
# Val Loss: 1.6062, Val Acc: 0.6511
# Precision: 0.6682, Recall: 0.6511, F1-score: 0.6525
# --------------------------------------------------
# Epoch [151/1500]
# Train Loss: 1.3201, Train Acc: 0.9544
# Val Loss: 1.6585, Val Acc: 0.6223
# Precision: 0.6354, Recall: 0.6223, F1-score: 0.6232
# --------------------------------------------------
# Epoch [152/1500]
# Train Loss: 1.3112, Train Acc: 0.9630
# Val Loss: 1.6846, Val Acc: 0.6187
# Precision: 0.6321, Recall: 0.6187, F1-score: 0.6149
# --------------------------------------------------
# Epoch [153/1500]
# Train Loss: 1.3180, Train Acc: 0.9561
# Val Loss: 1.6186, Val Acc: 0.6691
# Precision: 0.6846, Recall: 0.6691, F1-score: 0.6715
# --------------------------------------------------
# Epoch [154/1500]
# Train Loss: 1.3124, Train Acc: 0.9647
# Val Loss: 1.5397, Val Acc: 0.6871
# Precision: 0.7008, Recall: 0.6871, F1-score: 0.6872
# --------------------------------------------------
# Epoch [155/1500]
# Train Loss: 1.3136, Train Acc: 0.9630
# Val Loss: 1.6056, Val Acc: 0.7014
# Precision: 0.7074, Recall: 0.7014, F1-score: 0.6990
# --------------------------------------------------
# Epoch [156/1500]
# Train Loss: 1.3113, Train Acc: 0.9621
# Val Loss: 1.6574, Val Acc: 0.6619
# Precision: 0.6743, Recall: 0.6619, F1-score: 0.6588
# --------------------------------------------------
# Epoch [157/1500]
# Train Loss: 1.3054, Train Acc: 0.9690
# Val Loss: 1.5732, Val Acc: 0.6942
# Precision: 0.7074, Recall: 0.6942, F1-score: 0.6949
# --------------------------------------------------
# Epoch [158/1500]
# Train Loss: 1.3050, Train Acc: 0.9707
# Val Loss: 1.6175, Val Acc: 0.6511
# Precision: 0.6729, Recall: 0.6511, F1-score: 0.6531
# --------------------------------------------------
# Epoch [159/1500]
# Train Loss: 1.3016, Train Acc: 0.9733
# Val Loss: 1.5842, Val Acc: 0.6799
# Precision: 0.6885, Recall: 0.6799, F1-score: 0.6788
# --------------------------------------------------
# Epoch [160/1500]
# Train Loss: 1.3065, Train Acc: 0.9682
# Val Loss: 1.5547, Val Acc: 0.7050
# Precision: 0.7168, Recall: 0.7050, F1-score: 0.7055
# --------------------------------------------------
# Epoch [161/1500]
# Train Loss: 1.3070, Train Acc: 0.9699
# Val Loss: 1.5551, Val Acc: 0.7050
# Precision: 0.7200, Recall: 0.7050, F1-score: 0.7059
# --------------------------------------------------
# Epoch [162/1500]
# Train Loss: 1.3056, Train Acc: 0.9699
# Val Loss: 1.5688, Val Acc: 0.6942
# Precision: 0.7088, Recall: 0.6942, F1-score: 0.6923
# --------------------------------------------------
# Epoch [163/1500]
# Train Loss: 1.3091, Train Acc: 0.9656
# Val Loss: 1.6296, Val Acc: 0.6583
# Precision: 0.6962, Recall: 0.6583, F1-score: 0.6569
# --------------------------------------------------
# Epoch [164/1500]
# Train Loss: 1.3073, Train Acc: 0.9682
# Val Loss: 1.6254, Val Acc: 0.6511
# Precision: 0.6920, Recall: 0.6511, F1-score: 0.6530
# --------------------------------------------------
# Epoch [165/1500]
# Train Loss: 1.3092, Train Acc: 0.9673
# Val Loss: 1.5780, Val Acc: 0.6906
# Precision: 0.7141, Recall: 0.6906, F1-score: 0.6908
# --------------------------------------------------
# Epoch [166/1500]
# Train Loss: 1.2993, Train Acc: 0.9742
# Val Loss: 1.5428, Val Acc: 0.7014
# Precision: 0.7047, Recall: 0.7014, F1-score: 0.6982
# --------------------------------------------------
# Epoch [167/1500]
# Train Loss: 1.3137, Train Acc: 0.9604
# Val Loss: 1.5319, Val Acc: 0.7050
# Precision: 0.7105, Recall: 0.7050, F1-score: 0.7015
# --------------------------------------------------
# Epoch [168/1500]
# Train Loss: 1.3117, Train Acc: 0.9630
# Val Loss: 1.5989, Val Acc: 0.6547
# Precision: 0.6775, Recall: 0.6547, F1-score: 0.6519
# --------------------------------------------------
# Epoch [169/1500]
# Train Loss: 1.3170, Train Acc: 0.9587
# Val Loss: 1.5936, Val Acc: 0.6763
# Precision: 0.7013, Recall: 0.6763, F1-score: 0.6754
# --------------------------------------------------
# Epoch [170/1500]
# Train Loss: 1.3155, Train Acc: 0.9587
# Val Loss: 1.5354, Val Acc: 0.6763
# Precision: 0.6789, Recall: 0.6763, F1-score: 0.6731
# --------------------------------------------------
# Epoch [171/1500]
# Train Loss: 1.3335, Train Acc: 0.9441
# Val Loss: 1.5702, Val Acc: 0.6151
# Precision: 0.6365, Recall: 0.6151, F1-score: 0.6149
# --------------------------------------------------
# Epoch [172/1500]
# Train Loss: 1.3308, Train Acc: 0.9441
# Val Loss: 1.5998, Val Acc: 0.6763
# Precision: 0.6850, Recall: 0.6763, F1-score: 0.6749
# --------------------------------------------------
# Epoch [173/1500]
# Train Loss: 1.3243, Train Acc: 0.9484
# Val Loss: 1.5618, Val Acc: 0.6942
# Precision: 0.7037, Recall: 0.6942, F1-score: 0.6953
# --------------------------------------------------
# Epoch [174/1500]
# Train Loss: 1.3285, Train Acc: 0.9492
# Val Loss: 1.5736, Val Acc: 0.6799
# Precision: 0.6916, Recall: 0.6799, F1-score: 0.6804
# --------------------------------------------------
# Epoch [175/1500]
# Train Loss: 1.3203, Train Acc: 0.9570
# Val Loss: 1.6077, Val Acc: 0.6583
# Precision: 0.6716, Recall: 0.6583, F1-score: 0.6606
# --------------------------------------------------
# Epoch [176/1500]
# Train Loss: 1.3117, Train Acc: 0.9639
# Val Loss: 1.5940, Val Acc: 0.6835
# Precision: 0.7025, Recall: 0.6835, F1-score: 0.6848
# --------------------------------------------------
# Epoch [177/1500]
# Train Loss: 1.3134, Train Acc: 0.9621
# Val Loss: 1.6226, Val Acc: 0.6295
# Precision: 0.6671, Recall: 0.6295, F1-score: 0.6291
# --------------------------------------------------
# Epoch [178/1500]
# Train Loss: 1.3165, Train Acc: 0.9613
# Val Loss: 1.5665, Val Acc: 0.6727
# Precision: 0.6849, Recall: 0.6727, F1-score: 0.6726
# --------------------------------------------------
# Epoch [179/1500]
# Train Loss: 1.3113, Train Acc: 0.9604
# Val Loss: 1.5660, Val Acc: 0.6799
# Precision: 0.6916, Recall: 0.6799, F1-score: 0.6826
# --------------------------------------------------
# Epoch [180/1500]
# Train Loss: 1.3170, Train Acc: 0.9587
# Val Loss: 1.5418, Val Acc: 0.7086
# Precision: 0.7218, Recall: 0.7086, F1-score: 0.7089
# --------------------------------------------------
# Epoch [181/1500]
# Train Loss: 1.3099, Train Acc: 0.9664
# Val Loss: 1.5953, Val Acc: 0.6835
# Precision: 0.7170, Recall: 0.6835, F1-score: 0.6872
# --------------------------------------------------
# Epoch [182/1500]
# Train Loss: 1.3105, Train Acc: 0.9630
# Val Loss: 1.5911, Val Acc: 0.6835
# Precision: 0.7045, Recall: 0.6835, F1-score: 0.6892
# --------------------------------------------------
# Epoch [183/1500]
# Train Loss: 1.3032, Train Acc: 0.9725
# Val Loss: 1.6195, Val Acc: 0.6691
# Precision: 0.6933, Recall: 0.6691, F1-score: 0.6645
# --------------------------------------------------
# Epoch [184/1500]
# Train Loss: 1.3118, Train Acc: 0.9621
# Val Loss: 1.5693, Val Acc: 0.7122
# Precision: 0.7277, Recall: 0.7122, F1-score: 0.7148
# --------------------------------------------------
# Epoch [185/1500]
# Train Loss: 1.3118, Train Acc: 0.9664
# Val Loss: 1.5648, Val Acc: 0.7014
# Precision: 0.7148, Recall: 0.7014, F1-score: 0.7035
# --------------------------------------------------
# Epoch [186/1500]
# Train Loss: 1.3148, Train Acc: 0.9630
# Val Loss: 1.5948, Val Acc: 0.7050
# Precision: 0.7177, Recall: 0.7050, F1-score: 0.7049
# --------------------------------------------------
# Epoch [187/1500]
# Train Loss: 1.3186, Train Acc: 0.9604
# Val Loss: 1.6011, Val Acc: 0.6619
# Precision: 0.6693, Recall: 0.6619, F1-score: 0.6629
# --------------------------------------------------
# Epoch [188/1500]
# Train Loss: 1.3190, Train Acc: 0.9570
# Val Loss: 1.6070, Val Acc: 0.6727
# Precision: 0.6806, Recall: 0.6727, F1-score: 0.6741
# --------------------------------------------------
# Epoch [189/1500]
# Train Loss: 1.3132, Train Acc: 0.9621
# Val Loss: 1.6154, Val Acc: 0.6403
# Precision: 0.6667, Recall: 0.6403, F1-score: 0.6421
# --------------------------------------------------
# Epoch [190/1500]
# Train Loss: 1.3073, Train Acc: 0.9664
# Val Loss: 1.5754, Val Acc: 0.6906
# Precision: 0.7343, Recall: 0.6906, F1-score: 0.6887
# --------------------------------------------------
# Epoch [191/1500]
# Train Loss: 1.3265, Train Acc: 0.9535
# Val Loss: 1.5893, Val Acc: 0.6835
# Precision: 0.6870, Recall: 0.6835, F1-score: 0.6797
# --------------------------------------------------
# Epoch [192/1500]
# Train Loss: 1.3056, Train Acc: 0.9690
# Val Loss: 1.5778, Val Acc: 0.6727
# Precision: 0.6953, Recall: 0.6727, F1-score: 0.6714
# --------------------------------------------------
# Epoch [193/1500]
# Train Loss: 1.3146, Train Acc: 0.9613
# Val Loss: 1.6017, Val Acc: 0.6547
# Precision: 0.6788, Recall: 0.6547, F1-score: 0.6539
# --------------------------------------------------
# Epoch [194/1500]
# Train Loss: 1.3058, Train Acc: 0.9656
# Val Loss: 1.5578, Val Acc: 0.6763
# Precision: 0.7029, Recall: 0.6763, F1-score: 0.6766
# --------------------------------------------------
# Epoch [195/1500]
# Train Loss: 1.3071, Train Acc: 0.9690
# Val Loss: 1.6714, Val Acc: 0.6403
# Precision: 0.6491, Recall: 0.6403, F1-score: 0.6401
# --------------------------------------------------
# Epoch [196/1500]
# Train Loss: 1.3148, Train Acc: 0.9656
# Val Loss: 1.6767, Val Acc: 0.6367
# Precision: 0.6807, Recall: 0.6367, F1-score: 0.6428
# --------------------------------------------------
# Epoch [197/1500]
# Train Loss: 1.3170, Train Acc: 0.9570
# Val Loss: 1.6161, Val Acc: 0.6835
# Precision: 0.7043, Recall: 0.6835, F1-score: 0.6848
# --------------------------------------------------
# Epoch [198/1500]
# Train Loss: 1.3201, Train Acc: 0.9570
# Val Loss: 1.6192, Val Acc: 0.6439
# Precision: 0.6454, Recall: 0.6439, F1-score: 0.6376
# --------------------------------------------------
# Epoch [199/1500]
# Train Loss: 1.3127, Train Acc: 0.9621
# Val Loss: 1.6346, Val Acc: 0.6655
# Precision: 0.6837, Recall: 0.6655, F1-score: 0.6633
# --------------------------------------------------
# Epoch [200/1500]
# Train Loss: 1.3231, Train Acc: 0.9527
# Val Loss: 1.5793, Val Acc: 0.7014
# Precision: 0.7186, Recall: 0.7014, F1-score: 0.7003
# --------------------------------------------------
# Epoch [201/1500]
# Train Loss: 1.3073, Train Acc: 0.9664
# Val Loss: 1.6125, Val Acc: 0.6906
# Precision: 0.6961, Recall: 0.6906, F1-score: 0.6910
# --------------------------------------------------
# Epoch [202/1500]
# Train Loss: 1.3155, Train Acc: 0.9587
# Val Loss: 1.6247, Val Acc: 0.6655
# Precision: 0.6734, Recall: 0.6655, F1-score: 0.6629
# --------------------------------------------------
# Epoch [203/1500]
# Train Loss: 1.3028, Train Acc: 0.9725
# Val Loss: 1.6001, Val Acc: 0.6835
# Precision: 0.6977, Recall: 0.6835, F1-score: 0.6832
# --------------------------------------------------
# Epoch [204/1500]
# Train Loss: 1.3142, Train Acc: 0.9621
# Val Loss: 1.6250, Val Acc: 0.6727
# Precision: 0.6787, Recall: 0.6727, F1-score: 0.6728
# --------------------------------------------------
# Epoch [205/1500]
# Train Loss: 1.3068, Train Acc: 0.9682
# Val Loss: 1.6491, Val Acc: 0.6439
# Precision: 0.6678, Recall: 0.6439, F1-score: 0.6467
# --------------------------------------------------
# Epoch [206/1500]
# Train Loss: 1.3050, Train Acc: 0.9673
# Val Loss: 1.5935, Val Acc: 0.6978
# Precision: 0.7165, Recall: 0.6978, F1-score: 0.6959
# --------------------------------------------------
# Epoch [207/1500]
# Train Loss: 1.3001, Train Acc: 0.9742
# Val Loss: 1.5727, Val Acc: 0.6727
# Precision: 0.6774, Recall: 0.6727, F1-score: 0.6691
# --------------------------------------------------
# Epoch [208/1500]
# Train Loss: 1.3024, Train Acc: 0.9716
# Val Loss: 1.5618, Val Acc: 0.6942
# Precision: 0.7018, Recall: 0.6942, F1-score: 0.6957
# --------------------------------------------------
# Epoch [209/1500]
# Train Loss: 1.3071, Train Acc: 0.9647
# Val Loss: 1.5944, Val Acc: 0.6871
# Precision: 0.6935, Recall: 0.6871, F1-score: 0.6851
# --------------------------------------------------
# Epoch [210/1500]
# Train Loss: 1.3096, Train Acc: 0.9690
# Val Loss: 1.5960, Val Acc: 0.6547
# Precision: 0.6800, Recall: 0.6547, F1-score: 0.6528
# --------------------------------------------------
# Epoch [211/1500]
# Train Loss: 1.3007, Train Acc: 0.9768
# Val Loss: 1.5314, Val Acc: 0.6978
# Precision: 0.7006, Recall: 0.6978, F1-score: 0.6959
# --------------------------------------------------
# Epoch [212/1500]
# Train Loss: 1.3010, Train Acc: 0.9750
# Val Loss: 1.5707, Val Acc: 0.6871
# Precision: 0.6926, Recall: 0.6871, F1-score: 0.6871
# --------------------------------------------------
# Epoch [213/1500]
# Train Loss: 1.3013, Train Acc: 0.9716
# Val Loss: 1.5715, Val Acc: 0.6655
# Precision: 0.6861, Recall: 0.6655, F1-score: 0.6665
# --------------------------------------------------
# Epoch [214/1500]
# Train Loss: 1.3002, Train Acc: 0.9716
# Val Loss: 1.5650, Val Acc: 0.6439
# Precision: 0.6992, Recall: 0.6439, F1-score: 0.6456
# --------------------------------------------------
# Epoch [215/1500]
# Train Loss: 1.3002, Train Acc: 0.9733
# Val Loss: 1.5576, Val Acc: 0.7194
# Precision: 0.7292, Recall: 0.7194, F1-score: 0.7188
# --------------------------------------------------
# Epoch [216/1500]
# Train Loss: 1.2951, Train Acc: 0.9793
# Val Loss: 1.5703, Val Acc: 0.7194
# Precision: 0.7256, Recall: 0.7194, F1-score: 0.7180
# --------------------------------------------------
# Epoch [217/1500]
# Train Loss: 1.2932, Train Acc: 0.9793
# Val Loss: 1.5921, Val Acc: 0.7014
# Precision: 0.7125, Recall: 0.7014, F1-score: 0.7029
# --------------------------------------------------
# Epoch [218/1500]
# Train Loss: 1.3040, Train Acc: 0.9716
# Val Loss: 1.5734, Val Acc: 0.6727
# Precision: 0.7038, Recall: 0.6727, F1-score: 0.6703
# --------------------------------------------------
# Epoch [219/1500]
# Train Loss: 1.3057, Train Acc: 0.9682
# Val Loss: 1.6182, Val Acc: 0.6331
# Precision: 0.6588, Recall: 0.6331, F1-score: 0.6308
# --------------------------------------------------
# Epoch [220/1500]
# Train Loss: 1.3138, Train Acc: 0.9613
# Val Loss: 1.6704, Val Acc: 0.6295
# Precision: 0.6552, Recall: 0.6295, F1-score: 0.6300
# --------------------------------------------------
# Epoch [221/1500]
# Train Loss: 1.3102, Train Acc: 0.9639
# Val Loss: 1.5788, Val Acc: 0.6511
# Precision: 0.6587, Recall: 0.6511, F1-score: 0.6510
# --------------------------------------------------
# Epoch [222/1500]
# Train Loss: 1.3096, Train Acc: 0.9613
# Val Loss: 1.4944, Val Acc: 0.7014
# Precision: 0.7153, Recall: 0.7014, F1-score: 0.7024
# --------------------------------------------------
# Epoch [223/1500]
# Train Loss: 1.2959, Train Acc: 0.9811
# Val Loss: 1.5254, Val Acc: 0.6942
# Precision: 0.6996, Recall: 0.6942, F1-score: 0.6944
# --------------------------------------------------
# Epoch [224/1500]
# Train Loss: 1.3021, Train Acc: 0.9725
# Val Loss: 1.5723, Val Acc: 0.6799
# Precision: 0.6924, Recall: 0.6799, F1-score: 0.6813
# --------------------------------------------------
# Epoch [225/1500]
# Train Loss: 1.2977, Train Acc: 0.9759
# Val Loss: 1.5380, Val Acc: 0.7122
# Precision: 0.7216, Recall: 0.7122, F1-score: 0.7127
# --------------------------------------------------
# Epoch [226/1500]
# Train Loss: 1.2970, Train Acc: 0.9759
# Val Loss: 1.5750, Val Acc: 0.6691
# Precision: 0.6762, Recall: 0.6691, F1-score: 0.6667
# --------------------------------------------------
# Epoch [227/1500]
# Train Loss: 1.3025, Train Acc: 0.9725
# Val Loss: 1.5950, Val Acc: 0.6799
# Precision: 0.6866, Recall: 0.6799, F1-score: 0.6763
# --------------------------------------------------
# Epoch [228/1500]
# Train Loss: 1.3027, Train Acc: 0.9699
# Val Loss: 1.5520, Val Acc: 0.6871
# Precision: 0.6997, Recall: 0.6871, F1-score: 0.6836
# --------------------------------------------------
# Epoch [229/1500]
# Train Loss: 1.3025, Train Acc: 0.9733
# Val Loss: 1.5784, Val Acc: 0.6691
# Precision: 0.6836, Recall: 0.6691, F1-score: 0.6650
# --------------------------------------------------
# Epoch [230/1500]
# Train Loss: 1.3005, Train Acc: 0.9742
# Val Loss: 1.6086, Val Acc: 0.6475
# Precision: 0.6611, Recall: 0.6475, F1-score: 0.6435
# --------------------------------------------------
# Epoch [231/1500]
# Train Loss: 1.3005, Train Acc: 0.9750
# Val Loss: 1.5865, Val Acc: 0.6403
# Precision: 0.6694, Recall: 0.6403, F1-score: 0.6369
# --------------------------------------------------
# Epoch [232/1500]
# Train Loss: 1.3060, Train Acc: 0.9716
# Val Loss: 1.5770, Val Acc: 0.7050
# Precision: 0.7202, Recall: 0.7050, F1-score: 0.7055
# --------------------------------------------------
# Epoch [233/1500]
# Train Loss: 1.2958, Train Acc: 0.9785
# Val Loss: 1.6533, Val Acc: 0.6691
# Precision: 0.6913, Recall: 0.6691, F1-score: 0.6658
# --------------------------------------------------
# Epoch [234/1500]
# Train Loss: 1.3107, Train Acc: 0.9673
# Val Loss: 1.5875, Val Acc: 0.6906
# Precision: 0.7201, Recall: 0.6906, F1-score: 0.6950
# --------------------------------------------------
# Epoch [235/1500]
# Train Loss: 1.3085, Train Acc: 0.9664
# Val Loss: 1.6076, Val Acc: 0.6655
# Precision: 0.6690, Recall: 0.6655, F1-score: 0.6623
# --------------------------------------------------
# Epoch [236/1500]
# Train Loss: 1.3122, Train Acc: 0.9604
# Val Loss: 1.5881, Val Acc: 0.6799
# Precision: 0.6980, Recall: 0.6799, F1-score: 0.6814
# --------------------------------------------------
# Epoch [237/1500]
# Train Loss: 1.3062, Train Acc: 0.9725
# Val Loss: 1.6168, Val Acc: 0.6259
# Precision: 0.6440, Recall: 0.6259, F1-score: 0.6281
# --------------------------------------------------
# Epoch [238/1500]
# Train Loss: 1.3109, Train Acc: 0.9664
# Val Loss: 1.5857, Val Acc: 0.6691
# Precision: 0.6881, Recall: 0.6691, F1-score: 0.6693
# --------------------------------------------------
# Epoch [239/1500]
# Train Loss: 1.3057, Train Acc: 0.9699
# Val Loss: 1.5839, Val Acc: 0.6835
# Precision: 0.7046, Recall: 0.6835, F1-score: 0.6838
# --------------------------------------------------
# Epoch [240/1500]
# Train Loss: 1.3149, Train Acc: 0.9587
# Val Loss: 1.6652, Val Acc: 0.6475
# Precision: 0.6651, Recall: 0.6475, F1-score: 0.6464
# --------------------------------------------------
# Epoch [241/1500]
# Train Loss: 1.3151, Train Acc: 0.9604
# Val Loss: 1.5890, Val Acc: 0.7014
# Precision: 0.7123, Recall: 0.7014, F1-score: 0.6983
# --------------------------------------------------
# Epoch [242/1500]
# Train Loss: 1.3112, Train Acc: 0.9621
# Val Loss: 1.5715, Val Acc: 0.6871
# Precision: 0.7004, Recall: 0.6871, F1-score: 0.6842
# --------------------------------------------------
# Epoch [243/1500]
# Train Loss: 1.3116, Train Acc: 0.9647
# Val Loss: 1.5701, Val Acc: 0.7014
# Precision: 0.7050, Recall: 0.7014, F1-score: 0.7015
# --------------------------------------------------
# Epoch [244/1500]
# Train Loss: 1.3061, Train Acc: 0.9707
# Val Loss: 1.5669, Val Acc: 0.6799
# Precision: 0.6957, Recall: 0.6799, F1-score: 0.6794
# --------------------------------------------------
# Epoch [245/1500]
# Train Loss: 1.3149, Train Acc: 0.9604
# Val Loss: 1.6211, Val Acc: 0.6583
# Precision: 0.6702, Recall: 0.6583, F1-score: 0.6548
# --------------------------------------------------
# Epoch [246/1500]
# Train Loss: 1.3074, Train Acc: 0.9673
# Val Loss: 1.6208, Val Acc: 0.6475
# Precision: 0.6672, Recall: 0.6475, F1-score: 0.6422
# --------------------------------------------------
# Epoch [247/1500]
# Train Loss: 1.3047, Train Acc: 0.9716
# Val Loss: 1.5858, Val Acc: 0.7050
# Precision: 0.7130, Recall: 0.7050, F1-score: 0.7057
# --------------------------------------------------
# Epoch [248/1500]
# Train Loss: 1.3050, Train Acc: 0.9690
# Val Loss: 1.6222, Val Acc: 0.6583
# Precision: 0.6660, Recall: 0.6583, F1-score: 0.6602
# --------------------------------------------------
# Epoch [249/1500]
# Train Loss: 1.3057, Train Acc: 0.9707
# Val Loss: 1.5787, Val Acc: 0.7122
# Precision: 0.7260, Recall: 0.7122, F1-score: 0.7119
# --------------------------------------------------
# Epoch [250/1500]
# Train Loss: 1.3005, Train Acc: 0.9725
# Val Loss: 1.6270, Val Acc: 0.6511
# Precision: 0.6789, Recall: 0.6511, F1-score: 0.6540
# --------------------------------------------------
# Epoch [251/1500]
# Train Loss: 1.3274, Train Acc: 0.9475
# Val Loss: 1.6465, Val Acc: 0.6151
# ...
# Val Loss: 1.5981, Val Acc: 0.6799
# Precision: 0.6915, Recall: 0.6799, F1-score: 0.6795
# --------------------------------------------------
# Epoch [1419/1500]
# Train Loss: 1.2892, Train Acc: 0.9854
# Val Loss: 1.6235, Val Acc: 0.6906
# Precision: 0.6982, Recall: 0.6906, F1-score: 0.6896
# --------------------------------------------------
# Epoch [1420/1500]
# Train Loss: 1.2898, Train Acc: 0.9845
# Val Loss: 1.6400, Val Acc: 0.6978
# Precision: 0.7015, Recall: 0.6978, F1-score: 0.6971
# --------------------------------------------------
# Epoch [1421/1500]
# Train Loss: 1.2848, Train Acc: 0.9888
# Val Loss: 1.6782, Val Acc: 0.6691
# Precision: 0.6821, Recall: 0.6691, F1-score: 0.6678
# --------------------------------------------------
# Epoch [1422/1500]
# Train Loss: 1.3041, Train Acc: 0.9716
# Val Loss: 1.6340, Val Acc: 0.6835
# Precision: 0.6926, Recall: 0.6835, F1-score: 0.6838
# --------------------------------------------------
# Epoch [1423/1500]
# Train Loss: 1.2948, Train Acc: 0.9811
# Val Loss: 1.6105, Val Acc: 0.6727
# Precision: 0.6779, Recall: 0.6727, F1-score: 0.6728
# --------------------------------------------------
# Epoch [1424/1500]
# Train Loss: 1.2960, Train Acc: 0.9785
# Val Loss: 1.6334, Val Acc: 0.6475
# Precision: 0.6558, Recall: 0.6475, F1-score: 0.6470
# --------------------------------------------------
# Epoch [1425/1500]
# Train Loss: 1.3114, Train Acc: 0.9664
# Val Loss: 1.6703, Val Acc: 0.6475
# Precision: 0.6575, Recall: 0.6475, F1-score: 0.6450
# --------------------------------------------------
# Epoch [1426/1500]
# Train Loss: 1.3034, Train Acc: 0.9707
# Val Loss: 1.6736, Val Acc: 0.6367
# Precision: 0.6484, Recall: 0.6367, F1-score: 0.6323
# --------------------------------------------------
# Epoch [1427/1500]
# Train Loss: 1.3009, Train Acc: 0.9742
# Val Loss: 1.5800, Val Acc: 0.6978
# Precision: 0.7048, Recall: 0.6978, F1-score: 0.6948
# --------------------------------------------------
# Epoch [1428/1500]
# Train Loss: 1.2937, Train Acc: 0.9802
# Val Loss: 1.5656, Val Acc: 0.6942
# Precision: 0.7052, Recall: 0.6942, F1-score: 0.6922
# --------------------------------------------------
# Epoch [1429/1500]
# Train Loss: 1.2962, Train Acc: 0.9776
# Val Loss: 1.5720, Val Acc: 0.6691
# Precision: 0.6924, Recall: 0.6691, F1-score: 0.6697
# --------------------------------------------------
# Epoch [1430/1500]
# Train Loss: 1.2982, Train Acc: 0.9785
# Val Loss: 1.5628, Val Acc: 0.6691
# Precision: 0.6944, Recall: 0.6691, F1-score: 0.6672
# --------------------------------------------------
# Epoch [1431/1500]
# Train Loss: 1.2946, Train Acc: 0.9785
# Val Loss: 1.6133, Val Acc: 0.6727
# Precision: 0.7019, Recall: 0.6727, F1-score: 0.6710
# --------------------------------------------------
# Epoch [1432/1500]
# Train Loss: 1.2904, Train Acc: 0.9828
# Val Loss: 1.5749, Val Acc: 0.6835
# Precision: 0.7023, Recall: 0.6835, F1-score: 0.6792
# --------------------------------------------------
# Epoch [1433/1500]
# Train Loss: 1.2900, Train Acc: 0.9836
# Val Loss: 1.5697, Val Acc: 0.6871
# Precision: 0.7003, Recall: 0.6871, F1-score: 0.6847
# --------------------------------------------------
# Epoch [1434/1500]
# Train Loss: 1.2980, Train Acc: 0.9768
# Val Loss: 1.5830, Val Acc: 0.6547
# Precision: 0.6680, Recall: 0.6547, F1-score: 0.6523
# --------------------------------------------------
# Epoch [1435/1500]
# Train Loss: 1.2921, Train Acc: 0.9802
# Val Loss: 1.6143, Val Acc: 0.6727
# Precision: 0.6891, Recall: 0.6727, F1-score: 0.6701
# --------------------------------------------------
# Epoch [1436/1500]
# Train Loss: 1.2913, Train Acc: 0.9836
# Val Loss: 1.5831, Val Acc: 0.6691
# Precision: 0.6913, Recall: 0.6691, F1-score: 0.6679
# --------------------------------------------------
# Epoch [1437/1500]
# Train Loss: 1.2860, Train Acc: 0.9880
# Val Loss: 1.5834, Val Acc: 0.6511
# Precision: 0.6757, Recall: 0.6511, F1-score: 0.6500
# --------------------------------------------------
# Epoch [1438/1500]
# Train Loss: 1.2885, Train Acc: 0.9854
# Val Loss: 1.5873, Val Acc: 0.6763
# Precision: 0.7012, Recall: 0.6763, F1-score: 0.6745
# --------------------------------------------------
# Epoch [1439/1500]
# Train Loss: 1.2850, Train Acc: 0.9897
# Val Loss: 1.5931, Val Acc: 0.6691
# Precision: 0.6997, Recall: 0.6691, F1-score: 0.6656
# --------------------------------------------------
# Epoch [1440/1500]
# Train Loss: 1.2866, Train Acc: 0.9871
# Val Loss: 1.6020, Val Acc: 0.6655
# Precision: 0.6891, Recall: 0.6655, F1-score: 0.6620
# --------------------------------------------------
# Epoch [1441/1500]
# Train Loss: 1.2852, Train Acc: 0.9897
# Val Loss: 1.5958, Val Acc: 0.6727
# Precision: 0.6911, Recall: 0.6727, F1-score: 0.6699
# --------------------------------------------------
# Epoch [1442/1500]
# Train Loss: 1.2894, Train Acc: 0.9845
# Val Loss: 1.5909, Val Acc: 0.6799
# Precision: 0.6956, Recall: 0.6799, F1-score: 0.6779
# --------------------------------------------------
# Epoch [1443/1500]
# Train Loss: 1.2897, Train Acc: 0.9854
# Val Loss: 1.5895, Val Acc: 0.6871
# Precision: 0.6993, Recall: 0.6871, F1-score: 0.6858
# --------------------------------------------------
# Epoch [1444/1500]
# Train Loss: 1.2882, Train Acc: 0.9880
# Val Loss: 1.6341, Val Acc: 0.6583
# Precision: 0.6726, Recall: 0.6583, F1-score: 0.6563
# --------------------------------------------------
# Epoch [1445/1500]
# Train Loss: 1.2888, Train Acc: 0.9845
# Val Loss: 1.5560, Val Acc: 0.6799
# Precision: 0.6894, Recall: 0.6799, F1-score: 0.6780
# --------------------------------------------------
# Epoch [1446/1500]
# Train Loss: 1.2872, Train Acc: 0.9854
# Val Loss: 1.5743, Val Acc: 0.6439
# Precision: 0.6611, Recall: 0.6439, F1-score: 0.6380
# --------------------------------------------------
# Epoch [1447/1500]
# Train Loss: 1.3021, Train Acc: 0.9699
# Val Loss: 1.5553, Val Acc: 0.6727
# Precision: 0.6890, Recall: 0.6727, F1-score: 0.6712
# --------------------------------------------------
# Epoch [1448/1500]
# Train Loss: 1.2884, Train Acc: 0.9836
# Val Loss: 1.5587, Val Acc: 0.6727
# Precision: 0.6874, Recall: 0.6727, F1-score: 0.6725
# --------------------------------------------------
# Epoch [1449/1500]
# Train Loss: 1.2912, Train Acc: 0.9845
# Val Loss: 1.5842, Val Acc: 0.6655
# Precision: 0.6885, Recall: 0.6655, F1-score: 0.6672
# --------------------------------------------------
# Epoch [1450/1500]
# Train Loss: 1.2896, Train Acc: 0.9845
# Val Loss: 1.5861, Val Acc: 0.6799
# Precision: 0.7022, Recall: 0.6799, F1-score: 0.6826
# --------------------------------------------------
# Epoch [1451/1500]
# Train Loss: 1.2894, Train Acc: 0.9880
# Val Loss: 1.5956, Val Acc: 0.6691
# Precision: 0.6893, Recall: 0.6691, F1-score: 0.6708
# --------------------------------------------------
# Epoch [1452/1500]
# Train Loss: 1.2892, Train Acc: 0.9854
# Val Loss: 1.6185, Val Acc: 0.6691
# Precision: 0.6893, Recall: 0.6691, F1-score: 0.6697
# --------------------------------------------------
# Epoch [1453/1500]
# Train Loss: 1.2852, Train Acc: 0.9880
# Val Loss: 1.5946, Val Acc: 0.6655
# Precision: 0.6874, Recall: 0.6655, F1-score: 0.6667
# --------------------------------------------------
# Epoch [1454/1500]
# Train Loss: 1.2874, Train Acc: 0.9862
# Val Loss: 1.5560, Val Acc: 0.6619
# Precision: 0.6792, Recall: 0.6619, F1-score: 0.6607
# --------------------------------------------------
# Epoch [1455/1500]
# Train Loss: 1.2917, Train Acc: 0.9819
# Val Loss: 1.6360, Val Acc: 0.6331
# Precision: 0.6463, Recall: 0.6331, F1-score: 0.6286
# --------------------------------------------------
# Epoch [1456/1500]
# Train Loss: 1.2960, Train Acc: 0.9785
# Val Loss: 1.7151, Val Acc: 0.6079
# Precision: 0.6189, Recall: 0.6079, F1-score: 0.6049
# --------------------------------------------------
# Epoch [1457/1500]
# Train Loss: 1.3167, Train Acc: 0.9578
# Val Loss: 1.6864, Val Acc: 0.6151
# Precision: 0.6179, Recall: 0.6151, F1-score: 0.6088
# --------------------------------------------------
# Epoch [1458/1500]
# Train Loss: 1.3121, Train Acc: 0.9621
# Val Loss: 1.6245, Val Acc: 0.6439
# Precision: 0.6486, Recall: 0.6439, F1-score: 0.6411
# --------------------------------------------------
# Epoch [1459/1500]
# Train Loss: 1.3064, Train Acc: 0.9682
# Val Loss: 1.5769, Val Acc: 0.6655
# Precision: 0.6781, Recall: 0.6655, F1-score: 0.6647
# --------------------------------------------------
# Epoch [1460/1500]
# Train Loss: 1.2959, Train Acc: 0.9776
# Val Loss: 1.5900, Val Acc: 0.6583
# Precision: 0.6818, Recall: 0.6583, F1-score: 0.6584
# --------------------------------------------------
# Epoch [1461/1500]
# Train Loss: 1.2976, Train Acc: 0.9759
# Val Loss: 1.6025, Val Acc: 0.6439
# Precision: 0.6573, Recall: 0.6439, F1-score: 0.6425
# --------------------------------------------------
# Epoch [1462/1500]
# Train Loss: 1.2971, Train Acc: 0.9768
# Val Loss: 1.6110, Val Acc: 0.6475
# Precision: 0.6540, Recall: 0.6475, F1-score: 0.6444
# --------------------------------------------------
# Epoch [1463/1500]
# Train Loss: 1.2926, Train Acc: 0.9836
# Val Loss: 1.6220, Val Acc: 0.6475
# Precision: 0.6519, Recall: 0.6475, F1-score: 0.6416
# --------------------------------------------------
# Epoch [1464/1500]
# Train Loss: 1.2917, Train Acc: 0.9811
# Val Loss: 1.6630, Val Acc: 0.6259
# Precision: 0.6480, Recall: 0.6259, F1-score: 0.6243
# --------------------------------------------------
# Epoch [1465/1500]
# Train Loss: 1.3026, Train Acc: 0.9725
# Val Loss: 1.6148, Val Acc: 0.6187
# Precision: 0.6411, Recall: 0.6187, F1-score: 0.6157
# --------------------------------------------------
# Epoch [1466/1500]
# Train Loss: 1.3130, Train Acc: 0.9630
# Val Loss: 1.6454, Val Acc: 0.6331
# Precision: 0.6423, Recall: 0.6331, F1-score: 0.6334
# --------------------------------------------------
# Epoch [1467/1500]
# Train Loss: 1.3123, Train Acc: 0.9621
# Val Loss: 1.6569, Val Acc: 0.6151
# Precision: 0.6303, Recall: 0.6151, F1-score: 0.6160
# --------------------------------------------------
# Epoch [1468/1500]
# Train Loss: 1.3110, Train Acc: 0.9656
# Val Loss: 1.6188, Val Acc: 0.6295
# Precision: 0.6465, Recall: 0.6295, F1-score: 0.6276
# --------------------------------------------------
# Epoch [1469/1500]
# Train Loss: 1.3045, Train Acc: 0.9716
# Val Loss: 1.5920, Val Acc: 0.6439
# Precision: 0.6568, Recall: 0.6439, F1-score: 0.6456
# --------------------------------------------------
# Epoch [1470/1500]
# Train Loss: 1.2980, Train Acc: 0.9742
# Val Loss: 1.6001, Val Acc: 0.6367
# Precision: 0.6504, Recall: 0.6367, F1-score: 0.6358
# --------------------------------------------------
# Epoch [1471/1500]
# Train Loss: 1.3009, Train Acc: 0.9750
# Val Loss: 1.6569, Val Acc: 0.6295
# Precision: 0.6380, Recall: 0.6295, F1-score: 0.6274
# --------------------------------------------------
# Epoch [1472/1500]
# Train Loss: 1.2946, Train Acc: 0.9802
# Val Loss: 1.6040, Val Acc: 0.7014
# Precision: 0.7116, Recall: 0.7014, F1-score: 0.7014
# --------------------------------------------------
# Epoch [1473/1500]
# Train Loss: 1.2886, Train Acc: 0.9862
# Val Loss: 1.6529, Val Acc: 0.6619
# Precision: 0.6770, Recall: 0.6619, F1-score: 0.6625
# --------------------------------------------------
# Epoch [1474/1500]
# Train Loss: 1.2959, Train Acc: 0.9802
# Val Loss: 1.6581, Val Acc: 0.6583
# Precision: 0.6637, Recall: 0.6583, F1-score: 0.6577
# --------------------------------------------------
# Epoch [1475/1500]
# Train Loss: 1.2957, Train Acc: 0.9793
# Val Loss: 1.6804, Val Acc: 0.6331
# Precision: 0.6396, Recall: 0.6331, F1-score: 0.6311
# --------------------------------------------------
# Epoch [1476/1500]
# Train Loss: 1.2900, Train Acc: 0.9854
# Val Loss: 1.6071, Val Acc: 0.6475
# Precision: 0.6603, Recall: 0.6475, F1-score: 0.6444
# --------------------------------------------------
# Epoch [1477/1500]
# Train Loss: 1.2981, Train Acc: 0.9768
# Val Loss: 1.6577, Val Acc: 0.5935
# Precision: 0.6189, Recall: 0.5935, F1-score: 0.5886
# --------------------------------------------------
# Epoch [1478/1500]
# Train Loss: 1.3085, Train Acc: 0.9673
# Val Loss: 1.6841, Val Acc: 0.6079
# Precision: 0.6202, Recall: 0.6079, F1-score: 0.6030
# --------------------------------------------------
# Epoch [1479/1500]
# Train Loss: 1.3153, Train Acc: 0.9596
# Val Loss: 1.6393, Val Acc: 0.6367
# Precision: 0.6531, Recall: 0.6367, F1-score: 0.6333
# --------------------------------------------------
# Epoch [1480/1500]
# Train Loss: 1.3103, Train Acc: 0.9630
# Val Loss: 1.6699, Val Acc: 0.6295
# Precision: 0.6557, Recall: 0.6295, F1-score: 0.6270
# --------------------------------------------------
# Epoch [1481/1500]
# Train Loss: 1.3054, Train Acc: 0.9699
# Val Loss: 1.6576, Val Acc: 0.6403
# Precision: 0.6550, Recall: 0.6403, F1-score: 0.6365
# --------------------------------------------------
# Epoch [1482/1500]
# Train Loss: 1.3092, Train Acc: 0.9707
# Val Loss: 1.6974, Val Acc: 0.6331
# Precision: 0.6391, Recall: 0.6331, F1-score: 0.6347
# --------------------------------------------------
# Epoch [1483/1500]
# Train Loss: 1.3072, Train Acc: 0.9664
# Val Loss: 1.7006, Val Acc: 0.6331
# Precision: 0.6386, Recall: 0.6331, F1-score: 0.6328
# --------------------------------------------------
# Epoch [1484/1500]
# Train Loss: 1.2958, Train Acc: 0.9785
# Val Loss: 1.6688, Val Acc: 0.6511
# Precision: 0.6593, Recall: 0.6511, F1-score: 0.6506
# --------------------------------------------------
# Epoch [1485/1500]
# Train Loss: 1.2953, Train Acc: 0.9811
# Val Loss: 1.6387, Val Acc: 0.6403
# Precision: 0.6605, Recall: 0.6403, F1-score: 0.6386
# --------------------------------------------------
# Epoch [1486/1500]
# Train Loss: 1.2980, Train Acc: 0.9768
# Val Loss: 1.6491, Val Acc: 0.6403
# Precision: 0.6661, Recall: 0.6403, F1-score: 0.6424
# --------------------------------------------------
# Epoch [1487/1500]
# Train Loss: 1.2952, Train Acc: 0.9759
# Val Loss: 1.6521, Val Acc: 0.6511
# Precision: 0.6557, Recall: 0.6511, F1-score: 0.6511
# --------------------------------------------------
# Epoch [1488/1500]
# Train Loss: 1.2913, Train Acc: 0.9836
# Val Loss: 1.7104, Val Acc: 0.6259
# Precision: 0.6423, Recall: 0.6259, F1-score: 0.6264
# --------------------------------------------------
# Epoch [1489/1500]
# Train Loss: 1.2951, Train Acc: 0.9785
# Val Loss: 1.6595, Val Acc: 0.6331
# Precision: 0.6499, Recall: 0.6331, F1-score: 0.6307
# --------------------------------------------------
# Epoch [1490/1500]
# Train Loss: 1.2879, Train Acc: 0.9871
# Val Loss: 1.6458, Val Acc: 0.6619
# Precision: 0.6789, Recall: 0.6619, F1-score: 0.6563
# --------------------------------------------------
# Epoch [1491/1500]
# Train Loss: 1.2872, Train Acc: 0.9880
# Val Loss: 1.6804, Val Acc: 0.6331
# Precision: 0.6498, Recall: 0.6331, F1-score: 0.6328
# --------------------------------------------------
# Epoch [1492/1500]
# Train Loss: 1.2943, Train Acc: 0.9828
# Val Loss: 1.6694, Val Acc: 0.6367
# Precision: 0.6523, Recall: 0.6367, F1-score: 0.6367
# --------------------------------------------------
# Epoch [1493/1500]
# Train Loss: 1.2877, Train Acc: 0.9871
# Val Loss: 1.6124, Val Acc: 0.6439
# Precision: 0.6605, Recall: 0.6439, F1-score: 0.6412
# --------------------------------------------------
# Epoch [1494/1500]
# Train Loss: 1.2913, Train Acc: 0.9845
# Val Loss: 1.6442, Val Acc: 0.6187
# Precision: 0.6371, Recall: 0.6187, F1-score: 0.6174
# --------------------------------------------------
# Epoch [1495/1500]
# Train Loss: 1.2966, Train Acc: 0.9768
# Val Loss: 1.6591, Val Acc: 0.6295
# Precision: 0.6452, Recall: 0.6295, F1-score: 0.6307
# --------------------------------------------------
# Epoch [1496/1500]
# Train Loss: 1.2906, Train Acc: 0.9845
# Val Loss: 1.6292, Val Acc: 0.6403
# Precision: 0.6617, Recall: 0.6403, F1-score: 0.6394
# --------------------------------------------------
# Epoch [1497/1500]
# Train Loss: 1.2922, Train Acc: 0.9836
# Val Loss: 1.6861, Val Acc: 0.6079
# Precision: 0.6354, Recall: 0.6079, F1-score: 0.6066
# --------------------------------------------------
# Epoch [1498/1500]
# Train Loss: 1.2865, Train Acc: 0.9871
# Val Loss: 1.6543, Val Acc: 0.6259
# Precision: 0.6411, Recall: 0.6259, F1-score: 0.6206
# --------------------------------------------------
# Epoch [1499/1500]
# Train Loss: 1.2920, Train Acc: 0.9811
# Val Loss: 1.6533, Val Acc: 0.6403
# Precision: 0.6589, Recall: 0.6403, F1-score: 0.6400
# --------------------------------------------------
# Epoch [1500/1500]
# Train Loss: 1.2917, Train Acc: 0.9819
# Val Loss: 1.6365, Val Acc: 0.6475
# Precision: 0.6587, Recall: 0.6475, F1-score: 0.6455
# --------------------------------------------------

# %%
torch.save(model.state_dict(), "C:/Nini/Capstone/Models/LSTM_model.pth")
