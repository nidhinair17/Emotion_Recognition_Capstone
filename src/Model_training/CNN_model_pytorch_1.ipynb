# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle

# %%
features = pd.read_csv("C:/Nini/Capstone/CSV_Files/ravdess_extracted_features_mel_mfcc_chroma.csv")
features = features.drop(features.columns[0], axis=1)
temp = shuffle(features)
df = np.random.rand(len(temp)) < 0.8
train = temp[df]
test = temp[~df]

# %%
X_train = np.array(train.iloc[:,:-1])
y_train = np.array(train.iloc[:,-1])
X_test = np.array(test.iloc[:,:-1])
y_test = np.array(test.iloc[:,-1])

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
batch_size = 256
train_loader = DataLoader(TensorDataset(X_train,y_train), batch_size=batch_size,shuffle=True)
test_loader = DataLoader(TensorDataset(X_test,y_test), batch_size=batch_size, shuffle=False)

# %% [markdown]
# Test 1

# %%
# class CNNModel(nn.Module):
#     def __init__(self, input_size, num_classes):
#         super(CNNModel, self).__init__()
#         self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=8)
#         self.bn1 = nn.BatchNorm1d(64)
#         self.conv2 = nn.Conv1d(64, 128, kernel_size=8)
#         self.bn2 = nn.BatchNorm1d(128)
#         self.pool1 = nn.MaxPool1d(kernel_size=4, padding=2)
#         self.dropout1 = nn.Dropout(0.5)
#         self.conv3 = nn.Conv1d(128, 128, kernel_size=8)
#         self.bn3 = nn.BatchNorm1d(128)
#         self.pool2 = nn.MaxPool1d(kernel_size=4, padding=2)
#         self.dropout2 = nn.Dropout(0.5)
#         self.conv4 = nn.Conv1d(128, 64, kernel_size=3, padding=2)
#         self.bn4 = nn.BatchNorm1d(64)
#         self.fc1 = nn.Linear(640, 256)
#         self.dropout3 = nn.Dropout(0.5)
#         self.fc2 = nn.Linear(256, num_classes)

#     # def _compute_flattened_size(self, input_size):
#     #     with torch.no_grad():
#     #         x = torch.randn(1, 1, input_size)  # Create a dummy input
#     #         x = self.conv1(x)
#     #         x = F.relu(x)
#     #         x = self.conv2(x)
#     #         x = F.relu(x)
#     #         x = self.pool1(x)
#     #         x = self.dropout1(x)
#     #         x = self.conv3(x)
#     #         x = F.relu(x)
#     #         x = self.pool2(x)
#     #         x = self.dropout2(x)
#     #         x = self.conv4(x)
#     #         x = F.relu(x)
#     #         x = x.view(1, -1)  # Flatten
#     #         self._to_linear = x.shape[1]

#     def forward(self, x):
#         x = F.relu(self.bn1(self.conv1(x)))
#         x = F.relu(self.bn2(self.conv2(x)))
#         x = self.pool1(x)
#         x = self.dropout1(x)
#         x = F.relu(self.bn3(self.conv3(x)))
#         x = self.pool2(x)
#         x = self.dropout2(x)
#         x = F.relu(self.bn4(self.conv4(x)))
#         x = x.view(x.size(0), -1)
#         x = F.relu(self.fc1(x))
#         x = self.dropout3(x)
#         x = self.fc2(x)
#         return x

# %% [markdown]
# Test 2

# %%
class CNNModel(nn.Module):
    def __init__(self, input_size, num_classes):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=8)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=8)
        self.bn2 = nn.BatchNorm1d(128)
        self.pool1 = nn.MaxPool1d(kernel_size=6, padding=2)
        self.dropout1 = nn.Dropout(0.5)
        self.conv3 = nn.Conv1d(128, 128, kernel_size=8)
        self.bn3 = nn.BatchNorm1d(128)
        self.pool2 = nn.MaxPool1d(kernel_size=6, padding=2)
        self.dropout2 = nn.Dropout(0.5)
        # self.conv4 = nn.Conv1d(128, 64, kernel_size=4, padding=2)
        # self.bn4 = nn.BatchNorm1d(64)
        self.fc1 = nn.Linear(384, 256)
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, num_classes)

    # def _compute_flattened_size(self, input_size):
    #     with torch.no_grad():
    #         x = torch.randn(1, 1, input_size)  # Create a dummy input
    #         x = self.conv1(x)
    #         x = F.relu(x)
    #         x = self.conv2(x)
    #         x = F.relu(x)
    #         x = self.pool1(x)
    #         x = self.dropout1(x)
    #         x = self.conv3(x)
    #         x = F.relu(x)
    #         x = self.pool2(x)
    #         x = self.dropout2(x)
    #         x = self.conv4(x)
    #         x = F.relu(x)
    #         x = x.view(1, -1)  # Flatten
    #         self._to_linear = x.shape[1]

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool2(x)
        x = self.dropout2(x)
        # x = F.relu(self.bn4(self.conv4(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNModel(input_size=X_train.shape[1], num_classes=8).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=1e-4)

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: torch.Size([1169, 1, 153])

# %%
epochs = 1500
for epoch in range(epochs):
    model.train()
    running_loss = 0
    total_loss = 0
    total = 0
    correct = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)
    train_accuracy = correct / total
    avg_train_loss = running_loss / len(train_loader)
        # total_loss += loss.item()
        # correct += (outputs.argmax(dim=1) == y_batch).sum().item()
    model.eval()  # Set model to evaluation mode
    val_correct = 0
    val_total = 0
    val_loss = 0.0

    with torch.no_grad():  # Disable gradient computation for validation
        for val_inputs, val_labels in test_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)

            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()

            _, val_predicted = torch.max(val_outputs, 1)
            val_correct += (val_predicted == val_labels).sum().item()
            val_total += val_labels.size(0)
    
    val_accuracy = val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)
    # accuracy = correct / len(train_loader.dataset)
    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    print("-" * 50)
# Out:
# Epoch [1/1500]
# Train Loss: 1.9835, Train Acc: 0.2198
# Val Loss: 1.9590, Val Acc: 0.2583
# --------------------------------------------------
# Epoch [2/1500]
# Train Loss: 1.7835, Train Acc: 0.3174
# Val Loss: 1.9130, Val Acc: 0.3247
# --------------------------------------------------
# Epoch [3/1500]
# Train Loss: 1.7520, Train Acc: 0.3199
# Val Loss: 1.8760, Val Acc: 0.2989
# --------------------------------------------------
# Epoch [4/1500]
# Train Loss: 1.6729, Train Acc: 0.3507
# Val Loss: 1.8102, Val Acc: 0.3395
# --------------------------------------------------
# Epoch [5/1500]
# Train Loss: 1.6336, Train Acc: 0.3653
# Val Loss: 1.7826, Val Acc: 0.3395
# --------------------------------------------------
# Epoch [6/1500]
# Train Loss: 1.5688, Train Acc: 0.3832
# Val Loss: 1.7065, Val Acc: 0.3764
# --------------------------------------------------
# Epoch [7/1500]
# Train Loss: 1.5208, Train Acc: 0.4132
# Val Loss: 1.6799, Val Acc: 0.4096
# --------------------------------------------------
# Epoch [8/1500]
# Train Loss: 1.4744, Train Acc: 0.4269
# Val Loss: 1.6376, Val Acc: 0.4539
# --------------------------------------------------
# Epoch [9/1500]
# Train Loss: 1.4591, Train Acc: 0.4611
# Val Loss: 1.5955, Val Acc: 0.4502
# --------------------------------------------------
# Epoch [10/1500]
# Train Loss: 1.4333, Train Acc: 0.4662
# Val Loss: 1.5501, Val Acc: 0.4539
# --------------------------------------------------
# Epoch [11/1500]
# Train Loss: 1.3692, Train Acc: 0.4508
# Val Loss: 1.5567, Val Acc: 0.4945
# --------------------------------------------------
# Epoch [12/1500]
# Train Loss: 1.3618, Train Acc: 0.4876
# Val Loss: 1.5148, Val Acc: 0.4723
# --------------------------------------------------
# Epoch [13/1500]
# Train Loss: 1.3240, Train Acc: 0.5038
# Val Loss: 1.5048, Val Acc: 0.4982
# --------------------------------------------------
# Epoch [14/1500]
# Train Loss: 1.2868, Train Acc: 0.5115
# Val Loss: 1.4767, Val Acc: 0.5240
# --------------------------------------------------
# Epoch [15/1500]
# Train Loss: 1.2602, Train Acc: 0.5321
# Val Loss: 1.4552, Val Acc: 0.5351
# --------------------------------------------------
# Epoch [16/1500]
# Train Loss: 1.2506, Train Acc: 0.5364
# Val Loss: 1.4442, Val Acc: 0.5203
# --------------------------------------------------
# Epoch [17/1500]
# Train Loss: 1.1955, Train Acc: 0.5552
# Val Loss: 1.4197, Val Acc: 0.5277
# --------------------------------------------------
# Epoch [18/1500]
# Train Loss: 1.1807, Train Acc: 0.5620
# Val Loss: 1.3818, Val Acc: 0.5314
# --------------------------------------------------
# Epoch [19/1500]
# Train Loss: 1.1953, Train Acc: 0.5500
# Val Loss: 1.3919, Val Acc: 0.5387
# --------------------------------------------------
# Epoch [20/1500]
# Train Loss: 1.1610, Train Acc: 0.5646
# Val Loss: 1.4091, Val Acc: 0.5387
# --------------------------------------------------
# Epoch [21/1500]
# Train Loss: 1.1361, Train Acc: 0.5945
# Val Loss: 1.3972, Val Acc: 0.5424
# --------------------------------------------------
# Epoch [22/1500]
# Train Loss: 1.0993, Train Acc: 0.5928
# Val Loss: 1.3839, Val Acc: 0.5314
# --------------------------------------------------
# Epoch [23/1500]
# Train Loss: 1.0965, Train Acc: 0.5954
# Val Loss: 1.3150, Val Acc: 0.5720
# --------------------------------------------------
# Epoch [24/1500]
# Train Loss: 1.0614, Train Acc: 0.6082
# Val Loss: 1.3447, Val Acc: 0.5535
# --------------------------------------------------
# Epoch [25/1500]
# Train Loss: 1.0286, Train Acc: 0.6287
# Val Loss: 1.3135, Val Acc: 0.5830
# --------------------------------------------------
# Epoch [26/1500]
# Train Loss: 1.0126, Train Acc: 0.6476
# Val Loss: 1.3083, Val Acc: 0.5572
# --------------------------------------------------
# Epoch [27/1500]
# Train Loss: 0.9841, Train Acc: 0.6501
# Val Loss: 1.2786, Val Acc: 0.5609
# --------------------------------------------------
# Epoch [28/1500]
# Train Loss: 0.9967, Train Acc: 0.6202
# Val Loss: 1.2919, Val Acc: 0.5756
# --------------------------------------------------
# Epoch [29/1500]
# Train Loss: 0.9418, Train Acc: 0.6484
# Val Loss: 1.2645, Val Acc: 0.5387
# --------------------------------------------------
# Epoch [30/1500]
# Train Loss: 0.9389, Train Acc: 0.6441
# Val Loss: 1.2359, Val Acc: 0.5572
# --------------------------------------------------
# Epoch [31/1500]
# Train Loss: 0.9261, Train Acc: 0.6630
# Val Loss: 1.2709, Val Acc: 0.5904
# --------------------------------------------------
# Epoch [32/1500]
# Train Loss: 0.9112, Train Acc: 0.6749
# Val Loss: 1.2456, Val Acc: 0.5867
# --------------------------------------------------
# Epoch [33/1500]
# Train Loss: 0.9208, Train Acc: 0.6732
# Val Loss: 1.2558, Val Acc: 0.5904
# --------------------------------------------------
# Epoch [34/1500]
# Train Loss: 0.8967, Train Acc: 0.6758
# Val Loss: 1.2335, Val Acc: 0.5793
# --------------------------------------------------
# Epoch [35/1500]
# Train Loss: 0.8690, Train Acc: 0.6903
# Val Loss: 1.2445, Val Acc: 0.5646
# --------------------------------------------------
# Epoch [36/1500]
# Train Loss: 0.8633, Train Acc: 0.6869
# Val Loss: 1.1606, Val Acc: 0.5941
# --------------------------------------------------
# Epoch [37/1500]
# Train Loss: 0.8415, Train Acc: 0.6963
# Val Loss: 1.1927, Val Acc: 0.5904
# --------------------------------------------------
# Epoch [38/1500]
# Train Loss: 0.8141, Train Acc: 0.7109
# Val Loss: 1.1882, Val Acc: 0.6162
# --------------------------------------------------
# Epoch [39/1500]
# Train Loss: 0.8588, Train Acc: 0.6775
# Val Loss: 1.1740, Val Acc: 0.6162
# --------------------------------------------------
# Epoch [40/1500]
# Train Loss: 0.7931, Train Acc: 0.6989
# Val Loss: 1.1971, Val Acc: 0.6089
# --------------------------------------------------
# Epoch [41/1500]
# Train Loss: 0.8116, Train Acc: 0.7126
# Val Loss: 1.2080, Val Acc: 0.5904
# --------------------------------------------------
# Epoch [42/1500]
# Train Loss: 0.8213, Train Acc: 0.7049
# Val Loss: 1.1773, Val Acc: 0.5978
# --------------------------------------------------
# Epoch [43/1500]
# Train Loss: 0.8012, Train Acc: 0.7083
# Val Loss: 1.1437, Val Acc: 0.6015
# --------------------------------------------------
# Epoch [44/1500]
# Train Loss: 0.7687, Train Acc: 0.7297
# Val Loss: 1.1522, Val Acc: 0.6199
# --------------------------------------------------
# Epoch [45/1500]
# Train Loss: 0.7373, Train Acc: 0.7305
# Val Loss: 1.1117, Val Acc: 0.6089
# --------------------------------------------------
# Epoch [46/1500]
# Train Loss: 0.7419, Train Acc: 0.7331
# Val Loss: 1.1117, Val Acc: 0.6162
# --------------------------------------------------
# Epoch [47/1500]
# Train Loss: 0.7249, Train Acc: 0.7271
# Val Loss: 1.1032, Val Acc: 0.6347
# --------------------------------------------------
# Epoch [48/1500]
# Train Loss: 0.7524, Train Acc: 0.7246
# Val Loss: 1.1207, Val Acc: 0.6162
# --------------------------------------------------
# Epoch [49/1500]
# Train Loss: 0.7479, Train Acc: 0.7357
# Val Loss: 1.1296, Val Acc: 0.6089
# --------------------------------------------------
# Epoch [50/1500]
# Train Loss: 0.7052, Train Acc: 0.7374
# Val Loss: 1.0698, Val Acc: 0.6199
# --------------------------------------------------
# Epoch [51/1500]
# Train Loss: 0.6906, Train Acc: 0.7648
# Val Loss: 1.1290, Val Acc: 0.6384
# --------------------------------------------------
# Epoch [52/1500]
# Train Loss: 0.6301, Train Acc: 0.7861
# Val Loss: 1.0762, Val Acc: 0.6384
# --------------------------------------------------
# Epoch [53/1500]
# Train Loss: 0.6424, Train Acc: 0.7733
# Val Loss: 1.1193, Val Acc: 0.6384
# --------------------------------------------------
# Epoch [54/1500]
# Train Loss: 0.6398, Train Acc: 0.7690
# Val Loss: 1.1076, Val Acc: 0.6273
# --------------------------------------------------
# Epoch [55/1500]
# Train Loss: 0.6612, Train Acc: 0.7767
# Val Loss: 1.1115, Val Acc: 0.6421
# --------------------------------------------------
# Epoch [56/1500]
# Train Loss: 0.6280, Train Acc: 0.7707
# Val Loss: 1.1326, Val Acc: 0.6199
# --------------------------------------------------
# Epoch [57/1500]
# Train Loss: 0.6447, Train Acc: 0.7784
# Val Loss: 1.1311, Val Acc: 0.6384
# --------------------------------------------------
# Epoch [58/1500]
# Train Loss: 0.5953, Train Acc: 0.7819
# Val Loss: 1.0984, Val Acc: 0.6384
# --------------------------------------------------
# Epoch [59/1500]
# Train Loss: 0.6215, Train Acc: 0.7827
# Val Loss: 1.1131, Val Acc: 0.6421
# --------------------------------------------------
# Epoch [60/1500]
# Train Loss: 0.5703, Train Acc: 0.7990
# Val Loss: 1.0211, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [61/1500]
# Train Loss: 0.5728, Train Acc: 0.7930
# Val Loss: 1.1076, Val Acc: 0.6384
# --------------------------------------------------
# Epoch [62/1500]
# Train Loss: 0.5200, Train Acc: 0.8289
# Val Loss: 1.0606, Val Acc: 0.6310
# --------------------------------------------------
# Epoch [63/1500]
# Train Loss: 0.5288, Train Acc: 0.8092
# Val Loss: 1.0650, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [64/1500]
# Train Loss: 0.5456, Train Acc: 0.8109
# Val Loss: 1.0116, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [65/1500]
# Train Loss: 0.5676, Train Acc: 0.7998
# Val Loss: 1.0833, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [66/1500]
# Train Loss: 0.5469, Train Acc: 0.7998
# Val Loss: 1.0895, Val Acc: 0.6384
# --------------------------------------------------
# Epoch [67/1500]
# Train Loss: 0.5522, Train Acc: 0.8092
# Val Loss: 1.0747, Val Acc: 0.6421
# --------------------------------------------------
# Epoch [68/1500]
# Train Loss: 0.4937, Train Acc: 0.8263
# Val Loss: 1.0689, Val Acc: 0.6494
# --------------------------------------------------
# Epoch [69/1500]
# Train Loss: 0.4945, Train Acc: 0.8212
# Val Loss: 1.0385, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [70/1500]
# Train Loss: 0.5241, Train Acc: 0.8204
# Val Loss: 1.0695, Val Acc: 0.6421
# --------------------------------------------------
# Epoch [71/1500]
# Train Loss: 0.4803, Train Acc: 0.8315
# Val Loss: 1.0567, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [72/1500]
# Train Loss: 0.4682, Train Acc: 0.8323
# Val Loss: 1.0572, Val Acc: 0.6531
# --------------------------------------------------
# Epoch [73/1500]
# Train Loss: 0.4703, Train Acc: 0.8178
# Val Loss: 1.0063, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [74/1500]
# Train Loss: 0.4770, Train Acc: 0.8281
# Val Loss: 1.0633, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [75/1500]
# Train Loss: 0.4702, Train Acc: 0.8366
# Val Loss: 1.0764, Val Acc: 0.6347
# --------------------------------------------------
# Epoch [76/1500]
# Train Loss: 0.4540, Train Acc: 0.8409
# Val Loss: 1.0377, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [77/1500]
# Train Loss: 0.4614, Train Acc: 0.8306
# Val Loss: 1.0806, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [78/1500]
# Train Loss: 0.4254, Train Acc: 0.8503
# Val Loss: 1.0770, Val Acc: 0.6384
# --------------------------------------------------
# Epoch [79/1500]
# Train Loss: 0.4356, Train Acc: 0.8409
# Val Loss: 1.0351, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [80/1500]
# Train Loss: 0.4346, Train Acc: 0.8648
# Val Loss: 1.0723, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [81/1500]
# Train Loss: 0.4040, Train Acc: 0.8529
# Val Loss: 1.0786, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [82/1500]
# Train Loss: 0.4295, Train Acc: 0.8392
# Val Loss: 1.0301, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [83/1500]
# Train Loss: 0.4222, Train Acc: 0.8589
# Val Loss: 1.0799, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [84/1500]
# Train Loss: 0.4339, Train Acc: 0.8580
# Val Loss: 1.0486, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [85/1500]
# Train Loss: 0.3997, Train Acc: 0.8571
# Val Loss: 1.0663, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [86/1500]
# Train Loss: 0.3703, Train Acc: 0.8734
# Val Loss: 0.9946, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [87/1500]
# Train Loss: 0.3884, Train Acc: 0.8623
# Val Loss: 1.0719, Val Acc: 0.6494
# --------------------------------------------------
# Epoch [88/1500]
# Train Loss: 0.3805, Train Acc: 0.8768
# Val Loss: 1.0017, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [89/1500]
# Train Loss: 0.3716, Train Acc: 0.8751
# Val Loss: 1.0506, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [90/1500]
# Train Loss: 0.3609, Train Acc: 0.8743
# Val Loss: 1.0211, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [91/1500]
# Train Loss: 0.3898, Train Acc: 0.8657
# Val Loss: 1.0708, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [92/1500]
# Train Loss: 0.3722, Train Acc: 0.8820
# Val Loss: 1.0450, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [93/1500]
# Train Loss: 0.3819, Train Acc: 0.8657
# Val Loss: 1.0297, Val Acc: 0.6531
# --------------------------------------------------
# Epoch [94/1500]
# Train Loss: 0.3806, Train Acc: 0.8734
# Val Loss: 1.0037, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [95/1500]
# Train Loss: 0.3564, Train Acc: 0.8768
# Val Loss: 1.0901, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [96/1500]
# Train Loss: 0.3819, Train Acc: 0.8691
# Val Loss: 1.0922, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [97/1500]
# Train Loss: 0.3512, Train Acc: 0.8802
# Val Loss: 1.0404, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [98/1500]
# Train Loss: 0.3574, Train Acc: 0.8674
# Val Loss: 1.0353, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [99/1500]
# Train Loss: 0.3392, Train Acc: 0.8802
# Val Loss: 1.0983, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [100/1500]
# Train Loss: 0.3633, Train Acc: 0.8700
# Val Loss: 1.1108, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [101/1500]
# Train Loss: 0.3403, Train Acc: 0.8837
# Val Loss: 1.0228, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [102/1500]
# Train Loss: 0.3294, Train Acc: 0.8888
# Val Loss: 1.0233, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [103/1500]
# Train Loss: 0.3320, Train Acc: 0.8905
# Val Loss: 0.9969, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [104/1500]
# Train Loss: 0.2975, Train Acc: 0.9110
# Val Loss: 1.0410, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [105/1500]
# Train Loss: 0.3200, Train Acc: 0.8965
# Val Loss: 1.0069, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [106/1500]
# Train Loss: 0.3453, Train Acc: 0.8760
# Val Loss: 1.0548, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [107/1500]
# Train Loss: 0.2826, Train Acc: 0.9076
# Val Loss: 1.0319, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [108/1500]
# Train Loss: 0.3266, Train Acc: 0.8862
# Val Loss: 1.0573, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [109/1500]
# Train Loss: 0.3063, Train Acc: 0.8965
# Val Loss: 0.9598, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [110/1500]
# Train Loss: 0.3000, Train Acc: 0.9033
# Val Loss: 1.0140, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [111/1500]
# Train Loss: 0.3084, Train Acc: 0.9016
# Val Loss: 1.0390, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [112/1500]
# Train Loss: 0.3041, Train Acc: 0.8999
# Val Loss: 1.0317, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [113/1500]
# Train Loss: 0.2913, Train Acc: 0.9025
# Val Loss: 1.0502, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [114/1500]
# Train Loss: 0.3081, Train Acc: 0.8973
# Val Loss: 1.0026, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [115/1500]
# Train Loss: 0.2664, Train Acc: 0.9127
# Val Loss: 1.1167, Val Acc: 0.6568
# --------------------------------------------------
# Epoch [116/1500]
# Train Loss: 0.2788, Train Acc: 0.9042
# Val Loss: 1.0686, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [117/1500]
# Train Loss: 0.2998, Train Acc: 0.8999
# Val Loss: 1.0784, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [118/1500]
# Train Loss: 0.3087, Train Acc: 0.8999
# Val Loss: 1.0719, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [119/1500]
# Train Loss: 0.2632, Train Acc: 0.9102
# Val Loss: 1.1057, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [120/1500]
# Train Loss: 0.3132, Train Acc: 0.8931
# Val Loss: 1.1512, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [121/1500]
# Train Loss: 0.3094, Train Acc: 0.8922
# Val Loss: 1.1528, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [122/1500]
# Train Loss: 0.2904, Train Acc: 0.9033
# Val Loss: 1.1448, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [123/1500]
# Train Loss: 0.2522, Train Acc: 0.9222
# Val Loss: 1.1180, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [124/1500]
# Train Loss: 0.2543, Train Acc: 0.9247
# Val Loss: 1.0703, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [125/1500]
# Train Loss: 0.2601, Train Acc: 0.9025
# Val Loss: 1.0283, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [126/1500]
# Train Loss: 0.2467, Train Acc: 0.9102
# Val Loss: 1.1332, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [127/1500]
# Train Loss: 0.2263, Train Acc: 0.9204
# Val Loss: 1.0355, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [128/1500]
# Train Loss: 0.2649, Train Acc: 0.9076
# Val Loss: 1.0543, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [129/1500]
# Train Loss: 0.2413, Train Acc: 0.9187
# Val Loss: 1.0638, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [130/1500]
# Train Loss: 0.2350, Train Acc: 0.9281
# Val Loss: 1.0410, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [131/1500]
# Train Loss: 0.2197, Train Acc: 0.9376
# Val Loss: 1.0517, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [132/1500]
# Train Loss: 0.2471, Train Acc: 0.9170
# Val Loss: 1.0576, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [133/1500]
# Train Loss: 0.2515, Train Acc: 0.9153
# Val Loss: 1.0985, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [134/1500]
# Train Loss: 0.2173, Train Acc: 0.9307
# Val Loss: 1.0391, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [135/1500]
# Train Loss: 0.2192, Train Acc: 0.9230
# Val Loss: 1.0727, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [136/1500]
# Train Loss: 0.1927, Train Acc: 0.9341
# Val Loss: 1.0372, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [137/1500]
# Train Loss: 0.2297, Train Acc: 0.9213
# Val Loss: 1.0791, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [138/1500]
# Train Loss: 0.2313, Train Acc: 0.9239
# Val Loss: 1.0537, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [139/1500]
# Train Loss: 0.2441, Train Acc: 0.9239
# Val Loss: 1.0773, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [140/1500]
# Train Loss: 0.2380, Train Acc: 0.9204
# Val Loss: 1.0063, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [141/1500]
# Train Loss: 0.2161, Train Acc: 0.9341
# Val Loss: 1.0007, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [142/1500]
# Train Loss: 0.2266, Train Acc: 0.9230
# Val Loss: 1.0482, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [143/1500]
# Train Loss: 0.2165, Train Acc: 0.9341
# Val Loss: 1.0037, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [144/1500]
# Train Loss: 0.2165, Train Acc: 0.9281
# Val Loss: 1.1138, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [145/1500]
# Train Loss: 0.2087, Train Acc: 0.9299
# Val Loss: 1.1179, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [146/1500]
# Train Loss: 0.2201, Train Acc: 0.9264
# Val Loss: 1.0721, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [147/1500]
# Train Loss: 0.2108, Train Acc: 0.9290
# Val Loss: 1.1402, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [148/1500]
# Train Loss: 0.2257, Train Acc: 0.9247
# Val Loss: 1.0316, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [149/1500]
# Train Loss: 0.2100, Train Acc: 0.9256
# Val Loss: 0.9549, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [150/1500]
# Train Loss: 0.1869, Train Acc: 0.9470
# Val Loss: 1.0382, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [151/1500]
# Train Loss: 0.1773, Train Acc: 0.9410
# Val Loss: 1.0410, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [152/1500]
# Train Loss: 0.1963, Train Acc: 0.9358
# Val Loss: 1.1174, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [153/1500]
# Train Loss: 0.1926, Train Acc: 0.9324
# Val Loss: 1.0547, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [154/1500]
# Train Loss: 0.2043, Train Acc: 0.9333
# Val Loss: 1.0583, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [155/1500]
# Train Loss: 0.1841, Train Acc: 0.9384
# Val Loss: 1.0497, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [156/1500]
# Train Loss: 0.1929, Train Acc: 0.9350
# Val Loss: 1.1175, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [157/1500]
# Train Loss: 0.1737, Train Acc: 0.9547
# Val Loss: 1.1264, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [158/1500]
# Train Loss: 0.1854, Train Acc: 0.9487
# Val Loss: 1.0763, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [159/1500]
# Train Loss: 0.1915, Train Acc: 0.9367
# Val Loss: 1.1441, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [160/1500]
# Train Loss: 0.1959, Train Acc: 0.9427
# Val Loss: 1.0671, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [161/1500]
# Train Loss: 0.1750, Train Acc: 0.9427
# Val Loss: 1.0574, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [162/1500]
# Train Loss: 0.1924, Train Acc: 0.9358
# Val Loss: 0.9977, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [163/1500]
# Train Loss: 0.2096, Train Acc: 0.9393
# Val Loss: 1.0886, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [164/1500]
# Train Loss: 0.1911, Train Acc: 0.9384
# Val Loss: 1.0396, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [165/1500]
# Train Loss: 0.1759, Train Acc: 0.9470
# Val Loss: 0.9683, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [166/1500]
# Train Loss: 0.1883, Train Acc: 0.9367
# Val Loss: 0.9942, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [167/1500]
# Train Loss: 0.1664, Train Acc: 0.9495
# Val Loss: 1.0627, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [168/1500]
# Train Loss: 0.1643, Train Acc: 0.9470
# Val Loss: 1.0133, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [169/1500]
# Train Loss: 0.1871, Train Acc: 0.9358
# Val Loss: 1.0247, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [170/1500]
# Train Loss: 0.2063, Train Acc: 0.9376
# Val Loss: 1.0659, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [171/1500]
# Train Loss: 0.1917, Train Acc: 0.9333
# Val Loss: 1.0572, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [172/1500]
# Train Loss: 0.1663, Train Acc: 0.9461
# Val Loss: 1.1061, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [173/1500]
# Train Loss: 0.1863, Train Acc: 0.9453
# Val Loss: 1.0528, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [174/1500]
# Train Loss: 0.1796, Train Acc: 0.9376
# Val Loss: 1.0299, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [175/1500]
# Train Loss: 0.1762, Train Acc: 0.9418
# Val Loss: 1.1107, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [176/1500]
# Train Loss: 0.1683, Train Acc: 0.9470
# Val Loss: 1.0652, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [177/1500]
# Train Loss: 0.1610, Train Acc: 0.9478
# Val Loss: 1.0789, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [178/1500]
# Train Loss: 0.1724, Train Acc: 0.9453
# Val Loss: 1.0816, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [179/1500]
# Train Loss: 0.1572, Train Acc: 0.9495
# Val Loss: 1.0709, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [180/1500]
# Train Loss: 0.1641, Train Acc: 0.9487
# Val Loss: 1.0381, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [181/1500]
# Train Loss: 0.1642, Train Acc: 0.9410
# Val Loss: 1.0870, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [182/1500]
# Train Loss: 0.1531, Train Acc: 0.9521
# Val Loss: 1.1724, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [183/1500]
# Train Loss: 0.1347, Train Acc: 0.9555
# Val Loss: 1.1810, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [184/1500]
# Train Loss: 0.1490, Train Acc: 0.9538
# Val Loss: 1.1951, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [185/1500]
# Train Loss: 0.1677, Train Acc: 0.9470
# Val Loss: 1.1401, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [186/1500]
# Train Loss: 0.1602, Train Acc: 0.9470
# Val Loss: 1.1359, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [187/1500]
# Train Loss: 0.1450, Train Acc: 0.9504
# Val Loss: 1.0550, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [188/1500]
# Train Loss: 0.1503, Train Acc: 0.9581
# Val Loss: 1.0918, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [189/1500]
# Train Loss: 0.1650, Train Acc: 0.9478
# Val Loss: 1.0757, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [190/1500]
# Train Loss: 0.1526, Train Acc: 0.9512
# Val Loss: 1.0731, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [191/1500]
# Train Loss: 0.1510, Train Acc: 0.9547
# Val Loss: 1.1220, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [192/1500]
# Train Loss: 0.1397, Train Acc: 0.9555
# Val Loss: 1.0915, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [193/1500]
# Train Loss: 0.1628, Train Acc: 0.9495
# Val Loss: 1.1313, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [194/1500]
# Train Loss: 0.1664, Train Acc: 0.9470
# Val Loss: 1.0772, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [195/1500]
# Train Loss: 0.1373, Train Acc: 0.9589
# Val Loss: 1.0847, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [196/1500]
# Train Loss: 0.1490, Train Acc: 0.9512
# Val Loss: 1.1556, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [197/1500]
# Train Loss: 0.1440, Train Acc: 0.9572
# Val Loss: 1.1590, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [198/1500]
# Train Loss: 0.1584, Train Acc: 0.9521
# Val Loss: 1.1446, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [199/1500]
# Train Loss: 0.1717, Train Acc: 0.9555
# Val Loss: 1.1087, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [200/1500]
# Train Loss: 0.1303, Train Acc: 0.9547
# Val Loss: 1.0812, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [201/1500]
# Train Loss: 0.1566, Train Acc: 0.9512
# Val Loss: 1.0422, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [202/1500]
# Train Loss: 0.1694, Train Acc: 0.9418
# Val Loss: 1.1245, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [203/1500]
# Train Loss: 0.1410, Train Acc: 0.9512
# Val Loss: 1.1309, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [204/1500]
# Train Loss: 0.1457, Train Acc: 0.9607
# Val Loss: 1.0863, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [205/1500]
# Train Loss: 0.1387, Train Acc: 0.9564
# Val Loss: 1.0127, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [206/1500]
# Train Loss: 0.1225, Train Acc: 0.9598
# Val Loss: 1.2230, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [207/1500]
# Train Loss: 0.1193, Train Acc: 0.9598
# Val Loss: 1.1991, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [208/1500]
# Train Loss: 0.1383, Train Acc: 0.9538
# Val Loss: 1.2247, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [209/1500]
# Train Loss: 0.1247, Train Acc: 0.9624
# Val Loss: 1.3070, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [210/1500]
# Train Loss: 0.1390, Train Acc: 0.9495
# Val Loss: 1.2706, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [211/1500]
# Train Loss: 0.1185, Train Acc: 0.9607
# Val Loss: 1.2785, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [212/1500]
# Train Loss: 0.1182, Train Acc: 0.9598
# Val Loss: 1.3000, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [213/1500]
# Train Loss: 0.1266, Train Acc: 0.9615
# Val Loss: 1.1993, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [214/1500]
# Train Loss: 0.1265, Train Acc: 0.9538
# Val Loss: 1.1843, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [215/1500]
# Train Loss: 0.1188, Train Acc: 0.9632
# Val Loss: 1.1805, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [216/1500]
# Train Loss: 0.1305, Train Acc: 0.9598
# Val Loss: 1.1756, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [217/1500]
# Train Loss: 0.1202, Train Acc: 0.9598
# Val Loss: 1.1423, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [218/1500]
# Train Loss: 0.1300, Train Acc: 0.9564
# Val Loss: 1.1647, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [219/1500]
# Train Loss: 0.1324, Train Acc: 0.9572
# Val Loss: 1.1476, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [220/1500]
# Train Loss: 0.1409, Train Acc: 0.9589
# Val Loss: 1.1398, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [221/1500]
# Train Loss: 0.1018, Train Acc: 0.9675
# Val Loss: 1.1969, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [222/1500]
# Train Loss: 0.1309, Train Acc: 0.9649
# Val Loss: 1.1376, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [223/1500]
# Train Loss: 0.1279, Train Acc: 0.9538
# Val Loss: 1.1801, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [224/1500]
# Train Loss: 0.1446, Train Acc: 0.9521
# Val Loss: 1.1647, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [225/1500]
# Train Loss: 0.1513, Train Acc: 0.9547
# Val Loss: 1.1159, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [226/1500]
# Train Loss: 0.1236, Train Acc: 0.9581
# Val Loss: 1.2307, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [227/1500]
# Train Loss: 0.1328, Train Acc: 0.9641
# Val Loss: 1.2143, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [228/1500]
# Train Loss: 0.1170, Train Acc: 0.9675
# Val Loss: 1.1672, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [229/1500]
# Train Loss: 0.1077, Train Acc: 0.9675
# Val Loss: 1.1641, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [230/1500]
# Train Loss: 0.1127, Train Acc: 0.9624
# Val Loss: 1.1377, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [231/1500]
# Train Loss: 0.1228, Train Acc: 0.9589
# Val Loss: 1.0933, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [232/1500]
# Train Loss: 0.1095, Train Acc: 0.9649
# Val Loss: 1.1258, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [233/1500]
# Train Loss: 0.1165, Train Acc: 0.9649
# Val Loss: 1.0672, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [234/1500]
# Train Loss: 0.1149, Train Acc: 0.9666
# Val Loss: 1.0983, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [235/1500]
# Train Loss: 0.1000, Train Acc: 0.9726
# Val Loss: 1.1586, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [236/1500]
# Train Loss: 0.1121, Train Acc: 0.9615
# Val Loss: 1.2188, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [237/1500]
# Train Loss: 0.1265, Train Acc: 0.9581
# Val Loss: 1.2351, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [238/1500]
# Train Loss: 0.1198, Train Acc: 0.9624
# Val Loss: 1.1027, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [239/1500]
# Train Loss: 0.1083, Train Acc: 0.9683
# Val Loss: 1.2200, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [240/1500]
# Train Loss: 0.1334, Train Acc: 0.9555
# Val Loss: 1.2160, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [241/1500]
# Train Loss: 0.1055, Train Acc: 0.9743
# Val Loss: 1.2444, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [242/1500]
# Train Loss: 0.1048, Train Acc: 0.9709
# Val Loss: 1.2462, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [243/1500]
# Train Loss: 0.1144, Train Acc: 0.9632
# Val Loss: 1.2114, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [244/1500]
# Train Loss: 0.0948, Train Acc: 0.9718
# Val Loss: 1.1902, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [245/1500]
# Train Loss: 0.1128, Train Acc: 0.9581
# Val Loss: 1.1446, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [246/1500]
# Train Loss: 0.1135, Train Acc: 0.9589
# Val Loss: 1.1700, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [247/1500]
# Train Loss: 0.1048, Train Acc: 0.9615
# Val Loss: 1.1792, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [248/1500]
# Train Loss: 0.0957, Train Acc: 0.9666
# Val Loss: 1.0737, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [249/1500]
# Train Loss: 0.1069, Train Acc: 0.9649
# Val Loss: 1.1338, Val Acc: 0.7232
# --------------------------------------------------
# Epoch [250/1500]
# Train Loss: 0.1122, Train Acc: 0.9641
# Val Loss: 1.2237, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [251/1500]
# Train Loss: 0.1110, Train Acc: 0.9658
# Val Loss: 1.1758, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [252/1500]
# Train Loss: 0.1081, Train Acc: 0.9598
# Val Loss: 1.1518, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [253/1500]
# Train Loss: 0.0974, Train Acc: 0.9692
# Val Loss: 1.2334, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [254/1500]
# Train Loss: 0.1106, Train Acc: 0.9683
# Val Loss: 1.2213, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [255/1500]
# Train Loss: 0.1204, Train Acc: 0.9658
# Val Loss: 1.1891, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [256/1500]
# Train Loss: 0.1043, Train Acc: 0.9658
# Val Loss: 1.2328, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [257/1500]
# Train Loss: 0.1003, Train Acc: 0.9701
# Val Loss: 1.1597, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [258/1500]
# Train Loss: 0.0930, Train Acc: 0.9752
# Val Loss: 1.1301, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [259/1500]
# Train Loss: 0.0889, Train Acc: 0.9735
# Val Loss: 1.2159, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [260/1500]
# Train Loss: 0.1008, Train Acc: 0.9683
# Val Loss: 1.2317, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [261/1500]
# Train Loss: 0.0974, Train Acc: 0.9709
# Val Loss: 1.2062, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [262/1500]
# Train Loss: 0.0982, Train Acc: 0.9666
# Val Loss: 1.0482, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [263/1500]
# Train Loss: 0.0893, Train Acc: 0.9743
# Val Loss: 1.1308, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [264/1500]
# Train Loss: 0.0938, Train Acc: 0.9709
# Val Loss: 1.2685, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [265/1500]
# Train Loss: 0.0990, Train Acc: 0.9692
# Val Loss: 1.2312, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [266/1500]
# Train Loss: 0.1053, Train Acc: 0.9624
# Val Loss: 1.1664, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [267/1500]
# Train Loss: 0.0835, Train Acc: 0.9786
# Val Loss: 1.1313, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [268/1500]
# Train Loss: 0.1116, Train Acc: 0.9675
# Val Loss: 1.0951, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [269/1500]
# Train Loss: 0.1149, Train Acc: 0.9666
# Val Loss: 1.1925, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [270/1500]
# Train Loss: 0.0849, Train Acc: 0.9735
# Val Loss: 1.3214, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [271/1500]
# Train Loss: 0.1078, Train Acc: 0.9641
# Val Loss: 1.1678, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [272/1500]
# Train Loss: 0.1012, Train Acc: 0.9666
# Val Loss: 1.1484, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [273/1500]
# Train Loss: 0.1054, Train Acc: 0.9658
# Val Loss: 1.2127, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [274/1500]
# Train Loss: 0.1004, Train Acc: 0.9701
# Val Loss: 1.2057, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [275/1500]
# Train Loss: 0.0945, Train Acc: 0.9726
# Val Loss: 1.1803, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [276/1500]
# Train Loss: 0.0769, Train Acc: 0.9795
# Val Loss: 1.2906, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [277/1500]
# Train Loss: 0.0975, Train Acc: 0.9718
# Val Loss: 1.3329, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [278/1500]
# Train Loss: 0.0845, Train Acc: 0.9743
# Val Loss: 1.2422, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [279/1500]
# Train Loss: 0.0942, Train Acc: 0.9760
# Val Loss: 1.1544, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [280/1500]
# Train Loss: 0.0897, Train Acc: 0.9709
# Val Loss: 1.2489, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [281/1500]
# Train Loss: 0.0922, Train Acc: 0.9718
# Val Loss: 1.1892, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [282/1500]
# Train Loss: 0.1072, Train Acc: 0.9641
# Val Loss: 1.0732, Val Acc: 0.6679
# --------------------------------------------------
# Epoch [283/1500]
# Train Loss: 0.0910, Train Acc: 0.9735
# Val Loss: 1.2051, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [284/1500]
# Train Loss: 0.0863, Train Acc: 0.9718
# Val Loss: 1.2266, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [285/1500]
# Train Loss: 0.0822, Train Acc: 0.9743
# Val Loss: 1.2286, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [286/1500]
# Train Loss: 0.0746, Train Acc: 0.9769
# Val Loss: 1.1361, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [287/1500]
# Train Loss: 0.0884, Train Acc: 0.9760
# Val Loss: 1.1361, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [288/1500]
# Train Loss: 0.0923, Train Acc: 0.9692
# Val Loss: 1.0848, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [289/1500]
# Train Loss: 0.0936, Train Acc: 0.9675
# Val Loss: 1.1411, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [290/1500]
# Train Loss: 0.0829, Train Acc: 0.9726
# Val Loss: 1.2376, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [291/1500]
# Train Loss: 0.0802, Train Acc: 0.9769
# Val Loss: 1.2512, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [292/1500]
# Train Loss: 0.0908, Train Acc: 0.9752
# Val Loss: 1.2825, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [293/1500]
# Train Loss: 0.1042, Train Acc: 0.9683
# Val Loss: 1.3084, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [294/1500]
# Train Loss: 0.0943, Train Acc: 0.9701
# Val Loss: 1.1745, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [295/1500]
# Train Loss: 0.0888, Train Acc: 0.9743
# Val Loss: 1.1832, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [296/1500]
# Train Loss: 0.0877, Train Acc: 0.9701
# Val Loss: 1.2606, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [297/1500]
# Train Loss: 0.0750, Train Acc: 0.9786
# Val Loss: 1.2345, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [298/1500]
# Train Loss: 0.0782, Train Acc: 0.9752
# Val Loss: 1.1232, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [299/1500]
# Train Loss: 0.1017, Train Acc: 0.9743
# Val Loss: 1.1365, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [300/1500]
# Train Loss: 0.0949, Train Acc: 0.9718
# Val Loss: 1.1973, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [301/1500]
# Train Loss: 0.0841, Train Acc: 0.9658
# Val Loss: 1.1954, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [302/1500]
# Train Loss: 0.0737, Train Acc: 0.9803
# Val Loss: 1.1647, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [303/1500]
# Train Loss: 0.0952, Train Acc: 0.9666
# Val Loss: 1.3745, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [304/1500]
# Train Loss: 0.0896, Train Acc: 0.9735
# Val Loss: 1.3065, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [305/1500]
# Train Loss: 0.0926, Train Acc: 0.9683
# Val Loss: 1.1754, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [306/1500]
# Train Loss: 0.0811, Train Acc: 0.9743
# Val Loss: 1.1913, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [307/1500]
# Train Loss: 0.0923, Train Acc: 0.9683
# Val Loss: 1.2195, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [308/1500]
# Train Loss: 0.0821, Train Acc: 0.9812
# Val Loss: 1.3110, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [309/1500]
# Train Loss: 0.0819, Train Acc: 0.9769
# Val Loss: 1.4129, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [310/1500]
# Train Loss: 0.0860, Train Acc: 0.9735
# Val Loss: 1.2993, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [311/1500]
# Train Loss: 0.0824, Train Acc: 0.9769
# Val Loss: 1.2054, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [312/1500]
# Train Loss: 0.0835, Train Acc: 0.9726
# Val Loss: 1.1749, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [313/1500]
# Train Loss: 0.0901, Train Acc: 0.9752
# Val Loss: 1.0543, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [314/1500]
# Train Loss: 0.0790, Train Acc: 0.9786
# Val Loss: 1.1895, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [315/1500]
# Train Loss: 0.1049, Train Acc: 0.9666
# Val Loss: 1.2955, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [316/1500]
# Train Loss: 0.0937, Train Acc: 0.9709
# Val Loss: 1.1824, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [317/1500]
# Train Loss: 0.0847, Train Acc: 0.9718
# Val Loss: 1.2698, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [318/1500]
# Train Loss: 0.0820, Train Acc: 0.9709
# Val Loss: 1.2631, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [319/1500]
# Train Loss: 0.0911, Train Acc: 0.9735
# Val Loss: 1.2383, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [320/1500]
# Train Loss: 0.0814, Train Acc: 0.9752
# Val Loss: 1.2270, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [321/1500]
# Train Loss: 0.0806, Train Acc: 0.9760
# Val Loss: 1.1765, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [322/1500]
# Train Loss: 0.0893, Train Acc: 0.9743
# Val Loss: 1.1925, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [323/1500]
# Train Loss: 0.0763, Train Acc: 0.9743
# Val Loss: 1.2582, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [324/1500]
# Train Loss: 0.0953, Train Acc: 0.9718
# Val Loss: 1.3265, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [325/1500]
# Train Loss: 0.0755, Train Acc: 0.9752
# Val Loss: 1.2865, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [326/1500]
# Train Loss: 0.0627, Train Acc: 0.9812
# Val Loss: 1.3091, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [327/1500]
# Train Loss: 0.0755, Train Acc: 0.9778
# Val Loss: 1.3016, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [328/1500]
# Train Loss: 0.0828, Train Acc: 0.9726
# Val Loss: 1.3316, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [329/1500]
# Train Loss: 0.0702, Train Acc: 0.9812
# Val Loss: 1.2999, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [330/1500]
# Train Loss: 0.0662, Train Acc: 0.9778
# Val Loss: 1.1855, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [331/1500]
# Train Loss: 0.0749, Train Acc: 0.9769
# Val Loss: 1.2066, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [332/1500]
# Train Loss: 0.0846, Train Acc: 0.9675
# Val Loss: 1.3111, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [333/1500]
# Train Loss: 0.0790, Train Acc: 0.9735
# Val Loss: 1.2355, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [334/1500]
# Train Loss: 0.0951, Train Acc: 0.9701
# Val Loss: 1.1873, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [335/1500]
# Train Loss: 0.0712, Train Acc: 0.9760
# Val Loss: 1.2057, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [336/1500]
# Train Loss: 0.0738, Train Acc: 0.9760
# Val Loss: 1.1656, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [337/1500]
# Train Loss: 0.0603, Train Acc: 0.9812
# Val Loss: 1.3212, Val Acc: 0.6716
# --------------------------------------------------
# Epoch [338/1500]
# Train Loss: 0.0832, Train Acc: 0.9675
# Val Loss: 1.3101, Val Acc: 0.6605
# --------------------------------------------------
# Epoch [339/1500]
# Train Loss: 0.0721, Train Acc: 0.9726
# Val Loss: 1.2706, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [340/1500]
# Train Loss: 0.0769, Train Acc: 0.9726
# Val Loss: 1.2135, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [341/1500]
# Train Loss: 0.0711, Train Acc: 0.9786
# Val Loss: 1.1769, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [342/1500]
# Train Loss: 0.0811, Train Acc: 0.9752
# Val Loss: 1.2735, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [343/1500]
# Train Loss: 0.0610, Train Acc: 0.9812
# Val Loss: 1.2387, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [344/1500]
# Train Loss: 0.0656, Train Acc: 0.9812
# ...
# --------------------------------------------------
# Epoch [1388/1500]
# Train Loss: 0.0191, Train Acc: 0.9966
# Val Loss: 1.4245, Val Acc: 0.7196
# --------------------------------------------------
# Epoch [1389/1500]
# Train Loss: 0.0172, Train Acc: 0.9949
# Val Loss: 1.5948, Val Acc: 0.7196
# --------------------------------------------------
# Epoch [1390/1500]
# Train Loss: 0.0175, Train Acc: 0.9949
# Val Loss: 1.5223, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1391/1500]
# Train Loss: 0.0190, Train Acc: 0.9957
# Val Loss: 1.4444, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1392/1500]
# Train Loss: 0.0231, Train Acc: 0.9932
# Val Loss: 1.3615, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1393/1500]
# Train Loss: 0.0106, Train Acc: 0.9983
# Val Loss: 1.4288, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [1394/1500]
# Train Loss: 0.0173, Train Acc: 0.9949
# Val Loss: 1.5552, Val Acc: 0.7269
# --------------------------------------------------
# Epoch [1395/1500]
# Train Loss: 0.0222, Train Acc: 0.9923
# Val Loss: 1.5616, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1396/1500]
# Train Loss: 0.0277, Train Acc: 0.9932
# Val Loss: 1.6108, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1397/1500]
# Train Loss: 0.0101, Train Acc: 0.9974
# Val Loss: 1.6429, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1398/1500]
# Train Loss: 0.0169, Train Acc: 0.9957
# Val Loss: 1.6376, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1399/1500]
# Train Loss: 0.0162, Train Acc: 0.9949
# Val Loss: 1.6088, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [1400/1500]
# Train Loss: 0.0280, Train Acc: 0.9906
# Val Loss: 1.6173, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1401/1500]
# Train Loss: 0.0268, Train Acc: 0.9923
# Val Loss: 1.6253, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1402/1500]
# Train Loss: 0.0124, Train Acc: 0.9957
# Val Loss: 1.6570, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [1403/1500]
# Train Loss: 0.0221, Train Acc: 0.9932
# Val Loss: 1.5174, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1404/1500]
# Train Loss: 0.0241, Train Acc: 0.9932
# Val Loss: 1.2655, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1405/1500]
# Train Loss: 0.0135, Train Acc: 0.9974
# Val Loss: 1.2967, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1406/1500]
# Train Loss: 0.0146, Train Acc: 0.9923
# Val Loss: 1.4817, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1407/1500]
# Train Loss: 0.0200, Train Acc: 0.9932
# Val Loss: 1.5821, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [1408/1500]
# Train Loss: 0.0129, Train Acc: 0.9983
# Val Loss: 1.4711, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1409/1500]
# Train Loss: 0.0198, Train Acc: 0.9932
# Val Loss: 1.4191, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [1410/1500]
# Train Loss: 0.0215, Train Acc: 0.9914
# Val Loss: 1.4634, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1411/1500]
# Train Loss: 0.0164, Train Acc: 0.9966
# Val Loss: 1.4270, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1412/1500]
# Train Loss: 0.0132, Train Acc: 0.9983
# Val Loss: 1.3795, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [1413/1500]
# Train Loss: 0.0249, Train Acc: 0.9897
# Val Loss: 1.3238, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [1414/1500]
# Train Loss: 0.0130, Train Acc: 0.9949
# Val Loss: 1.3437, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1415/1500]
# Train Loss: 0.0132, Train Acc: 0.9949
# Val Loss: 1.4354, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [1416/1500]
# Train Loss: 0.0247, Train Acc: 0.9957
# Val Loss: 1.4527, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1417/1500]
# Train Loss: 0.0185, Train Acc: 0.9932
# Val Loss: 1.5523, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1418/1500]
# Train Loss: 0.0179, Train Acc: 0.9949
# Val Loss: 1.6295, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1419/1500]
# Train Loss: 0.0230, Train Acc: 0.9914
# Val Loss: 1.6207, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1420/1500]
# Train Loss: 0.0211, Train Acc: 0.9940
# Val Loss: 1.6063, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1421/1500]
# Train Loss: 0.0163, Train Acc: 0.9940
# Val Loss: 1.6973, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1422/1500]
# Train Loss: 0.0161, Train Acc: 0.9932
# Val Loss: 1.7079, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1423/1500]
# Train Loss: 0.0159, Train Acc: 0.9957
# Val Loss: 1.6325, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [1424/1500]
# Train Loss: 0.0148, Train Acc: 0.9949
# Val Loss: 1.5177, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1425/1500]
# Train Loss: 0.0215, Train Acc: 0.9932
# Val Loss: 1.3612, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [1426/1500]
# Train Loss: 0.0165, Train Acc: 0.9974
# Val Loss: 1.4151, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1427/1500]
# Train Loss: 0.0151, Train Acc: 0.9940
# Val Loss: 1.4966, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1428/1500]
# Train Loss: 0.0120, Train Acc: 0.9957
# Val Loss: 1.4757, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1429/1500]
# Train Loss: 0.0172, Train Acc: 0.9957
# Val Loss: 1.4035, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [1430/1500]
# Train Loss: 0.0194, Train Acc: 0.9949
# Val Loss: 1.3702, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1431/1500]
# Train Loss: 0.0126, Train Acc: 0.9966
# Val Loss: 1.3937, Val Acc: 0.7196
# --------------------------------------------------
# Epoch [1432/1500]
# Train Loss: 0.0215, Train Acc: 0.9923
# Val Loss: 1.4558, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1433/1500]
# Train Loss: 0.0286, Train Acc: 0.9940
# Val Loss: 1.4569, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [1434/1500]
# Train Loss: 0.0134, Train Acc: 0.9991
# Val Loss: 1.4152, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1435/1500]
# Train Loss: 0.0247, Train Acc: 0.9923
# Val Loss: 1.4213, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1436/1500]
# Train Loss: 0.0304, Train Acc: 0.9923
# Val Loss: 1.3939, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [1437/1500]
# Train Loss: 0.0253, Train Acc: 0.9872
# Val Loss: 1.4697, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1438/1500]
# Train Loss: 0.0208, Train Acc: 0.9932
# Val Loss: 1.7143, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1439/1500]
# Train Loss: 0.0189, Train Acc: 0.9940
# Val Loss: 1.8114, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1440/1500]
# Train Loss: 0.0153, Train Acc: 0.9957
# Val Loss: 1.6712, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1441/1500]
# Train Loss: 0.0260, Train Acc: 0.9897
# Val Loss: 1.4927, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [1442/1500]
# Train Loss: 0.0221, Train Acc: 0.9923
# Val Loss: 1.4885, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1443/1500]
# Train Loss: 0.0219, Train Acc: 0.9932
# Val Loss: 1.5938, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [1444/1500]
# Train Loss: 0.0204, Train Acc: 0.9949
# Val Loss: 1.6656, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [1445/1500]
# Train Loss: 0.0199, Train Acc: 0.9949
# Val Loss: 1.5994, Val Acc: 0.6642
# --------------------------------------------------
# Epoch [1446/1500]
# Train Loss: 0.0253, Train Acc: 0.9897
# Val Loss: 1.4957, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [1447/1500]
# Train Loss: 0.0119, Train Acc: 0.9966
# Val Loss: 1.4548, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [1448/1500]
# Train Loss: 0.0283, Train Acc: 0.9914
# Val Loss: 1.5853, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [1449/1500]
# Train Loss: 0.0345, Train Acc: 0.9889
# Val Loss: 1.5301, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1450/1500]
# Train Loss: 0.0177, Train Acc: 0.9949
# Val Loss: 1.3730, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1451/1500]
# Train Loss: 0.0224, Train Acc: 0.9949
# Val Loss: 1.2173, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [1452/1500]
# Train Loss: 0.0274, Train Acc: 0.9906
# Val Loss: 1.2341, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1453/1500]
# Train Loss: 0.0106, Train Acc: 0.9974
# Val Loss: 1.3198, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1454/1500]
# Train Loss: 0.0221, Train Acc: 0.9949
# Val Loss: 1.3633, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1455/1500]
# Train Loss: 0.0256, Train Acc: 0.9940
# Val Loss: 1.4112, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1456/1500]
# Train Loss: 0.0246, Train Acc: 0.9923
# Val Loss: 1.6222, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [1457/1500]
# Train Loss: 0.0334, Train Acc: 0.9906
# Val Loss: 1.6918, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [1458/1500]
# Train Loss: 0.0151, Train Acc: 0.9949
# Val Loss: 1.6474, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [1459/1500]
# Train Loss: 0.0137, Train Acc: 0.9957
# Val Loss: 1.4943, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [1460/1500]
# Train Loss: 0.0166, Train Acc: 0.9940
# Val Loss: 1.4297, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1461/1500]
# Train Loss: 0.0183, Train Acc: 0.9949
# Val Loss: 1.5068, Val Acc: 0.6790
# --------------------------------------------------
# Epoch [1462/1500]
# Train Loss: 0.0175, Train Acc: 0.9949
# Val Loss: 1.4950, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1463/1500]
# Train Loss: 0.0234, Train Acc: 0.9932
# Val Loss: 1.4747, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [1464/1500]
# Train Loss: 0.0152, Train Acc: 0.9957
# Val Loss: 1.3735, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1465/1500]
# Train Loss: 0.0222, Train Acc: 0.9923
# Val Loss: 1.2467, Val Acc: 0.7196
# --------------------------------------------------
# Epoch [1466/1500]
# Train Loss: 0.0257, Train Acc: 0.9897
# Val Loss: 1.3534, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1467/1500]
# Train Loss: 0.0170, Train Acc: 0.9966
# Val Loss: 1.3966, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1468/1500]
# Train Loss: 0.0206, Train Acc: 0.9914
# Val Loss: 1.3704, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1469/1500]
# Train Loss: 0.0173, Train Acc: 0.9949
# Val Loss: 1.4146, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1470/1500]
# Train Loss: 0.0254, Train Acc: 0.9897
# Val Loss: 1.3565, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1471/1500]
# Train Loss: 0.0206, Train Acc: 0.9940
# Val Loss: 1.4232, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1472/1500]
# Train Loss: 0.0161, Train Acc: 0.9949
# Val Loss: 1.4771, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1473/1500]
# Train Loss: 0.0236, Train Acc: 0.9932
# Val Loss: 1.3618, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [1474/1500]
# Train Loss: 0.0203, Train Acc: 0.9966
# Val Loss: 1.4118, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1475/1500]
# Train Loss: 0.0160, Train Acc: 0.9966
# Val Loss: 1.5554, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1476/1500]
# Train Loss: 0.0148, Train Acc: 0.9957
# Val Loss: 1.5318, Val Acc: 0.6753
# --------------------------------------------------
# Epoch [1477/1500]
# Train Loss: 0.0205, Train Acc: 0.9949
# Val Loss: 1.4532, Val Acc: 0.6827
# --------------------------------------------------
# Epoch [1478/1500]
# Train Loss: 0.0200, Train Acc: 0.9966
# Val Loss: 1.4453, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [1479/1500]
# Train Loss: 0.0126, Train Acc: 0.9974
# Val Loss: 1.4244, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [1480/1500]
# Train Loss: 0.0173, Train Acc: 0.9914
# Val Loss: 1.4350, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1481/1500]
# Train Loss: 0.0223, Train Acc: 0.9932
# Val Loss: 1.3459, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [1482/1500]
# Train Loss: 0.0145, Train Acc: 0.9966
# Val Loss: 1.3193, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [1483/1500]
# Train Loss: 0.0215, Train Acc: 0.9932
# Val Loss: 1.3193, Val Acc: 0.7048
# --------------------------------------------------
# Epoch [1484/1500]
# Train Loss: 0.0092, Train Acc: 0.9983
# Val Loss: 1.3578, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [1485/1500]
# Train Loss: 0.0152, Train Acc: 0.9932
# Val Loss: 1.3153, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1486/1500]
# Train Loss: 0.0119, Train Acc: 0.9983
# Val Loss: 1.2620, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1487/1500]
# Train Loss: 0.0158, Train Acc: 0.9957
# Val Loss: 1.2230, Val Acc: 0.7011
# --------------------------------------------------
# Epoch [1488/1500]
# Train Loss: 0.0256, Train Acc: 0.9940
# Val Loss: 1.2305, Val Acc: 0.6974
# --------------------------------------------------
# Epoch [1489/1500]
# Train Loss: 0.0175, Train Acc: 0.9932
# Val Loss: 1.3426, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [1490/1500]
# Train Loss: 0.0216, Train Acc: 0.9940
# Val Loss: 1.3605, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [1491/1500]
# Train Loss: 0.0204, Train Acc: 0.9923
# Val Loss: 1.4134, Val Acc: 0.7232
# --------------------------------------------------
# Epoch [1492/1500]
# Train Loss: 0.0160, Train Acc: 0.9966
# Val Loss: 1.4839, Val Acc: 0.7085
# --------------------------------------------------
# Epoch [1493/1500]
# Train Loss: 0.0141, Train Acc: 0.9932
# Val Loss: 1.4959, Val Acc: 0.6937
# --------------------------------------------------
# Epoch [1494/1500]
# Train Loss: 0.0129, Train Acc: 0.9966
# Val Loss: 1.4763, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [1495/1500]
# Train Loss: 0.0181, Train Acc: 0.9923
# Val Loss: 1.5497, Val Acc: 0.6863
# --------------------------------------------------
# Epoch [1496/1500]
# Train Loss: 0.0130, Train Acc: 0.9957
# Val Loss: 1.6550, Val Acc: 0.7159
# --------------------------------------------------
# Epoch [1497/1500]
# Train Loss: 0.0160, Train Acc: 0.9940
# Val Loss: 1.5528, Val Acc: 0.7122
# --------------------------------------------------
# Epoch [1498/1500]
# Train Loss: 0.0085, Train Acc: 0.9983
# Val Loss: 1.5493, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [1499/1500]
# Train Loss: 0.0172, Train Acc: 0.9957
# Val Loss: 1.5122, Val Acc: 0.6900
# --------------------------------------------------
# Epoch [1500/1500]
# Train Loss: 0.0162, Train Acc: 0.9949
# Val Loss: 1.4662, Val Acc: 0.7011
# --------------------------------------------------

# %%
torch.save(model.state_dict(), "C:/Nini/Capstone/Models/cnn_model_mel_mfcc_chroma_snippets.pth")
