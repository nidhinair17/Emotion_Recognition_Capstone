# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle

# %%
features = pd.read_csv("C:/Nini/Capstone/CSV_Files/ravdess_extracted_features_snippets.csv")
features = features.drop(features.columns[0], axis=1)
temp = shuffle(features)
df = np.random.rand(len(temp)) < 0.8
train = temp[df]
test = temp[~df]

# %%
X_train = np.array(train.iloc[:,:-1])
y_train = np.array(train.iloc[:,-1])
X_test = np.array(test.iloc[:,:-1])
y_test = np.array(test.iloc[:,-1])

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
batch_size = 256
train_loader = DataLoader(TensorDataset(X_train,y_train), batch_size=batch_size,shuffle=True)
test_loader = DataLoader(TensorDataset(X_test,y_test), batch_size=batch_size, shuffle=False)

# %%
class CNNModel(nn.Module):
    def __init__(self, input_size, num_classes):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=8)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=8)
        self.bn2 = nn.BatchNorm1d(128)
        self.pool1 = nn.MaxPool1d(kernel_size=4, padding=2)
        self.dropout1 = nn.Dropout(0.5)
        self.conv3 = nn.Conv1d(128, 128, kernel_size=8)
        self.bn3 = nn.BatchNorm1d(128)
        self.pool2 = nn.MaxPool1d(kernel_size=4, padding=2)
        self.dropout2 = nn.Dropout(0.5)
        self.conv4 = nn.Conv1d(128, 64, kernel_size=3, padding=2)
        self.bn4 = nn.BatchNorm1d(64)
        self.fc1 = nn.Linear(512, 256)
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, num_classes)

    # def _compute_flattened_size(self, input_size):
    #     with torch.no_grad():
    #         x = torch.randn(1, 1, input_size)  # Create a dummy input
    #         x = self.conv1(x)
    #         x = F.relu(x)
    #         x = self.conv2(x)
    #         x = F.relu(x)
    #         x = self.pool1(x)
    #         x = self.dropout1(x)
    #         x = self.conv3(x)
    #         x = F.relu(x)
    #         x = self.pool2(x)
    #         x = self.dropout2(x)
    #         x = self.conv4(x)
    #         x = F.relu(x)
    #         x = x.view(1, -1)  # Flatten
    #         self._to_linear = x.shape[1]

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNModel(input_size=X_train.shape[1], num_classes=8).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=1e-4)

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: torch.Size([4166, 1, 128])

# %%
epochs = 1500
for epoch in range(epochs):
    model.train()
    running_loss = 0
    total_loss = 0
    total = 0
    correct = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)
    train_accuracy = correct / total
    avg_train_loss = running_loss / len(train_loader)
        # total_loss += loss.item()
        # correct += (outputs.argmax(dim=1) == y_batch).sum().item()
    model.eval()  # Set model to evaluation mode
    val_correct = 0
    val_total = 0
    val_loss = 0.0

    with torch.no_grad():  # Disable gradient computation for validation
        for val_inputs, val_labels in test_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)

            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()

            _, val_predicted = torch.max(val_outputs, 1)
            val_correct += (val_predicted == val_labels).sum().item()
            val_total += val_labels.size(0)
    
    val_accuracy = val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)
    # accuracy = correct / len(train_loader.dataset)
    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    print("-" * 50)
# Out:
# Epoch [1/1500]
# Train Loss: 2.0058, Train Acc: 0.1776
# Val Loss: 1.9636, Val Acc: 0.2129
# --------------------------------------------------
# Epoch [2/1500]
# Train Loss: 1.9200, Train Acc: 0.2271
# Val Loss: 1.9135, Val Acc: 0.2512
# --------------------------------------------------
# Epoch [3/1500]
# Train Loss: 1.9016, Train Acc: 0.2458
# Val Loss: 1.8884, Val Acc: 0.2325
# --------------------------------------------------
# Epoch [4/1500]
# Train Loss: 1.8530, Train Acc: 0.2626
# Val Loss: 1.8377, Val Acc: 0.2577
# --------------------------------------------------
# Epoch [5/1500]
# Train Loss: 1.8347, Train Acc: 0.2698
# Val Loss: 1.8309, Val Acc: 0.2652
# --------------------------------------------------
# Epoch [6/1500]
# Train Loss: 1.8114, Train Acc: 0.2782
# Val Loss: 1.8305, Val Acc: 0.2698
# --------------------------------------------------
# Epoch [7/1500]
# Train Loss: 1.8020, Train Acc: 0.2823
# Val Loss: 1.8153, Val Acc: 0.2736
# --------------------------------------------------
# Epoch [8/1500]
# Train Loss: 1.7876, Train Acc: 0.2861
# Val Loss: 1.8020, Val Acc: 0.2848
# --------------------------------------------------
# Epoch [9/1500]
# Train Loss: 1.7792, Train Acc: 0.2880
# Val Loss: 1.7757, Val Acc: 0.2857
# --------------------------------------------------
# Epoch [10/1500]
# Train Loss: 1.7739, Train Acc: 0.3022
# Val Loss: 1.7706, Val Acc: 0.3044
# --------------------------------------------------
# Epoch [11/1500]
# Train Loss: 1.7527, Train Acc: 0.3041
# Val Loss: 1.7586, Val Acc: 0.3044
# --------------------------------------------------
# Epoch [12/1500]
# Train Loss: 1.7374, Train Acc: 0.3269
# Val Loss: 1.7481, Val Acc: 0.3044
# --------------------------------------------------
# Epoch [13/1500]
# Train Loss: 1.7213, Train Acc: 0.3202
# Val Loss: 1.7356, Val Acc: 0.3249
# --------------------------------------------------
# Epoch [14/1500]
# Train Loss: 1.7164, Train Acc: 0.3281
# Val Loss: 1.7222, Val Acc: 0.3380
# --------------------------------------------------
# Epoch [15/1500]
# Train Loss: 1.7020, Train Acc: 0.3380
# Val Loss: 1.6985, Val Acc: 0.3268
# --------------------------------------------------
# Epoch [16/1500]
# Train Loss: 1.6860, Train Acc: 0.3411
# Val Loss: 1.6888, Val Acc: 0.3557
# --------------------------------------------------
# Epoch [17/1500]
# Train Loss: 1.6818, Train Acc: 0.3500
# Val Loss: 1.6684, Val Acc: 0.3697
# --------------------------------------------------
# Epoch [18/1500]
# Train Loss: 1.6599, Train Acc: 0.3601
# Val Loss: 1.6992, Val Acc: 0.3585
# --------------------------------------------------
# Epoch [19/1500]
# Train Loss: 1.6615, Train Acc: 0.3526
# Val Loss: 1.6778, Val Acc: 0.3548
# --------------------------------------------------
# Epoch [20/1500]
# Train Loss: 1.6349, Train Acc: 0.3687
# Val Loss: 1.6628, Val Acc: 0.3688
# --------------------------------------------------
# Epoch [21/1500]
# Train Loss: 1.6356, Train Acc: 0.3632
# Val Loss: 1.6463, Val Acc: 0.3838
# --------------------------------------------------
# Epoch [22/1500]
# Train Loss: 1.6253, Train Acc: 0.3754
# Val Loss: 1.6285, Val Acc: 0.3791
# --------------------------------------------------
# Epoch [23/1500]
# Train Loss: 1.6180, Train Acc: 0.3800
# Val Loss: 1.6368, Val Acc: 0.3912
# --------------------------------------------------
# Epoch [24/1500]
# Train Loss: 1.6064, Train Acc: 0.3773
# Val Loss: 1.6150, Val Acc: 0.3875
# --------------------------------------------------
# Epoch [25/1500]
# Train Loss: 1.5969, Train Acc: 0.3862
# Val Loss: 1.6048, Val Acc: 0.3950
# --------------------------------------------------
# Epoch [26/1500]
# Train Loss: 1.5908, Train Acc: 0.3925
# Val Loss: 1.6064, Val Acc: 0.4062
# --------------------------------------------------
# Epoch [27/1500]
# Train Loss: 1.5668, Train Acc: 0.4016
# Val Loss: 1.5752, Val Acc: 0.4230
# --------------------------------------------------
# Epoch [28/1500]
# Train Loss: 1.5642, Train Acc: 0.3927
# Val Loss: 1.5748, Val Acc: 0.4220
# --------------------------------------------------
# Epoch [29/1500]
# Train Loss: 1.5486, Train Acc: 0.4076
# Val Loss: 1.5817, Val Acc: 0.4192
# --------------------------------------------------
# Epoch [30/1500]
# Train Loss: 1.5635, Train Acc: 0.4061
# Val Loss: 1.5672, Val Acc: 0.4108
# --------------------------------------------------
# Epoch [31/1500]
# Train Loss: 1.5432, Train Acc: 0.4023
# Val Loss: 1.5692, Val Acc: 0.3996
# --------------------------------------------------
# Epoch [32/1500]
# Train Loss: 1.5374, Train Acc: 0.4196
# Val Loss: 1.5437, Val Acc: 0.4211
# --------------------------------------------------
# Epoch [33/1500]
# Train Loss: 1.5324, Train Acc: 0.4160
# Val Loss: 1.5486, Val Acc: 0.4258
# --------------------------------------------------
# Epoch [34/1500]
# Train Loss: 1.5146, Train Acc: 0.4225
# Val Loss: 1.5375, Val Acc: 0.4183
# --------------------------------------------------
# Epoch [35/1500]
# Train Loss: 1.5106, Train Acc: 0.4198
# Val Loss: 1.5270, Val Acc: 0.4314
# --------------------------------------------------
# Epoch [36/1500]
# Train Loss: 1.5033, Train Acc: 0.4265
# Val Loss: 1.5156, Val Acc: 0.4239
# --------------------------------------------------
# Epoch [37/1500]
# Train Loss: 1.5059, Train Acc: 0.4361
# Val Loss: 1.5206, Val Acc: 0.4398
# --------------------------------------------------
# Epoch [38/1500]
# Train Loss: 1.4901, Train Acc: 0.4381
# Val Loss: 1.5096, Val Acc: 0.4276
# --------------------------------------------------
# Epoch [39/1500]
# Train Loss: 1.4842, Train Acc: 0.4388
# Val Loss: 1.5087, Val Acc: 0.4267
# --------------------------------------------------
# Epoch [40/1500]
# Train Loss: 1.4632, Train Acc: 0.4431
# Val Loss: 1.5021, Val Acc: 0.4295
# --------------------------------------------------
# Epoch [41/1500]
# Train Loss: 1.4596, Train Acc: 0.4395
# Val Loss: 1.4981, Val Acc: 0.4286
# --------------------------------------------------
# Epoch [42/1500]
# Train Loss: 1.4606, Train Acc: 0.4395
# Val Loss: 1.4909, Val Acc: 0.4426
# --------------------------------------------------
# Epoch [43/1500]
# Train Loss: 1.4489, Train Acc: 0.4585
# Val Loss: 1.4950, Val Acc: 0.4295
# --------------------------------------------------
# Epoch [44/1500]
# Train Loss: 1.4612, Train Acc: 0.4551
# Val Loss: 1.4770, Val Acc: 0.4332
# --------------------------------------------------
# Epoch [45/1500]
# Train Loss: 1.4340, Train Acc: 0.4525
# Val Loss: 1.4883, Val Acc: 0.4342
# --------------------------------------------------
# Epoch [46/1500]
# Train Loss: 1.4156, Train Acc: 0.4606
# Val Loss: 1.4932, Val Acc: 0.4444
# --------------------------------------------------
# Epoch [47/1500]
# Train Loss: 1.4267, Train Acc: 0.4501
# Val Loss: 1.4507, Val Acc: 0.4454
# --------------------------------------------------
# Epoch [48/1500]
# Train Loss: 1.4027, Train Acc: 0.4611
# Val Loss: 1.4968, Val Acc: 0.4398
# --------------------------------------------------
# Epoch [49/1500]
# Train Loss: 1.4203, Train Acc: 0.4578
# Val Loss: 1.4488, Val Acc: 0.4444
# --------------------------------------------------
# Epoch [50/1500]
# Train Loss: 1.4132, Train Acc: 0.4753
# Val Loss: 1.4616, Val Acc: 0.4528
# --------------------------------------------------
# Epoch [51/1500]
# Train Loss: 1.4012, Train Acc: 0.4671
# Val Loss: 1.4538, Val Acc: 0.4500
# --------------------------------------------------
# Epoch [52/1500]
# Train Loss: 1.3899, Train Acc: 0.4736
# Val Loss: 1.4588, Val Acc: 0.4454
# --------------------------------------------------
# Epoch [53/1500]
# Train Loss: 1.3798, Train Acc: 0.4808
# Val Loss: 1.4453, Val Acc: 0.4594
# --------------------------------------------------
# Epoch [54/1500]
# Train Loss: 1.3793, Train Acc: 0.4801
# Val Loss: 1.4646, Val Acc: 0.4538
# --------------------------------------------------
# Epoch [55/1500]
# Train Loss: 1.3824, Train Acc: 0.4801
# Val Loss: 1.4485, Val Acc: 0.4556
# --------------------------------------------------
# Epoch [56/1500]
# Train Loss: 1.3586, Train Acc: 0.4858
# Val Loss: 1.4112, Val Acc: 0.4613
# --------------------------------------------------
# Epoch [57/1500]
# Train Loss: 1.3624, Train Acc: 0.4736
# Val Loss: 1.4300, Val Acc: 0.4491
# --------------------------------------------------
# Epoch [58/1500]
# Train Loss: 1.3446, Train Acc: 0.4923
# Val Loss: 1.4703, Val Acc: 0.4360
# --------------------------------------------------
# Epoch [59/1500]
# Train Loss: 1.3480, Train Acc: 0.4885
# Val Loss: 1.4249, Val Acc: 0.4566
# --------------------------------------------------
# Epoch [60/1500]
# Train Loss: 1.3421, Train Acc: 0.4928
# Val Loss: 1.4351, Val Acc: 0.4556
# --------------------------------------------------
# Epoch [61/1500]
# Train Loss: 1.3478, Train Acc: 0.4933
# Val Loss: 1.4178, Val Acc: 0.4613
# --------------------------------------------------
# Epoch [62/1500]
# Train Loss: 1.3393, Train Acc: 0.4966
# Val Loss: 1.4077, Val Acc: 0.4613
# --------------------------------------------------
# Epoch [63/1500]
# Train Loss: 1.3478, Train Acc: 0.4978
# Val Loss: 1.4147, Val Acc: 0.4622
# --------------------------------------------------
# Epoch [64/1500]
# Train Loss: 1.3278, Train Acc: 0.4933
# Val Loss: 1.4281, Val Acc: 0.4547
# --------------------------------------------------
# Epoch [65/1500]
# Train Loss: 1.3143, Train Acc: 0.4940
# Val Loss: 1.4004, Val Acc: 0.4659
# --------------------------------------------------
# Epoch [66/1500]
# Train Loss: 1.3127, Train Acc: 0.4971
# Val Loss: 1.4213, Val Acc: 0.4566
# --------------------------------------------------
# Epoch [67/1500]
# Train Loss: 1.3396, Train Acc: 0.4954
# Val Loss: 1.3972, Val Acc: 0.4585
# --------------------------------------------------
# Epoch [68/1500]
# Train Loss: 1.3093, Train Acc: 0.5079
# Val Loss: 1.3873, Val Acc: 0.4622
# --------------------------------------------------
# Epoch [69/1500]
# Train Loss: 1.2960, Train Acc: 0.5086
# Val Loss: 1.4101, Val Acc: 0.4566
# --------------------------------------------------
# Epoch [70/1500]
# Train Loss: 1.3019, Train Acc: 0.5089
# Val Loss: 1.3926, Val Acc: 0.4641
# --------------------------------------------------
# Epoch [71/1500]
# Train Loss: 1.2981, Train Acc: 0.5091
# Val Loss: 1.4060, Val Acc: 0.4613
# --------------------------------------------------
# Epoch [72/1500]
# Train Loss: 1.2707, Train Acc: 0.5214
# Val Loss: 1.4012, Val Acc: 0.4613
# --------------------------------------------------
# Epoch [73/1500]
# Train Loss: 1.2721, Train Acc: 0.5182
# Val Loss: 1.3868, Val Acc: 0.4837
# --------------------------------------------------
# Epoch [74/1500]
# Train Loss: 1.2668, Train Acc: 0.5245
# Val Loss: 1.3840, Val Acc: 0.4706
# --------------------------------------------------
# Epoch [75/1500]
# Train Loss: 1.2756, Train Acc: 0.5182
# Val Loss: 1.3770, Val Acc: 0.4706
# --------------------------------------------------
# Epoch [76/1500]
# Train Loss: 1.2490, Train Acc: 0.5300
# Val Loss: 1.3938, Val Acc: 0.4715
# --------------------------------------------------
# Epoch [77/1500]
# Train Loss: 1.2767, Train Acc: 0.5175
# Val Loss: 1.3857, Val Acc: 0.4743
# --------------------------------------------------
# Epoch [78/1500]
# Train Loss: 1.2485, Train Acc: 0.5288
# Val Loss: 1.3845, Val Acc: 0.4706
# --------------------------------------------------
# Epoch [79/1500]
# Train Loss: 1.2511, Train Acc: 0.5250
# Val Loss: 1.3672, Val Acc: 0.4678
# --------------------------------------------------
# Epoch [80/1500]
# Train Loss: 1.2586, Train Acc: 0.5274
# Val Loss: 1.3523, Val Acc: 0.4743
# --------------------------------------------------
# Epoch [81/1500]
# Train Loss: 1.2220, Train Acc: 0.5374
# Val Loss: 1.3935, Val Acc: 0.4715
# --------------------------------------------------
# Epoch [82/1500]
# Train Loss: 1.2237, Train Acc: 0.5350
# Val Loss: 1.3925, Val Acc: 0.4809
# --------------------------------------------------
# Epoch [83/1500]
# Train Loss: 1.2299, Train Acc: 0.5494
# Val Loss: 1.3705, Val Acc: 0.4706
# --------------------------------------------------
# Epoch [84/1500]
# Train Loss: 1.2200, Train Acc: 0.5367
# Val Loss: 1.3722, Val Acc: 0.4893
# --------------------------------------------------
# Epoch [85/1500]
# Train Loss: 1.2191, Train Acc: 0.5449
# Val Loss: 1.3846, Val Acc: 0.4678
# --------------------------------------------------
# Epoch [86/1500]
# Train Loss: 1.2254, Train Acc: 0.5341
# Val Loss: 1.3774, Val Acc: 0.4855
# --------------------------------------------------
# Epoch [87/1500]
# Train Loss: 1.2186, Train Acc: 0.5432
# Val Loss: 1.3568, Val Acc: 0.4837
# --------------------------------------------------
# Epoch [88/1500]
# Train Loss: 1.2124, Train Acc: 0.5497
# Val Loss: 1.3682, Val Acc: 0.4743
# --------------------------------------------------
# Epoch [89/1500]
# Train Loss: 1.2208, Train Acc: 0.5480
# Val Loss: 1.3518, Val Acc: 0.4846
# --------------------------------------------------
# Epoch [90/1500]
# Train Loss: 1.1971, Train Acc: 0.5506
# Val Loss: 1.3756, Val Acc: 0.4930
# --------------------------------------------------
# Epoch [91/1500]
# Train Loss: 1.1914, Train Acc: 0.5497
# Val Loss: 1.3740, Val Acc: 0.4911
# --------------------------------------------------
# Epoch [92/1500]
# Train Loss: 1.1865, Train Acc: 0.5482
# Val Loss: 1.3571, Val Acc: 0.4893
# --------------------------------------------------
# Epoch [93/1500]
# Train Loss: 1.1762, Train Acc: 0.5622
# Val Loss: 1.3578, Val Acc: 0.4949
# --------------------------------------------------
# Epoch [94/1500]
# Train Loss: 1.1621, Train Acc: 0.5562
# Val Loss: 1.3494, Val Acc: 0.4930
# --------------------------------------------------
# Epoch [95/1500]
# Train Loss: 1.1736, Train Acc: 0.5552
# Val Loss: 1.3628, Val Acc: 0.4958
# --------------------------------------------------
# Epoch [96/1500]
# Train Loss: 1.1542, Train Acc: 0.5634
# Val Loss: 1.3633, Val Acc: 0.4846
# --------------------------------------------------
# Epoch [97/1500]
# Train Loss: 1.1736, Train Acc: 0.5629
# Val Loss: 1.3306, Val Acc: 0.5005
# --------------------------------------------------
# Epoch [98/1500]
# Train Loss: 1.1527, Train Acc: 0.5528
# Val Loss: 1.3595, Val Acc: 0.4855
# --------------------------------------------------
# Epoch [99/1500]
# Train Loss: 1.1713, Train Acc: 0.5574
# Val Loss: 1.3322, Val Acc: 0.4874
# --------------------------------------------------
# Epoch [100/1500]
# Train Loss: 1.1446, Train Acc: 0.5792
# Val Loss: 1.3275, Val Acc: 0.5005
# --------------------------------------------------
# Epoch [101/1500]
# Train Loss: 1.1607, Train Acc: 0.5660
# Val Loss: 1.3313, Val Acc: 0.4883
# --------------------------------------------------
# Epoch [102/1500]
# Train Loss: 1.1519, Train Acc: 0.5718
# Val Loss: 1.3421, Val Acc: 0.4939
# --------------------------------------------------
# Epoch [103/1500]
# Train Loss: 1.1255, Train Acc: 0.5783
# Val Loss: 1.3376, Val Acc: 0.4874
# --------------------------------------------------
# Epoch [104/1500]
# Train Loss: 1.1262, Train Acc: 0.5790
# Val Loss: 1.3384, Val Acc: 0.4921
# --------------------------------------------------
# Epoch [105/1500]
# Train Loss: 1.1410, Train Acc: 0.5715
# Val Loss: 1.3820, Val Acc: 0.4827
# --------------------------------------------------
# Epoch [106/1500]
# Train Loss: 1.1457, Train Acc: 0.5701
# Val Loss: 1.3166, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [107/1500]
# Train Loss: 1.1271, Train Acc: 0.5771
# Val Loss: 1.3218, Val Acc: 0.4883
# --------------------------------------------------
# Epoch [108/1500]
# Train Loss: 1.1334, Train Acc: 0.5744
# Val Loss: 1.3368, Val Acc: 0.4958
# --------------------------------------------------
# Epoch [109/1500]
# Train Loss: 1.1347, Train Acc: 0.5679
# Val Loss: 1.3192, Val Acc: 0.4930
# --------------------------------------------------
# Epoch [110/1500]
# Train Loss: 1.1146, Train Acc: 0.5881
# Val Loss: 1.3287, Val Acc: 0.4967
# --------------------------------------------------
# Epoch [111/1500]
# Train Loss: 1.0958, Train Acc: 0.5871
# Val Loss: 1.3268, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [112/1500]
# Train Loss: 1.0956, Train Acc: 0.5876
# Val Loss: 1.3170, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [113/1500]
# Train Loss: 1.1283, Train Acc: 0.5739
# Val Loss: 1.3130, Val Acc: 0.4995
# --------------------------------------------------
# Epoch [114/1500]
# Train Loss: 1.0963, Train Acc: 0.5869
# Val Loss: 1.3416, Val Acc: 0.4921
# --------------------------------------------------
# Epoch [115/1500]
# Train Loss: 1.0965, Train Acc: 0.5893
# Val Loss: 1.3297, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [116/1500]
# Train Loss: 1.0842, Train Acc: 0.5953
# Val Loss: 1.3039, Val Acc: 0.4977
# --------------------------------------------------
# Epoch [117/1500]
# Train Loss: 1.1081, Train Acc: 0.5862
# Val Loss: 1.3280, Val Acc: 0.5033
# --------------------------------------------------
# Epoch [118/1500]
# Train Loss: 1.0890, Train Acc: 0.5955
# Val Loss: 1.3117, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [119/1500]
# Train Loss: 1.0593, Train Acc: 0.6015
# Val Loss: 1.2989, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [120/1500]
# Train Loss: 1.0633, Train Acc: 0.5905
# Val Loss: 1.3438, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [121/1500]
# Train Loss: 1.0887, Train Acc: 0.5915
# Val Loss: 1.3153, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [122/1500]
# Train Loss: 1.0650, Train Acc: 0.5895
# Val Loss: 1.3112, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [123/1500]
# Train Loss: 1.0632, Train Acc: 0.6018
# Val Loss: 1.3461, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [124/1500]
# Train Loss: 1.0542, Train Acc: 0.5991
# Val Loss: 1.3237, Val Acc: 0.5005
# --------------------------------------------------
# Epoch [125/1500]
# Train Loss: 1.0378, Train Acc: 0.6092
# Val Loss: 1.3295, Val Acc: 0.4967
# --------------------------------------------------
# Epoch [126/1500]
# Train Loss: 1.0755, Train Acc: 0.6063
# Val Loss: 1.3143, Val Acc: 0.5098
# --------------------------------------------------
# Epoch [127/1500]
# Train Loss: 1.0355, Train Acc: 0.6114
# Val Loss: 1.3219, Val Acc: 0.5033
# --------------------------------------------------
# Epoch [128/1500]
# Train Loss: 1.0363, Train Acc: 0.6061
# Val Loss: 1.3168, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [129/1500]
# Train Loss: 1.0509, Train Acc: 0.6171
# Val Loss: 1.2993, Val Acc: 0.5014
# --------------------------------------------------
# Epoch [130/1500]
# Train Loss: 1.0242, Train Acc: 0.6191
# Val Loss: 1.3178, Val Acc: 0.5051
# --------------------------------------------------
# Epoch [131/1500]
# Train Loss: 1.0185, Train Acc: 0.6147
# Val Loss: 1.3691, Val Acc: 0.4967
# --------------------------------------------------
# Epoch [132/1500]
# Train Loss: 1.0426, Train Acc: 0.6080
# Val Loss: 1.3068, Val Acc: 0.5154
# --------------------------------------------------
# Epoch [133/1500]
# Train Loss: 1.0284, Train Acc: 0.6092
# Val Loss: 1.3339, Val Acc: 0.4977
# --------------------------------------------------
# Epoch [134/1500]
# Train Loss: 1.0262, Train Acc: 0.6087
# Val Loss: 1.3268, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [135/1500]
# Train Loss: 1.0052, Train Acc: 0.6195
# Val Loss: 1.3356, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [136/1500]
# Train Loss: 1.0094, Train Acc: 0.6179
# Val Loss: 1.3288, Val Acc: 0.5051
# --------------------------------------------------
# Epoch [137/1500]
# Train Loss: 0.9912, Train Acc: 0.6210
# Val Loss: 1.3237, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [138/1500]
# Train Loss: 0.9939, Train Acc: 0.6239
# Val Loss: 1.3162, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [139/1500]
# Train Loss: 0.9885, Train Acc: 0.6349
# Val Loss: 1.3582, Val Acc: 0.4986
# --------------------------------------------------
# Epoch [140/1500]
# Train Loss: 1.0022, Train Acc: 0.6227
# Val Loss: 1.3219, Val Acc: 0.5070
# --------------------------------------------------
# Epoch [141/1500]
# Train Loss: 1.0059, Train Acc: 0.6174
# Val Loss: 1.3038, Val Acc: 0.5033
# --------------------------------------------------
# Epoch [142/1500]
# Train Loss: 0.9991, Train Acc: 0.6342
# Val Loss: 1.3085, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [143/1500]
# Train Loss: 0.9816, Train Acc: 0.6426
# Val Loss: 1.3450, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [144/1500]
# Train Loss: 0.9964, Train Acc: 0.6327
# Val Loss: 1.3357, Val Acc: 0.4967
# --------------------------------------------------
# Epoch [145/1500]
# Train Loss: 0.9698, Train Acc: 0.6323
# Val Loss: 1.3345, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [146/1500]
# Train Loss: 0.9669, Train Acc: 0.6320
# Val Loss: 1.3232, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [147/1500]
# Train Loss: 0.9832, Train Acc: 0.6339
# Val Loss: 1.3305, Val Acc: 0.5070
# --------------------------------------------------
# Epoch [148/1500]
# Train Loss: 0.9331, Train Acc: 0.6409
# Val Loss: 1.3290, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [149/1500]
# Train Loss: 0.9738, Train Acc: 0.6399
# Val Loss: 1.3187, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [150/1500]
# Train Loss: 0.9537, Train Acc: 0.6469
# Val Loss: 1.3494, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [151/1500]
# Train Loss: 0.9591, Train Acc: 0.6407
# Val Loss: 1.3238, Val Acc: 0.5070
# --------------------------------------------------
# Epoch [152/1500]
# Train Loss: 0.9562, Train Acc: 0.6409
# Val Loss: 1.3121, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [153/1500]
# Train Loss: 0.9553, Train Acc: 0.6462
# Val Loss: 1.3278, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [154/1500]
# Train Loss: 0.9434, Train Acc: 0.6555
# Val Loss: 1.3685, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [155/1500]
# Train Loss: 0.9484, Train Acc: 0.6433
# Val Loss: 1.3090, Val Acc: 0.5033
# --------------------------------------------------
# Epoch [156/1500]
# Train Loss: 0.9313, Train Acc: 0.6512
# Val Loss: 1.3404, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [157/1500]
# Train Loss: 0.9404, Train Acc: 0.6575
# Val Loss: 1.3323, Val Acc: 0.5070
# --------------------------------------------------
# Epoch [158/1500]
# Train Loss: 0.9495, Train Acc: 0.6452
# Val Loss: 1.3263, Val Acc: 0.5005
# --------------------------------------------------
# Epoch [159/1500]
# Train Loss: 0.9449, Train Acc: 0.6495
# Val Loss: 1.3144, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [160/1500]
# Train Loss: 0.9611, Train Acc: 0.6431
# Val Loss: 1.3466, Val Acc: 0.4967
# --------------------------------------------------
# Epoch [161/1500]
# Train Loss: 0.9144, Train Acc: 0.6572
# Val Loss: 1.3612, Val Acc: 0.4967
# --------------------------------------------------
# Epoch [162/1500]
# Train Loss: 0.9245, Train Acc: 0.6613
# Val Loss: 1.3009, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [163/1500]
# Train Loss: 0.9298, Train Acc: 0.6567
# Val Loss: 1.3169, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [164/1500]
# Train Loss: 0.9177, Train Acc: 0.6546
# Val Loss: 1.3336, Val Acc: 0.5201
# --------------------------------------------------
# Epoch [165/1500]
# Train Loss: 0.9077, Train Acc: 0.6663
# Val Loss: 1.3279, Val Acc: 0.4986
# --------------------------------------------------
# Epoch [166/1500]
# Train Loss: 0.9077, Train Acc: 0.6699
# Val Loss: 1.3508, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [167/1500]
# Train Loss: 0.9088, Train Acc: 0.6651
# Val Loss: 1.3279, Val Acc: 0.5201
# --------------------------------------------------
# Epoch [168/1500]
# Train Loss: 0.9125, Train Acc: 0.6709
# Val Loss: 1.3309, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [169/1500]
# Train Loss: 0.9284, Train Acc: 0.6541
# Val Loss: 1.3270, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [170/1500]
# Train Loss: 0.8794, Train Acc: 0.6721
# Val Loss: 1.3152, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [171/1500]
# Train Loss: 0.8919, Train Acc: 0.6668
# Val Loss: 1.3091, Val Acc: 0.5154
# --------------------------------------------------
# Epoch [172/1500]
# Train Loss: 0.8784, Train Acc: 0.6666
# Val Loss: 1.3293, Val Acc: 0.5051
# --------------------------------------------------
# Epoch [173/1500]
# Train Loss: 0.8915, Train Acc: 0.6723
# Val Loss: 1.3030, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [174/1500]
# Train Loss: 0.8790, Train Acc: 0.6750
# Val Loss: 1.3342, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [175/1500]
# Train Loss: 0.8835, Train Acc: 0.6769
# Val Loss: 1.3134, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [176/1500]
# Train Loss: 0.8689, Train Acc: 0.6779
# Val Loss: 1.3614, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [177/1500]
# Train Loss: 0.8608, Train Acc: 0.6834
# Val Loss: 1.3347, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [178/1500]
# Train Loss: 0.8973, Train Acc: 0.6704
# Val Loss: 1.3286, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [179/1500]
# Train Loss: 0.8734, Train Acc: 0.6843
# Val Loss: 1.3314, Val Acc: 0.5070
# --------------------------------------------------
# Epoch [180/1500]
# Train Loss: 0.8867, Train Acc: 0.6697
# Val Loss: 1.3252, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [181/1500]
# Train Loss: 0.8643, Train Acc: 0.6812
# Val Loss: 1.3193, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [182/1500]
# Train Loss: 0.8495, Train Acc: 0.6863
# Val Loss: 1.3295, Val Acc: 0.5014
# --------------------------------------------------
# Epoch [183/1500]
# Train Loss: 0.8675, Train Acc: 0.6800
# Val Loss: 1.3241, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [184/1500]
# Train Loss: 0.8328, Train Acc: 0.6815
# Val Loss: 1.3434, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [185/1500]
# Train Loss: 0.8677, Train Acc: 0.6747
# Val Loss: 1.3446, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [186/1500]
# Train Loss: 0.8398, Train Acc: 0.6858
# Val Loss: 1.3416, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [187/1500]
# Train Loss: 0.8513, Train Acc: 0.6817
# Val Loss: 1.3321, Val Acc: 0.5117
# --------------------------------------------------
# Epoch [188/1500]
# Train Loss: 0.8627, Train Acc: 0.6904
# Val Loss: 1.3715, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [189/1500]
# Train Loss: 0.8301, Train Acc: 0.6964
# Val Loss: 1.3290, Val Acc: 0.5051
# --------------------------------------------------
# Epoch [190/1500]
# Train Loss: 0.8395, Train Acc: 0.6865
# Val Loss: 1.3600, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [191/1500]
# Train Loss: 0.8357, Train Acc: 0.6916
# Val Loss: 1.3250, Val Acc: 0.5117
# --------------------------------------------------
# Epoch [192/1500]
# Train Loss: 0.8518, Train Acc: 0.6916
# Val Loss: 1.3536, Val Acc: 0.5098
# --------------------------------------------------
# Epoch [193/1500]
# Train Loss: 0.8215, Train Acc: 0.7000
# Val Loss: 1.3362, Val Acc: 0.5051
# --------------------------------------------------
# Epoch [194/1500]
# Train Loss: 0.8290, Train Acc: 0.7009
# Val Loss: 1.3360, Val Acc: 0.5210
# --------------------------------------------------
# Epoch [195/1500]
# Train Loss: 0.8233, Train Acc: 0.6932
# Val Loss: 1.3693, Val Acc: 0.4949
# --------------------------------------------------
# Epoch [196/1500]
# Train Loss: 0.8272, Train Acc: 0.7014
# Val Loss: 1.3282, Val Acc: 0.5238
# --------------------------------------------------
# Epoch [197/1500]
# Train Loss: 0.8001, Train Acc: 0.7004
# Val Loss: 1.3459, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [198/1500]
# Train Loss: 0.8074, Train Acc: 0.6978
# Val Loss: 1.3427, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [199/1500]
# Train Loss: 0.8258, Train Acc: 0.6925
# Val Loss: 1.3567, Val Acc: 0.5033
# --------------------------------------------------
# Epoch [200/1500]
# Train Loss: 0.7975, Train Acc: 0.7045
# Val Loss: 1.3329, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [201/1500]
# Train Loss: 0.7986, Train Acc: 0.7007
# Val Loss: 1.3409, Val Acc: 0.5210
# --------------------------------------------------
# Epoch [202/1500]
# Train Loss: 0.7905, Train Acc: 0.7064
# Val Loss: 1.3578, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [203/1500]
# Train Loss: 0.8330, Train Acc: 0.6932
# Val Loss: 1.3359, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [204/1500]
# Train Loss: 0.7862, Train Acc: 0.6988
# Val Loss: 1.3399, Val Acc: 0.5219
# --------------------------------------------------
# Epoch [205/1500]
# Train Loss: 0.7707, Train Acc: 0.7038
# Val Loss: 1.3559, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [206/1500]
# Train Loss: 0.8042, Train Acc: 0.6985
# Val Loss: 1.3664, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [207/1500]
# Train Loss: 0.8005, Train Acc: 0.7064
# Val Loss: 1.3702, Val Acc: 0.5266
# --------------------------------------------------
# Epoch [208/1500]
# Train Loss: 0.7901, Train Acc: 0.7076
# Val Loss: 1.3218, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [209/1500]
# Train Loss: 0.7868, Train Acc: 0.7124
# Val Loss: 1.3719, Val Acc: 0.5257
# --------------------------------------------------
# Epoch [210/1500]
# Train Loss: 0.7781, Train Acc: 0.7115
# Val Loss: 1.3595, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [211/1500]
# Train Loss: 0.8150, Train Acc: 0.6985
# Val Loss: 1.3385, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [212/1500]
# Train Loss: 0.7878, Train Acc: 0.7036
# Val Loss: 1.3526, Val Acc: 0.5378
# --------------------------------------------------
# Epoch [213/1500]
# Train Loss: 0.7866, Train Acc: 0.7081
# Val Loss: 1.3621, Val Acc: 0.5117
# --------------------------------------------------
# Epoch [214/1500]
# Train Loss: 0.7777, Train Acc: 0.7151
# Val Loss: 1.3934, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [215/1500]
# Train Loss: 0.7608, Train Acc: 0.7144
# Val Loss: 1.3888, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [216/1500]
# Train Loss: 0.7400, Train Acc: 0.7331
# Val Loss: 1.3865, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [217/1500]
# Train Loss: 0.7521, Train Acc: 0.7158
# Val Loss: 1.3657, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [218/1500]
# Train Loss: 0.7552, Train Acc: 0.7225
# Val Loss: 1.3839, Val Acc: 0.5098
# --------------------------------------------------
# Epoch [219/1500]
# Train Loss: 0.7842, Train Acc: 0.7096
# Val Loss: 1.3574, Val Acc: 0.5051
# --------------------------------------------------
# Epoch [220/1500]
# Train Loss: 0.7569, Train Acc: 0.7141
# Val Loss: 1.3538, Val Acc: 0.5219
# --------------------------------------------------
# Epoch [221/1500]
# Train Loss: 0.7735, Train Acc: 0.7158
# Val Loss: 1.4700, Val Acc: 0.4921
# --------------------------------------------------
# Epoch [222/1500]
# Train Loss: 0.7510, Train Acc: 0.7237
# Val Loss: 1.3656, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [223/1500]
# Train Loss: 0.7465, Train Acc: 0.7237
# Val Loss: 1.3783, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [224/1500]
# Train Loss: 0.7702, Train Acc: 0.7146
# Val Loss: 1.3392, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [225/1500]
# Train Loss: 0.7631, Train Acc: 0.7213
# Val Loss: 1.3731, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [226/1500]
# Train Loss: 0.7380, Train Acc: 0.7316
# Val Loss: 1.3492, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [227/1500]
# Train Loss: 0.7330, Train Acc: 0.7297
# Val Loss: 1.3928, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [228/1500]
# Train Loss: 0.7257, Train Acc: 0.7321
# Val Loss: 1.3814, Val Acc: 0.5098
# --------------------------------------------------
# Epoch [229/1500]
# Train Loss: 0.7401, Train Acc: 0.7288
# Val Loss: 1.3735, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [230/1500]
# Train Loss: 0.7538, Train Acc: 0.7254
# Val Loss: 1.3686, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [231/1500]
# Train Loss: 0.7502, Train Acc: 0.7328
# Val Loss: 1.3940, Val Acc: 0.5154
# --------------------------------------------------
# Epoch [232/1500]
# Train Loss: 0.7441, Train Acc: 0.7264
# Val Loss: 1.3478, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [233/1500]
# Train Loss: 0.7219, Train Acc: 0.7336
# Val Loss: 1.3708, Val Acc: 0.5285
# --------------------------------------------------
# Epoch [234/1500]
# Train Loss: 0.7006, Train Acc: 0.7468
# Val Loss: 1.4280, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [235/1500]
# Train Loss: 0.7046, Train Acc: 0.7424
# Val Loss: 1.3773, Val Acc: 0.5117
# --------------------------------------------------
# Epoch [236/1500]
# Train Loss: 0.7260, Train Acc: 0.7328
# Val Loss: 1.3773, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [237/1500]
# Train Loss: 0.6955, Train Acc: 0.7460
# Val Loss: 1.4019, Val Acc: 0.5070
# --------------------------------------------------
# Epoch [238/1500]
# Train Loss: 0.7205, Train Acc: 0.7357
# Val Loss: 1.4087, Val Acc: 0.5210
# --------------------------------------------------
# Epoch [239/1500]
# Train Loss: 0.7327, Train Acc: 0.7300
# Val Loss: 1.3551, Val Acc: 0.5219
# --------------------------------------------------
# Epoch [240/1500]
# Train Loss: 0.7050, Train Acc: 0.7424
# Val Loss: 1.4096, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [241/1500]
# Train Loss: 0.6849, Train Acc: 0.7434
# Val Loss: 1.3682, Val Acc: 0.5275
# --------------------------------------------------
# Epoch [242/1500]
# Train Loss: 0.6998, Train Acc: 0.7420
# Val Loss: 1.3690, Val Acc: 0.5238
# --------------------------------------------------
# Epoch [243/1500]
# Train Loss: 0.7161, Train Acc: 0.7424
# Val Loss: 1.3783, Val Acc: 0.5229
# --------------------------------------------------
# Epoch [244/1500]
# Train Loss: 0.7057, Train Acc: 0.7412
# Val Loss: 1.3904, Val Acc: 0.5341
# --------------------------------------------------
# Epoch [245/1500]
# Train Loss: 0.6953, Train Acc: 0.7432
# Val Loss: 1.3822, Val Acc: 0.5238
# --------------------------------------------------
# Epoch [246/1500]
# Train Loss: 0.6939, Train Acc: 0.7410
# Val Loss: 1.3964, Val Acc: 0.5331
# --------------------------------------------------
# Epoch [247/1500]
# Train Loss: 0.6790, Train Acc: 0.7492
# Val Loss: 1.3969, Val Acc: 0.5005
# --------------------------------------------------
# Epoch [248/1500]
# Train Loss: 0.6805, Train Acc: 0.7547
# Val Loss: 1.4010, Val Acc: 0.5266
# --------------------------------------------------
# Epoch [249/1500]
# Train Loss: 0.7110, Train Acc: 0.7393
# Val Loss: 1.3907, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [250/1500]
# Train Loss: 0.6893, Train Acc: 0.7532
# Val Loss: 1.4204, Val Acc: 0.5229
# --------------------------------------------------
# Epoch [251/1500]
# Train Loss: 0.6829, Train Acc: 0.7501
# Val Loss: 1.4020, Val Acc: 0.5397
# --------------------------------------------------
# Epoch [252/1500]
# Train Loss: 0.6926, Train Acc: 0.7465
# Val Loss: 1.4283, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [253/1500]
# Train Loss: 0.6819, Train Acc: 0.7439
# Val Loss: 1.3966, Val Acc: 0.5154
# --------------------------------------------------
# Epoch [254/1500]
# Train Loss: 0.6954, Train Acc: 0.7544
# Val Loss: 1.4225, Val Acc: 0.5033
# --------------------------------------------------
# Epoch [255/1500]
# Train Loss: 0.6885, Train Acc: 0.7496
# Val Loss: 1.3951, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [256/1500]
# Train Loss: 0.7004, Train Acc: 0.7396
# Val Loss: 1.4350, Val Acc: 0.5201
# --------------------------------------------------
# Epoch [257/1500]
# Train Loss: 0.6655, Train Acc: 0.7554
# Val Loss: 1.4099, Val Acc: 0.5201
# --------------------------------------------------
# Epoch [258/1500]
# Train Loss: 0.6658, Train Acc: 0.7494
# Val Loss: 1.4157, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [259/1500]
# Train Loss: 0.6621, Train Acc: 0.7525
# Val Loss: 1.4449, Val Acc: 0.5014
# --------------------------------------------------
# Epoch [260/1500]
# Train Loss: 0.6701, Train Acc: 0.7624
# Val Loss: 1.4642, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [261/1500]
# Train Loss: 0.6802, Train Acc: 0.7592
# Val Loss: 1.3989, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [262/1500]
# Train Loss: 0.6640, Train Acc: 0.7600
# Val Loss: 1.4320, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [263/1500]
# Train Loss: 0.6371, Train Acc: 0.7684
# Val Loss: 1.4283, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [264/1500]
# Train Loss: 0.6593, Train Acc: 0.7535
# Val Loss: 1.4275, Val Acc: 0.5238
# --------------------------------------------------
# Epoch [265/1500]
# Train Loss: 0.6552, Train Acc: 0.7554
# Val Loss: 1.4036, Val Acc: 0.5247
# --------------------------------------------------
# Epoch [266/1500]
# Train Loss: 0.6514, Train Acc: 0.7564
# Val Loss: 1.3875, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [267/1500]
# Train Loss: 0.6546, Train Acc: 0.7674
# Val Loss: 1.4141, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [268/1500]
# Train Loss: 0.6398, Train Acc: 0.7609
# Val Loss: 1.4114, Val Acc: 0.5229
# --------------------------------------------------
# Epoch [269/1500]
# Train Loss: 0.6528, Train Acc: 0.7549
# Val Loss: 1.4748, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [270/1500]
# Train Loss: 0.6291, Train Acc: 0.7650
# Val Loss: 1.4594, Val Acc: 0.5014
# --------------------------------------------------
# Epoch [271/1500]
# Train Loss: 0.6421, Train Acc: 0.7588
# Val Loss: 1.4352, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [272/1500]
# Train Loss: 0.6357, Train Acc: 0.7698
# Val Loss: 1.4276, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [273/1500]
# Train Loss: 0.6685, Train Acc: 0.7590
# Val Loss: 1.3911, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [274/1500]
# Train Loss: 0.6542, Train Acc: 0.7588
# Val Loss: 1.4364, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [275/1500]
# Train Loss: 0.6635, Train Acc: 0.7564
# Val Loss: 1.4328, Val Acc: 0.5247
# --------------------------------------------------
# Epoch [276/1500]
# Train Loss: 0.6534, Train Acc: 0.7619
# Val Loss: 1.4456, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [277/1500]
# Train Loss: 0.6350, Train Acc: 0.7705
# Val Loss: 1.4741, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [278/1500]
# Train Loss: 0.6441, Train Acc: 0.7681
# Val Loss: 1.4297, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [279/1500]
# Train Loss: 0.6657, Train Acc: 0.7674
# Val Loss: 1.4711, Val Acc: 0.5051
# --------------------------------------------------
# Epoch [280/1500]
# Train Loss: 0.6387, Train Acc: 0.7705
# Val Loss: 1.4768, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [281/1500]
# Train Loss: 0.6393, Train Acc: 0.7616
# Val Loss: 1.4278, Val Acc: 0.5275
# --------------------------------------------------
# Epoch [282/1500]
# Train Loss: 0.6076, Train Acc: 0.7808
# Val Loss: 1.4629, Val Acc: 0.5210
# --------------------------------------------------
# Epoch [283/1500]
# Train Loss: 0.6296, Train Acc: 0.7688
# Val Loss: 1.4452, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [284/1500]
# Train Loss: 0.6086, Train Acc: 0.7691
# Val Loss: 1.4366, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [285/1500]
# Train Loss: 0.6192, Train Acc: 0.7801
# Val Loss: 1.5215, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [286/1500]
# Train Loss: 0.6089, Train Acc: 0.7770
# Val Loss: 1.4217, Val Acc: 0.5219
# --------------------------------------------------
# Epoch [287/1500]
# Train Loss: 0.6315, Train Acc: 0.7732
# Val Loss: 1.4569, Val Acc: 0.5247
# --------------------------------------------------
# Epoch [288/1500]
# Train Loss: 0.6240, Train Acc: 0.7741
# Val Loss: 1.4527, Val Acc: 0.5219
# --------------------------------------------------
# Epoch [289/1500]
# Train Loss: 0.6213, Train Acc: 0.7760
# Val Loss: 1.4491, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [290/1500]
# Train Loss: 0.6120, Train Acc: 0.7744
# Val Loss: 1.4871, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [291/1500]
# Train Loss: 0.5935, Train Acc: 0.7921
# Val Loss: 1.4634, Val Acc: 0.5070
# --------------------------------------------------
# Epoch [292/1500]
# Train Loss: 0.6016, Train Acc: 0.7808
# Val Loss: 1.4662, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [293/1500]
# Train Loss: 0.6220, Train Acc: 0.7674
# Val Loss: 1.4888, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [294/1500]
# Train Loss: 0.5853, Train Acc: 0.7830
# Val Loss: 1.4551, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [295/1500]
# Train Loss: 0.6218, Train Acc: 0.7746
# Val Loss: 1.4641, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [296/1500]
# Train Loss: 0.5897, Train Acc: 0.7832
# Val Loss: 1.4852, Val Acc: 0.5154
# --------------------------------------------------
# Epoch [297/1500]
# Train Loss: 0.6211, Train Acc: 0.7806
# Val Loss: 1.4620, Val Acc: 0.5229
# --------------------------------------------------
# Epoch [298/1500]
# Train Loss: 0.5839, Train Acc: 0.7878
# Val Loss: 1.4979, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [299/1500]
# Train Loss: 0.6138, Train Acc: 0.7856
# Val Loss: 1.4696, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [300/1500]
# Train Loss: 0.5938, Train Acc: 0.7835
# Val Loss: 1.4717, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [301/1500]
# Train Loss: 0.6134, Train Acc: 0.7787
# Val Loss: 1.4928, Val Acc: 0.5117
# --------------------------------------------------
# Epoch [302/1500]
# Train Loss: 0.5935, Train Acc: 0.7816
# Val Loss: 1.4491, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [303/1500]
# Train Loss: 0.5881, Train Acc: 0.7801
# Val Loss: 1.4450, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [304/1500]
# Train Loss: 0.5799, Train Acc: 0.7856
# Val Loss: 1.4652, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [305/1500]
# Train Loss: 0.5549, Train Acc: 0.7948
# Val Loss: 1.5068, Val Acc: 0.5210
# --------------------------------------------------
# Epoch [306/1500]
# Train Loss: 0.5960, Train Acc: 0.7883
# Val Loss: 1.4931, Val Acc: 0.4967
# --------------------------------------------------
# Epoch [307/1500]
# Train Loss: 0.6123, Train Acc: 0.7873
# Val Loss: 1.4519, Val Acc: 0.5201
# --------------------------------------------------
# Epoch [308/1500]
# Train Loss: 0.5771, Train Acc: 0.7837
# Val Loss: 1.4609, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [309/1500]
# Train Loss: 0.5864, Train Acc: 0.7830
# Val Loss: 1.4894, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [310/1500]
# Train Loss: 0.5601, Train Acc: 0.7962
# Val Loss: 1.5103, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [311/1500]
# Train Loss: 0.5910, Train Acc: 0.7849
# Val Loss: 1.4868, Val Acc: 0.5098
# --------------------------------------------------
# Epoch [312/1500]
# Train Loss: 0.5879, Train Acc: 0.7852
# Val Loss: 1.4783, Val Acc: 0.5051
# --------------------------------------------------
# Epoch [313/1500]
# Train Loss: 0.6036, Train Acc: 0.7813
# Val Loss: 1.4563, Val Acc: 0.5266
# --------------------------------------------------
# Epoch [314/1500]
# Train Loss: 0.5742, Train Acc: 0.7856
# Val Loss: 1.4480, Val Acc: 0.5266
# --------------------------------------------------
# Epoch [315/1500]
# Train Loss: 0.5658, Train Acc: 0.8032
# Val Loss: 1.4925, Val Acc: 0.5229
# --------------------------------------------------
# Epoch [316/1500]
# Train Loss: 0.5764, Train Acc: 0.7924
# Val Loss: 1.4974, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [317/1500]
# Train Loss: 0.5574, Train Acc: 0.7936
# Val Loss: 1.4910, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [318/1500]
# Train Loss: 0.5705, Train Acc: 0.7940
# Val Loss: 1.5404, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [319/1500]
# Train Loss: 0.5785, Train Acc: 0.7885
# Val Loss: 1.4561, Val Acc: 0.5294
# --------------------------------------------------
# Epoch [320/1500]
# Train Loss: 0.5746, Train Acc: 0.7914
# Val Loss: 1.4850, Val Acc: 0.5257
# --------------------------------------------------
# Epoch [321/1500]
# Train Loss: 0.5646, Train Acc: 0.7979
# Val Loss: 1.4943, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [322/1500]
# Train Loss: 0.5727, Train Acc: 0.7933
# Val Loss: 1.5129, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [323/1500]
# Train Loss: 0.5553, Train Acc: 0.8039
# Val Loss: 1.4867, Val Acc: 0.5275
# --------------------------------------------------
# Epoch [324/1500]
# Train Loss: 0.5606, Train Acc: 0.7984
# Val Loss: 1.5089, Val Acc: 0.5257
# --------------------------------------------------
# Epoch [325/1500]
# Train Loss: 0.5713, Train Acc: 0.7938
# Val Loss: 1.5014, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [326/1500]
# Train Loss: 0.5456, Train Acc: 0.8010
# Val Loss: 1.5207, Val Acc: 0.5219
# --------------------------------------------------
# Epoch [327/1500]
# Train Loss: 0.5692, Train Acc: 0.8000
# Val Loss: 1.5247, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [328/1500]
# Train Loss: 0.5447, Train Acc: 0.7993
# Val Loss: 1.5175, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [329/1500]
# Train Loss: 0.5601, Train Acc: 0.7984
# Val Loss: 1.5013, Val Acc: 0.5219
# --------------------------------------------------
# Epoch [330/1500]
# Train Loss: 0.5619, Train Acc: 0.7950
# Val Loss: 1.5148, Val Acc: 0.5033
# --------------------------------------------------
# Epoch [331/1500]
# Train Loss: 0.5720, Train Acc: 0.7960
# Val Loss: 1.5281, Val Acc: 0.5098
# --------------------------------------------------
# Epoch [332/1500]
# Train Loss: 0.5663, Train Acc: 0.7979
# Val Loss: 1.5733, Val Acc: 0.5154
# --------------------------------------------------
# Epoch [333/1500]
# Train Loss: 0.5425, Train Acc: 0.8012
# Val Loss: 1.5591, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [334/1500]
# Train Loss: 0.5447, Train Acc: 0.8039
# Val Loss: 1.5281, Val Acc: 0.5229
# --------------------------------------------------
# Epoch [335/1500]
# Train Loss: 0.5659, Train Acc: 0.7960
# Val Loss: 1.5319, Val Acc: 0.5154
# --------------------------------------------------
# Epoch [336/1500]
# Train Loss: 0.5457, Train Acc: 0.8041
# Val Loss: 1.5447, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [337/1500]
# Train Loss: 0.5515, Train Acc: 0.8012
# Val Loss: 1.5615, Val Acc: 0.5154
# --------------------------------------------------
# Epoch [338/1500]
# Train Loss: 0.5279, Train Acc: 0.7979
# Val Loss: 1.5331, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [339/1500]
# Train Loss: 0.5595, Train Acc: 0.7998
# Val Loss: 1.5093, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [340/1500]
# Train Loss: 0.5704, Train Acc: 0.8005
# Val Loss: 1.5294, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [341/1500]
# Train Loss: 0.5281, Train Acc: 0.8135
# Val Loss: 1.5422, Val Acc: 0.5219
# --------------------------------------------------
# Epoch [342/1500]
# Train Loss: 0.5138, Train Acc: 0.8060
# Val Loss: 1.5840, Val Acc: 0.5201
# --------------------------------------------------
# Epoch [343/1500]
# Train Loss: 0.5450, Train Acc: 0.8024
# Val Loss: 1.4968, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [344/1500]
# Train Loss: 0.5767, Train Acc: 0.7969
# ...
# --------------------------------------------------
# Epoch [1388/1500]
# Train Loss: 0.2199, Train Acc: 0.9237
# Val Loss: 2.0365, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [1389/1500]
# Train Loss: 0.2126, Train Acc: 0.9258
# Val Loss: 2.0331, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [1390/1500]
# Train Loss: 0.2136, Train Acc: 0.9277
# Val Loss: 2.0249, Val Acc: 0.5247
# --------------------------------------------------
# Epoch [1391/1500]
# Train Loss: 0.2003, Train Acc: 0.9373
# Val Loss: 2.0297, Val Acc: 0.5033
# --------------------------------------------------
# Epoch [1392/1500]
# Train Loss: 0.2193, Train Acc: 0.9265
# Val Loss: 2.0507, Val Acc: 0.5257
# --------------------------------------------------
# Epoch [1393/1500]
# Train Loss: 0.1983, Train Acc: 0.9270
# Val Loss: 2.0654, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [1394/1500]
# Train Loss: 0.2034, Train Acc: 0.9287
# Val Loss: 2.0529, Val Acc: 0.5219
# --------------------------------------------------
# Epoch [1395/1500]
# Train Loss: 0.2300, Train Acc: 0.9220
# Val Loss: 2.0278, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [1396/1500]
# Train Loss: 0.2147, Train Acc: 0.9289
# Val Loss: 2.0151, Val Acc: 0.5219
# --------------------------------------------------
# Epoch [1397/1500]
# Train Loss: 0.2279, Train Acc: 0.9251
# Val Loss: 1.9925, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [1398/1500]
# Train Loss: 0.2083, Train Acc: 0.9313
# Val Loss: 1.9664, Val Acc: 0.5275
# --------------------------------------------------
# Epoch [1399/1500]
# Train Loss: 0.2121, Train Acc: 0.9294
# Val Loss: 2.0045, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [1400/1500]
# Train Loss: 0.1829, Train Acc: 0.9357
# Val Loss: 2.0897, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [1401/1500]
# Train Loss: 0.2031, Train Acc: 0.9294
# Val Loss: 2.0885, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [1402/1500]
# Train Loss: 0.2106, Train Acc: 0.9265
# Val Loss: 2.1019, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [1403/1500]
# Train Loss: 0.2300, Train Acc: 0.9239
# Val Loss: 2.0810, Val Acc: 0.5051
# --------------------------------------------------
# Epoch [1404/1500]
# Train Loss: 0.2079, Train Acc: 0.9261
# Val Loss: 1.9950, Val Acc: 0.5005
# --------------------------------------------------
# Epoch [1405/1500]
# Train Loss: 0.2170, Train Acc: 0.9253
# Val Loss: 2.0173, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [1406/1500]
# Train Loss: 0.2086, Train Acc: 0.9335
# Val Loss: 2.0402, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [1407/1500]
# Train Loss: 0.2239, Train Acc: 0.9220
# Val Loss: 2.0527, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [1408/1500]
# Train Loss: 0.2256, Train Acc: 0.9220
# Val Loss: 2.0593, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [1409/1500]
# Train Loss: 0.2361, Train Acc: 0.9213
# Val Loss: 2.0584, Val Acc: 0.4995
# --------------------------------------------------
# Epoch [1410/1500]
# Train Loss: 0.2172, Train Acc: 0.9280
# Val Loss: 2.0155, Val Acc: 0.4986
# --------------------------------------------------
# Epoch [1411/1500]
# Train Loss: 0.2204, Train Acc: 0.9220
# Val Loss: 1.9944, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [1412/1500]
# Train Loss: 0.2115, Train Acc: 0.9265
# Val Loss: 2.0236, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [1413/1500]
# Train Loss: 0.2138, Train Acc: 0.9268
# Val Loss: 2.0635, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [1414/1500]
# Train Loss: 0.2200, Train Acc: 0.9311
# Val Loss: 2.1051, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [1415/1500]
# Train Loss: 0.2171, Train Acc: 0.9208
# Val Loss: 2.0355, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [1416/1500]
# Train Loss: 0.2145, Train Acc: 0.9289
# Val Loss: 2.0842, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [1417/1500]
# Train Loss: 0.1956, Train Acc: 0.9316
# Val Loss: 2.0043, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [1418/1500]
# Train Loss: 0.1948, Train Acc: 0.9323
# Val Loss: 2.1067, Val Acc: 0.4995
# --------------------------------------------------
# Epoch [1419/1500]
# Train Loss: 0.2244, Train Acc: 0.9294
# Val Loss: 2.0813, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [1420/1500]
# Train Loss: 0.2262, Train Acc: 0.9196
# Val Loss: 1.9868, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [1421/1500]
# Train Loss: 0.2085, Train Acc: 0.9268
# Val Loss: 2.0253, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [1422/1500]
# Train Loss: 0.2177, Train Acc: 0.9263
# Val Loss: 2.0488, Val Acc: 0.5098
# --------------------------------------------------
# Epoch [1423/1500]
# Train Loss: 0.2124, Train Acc: 0.9239
# Val Loss: 1.9980, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [1424/1500]
# Train Loss: 0.2221, Train Acc: 0.9311
# Val Loss: 1.9990, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [1425/1500]
# Train Loss: 0.1903, Train Acc: 0.9316
# Val Loss: 2.0076, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [1426/1500]
# Train Loss: 0.2117, Train Acc: 0.9237
# Val Loss: 2.0268, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [1427/1500]
# Train Loss: 0.1988, Train Acc: 0.9309
# Val Loss: 2.0447, Val Acc: 0.5191
# --------------------------------------------------
# Epoch [1428/1500]
# Train Loss: 0.2080, Train Acc: 0.9256
# Val Loss: 2.0408, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [1429/1500]
# Train Loss: 0.2088, Train Acc: 0.9292
# Val Loss: 2.0305, Val Acc: 0.5005
# --------------------------------------------------
# Epoch [1430/1500]
# Train Loss: 0.1920, Train Acc: 0.9364
# Val Loss: 2.0829, Val Acc: 0.4986
# --------------------------------------------------
# Epoch [1431/1500]
# Train Loss: 0.2132, Train Acc: 0.9256
# Val Loss: 2.0497, Val Acc: 0.5070
# --------------------------------------------------
# Epoch [1432/1500]
# Train Loss: 0.1982, Train Acc: 0.9342
# Val Loss: 2.0247, Val Acc: 0.5098
# --------------------------------------------------
# Epoch [1433/1500]
# Train Loss: 0.2201, Train Acc: 0.9244
# Val Loss: 2.0339, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [1434/1500]
# Train Loss: 0.2215, Train Acc: 0.9304
# Val Loss: 2.0439, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [1435/1500]
# Train Loss: 0.1952, Train Acc: 0.9345
# Val Loss: 2.0431, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [1436/1500]
# Train Loss: 0.1921, Train Acc: 0.9335
# Val Loss: 2.1176, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [1437/1500]
# Train Loss: 0.1949, Train Acc: 0.9299
# Val Loss: 2.1548, Val Acc: 0.4977
# --------------------------------------------------
# Epoch [1438/1500]
# Train Loss: 0.2018, Train Acc: 0.9328
# Val Loss: 2.1823, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [1439/1500]
# Train Loss: 0.2027, Train Acc: 0.9285
# Val Loss: 2.1002, Val Acc: 0.5033
# --------------------------------------------------
# Epoch [1440/1500]
# Train Loss: 0.1883, Train Acc: 0.9410
# Val Loss: 2.0674, Val Acc: 0.5098
# --------------------------------------------------
# Epoch [1441/1500]
# Train Loss: 0.2276, Train Acc: 0.9253
# Val Loss: 2.0853, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [1442/1500]
# Train Loss: 0.2143, Train Acc: 0.9299
# Val Loss: 2.0405, Val Acc: 0.5098
# --------------------------------------------------
# Epoch [1443/1500]
# Train Loss: 0.1959, Train Acc: 0.9347
# Val Loss: 2.0171, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [1444/1500]
# Train Loss: 0.1998, Train Acc: 0.9313
# Val Loss: 2.0387, Val Acc: 0.5117
# --------------------------------------------------
# Epoch [1445/1500]
# Train Loss: 0.1924, Train Acc: 0.9361
# Val Loss: 2.0883, Val Acc: 0.5070
# --------------------------------------------------
# Epoch [1446/1500]
# Train Loss: 0.2012, Train Acc: 0.9357
# Val Loss: 2.0907, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [1447/1500]
# Train Loss: 0.2051, Train Acc: 0.9277
# Val Loss: 2.0861, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [1448/1500]
# Train Loss: 0.2128, Train Acc: 0.9273
# Val Loss: 2.0602, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [1449/1500]
# Train Loss: 0.2031, Train Acc: 0.9352
# Val Loss: 2.0726, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [1450/1500]
# Train Loss: 0.1831, Train Acc: 0.9373
# Val Loss: 2.0772, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [1451/1500]
# Train Loss: 0.2208, Train Acc: 0.9246
# Val Loss: 2.0712, Val Acc: 0.5117
# --------------------------------------------------
# Epoch [1452/1500]
# Train Loss: 0.2058, Train Acc: 0.9318
# Val Loss: 2.0478, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [1453/1500]
# Train Loss: 0.1982, Train Acc: 0.9313
# Val Loss: 2.1039, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [1454/1500]
# Train Loss: 0.2181, Train Acc: 0.9299
# Val Loss: 2.1013, Val Acc: 0.5145
# --------------------------------------------------
# Epoch [1455/1500]
# Train Loss: 0.2113, Train Acc: 0.9265
# Val Loss: 2.0821, Val Acc: 0.5182
# --------------------------------------------------
# Epoch [1456/1500]
# Train Loss: 0.1950, Train Acc: 0.9306
# Val Loss: 2.0851, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [1457/1500]
# Train Loss: 0.2122, Train Acc: 0.9263
# Val Loss: 2.0933, Val Acc: 0.5210
# --------------------------------------------------
# Epoch [1458/1500]
# Train Loss: 0.1861, Train Acc: 0.9318
# Val Loss: 2.0808, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [1459/1500]
# Train Loss: 0.2073, Train Acc: 0.9354
# Val Loss: 2.1213, Val Acc: 0.5154
# --------------------------------------------------
# Epoch [1460/1500]
# Train Loss: 0.2146, Train Acc: 0.9304
# Val Loss: 2.0757, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [1461/1500]
# Train Loss: 0.1938, Train Acc: 0.9361
# Val Loss: 2.0570, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [1462/1500]
# Train Loss: 0.2052, Train Acc: 0.9285
# Val Loss: 2.0704, Val Acc: 0.5154
# --------------------------------------------------
# Epoch [1463/1500]
# Train Loss: 0.2269, Train Acc: 0.9220
# Val Loss: 2.0842, Val Acc: 0.5070
# --------------------------------------------------
# Epoch [1464/1500]
# Train Loss: 0.2045, Train Acc: 0.9261
# Val Loss: 2.0912, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [1465/1500]
# Train Loss: 0.1946, Train Acc: 0.9340
# Val Loss: 2.0880, Val Acc: 0.5229
# --------------------------------------------------
# Epoch [1466/1500]
# Train Loss: 0.2247, Train Acc: 0.9241
# Val Loss: 2.0786, Val Acc: 0.5014
# --------------------------------------------------
# Epoch [1467/1500]
# Train Loss: 0.1995, Train Acc: 0.9335
# Val Loss: 2.1025, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [1468/1500]
# Train Loss: 0.1930, Train Acc: 0.9340
# Val Loss: 2.1199, Val Acc: 0.5201
# --------------------------------------------------
# Epoch [1469/1500]
# Train Loss: 0.2259, Train Acc: 0.9227
# Val Loss: 2.0357, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [1470/1500]
# Train Loss: 0.1975, Train Acc: 0.9313
# Val Loss: 2.0679, Val Acc: 0.5135
# --------------------------------------------------
# Epoch [1471/1500]
# Train Loss: 0.2065, Train Acc: 0.9270
# Val Loss: 2.0682, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [1472/1500]
# Train Loss: 0.1955, Train Acc: 0.9333
# Val Loss: 2.1277, Val Acc: 0.5173
# --------------------------------------------------
# Epoch [1473/1500]
# Train Loss: 0.2019, Train Acc: 0.9311
# Val Loss: 2.0714, Val Acc: 0.5005
# --------------------------------------------------
# Epoch [1474/1500]
# Train Loss: 0.2023, Train Acc: 0.9352
# Val Loss: 2.1267, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [1475/1500]
# Train Loss: 0.2031, Train Acc: 0.9337
# Val Loss: 2.0574, Val Acc: 0.5005
# --------------------------------------------------
# Epoch [1476/1500]
# Train Loss: 0.2088, Train Acc: 0.9270
# Val Loss: 2.0742, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [1477/1500]
# Train Loss: 0.2098, Train Acc: 0.9328
# Val Loss: 2.1031, Val Acc: 0.5051
# --------------------------------------------------
# Epoch [1478/1500]
# Train Loss: 0.2064, Train Acc: 0.9301
# Val Loss: 2.0591, Val Acc: 0.5079
# --------------------------------------------------
# Epoch [1479/1500]
# Train Loss: 0.2102, Train Acc: 0.9292
# Val Loss: 2.0450, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [1480/1500]
# Train Loss: 0.2009, Train Acc: 0.9347
# Val Loss: 2.1196, Val Acc: 0.5089
# --------------------------------------------------
# Epoch [1481/1500]
# Train Loss: 0.2177, Train Acc: 0.9282
# Val Loss: 2.0763, Val Acc: 0.4949
# --------------------------------------------------
# Epoch [1482/1500]
# Train Loss: 0.2457, Train Acc: 0.9241
# Val Loss: 2.0238, Val Acc: 0.5023
# --------------------------------------------------
# Epoch [1483/1500]
# Train Loss: 0.2222, Train Acc: 0.9251
# Val Loss: 2.0072, Val Acc: 0.4986
# --------------------------------------------------
# Epoch [1484/1500]
# Train Loss: 0.2015, Train Acc: 0.9287
# Val Loss: 2.0314, Val Acc: 0.5014
# --------------------------------------------------
# Epoch [1485/1500]
# Train Loss: 0.2082, Train Acc: 0.9275
# Val Loss: 2.0506, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [1486/1500]
# Train Loss: 0.1872, Train Acc: 0.9429
# Val Loss: 2.0831, Val Acc: 0.5014
# --------------------------------------------------
# Epoch [1487/1500]
# Train Loss: 0.1981, Train Acc: 0.9306
# Val Loss: 2.1195, Val Acc: 0.5042
# --------------------------------------------------
# Epoch [1488/1500]
# Train Loss: 0.1907, Train Acc: 0.9345
# Val Loss: 2.1536, Val Acc: 0.4930
# --------------------------------------------------
# Epoch [1489/1500]
# Train Loss: 0.1961, Train Acc: 0.9313
# Val Loss: 2.1554, Val Acc: 0.5005
# --------------------------------------------------
# Epoch [1490/1500]
# Train Loss: 0.2223, Train Acc: 0.9268
# Val Loss: 2.1489, Val Acc: 0.5005
# --------------------------------------------------
# Epoch [1491/1500]
# Train Loss: 0.2044, Train Acc: 0.9352
# Val Loss: 2.1557, Val Acc: 0.5126
# --------------------------------------------------
# Epoch [1492/1500]
# Train Loss: 0.2143, Train Acc: 0.9261
# Val Loss: 2.0824, Val Acc: 0.5070
# --------------------------------------------------
# Epoch [1493/1500]
# Train Loss: 0.2153, Train Acc: 0.9249
# Val Loss: 2.0783, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [1494/1500]
# Train Loss: 0.2047, Train Acc: 0.9321
# Val Loss: 2.1181, Val Acc: 0.4958
# --------------------------------------------------
# Epoch [1495/1500]
# Train Loss: 0.2056, Train Acc: 0.9333
# Val Loss: 2.0859, Val Acc: 0.5107
# --------------------------------------------------
# Epoch [1496/1500]
# Train Loss: 0.2161, Train Acc: 0.9208
# Val Loss: 2.1245, Val Acc: 0.5033
# --------------------------------------------------
# Epoch [1497/1500]
# Train Loss: 0.2021, Train Acc: 0.9311
# Val Loss: 2.1271, Val Acc: 0.5061
# --------------------------------------------------
# Epoch [1498/1500]
# Train Loss: 0.1923, Train Acc: 0.9349
# Val Loss: 2.1835, Val Acc: 0.5163
# --------------------------------------------------
# Epoch [1499/1500]
# Train Loss: 0.2074, Train Acc: 0.9323
# Val Loss: 2.1271, Val Acc: 0.5098
# --------------------------------------------------
# Epoch [1500/1500]
# Train Loss: 0.1748, Train Acc: 0.9381
# Val Loss: 2.1739, Val Acc: 0.5005
# --------------------------------------------------

# %%
torch.save(model.state_dict(), "C:/Nini/Capstone/Models/cnn_model_snippets.pth")
