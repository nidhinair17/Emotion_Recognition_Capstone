# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle

# %%
features = pd.read_csv("C:/Nini/Capstone/CSV_Files/ravdess_extracted_features_mel_mfcc_chroma.csv")
features = features.drop(features.columns[0], axis=1)
temp = shuffle(features)
df = np.random.rand(len(temp)) < 0.8
train = temp[df]
test = temp[~df]

# %%
X_train = np.array(train.iloc[:,:-1])
y_train = np.array(train.iloc[:,-1])
X_test = np.array(test.iloc[:,:-1])
y_test = np.array(test.iloc[:,-1])

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
batch_size = 256
train_loader = DataLoader(TensorDataset(X_train,y_train), batch_size=batch_size,shuffle=True)
test_loader = DataLoader(TensorDataset(X_test,y_test), batch_size=batch_size, shuffle=False)

# %%
class CNNModel(nn.Module):
    def __init__(self, input_size, num_classes):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=10)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=8)
        self.bn2 = nn.BatchNorm1d(128)
        self.pool1 = nn.MaxPool1d(kernel_size=4, padding=2)
        self.dropout1 = nn.Dropout(0.5)
        self.conv3 = nn.Conv1d(128, 128, kernel_size=8)
        self.bn3 = nn.BatchNorm1d(128)
        self.pool2 = nn.MaxPool1d(kernel_size=4, padding=2)
        self.dropout2 = nn.Dropout(0.5)
        self.conv4 = nn.Conv1d(128, 64, kernel_size=3, padding=2)
        self.bn4 = nn.BatchNorm1d(64)
        self.fc1 = nn.Linear(640, 256)
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, num_classes)

    # def _compute_flattened_size(self, input_size):
    #     with torch.no_grad():
    #         x = torch.randn(1, 1, input_size)  # Create a dummy input
    #         x = self.conv1(x)
    #         x = F.relu(x)
    #         x = self.conv2(x)
    #         x = F.relu(x)
    #         x = self.pool1(x)
    #         x = self.dropout1(x)
    #         x = self.conv3(x)
    #         x = F.relu(x)
    #         x = self.pool2(x)
    #         x = self.dropout2(x)
    #         x = self.conv4(x)
    #         x = F.relu(x)
    #         x = x.view(1, -1)  # Flatten
    #         self._to_linear = x.shape[1]

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNModel(input_size=X_train.shape[1], num_classes=8).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=1e-4)

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: torch.Size([1152, 1, 153])

# %%
epochs = 1500
for epoch in range(epochs):
    model.train()
    running_loss = 0
    total_loss = 0
    total = 0
    correct = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)
    train_accuracy = correct / total
    avg_train_loss = running_loss / len(train_loader)
        # total_loss += loss.item()
        # correct += (outputs.argmax(dim=1) == y_batch).sum().item()
    model.eval()  # Set model to evaluation mode
    val_correct = 0
    val_total = 0
    val_loss = 0.0

    with torch.no_grad():  # Disable gradient computation for validation
        for val_inputs, val_labels in test_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)

            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()

            _, val_predicted = torch.max(val_outputs, 1)
            val_correct += (val_predicted == val_labels).sum().item()
            val_total += val_labels.size(0)
    
    val_accuracy = val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)
    # accuracy = correct / len(train_loader.dataset)
    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    print("-" * 50)
# Out:
# Epoch [1/1500]
# Train Loss: 2.0308, Train Acc: 0.1884
# Val Loss: 2.0455, Val Acc: 0.2535
# --------------------------------------------------
# Epoch [2/1500]
# Train Loss: 1.9117, Train Acc: 0.2431
# Val Loss: 1.9467, Val Acc: 0.2604
# --------------------------------------------------
# Epoch [3/1500]
# Train Loss: 1.8286, Train Acc: 0.2743
# Val Loss: 1.8586, Val Acc: 0.2812
# --------------------------------------------------
# Epoch [4/1500]
# Train Loss: 1.8028, Train Acc: 0.2821
# Val Loss: 1.7919, Val Acc: 0.2674
# --------------------------------------------------
# Epoch [5/1500]
# Train Loss: 1.7900, Train Acc: 0.2752
# Val Loss: 1.7778, Val Acc: 0.2604
# --------------------------------------------------
# Epoch [6/1500]
# Train Loss: 1.7577, Train Acc: 0.2821
# Val Loss: 1.7485, Val Acc: 0.2986
# --------------------------------------------------
# Epoch [7/1500]
# Train Loss: 1.7361, Train Acc: 0.3047
# Val Loss: 1.7149, Val Acc: 0.2917
# --------------------------------------------------
# Epoch [8/1500]
# Train Loss: 1.7119, Train Acc: 0.3229
# Val Loss: 1.6755, Val Acc: 0.3021
# --------------------------------------------------
# Epoch [9/1500]
# Train Loss: 1.7033, Train Acc: 0.3472
# Val Loss: 1.6511, Val Acc: 0.3333
# --------------------------------------------------
# Epoch [10/1500]
# Train Loss: 1.6729, Train Acc: 0.3307
# Val Loss: 1.6210, Val Acc: 0.3299
# --------------------------------------------------
# Epoch [11/1500]
# Train Loss: 1.6330, Train Acc: 0.3802
# Val Loss: 1.6263, Val Acc: 0.3403
# --------------------------------------------------
# Epoch [12/1500]
# Train Loss: 1.6425, Train Acc: 0.3602
# Val Loss: 1.6450, Val Acc: 0.3403
# --------------------------------------------------
# Epoch [13/1500]
# Train Loss: 1.6185, Train Acc: 0.3655
# Val Loss: 1.5811, Val Acc: 0.3507
# --------------------------------------------------
# Epoch [14/1500]
# Train Loss: 1.5945, Train Acc: 0.3741
# Val Loss: 1.5437, Val Acc: 0.3785
# --------------------------------------------------
# Epoch [15/1500]
# Train Loss: 1.5609, Train Acc: 0.4201
# Val Loss: 1.5867, Val Acc: 0.3368
# --------------------------------------------------
# Epoch [16/1500]
# Train Loss: 1.5434, Train Acc: 0.4175
# Val Loss: 1.5638, Val Acc: 0.3403
# --------------------------------------------------
# Epoch [17/1500]
# Train Loss: 1.5484, Train Acc: 0.4115
# Val Loss: 1.5344, Val Acc: 0.3611
# --------------------------------------------------
# Epoch [18/1500]
# Train Loss: 1.5112, Train Acc: 0.4175
# Val Loss: 1.5251, Val Acc: 0.3715
# --------------------------------------------------
# Epoch [19/1500]
# Train Loss: 1.4909, Train Acc: 0.4201
# Val Loss: 1.5529, Val Acc: 0.3507
# --------------------------------------------------
# Epoch [20/1500]
# Train Loss: 1.4896, Train Acc: 0.4462
# Val Loss: 1.5062, Val Acc: 0.3785
# --------------------------------------------------
# Epoch [21/1500]
# Train Loss: 1.4639, Train Acc: 0.4392
# Val Loss: 1.5364, Val Acc: 0.3576
# --------------------------------------------------
# Epoch [22/1500]
# Train Loss: 1.4559, Train Acc: 0.4583
# Val Loss: 1.4988, Val Acc: 0.3819
# --------------------------------------------------
# Epoch [23/1500]
# Train Loss: 1.4432, Train Acc: 0.4514
# Val Loss: 1.5202, Val Acc: 0.3889
# --------------------------------------------------
# Epoch [24/1500]
# Train Loss: 1.4298, Train Acc: 0.4497
# Val Loss: 1.4933, Val Acc: 0.3958
# --------------------------------------------------
# Epoch [25/1500]
# Train Loss: 1.3758, Train Acc: 0.4974
# Val Loss: 1.4909, Val Acc: 0.4062
# --------------------------------------------------
# Epoch [26/1500]
# Train Loss: 1.3695, Train Acc: 0.4939
# Val Loss: 1.4892, Val Acc: 0.4167
# --------------------------------------------------
# Epoch [27/1500]
# Train Loss: 1.4408, Train Acc: 0.4644
# Val Loss: 1.5436, Val Acc: 0.3750
# --------------------------------------------------
# Epoch [28/1500]
# Train Loss: 1.3637, Train Acc: 0.4983
# Val Loss: 1.5173, Val Acc: 0.3819
# --------------------------------------------------
# Epoch [29/1500]
# Train Loss: 1.3347, Train Acc: 0.4861
# Val Loss: 1.5169, Val Acc: 0.3819
# --------------------------------------------------
# Epoch [30/1500]
# Train Loss: 1.3281, Train Acc: 0.5148
# Val Loss: 1.4772, Val Acc: 0.4062
# --------------------------------------------------
# Epoch [31/1500]
# Train Loss: 1.3188, Train Acc: 0.5182
# Val Loss: 1.4111, Val Acc: 0.4410
# --------------------------------------------------
# Epoch [32/1500]
# Train Loss: 1.3140, Train Acc: 0.4896
# Val Loss: 1.4423, Val Acc: 0.4479
# --------------------------------------------------
# Epoch [33/1500]
# Train Loss: 1.3508, Train Acc: 0.5165
# Val Loss: 1.3784, Val Acc: 0.4514
# --------------------------------------------------
# Epoch [34/1500]
# Train Loss: 1.3021, Train Acc: 0.5087
# Val Loss: 1.4377, Val Acc: 0.4306
# --------------------------------------------------
# Epoch [35/1500]
# Train Loss: 1.2510, Train Acc: 0.5469
# Val Loss: 1.4317, Val Acc: 0.4444
# --------------------------------------------------
# Epoch [36/1500]
# Train Loss: 1.2615, Train Acc: 0.5295
# Val Loss: 1.3598, Val Acc: 0.4618
# --------------------------------------------------
# Epoch [37/1500]
# Train Loss: 1.2145, Train Acc: 0.5582
# Val Loss: 1.3922, Val Acc: 0.4583
# --------------------------------------------------
# Epoch [38/1500]
# Train Loss: 1.2499, Train Acc: 0.5312
# Val Loss: 1.3364, Val Acc: 0.4722
# --------------------------------------------------
# Epoch [39/1500]
# Train Loss: 1.2351, Train Acc: 0.5538
# Val Loss: 1.3830, Val Acc: 0.4549
# --------------------------------------------------
# Epoch [40/1500]
# Train Loss: 1.2035, Train Acc: 0.5538
# Val Loss: 1.3638, Val Acc: 0.4792
# --------------------------------------------------
# Epoch [41/1500]
# Train Loss: 1.2114, Train Acc: 0.5564
# Val Loss: 1.4434, Val Acc: 0.4340
# --------------------------------------------------
# Epoch [42/1500]
# Train Loss: 1.1578, Train Acc: 0.5703
# Val Loss: 1.4031, Val Acc: 0.4340
# --------------------------------------------------
# Epoch [43/1500]
# Train Loss: 1.1538, Train Acc: 0.5677
# Val Loss: 1.4073, Val Acc: 0.4410
# --------------------------------------------------
# Epoch [44/1500]
# Train Loss: 1.1394, Train Acc: 0.5755
# Val Loss: 1.2734, Val Acc: 0.4792
# --------------------------------------------------
# Epoch [45/1500]
# Train Loss: 1.1109, Train Acc: 0.5990
# Val Loss: 1.3452, Val Acc: 0.4653
# --------------------------------------------------
# Epoch [46/1500]
# Train Loss: 1.0965, Train Acc: 0.5964
# Val Loss: 1.3027, Val Acc: 0.4618
# --------------------------------------------------
# Epoch [47/1500]
# Train Loss: 1.1143, Train Acc: 0.5938
# Val Loss: 1.3262, Val Acc: 0.5000
# --------------------------------------------------
# Epoch [48/1500]
# Train Loss: 1.0670, Train Acc: 0.6337
# Val Loss: 1.3205, Val Acc: 0.4757
# --------------------------------------------------
# Epoch [49/1500]
# Train Loss: 1.0729, Train Acc: 0.6224
# Val Loss: 1.3309, Val Acc: 0.4757
# --------------------------------------------------
# Epoch [50/1500]
# Train Loss: 1.0823, Train Acc: 0.6042
# Val Loss: 1.1906, Val Acc: 0.5104
# --------------------------------------------------
# Epoch [51/1500]
# Train Loss: 1.0495, Train Acc: 0.6189
# Val Loss: 1.3003, Val Acc: 0.4965
# --------------------------------------------------
# Epoch [52/1500]
# Train Loss: 1.0493, Train Acc: 0.6189
# Val Loss: 1.4216, Val Acc: 0.4444
# --------------------------------------------------
# Epoch [53/1500]
# Train Loss: 1.0384, Train Acc: 0.6128
# Val Loss: 1.1909, Val Acc: 0.5243
# --------------------------------------------------
# Epoch [54/1500]
# Train Loss: 1.0215, Train Acc: 0.6441
# Val Loss: 1.2904, Val Acc: 0.4826
# --------------------------------------------------
# Epoch [55/1500]
# Train Loss: 1.0085, Train Acc: 0.6319
# Val Loss: 1.2515, Val Acc: 0.5069
# --------------------------------------------------
# Epoch [56/1500]
# Train Loss: 0.9775, Train Acc: 0.6424
# Val Loss: 1.3128, Val Acc: 0.4826
# --------------------------------------------------
# Epoch [57/1500]
# Train Loss: 0.9650, Train Acc: 0.6536
# Val Loss: 1.3124, Val Acc: 0.4861
# --------------------------------------------------
# Epoch [58/1500]
# Train Loss: 0.9604, Train Acc: 0.6641
# Val Loss: 1.2570, Val Acc: 0.4965
# --------------------------------------------------
# Epoch [59/1500]
# Train Loss: 0.9102, Train Acc: 0.6840
# Val Loss: 1.3264, Val Acc: 0.5174
# --------------------------------------------------
# Epoch [60/1500]
# Train Loss: 0.9298, Train Acc: 0.6641
# Val Loss: 1.2634, Val Acc: 0.5139
# --------------------------------------------------
# Epoch [61/1500]
# Train Loss: 0.9269, Train Acc: 0.6667
# Val Loss: 1.2090, Val Acc: 0.5347
# --------------------------------------------------
# Epoch [62/1500]
# Train Loss: 0.9297, Train Acc: 0.6641
# Val Loss: 1.2767, Val Acc: 0.4896
# --------------------------------------------------
# Epoch [63/1500]
# Train Loss: 0.9056, Train Acc: 0.6719
# Val Loss: 1.2421, Val Acc: 0.5035
# --------------------------------------------------
# Epoch [64/1500]
# Train Loss: 0.9063, Train Acc: 0.6562
# Val Loss: 1.1971, Val Acc: 0.5174
# --------------------------------------------------
# Epoch [65/1500]
# Train Loss: 0.8692, Train Acc: 0.6858
# Val Loss: 1.1783, Val Acc: 0.5278
# --------------------------------------------------
# Epoch [66/1500]
# Train Loss: 0.8884, Train Acc: 0.6797
# Val Loss: 1.1952, Val Acc: 0.5556
# --------------------------------------------------
# Epoch [67/1500]
# Train Loss: 0.8985, Train Acc: 0.6719
# Val Loss: 1.2811, Val Acc: 0.5000
# --------------------------------------------------
# Epoch [68/1500]
# Train Loss: 0.8850, Train Acc: 0.6710
# Val Loss: 1.1465, Val Acc: 0.5208
# --------------------------------------------------
# Epoch [69/1500]
# Train Loss: 0.8790, Train Acc: 0.6936
# Val Loss: 1.3465, Val Acc: 0.4792
# --------------------------------------------------
# Epoch [70/1500]
# Train Loss: 0.8444, Train Acc: 0.6988
# Val Loss: 1.2101, Val Acc: 0.5451
# --------------------------------------------------
# Epoch [71/1500]
# Train Loss: 0.8263, Train Acc: 0.7188
# Val Loss: 1.1712, Val Acc: 0.5382
# --------------------------------------------------
# Epoch [72/1500]
# Train Loss: 0.8210, Train Acc: 0.7023
# Val Loss: 1.1871, Val Acc: 0.5243
# --------------------------------------------------
# Epoch [73/1500]
# Train Loss: 0.8518, Train Acc: 0.6979
# Val Loss: 1.1577, Val Acc: 0.5243
# --------------------------------------------------
# Epoch [74/1500]
# Train Loss: 0.8147, Train Acc: 0.7222
# Val Loss: 1.1994, Val Acc: 0.5312
# --------------------------------------------------
# Epoch [75/1500]
# Train Loss: 0.7977, Train Acc: 0.7127
# Val Loss: 1.2452, Val Acc: 0.5451
# --------------------------------------------------
# Epoch [76/1500]
# Train Loss: 0.8004, Train Acc: 0.7092
# Val Loss: 1.2323, Val Acc: 0.5347
# --------------------------------------------------
# Epoch [77/1500]
# Train Loss: 0.7713, Train Acc: 0.7205
# Val Loss: 1.2696, Val Acc: 0.5451
# --------------------------------------------------
# Epoch [78/1500]
# Train Loss: 0.7866, Train Acc: 0.7335
# Val Loss: 1.3510, Val Acc: 0.4931
# --------------------------------------------------
# Epoch [79/1500]
# Train Loss: 0.8042, Train Acc: 0.7222
# Val Loss: 1.1556, Val Acc: 0.5556
# --------------------------------------------------
# Epoch [80/1500]
# Train Loss: 0.7405, Train Acc: 0.7457
# Val Loss: 1.2196, Val Acc: 0.5417
# --------------------------------------------------
# Epoch [81/1500]
# Train Loss: 0.7335, Train Acc: 0.7300
# Val Loss: 1.1737, Val Acc: 0.5486
# --------------------------------------------------
# Epoch [82/1500]
# Train Loss: 0.7408, Train Acc: 0.7370
# Val Loss: 1.1391, Val Acc: 0.5694
# --------------------------------------------------
# Epoch [83/1500]
# Train Loss: 0.7084, Train Acc: 0.7474
# Val Loss: 1.2804, Val Acc: 0.5382
# --------------------------------------------------
# Epoch [84/1500]
# Train Loss: 0.6922, Train Acc: 0.7378
# Val Loss: 1.1767, Val Acc: 0.5590
# --------------------------------------------------
# Epoch [85/1500]
# Train Loss: 0.7536, Train Acc: 0.7309
# Val Loss: 1.3131, Val Acc: 0.5347
# --------------------------------------------------
# Epoch [86/1500]
# Train Loss: 0.6866, Train Acc: 0.7552
# Val Loss: 1.1214, Val Acc: 0.5799
# --------------------------------------------------
# Epoch [87/1500]
# Train Loss: 0.6936, Train Acc: 0.7396
# Val Loss: 1.6074, Val Acc: 0.4861
# --------------------------------------------------
# Epoch [88/1500]
# Train Loss: 0.7137, Train Acc: 0.7439
# Val Loss: 1.1651, Val Acc: 0.5799
# --------------------------------------------------
# Epoch [89/1500]
# Train Loss: 0.6678, Train Acc: 0.7665
# Val Loss: 1.2429, Val Acc: 0.5382
# --------------------------------------------------
# Epoch [90/1500]
# Train Loss: 0.6820, Train Acc: 0.7448
# Val Loss: 1.2019, Val Acc: 0.5382
# --------------------------------------------------
# Epoch [91/1500]
# Train Loss: 0.6642, Train Acc: 0.7491
# Val Loss: 1.0716, Val Acc: 0.5556
# --------------------------------------------------
# Epoch [92/1500]
# Train Loss: 0.6799, Train Acc: 0.7639
# Val Loss: 1.3400, Val Acc: 0.5312
# --------------------------------------------------
# Epoch [93/1500]
# Train Loss: 0.6291, Train Acc: 0.7812
# Val Loss: 1.1318, Val Acc: 0.5799
# --------------------------------------------------
# Epoch [94/1500]
# Train Loss: 0.6124, Train Acc: 0.7873
# Val Loss: 1.1248, Val Acc: 0.5903
# --------------------------------------------------
# Epoch [95/1500]
# Train Loss: 0.6228, Train Acc: 0.7812
# Val Loss: 1.1644, Val Acc: 0.6042
# --------------------------------------------------
# Epoch [96/1500]
# Train Loss: 0.5958, Train Acc: 0.7917
# Val Loss: 1.1706, Val Acc: 0.6007
# --------------------------------------------------
# Epoch [97/1500]
# Train Loss: 0.6265, Train Acc: 0.7795
# Val Loss: 1.0473, Val Acc: 0.6076
# --------------------------------------------------
# Epoch [98/1500]
# Train Loss: 0.5890, Train Acc: 0.7821
# Val Loss: 1.0886, Val Acc: 0.5938
# --------------------------------------------------
# Epoch [99/1500]
# Train Loss: 0.5825, Train Acc: 0.8030
# Val Loss: 1.1477, Val Acc: 0.5868
# --------------------------------------------------
# Epoch [100/1500]
# Train Loss: 0.6347, Train Acc: 0.7708
# Val Loss: 1.1093, Val Acc: 0.5764
# --------------------------------------------------
# Epoch [101/1500]
# Train Loss: 0.5934, Train Acc: 0.7986
# Val Loss: 1.1943, Val Acc: 0.5868
# --------------------------------------------------
# Epoch [102/1500]
# Train Loss: 0.5977, Train Acc: 0.7873
# Val Loss: 1.1347, Val Acc: 0.5833
# --------------------------------------------------
# Epoch [103/1500]
# Train Loss: 0.5758, Train Acc: 0.7960
# Val Loss: 1.2540, Val Acc: 0.5729
# --------------------------------------------------
# Epoch [104/1500]
# Train Loss: 0.5576, Train Acc: 0.7908
# Val Loss: 1.0744, Val Acc: 0.6007
# --------------------------------------------------
# Epoch [105/1500]
# Train Loss: 0.5453, Train Acc: 0.8012
# Val Loss: 1.1170, Val Acc: 0.5903
# --------------------------------------------------
# Epoch [106/1500]
# Train Loss: 0.5473, Train Acc: 0.8021
# Val Loss: 1.2433, Val Acc: 0.5660
# --------------------------------------------------
# Epoch [107/1500]
# Train Loss: 0.5805, Train Acc: 0.7891
# Val Loss: 1.1445, Val Acc: 0.6042
# --------------------------------------------------
# Epoch [108/1500]
# Train Loss: 0.5494, Train Acc: 0.8073
# Val Loss: 1.0397, Val Acc: 0.6111
# --------------------------------------------------
# Epoch [109/1500]
# Train Loss: 0.5857, Train Acc: 0.7917
# Val Loss: 1.0604, Val Acc: 0.6146
# --------------------------------------------------
# Epoch [110/1500]
# Train Loss: 0.5403, Train Acc: 0.8082
# Val Loss: 1.0418, Val Acc: 0.6146
# --------------------------------------------------
# Epoch [111/1500]
# Train Loss: 0.5029, Train Acc: 0.8194
# Val Loss: 1.0944, Val Acc: 0.5972
# --------------------------------------------------
# Epoch [112/1500]
# Train Loss: 0.5369, Train Acc: 0.8038
# Val Loss: 1.1373, Val Acc: 0.5903
# --------------------------------------------------
# Epoch [113/1500]
# Train Loss: 0.5330, Train Acc: 0.8307
# Val Loss: 1.0631, Val Acc: 0.5938
# --------------------------------------------------
# Epoch [114/1500]
# Train Loss: 0.5113, Train Acc: 0.8160
# Val Loss: 1.3244, Val Acc: 0.5729
# --------------------------------------------------
# Epoch [115/1500]
# Train Loss: 0.5110, Train Acc: 0.8290
# Val Loss: 1.1589, Val Acc: 0.5938
# --------------------------------------------------
# Epoch [116/1500]
# Train Loss: 0.5673, Train Acc: 0.7925
# Val Loss: 1.1047, Val Acc: 0.6042
# --------------------------------------------------
# Epoch [117/1500]
# Train Loss: 0.5318, Train Acc: 0.8030
# Val Loss: 1.1856, Val Acc: 0.5938
# --------------------------------------------------
# Epoch [118/1500]
# Train Loss: 0.5176, Train Acc: 0.8168
# Val Loss: 1.0195, Val Acc: 0.5972
# --------------------------------------------------
# Epoch [119/1500]
# Train Loss: 0.5014, Train Acc: 0.8108
# Val Loss: 1.0676, Val Acc: 0.6007
# --------------------------------------------------
# Epoch [120/1500]
# Train Loss: 0.4920, Train Acc: 0.8134
# Val Loss: 1.1262, Val Acc: 0.6076
# --------------------------------------------------
# Epoch [121/1500]
# Train Loss: 0.4752, Train Acc: 0.8377
# Val Loss: 1.2019, Val Acc: 0.6181
# --------------------------------------------------
# Epoch [122/1500]
# Train Loss: 0.4483, Train Acc: 0.8420
# Val Loss: 1.1050, Val Acc: 0.6181
# --------------------------------------------------
# Epoch [123/1500]
# Train Loss: 0.4236, Train Acc: 0.8559
# Val Loss: 1.1583, Val Acc: 0.6007
# --------------------------------------------------
# Epoch [124/1500]
# Train Loss: 0.4509, Train Acc: 0.8464
# Val Loss: 1.0675, Val Acc: 0.6146
# --------------------------------------------------
# Epoch [125/1500]
# Train Loss: 0.4372, Train Acc: 0.8438
# Val Loss: 1.0873, Val Acc: 0.6146
# --------------------------------------------------
# Epoch [126/1500]
# Train Loss: 0.4581, Train Acc: 0.8420
# Val Loss: 1.1153, Val Acc: 0.6042
# --------------------------------------------------
# Epoch [127/1500]
# Train Loss: 0.4161, Train Acc: 0.8602
# Val Loss: 1.0605, Val Acc: 0.6042
# --------------------------------------------------
# Epoch [128/1500]
# Train Loss: 0.4206, Train Acc: 0.8542
# Val Loss: 1.0752, Val Acc: 0.6215
# --------------------------------------------------
# Epoch [129/1500]
# Train Loss: 0.4495, Train Acc: 0.8377
# Val Loss: 1.1108, Val Acc: 0.6111
# --------------------------------------------------
# Epoch [130/1500]
# Train Loss: 0.4092, Train Acc: 0.8707
# Val Loss: 1.1121, Val Acc: 0.5972
# --------------------------------------------------
# Epoch [131/1500]
# Train Loss: 0.4513, Train Acc: 0.8438
# Val Loss: 1.1217, Val Acc: 0.6319
# --------------------------------------------------
# Epoch [132/1500]
# Train Loss: 0.4541, Train Acc: 0.8420
# Val Loss: 1.0844, Val Acc: 0.6111
# --------------------------------------------------
# Epoch [133/1500]
# Train Loss: 0.4128, Train Acc: 0.8455
# Val Loss: 1.0844, Val Acc: 0.6146
# --------------------------------------------------
# Epoch [134/1500]
# Train Loss: 0.4187, Train Acc: 0.8594
# Val Loss: 1.1298, Val Acc: 0.6111
# --------------------------------------------------
# Epoch [135/1500]
# Train Loss: 0.4065, Train Acc: 0.8455
# Val Loss: 1.0754, Val Acc: 0.6389
# --------------------------------------------------
# Epoch [136/1500]
# Train Loss: 0.4199, Train Acc: 0.8438
# Val Loss: 1.1557, Val Acc: 0.5972
# --------------------------------------------------
# Epoch [137/1500]
# Train Loss: 0.4235, Train Acc: 0.8516
# Val Loss: 1.0930, Val Acc: 0.6354
# --------------------------------------------------
# Epoch [138/1500]
# Train Loss: 0.4438, Train Acc: 0.8307
# Val Loss: 1.2303, Val Acc: 0.6111
# --------------------------------------------------
# Epoch [139/1500]
# Train Loss: 0.3989, Train Acc: 0.8733
# Val Loss: 1.2944, Val Acc: 0.6076
# --------------------------------------------------
# Epoch [140/1500]
# Train Loss: 0.4076, Train Acc: 0.8533
# Val Loss: 1.1839, Val Acc: 0.6076
# --------------------------------------------------
# Epoch [141/1500]
# Train Loss: 0.4145, Train Acc: 0.8542
# Val Loss: 1.2951, Val Acc: 0.5903
# --------------------------------------------------
# Epoch [142/1500]
# Train Loss: 0.3851, Train Acc: 0.8672
# Val Loss: 1.0839, Val Acc: 0.6181
# --------------------------------------------------
# Epoch [143/1500]
# Train Loss: 0.3774, Train Acc: 0.8759
# Val Loss: 1.2117, Val Acc: 0.5903
# --------------------------------------------------
# Epoch [144/1500]
# Train Loss: 0.3809, Train Acc: 0.8550
# Val Loss: 1.1310, Val Acc: 0.6181
# --------------------------------------------------
# Epoch [145/1500]
# Train Loss: 0.3546, Train Acc: 0.8793
# Val Loss: 1.1378, Val Acc: 0.6181
# --------------------------------------------------
# Epoch [146/1500]
# Train Loss: 0.3661, Train Acc: 0.8750
# Val Loss: 1.0778, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [147/1500]
# Train Loss: 0.3478, Train Acc: 0.8785
# Val Loss: 1.0941, Val Acc: 0.6493
# --------------------------------------------------
# Epoch [148/1500]
# Train Loss: 0.3510, Train Acc: 0.8672
# Val Loss: 1.1624, Val Acc: 0.6319
# --------------------------------------------------
# Epoch [149/1500]
# Train Loss: 0.3774, Train Acc: 0.8576
# Val Loss: 1.1682, Val Acc: 0.6215
# --------------------------------------------------
# Epoch [150/1500]
# Train Loss: 0.3629, Train Acc: 0.8759
# Val Loss: 1.2190, Val Acc: 0.6424
# --------------------------------------------------
# Epoch [151/1500]
# Train Loss: 0.3312, Train Acc: 0.8915
# Val Loss: 1.1111, Val Acc: 0.6354
# --------------------------------------------------
# Epoch [152/1500]
# Train Loss: 0.3341, Train Acc: 0.8828
# Val Loss: 1.2408, Val Acc: 0.6285
# --------------------------------------------------
# Epoch [153/1500]
# Train Loss: 0.3188, Train Acc: 0.8958
# Val Loss: 1.2705, Val Acc: 0.6042
# --------------------------------------------------
# Epoch [154/1500]
# Train Loss: 0.3612, Train Acc: 0.8707
# Val Loss: 1.1812, Val Acc: 0.6319
# --------------------------------------------------
# Epoch [155/1500]
# Train Loss: 0.3366, Train Acc: 0.8785
# Val Loss: 1.2168, Val Acc: 0.6389
# --------------------------------------------------
# Epoch [156/1500]
# Train Loss: 0.3277, Train Acc: 0.8828
# Val Loss: 1.1281, Val Acc: 0.6389
# --------------------------------------------------
# Epoch [157/1500]
# Train Loss: 0.3358, Train Acc: 0.8819
# Val Loss: 1.1375, Val Acc: 0.6285
# --------------------------------------------------
# Epoch [158/1500]
# Train Loss: 0.3162, Train Acc: 0.8924
# Val Loss: 1.2075, Val Acc: 0.6181
# --------------------------------------------------
# Epoch [159/1500]
# Train Loss: 0.3159, Train Acc: 0.8863
# Val Loss: 1.1742, Val Acc: 0.6354
# --------------------------------------------------
# Epoch [160/1500]
# Train Loss: 0.2868, Train Acc: 0.8932
# Val Loss: 1.0646, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [161/1500]
# Train Loss: 0.3333, Train Acc: 0.8880
# Val Loss: 1.0801, Val Acc: 0.6215
# --------------------------------------------------
# Epoch [162/1500]
# Train Loss: 0.3456, Train Acc: 0.8837
# Val Loss: 1.1485, Val Acc: 0.6319
# --------------------------------------------------
# Epoch [163/1500]
# Train Loss: 0.2753, Train Acc: 0.9097
# Val Loss: 1.1762, Val Acc: 0.6146
# --------------------------------------------------
# Epoch [164/1500]
# Train Loss: 0.2849, Train Acc: 0.8984
# Val Loss: 1.1879, Val Acc: 0.6285
# --------------------------------------------------
# Epoch [165/1500]
# Train Loss: 0.2880, Train Acc: 0.8993
# Val Loss: 1.3960, Val Acc: 0.5938
# --------------------------------------------------
# Epoch [166/1500]
# Train Loss: 0.2499, Train Acc: 0.9175
# Val Loss: 1.3421, Val Acc: 0.6007
# --------------------------------------------------
# Epoch [167/1500]
# Train Loss: 0.2929, Train Acc: 0.8880
# Val Loss: 1.3806, Val Acc: 0.6076
# --------------------------------------------------
# Epoch [168/1500]
# Train Loss: 0.3291, Train Acc: 0.8967
# Val Loss: 1.1418, Val Acc: 0.6250
# --------------------------------------------------
# Epoch [169/1500]
# Train Loss: 0.3297, Train Acc: 0.8906
# Val Loss: 1.1524, Val Acc: 0.6354
# --------------------------------------------------
# Epoch [170/1500]
# Train Loss: 0.3242, Train Acc: 0.8845
# Val Loss: 1.2855, Val Acc: 0.6319
# --------------------------------------------------
# Epoch [171/1500]
# Train Loss: 0.2913, Train Acc: 0.8984
# Val Loss: 1.1259, Val Acc: 0.6285
# --------------------------------------------------
# Epoch [172/1500]
# Train Loss: 0.3067, Train Acc: 0.8819
# Val Loss: 1.3321, Val Acc: 0.6042
# --------------------------------------------------
# Epoch [173/1500]
# Train Loss: 0.2727, Train Acc: 0.9123
# Val Loss: 1.2656, Val Acc: 0.6146
# --------------------------------------------------
# Epoch [174/1500]
# Train Loss: 0.2988, Train Acc: 0.9002
# Val Loss: 1.3296, Val Acc: 0.6146
# --------------------------------------------------
# Epoch [175/1500]
# Train Loss: 0.3110, Train Acc: 0.8958
# Val Loss: 1.1444, Val Acc: 0.6493
# --------------------------------------------------
# Epoch [176/1500]
# Train Loss: 0.2800, Train Acc: 0.8915
# Val Loss: 1.2402, Val Acc: 0.6354
# --------------------------------------------------
# Epoch [177/1500]
# Train Loss: 0.2778, Train Acc: 0.9089
# Val Loss: 1.1593, Val Acc: 0.6528
# --------------------------------------------------
# Epoch [178/1500]
# Train Loss: 0.3154, Train Acc: 0.8802
# Val Loss: 1.1661, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [179/1500]
# Train Loss: 0.2633, Train Acc: 0.9045
# Val Loss: 1.2393, Val Acc: 0.6389
# --------------------------------------------------
# Epoch [180/1500]
# Train Loss: 0.2873, Train Acc: 0.8984
# Val Loss: 1.3897, Val Acc: 0.6181
# --------------------------------------------------
# Epoch [181/1500]
# Train Loss: 0.2739, Train Acc: 0.9054
# Val Loss: 1.4320, Val Acc: 0.6424
# --------------------------------------------------
# Epoch [182/1500]
# Train Loss: 0.2840, Train Acc: 0.9028
# Val Loss: 1.1604, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [183/1500]
# Train Loss: 0.2638, Train Acc: 0.9080
# Val Loss: 1.1782, Val Acc: 0.6597
# --------------------------------------------------
# Epoch [184/1500]
# Train Loss: 0.2820, Train Acc: 0.8993
# Val Loss: 1.1925, Val Acc: 0.6319
# --------------------------------------------------
# Epoch [185/1500]
# Train Loss: 0.2377, Train Acc: 0.9236
# Val Loss: 1.1329, Val Acc: 0.6493
# --------------------------------------------------
# Epoch [186/1500]
# Train Loss: 0.2434, Train Acc: 0.9062
# Val Loss: 1.1196, Val Acc: 0.6424
# --------------------------------------------------
# Epoch [187/1500]
# Train Loss: 0.2520, Train Acc: 0.9097
# Val Loss: 1.3021, Val Acc: 0.6181
# --------------------------------------------------
# Epoch [188/1500]
# Train Loss: 0.2616, Train Acc: 0.9036
# Val Loss: 1.2405, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [189/1500]
# Train Loss: 0.2487, Train Acc: 0.9132
# Val Loss: 1.2042, Val Acc: 0.6181
# --------------------------------------------------
# Epoch [190/1500]
# Train Loss: 0.2472, Train Acc: 0.9028
# Val Loss: 1.2231, Val Acc: 0.6354
# --------------------------------------------------
# Epoch [191/1500]
# Train Loss: 0.2554, Train Acc: 0.9106
# Val Loss: 1.2775, Val Acc: 0.6354
# --------------------------------------------------
# Epoch [192/1500]
# Train Loss: 0.2460, Train Acc: 0.9141
# Val Loss: 1.1657, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [193/1500]
# Train Loss: 0.2734, Train Acc: 0.9097
# Val Loss: 1.1958, Val Acc: 0.6285
# --------------------------------------------------
# Epoch [194/1500]
# Train Loss: 0.2252, Train Acc: 0.9227
# Val Loss: 1.3244, Val Acc: 0.6250
# --------------------------------------------------
# Epoch [195/1500]
# Train Loss: 0.2362, Train Acc: 0.9132
# Val Loss: 1.2521, Val Acc: 0.6424
# --------------------------------------------------
# Epoch [196/1500]
# Train Loss: 0.2523, Train Acc: 0.9149
# Val Loss: 1.3019, Val Acc: 0.6354
# --------------------------------------------------
# Epoch [197/1500]
# Train Loss: 0.2473, Train Acc: 0.9175
# Val Loss: 1.3782, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [198/1500]
# Train Loss: 0.2515, Train Acc: 0.9175
# Val Loss: 1.4558, Val Acc: 0.6528
# --------------------------------------------------
# Epoch [199/1500]
# Train Loss: 0.2356, Train Acc: 0.9219
# Val Loss: 1.3939, Val Acc: 0.6597
# --------------------------------------------------
# Epoch [200/1500]
# Train Loss: 0.2677, Train Acc: 0.9062
# Val Loss: 1.4060, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [201/1500]
# Train Loss: 0.2019, Train Acc: 0.9306
# Val Loss: 1.2667, Val Acc: 0.6389
# --------------------------------------------------
# Epoch [202/1500]
# Train Loss: 0.2372, Train Acc: 0.9149
# Val Loss: 1.2579, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [203/1500]
# Train Loss: 0.2192, Train Acc: 0.9219
# Val Loss: 1.1355, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [204/1500]
# Train Loss: 0.2347, Train Acc: 0.9236
# Val Loss: 1.3014, Val Acc: 0.6354
# --------------------------------------------------
# Epoch [205/1500]
# Train Loss: 0.2298, Train Acc: 0.9253
# Val Loss: 1.1857, Val Acc: 0.6632
# --------------------------------------------------
# Epoch [206/1500]
# Train Loss: 0.2522, Train Acc: 0.9106
# Val Loss: 1.2473, Val Acc: 0.6424
# --------------------------------------------------
# Epoch [207/1500]
# Train Loss: 0.2421, Train Acc: 0.9115
# Val Loss: 1.2294, Val Acc: 0.6424
# --------------------------------------------------
# Epoch [208/1500]
# Train Loss: 0.2215, Train Acc: 0.9210
# Val Loss: 1.1679, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [209/1500]
# Train Loss: 0.1863, Train Acc: 0.9280
# Val Loss: 1.4185, Val Acc: 0.6285
# --------------------------------------------------
# Epoch [210/1500]
# Train Loss: 0.1995, Train Acc: 0.9314
# Val Loss: 1.2874, Val Acc: 0.6424
# --------------------------------------------------
# Epoch [211/1500]
# Train Loss: 0.2316, Train Acc: 0.9271
# Val Loss: 1.2044, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [212/1500]
# Train Loss: 0.2146, Train Acc: 0.9280
# Val Loss: 1.2708, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [213/1500]
# Train Loss: 0.2018, Train Acc: 0.9323
# Val Loss: 1.2353, Val Acc: 0.6528
# --------------------------------------------------
# Epoch [214/1500]
# Train Loss: 0.1982, Train Acc: 0.9288
# Val Loss: 1.1641, Val Acc: 0.6597
# --------------------------------------------------
# Epoch [215/1500]
# Train Loss: 0.1811, Train Acc: 0.9366
# Val Loss: 1.2240, Val Acc: 0.6632
# --------------------------------------------------
# Epoch [216/1500]
# Train Loss: 0.1935, Train Acc: 0.9314
# Val Loss: 1.5543, Val Acc: 0.6389
# --------------------------------------------------
# Epoch [217/1500]
# Train Loss: 0.2075, Train Acc: 0.9288
# Val Loss: 1.4806, Val Acc: 0.6354
# --------------------------------------------------
# Epoch [218/1500]
# Train Loss: 0.1642, Train Acc: 0.9427
# Val Loss: 1.3699, Val Acc: 0.6632
# --------------------------------------------------
# Epoch [219/1500]
# Train Loss: 0.1948, Train Acc: 0.9306
# Val Loss: 1.3654, Val Acc: 0.6667
# --------------------------------------------------
# Epoch [220/1500]
# Train Loss: 0.1989, Train Acc: 0.9297
# Val Loss: 1.3173, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [221/1500]
# Train Loss: 0.2306, Train Acc: 0.9271
# Val Loss: 1.3027, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [222/1500]
# Train Loss: 0.2066, Train Acc: 0.9306
# Val Loss: 1.3187, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [223/1500]
# Train Loss: 0.1875, Train Acc: 0.9306
# Val Loss: 1.2656, Val Acc: 0.6597
# --------------------------------------------------
# Epoch [224/1500]
# Train Loss: 0.2020, Train Acc: 0.9288
# Val Loss: 1.2746, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [225/1500]
# Train Loss: 0.2396, Train Acc: 0.9149
# Val Loss: 1.2500, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [226/1500]
# Train Loss: 0.2149, Train Acc: 0.9306
# Val Loss: 1.2888, Val Acc: 0.6632
# --------------------------------------------------
# Epoch [227/1500]
# Train Loss: 0.1739, Train Acc: 0.9444
# Val Loss: 1.4380, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [228/1500]
# Train Loss: 0.2119, Train Acc: 0.9332
# Val Loss: 1.2633, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [229/1500]
# Train Loss: 0.1905, Train Acc: 0.9332
# Val Loss: 1.1983, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [230/1500]
# Train Loss: 0.2024, Train Acc: 0.9271
# Val Loss: 1.2445, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [231/1500]
# Train Loss: 0.1962, Train Acc: 0.9280
# Val Loss: 1.2752, Val Acc: 0.6597
# --------------------------------------------------
# Epoch [232/1500]
# Train Loss: 0.1862, Train Acc: 0.9323
# Val Loss: 1.2472, Val Acc: 0.6528
# --------------------------------------------------
# Epoch [233/1500]
# Train Loss: 0.1835, Train Acc: 0.9262
# Val Loss: 1.1980, Val Acc: 0.6632
# --------------------------------------------------
# Epoch [234/1500]
# Train Loss: 0.1572, Train Acc: 0.9444
# Val Loss: 1.2402, Val Acc: 0.6597
# --------------------------------------------------
# Epoch [235/1500]
# Train Loss: 0.2020, Train Acc: 0.9366
# Val Loss: 1.1836, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [236/1500]
# Train Loss: 0.1672, Train Acc: 0.9444
# Val Loss: 1.1471, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [237/1500]
# Train Loss: 0.1618, Train Acc: 0.9453
# Val Loss: 1.2316, Val Acc: 0.6528
# --------------------------------------------------
# Epoch [238/1500]
# Train Loss: 0.1751, Train Acc: 0.9418
# Val Loss: 1.2391, Val Acc: 0.6667
# --------------------------------------------------
# Epoch [239/1500]
# Train Loss: 0.1426, Train Acc: 0.9488
# Val Loss: 1.3246, Val Acc: 0.6632
# --------------------------------------------------
# Epoch [240/1500]
# Train Loss: 0.1932, Train Acc: 0.9332
# Val Loss: 1.3850, Val Acc: 0.6528
# --------------------------------------------------
# Epoch [241/1500]
# Train Loss: 0.1641, Train Acc: 0.9418
# Val Loss: 1.2691, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [242/1500]
# Train Loss: 0.1673, Train Acc: 0.9488
# Val Loss: 1.3376, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [243/1500]
# Train Loss: 0.1831, Train Acc: 0.9297
# Val Loss: 1.3909, Val Acc: 0.6493
# --------------------------------------------------
# Epoch [244/1500]
# Train Loss: 0.1801, Train Acc: 0.9410
# Val Loss: 1.2482, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [245/1500]
# Train Loss: 0.2100, Train Acc: 0.9314
# Val Loss: 1.2727, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [246/1500]
# Train Loss: 0.1679, Train Acc: 0.9410
# Val Loss: 1.4371, Val Acc: 0.6667
# --------------------------------------------------
# Epoch [247/1500]
# Train Loss: 0.1736, Train Acc: 0.9384
# Val Loss: 1.2656, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [248/1500]
# Train Loss: 0.1797, Train Acc: 0.9418
# Val Loss: 1.3045, Val Acc: 0.6667
# --------------------------------------------------
# Epoch [249/1500]
# Train Loss: 0.1829, Train Acc: 0.9384
# Val Loss: 1.4764, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [250/1500]
# Train Loss: 0.1581, Train Acc: 0.9531
# Val Loss: 1.4321, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [251/1500]
# Train Loss: 0.1804, Train Acc: 0.9375
# Val Loss: 1.2848, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [252/1500]
# Train Loss: 0.1424, Train Acc: 0.9549
# Val Loss: 1.2622, Val Acc: 0.6667
# --------------------------------------------------
# Epoch [253/1500]
# Train Loss: 0.1698, Train Acc: 0.9306
# Val Loss: 1.2289, Val Acc: 0.6667
# --------------------------------------------------
# Epoch [254/1500]
# Train Loss: 0.1496, Train Acc: 0.9444
# Val Loss: 1.3845, Val Acc: 0.6493
# --------------------------------------------------
# Epoch [255/1500]
# Train Loss: 0.1719, Train Acc: 0.9384
# Val Loss: 1.2474, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [256/1500]
# Train Loss: 0.1571, Train Acc: 0.9436
# Val Loss: 1.2321, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [257/1500]
# Train Loss: 0.1916, Train Acc: 0.9332
# Val Loss: 1.4695, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [258/1500]
# Train Loss: 0.1454, Train Acc: 0.9479
# Val Loss: 1.3531, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [259/1500]
# Train Loss: 0.1694, Train Acc: 0.9505
# Val Loss: 1.2784, Val Acc: 0.6910
# --------------------------------------------------
# Epoch [260/1500]
# Train Loss: 0.1697, Train Acc: 0.9470
# Val Loss: 1.3858, Val Acc: 0.6632
# --------------------------------------------------
# Epoch [261/1500]
# Train Loss: 0.1895, Train Acc: 0.9358
# Val Loss: 1.3878, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [262/1500]
# Train Loss: 0.1765, Train Acc: 0.9392
# Val Loss: 1.3152, Val Acc: 0.6667
# --------------------------------------------------
# Epoch [263/1500]
# Train Loss: 0.1610, Train Acc: 0.9470
# Val Loss: 1.4194, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [264/1500]
# Train Loss: 0.1437, Train Acc: 0.9462
# Val Loss: 1.2497, Val Acc: 0.6667
# --------------------------------------------------
# Epoch [265/1500]
# Train Loss: 0.1639, Train Acc: 0.9436
# Val Loss: 1.1641, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [266/1500]
# Train Loss: 0.1430, Train Acc: 0.9523
# Val Loss: 1.2032, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [267/1500]
# Train Loss: 0.1607, Train Acc: 0.9470
# Val Loss: 1.2363, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [268/1500]
# Train Loss: 0.1523, Train Acc: 0.9462
# Val Loss: 1.2030, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [269/1500]
# Train Loss: 0.1814, Train Acc: 0.9375
# Val Loss: 1.2844, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [270/1500]
# Train Loss: 0.1327, Train Acc: 0.9523
# Val Loss: 1.1772, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [271/1500]
# Train Loss: 0.1372, Train Acc: 0.9540
# Val Loss: 1.1824, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [272/1500]
# Train Loss: 0.1484, Train Acc: 0.9531
# Val Loss: 1.2980, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [273/1500]
# Train Loss: 0.1639, Train Acc: 0.9514
# Val Loss: 1.2300, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [274/1500]
# Train Loss: 0.1455, Train Acc: 0.9497
# Val Loss: 1.2627, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [275/1500]
# Train Loss: 0.1562, Train Acc: 0.9366
# Val Loss: 1.3292, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [276/1500]
# Train Loss: 0.1732, Train Acc: 0.9436
# Val Loss: 1.3293, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [277/1500]
# Train Loss: 0.1792, Train Acc: 0.9392
# Val Loss: 1.3264, Val Acc: 0.6493
# --------------------------------------------------
# Epoch [278/1500]
# Train Loss: 0.1484, Train Acc: 0.9462
# Val Loss: 1.2516, Val Acc: 0.6528
# --------------------------------------------------
# Epoch [279/1500]
# Train Loss: 0.1912, Train Acc: 0.9332
# Val Loss: 1.3625, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [280/1500]
# Train Loss: 0.1733, Train Acc: 0.9375
# Val Loss: 1.2048, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [281/1500]
# Train Loss: 0.1619, Train Acc: 0.9505
# Val Loss: 1.3493, Val Acc: 0.6493
# --------------------------------------------------
# Epoch [282/1500]
# Train Loss: 0.1499, Train Acc: 0.9514
# Val Loss: 1.3335, Val Acc: 0.6528
# --------------------------------------------------
# Epoch [283/1500]
# Train Loss: 0.1759, Train Acc: 0.9366
# Val Loss: 1.2271, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [284/1500]
# Train Loss: 0.1706, Train Acc: 0.9401
# Val Loss: 1.2373, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [285/1500]
# Train Loss: 0.1351, Train Acc: 0.9575
# Val Loss: 1.4177, Val Acc: 0.6493
# --------------------------------------------------
# Epoch [286/1500]
# Train Loss: 0.1182, Train Acc: 0.9653
# Val Loss: 1.2792, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [287/1500]
# Train Loss: 0.1455, Train Acc: 0.9462
# Val Loss: 1.2781, Val Acc: 0.6528
# --------------------------------------------------
# Epoch [288/1500]
# Train Loss: 0.1461, Train Acc: 0.9488
# Val Loss: 1.4662, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [289/1500]
# Train Loss: 0.1477, Train Acc: 0.9514
# Val Loss: 1.3079, Val Acc: 0.6458
# --------------------------------------------------
# Epoch [290/1500]
# Train Loss: 0.1254, Train Acc: 0.9583
# Val Loss: 1.2787, Val Acc: 0.6667
# --------------------------------------------------
# Epoch [291/1500]
# Train Loss: 0.1213, Train Acc: 0.9583
# Val Loss: 1.3956, Val Acc: 0.6597
# --------------------------------------------------
# Epoch [292/1500]
# Train Loss: 0.1349, Train Acc: 0.9523
# Val Loss: 1.3512, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [293/1500]
# Train Loss: 0.1199, Train Acc: 0.9549
# Val Loss: 1.2684, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [294/1500]
# Train Loss: 0.1451, Train Acc: 0.9575
# Val Loss: 1.2962, Val Acc: 0.6632
# --------------------------------------------------
# Epoch [295/1500]
# Train Loss: 0.1224, Train Acc: 0.9540
# Val Loss: 1.3604, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [296/1500]
# Train Loss: 0.1546, Train Acc: 0.9462
# Val Loss: 1.4229, Val Acc: 0.6667
# --------------------------------------------------
# Epoch [297/1500]
# Train Loss: 0.1529, Train Acc: 0.9523
# Val Loss: 1.3740, Val Acc: 0.6632
# --------------------------------------------------
# Epoch [298/1500]
# Train Loss: 0.1215, Train Acc: 0.9531
# Val Loss: 1.2193, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [299/1500]
# Train Loss: 0.1333, Train Acc: 0.9583
# Val Loss: 1.2498, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [300/1500]
# Train Loss: 0.1291, Train Acc: 0.9557
# Val Loss: 1.3699, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [301/1500]
# Train Loss: 0.1256, Train Acc: 0.9609
# Val Loss: 1.3083, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [302/1500]
# Train Loss: 0.1312, Train Acc: 0.9497
# Val Loss: 1.3275, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [303/1500]
# Train Loss: 0.1223, Train Acc: 0.9592
# Val Loss: 1.2434, Val Acc: 0.7049
# --------------------------------------------------
# Epoch [304/1500]
# Train Loss: 0.1199, Train Acc: 0.9540
# Val Loss: 1.2918, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [305/1500]
# Train Loss: 0.1531, Train Acc: 0.9488
# Val Loss: 1.1783, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [306/1500]
# Train Loss: 0.1189, Train Acc: 0.9609
# Val Loss: 1.2370, Val Acc: 0.7153
# --------------------------------------------------
# Epoch [307/1500]
# Train Loss: 0.1449, Train Acc: 0.9453
# Val Loss: 1.2612, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [308/1500]
# Train Loss: 0.1273, Train Acc: 0.9540
# Val Loss: 1.2221, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [309/1500]
# Train Loss: 0.1216, Train Acc: 0.9575
# Val Loss: 1.2688, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [310/1500]
# Train Loss: 0.1075, Train Acc: 0.9679
# Val Loss: 1.3255, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [311/1500]
# Train Loss: 0.1155, Train Acc: 0.9566
# Val Loss: 1.2966, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [312/1500]
# Train Loss: 0.1331, Train Acc: 0.9497
# Val Loss: 1.2550, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [313/1500]
# Train Loss: 0.1351, Train Acc: 0.9505
# Val Loss: 1.2803, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [314/1500]
# Train Loss: 0.1195, Train Acc: 0.9540
# Val Loss: 1.3313, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [315/1500]
# Train Loss: 0.1062, Train Acc: 0.9627
# Val Loss: 1.3655, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [316/1500]
# Train Loss: 0.1488, Train Acc: 0.9531
# Val Loss: 1.3750, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [317/1500]
# Train Loss: 0.1221, Train Acc: 0.9557
# Val Loss: 1.3273, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [318/1500]
# Train Loss: 0.1142, Train Acc: 0.9575
# Val Loss: 1.3769, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [319/1500]
# Train Loss: 0.1338, Train Acc: 0.9549
# Val Loss: 1.3721, Val Acc: 0.6493
# --------------------------------------------------
# Epoch [320/1500]
# Train Loss: 0.1165, Train Acc: 0.9540
# Val Loss: 1.4051, Val Acc: 0.6632
# --------------------------------------------------
# Epoch [321/1500]
# Train Loss: 0.1127, Train Acc: 0.9575
# Val Loss: 1.4639, Val Acc: 0.6528
# --------------------------------------------------
# Epoch [322/1500]
# Train Loss: 0.1341, Train Acc: 0.9592
# Val Loss: 1.4249, Val Acc: 0.6597
# --------------------------------------------------
# Epoch [323/1500]
# Train Loss: 0.1407, Train Acc: 0.9488
# Val Loss: 1.5540, Val Acc: 0.6424
# --------------------------------------------------
# Epoch [324/1500]
# Train Loss: 0.1025, Train Acc: 0.9592
# Val Loss: 1.4093, Val Acc: 0.6667
# --------------------------------------------------
# Epoch [325/1500]
# Train Loss: 0.1437, Train Acc: 0.9557
# Val Loss: 1.3583, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [326/1500]
# Train Loss: 0.1303, Train Acc: 0.9531
# Val Loss: 1.3164, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [327/1500]
# Train Loss: 0.1185, Train Acc: 0.9661
# Val Loss: 1.4317, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [328/1500]
# Train Loss: 0.1241, Train Acc: 0.9601
# Val Loss: 1.4879, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [329/1500]
# Train Loss: 0.1400, Train Acc: 0.9444
# Val Loss: 1.3751, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [330/1500]
# Train Loss: 0.1089, Train Acc: 0.9583
# Val Loss: 1.3648, Val Acc: 0.6632
# --------------------------------------------------
# Epoch [331/1500]
# Train Loss: 0.1433, Train Acc: 0.9583
# Val Loss: 1.6180, Val Acc: 0.6354
# --------------------------------------------------
# Epoch [332/1500]
# Train Loss: 0.1370, Train Acc: 0.9601
# Val Loss: 1.3630, Val Acc: 0.6910
# --------------------------------------------------
# Epoch [333/1500]
# Train Loss: 0.1335, Train Acc: 0.9523
# Val Loss: 1.2078, Val Acc: 0.7222
# --------------------------------------------------
# Epoch [334/1500]
# Train Loss: 0.1064, Train Acc: 0.9644
# Val Loss: 1.2731, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [335/1500]
# Train Loss: 0.1279, Train Acc: 0.9575
# Val Loss: 1.3098, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [336/1500]
# Train Loss: 0.1290, Train Acc: 0.9540
# Val Loss: 1.2889, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [337/1500]
# Train Loss: 0.0999, Train Acc: 0.9635
# Val Loss: 1.1800, Val Acc: 0.7049
# --------------------------------------------------
# Epoch [338/1500]
# Train Loss: 0.1230, Train Acc: 0.9618
# Val Loss: 1.3240, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [339/1500]
# Train Loss: 0.1208, Train Acc: 0.9635
# Val Loss: 1.3450, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [340/1500]
# Train Loss: 0.1203, Train Acc: 0.9549
# Val Loss: 1.2882, Val Acc: 0.7118
# --------------------------------------------------
# Epoch [341/1500]
# Train Loss: 0.1123, Train Acc: 0.9575
# Val Loss: 1.3686, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [342/1500]
# Train Loss: 0.1302, Train Acc: 0.9566
# Val Loss: 1.3549, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [343/1500]
# Train Loss: 0.1121, Train Acc: 0.9557
# Val Loss: 1.4701, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [344/1500]
# Train Loss: 0.1060, Train Acc: 0.9661
# ...
# --------------------------------------------------
# Epoch [1388/1500]
# Train Loss: 0.0343, Train Acc: 0.9913
# Val Loss: 1.5127, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [1389/1500]
# Train Loss: 0.0488, Train Acc: 0.9878
# Val Loss: 1.6188, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1390/1500]
# Train Loss: 0.0491, Train Acc: 0.9870
# Val Loss: 1.6484, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1391/1500]
# Train Loss: 0.0330, Train Acc: 0.9887
# Val Loss: 1.5495, Val Acc: 0.6910
# --------------------------------------------------
# Epoch [1392/1500]
# Train Loss: 0.0269, Train Acc: 0.9913
# Val Loss: 1.5679, Val Acc: 0.6597
# --------------------------------------------------
# Epoch [1393/1500]
# Train Loss: 0.0225, Train Acc: 0.9939
# Val Loss: 1.6070, Val Acc: 0.6562
# --------------------------------------------------
# Epoch [1394/1500]
# Train Loss: 0.0142, Train Acc: 0.9957
# Val Loss: 1.6037, Val Acc: 0.6701
# --------------------------------------------------
# Epoch [1395/1500]
# Train Loss: 0.0438, Train Acc: 0.9826
# Val Loss: 1.5875, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [1396/1500]
# Train Loss: 0.0251, Train Acc: 0.9905
# Val Loss: 1.5596, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [1397/1500]
# Train Loss: 0.0444, Train Acc: 0.9852
# Val Loss: 1.5231, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1398/1500]
# Train Loss: 0.0290, Train Acc: 0.9878
# Val Loss: 1.5208, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1399/1500]
# Train Loss: 0.0358, Train Acc: 0.9896
# Val Loss: 1.5925, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1400/1500]
# Train Loss: 0.0241, Train Acc: 0.9922
# Val Loss: 1.6009, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1401/1500]
# Train Loss: 0.0347, Train Acc: 0.9913
# Val Loss: 1.5809, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1402/1500]
# Train Loss: 0.0347, Train Acc: 0.9913
# Val Loss: 1.5727, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1403/1500]
# Train Loss: 0.0246, Train Acc: 0.9913
# Val Loss: 1.6115, Val Acc: 0.6910
# --------------------------------------------------
# Epoch [1404/1500]
# Train Loss: 0.0268, Train Acc: 0.9905
# Val Loss: 1.5807, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [1405/1500]
# Train Loss: 0.0230, Train Acc: 0.9922
# Val Loss: 1.5804, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [1406/1500]
# Train Loss: 0.0392, Train Acc: 0.9844
# Val Loss: 1.6504, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1407/1500]
# Train Loss: 0.0208, Train Acc: 0.9948
# Val Loss: 1.6972, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1408/1500]
# Train Loss: 0.0240, Train Acc: 0.9939
# Val Loss: 1.6907, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1409/1500]
# Train Loss: 0.0400, Train Acc: 0.9852
# Val Loss: 1.6748, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1410/1500]
# Train Loss: 0.0324, Train Acc: 0.9861
# Val Loss: 1.6817, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [1411/1500]
# Train Loss: 0.0259, Train Acc: 0.9948
# Val Loss: 1.6648, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1412/1500]
# Train Loss: 0.0270, Train Acc: 0.9905
# Val Loss: 1.6587, Val Acc: 0.7049
# --------------------------------------------------
# Epoch [1413/1500]
# Train Loss: 0.0282, Train Acc: 0.9913
# Val Loss: 1.7487, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1414/1500]
# Train Loss: 0.0247, Train Acc: 0.9931
# Val Loss: 1.7245, Val Acc: 0.7049
# --------------------------------------------------
# Epoch [1415/1500]
# Train Loss: 0.0260, Train Acc: 0.9939
# Val Loss: 1.7418, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1416/1500]
# Train Loss: 0.0340, Train Acc: 0.9913
# Val Loss: 1.7314, Val Acc: 0.7083
# --------------------------------------------------
# Epoch [1417/1500]
# Train Loss: 0.0220, Train Acc: 0.9905
# Val Loss: 1.6364, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1418/1500]
# Train Loss: 0.0247, Train Acc: 0.9905
# Val Loss: 1.6750, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [1419/1500]
# Train Loss: 0.0401, Train Acc: 0.9896
# Val Loss: 1.5880, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [1420/1500]
# Train Loss: 0.0232, Train Acc: 0.9896
# Val Loss: 1.5712, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [1421/1500]
# Train Loss: 0.0237, Train Acc: 0.9931
# Val Loss: 1.6297, Val Acc: 0.6910
# --------------------------------------------------
# Epoch [1422/1500]
# Train Loss: 0.0317, Train Acc: 0.9931
# Val Loss: 1.7038, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1423/1500]
# Train Loss: 0.0294, Train Acc: 0.9896
# Val Loss: 1.7204, Val Acc: 0.7118
# --------------------------------------------------
# Epoch [1424/1500]
# Train Loss: 0.0356, Train Acc: 0.9887
# Val Loss: 1.6637, Val Acc: 0.7049
# --------------------------------------------------
# Epoch [1425/1500]
# Train Loss: 0.0268, Train Acc: 0.9922
# Val Loss: 1.5797, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1426/1500]
# Train Loss: 0.0344, Train Acc: 0.9896
# Val Loss: 1.6073, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [1427/1500]
# Train Loss: 0.0183, Train Acc: 0.9939
# Val Loss: 1.6567, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1428/1500]
# Train Loss: 0.0207, Train Acc: 0.9913
# Val Loss: 1.6511, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1429/1500]
# Train Loss: 0.0307, Train Acc: 0.9896
# Val Loss: 1.5962, Val Acc: 0.7049
# --------------------------------------------------
# Epoch [1430/1500]
# Train Loss: 0.0338, Train Acc: 0.9931
# Val Loss: 1.5421, Val Acc: 0.7049
# --------------------------------------------------
# Epoch [1431/1500]
# Train Loss: 0.0170, Train Acc: 0.9939
# Val Loss: 1.4976, Val Acc: 0.7118
# --------------------------------------------------
# Epoch [1432/1500]
# Train Loss: 0.0162, Train Acc: 0.9957
# Val Loss: 1.5726, Val Acc: 0.7083
# --------------------------------------------------
# Epoch [1433/1500]
# Train Loss: 0.0358, Train Acc: 0.9896
# Val Loss: 1.6803, Val Acc: 0.7222
# --------------------------------------------------
# Epoch [1434/1500]
# Train Loss: 0.0460, Train Acc: 0.9896
# Val Loss: 1.7174, Val Acc: 0.7188
# --------------------------------------------------
# Epoch [1435/1500]
# Train Loss: 0.0246, Train Acc: 0.9896
# Val Loss: 1.8072, Val Acc: 0.7118
# --------------------------------------------------
# Epoch [1436/1500]
# Train Loss: 0.0627, Train Acc: 0.9809
# Val Loss: 1.8448, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1437/1500]
# Train Loss: 0.0389, Train Acc: 0.9887
# Val Loss: 1.7023, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [1438/1500]
# Train Loss: 0.0306, Train Acc: 0.9913
# Val Loss: 1.6462, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1439/1500]
# Train Loss: 0.0227, Train Acc: 0.9887
# Val Loss: 1.6533, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [1440/1500]
# Train Loss: 0.0316, Train Acc: 0.9896
# Val Loss: 1.6757, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1441/1500]
# Train Loss: 0.0297, Train Acc: 0.9905
# Val Loss: 1.7207, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [1442/1500]
# Train Loss: 0.0224, Train Acc: 0.9922
# Val Loss: 1.6754, Val Acc: 0.7083
# --------------------------------------------------
# Epoch [1443/1500]
# Train Loss: 0.0225, Train Acc: 0.9939
# Val Loss: 1.5799, Val Acc: 0.7118
# --------------------------------------------------
# Epoch [1444/1500]
# Train Loss: 0.0249, Train Acc: 0.9957
# Val Loss: 1.5378, Val Acc: 0.7049
# --------------------------------------------------
# Epoch [1445/1500]
# Train Loss: 0.0316, Train Acc: 0.9878
# Val Loss: 1.4777, Val Acc: 0.7188
# --------------------------------------------------
# Epoch [1446/1500]
# Train Loss: 0.0144, Train Acc: 0.9974
# Val Loss: 1.5299, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1447/1500]
# Train Loss: 0.0227, Train Acc: 0.9931
# Val Loss: 1.5979, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [1448/1500]
# Train Loss: 0.0158, Train Acc: 0.9957
# Val Loss: 1.6989, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1449/1500]
# Train Loss: 0.0170, Train Acc: 0.9939
# Val Loss: 1.7400, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1450/1500]
# Train Loss: 0.0244, Train Acc: 0.9913
# Val Loss: 1.7205, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1451/1500]
# Train Loss: 0.0240, Train Acc: 0.9922
# Val Loss: 1.6995, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [1452/1500]
# Train Loss: 0.0204, Train Acc: 0.9905
# Val Loss: 1.7964, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [1453/1500]
# Train Loss: 0.0255, Train Acc: 0.9922
# Val Loss: 1.8581, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [1454/1500]
# Train Loss: 0.0230, Train Acc: 0.9922
# Val Loss: 1.8268, Val Acc: 0.7049
# --------------------------------------------------
# Epoch [1455/1500]
# Train Loss: 0.0254, Train Acc: 0.9939
# Val Loss: 1.7626, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1456/1500]
# Train Loss: 0.0427, Train Acc: 0.9913
# Val Loss: 1.7187, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1457/1500]
# Train Loss: 0.0334, Train Acc: 0.9896
# Val Loss: 1.7416, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [1458/1500]
# Train Loss: 0.0254, Train Acc: 0.9913
# Val Loss: 1.7183, Val Acc: 0.7049
# --------------------------------------------------
# Epoch [1459/1500]
# Train Loss: 0.0200, Train Acc: 0.9957
# Val Loss: 1.7473, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1460/1500]
# Train Loss: 0.0307, Train Acc: 0.9948
# Val Loss: 1.7795, Val Acc: 0.7083
# --------------------------------------------------
# Epoch [1461/1500]
# Train Loss: 0.0251, Train Acc: 0.9939
# Val Loss: 1.8541, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1462/1500]
# Train Loss: 0.0240, Train Acc: 0.9896
# Val Loss: 1.7803, Val Acc: 0.7049
# --------------------------------------------------
# Epoch [1463/1500]
# Train Loss: 0.0241, Train Acc: 0.9913
# Val Loss: 1.6761, Val Acc: 0.7188
# --------------------------------------------------
# Epoch [1464/1500]
# Train Loss: 0.0249, Train Acc: 0.9922
# Val Loss: 1.6425, Val Acc: 0.7083
# --------------------------------------------------
# Epoch [1465/1500]
# Train Loss: 0.0217, Train Acc: 0.9931
# Val Loss: 1.7308, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1466/1500]
# Train Loss: 0.0258, Train Acc: 0.9905
# Val Loss: 1.7507, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1467/1500]
# Train Loss: 0.0343, Train Acc: 0.9878
# Val Loss: 1.7217, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1468/1500]
# Train Loss: 0.0345, Train Acc: 0.9913
# Val Loss: 1.7196, Val Acc: 0.6910
# --------------------------------------------------
# Epoch [1469/1500]
# Train Loss: 0.0203, Train Acc: 0.9913
# Val Loss: 1.7575, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1470/1500]
# Train Loss: 0.0287, Train Acc: 0.9913
# Val Loss: 1.6912, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1471/1500]
# Train Loss: 0.0234, Train Acc: 0.9939
# Val Loss: 1.6342, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1472/1500]
# Train Loss: 0.0282, Train Acc: 0.9913
# Val Loss: 1.6746, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [1473/1500]
# Train Loss: 0.0254, Train Acc: 0.9931
# Val Loss: 1.6759, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1474/1500]
# Train Loss: 0.0272, Train Acc: 0.9905
# Val Loss: 1.7431, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1475/1500]
# Train Loss: 0.0332, Train Acc: 0.9905
# Val Loss: 1.7953, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [1476/1500]
# Train Loss: 0.0421, Train Acc: 0.9905
# Val Loss: 1.7017, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1477/1500]
# Train Loss: 0.0255, Train Acc: 0.9931
# Val Loss: 1.5826, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1478/1500]
# Train Loss: 0.0166, Train Acc: 0.9948
# Val Loss: 1.5595, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1479/1500]
# Train Loss: 0.0295, Train Acc: 0.9913
# Val Loss: 1.5856, Val Acc: 0.6910
# --------------------------------------------------
# Epoch [1480/1500]
# Train Loss: 0.0146, Train Acc: 0.9931
# Val Loss: 1.6600, Val Acc: 0.7118
# --------------------------------------------------
# Epoch [1481/1500]
# Train Loss: 0.0206, Train Acc: 0.9913
# Val Loss: 1.7146, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1482/1500]
# Train Loss: 0.0245, Train Acc: 0.9922
# Val Loss: 1.6278, Val Acc: 0.6910
# --------------------------------------------------
# Epoch [1483/1500]
# Train Loss: 0.0396, Train Acc: 0.9922
# Val Loss: 1.5871, Val Acc: 0.6979
# --------------------------------------------------
# Epoch [1484/1500]
# Train Loss: 0.0312, Train Acc: 0.9913
# Val Loss: 1.6373, Val Acc: 0.6910
# --------------------------------------------------
# Epoch [1485/1500]
# Train Loss: 0.0320, Train Acc: 0.9913
# Val Loss: 1.6884, Val Acc: 0.7153
# --------------------------------------------------
# Epoch [1486/1500]
# Train Loss: 0.0320, Train Acc: 0.9896
# Val Loss: 1.6587, Val Acc: 0.7014
# --------------------------------------------------
# Epoch [1487/1500]
# Train Loss: 0.0150, Train Acc: 0.9948
# Val Loss: 1.6790, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1488/1500]
# Train Loss: 0.0240, Train Acc: 0.9939
# Val Loss: 1.7121, Val Acc: 0.6875
# --------------------------------------------------
# Epoch [1489/1500]
# Train Loss: 0.0241, Train Acc: 0.9887
# Val Loss: 1.7420, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1490/1500]
# Train Loss: 0.0274, Train Acc: 0.9878
# Val Loss: 1.7849, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [1491/1500]
# Train Loss: 0.0295, Train Acc: 0.9905
# Val Loss: 1.7738, Val Acc: 0.6840
# --------------------------------------------------
# Epoch [1492/1500]
# Train Loss: 0.0253, Train Acc: 0.9913
# Val Loss: 1.7441, Val Acc: 0.6910
# --------------------------------------------------
# Epoch [1493/1500]
# Train Loss: 0.0167, Train Acc: 0.9948
# Val Loss: 1.7525, Val Acc: 0.6944
# --------------------------------------------------
# Epoch [1494/1500]
# Train Loss: 0.0261, Train Acc: 0.9922
# Val Loss: 1.7872, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [1495/1500]
# Train Loss: 0.0262, Train Acc: 0.9896
# Val Loss: 1.8667, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [1496/1500]
# Train Loss: 0.0157, Train Acc: 0.9965
# Val Loss: 1.9033, Val Acc: 0.6736
# --------------------------------------------------
# Epoch [1497/1500]
# Train Loss: 0.0305, Train Acc: 0.9887
# Val Loss: 1.8861, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [1498/1500]
# Train Loss: 0.0215, Train Acc: 0.9931
# Val Loss: 1.8273, Val Acc: 0.6771
# --------------------------------------------------
# Epoch [1499/1500]
# Train Loss: 0.0207, Train Acc: 0.9922
# Val Loss: 1.7123, Val Acc: 0.6806
# --------------------------------------------------
# Epoch [1500/1500]
# Train Loss: 0.0379, Train Acc: 0.9905
# Val Loss: 1.7203, Val Acc: 0.6701
# --------------------------------------------------

# %%
torch.save(model.state_dict(), "C:/Nini/Capstone/Models/cnn_model_mel_mfcc_chroma.pth")
