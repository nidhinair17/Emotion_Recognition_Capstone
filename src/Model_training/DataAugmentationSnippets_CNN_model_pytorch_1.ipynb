# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import precision_recall_fscore_support

# %%
features = pd.read_csv("C:/Nini/Capstone/CSV_Files/DataAugmentationSnippets_ravdess_extracted_features.csv")
features = features.drop(features.columns[0], axis=1)
temp = shuffle(features)
df = np.random.rand(len(temp)) < 0.8
train = temp[df]
test = temp[~df]

# %%
X_train = np.array(train.iloc[:,:-1])
y_train = np.array(train.iloc[:,-1])
X_test = np.array(test.iloc[:,:-1])
y_test = np.array(test.iloc[:,-1])

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
batch_size = 256
train_loader = DataLoader(TensorDataset(X_train,y_train), batch_size=batch_size,shuffle=True)
test_loader = DataLoader(TensorDataset(X_test,y_test), batch_size=batch_size, shuffle=False)

# %% [markdown]
# Test 1

# %%
class CNNModel(nn.Module):
    def __init__(self, input_size, num_classes):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=8)
        self.bn1 = nn.BatchNorm1d(64)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=8)
        self.bn2 = nn.BatchNorm1d(128)
        self.pool1 = nn.MaxPool1d(kernel_size=4, padding=2)
        self.dropout1 = nn.Dropout(0.5)
        self.conv3 = nn.Conv1d(128, 128, kernel_size=8)
        self.bn3 = nn.BatchNorm1d(128)
        self.pool2 = nn.MaxPool1d(kernel_size=4, padding=2)
        self.dropout2 = nn.Dropout(0.5)
        self.conv4 = nn.Conv1d(128, 64, kernel_size=3, padding=2)
        self.bn4 = nn.BatchNorm1d(64)
        self.fc1 = nn.Linear(512, 256)
        self.dropout3 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, num_classes)

    # def _compute_flattened_size(self, input_size):
    #     with torch.no_grad():
    #         x = torch.randn(1, 1, input_size)  # Create a dummy input
    #         x = self.conv1(x)
    #         x = F.relu(x)
    #         x = self.conv2(x)
    #         x = F.relu(x)
    #         x = self.pool1(x)
    #         x = self.dropout1(x)
    #         x = self.conv3(x)
    #         x = F.relu(x)
    #         x = self.pool2(x)
    #         x = self.dropout2(x)
    #         x = self.conv4(x)
    #         x = F.relu(x)
    #         x = x.view(1, -1)  # Flatten
    #         self._to_linear = x.shape[1]

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool1(x)
        x = self.dropout1(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool2(x)
        x = self.dropout2(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout3(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# Test 2

# %%
# class CNNModel(nn.Module):
#     def __init__(self, input_size, num_classes):
#         super(CNNModel, self).__init__()
#         self.conv1 = nn.Conv1d(in_channels=1, out_channels=64, kernel_size=8)
#         self.bn1 = nn.BatchNorm1d(64)
#         self.conv2 = nn.Conv1d(64, 128, kernel_size=8)
#         self.bn2 = nn.BatchNorm1d(128)
#         self.pool1 = nn.MaxPool1d(kernel_size=6, padding=2)
#         self.dropout1 = nn.Dropout(0.5)
#         self.conv3 = nn.Conv1d(128, 128, kernel_size=8)
#         self.bn3 = nn.BatchNorm1d(128)
#         self.pool2 = nn.MaxPool1d(kernel_size=6, padding=2)
#         self.dropout2 = nn.Dropout(0.5)
#         # self.conv4 = nn.Conv1d(128, 64, kernel_size=4, padding=2)
#         # self.bn4 = nn.BatchNorm1d(64)
#         self.fc1 = nn.Linear(384, 256)
#         self.dropout3 = nn.Dropout(0.5)
#         self.fc2 = nn.Linear(256, num_classes)

#     # def _compute_flattened_size(self, input_size):
#     #     with torch.no_grad():
#     #         x = torch.randn(1, 1, input_size)  # Create a dummy input
#     #         x = self.conv1(x)
#     #         x = F.relu(x)
#     #         x = self.conv2(x)
#     #         x = F.relu(x)
#     #         x = self.pool1(x)
#     #         x = self.dropout1(x)
#     #         x = self.conv3(x)
#     #         x = F.relu(x)
#     #         x = self.pool2(x)
#     #         x = self.dropout2(x)
#     #         x = self.conv4(x)
#     #         x = F.relu(x)
#     #         x = x.view(1, -1)  # Flatten
#     #         self._to_linear = x.shape[1]

#     def forward(self, x):
#         x = F.relu(self.bn1(self.conv1(x)))
#         x = F.relu(self.bn2(self.conv2(x)))
#         x = self.pool1(x)
#         x = self.dropout1(x)
#         x = F.relu(self.bn3(self.conv3(x)))
#         x = self.pool2(x)
#         x = self.dropout2(x)
#         # x = F.relu(self.bn4(self.conv4(x)))
#         x = x.view(x.size(0), -1)
#         x = F.relu(self.fc1(x))
#         x = self.dropout3(x)
#         x = self.fc2(x)
#         return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNNModel(input_size=X_train.shape[1], num_classes=8).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=1e-4)

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: torch.Size([8355, 1, 128])

# %%
# epochs = 1500
# for epoch in range(epochs):
#     model.train()
#     running_loss = 0
#     total_loss = 0
#     total = 0
#     correct = 0
#     for X_batch, y_batch in train_loader:
#         X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#         optimizer.zero_grad()
#         outputs = model(X_batch)
#         loss = criterion(outputs, y_batch)
#         loss.backward()
#         optimizer.step()
#         running_loss += loss.item()
#         _, predicted = torch.max(outputs, 1)  # Get predicted class
#         correct += (predicted == y_batch).sum().item()
#         total += y_batch.size(0)
#     train_accuracy = correct / total
#     avg_train_loss = running_loss / len(train_loader)
#         # total_loss += loss.item()
#         # correct += (outputs.argmax(dim=1) == y_batch).sum().item()
#     model.eval()  # Set model to evaluation mode
#     val_correct = 0
#     val_total = 0
#     val_loss = 0.0

#     with torch.no_grad():  # Disable gradient computation for validation
#         for val_inputs, val_labels in test_loader:
#             val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)

#             val_outputs = model(val_inputs)
#             loss = criterion(val_outputs, val_labels)
#             val_loss += loss.item()

#             _, val_predicted = torch.max(val_outputs, 1)
#             val_correct += (val_predicted == val_labels).sum().item()
#             val_total += val_labels.size(0)
    
#     val_accuracy = val_correct / val_total
#     avg_val_loss = val_loss / len(test_loader)
#     # accuracy = correct / len(train_loader.dataset)
#     print(f"Epoch [{epoch+1}/{epochs}]")
#     print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
#     print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
#     print("-" * 50)

# %% [markdown]
# With Precision, recall and f1-score

# %%
epochs = 1500
for epoch in range(epochs):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    # Training loop
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)
    
    train_accuracy = correct / total
    avg_train_loss = running_loss / len(train_loader)

    # Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for val_inputs, val_labels in test_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()
            _, val_predicted = torch.max(val_outputs, 1)

            val_correct += (val_predicted == val_labels).sum().item()
            val_total += val_labels.size(0)

            # Store predictions and labels for evaluation
            all_preds.extend(val_predicted.cpu().numpy())
            all_labels.extend(val_labels.cpu().numpy())

    val_accuracy = val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)

    # Compute Precision, Recall, F1-score
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted',zero_division=1)

    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}")
    print("-" * 50)
# Out:
# Epoch [1/1500]
# Train Loss: 1.9647, Train Acc: 0.2084
# Val Loss: 1.9019, Val Acc: 0.2242
# Precision: 0.3752, Recall: 0.2242, F1-score: 0.1683
# --------------------------------------------------
# Epoch [2/1500]
# Train Loss: 1.8628, Train Acc: 0.2642
# Val Loss: 1.8107, Val Acc: 0.2822
# Precision: 0.3598, Recall: 0.2822, F1-score: 0.2326
# --------------------------------------------------
# Epoch [3/1500]
# Train Loss: 1.8026, Train Acc: 0.2786
# Val Loss: 1.7798, Val Acc: 0.2968
# Precision: 0.3791, Recall: 0.2968, F1-score: 0.2683
# --------------------------------------------------
# Epoch [4/1500]
# Train Loss: 1.7620, Train Acc: 0.3009
# Val Loss: 1.7165, Val Acc: 0.3204
# Precision: 0.3749, Recall: 0.3204, F1-score: 0.2820
# --------------------------------------------------
# Epoch [5/1500]
# Train Loss: 1.7373, Train Acc: 0.3209
# Val Loss: 1.6838, Val Acc: 0.3459
# Precision: 0.4247, Recall: 0.3459, F1-score: 0.3176
# --------------------------------------------------
# Epoch [6/1500]
# Train Loss: 1.7062, Train Acc: 0.3361
# Val Loss: 1.6601, Val Acc: 0.3577
# Precision: 0.4193, Recall: 0.3577, F1-score: 0.3367
# --------------------------------------------------
# Epoch [7/1500]
# Train Loss: 1.6729, Train Acc: 0.3537
# Val Loss: 1.6356, Val Acc: 0.3719
# Precision: 0.4363, Recall: 0.3719, F1-score: 0.3526
# --------------------------------------------------
# Epoch [8/1500]
# Train Loss: 1.6414, Train Acc: 0.3692
# Val Loss: 1.6088, Val Acc: 0.3879
# Precision: 0.3758, Recall: 0.3879, F1-score: 0.3640
# --------------------------------------------------
# Epoch [9/1500]
# Train Loss: 1.6329, Train Acc: 0.3721
# Val Loss: 1.5875, Val Acc: 0.4063
# Precision: 0.4068, Recall: 0.4063, F1-score: 0.3852
# --------------------------------------------------
# Epoch [10/1500]
# Train Loss: 1.6046, Train Acc: 0.3896
# Val Loss: 1.5707, Val Acc: 0.4063
# Precision: 0.4064, Recall: 0.4063, F1-score: 0.3852
# --------------------------------------------------
# Epoch [11/1500]
# Train Loss: 1.5907, Train Acc: 0.3982
# Val Loss: 1.5588, Val Acc: 0.4096
# Precision: 0.4136, Recall: 0.4096, F1-score: 0.3863
# --------------------------------------------------
# Epoch [12/1500]
# Train Loss: 1.5730, Train Acc: 0.3994
# Val Loss: 1.5304, Val Acc: 0.4252
# Precision: 0.4240, Recall: 0.4252, F1-score: 0.4070
# --------------------------------------------------
# Epoch [13/1500]
# Train Loss: 1.5586, Train Acc: 0.4077
# Val Loss: 1.5278, Val Acc: 0.4332
# Precision: 0.4405, Recall: 0.4332, F1-score: 0.4282
# --------------------------------------------------
# Epoch [14/1500]
# Train Loss: 1.5374, Train Acc: 0.4184
# Val Loss: 1.5049, Val Acc: 0.4479
# Precision: 0.4471, Recall: 0.4479, F1-score: 0.4374
# --------------------------------------------------
# Epoch [15/1500]
# Train Loss: 1.5305, Train Acc: 0.4230
# Val Loss: 1.5083, Val Acc: 0.4394
# Precision: 0.4502, Recall: 0.4394, F1-score: 0.4233
# --------------------------------------------------
# Epoch [16/1500]
# Train Loss: 1.5016, Train Acc: 0.4396
# Val Loss: 1.4737, Val Acc: 0.4502
# Precision: 0.4632, Recall: 0.4502, F1-score: 0.4493
# --------------------------------------------------
# Epoch [17/1500]
# Train Loss: 1.4870, Train Acc: 0.4395
# Val Loss: 1.4604, Val Acc: 0.4601
# Precision: 0.4610, Recall: 0.4601, F1-score: 0.4464
# --------------------------------------------------
# Epoch [18/1500]
# Train Loss: 1.4916, Train Acc: 0.4298
# Val Loss: 1.4445, Val Acc: 0.4677
# Precision: 0.4713, Recall: 0.4677, F1-score: 0.4583
# --------------------------------------------------
# Epoch [19/1500]
# Train Loss: 1.4637, Train Acc: 0.4436
# Val Loss: 1.4391, Val Acc: 0.4620
# Precision: 0.4728, Recall: 0.4620, F1-score: 0.4549
# --------------------------------------------------
# Epoch [20/1500]
# Train Loss: 1.4495, Train Acc: 0.4515
# Val Loss: 1.4226, Val Acc: 0.4696
# Precision: 0.4700, Recall: 0.4696, F1-score: 0.4606
# --------------------------------------------------
# Epoch [21/1500]
# Train Loss: 1.4411, Train Acc: 0.4535
# Val Loss: 1.4189, Val Acc: 0.4743
# Precision: 0.4762, Recall: 0.4743, F1-score: 0.4628
# --------------------------------------------------
# Epoch [22/1500]
# Train Loss: 1.4484, Train Acc: 0.4505
# Val Loss: 1.3988, Val Acc: 0.4781
# Precision: 0.4779, Recall: 0.4781, F1-score: 0.4679
# --------------------------------------------------
# Epoch [23/1500]
# Train Loss: 1.4204, Train Acc: 0.4652
# Val Loss: 1.3802, Val Acc: 0.4884
# Precision: 0.4874, Recall: 0.4884, F1-score: 0.4780
# --------------------------------------------------
# Epoch [24/1500]
# Train Loss: 1.4111, Train Acc: 0.4694
# Val Loss: 1.3723, Val Acc: 0.4832
# Precision: 0.4880, Recall: 0.4832, F1-score: 0.4731
# --------------------------------------------------
# Epoch [25/1500]
# Train Loss: 1.4024, Train Acc: 0.4759
# Val Loss: 1.3725, Val Acc: 0.4913
# Precision: 0.5059, Recall: 0.4913, F1-score: 0.4813
# --------------------------------------------------
# Epoch [26/1500]
# Train Loss: 1.3989, Train Acc: 0.4750
# Val Loss: 1.3528, Val Acc: 0.4983
# Precision: 0.4983, Recall: 0.4983, F1-score: 0.4949
# --------------------------------------------------
# Epoch [27/1500]
# Train Loss: 1.3880, Train Acc: 0.4832
# Val Loss: 1.3489, Val Acc: 0.4983
# Precision: 0.5047, Recall: 0.4983, F1-score: 0.4937
# --------------------------------------------------
# Epoch [28/1500]
# Train Loss: 1.3710, Train Acc: 0.4846
# Val Loss: 1.3351, Val Acc: 0.5064
# Precision: 0.5101, Recall: 0.5064, F1-score: 0.5017
# --------------------------------------------------
# Epoch [29/1500]
# Train Loss: 1.3671, Train Acc: 0.4894
# Val Loss: 1.3229, Val Acc: 0.4969
# Precision: 0.5059, Recall: 0.4969, F1-score: 0.4907
# --------------------------------------------------
# Epoch [30/1500]
# Train Loss: 1.3552, Train Acc: 0.4898
# Val Loss: 1.3219, Val Acc: 0.5068
# Precision: 0.5139, Recall: 0.5068, F1-score: 0.5025
# --------------------------------------------------
# Epoch [31/1500]
# Train Loss: 1.3443, Train Acc: 0.4993
# Val Loss: 1.3106, Val Acc: 0.5106
# Precision: 0.5142, Recall: 0.5106, F1-score: 0.5071
# --------------------------------------------------
# Epoch [32/1500]
# Train Loss: 1.3333, Train Acc: 0.5056
# Val Loss: 1.3064, Val Acc: 0.4988
# Precision: 0.5106, Recall: 0.4988, F1-score: 0.4951
# --------------------------------------------------
# Epoch [33/1500]
# Train Loss: 1.3168, Train Acc: 0.5074
# Val Loss: 1.2836, Val Acc: 0.5144
# Precision: 0.5249, Recall: 0.5144, F1-score: 0.5103
# --------------------------------------------------
# Epoch [34/1500]
# Train Loss: 1.3105, Train Acc: 0.5064
# Val Loss: 1.2765, Val Acc: 0.5205
# Precision: 0.5363, Recall: 0.5205, F1-score: 0.5100
# --------------------------------------------------
# Epoch [35/1500]
# Train Loss: 1.3065, Train Acc: 0.5093
# Val Loss: 1.2662, Val Acc: 0.5276
# Precision: 0.5288, Recall: 0.5276, F1-score: 0.5246
# --------------------------------------------------
# Epoch [36/1500]
# Train Loss: 1.2924, Train Acc: 0.5200
# Val Loss: 1.2554, Val Acc: 0.5352
# Precision: 0.5399, Recall: 0.5352, F1-score: 0.5264
# --------------------------------------------------
# Epoch [37/1500]
# Train Loss: 1.2851, Train Acc: 0.5160
# Val Loss: 1.2460, Val Acc: 0.5380
# Precision: 0.5407, Recall: 0.5380, F1-score: 0.5348
# --------------------------------------------------
# Epoch [38/1500]
# Train Loss: 1.2840, Train Acc: 0.5184
# Val Loss: 1.2361, Val Acc: 0.5432
# Precision: 0.5453, Recall: 0.5432, F1-score: 0.5388
# --------------------------------------------------
# Epoch [39/1500]
# Train Loss: 1.2772, Train Acc: 0.5185
# Val Loss: 1.2278, Val Acc: 0.5394
# Precision: 0.5391, Recall: 0.5394, F1-score: 0.5372
# --------------------------------------------------
# Epoch [40/1500]
# Train Loss: 1.2679, Train Acc: 0.5232
# Val Loss: 1.2292, Val Acc: 0.5403
# Precision: 0.5451, Recall: 0.5403, F1-score: 0.5373
# --------------------------------------------------
# Epoch [41/1500]
# Train Loss: 1.2544, Train Acc: 0.5314
# Val Loss: 1.2230, Val Acc: 0.5328
# Precision: 0.5360, Recall: 0.5328, F1-score: 0.5297
# --------------------------------------------------
# Epoch [42/1500]
# Train Loss: 1.2402, Train Acc: 0.5348
# Val Loss: 1.2037, Val Acc: 0.5403
# Precision: 0.5474, Recall: 0.5403, F1-score: 0.5389
# --------------------------------------------------
# Epoch [43/1500]
# Train Loss: 1.2438, Train Acc: 0.5318
# Val Loss: 1.1981, Val Acc: 0.5446
# Precision: 0.5482, Recall: 0.5446, F1-score: 0.5400
# --------------------------------------------------
# Epoch [44/1500]
# Train Loss: 1.2342, Train Acc: 0.5402
# Val Loss: 1.2024, Val Acc: 0.5460
# Precision: 0.5505, Recall: 0.5460, F1-score: 0.5429
# --------------------------------------------------
# Epoch [45/1500]
# Train Loss: 1.2401, Train Acc: 0.5373
# Val Loss: 1.1812, Val Acc: 0.5588
# Precision: 0.5598, Recall: 0.5588, F1-score: 0.5538
# --------------------------------------------------
# Epoch [46/1500]
# Train Loss: 1.2052, Train Acc: 0.5482
# Val Loss: 1.1944, Val Acc: 0.5512
# Precision: 0.5586, Recall: 0.5512, F1-score: 0.5488
# --------------------------------------------------
# Epoch [47/1500]
# Train Loss: 1.2052, Train Acc: 0.5476
# Val Loss: 1.1740, Val Acc: 0.5588
# Precision: 0.5588, Recall: 0.5588, F1-score: 0.5554
# --------------------------------------------------
# Epoch [48/1500]
# Train Loss: 1.1872, Train Acc: 0.5545
# Val Loss: 1.1636, Val Acc: 0.5672
# Precision: 0.5677, Recall: 0.5672, F1-score: 0.5649
# --------------------------------------------------
# Epoch [49/1500]
# Train Loss: 1.1997, Train Acc: 0.5489
# Val Loss: 1.1676, Val Acc: 0.5635
# Precision: 0.5661, Recall: 0.5635, F1-score: 0.5584
# --------------------------------------------------
# Epoch [50/1500]
# Train Loss: 1.1926, Train Acc: 0.5475
# Val Loss: 1.1523, Val Acc: 0.5621
# Precision: 0.5636, Recall: 0.5621, F1-score: 0.5623
# --------------------------------------------------
# Epoch [51/1500]
# Train Loss: 1.1725, Train Acc: 0.5625
# Val Loss: 1.1631, Val Acc: 0.5710
# Precision: 0.5806, Recall: 0.5710, F1-score: 0.5687
# --------------------------------------------------
# Epoch [52/1500]
# Train Loss: 1.1551, Train Acc: 0.5708
# Val Loss: 1.1497, Val Acc: 0.5729
# Precision: 0.5824, Recall: 0.5729, F1-score: 0.5688
# --------------------------------------------------
# Epoch [53/1500]
# Train Loss: 1.1691, Train Acc: 0.5629
# Val Loss: 1.1407, Val Acc: 0.5729
# Precision: 0.5742, Recall: 0.5729, F1-score: 0.5703
# --------------------------------------------------
# Epoch [54/1500]
# Train Loss: 1.1510, Train Acc: 0.5715
# Val Loss: 1.1362, Val Acc: 0.5734
# Precision: 0.5822, Recall: 0.5734, F1-score: 0.5715
# --------------------------------------------------
# Epoch [55/1500]
# Train Loss: 1.1554, Train Acc: 0.5721
# Val Loss: 1.1384, Val Acc: 0.5706
# Precision: 0.5823, Recall: 0.5706, F1-score: 0.5645
# --------------------------------------------------
# Epoch [56/1500]
# Train Loss: 1.1492, Train Acc: 0.5704
# Val Loss: 1.1398, Val Acc: 0.5677
# Precision: 0.5832, Recall: 0.5677, F1-score: 0.5669
# --------------------------------------------------
# Epoch [57/1500]
# Train Loss: 1.1437, Train Acc: 0.5753
# Val Loss: 1.1498, Val Acc: 0.5706
# Precision: 0.5841, Recall: 0.5706, F1-score: 0.5716
# --------------------------------------------------
# Epoch [58/1500]
# Train Loss: 1.1345, Train Acc: 0.5735
# Val Loss: 1.1236, Val Acc: 0.5781
# Precision: 0.5871, Recall: 0.5781, F1-score: 0.5738
# --------------------------------------------------
# Epoch [59/1500]
# Train Loss: 1.1228, Train Acc: 0.5838
# Val Loss: 1.1162, Val Acc: 0.5762
# Precision: 0.5819, Recall: 0.5762, F1-score: 0.5725
# --------------------------------------------------
# Epoch [60/1500]
# Train Loss: 1.1147, Train Acc: 0.5836
# Val Loss: 1.1052, Val Acc: 0.5890
# Precision: 0.5959, Recall: 0.5890, F1-score: 0.5852
# --------------------------------------------------
# Epoch [61/1500]
# Train Loss: 1.1072, Train Acc: 0.5902
# Val Loss: 1.1050, Val Acc: 0.5894
# Precision: 0.6011, Recall: 0.5894, F1-score: 0.5864
# --------------------------------------------------
# Epoch [62/1500]
# Train Loss: 1.0938, Train Acc: 0.5943
# Val Loss: 1.0884, Val Acc: 0.5970
# Precision: 0.6015, Recall: 0.5970, F1-score: 0.5968
# --------------------------------------------------
# Epoch [63/1500]
# Train Loss: 1.1076, Train Acc: 0.5870
# Val Loss: 1.0833, Val Acc: 0.6012
# Precision: 0.6030, Recall: 0.6012, F1-score: 0.5978
# --------------------------------------------------
# Epoch [64/1500]
# Train Loss: 1.0903, Train Acc: 0.5947
# Val Loss: 1.0847, Val Acc: 0.5937
# Precision: 0.6003, Recall: 0.5937, F1-score: 0.5896
# --------------------------------------------------
# Epoch [65/1500]
# Train Loss: 1.0887, Train Acc: 0.5882
# Val Loss: 1.0862, Val Acc: 0.5989
# Precision: 0.6021, Recall: 0.5989, F1-score: 0.5956
# --------------------------------------------------
# Epoch [66/1500]
# Train Loss: 1.0812, Train Acc: 0.5940
# Val Loss: 1.0909, Val Acc: 0.5965
# Precision: 0.6031, Recall: 0.5965, F1-score: 0.5952
# --------------------------------------------------
# Epoch [67/1500]
# Train Loss: 1.0788, Train Acc: 0.5998
# Val Loss: 1.0640, Val Acc: 0.6026
# Precision: 0.6041, Recall: 0.6026, F1-score: 0.5981
# --------------------------------------------------
# Epoch [68/1500]
# Train Loss: 1.0715, Train Acc: 0.6029
# Val Loss: 1.0642, Val Acc: 0.5975
# Precision: 0.6035, Recall: 0.5975, F1-score: 0.5948
# --------------------------------------------------
# Epoch [69/1500]
# Train Loss: 1.0657, Train Acc: 0.6065
# Val Loss: 1.0448, Val Acc: 0.6126
# Precision: 0.6145, Recall: 0.6126, F1-score: 0.6073
# --------------------------------------------------
# Epoch [70/1500]
# Train Loss: 1.0582, Train Acc: 0.6057
# Val Loss: 1.0559, Val Acc: 0.6083
# Precision: 0.6146, Recall: 0.6083, F1-score: 0.6062
# --------------------------------------------------
# Epoch [71/1500]
# Train Loss: 1.0470, Train Acc: 0.6056
# Val Loss: 1.0367, Val Acc: 0.6088
# Precision: 0.6136, Recall: 0.6088, F1-score: 0.6071
# --------------------------------------------------
# Epoch [72/1500]
# Train Loss: 1.0509, Train Acc: 0.6113
# Val Loss: 1.0592, Val Acc: 0.6069
# Precision: 0.6115, Recall: 0.6069, F1-score: 0.6053
# --------------------------------------------------
# Epoch [73/1500]
# Train Loss: 1.0395, Train Acc: 0.6135
# Val Loss: 1.0417, Val Acc: 0.6135
# Precision: 0.6207, Recall: 0.6135, F1-score: 0.6128
# --------------------------------------------------
# Epoch [74/1500]
# Train Loss: 1.0428, Train Acc: 0.6135
# Val Loss: 1.0409, Val Acc: 0.6130
# Precision: 0.6210, Recall: 0.6130, F1-score: 0.6090
# --------------------------------------------------
# Epoch [75/1500]
# Train Loss: 1.0312, Train Acc: 0.6123
# Val Loss: 1.0335, Val Acc: 0.6192
# Precision: 0.6312, Recall: 0.6192, F1-score: 0.6168
# --------------------------------------------------
# Epoch [76/1500]
# Train Loss: 1.0190, Train Acc: 0.6235
# Val Loss: 1.0291, Val Acc: 0.6126
# Precision: 0.6242, Recall: 0.6126, F1-score: 0.6094
# --------------------------------------------------
# Epoch [77/1500]
# Train Loss: 1.0281, Train Acc: 0.6105
# Val Loss: 1.0300, Val Acc: 0.6102
# Precision: 0.6129, Recall: 0.6102, F1-score: 0.6072
# --------------------------------------------------
# Epoch [78/1500]
# Train Loss: 1.0192, Train Acc: 0.6249
# Val Loss: 1.0186, Val Acc: 0.6210
# Precision: 0.6255, Recall: 0.6210, F1-score: 0.6177
# --------------------------------------------------
# Epoch [79/1500]
# Train Loss: 1.0073, Train Acc: 0.6224
# Val Loss: 1.0173, Val Acc: 0.6206
# Precision: 0.6287, Recall: 0.6206, F1-score: 0.6192
# --------------------------------------------------
# Epoch [80/1500]
# Train Loss: 1.0064, Train Acc: 0.6266
# Val Loss: 1.0096, Val Acc: 0.6258
# Precision: 0.6357, Recall: 0.6258, F1-score: 0.6240
# --------------------------------------------------
# Epoch [81/1500]
# Train Loss: 0.9937, Train Acc: 0.6342
# Val Loss: 0.9964, Val Acc: 0.6338
# Precision: 0.6374, Recall: 0.6338, F1-score: 0.6289
# --------------------------------------------------
# Epoch [82/1500]
# Train Loss: 0.9970, Train Acc: 0.6276
# Val Loss: 1.0067, Val Acc: 0.6168
# Precision: 0.6278, Recall: 0.6168, F1-score: 0.6126
# --------------------------------------------------
# Epoch [83/1500]
# Train Loss: 1.0002, Train Acc: 0.6253
# Val Loss: 1.0040, Val Acc: 0.6173
# Precision: 0.6265, Recall: 0.6173, F1-score: 0.6173
# --------------------------------------------------
# Epoch [84/1500]
# Train Loss: 0.9832, Train Acc: 0.6359
# Val Loss: 0.9900, Val Acc: 0.6380
# Precision: 0.6438, Recall: 0.6380, F1-score: 0.6366
# --------------------------------------------------
# Epoch [85/1500]
# Train Loss: 0.9790, Train Acc: 0.6353
# Val Loss: 0.9898, Val Acc: 0.6272
# Precision: 0.6286, Recall: 0.6272, F1-score: 0.6241
# --------------------------------------------------
# Epoch [86/1500]
# Train Loss: 0.9819, Train Acc: 0.6370
# Val Loss: 0.9876, Val Acc: 0.6376
# Precision: 0.6426, Recall: 0.6376, F1-score: 0.6341
# --------------------------------------------------
# Epoch [87/1500]
# Train Loss: 0.9638, Train Acc: 0.6383
# Val Loss: 0.9807, Val Acc: 0.6286
# Precision: 0.6346, Recall: 0.6286, F1-score: 0.6252
# --------------------------------------------------
# Epoch [88/1500]
# Train Loss: 0.9633, Train Acc: 0.6428
# Val Loss: 0.9747, Val Acc: 0.6361
# Precision: 0.6378, Recall: 0.6361, F1-score: 0.6351
# --------------------------------------------------
# Epoch [89/1500]
# Train Loss: 0.9612, Train Acc: 0.6450
# Val Loss: 0.9672, Val Acc: 0.6300
# Precision: 0.6342, Recall: 0.6300, F1-score: 0.6287
# --------------------------------------------------
# Epoch [90/1500]
# Train Loss: 0.9581, Train Acc: 0.6433
# Val Loss: 0.9825, Val Acc: 0.6428
# Precision: 0.6438, Recall: 0.6428, F1-score: 0.6401
# --------------------------------------------------
# Epoch [91/1500]
# Train Loss: 0.9486, Train Acc: 0.6523
# Val Loss: 0.9549, Val Acc: 0.6413
# Precision: 0.6451, Recall: 0.6413, F1-score: 0.6382
# --------------------------------------------------
# Epoch [92/1500]
# Train Loss: 0.9407, Train Acc: 0.6537
# Val Loss: 0.9602, Val Acc: 0.6404
# Precision: 0.6400, Recall: 0.6404, F1-score: 0.6377
# --------------------------------------------------
# Epoch [93/1500]
# Train Loss: 0.9371, Train Acc: 0.6505
# Val Loss: 0.9526, Val Acc: 0.6432
# Precision: 0.6458, Recall: 0.6432, F1-score: 0.6422
# --------------------------------------------------
# Epoch [94/1500]
# Train Loss: 0.9245, Train Acc: 0.6560
# Val Loss: 0.9471, Val Acc: 0.6357
# Precision: 0.6357, Recall: 0.6357, F1-score: 0.6324
# --------------------------------------------------
# Epoch [95/1500]
# Train Loss: 0.9297, Train Acc: 0.6529
# Val Loss: 0.9620, Val Acc: 0.6352
# Precision: 0.6361, Recall: 0.6352, F1-score: 0.6315
# --------------------------------------------------
# Epoch [96/1500]
# Train Loss: 0.9226, Train Acc: 0.6594
# Val Loss: 0.9560, Val Acc: 0.6494
# Precision: 0.6507, Recall: 0.6494, F1-score: 0.6462
# --------------------------------------------------
# Epoch [97/1500]
# Train Loss: 0.9238, Train Acc: 0.6552
# Val Loss: 0.9492, Val Acc: 0.6470
# Precision: 0.6544, Recall: 0.6470, F1-score: 0.6458
# --------------------------------------------------
# Epoch [98/1500]
# Train Loss: 0.9265, Train Acc: 0.6549
# Val Loss: 0.9589, Val Acc: 0.6494
# Precision: 0.6558, Recall: 0.6494, F1-score: 0.6486
# --------------------------------------------------
# Epoch [99/1500]
# Train Loss: 0.9156, Train Acc: 0.6616
# Val Loss: 0.9419, Val Acc: 0.6564
# Precision: 0.6636, Recall: 0.6564, F1-score: 0.6564
# --------------------------------------------------
# Epoch [100/1500]
# Train Loss: 0.9121, Train Acc: 0.6551
# Val Loss: 0.9560, Val Acc: 0.6380
# Precision: 0.6470, Recall: 0.6380, F1-score: 0.6361
# --------------------------------------------------
# Epoch [101/1500]
# Train Loss: 0.9081, Train Acc: 0.6609
# Val Loss: 0.9272, Val Acc: 0.6479
# Precision: 0.6496, Recall: 0.6479, F1-score: 0.6452
# --------------------------------------------------
# Epoch [102/1500]
# Train Loss: 0.9003, Train Acc: 0.6655
# Val Loss: 0.9464, Val Acc: 0.6503
# Precision: 0.6622, Recall: 0.6503, F1-score: 0.6508
# --------------------------------------------------
# Epoch [103/1500]
# Train Loss: 0.8899, Train Acc: 0.6762
# Val Loss: 0.9392, Val Acc: 0.6461
# Precision: 0.6525, Recall: 0.6461, F1-score: 0.6433
# --------------------------------------------------
# Epoch [104/1500]
# Train Loss: 0.8937, Train Acc: 0.6741
# Val Loss: 0.9200, Val Acc: 0.6550
# Precision: 0.6582, Recall: 0.6550, F1-score: 0.6526
# --------------------------------------------------
# Epoch [105/1500]
# Train Loss: 0.8991, Train Acc: 0.6710
# Val Loss: 0.9371, Val Acc: 0.6513
# Precision: 0.6592, Recall: 0.6513, F1-score: 0.6488
# --------------------------------------------------
# Epoch [106/1500]
# Train Loss: 0.8756, Train Acc: 0.6788
# Val Loss: 0.9485, Val Acc: 0.6432
# Precision: 0.6522, Recall: 0.6432, F1-score: 0.6433
# --------------------------------------------------
# Epoch [107/1500]
# Train Loss: 0.8717, Train Acc: 0.6794
# Val Loss: 0.9378, Val Acc: 0.6451
# Precision: 0.6569, Recall: 0.6451, F1-score: 0.6434
# --------------------------------------------------
# Epoch [108/1500]
# Train Loss: 0.8858, Train Acc: 0.6734
# Val Loss: 0.9184, Val Acc: 0.6546
# Precision: 0.6590, Recall: 0.6546, F1-score: 0.6538
# --------------------------------------------------
# Epoch [109/1500]
# Train Loss: 0.8750, Train Acc: 0.6758
# Val Loss: 0.9220, Val Acc: 0.6527
# Precision: 0.6591, Recall: 0.6527, F1-score: 0.6517
# --------------------------------------------------
# Epoch [110/1500]
# Train Loss: 0.8622, Train Acc: 0.6816
# Val Loss: 0.9081, Val Acc: 0.6564
# Precision: 0.6596, Recall: 0.6564, F1-score: 0.6538
# --------------------------------------------------
# Epoch [111/1500]
# Train Loss: 0.8812, Train Acc: 0.6833
# Val Loss: 0.9167, Val Acc: 0.6593
# Precision: 0.6655, Recall: 0.6593, F1-score: 0.6588
# --------------------------------------------------
# Epoch [112/1500]
# Train Loss: 0.8678, Train Acc: 0.6802
# Val Loss: 0.9127, Val Acc: 0.6640
# Precision: 0.6699, Recall: 0.6640, F1-score: 0.6625
# --------------------------------------------------
# Epoch [113/1500]
# Train Loss: 0.8587, Train Acc: 0.6828
# Val Loss: 0.8958, Val Acc: 0.6626
# Precision: 0.6640, Recall: 0.6626, F1-score: 0.6605
# --------------------------------------------------
# Epoch [114/1500]
# Train Loss: 0.8564, Train Acc: 0.6789
# Val Loss: 0.9075, Val Acc: 0.6555
# Precision: 0.6621, Recall: 0.6555, F1-score: 0.6552
# --------------------------------------------------
# Epoch [115/1500]
# Train Loss: 0.8566, Train Acc: 0.6814
# Val Loss: 0.8940, Val Acc: 0.6692
# Precision: 0.6700, Recall: 0.6692, F1-score: 0.6673
# --------------------------------------------------
# Epoch [116/1500]
# Train Loss: 0.8542, Train Acc: 0.6844
# Val Loss: 0.8862, Val Acc: 0.6706
# Precision: 0.6705, Recall: 0.6706, F1-score: 0.6692
# --------------------------------------------------
# Epoch [117/1500]
# Train Loss: 0.8389, Train Acc: 0.6881
# Val Loss: 0.8960, Val Acc: 0.6659
# Precision: 0.6707, Recall: 0.6659, F1-score: 0.6642
# --------------------------------------------------
# Epoch [118/1500]
# Train Loss: 0.8390, Train Acc: 0.6889
# Val Loss: 0.9052, Val Acc: 0.6659
# Precision: 0.6724, Recall: 0.6659, F1-score: 0.6668
# --------------------------------------------------
# Epoch [119/1500]
# Train Loss: 0.8578, Train Acc: 0.6850
# Val Loss: 0.9084, Val Acc: 0.6616
# Precision: 0.6663, Recall: 0.6616, F1-score: 0.6586
# --------------------------------------------------
# Epoch [120/1500]
# Train Loss: 0.8288, Train Acc: 0.6925
# Val Loss: 0.8971, Val Acc: 0.6659
# Precision: 0.6716, Recall: 0.6659, F1-score: 0.6643
# --------------------------------------------------
# Epoch [121/1500]
# Train Loss: 0.8379, Train Acc: 0.6862
# Val Loss: 0.8832, Val Acc: 0.6739
# Precision: 0.6779, Recall: 0.6739, F1-score: 0.6716
# --------------------------------------------------
# Epoch [122/1500]
# Train Loss: 0.8237, Train Acc: 0.6980
# Val Loss: 0.8603, Val Acc: 0.6744
# Precision: 0.6761, Recall: 0.6744, F1-score: 0.6741
# --------------------------------------------------
# Epoch [123/1500]
# Train Loss: 0.8314, Train Acc: 0.6893
# Val Loss: 0.8848, Val Acc: 0.6720
# Precision: 0.6745, Recall: 0.6720, F1-score: 0.6706
# --------------------------------------------------
# Epoch [124/1500]
# Train Loss: 0.8135, Train Acc: 0.6977
# Val Loss: 0.8746, Val Acc: 0.6791
# Precision: 0.6837, Recall: 0.6791, F1-score: 0.6778
# --------------------------------------------------
# Epoch [125/1500]
# Train Loss: 0.8135, Train Acc: 0.7034
# Val Loss: 0.8661, Val Acc: 0.6810
# Precision: 0.6826, Recall: 0.6810, F1-score: 0.6796
# --------------------------------------------------
# Epoch [126/1500]
# Train Loss: 0.8124, Train Acc: 0.7016
# Val Loss: 0.8870, Val Acc: 0.6687
# Precision: 0.6803, Recall: 0.6687, F1-score: 0.6691
# --------------------------------------------------
# Epoch [127/1500]
# Train Loss: 0.8089, Train Acc: 0.7041
# Val Loss: 0.8685, Val Acc: 0.6739
# Precision: 0.6750, Recall: 0.6739, F1-score: 0.6714
# --------------------------------------------------
# Epoch [128/1500]
# Train Loss: 0.8037, Train Acc: 0.7056
# Val Loss: 0.8662, Val Acc: 0.6819
# Precision: 0.6870, Recall: 0.6819, F1-score: 0.6817
# --------------------------------------------------
# Epoch [129/1500]
# Train Loss: 0.8061, Train Acc: 0.7096
# Val Loss: 0.8629, Val Acc: 0.6767
# Precision: 0.6795, Recall: 0.6767, F1-score: 0.6766
# --------------------------------------------------
# Epoch [130/1500]
# Train Loss: 0.8017, Train Acc: 0.7063
# Val Loss: 0.8476, Val Acc: 0.6857
# Precision: 0.6856, Recall: 0.6857, F1-score: 0.6840
# --------------------------------------------------
# Epoch [131/1500]
# Train Loss: 0.8011, Train Acc: 0.7080
# Val Loss: 0.8722, Val Acc: 0.6730
# Precision: 0.6833, Recall: 0.6730, F1-score: 0.6709
# --------------------------------------------------
# Epoch [132/1500]
# Train Loss: 0.7918, Train Acc: 0.7102
# Val Loss: 0.8513, Val Acc: 0.6843
# Precision: 0.6865, Recall: 0.6843, F1-score: 0.6827
# --------------------------------------------------
# Epoch [133/1500]
# Train Loss: 0.7883, Train Acc: 0.7086
# Val Loss: 0.8683, Val Acc: 0.6730
# Precision: 0.6824, Recall: 0.6730, F1-score: 0.6723
# --------------------------------------------------
# Epoch [134/1500]
# Train Loss: 0.7845, Train Acc: 0.7130
# Val Loss: 0.8722, Val Acc: 0.6744
# Precision: 0.6827, Recall: 0.6744, F1-score: 0.6738
# --------------------------------------------------
# Epoch [135/1500]
# Train Loss: 0.7920, Train Acc: 0.7105
# Val Loss: 0.8458, Val Acc: 0.6843
# Precision: 0.6900, Recall: 0.6843, F1-score: 0.6842
# --------------------------------------------------
# Epoch [136/1500]
# Train Loss: 0.7733, Train Acc: 0.7217
# Val Loss: 0.8443, Val Acc: 0.6782
# Precision: 0.6850, Recall: 0.6782, F1-score: 0.6776
# --------------------------------------------------
# Epoch [137/1500]
# Train Loss: 0.7795, Train Acc: 0.7143
# Val Loss: 0.8556, Val Acc: 0.6767
# Precision: 0.6823, Recall: 0.6767, F1-score: 0.6753
# --------------------------------------------------
# Epoch [138/1500]
# Train Loss: 0.7805, Train Acc: 0.7124
# Val Loss: 0.8458, Val Acc: 0.6890
# Precision: 0.6979, Recall: 0.6890, F1-score: 0.6867
# --------------------------------------------------
# Epoch [139/1500]
# Train Loss: 0.7817, Train Acc: 0.7127
# Val Loss: 0.8375, Val Acc: 0.6805
# Precision: 0.6868, Recall: 0.6805, F1-score: 0.6799
# --------------------------------------------------
# Epoch [140/1500]
# Train Loss: 0.7664, Train Acc: 0.7125
# Val Loss: 0.8783, Val Acc: 0.6763
# Precision: 0.6929, Recall: 0.6763, F1-score: 0.6782
# --------------------------------------------------
# Epoch [141/1500]
# Train Loss: 0.7590, Train Acc: 0.7186
# Val Loss: 0.8525, Val Acc: 0.6829
# Precision: 0.6900, Recall: 0.6829, F1-score: 0.6824
# --------------------------------------------------
# Epoch [142/1500]
# Train Loss: 0.7620, Train Acc: 0.7151
# Val Loss: 0.8453, Val Acc: 0.6833
# Precision: 0.6890, Recall: 0.6833, F1-score: 0.6823
# --------------------------------------------------
# Epoch [143/1500]
# Train Loss: 0.7514, Train Acc: 0.7260
# Val Loss: 0.8729, Val Acc: 0.6758
# Precision: 0.6875, Recall: 0.6758, F1-score: 0.6764
# --------------------------------------------------
# Epoch [144/1500]
# Train Loss: 0.7407, Train Acc: 0.7236
# Val Loss: 0.8198, Val Acc: 0.6947
# Precision: 0.6962, Recall: 0.6947, F1-score: 0.6930
# --------------------------------------------------
# Epoch [145/1500]
# Train Loss: 0.7592, Train Acc: 0.7232
# Val Loss: 0.8536, Val Acc: 0.6871
# Precision: 0.6967, Recall: 0.6871, F1-score: 0.6873
# --------------------------------------------------
# Epoch [146/1500]
# Train Loss: 0.7462, Train Acc: 0.7203
# Val Loss: 0.8500, Val Acc: 0.6810
# Precision: 0.6924, Recall: 0.6810, F1-score: 0.6806
# --------------------------------------------------
# Epoch [147/1500]
# Train Loss: 0.7515, Train Acc: 0.7264
# Val Loss: 0.8554, Val Acc: 0.6796
# Precision: 0.6862, Recall: 0.6796, F1-score: 0.6789
# --------------------------------------------------
# Epoch [148/1500]
# Train Loss: 0.7370, Train Acc: 0.7222
# Val Loss: 0.8393, Val Acc: 0.6838
# Precision: 0.6914, Recall: 0.6838, F1-score: 0.6827
# --------------------------------------------------
# Epoch [149/1500]
# Train Loss: 0.7494, Train Acc: 0.7265
# Val Loss: 0.8343, Val Acc: 0.6899
# Precision: 0.6993, Recall: 0.6899, F1-score: 0.6899
# --------------------------------------------------
# Epoch [150/1500]
# Train Loss: 0.7449, Train Acc: 0.7232
# Val Loss: 0.8369, Val Acc: 0.6881
# Precision: 0.6970, Recall: 0.6881, F1-score: 0.6870
# --------------------------------------------------
# Epoch [151/1500]
# Train Loss: 0.7431, Train Acc: 0.7277
# Val Loss: 0.8211, Val Acc: 0.6928
# Precision: 0.6990, Recall: 0.6928, F1-score: 0.6931
# --------------------------------------------------
# Epoch [152/1500]
# Train Loss: 0.7264, Train Acc: 0.7329
# Val Loss: 0.8061, Val Acc: 0.7032
# Precision: 0.7064, Recall: 0.7032, F1-score: 0.7021
# --------------------------------------------------
# Epoch [153/1500]
# Train Loss: 0.7388, Train Acc: 0.7264
# Val Loss: 0.8244, Val Acc: 0.6961
# Precision: 0.7033, Recall: 0.6961, F1-score: 0.6959
# --------------------------------------------------
# Epoch [154/1500]
# Train Loss: 0.7263, Train Acc: 0.7312
# Val Loss: 0.8254, Val Acc: 0.7022
# Precision: 0.7068, Recall: 0.7022, F1-score: 0.7009
# --------------------------------------------------
# Epoch [155/1500]
# Train Loss: 0.7268, Train Acc: 0.7272
# Val Loss: 0.8148, Val Acc: 0.7041
# Precision: 0.7127, Recall: 0.7041, F1-score: 0.7035
# --------------------------------------------------
# Epoch [156/1500]
# Train Loss: 0.7341, Train Acc: 0.7297
# Val Loss: 0.8465, Val Acc: 0.6909
# Precision: 0.7013, Recall: 0.6909, F1-score: 0.6913
# --------------------------------------------------
# Epoch [157/1500]
# Train Loss: 0.7124, Train Acc: 0.7336
# Val Loss: 0.8088, Val Acc: 0.7046
# Precision: 0.7136, Recall: 0.7046, F1-score: 0.7054
# --------------------------------------------------
# Epoch [158/1500]
# Train Loss: 0.7108, Train Acc: 0.7380
# Val Loss: 0.8424, Val Acc: 0.6881
# Precision: 0.6987, Recall: 0.6881, F1-score: 0.6875
# --------------------------------------------------
# Epoch [159/1500]
# Train Loss: 0.7225, Train Acc: 0.7333
# Val Loss: 0.8301, Val Acc: 0.6937
# Precision: 0.7002, Recall: 0.6937, F1-score: 0.6921
# --------------------------------------------------
# Epoch [160/1500]
# Train Loss: 0.7110, Train Acc: 0.7338
# Val Loss: 0.7968, Val Acc: 0.7069
# Precision: 0.7131, Recall: 0.7069, F1-score: 0.7068
# --------------------------------------------------
# Epoch [161/1500]
# Train Loss: 0.7022, Train Acc: 0.7412
# Val Loss: 0.8177, Val Acc: 0.6956
# Precision: 0.7029, Recall: 0.6956, F1-score: 0.6949
# --------------------------------------------------
# Epoch [162/1500]
# Train Loss: 0.6881, Train Acc: 0.7479
# Val Loss: 0.8206, Val Acc: 0.7046
# Precision: 0.7111, Recall: 0.7046, F1-score: 0.7052
# --------------------------------------------------
# Epoch [163/1500]
# Train Loss: 0.7025, Train Acc: 0.7463
# Val Loss: 0.8065, Val Acc: 0.6937
# Precision: 0.6993, Recall: 0.6937, F1-score: 0.6921
# --------------------------------------------------
# Epoch [164/1500]
# Train Loss: 0.6934, Train Acc: 0.7429
# Val Loss: 0.8138, Val Acc: 0.7008
# Precision: 0.7016, Recall: 0.7008, F1-score: 0.6973
# --------------------------------------------------
# Epoch [165/1500]
# Train Loss: 0.6839, Train Acc: 0.7478
# Val Loss: 0.8169, Val Acc: 0.7032
# Precision: 0.7080, Recall: 0.7032, F1-score: 0.7010
# --------------------------------------------------
# Epoch [166/1500]
# Train Loss: 0.6942, Train Acc: 0.7461
# Val Loss: 0.8087, Val Acc: 0.7027
# Precision: 0.7041, Recall: 0.7027, F1-score: 0.7010
# --------------------------------------------------
# Epoch [167/1500]
# Train Loss: 0.7015, Train Acc: 0.7455
# Val Loss: 0.8161, Val Acc: 0.7036
# Precision: 0.7110, Recall: 0.7036, F1-score: 0.7029
# --------------------------------------------------
# Epoch [168/1500]
# Train Loss: 0.6900, Train Acc: 0.7454
# Val Loss: 0.8070, Val Acc: 0.7017
# Precision: 0.7009, Recall: 0.7017, F1-score: 0.7004
# --------------------------------------------------
# Epoch [169/1500]
# Train Loss: 0.6932, Train Acc: 0.7537
# Val Loss: 0.8063, Val Acc: 0.6947
# Precision: 0.6964, Recall: 0.6947, F1-score: 0.6931
# --------------------------------------------------
# Epoch [170/1500]
# Train Loss: 0.6844, Train Acc: 0.7490
# Val Loss: 0.8087, Val Acc: 0.7022
# Precision: 0.7092, Recall: 0.7022, F1-score: 0.6995
# --------------------------------------------------
# Epoch [171/1500]
# Train Loss: 0.6773, Train Acc: 0.7549
# Val Loss: 0.8002, Val Acc: 0.7013
# Precision: 0.7074, Recall: 0.7013, F1-score: 0.7008
# --------------------------------------------------
# Epoch [172/1500]
# Train Loss: 0.6886, Train Acc: 0.7490
# Val Loss: 0.7851, Val Acc: 0.7098
# Precision: 0.7158, Recall: 0.7098, F1-score: 0.7094
# --------------------------------------------------
# Epoch [173/1500]
# Train Loss: 0.6818, Train Acc: 0.7522
# Val Loss: 0.7897, Val Acc: 0.7032
# Precision: 0.7106, Recall: 0.7032, F1-score: 0.7047
# --------------------------------------------------
# Epoch [174/1500]
# Train Loss: 0.6715, Train Acc: 0.7554
# Val Loss: 0.7830, Val Acc: 0.7060
# Precision: 0.7115, Recall: 0.7060, F1-score: 0.7060
# --------------------------------------------------
# Epoch [175/1500]
# Train Loss: 0.6881, Train Acc: 0.7391
# Val Loss: 0.8064, Val Acc: 0.7041
# Precision: 0.7122, Recall: 0.7041, F1-score: 0.7040
# --------------------------------------------------
# Epoch [176/1500]
# Train Loss: 0.6706, Train Acc: 0.7562
# Val Loss: 0.7949, Val Acc: 0.7093
# Precision: 0.7165, Recall: 0.7093, F1-score: 0.7095
# --------------------------------------------------
# Epoch [177/1500]
# Train Loss: 0.6695, Train Acc: 0.7509
# Val Loss: 0.8038, Val Acc: 0.7088
# Precision: 0.7145, Recall: 0.7088, F1-score: 0.7088
# --------------------------------------------------
# Epoch [178/1500]
# Train Loss: 0.6592, Train Acc: 0.7628
# Val Loss: 0.7744, Val Acc: 0.7225
# Precision: 0.7288, Recall: 0.7225, F1-score: 0.7231
# --------------------------------------------------
# Epoch [179/1500]
# Train Loss: 0.6708, Train Acc: 0.7503
# Val Loss: 0.7958, Val Acc: 0.7074
# Precision: 0.7106, Recall: 0.7074, F1-score: 0.7040
# --------------------------------------------------
# Epoch [180/1500]
# Train Loss: 0.6601, Train Acc: 0.7569
# Val Loss: 0.7853, Val Acc: 0.7131
# Precision: 0.7171, Recall: 0.7131, F1-score: 0.7123
# --------------------------------------------------
# Epoch [181/1500]
# Train Loss: 0.6550, Train Acc: 0.7635
# Val Loss: 0.7926, Val Acc: 0.7135
# Precision: 0.7156, Recall: 0.7135, F1-score: 0.7132
# --------------------------------------------------
# Epoch [182/1500]
# Train Loss: 0.6622, Train Acc: 0.7589
# Val Loss: 0.7859, Val Acc: 0.7126
# Precision: 0.7134, Recall: 0.7126, F1-score: 0.7109
# --------------------------------------------------
# Epoch [183/1500]
# Train Loss: 0.6701, Train Acc: 0.7519
# Val Loss: 0.8060, Val Acc: 0.7088
# Precision: 0.7129, Recall: 0.7088, F1-score: 0.7070
# --------------------------------------------------
# Epoch [184/1500]
# Train Loss: 0.6450, Train Acc: 0.7671
# Val Loss: 0.8114, Val Acc: 0.7032
# Precision: 0.7103, Recall: 0.7032, F1-score: 0.7033
# --------------------------------------------------
# Epoch [185/1500]
# Train Loss: 0.6463, Train Acc: 0.7643
# Val Loss: 0.8095, Val Acc: 0.7079
# Precision: 0.7153, Recall: 0.7079, F1-score: 0.7080
# --------------------------------------------------
# Epoch [186/1500]
# Train Loss: 0.6573, Train Acc: 0.7605
# Val Loss: 0.7846, Val Acc: 0.7112
# Precision: 0.7123, Recall: 0.7112, F1-score: 0.7098
# --------------------------------------------------
# Epoch [187/1500]
# Train Loss: 0.6572, Train Acc: 0.7589
# Val Loss: 0.7978, Val Acc: 0.7074
# Precision: 0.7105, Recall: 0.7074, F1-score: 0.7060
# --------------------------------------------------
# Epoch [188/1500]
# Train Loss: 0.6538, Train Acc: 0.7600
# Val Loss: 0.8198, Val Acc: 0.7065
# Precision: 0.7227, Recall: 0.7065, F1-score: 0.7090
# --------------------------------------------------
# Epoch [189/1500]
# Train Loss: 0.6619, Train Acc: 0.7656
# Val Loss: 0.7818, Val Acc: 0.7192
# Precision: 0.7261, Recall: 0.7192, F1-score: 0.7188
# --------------------------------------------------
# Epoch [190/1500]
# Train Loss: 0.6395, Train Acc: 0.7654
# Val Loss: 0.7728, Val Acc: 0.7154
# Precision: 0.7218, Recall: 0.7154, F1-score: 0.7140
# --------------------------------------------------
# Epoch [191/1500]
# Train Loss: 0.6472, Train Acc: 0.7603
# Val Loss: 0.7820, Val Acc: 0.7202
# Precision: 0.7257, Recall: 0.7202, F1-score: 0.7203
# --------------------------------------------------
# Epoch [192/1500]
# Train Loss: 0.6462, Train Acc: 0.7672
# Val Loss: 0.7869, Val Acc: 0.7159
# Precision: 0.7232, Recall: 0.7159, F1-score: 0.7156
# --------------------------------------------------
# Epoch [193/1500]
# Train Loss: 0.6494, Train Acc: 0.7628
# Val Loss: 0.7773, Val Acc: 0.7173
# Precision: 0.7220, Recall: 0.7173, F1-score: 0.7166
# --------------------------------------------------
# Epoch [194/1500]
# Train Loss: 0.6285, Train Acc: 0.7703
# Val Loss: 0.7684, Val Acc: 0.7154
# Precision: 0.7167, Recall: 0.7154, F1-score: 0.7148
# --------------------------------------------------
# Epoch [195/1500]
# Train Loss: 0.6303, Train Acc: 0.7750
# Val Loss: 0.7997, Val Acc: 0.7107
# Precision: 0.7203, Recall: 0.7107, F1-score: 0.7120
# --------------------------------------------------
# Epoch [196/1500]
# Train Loss: 0.6376, Train Acc: 0.7622
# Val Loss: 0.7865, Val Acc: 0.7168
# Precision: 0.7266, Recall: 0.7168, F1-score: 0.7174
# --------------------------------------------------
# Epoch [197/1500]
# Train Loss: 0.6230, Train Acc: 0.7727
# Val Loss: 0.7929, Val Acc: 0.7178
# Precision: 0.7287, Recall: 0.7178, F1-score: 0.7188
# --------------------------------------------------
# Epoch [198/1500]
# Train Loss: 0.6392, Train Acc: 0.7622
# Val Loss: 0.7795, Val Acc: 0.7173
# Precision: 0.7272, Recall: 0.7173, F1-score: 0.7175
# --------------------------------------------------
# Epoch [199/1500]
# Train Loss: 0.6191, Train Acc: 0.7718
# Val Loss: 0.7850, Val Acc: 0.7225
# Precision: 0.7277, Recall: 0.7225, F1-score: 0.7219
# --------------------------------------------------
# Epoch [200/1500]
# Train Loss: 0.6280, Train Acc: 0.7735
# Val Loss: 0.7691, Val Acc: 0.7239
# Precision: 0.7263, Recall: 0.7239, F1-score: 0.7227
# --------------------------------------------------
# Epoch [201/1500]
# Train Loss: 0.6265, Train Acc: 0.7732
# Val Loss: 0.7652, Val Acc: 0.7220
# Precision: 0.7283, Recall: 0.7220, F1-score: 0.7219
# --------------------------------------------------
# Epoch [202/1500]
# Train Loss: 0.6223, Train Acc: 0.7746
# Val Loss: 0.7829, Val Acc: 0.7197
# Precision: 0.7293, Recall: 0.7197, F1-score: 0.7206
# --------------------------------------------------
# Epoch [203/1500]
# Train Loss: 0.6320, Train Acc: 0.7683
# Val Loss: 0.7785, Val Acc: 0.7230
# Precision: 0.7305, Recall: 0.7230, F1-score: 0.7224
# --------------------------------------------------
# Epoch [204/1500]
# Train Loss: 0.6178, Train Acc: 0.7692
# Val Loss: 0.7847, Val Acc: 0.7159
# Precision: 0.7222, Recall: 0.7159, F1-score: 0.7154
# --------------------------------------------------
# Epoch [205/1500]
# Train Loss: 0.6179, Train Acc: 0.7726
# Val Loss: 0.7744, Val Acc: 0.7225
# Precision: 0.7250, Recall: 0.7225, F1-score: 0.7218
# --------------------------------------------------
# Epoch [206/1500]
# Train Loss: 0.6237, Train Acc: 0.7756
# Val Loss: 0.7612, Val Acc: 0.7263
# Precision: 0.7320, Recall: 0.7263, F1-score: 0.7265
# --------------------------------------------------
# Epoch [207/1500]
# Train Loss: 0.6189, Train Acc: 0.7763
# Val Loss: 0.7627, Val Acc: 0.7272
# Precision: 0.7351, Recall: 0.7272, F1-score: 0.7276
# --------------------------------------------------
# Epoch [208/1500]
# Train Loss: 0.6167, Train Acc: 0.7708
# Val Loss: 0.7665, Val Acc: 0.7305
# Precision: 0.7336, Recall: 0.7305, F1-score: 0.7288
# --------------------------------------------------
# Epoch [209/1500]
# Train Loss: 0.6050, Train Acc: 0.7787
# Val Loss: 0.7779, Val Acc: 0.7168
# Precision: 0.7223, Recall: 0.7168, F1-score: 0.7162
# --------------------------------------------------
# Epoch [210/1500]
# Train Loss: 0.6204, Train Acc: 0.7744
# Val Loss: 0.7503, Val Acc: 0.7334
# Precision: 0.7406, Recall: 0.7334, F1-score: 0.7334
# --------------------------------------------------
# Epoch [211/1500]
# Train Loss: 0.6132, Train Acc: 0.7714
# Val Loss: 0.7623, Val Acc: 0.7258
# Precision: 0.7299, Recall: 0.7258, F1-score: 0.7252
# --------------------------------------------------
# Epoch [212/1500]
# Train Loss: 0.6313, Train Acc: 0.7700
# Val Loss: 0.7542, Val Acc: 0.7296
# Precision: 0.7344, Recall: 0.7296, F1-score: 0.7299
# --------------------------------------------------
# Epoch [213/1500]
# Train Loss: 0.6052, Train Acc: 0.7782
# Val Loss: 0.7569, Val Acc: 0.7272
# Precision: 0.7320, Recall: 0.7272, F1-score: 0.7267
# --------------------------------------------------
# Epoch [214/1500]
# Train Loss: 0.6098, Train Acc: 0.7780
# Val Loss: 0.7765, Val Acc: 0.7183
# Precision: 0.7291, Recall: 0.7183, F1-score: 0.7199
# --------------------------------------------------
# Epoch [215/1500]
# Train Loss: 0.6075, Train Acc: 0.7813
# Val Loss: 0.7709, Val Acc: 0.7244
# Precision: 0.7344, Recall: 0.7244, F1-score: 0.7254
# --------------------------------------------------
# Epoch [216/1500]
# Train Loss: 0.6018, Train Acc: 0.7826
# Val Loss: 0.7545, Val Acc: 0.7334
# Precision: 0.7377, Recall: 0.7334, F1-score: 0.7330
# --------------------------------------------------
# Epoch [217/1500]
# Train Loss: 0.5967, Train Acc: 0.7820
# Val Loss: 0.7645, Val Acc: 0.7239
# Precision: 0.7281, Recall: 0.7239, F1-score: 0.7236
# --------------------------------------------------
# Epoch [218/1500]
# Train Loss: 0.6212, Train Acc: 0.7745
# Val Loss: 0.7514, Val Acc: 0.7367
# Precision: 0.7389, Recall: 0.7367, F1-score: 0.7363
# --------------------------------------------------
# Epoch [219/1500]
# Train Loss: 0.5951, Train Acc: 0.7826
# Val Loss: 0.7708, Val Acc: 0.7206
# Precision: 0.7320, Recall: 0.7206, F1-score: 0.7216
# --------------------------------------------------
# Epoch [220/1500]
# Train Loss: 0.5974, Train Acc: 0.7878
# Val Loss: 0.7604, Val Acc: 0.7291
# Precision: 0.7376, Recall: 0.7291, F1-score: 0.7299
# --------------------------------------------------
# Epoch [221/1500]
# Train Loss: 0.6056, Train Acc: 0.7791
# Val Loss: 0.7494, Val Acc: 0.7301
# Precision: 0.7323, Recall: 0.7301, F1-score: 0.7288
# --------------------------------------------------
# Epoch [222/1500]
# Train Loss: 0.5910, Train Acc: 0.7883
# Val Loss: 0.7487, Val Acc: 0.7310
# Precision: 0.7388, Recall: 0.7310, F1-score: 0.7325
# --------------------------------------------------
# Epoch [223/1500]
# Train Loss: 0.5904, Train Acc: 0.7836
# Val Loss: 0.7469, Val Acc: 0.7376
# Precision: 0.7384, Recall: 0.7376, F1-score: 0.7367
# --------------------------------------------------
# Epoch [224/1500]
# Train Loss: 0.5963, Train Acc: 0.7819
# Val Loss: 0.7686, Val Acc: 0.7319
# Precision: 0.7431, Recall: 0.7319, F1-score: 0.7328
# --------------------------------------------------
# Epoch [225/1500]
# Train Loss: 0.6032, Train Acc: 0.7828
# Val Loss: 0.7648, Val Acc: 0.7282
# Precision: 0.7361, Recall: 0.7282, F1-score: 0.7281
# --------------------------------------------------
# Epoch [226/1500]
# Train Loss: 0.5898, Train Acc: 0.7915
# Val Loss: 0.7562, Val Acc: 0.7291
# Precision: 0.7326, Recall: 0.7291, F1-score: 0.7284
# --------------------------------------------------
# Epoch [227/1500]
# Train Loss: 0.5827, Train Acc: 0.7871
# Val Loss: 0.7499, Val Acc: 0.7282
# Precision: 0.7293, Recall: 0.7282, F1-score: 0.7276
# --------------------------------------------------
# Epoch [228/1500]
# Train Loss: 0.5804, Train Acc: 0.7885
# Val Loss: 0.7429, Val Acc: 0.7386
# Precision: 0.7429, Recall: 0.7386, F1-score: 0.7382
# --------------------------------------------------
# Epoch [229/1500]
# Train Loss: 0.5913, Train Acc: 0.7882
# Val Loss: 0.7563, Val Acc: 0.7357
# Precision: 0.7424, Recall: 0.7357, F1-score: 0.7368
# --------------------------------------------------
# Epoch [230/1500]
# Train Loss: 0.5827, Train Acc: 0.7905
# Val Loss: 0.7576, Val Acc: 0.7263
# Precision: 0.7293, Recall: 0.7263, F1-score: 0.7255
# --------------------------------------------------
# Epoch [231/1500]
# Train Loss: 0.5985, Train Acc: 0.7884
# Val Loss: 0.7492, Val Acc: 0.7381
# Precision: 0.7412, Recall: 0.7381, F1-score: 0.7374
# --------------------------------------------------
# Epoch [232/1500]
# Train Loss: 0.5844, Train Acc: 0.7887
# Val Loss: 0.7520, Val Acc: 0.7343
# Precision: 0.7412, Recall: 0.7343, F1-score: 0.7340
# --------------------------------------------------
# Epoch [233/1500]
# Train Loss: 0.5889, Train Acc: 0.7866
# Val Loss: 0.7464, Val Acc: 0.7319
# Precision: 0.7356, Recall: 0.7319, F1-score: 0.7319
# --------------------------------------------------
# Epoch [234/1500]
# Train Loss: 0.5673, Train Acc: 0.7958
# Val Loss: 0.7647, Val Acc: 0.7367
# Precision: 0.7423, Recall: 0.7367, F1-score: 0.7368
# --------------------------------------------------
# Epoch [235/1500]
# Train Loss: 0.5866, Train Acc: 0.7896
# Val Loss: 0.7597, Val Acc: 0.7310
# Precision: 0.7365, Recall: 0.7310, F1-score: 0.7312
# --------------------------------------------------
# Epoch [236/1500]
# Train Loss: 0.5775, Train Acc: 0.7905
# Val Loss: 0.7421, Val Acc: 0.7286
# Precision: 0.7331, Recall: 0.7286, F1-score: 0.7283
# --------------------------------------------------
# Epoch [237/1500]
# Train Loss: 0.5646, Train Acc: 0.7995
# Val Loss: 0.7427, Val Acc: 0.7334
# Precision: 0.7416, Recall: 0.7334, F1-score: 0.7329
# --------------------------------------------------
# Epoch [238/1500]
# Train Loss: 0.5718, Train Acc: 0.7893
# Val Loss: 0.7593, Val Acc: 0.7282
# Precision: 0.7342, Recall: 0.7282, F1-score: 0.7275
# --------------------------------------------------
# Epoch [239/1500]
# Train Loss: 0.5584, Train Acc: 0.7988
# Val Loss: 0.7358, Val Acc: 0.7433
# Precision: 0.7515, Recall: 0.7433, F1-score: 0.7439
# --------------------------------------------------
# Epoch [240/1500]
# Train Loss: 0.5730, Train Acc: 0.7880
# Val Loss: 0.7439, Val Acc: 0.7353
# Precision: 0.7425, Recall: 0.7353, F1-score: 0.7357
# --------------------------------------------------
# Epoch [241/1500]
# Train Loss: 0.5694, Train Acc: 0.7919
# Val Loss: 0.7463, Val Acc: 0.7390
# Precision: 0.7453, Recall: 0.7390, F1-score: 0.7398
# --------------------------------------------------
# Epoch [242/1500]
# Train Loss: 0.5630, Train Acc: 0.7956
# Val Loss: 0.7342, Val Acc: 0.7381
# Precision: 0.7439, Recall: 0.7381, F1-score: 0.7376
# --------------------------------------------------
# Epoch [243/1500]
# Train Loss: 0.5770, Train Acc: 0.7903
# Val Loss: 0.7432, Val Acc: 0.7310
# Precision: 0.7362, Recall: 0.7310, F1-score: 0.7308
# --------------------------------------------------
# Epoch [244/1500]
# Train Loss: 0.5683, Train Acc: 0.7944
# Val Loss: 0.7317, Val Acc: 0.7442
# Precision: 0.7479, Recall: 0.7442, F1-score: 0.7432
# --------------------------------------------------
# Epoch [245/1500]
# Train Loss: 0.5563, Train Acc: 0.7989
# Val Loss: 0.7399, Val Acc: 0.7428
# Precision: 0.7479, Recall: 0.7428, F1-score: 0.7423
# --------------------------------------------------
# Epoch [246/1500]
# Train Loss: 0.5658, Train Acc: 0.7909
# Val Loss: 0.7256, Val Acc: 0.7456
# Precision: 0.7492, Recall: 0.7456, F1-score: 0.7453
# --------------------------------------------------
# Epoch [247/1500]
# Train Loss: 0.5665, Train Acc: 0.7946
# Val Loss: 0.7339, Val Acc: 0.7367
# Precision: 0.7416, Recall: 0.7367, F1-score: 0.7363
# --------------------------------------------------
# Epoch [248/1500]
# Train Loss: 0.5672, Train Acc: 0.7974
# Val Loss: 0.7265, Val Acc: 0.7489
# Precision: 0.7538, Recall: 0.7489, F1-score: 0.7490
# --------------------------------------------------
# Epoch [249/1500]
# Train Loss: 0.5762, Train Acc: 0.7897
# Val Loss: 0.7308, Val Acc: 0.7390
# Precision: 0.7419, Recall: 0.7390, F1-score: 0.7376
# --------------------------------------------------
# Epoch [250/1500]
# Train Loss: 0.5720, Train Acc: 0.7883
# Val Loss: 0.7417, Val Acc: 0.7348
# Precision: 0.7391, Recall: 0.7348, F1-score: 0.7344
# --------------------------------------------------
# Epoch [251/1500]
# Train Loss: 0.5438, Train Acc: 0.8025
# Val Loss: 0.7562, Val Acc: 0.7305
# ...
# Val Loss: 0.7736, Val Acc: 0.7796
# Precision: 0.7815, Recall: 0.7796, F1-score: 0.7786
# --------------------------------------------------
# Epoch [1419/1500]
# Train Loss: 0.2538, Train Acc: 0.9118
# Val Loss: 0.7538, Val Acc: 0.7801
# Precision: 0.7815, Recall: 0.7801, F1-score: 0.7798
# --------------------------------------------------
# Epoch [1420/1500]
# Train Loss: 0.2559, Train Acc: 0.9105
# Val Loss: 0.7807, Val Acc: 0.7777
# Precision: 0.7815, Recall: 0.7777, F1-score: 0.7777
# --------------------------------------------------
# Epoch [1421/1500]
# Train Loss: 0.2517, Train Acc: 0.9159
# Val Loss: 0.7558, Val Acc: 0.7862
# Precision: 0.7889, Recall: 0.7862, F1-score: 0.7860
# --------------------------------------------------
# Epoch [1422/1500]
# Train Loss: 0.2556, Train Acc: 0.9123
# Val Loss: 0.7494, Val Acc: 0.7853
# Precision: 0.7876, Recall: 0.7853, F1-score: 0.7848
# --------------------------------------------------
# Epoch [1423/1500]
# Train Loss: 0.2606, Train Acc: 0.9092
# Val Loss: 0.7699, Val Acc: 0.7749
# Precision: 0.7784, Recall: 0.7749, F1-score: 0.7738
# --------------------------------------------------
# Epoch [1424/1500]
# Train Loss: 0.2577, Train Acc: 0.9087
# Val Loss: 0.7608, Val Acc: 0.7810
# Precision: 0.7835, Recall: 0.7810, F1-score: 0.7801
# --------------------------------------------------
# Epoch [1425/1500]
# Train Loss: 0.2722, Train Acc: 0.9075
# Val Loss: 0.7484, Val Acc: 0.7763
# Precision: 0.7775, Recall: 0.7763, F1-score: 0.7750
# --------------------------------------------------
# Epoch [1426/1500]
# Train Loss: 0.2617, Train Acc: 0.9123
# Val Loss: 0.7518, Val Acc: 0.7782
# Precision: 0.7792, Recall: 0.7782, F1-score: 0.7773
# --------------------------------------------------
# Epoch [1427/1500]
# Train Loss: 0.2627, Train Acc: 0.9113
# Val Loss: 0.7544, Val Acc: 0.7773
# Precision: 0.7791, Recall: 0.7773, F1-score: 0.7767
# --------------------------------------------------
# Epoch [1428/1500]
# Train Loss: 0.2633, Train Acc: 0.9099
# Val Loss: 0.7446, Val Acc: 0.7773
# Precision: 0.7780, Recall: 0.7773, F1-score: 0.7763
# --------------------------------------------------
# Epoch [1429/1500]
# Train Loss: 0.2635, Train Acc: 0.9065
# Val Loss: 0.7595, Val Acc: 0.7777
# Precision: 0.7799, Recall: 0.7777, F1-score: 0.7774
# --------------------------------------------------
# Epoch [1430/1500]
# Train Loss: 0.2699, Train Acc: 0.9078
# Val Loss: 0.7418, Val Acc: 0.7834
# Precision: 0.7874, Recall: 0.7834, F1-score: 0.7831
# --------------------------------------------------
# Epoch [1431/1500]
# Train Loss: 0.2578, Train Acc: 0.9117
# Val Loss: 0.7539, Val Acc: 0.7773
# Precision: 0.7806, Recall: 0.7773, F1-score: 0.7769
# --------------------------------------------------
# Epoch [1432/1500]
# Train Loss: 0.2684, Train Acc: 0.9115
# Val Loss: 0.7638, Val Acc: 0.7758
# Precision: 0.7772, Recall: 0.7758, F1-score: 0.7752
# --------------------------------------------------
# Epoch [1433/1500]
# Train Loss: 0.2742, Train Acc: 0.9052
# Val Loss: 0.7473, Val Acc: 0.7777
# Precision: 0.7787, Recall: 0.7777, F1-score: 0.7767
# --------------------------------------------------
# Epoch [1434/1500]
# Train Loss: 0.2671, Train Acc: 0.9093
# Val Loss: 0.7470, Val Acc: 0.7791
# Precision: 0.7813, Recall: 0.7791, F1-score: 0.7791
# --------------------------------------------------
# Epoch [1435/1500]
# Train Loss: 0.2499, Train Acc: 0.9153
# Val Loss: 0.7572, Val Acc: 0.7834
# Precision: 0.7858, Recall: 0.7834, F1-score: 0.7828
# --------------------------------------------------
# Epoch [1436/1500]
# Train Loss: 0.2423, Train Acc: 0.9159
# Val Loss: 0.7504, Val Acc: 0.7843
# Precision: 0.7880, Recall: 0.7843, F1-score: 0.7842
# --------------------------------------------------
# Epoch [1437/1500]
# Train Loss: 0.2598, Train Acc: 0.9095
# Val Loss: 0.7499, Val Acc: 0.7739
# Precision: 0.7787, Recall: 0.7739, F1-score: 0.7734
# --------------------------------------------------
# Epoch [1438/1500]
# Train Loss: 0.2631, Train Acc: 0.9084
# Val Loss: 0.7599, Val Acc: 0.7749
# Precision: 0.7852, Recall: 0.7749, F1-score: 0.7749
# --------------------------------------------------
# Epoch [1439/1500]
# Train Loss: 0.2681, Train Acc: 0.9060
# Val Loss: 0.7285, Val Acc: 0.7782
# Precision: 0.7806, Recall: 0.7782, F1-score: 0.7775
# --------------------------------------------------
# Epoch [1440/1500]
# Train Loss: 0.2584, Train Acc: 0.9117
# Val Loss: 0.7522, Val Acc: 0.7824
# Precision: 0.7836, Recall: 0.7824, F1-score: 0.7820
# --------------------------------------------------
# Epoch [1441/1500]
# Train Loss: 0.2401, Train Acc: 0.9193
# Val Loss: 0.7540, Val Acc: 0.7791
# Precision: 0.7817, Recall: 0.7791, F1-score: 0.7789
# --------------------------------------------------
# Epoch [1442/1500]
# Train Loss: 0.2547, Train Acc: 0.9114
# Val Loss: 0.7618, Val Acc: 0.7787
# Precision: 0.7817, Recall: 0.7787, F1-score: 0.7785
# --------------------------------------------------
# Epoch [1443/1500]
# Train Loss: 0.2489, Train Acc: 0.9130
# Val Loss: 0.7336, Val Acc: 0.7829
# Precision: 0.7845, Recall: 0.7829, F1-score: 0.7819
# --------------------------------------------------
# Epoch [1444/1500]
# Train Loss: 0.2516, Train Acc: 0.9155
# Val Loss: 0.7583, Val Acc: 0.7876
# Precision: 0.7886, Recall: 0.7876, F1-score: 0.7872
# --------------------------------------------------
# Epoch [1445/1500]
# Train Loss: 0.2489, Train Acc: 0.9127
# Val Loss: 0.7490, Val Acc: 0.7853
# Precision: 0.7869, Recall: 0.7853, F1-score: 0.7845
# --------------------------------------------------
# Epoch [1446/1500]
# Train Loss: 0.2600, Train Acc: 0.9090
# Val Loss: 0.7471, Val Acc: 0.7791
# Precision: 0.7806, Recall: 0.7791, F1-score: 0.7780
# --------------------------------------------------
# Epoch [1447/1500]
# Train Loss: 0.2573, Train Acc: 0.9131
# Val Loss: 0.7541, Val Acc: 0.7806
# Precision: 0.7834, Recall: 0.7806, F1-score: 0.7795
# --------------------------------------------------
# Epoch [1448/1500]
# Train Loss: 0.2570, Train Acc: 0.9090
# Val Loss: 0.7589, Val Acc: 0.7834
# Precision: 0.7866, Recall: 0.7834, F1-score: 0.7831
# --------------------------------------------------
# Epoch [1449/1500]
# Train Loss: 0.2599, Train Acc: 0.9124
# Val Loss: 0.7374, Val Acc: 0.7867
# Precision: 0.7883, Recall: 0.7867, F1-score: 0.7862
# --------------------------------------------------
# Epoch [1450/1500]
# Train Loss: 0.2654, Train Acc: 0.9047
# Val Loss: 0.7516, Val Acc: 0.7810
# Precision: 0.7827, Recall: 0.7810, F1-score: 0.7801
# --------------------------------------------------
# Epoch [1451/1500]
# Train Loss: 0.2563, Train Acc: 0.9107
# Val Loss: 0.7372, Val Acc: 0.7820
# Precision: 0.7837, Recall: 0.7820, F1-score: 0.7812
# --------------------------------------------------
# Epoch [1452/1500]
# Train Loss: 0.2494, Train Acc: 0.9139
# Val Loss: 0.7704, Val Acc: 0.7806
# Precision: 0.7843, Recall: 0.7806, F1-score: 0.7800
# --------------------------------------------------
# Epoch [1453/1500]
# Train Loss: 0.2630, Train Acc: 0.9087
# Val Loss: 0.7452, Val Acc: 0.7853
# Precision: 0.7873, Recall: 0.7853, F1-score: 0.7847
# --------------------------------------------------
# Epoch [1454/1500]
# Train Loss: 0.2621, Train Acc: 0.9092
# Val Loss: 0.7308, Val Acc: 0.7824
# Precision: 0.7842, Recall: 0.7824, F1-score: 0.7820
# --------------------------------------------------
# Epoch [1455/1500]
# Train Loss: 0.2678, Train Acc: 0.9101
# Val Loss: 0.7346, Val Acc: 0.7820
# Precision: 0.7834, Recall: 0.7820, F1-score: 0.7815
# --------------------------------------------------
# Epoch [1456/1500]
# Train Loss: 0.2684, Train Acc: 0.9100
# Val Loss: 0.7400, Val Acc: 0.7791
# Precision: 0.7813, Recall: 0.7791, F1-score: 0.7784
# --------------------------------------------------
# Epoch [1457/1500]
# Train Loss: 0.2518, Train Acc: 0.9135
# Val Loss: 0.7586, Val Acc: 0.7735
# Precision: 0.7799, Recall: 0.7735, F1-score: 0.7737
# --------------------------------------------------
# Epoch [1458/1500]
# Train Loss: 0.2570, Train Acc: 0.9115
# Val Loss: 0.7155, Val Acc: 0.7876
# Precision: 0.7906, Recall: 0.7876, F1-score: 0.7873
# --------------------------------------------------
# Epoch [1459/1500]
# Train Loss: 0.2689, Train Acc: 0.9074
# Val Loss: 0.7375, Val Acc: 0.7862
# Precision: 0.7880, Recall: 0.7862, F1-score: 0.7857
# --------------------------------------------------
# Epoch [1460/1500]
# Train Loss: 0.2560, Train Acc: 0.9098
# Val Loss: 0.7127, Val Acc: 0.7853
# Precision: 0.7877, Recall: 0.7853, F1-score: 0.7850
# --------------------------------------------------
# Epoch [1461/1500]
# Train Loss: 0.2652, Train Acc: 0.9087
# Val Loss: 0.7388, Val Acc: 0.7796
# Precision: 0.7813, Recall: 0.7796, F1-score: 0.7793
# --------------------------------------------------
# Epoch [1462/1500]
# Train Loss: 0.2425, Train Acc: 0.9156
# Val Loss: 0.7516, Val Acc: 0.7815
# Precision: 0.7838, Recall: 0.7815, F1-score: 0.7809
# --------------------------------------------------
# Epoch [1463/1500]
# Train Loss: 0.2579, Train Acc: 0.9120
# Val Loss: 0.7285, Val Acc: 0.7791
# Precision: 0.7811, Recall: 0.7791, F1-score: 0.7787
# --------------------------------------------------
# Epoch [1464/1500]
# Train Loss: 0.2522, Train Acc: 0.9111
# Val Loss: 0.7579, Val Acc: 0.7744
# Precision: 0.7777, Recall: 0.7744, F1-score: 0.7737
# --------------------------------------------------
# Epoch [1465/1500]
# Train Loss: 0.2592, Train Acc: 0.9110
# Val Loss: 0.7481, Val Acc: 0.7768
# Precision: 0.7800, Recall: 0.7768, F1-score: 0.7763
# --------------------------------------------------
# Epoch [1466/1500]
# Train Loss: 0.2505, Train Acc: 0.9121
# Val Loss: 0.7420, Val Acc: 0.7857
# Precision: 0.7893, Recall: 0.7857, F1-score: 0.7853
# --------------------------------------------------
# Epoch [1467/1500]
# Train Loss: 0.2591, Train Acc: 0.9099
# Val Loss: 0.7554, Val Acc: 0.7754
# Precision: 0.7770, Recall: 0.7754, F1-score: 0.7749
# --------------------------------------------------
# Epoch [1468/1500]
# Train Loss: 0.2509, Train Acc: 0.9139
# Val Loss: 0.7607, Val Acc: 0.7739
# Precision: 0.7771, Recall: 0.7739, F1-score: 0.7738
# --------------------------------------------------
# Epoch [1469/1500]
# Train Loss: 0.2609, Train Acc: 0.9100
# Val Loss: 0.7561, Val Acc: 0.7716
# Precision: 0.7780, Recall: 0.7716, F1-score: 0.7723
# --------------------------------------------------
# Epoch [1470/1500]
# Train Loss: 0.2544, Train Acc: 0.9143
# Val Loss: 0.7671, Val Acc: 0.7796
# Precision: 0.7819, Recall: 0.7796, F1-score: 0.7789
# --------------------------------------------------
# Epoch [1471/1500]
# Train Loss: 0.2590, Train Acc: 0.9092
# Val Loss: 0.7522, Val Acc: 0.7702
# Precision: 0.7739, Recall: 0.7702, F1-score: 0.7704
# --------------------------------------------------
# Epoch [1472/1500]
# Train Loss: 0.2477, Train Acc: 0.9138
# Val Loss: 0.7697, Val Acc: 0.7754
# Precision: 0.7802, Recall: 0.7754, F1-score: 0.7760
# --------------------------------------------------
# Epoch [1473/1500]
# Train Loss: 0.2592, Train Acc: 0.9108
# Val Loss: 0.7620, Val Acc: 0.7650
# Precision: 0.7739, Recall: 0.7650, F1-score: 0.7661
# --------------------------------------------------
# Epoch [1474/1500]
# Train Loss: 0.2612, Train Acc: 0.9113
# Val Loss: 0.7430, Val Acc: 0.7810
# Precision: 0.7855, Recall: 0.7810, F1-score: 0.7812
# --------------------------------------------------
# Epoch [1475/1500]
# Train Loss: 0.2754, Train Acc: 0.9056
# Val Loss: 0.7665, Val Acc: 0.7791
# Precision: 0.7812, Recall: 0.7791, F1-score: 0.7782
# --------------------------------------------------
# Epoch [1476/1500]
# Train Loss: 0.2631, Train Acc: 0.9115
# Val Loss: 0.7308, Val Acc: 0.7834
# Precision: 0.7857, Recall: 0.7834, F1-score: 0.7829
# --------------------------------------------------
# Epoch [1477/1500]
# Train Loss: 0.2622, Train Acc: 0.9135
# Val Loss: 0.7427, Val Acc: 0.7796
# Precision: 0.7828, Recall: 0.7796, F1-score: 0.7797
# --------------------------------------------------
# Epoch [1478/1500]
# Train Loss: 0.2548, Train Acc: 0.9120
# Val Loss: 0.7533, Val Acc: 0.7754
# Precision: 0.7783, Recall: 0.7754, F1-score: 0.7750
# --------------------------------------------------
# Epoch [1479/1500]
# Train Loss: 0.2516, Train Acc: 0.9169
# Val Loss: 0.7332, Val Acc: 0.7791
# Precision: 0.7828, Recall: 0.7791, F1-score: 0.7791
# --------------------------------------------------
# Epoch [1480/1500]
# Train Loss: 0.2416, Train Acc: 0.9173
# Val Loss: 0.7669, Val Acc: 0.7796
# Precision: 0.7839, Recall: 0.7796, F1-score: 0.7798
# --------------------------------------------------
# Epoch [1481/1500]
# Train Loss: 0.2557, Train Acc: 0.9120
# Val Loss: 0.7566, Val Acc: 0.7796
# Precision: 0.7827, Recall: 0.7796, F1-score: 0.7796
# --------------------------------------------------
# Epoch [1482/1500]
# Train Loss: 0.2600, Train Acc: 0.9096
# Val Loss: 0.7614, Val Acc: 0.7787
# Precision: 0.7851, Recall: 0.7787, F1-score: 0.7794
# --------------------------------------------------
# Epoch [1483/1500]
# Train Loss: 0.2659, Train Acc: 0.9104
# Val Loss: 0.7384, Val Acc: 0.7763
# Precision: 0.7788, Recall: 0.7763, F1-score: 0.7762
# --------------------------------------------------
# Epoch [1484/1500]
# Train Loss: 0.2575, Train Acc: 0.9107
# Val Loss: 0.7491, Val Acc: 0.7796
# Precision: 0.7818, Recall: 0.7796, F1-score: 0.7787
# --------------------------------------------------
# Epoch [1485/1500]
# Train Loss: 0.2562, Train Acc: 0.9162
# Val Loss: 0.7478, Val Acc: 0.7810
# Precision: 0.7850, Recall: 0.7810, F1-score: 0.7808
# --------------------------------------------------
# Epoch [1486/1500]
# Train Loss: 0.2620, Train Acc: 0.9094
# Val Loss: 0.7339, Val Acc: 0.7815
# Precision: 0.7827, Recall: 0.7815, F1-score: 0.7807
# --------------------------------------------------
# Epoch [1487/1500]
# Train Loss: 0.2405, Train Acc: 0.9144
# Val Loss: 0.7493, Val Acc: 0.7739
# Precision: 0.7800, Recall: 0.7739, F1-score: 0.7742
# --------------------------------------------------
# Epoch [1488/1500]
# Train Loss: 0.2503, Train Acc: 0.9143
# Val Loss: 0.7470, Val Acc: 0.7796
# Precision: 0.7856, Recall: 0.7796, F1-score: 0.7797
# --------------------------------------------------
# Epoch [1489/1500]
# Train Loss: 0.2437, Train Acc: 0.9165
# Val Loss: 0.7538, Val Acc: 0.7815
# Precision: 0.7843, Recall: 0.7815, F1-score: 0.7809
# --------------------------------------------------
# Epoch [1490/1500]
# Train Loss: 0.2579, Train Acc: 0.9112
# Val Loss: 0.7411, Val Acc: 0.7820
# Precision: 0.7857, Recall: 0.7820, F1-score: 0.7810
# --------------------------------------------------
# Epoch [1491/1500]
# Train Loss: 0.2456, Train Acc: 0.9141
# Val Loss: 0.7484, Val Acc: 0.7839
# Precision: 0.7878, Recall: 0.7839, F1-score: 0.7836
# --------------------------------------------------
# Epoch [1492/1500]
# Train Loss: 0.2499, Train Acc: 0.9133
# Val Loss: 0.7244, Val Acc: 0.7900
# Precision: 0.7922, Recall: 0.7900, F1-score: 0.7894
# --------------------------------------------------
# Epoch [1493/1500]
# Train Loss: 0.2569, Train Acc: 0.9131
# Val Loss: 0.7355, Val Acc: 0.7763
# Precision: 0.7811, Recall: 0.7763, F1-score: 0.7766
# --------------------------------------------------
# Epoch [1494/1500]
# Train Loss: 0.2512, Train Acc: 0.9100
# Val Loss: 0.7421, Val Acc: 0.7787
# Precision: 0.7827, Recall: 0.7787, F1-score: 0.7786
# --------------------------------------------------
# Epoch [1495/1500]
# Train Loss: 0.2508, Train Acc: 0.9143
# Val Loss: 0.7517, Val Acc: 0.7787
# Precision: 0.7809, Recall: 0.7787, F1-score: 0.7776
# --------------------------------------------------
# Epoch [1496/1500]
# Train Loss: 0.2650, Train Acc: 0.9069
# Val Loss: 0.7563, Val Acc: 0.7791
# Precision: 0.7874, Recall: 0.7791, F1-score: 0.7793
# --------------------------------------------------
# Epoch [1497/1500]
# Train Loss: 0.2602, Train Acc: 0.9124
# Val Loss: 0.7695, Val Acc: 0.7749
# Precision: 0.7810, Recall: 0.7749, F1-score: 0.7741
# --------------------------------------------------
# Epoch [1498/1500]
# Train Loss: 0.2555, Train Acc: 0.9155
# Val Loss: 0.7583, Val Acc: 0.7773
# Precision: 0.7823, Recall: 0.7773, F1-score: 0.7765
# --------------------------------------------------
# Epoch [1499/1500]
# Train Loss: 0.2470, Train Acc: 0.9132
# Val Loss: 0.7553, Val Acc: 0.7787
# Precision: 0.7837, Recall: 0.7787, F1-score: 0.7779
# --------------------------------------------------
# Epoch [1500/1500]
# Train Loss: 0.2742, Train Acc: 0.9075
# Val Loss: 0.7296, Val Acc: 0.7815
# Precision: 0.7856, Recall: 0.7815, F1-score: 0.7817
# --------------------------------------------------

# %%
torch.save(model.state_dict(), "C:/Nini/Capstone/Models/DataAugmentationSnippets_cnn_model.pth")
