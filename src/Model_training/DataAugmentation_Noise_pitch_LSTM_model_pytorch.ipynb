# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import precision_recall_fscore_support

# %%
features = pd.read_csv("C:/Nini/Capstone/CSV_Files/DataAugmentation_ravdess_siya_extracted_features.csv")
features = features.drop(features.columns[0], axis=1)
temp = shuffle(features)
df = np.random.rand(len(temp)) < 0.8
train = temp[df]
test = temp[~df]

# %%
X_train = np.array(train.iloc[:,:-1])
y_train = np.array(train.iloc[:,-1])
X_test = np.array(test.iloc[:,:-1])
y_test = np.array(test.iloc[:,-1])

# %%
lb = LabelEncoder()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1)
y_train = torch.tensor(y_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
batch_size = 256
train_loader = DataLoader(TensorDataset(X_train,y_train), batch_size=batch_size,shuffle=True)
test_loader = DataLoader(TensorDataset(X_test,y_test), batch_size=batch_size, shuffle=False)

# %%
class LSTMPyTorch(nn.Module):
    def __init__(self, input_size, hidden_sizes=[256, 256, 128], output_size=8, dropout=0.2, l2_reg=1e-5):
        super(LSTMPyTorch, self).__init__()
        
        self.lstm1 = nn.LSTM(input_size, hidden_sizes[0], batch_first=True)
        self.lstm2 = nn.LSTM(hidden_sizes[0], hidden_sizes[1], batch_first=True)
        self.lstm3 = nn.LSTM(hidden_sizes[1], hidden_sizes[2], batch_first=True)
        
        self.bn1 = nn.BatchNorm1d(hidden_sizes[0])
        self.bn2 = nn.BatchNorm1d(hidden_sizes[1])
        self.bn3 = nn.BatchNorm1d(hidden_sizes[2])

        self.fc1 = nn.Linear(hidden_sizes[2], 256)
        self.fc2 = nn.Linear(256, output_size)
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.bn1(x.transpose(1,2)).transpose(1,2)

        x, _ = self.lstm2(x)
        x = self.bn2(x.transpose(1,2)).transpose(1,2)

        x, _ = self.lstm3(x)
        x = self.bn3(x.transpose(1,2)).transpose(1,2)
        
        x = self.relu(self.fc1(x[:, -1, :])) 
        x = self.dropout(x)
        x = self.softmax(self.fc2(x))
        return x

# %%
print("X_train shape:", X_train.shape)
# Out:
# X_train shape: torch.Size([3494, 1, 161])

# %%
input_size = 161
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMPyTorch(input_size).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

# %%
epochs = 1500
for epoch in range(epochs):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    # Training loop
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        correct += (predicted == y_batch).sum().item()
        total += y_batch.size(0)
    
    train_accuracy = correct / total
    avg_train_loss = running_loss / len(train_loader)

    # Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for val_inputs, val_labels in test_loader:
            val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)
            val_outputs = model(val_inputs)
            loss = criterion(val_outputs, val_labels)
            val_loss += loss.item()
            _, val_predicted = torch.max(val_outputs, 1)

            val_correct += (val_predicted == val_labels).sum().item()
            val_total += val_labels.size(0)

            # Store predictions and labels for evaluation
            all_preds.extend(val_predicted.cpu().numpy())
            all_labels.extend(val_labels.cpu().numpy())

    val_accuracy = val_correct / val_total
    avg_val_loss = val_loss / len(test_loader)

    # Compute Precision, Recall, F1-score
    precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted',zero_division=1)

    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy:.4f}")
    print(f"Val Loss: {avg_val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}")
    print("-" * 50)
# Out:
# Epoch [1/1500]
# Train Loss: 2.0039, Train Acc: 0.2765
# Val Loss: 2.0734, Val Acc: 0.2324
# Precision: 0.6190, Recall: 0.2324, F1-score: 0.1769
# --------------------------------------------------
# Epoch [2/1500]
# Train Loss: 1.8716, Train Acc: 0.4282
# Val Loss: 2.0137, Val Acc: 0.2724
# Precision: 0.5888, Recall: 0.2724, F1-score: 0.2396
# --------------------------------------------------
# Epoch [3/1500]
# Train Loss: 1.7941, Train Acc: 0.4923
# Val Loss: 1.8686, Val Acc: 0.4140
# Precision: 0.5357, Recall: 0.4140, F1-score: 0.3821
# --------------------------------------------------
# Epoch [4/1500]
# Train Loss: 1.7595, Train Acc: 0.5120
# Val Loss: 1.8296, Val Acc: 0.4346
# Precision: 0.6144, Recall: 0.4346, F1-score: 0.4388
# --------------------------------------------------
# Epoch [5/1500]
# Train Loss: 1.7283, Train Acc: 0.5492
# Val Loss: 1.7733, Val Acc: 0.5061
# Precision: 0.5758, Recall: 0.5061, F1-score: 0.4815
# --------------------------------------------------
# Epoch [6/1500]
# Train Loss: 1.7001, Train Acc: 0.5758
# Val Loss: 1.7462, Val Acc: 0.5206
# Precision: 0.5896, Recall: 0.5206, F1-score: 0.5028
# --------------------------------------------------
# Epoch [7/1500]
# Train Loss: 1.6855, Train Acc: 0.5913
# Val Loss: 1.7544, Val Acc: 0.5230
# Precision: 0.5848, Recall: 0.5230, F1-score: 0.5037
# --------------------------------------------------
# Epoch [8/1500]
# Train Loss: 1.6701, Train Acc: 0.6053
# Val Loss: 1.7963, Val Acc: 0.4734
# Precision: 0.5977, Recall: 0.4734, F1-score: 0.4395
# --------------------------------------------------
# Epoch [9/1500]
# Train Loss: 1.6669, Train Acc: 0.6059
# Val Loss: 1.7645, Val Acc: 0.4939
# Precision: 0.5712, Recall: 0.4939, F1-score: 0.4777
# --------------------------------------------------
# Epoch [10/1500]
# Train Loss: 1.6441, Train Acc: 0.6345
# Val Loss: 1.6958, Val Acc: 0.5654
# Precision: 0.6154, Recall: 0.5654, F1-score: 0.5514
# --------------------------------------------------
# Epoch [11/1500]
# Train Loss: 1.6352, Train Acc: 0.6411
# Val Loss: 1.7299, Val Acc: 0.5387
# Precision: 0.5769, Recall: 0.5387, F1-score: 0.5185
# --------------------------------------------------
# Epoch [12/1500]
# Train Loss: 1.6250, Train Acc: 0.6511
# Val Loss: 1.7396, Val Acc: 0.5278
# Precision: 0.6134, Recall: 0.5278, F1-score: 0.5023
# --------------------------------------------------
# Epoch [13/1500]
# Train Loss: 1.6085, Train Acc: 0.6697
# Val Loss: 1.7408, Val Acc: 0.5327
# Precision: 0.6119, Recall: 0.5327, F1-score: 0.5153
# --------------------------------------------------
# Epoch [14/1500]
# Train Loss: 1.6039, Train Acc: 0.6752
# Val Loss: 1.7076, Val Acc: 0.5642
# Precision: 0.6072, Recall: 0.5642, F1-score: 0.5363
# --------------------------------------------------
# Epoch [15/1500]
# Train Loss: 1.5860, Train Acc: 0.6920
# Val Loss: 1.7447, Val Acc: 0.5266
# Precision: 0.6069, Recall: 0.5266, F1-score: 0.5178
# --------------------------------------------------
# Epoch [16/1500]
# Train Loss: 1.5846, Train Acc: 0.6929
# Val Loss: 1.7144, Val Acc: 0.5533
# Precision: 0.6408, Recall: 0.5533, F1-score: 0.5313
# --------------------------------------------------
# Epoch [17/1500]
# Train Loss: 1.5645, Train Acc: 0.7129
# Val Loss: 1.6699, Val Acc: 0.6077
# Precision: 0.6587, Recall: 0.6077, F1-score: 0.5879
# --------------------------------------------------
# Epoch [18/1500]
# Train Loss: 1.5554, Train Acc: 0.7247
# Val Loss: 1.6711, Val Acc: 0.5981
# Precision: 0.6370, Recall: 0.5981, F1-score: 0.5764
# --------------------------------------------------
# Epoch [19/1500]
# Train Loss: 1.5413, Train Acc: 0.7355
# Val Loss: 1.6644, Val Acc: 0.6090
# Precision: 0.6828, Recall: 0.6090, F1-score: 0.5910
# --------------------------------------------------
# Epoch [20/1500]
# Train Loss: 1.5316, Train Acc: 0.7436
# Val Loss: 1.6289, Val Acc: 0.6429
# Precision: 0.6698, Recall: 0.6429, F1-score: 0.6234
# --------------------------------------------------
# Epoch [21/1500]
# Train Loss: 1.5249, Train Acc: 0.7536
# Val Loss: 1.6393, Val Acc: 0.6162
# Precision: 0.6649, Recall: 0.6162, F1-score: 0.5997
# --------------------------------------------------
# Epoch [22/1500]
# Train Loss: 1.5197, Train Acc: 0.7599
# Val Loss: 1.6475, Val Acc: 0.6308
# Precision: 0.6865, Recall: 0.6308, F1-score: 0.6081
# --------------------------------------------------
# Epoch [23/1500]
# Train Loss: 1.5164, Train Acc: 0.7627
# Val Loss: 1.6437, Val Acc: 0.6308
# Precision: 0.6804, Recall: 0.6308, F1-score: 0.6115
# --------------------------------------------------
# Epoch [24/1500]
# Train Loss: 1.5029, Train Acc: 0.7756
# Val Loss: 1.6210, Val Acc: 0.6416
# Precision: 0.6708, Recall: 0.6416, F1-score: 0.6209
# --------------------------------------------------
# Epoch [25/1500]
# Train Loss: 1.4969, Train Acc: 0.7813
# Val Loss: 1.6309, Val Acc: 0.6416
# Precision: 0.6950, Recall: 0.6416, F1-score: 0.6212
# --------------------------------------------------
# Epoch [26/1500]
# Train Loss: 1.4915, Train Acc: 0.7879
# Val Loss: 1.6016, Val Acc: 0.6804
# Precision: 0.6971, Recall: 0.6804, F1-score: 0.6678
# --------------------------------------------------
# Epoch [27/1500]
# Train Loss: 1.4778, Train Acc: 0.8039
# Val Loss: 1.6334, Val Acc: 0.6416
# Precision: 0.6539, Recall: 0.6416, F1-score: 0.6316
# --------------------------------------------------
# Epoch [28/1500]
# Train Loss: 1.4639, Train Acc: 0.8168
# Val Loss: 1.6138, Val Acc: 0.6683
# Precision: 0.6782, Recall: 0.6683, F1-score: 0.6644
# --------------------------------------------------
# Epoch [29/1500]
# Train Loss: 1.4608, Train Acc: 0.8217
# Val Loss: 1.6071, Val Acc: 0.6501
# Precision: 0.6373, Recall: 0.6501, F1-score: 0.6328
# --------------------------------------------------
# Epoch [30/1500]
# Train Loss: 1.4521, Train Acc: 0.8297
# Val Loss: 1.5852, Val Acc: 0.6998
# Precision: 0.7130, Recall: 0.6998, F1-score: 0.6889
# --------------------------------------------------
# Epoch [31/1500]
# Train Loss: 1.4438, Train Acc: 0.8374
# Val Loss: 1.5958, Val Acc: 0.6840
# Precision: 0.6869, Recall: 0.6840, F1-score: 0.6781
# --------------------------------------------------
# Epoch [32/1500]
# Train Loss: 1.4392, Train Acc: 0.8457
# Val Loss: 1.6438, Val Acc: 0.6429
# Precision: 0.6772, Recall: 0.6429, F1-score: 0.6445
# --------------------------------------------------
# Epoch [33/1500]
# Train Loss: 1.4276, Train Acc: 0.8523
# Val Loss: 1.6110, Val Acc: 0.6659
# Precision: 0.6780, Recall: 0.6659, F1-score: 0.6636
# --------------------------------------------------
# Epoch [34/1500]
# Train Loss: 1.4284, Train Acc: 0.8483
# Val Loss: 1.6128, Val Acc: 0.6659
# Precision: 0.6938, Recall: 0.6659, F1-score: 0.6593
# --------------------------------------------------
# Epoch [35/1500]
# Train Loss: 1.4273, Train Acc: 0.8540
# Val Loss: 1.6692, Val Acc: 0.6126
# Precision: 0.6623, Recall: 0.6126, F1-score: 0.6150
# --------------------------------------------------
# Epoch [36/1500]
# Train Loss: 1.4232, Train Acc: 0.8572
# Val Loss: 1.5531, Val Acc: 0.7155
# Precision: 0.7136, Recall: 0.7155, F1-score: 0.7112
# --------------------------------------------------
# Epoch [37/1500]
# Train Loss: 1.4195, Train Acc: 0.8615
# Val Loss: 1.5515, Val Acc: 0.7228
# Precision: 0.7378, Recall: 0.7228, F1-score: 0.7148
# --------------------------------------------------
# Epoch [38/1500]
# Train Loss: 1.4093, Train Acc: 0.8703
# Val Loss: 1.6372, Val Acc: 0.6477
# Precision: 0.7023, Recall: 0.6477, F1-score: 0.6613
# --------------------------------------------------
# Epoch [39/1500]
# Train Loss: 1.4106, Train Acc: 0.8689
# Val Loss: 1.5773, Val Acc: 0.6840
# Precision: 0.6961, Recall: 0.6840, F1-score: 0.6789
# --------------------------------------------------
# Epoch [40/1500]
# Train Loss: 1.4025, Train Acc: 0.8786
# Val Loss: 1.6145, Val Acc: 0.6707
# Precision: 0.6946, Recall: 0.6707, F1-score: 0.6734
# --------------------------------------------------
# Epoch [41/1500]
# Train Loss: 1.4055, Train Acc: 0.8738
# Val Loss: 1.5759, Val Acc: 0.6889
# Precision: 0.7225, Recall: 0.6889, F1-score: 0.6925
# --------------------------------------------------
# Epoch [42/1500]
# Train Loss: 1.4020, Train Acc: 0.8752
# Val Loss: 1.5738, Val Acc: 0.7058
# Precision: 0.7285, Recall: 0.7058, F1-score: 0.6995
# --------------------------------------------------
# Epoch [43/1500]
# Train Loss: 1.3908, Train Acc: 0.8895
# Val Loss: 1.5560, Val Acc: 0.7228
# Precision: 0.7339, Recall: 0.7228, F1-score: 0.7221
# --------------------------------------------------
# Epoch [44/1500]
# Train Loss: 1.3883, Train Acc: 0.8910
# Val Loss: 1.5549, Val Acc: 0.7240
# Precision: 0.7395, Recall: 0.7240, F1-score: 0.7270
# --------------------------------------------------
# Epoch [45/1500]
# Train Loss: 1.3876, Train Acc: 0.8924
# Val Loss: 1.5332, Val Acc: 0.7337
# Precision: 0.7306, Recall: 0.7337, F1-score: 0.7287
# --------------------------------------------------
# Epoch [46/1500]
# Train Loss: 1.3777, Train Acc: 0.9007
# Val Loss: 1.5500, Val Acc: 0.7240
# Precision: 0.7486, Recall: 0.7240, F1-score: 0.7260
# --------------------------------------------------
# Epoch [47/1500]
# Train Loss: 1.3628, Train Acc: 0.9167
# Val Loss: 1.4920, Val Acc: 0.7676
# Precision: 0.7679, Recall: 0.7676, F1-score: 0.7617
# --------------------------------------------------
# Epoch [48/1500]
# Train Loss: 1.3609, Train Acc: 0.9173
# Val Loss: 1.5417, Val Acc: 0.7373
# Precision: 0.7440, Recall: 0.7373, F1-score: 0.7379
# --------------------------------------------------
# Epoch [49/1500]
# Train Loss: 1.3616, Train Acc: 0.9167
# Val Loss: 1.5240, Val Acc: 0.7409
# Precision: 0.7626, Recall: 0.7409, F1-score: 0.7437
# --------------------------------------------------
# Epoch [50/1500]
# Train Loss: 1.3551, Train Acc: 0.9230
# Val Loss: 1.5531, Val Acc: 0.7288
# Precision: 0.7632, Recall: 0.7288, F1-score: 0.7339
# --------------------------------------------------
# Epoch [51/1500]
# Train Loss: 1.3552, Train Acc: 0.9253
# Val Loss: 1.5742, Val Acc: 0.7070
# Precision: 0.7288, Recall: 0.7070, F1-score: 0.7063
# --------------------------------------------------
# Epoch [52/1500]
# Train Loss: 1.3568, Train Acc: 0.9213
# Val Loss: 1.5159, Val Acc: 0.7482
# Precision: 0.7596, Recall: 0.7482, F1-score: 0.7476
# --------------------------------------------------
# Epoch [53/1500]
# Train Loss: 1.3547, Train Acc: 0.9236
# Val Loss: 1.5902, Val Acc: 0.6852
# Precision: 0.7120, Recall: 0.6852, F1-score: 0.6859
# --------------------------------------------------
# Epoch [54/1500]
# Train Loss: 1.3551, Train Acc: 0.9224
# Val Loss: 1.6131, Val Acc: 0.6683
# Precision: 0.7341, Recall: 0.6683, F1-score: 0.6747
# --------------------------------------------------
# Epoch [55/1500]
# Train Loss: 1.3530, Train Acc: 0.9262
# Val Loss: 1.5519, Val Acc: 0.7167
# Precision: 0.7415, Recall: 0.7167, F1-score: 0.7154
# --------------------------------------------------
# Epoch [56/1500]
# Train Loss: 1.3529, Train Acc: 0.9227
# Val Loss: 1.5331, Val Acc: 0.7482
# Precision: 0.7533, Recall: 0.7482, F1-score: 0.7450
# --------------------------------------------------
# Epoch [57/1500]
# Train Loss: 1.3514, Train Acc: 0.9244
# Val Loss: 1.5223, Val Acc: 0.7385
# Precision: 0.7696, Recall: 0.7385, F1-score: 0.7417
# --------------------------------------------------
# Epoch [58/1500]
# Train Loss: 1.3462, Train Acc: 0.9330
# Val Loss: 1.5671, Val Acc: 0.7046
# Precision: 0.7199, Recall: 0.7046, F1-score: 0.7006
# --------------------------------------------------
# Epoch [59/1500]
# Train Loss: 1.3558, Train Acc: 0.9207
# Val Loss: 1.5735, Val Acc: 0.6852
# Precision: 0.6986, Recall: 0.6852, F1-score: 0.6817
# --------------------------------------------------
# Epoch [60/1500]
# Train Loss: 1.3502, Train Acc: 0.9262
# Val Loss: 1.5469, Val Acc: 0.7252
# Precision: 0.7489, Recall: 0.7252, F1-score: 0.7263
# --------------------------------------------------
# Epoch [61/1500]
# Train Loss: 1.3464, Train Acc: 0.9310
# Val Loss: 1.4999, Val Acc: 0.7760
# Precision: 0.7806, Recall: 0.7760, F1-score: 0.7762
# --------------------------------------------------
# Epoch [62/1500]
# Train Loss: 1.3448, Train Acc: 0.9310
# Val Loss: 1.5101, Val Acc: 0.7748
# Precision: 0.7890, Recall: 0.7748, F1-score: 0.7764
# --------------------------------------------------
# Epoch [63/1500]
# Train Loss: 1.3457, Train Acc: 0.9296
# Val Loss: 1.5529, Val Acc: 0.7240
# Precision: 0.7351, Recall: 0.7240, F1-score: 0.7232
# --------------------------------------------------
# Epoch [64/1500]
# Train Loss: 1.3407, Train Acc: 0.9365
# Val Loss: 1.5408, Val Acc: 0.7276
# Precision: 0.7355, Recall: 0.7276, F1-score: 0.7254
# --------------------------------------------------
# Epoch [65/1500]
# Train Loss: 1.3364, Train Acc: 0.9408
# Val Loss: 1.4757, Val Acc: 0.7881
# Precision: 0.7896, Recall: 0.7881, F1-score: 0.7873
# --------------------------------------------------
# Epoch [66/1500]
# Train Loss: 1.3369, Train Acc: 0.9399
# Val Loss: 1.5230, Val Acc: 0.7530
# Precision: 0.7618, Recall: 0.7530, F1-score: 0.7547
# --------------------------------------------------
# Epoch [67/1500]
# Train Loss: 1.3385, Train Acc: 0.9373
# Val Loss: 1.5479, Val Acc: 0.7264
# Precision: 0.7485, Recall: 0.7264, F1-score: 0.7264
# --------------------------------------------------
# Epoch [68/1500]
# Train Loss: 1.3429, Train Acc: 0.9347
# Val Loss: 1.5475, Val Acc: 0.7167
# Precision: 0.7492, Recall: 0.7167, F1-score: 0.7177
# --------------------------------------------------
# Epoch [69/1500]
# Train Loss: 1.3383, Train Acc: 0.9379
# Val Loss: 1.5664, Val Acc: 0.7094
# Precision: 0.7162, Recall: 0.7094, F1-score: 0.7084
# --------------------------------------------------
# Epoch [70/1500]
# Train Loss: 1.3399, Train Acc: 0.9365
# Val Loss: 1.5196, Val Acc: 0.7446
# Precision: 0.7664, Recall: 0.7446, F1-score: 0.7471
# --------------------------------------------------
# Epoch [71/1500]
# Train Loss: 1.3312, Train Acc: 0.9453
# Val Loss: 1.5309, Val Acc: 0.7300
# Precision: 0.7405, Recall: 0.7300, F1-score: 0.7285
# --------------------------------------------------
# Epoch [72/1500]
# Train Loss: 1.3346, Train Acc: 0.9419
# Val Loss: 1.4970, Val Acc: 0.7772
# Precision: 0.7811, Recall: 0.7772, F1-score: 0.7775
# --------------------------------------------------
# Epoch [73/1500]
# Train Loss: 1.3316, Train Acc: 0.9433
# Val Loss: 1.6136, Val Acc: 0.6501
# Precision: 0.6818, Recall: 0.6501, F1-score: 0.6576
# --------------------------------------------------
# Epoch [74/1500]
# Train Loss: 1.3345, Train Acc: 0.9413
# Val Loss: 1.5751, Val Acc: 0.6937
# Precision: 0.7134, Recall: 0.6937, F1-score: 0.6885
# --------------------------------------------------
# Epoch [75/1500]
# Train Loss: 1.3291, Train Acc: 0.9482
# Val Loss: 1.4966, Val Acc: 0.7712
# Precision: 0.7796, Recall: 0.7712, F1-score: 0.7722
# --------------------------------------------------
# Epoch [76/1500]
# Train Loss: 1.3298, Train Acc: 0.9456
# Val Loss: 1.4841, Val Acc: 0.7857
# Precision: 0.7946, Recall: 0.7857, F1-score: 0.7869
# --------------------------------------------------
# Epoch [77/1500]
# Train Loss: 1.3267, Train Acc: 0.9488
# Val Loss: 1.5077, Val Acc: 0.7639
# Precision: 0.7629, Recall: 0.7639, F1-score: 0.7630
# --------------------------------------------------
# Epoch [78/1500]
# Train Loss: 1.3287, Train Acc: 0.9476
# Val Loss: 1.5069, Val Acc: 0.7470
# Precision: 0.7523, Recall: 0.7470, F1-score: 0.7473
# --------------------------------------------------
# Epoch [79/1500]
# Train Loss: 1.3340, Train Acc: 0.9430
# Val Loss: 1.5320, Val Acc: 0.7264
# Precision: 0.7462, Recall: 0.7264, F1-score: 0.7296
# --------------------------------------------------
# Epoch [80/1500]
# Train Loss: 1.3317, Train Acc: 0.9462
# Val Loss: 1.5723, Val Acc: 0.6925
# Precision: 0.7171, Recall: 0.6925, F1-score: 0.6967
# --------------------------------------------------
# Epoch [81/1500]
# Train Loss: 1.3321, Train Acc: 0.9445
# Val Loss: 1.4682, Val Acc: 0.7930
# Precision: 0.7951, Recall: 0.7930, F1-score: 0.7928
# --------------------------------------------------
# Epoch [82/1500]
# Train Loss: 1.3296, Train Acc: 0.9468
# Val Loss: 1.5234, Val Acc: 0.7361
# Precision: 0.7491, Recall: 0.7361, F1-score: 0.7373
# --------------------------------------------------
# Epoch [83/1500]
# Train Loss: 1.3280, Train Acc: 0.9479
# Val Loss: 1.4908, Val Acc: 0.7809
# Precision: 0.7880, Recall: 0.7809, F1-score: 0.7803
# --------------------------------------------------
# Epoch [84/1500]
# Train Loss: 1.3243, Train Acc: 0.9505
# Val Loss: 1.5004, Val Acc: 0.7712
# Precision: 0.7773, Recall: 0.7712, F1-score: 0.7703
# --------------------------------------------------
# Epoch [85/1500]
# Train Loss: 1.3218, Train Acc: 0.9545
# Val Loss: 1.4947, Val Acc: 0.7676
# Precision: 0.7886, Recall: 0.7676, F1-score: 0.7713
# --------------------------------------------------
# Epoch [86/1500]
# Train Loss: 1.3219, Train Acc: 0.9539
# Val Loss: 1.5383, Val Acc: 0.7409
# Precision: 0.7559, Recall: 0.7409, F1-score: 0.7447
# --------------------------------------------------
# Epoch [87/1500]
# Train Loss: 1.3232, Train Acc: 0.9525
# Val Loss: 1.5062, Val Acc: 0.7615
# Precision: 0.7686, Recall: 0.7615, F1-score: 0.7586
# --------------------------------------------------
# Epoch [88/1500]
# Train Loss: 1.3254, Train Acc: 0.9493
# Val Loss: 1.5367, Val Acc: 0.7361
# Precision: 0.7486, Recall: 0.7361, F1-score: 0.7355
# --------------------------------------------------
# Epoch [89/1500]
# Train Loss: 1.3198, Train Acc: 0.9562
# Val Loss: 1.5347, Val Acc: 0.7337
# Precision: 0.7432, Recall: 0.7337, F1-score: 0.7358
# --------------------------------------------------
# Epoch [90/1500]
# Train Loss: 1.3207, Train Acc: 0.9548
# Val Loss: 1.4550, Val Acc: 0.8015
# Precision: 0.8020, Recall: 0.8015, F1-score: 0.7994
# --------------------------------------------------
# Epoch [91/1500]
# Train Loss: 1.3185, Train Acc: 0.9576
# Val Loss: 1.5111, Val Acc: 0.7494
# Precision: 0.7610, Recall: 0.7494, F1-score: 0.7512
# --------------------------------------------------
# Epoch [92/1500]
# Train Loss: 1.3199, Train Acc: 0.9545
# Val Loss: 1.5231, Val Acc: 0.7433
# Precision: 0.7563, Recall: 0.7433, F1-score: 0.7411
# --------------------------------------------------
# Epoch [93/1500]
# Train Loss: 1.3198, Train Acc: 0.9545
# Val Loss: 1.5002, Val Acc: 0.7712
# Precision: 0.7834, Recall: 0.7712, F1-score: 0.7712
# --------------------------------------------------
# Epoch [94/1500]
# Train Loss: 1.3180, Train Acc: 0.9571
# Val Loss: 1.4669, Val Acc: 0.7966
# Precision: 0.7998, Recall: 0.7966, F1-score: 0.7955
# --------------------------------------------------
# Epoch [95/1500]
# Train Loss: 1.3156, Train Acc: 0.9585
# Val Loss: 1.4848, Val Acc: 0.7857
# Precision: 0.7949, Recall: 0.7857, F1-score: 0.7867
# --------------------------------------------------
# Epoch [96/1500]
# Train Loss: 1.3164, Train Acc: 0.9594
# Val Loss: 1.4742, Val Acc: 0.7869
# Precision: 0.7981, Recall: 0.7869, F1-score: 0.7881
# --------------------------------------------------
# Epoch [97/1500]
# Train Loss: 1.3163, Train Acc: 0.9591
# Val Loss: 1.5522, Val Acc: 0.7191
# Precision: 0.7434, Recall: 0.7191, F1-score: 0.7252
# --------------------------------------------------
# Epoch [98/1500]
# Train Loss: 1.3225, Train Acc: 0.9522
# Val Loss: 1.5180, Val Acc: 0.7518
# Precision: 0.7517, Recall: 0.7518, F1-score: 0.7485
# --------------------------------------------------
# Epoch [99/1500]
# Train Loss: 1.3168, Train Acc: 0.9594
# Val Loss: 1.5063, Val Acc: 0.7530
# Precision: 0.7769, Recall: 0.7530, F1-score: 0.7561
# --------------------------------------------------
# Epoch [100/1500]
# Train Loss: 1.3171, Train Acc: 0.9588
# Val Loss: 1.4960, Val Acc: 0.7615
# Precision: 0.7687, Recall: 0.7615, F1-score: 0.7620
# --------------------------------------------------
# Epoch [101/1500]
# Train Loss: 1.3188, Train Acc: 0.9579
# Val Loss: 1.4997, Val Acc: 0.7591
# Precision: 0.7634, Recall: 0.7591, F1-score: 0.7575
# --------------------------------------------------
# Epoch [102/1500]
# Train Loss: 1.3186, Train Acc: 0.9571
# Val Loss: 1.4978, Val Acc: 0.7869
# Precision: 0.8032, Recall: 0.7869, F1-score: 0.7896
# --------------------------------------------------
# Epoch [103/1500]
# Train Loss: 1.3138, Train Acc: 0.9614
# Val Loss: 1.4992, Val Acc: 0.7748
# Precision: 0.7881, Recall: 0.7748, F1-score: 0.7771
# --------------------------------------------------
# Epoch [104/1500]
# Train Loss: 1.3182, Train Acc: 0.9576
# Val Loss: 1.4903, Val Acc: 0.7845
# Precision: 0.7906, Recall: 0.7845, F1-score: 0.7837
# --------------------------------------------------
# Epoch [105/1500]
# Train Loss: 1.3151, Train Acc: 0.9614
# Val Loss: 1.5349, Val Acc: 0.7421
# Precision: 0.7570, Recall: 0.7421, F1-score: 0.7433
# --------------------------------------------------
# Epoch [106/1500]
# Train Loss: 1.3180, Train Acc: 0.9585
# Val Loss: 1.5400, Val Acc: 0.7179
# Precision: 0.7345, Recall: 0.7179, F1-score: 0.7168
# --------------------------------------------------
# Epoch [107/1500]
# Train Loss: 1.3134, Train Acc: 0.9634
# Val Loss: 1.4809, Val Acc: 0.8063
# Precision: 0.8122, Recall: 0.8063, F1-score: 0.8062
# --------------------------------------------------
# Epoch [108/1500]
# Train Loss: 1.3102, Train Acc: 0.9642
# Val Loss: 1.4818, Val Acc: 0.7881
# Precision: 0.7933, Recall: 0.7881, F1-score: 0.7886
# --------------------------------------------------
# Epoch [109/1500]
# Train Loss: 1.3107, Train Acc: 0.9642
# Val Loss: 1.4630, Val Acc: 0.8027
# Precision: 0.8072, Recall: 0.8027, F1-score: 0.8030
# --------------------------------------------------
# Epoch [110/1500]
# Train Loss: 1.3081, Train Acc: 0.9674
# Val Loss: 1.5028, Val Acc: 0.7639
# Precision: 0.7819, Recall: 0.7639, F1-score: 0.7660
# --------------------------------------------------
# Epoch [111/1500]
# Train Loss: 1.3057, Train Acc: 0.9691
# Val Loss: 1.4930, Val Acc: 0.7785
# Precision: 0.7885, Recall: 0.7785, F1-score: 0.7772
# --------------------------------------------------
# Epoch [112/1500]
# Train Loss: 1.3077, Train Acc: 0.9674
# Val Loss: 1.5130, Val Acc: 0.7554
# Precision: 0.7669, Recall: 0.7554, F1-score: 0.7545
# --------------------------------------------------
# Epoch [113/1500]
# Train Loss: 1.3049, Train Acc: 0.9705
# Val Loss: 1.4990, Val Acc: 0.7676
# Precision: 0.7791, Recall: 0.7676, F1-score: 0.7679
# --------------------------------------------------
# Epoch [114/1500]
# Train Loss: 1.3106, Train Acc: 0.9645
# Val Loss: 1.4869, Val Acc: 0.7760
# Precision: 0.7841, Recall: 0.7760, F1-score: 0.7775
# --------------------------------------------------
# Epoch [115/1500]
# Train Loss: 1.3090, Train Acc: 0.9682
# Val Loss: 1.5070, Val Acc: 0.7458
# Precision: 0.7669, Recall: 0.7458, F1-score: 0.7433
# --------------------------------------------------
# Epoch [116/1500]
# Train Loss: 1.3111, Train Acc: 0.9634
# Val Loss: 1.4759, Val Acc: 0.7906
# Precision: 0.7987, Recall: 0.7906, F1-score: 0.7918
# --------------------------------------------------
# Epoch [117/1500]
# Train Loss: 1.3118, Train Acc: 0.9642
# Val Loss: 1.4817, Val Acc: 0.7845
# Precision: 0.7933, Recall: 0.7845, F1-score: 0.7837
# --------------------------------------------------
# Epoch [118/1500]
# Train Loss: 1.3148, Train Acc: 0.9616
# Val Loss: 1.5268, Val Acc: 0.7421
# Precision: 0.7766, Recall: 0.7421, F1-score: 0.7459
# --------------------------------------------------
# Epoch [119/1500]
# Train Loss: 1.3127, Train Acc: 0.9639
# Val Loss: 1.5427, Val Acc: 0.7397
# Precision: 0.7537, Recall: 0.7397, F1-score: 0.7419
# --------------------------------------------------
# Epoch [120/1500]
# Train Loss: 1.3144, Train Acc: 0.9611
# Val Loss: 1.5270, Val Acc: 0.7567
# Precision: 0.7595, Recall: 0.7567, F1-score: 0.7564
# --------------------------------------------------
# Epoch [121/1500]
# Train Loss: 1.3097, Train Acc: 0.9654
# Val Loss: 1.5664, Val Acc: 0.6961
# Precision: 0.7130, Recall: 0.6961, F1-score: 0.6936
# --------------------------------------------------
# Epoch [122/1500]
# Train Loss: 1.3063, Train Acc: 0.9711
# Val Loss: 1.5164, Val Acc: 0.7409
# Precision: 0.7505, Recall: 0.7409, F1-score: 0.7411
# --------------------------------------------------
# Epoch [123/1500]
# Train Loss: 1.3076, Train Acc: 0.9671
# Val Loss: 1.5776, Val Acc: 0.6864
# Precision: 0.7130, Recall: 0.6864, F1-score: 0.6912
# --------------------------------------------------
# Epoch [124/1500]
# Train Loss: 1.3037, Train Acc: 0.9717
# Val Loss: 1.4647, Val Acc: 0.7869
# Precision: 0.7912, Recall: 0.7869, F1-score: 0.7869
# --------------------------------------------------
# Epoch [125/1500]
# Train Loss: 1.3066, Train Acc: 0.9671
# Val Loss: 1.4502, Val Acc: 0.8063
# Precision: 0.8120, Recall: 0.8063, F1-score: 0.8060
# --------------------------------------------------
# Epoch [126/1500]
# Train Loss: 1.3070, Train Acc: 0.9688
# Val Loss: 1.5151, Val Acc: 0.7542
# Precision: 0.7662, Recall: 0.7542, F1-score: 0.7555
# --------------------------------------------------
# Epoch [127/1500]
# Train Loss: 1.3024, Train Acc: 0.9728
# Val Loss: 1.4767, Val Acc: 0.7966
# Precision: 0.8090, Recall: 0.7966, F1-score: 0.7986
# --------------------------------------------------
# Epoch [128/1500]
# Train Loss: 1.3042, Train Acc: 0.9711
# Val Loss: 1.4792, Val Acc: 0.7857
# Precision: 0.7906, Recall: 0.7857, F1-score: 0.7849
# --------------------------------------------------
# Epoch [129/1500]
# Train Loss: 1.3051, Train Acc: 0.9708
# Val Loss: 1.4752, Val Acc: 0.7930
# Precision: 0.8077, Recall: 0.7930, F1-score: 0.7940
# --------------------------------------------------
# Epoch [130/1500]
# Train Loss: 1.3059, Train Acc: 0.9711
# Val Loss: 1.5497, Val Acc: 0.7264
# Precision: 0.7486, Recall: 0.7264, F1-score: 0.7259
# --------------------------------------------------
# Epoch [131/1500]
# Train Loss: 1.3070, Train Acc: 0.9677
# Val Loss: 1.5425, Val Acc: 0.7264
# Precision: 0.7446, Recall: 0.7264, F1-score: 0.7292
# --------------------------------------------------
# Epoch [132/1500]
# Train Loss: 1.3053, Train Acc: 0.9699
# Val Loss: 1.5051, Val Acc: 0.7627
# Precision: 0.7679, Recall: 0.7627, F1-score: 0.7622
# --------------------------------------------------
# Epoch [133/1500]
# Train Loss: 1.3037, Train Acc: 0.9725
# Val Loss: 1.5139, Val Acc: 0.7651
# Precision: 0.7731, Recall: 0.7651, F1-score: 0.7654
# --------------------------------------------------
# Epoch [134/1500]
# Train Loss: 1.3094, Train Acc: 0.9671
# Val Loss: 1.5340, Val Acc: 0.7276
# Precision: 0.7523, Recall: 0.7276, F1-score: 0.7289
# --------------------------------------------------
# Epoch [135/1500]
# Train Loss: 1.3040, Train Acc: 0.9705
# Val Loss: 1.5409, Val Acc: 0.7228
# Precision: 0.7314, Recall: 0.7228, F1-score: 0.7197
# --------------------------------------------------
# Epoch [136/1500]
# Train Loss: 1.3065, Train Acc: 0.9679
# Val Loss: 1.4842, Val Acc: 0.7918
# Precision: 0.7912, Recall: 0.7918, F1-score: 0.7898
# --------------------------------------------------
# Epoch [137/1500]
# Train Loss: 1.3058, Train Acc: 0.9682
# Val Loss: 1.5619, Val Acc: 0.7034
# Precision: 0.7190, Recall: 0.7034, F1-score: 0.7042
# --------------------------------------------------
# Epoch [138/1500]
# Train Loss: 1.3169, Train Acc: 0.9568
# Val Loss: 1.5361, Val Acc: 0.7179
# Precision: 0.7258, Recall: 0.7179, F1-score: 0.7137
# --------------------------------------------------
# Epoch [139/1500]
# Train Loss: 1.3017, Train Acc: 0.9734
# Val Loss: 1.4481, Val Acc: 0.8208
# Precision: 0.8252, Recall: 0.8208, F1-score: 0.8204
# --------------------------------------------------
# Epoch [140/1500]
# Train Loss: 1.3054, Train Acc: 0.9708
# Val Loss: 1.4778, Val Acc: 0.7833
# Precision: 0.7874, Recall: 0.7833, F1-score: 0.7831
# --------------------------------------------------
# Epoch [141/1500]
# Train Loss: 1.3024, Train Acc: 0.9728
# Val Loss: 1.4956, Val Acc: 0.7797
# Precision: 0.7922, Recall: 0.7797, F1-score: 0.7809
# --------------------------------------------------
# Epoch [142/1500]
# Train Loss: 1.3005, Train Acc: 0.9760
# Val Loss: 1.4885, Val Acc: 0.7869
# Precision: 0.7959, Recall: 0.7869, F1-score: 0.7886
# --------------------------------------------------
# Epoch [143/1500]
# Train Loss: 1.2985, Train Acc: 0.9762
# Val Loss: 1.4751, Val Acc: 0.7918
# Precision: 0.7970, Recall: 0.7918, F1-score: 0.7925
# --------------------------------------------------
# Epoch [144/1500]
# Train Loss: 1.3019, Train Acc: 0.9734
# Val Loss: 1.4878, Val Acc: 0.7942
# Precision: 0.8000, Recall: 0.7942, F1-score: 0.7935
# --------------------------------------------------
# Epoch [145/1500]
# Train Loss: 1.3000, Train Acc: 0.9762
# Val Loss: 1.4603, Val Acc: 0.8039
# Precision: 0.8117, Recall: 0.8039, F1-score: 0.8058
# --------------------------------------------------
# Epoch [146/1500]
# Train Loss: 1.2983, Train Acc: 0.9762
# Val Loss: 1.4760, Val Acc: 0.7930
# Precision: 0.7975, Recall: 0.7930, F1-score: 0.7903
# --------------------------------------------------
# Epoch [147/1500]
# Train Loss: 1.2954, Train Acc: 0.9791
# Val Loss: 1.5126, Val Acc: 0.7567
# Precision: 0.7658, Recall: 0.7567, F1-score: 0.7574
# --------------------------------------------------
# Epoch [148/1500]
# Train Loss: 1.2968, Train Acc: 0.9788
# Val Loss: 1.5244, Val Acc: 0.7421
# Precision: 0.7599, Recall: 0.7421, F1-score: 0.7401
# --------------------------------------------------
# Epoch [149/1500]
# Train Loss: 1.2987, Train Acc: 0.9754
# Val Loss: 1.5409, Val Acc: 0.7337
# Precision: 0.7527, Recall: 0.7337, F1-score: 0.7345
# --------------------------------------------------
# Epoch [150/1500]
# Train Loss: 1.2965, Train Acc: 0.9785
# Val Loss: 1.5362, Val Acc: 0.7312
# Precision: 0.7446, Recall: 0.7312, F1-score: 0.7295
# --------------------------------------------------
# Epoch [151/1500]
# Train Loss: 1.3014, Train Acc: 0.9734
# Val Loss: 1.5969, Val Acc: 0.6731
# Precision: 0.6973, Recall: 0.6731, F1-score: 0.6763
# --------------------------------------------------
# Epoch [152/1500]
# Train Loss: 1.3053, Train Acc: 0.9688
# Val Loss: 1.5305, Val Acc: 0.7433
# Precision: 0.7579, Recall: 0.7433, F1-score: 0.7437
# --------------------------------------------------
# Epoch [153/1500]
# Train Loss: 1.3031, Train Acc: 0.9720
# Val Loss: 1.5212, Val Acc: 0.7385
# Precision: 0.7470, Recall: 0.7385, F1-score: 0.7356
# --------------------------------------------------
# Epoch [154/1500]
# Train Loss: 1.3063, Train Acc: 0.9691
# Val Loss: 1.5148, Val Acc: 0.7421
# Precision: 0.7593, Recall: 0.7421, F1-score: 0.7433
# --------------------------------------------------
# Epoch [155/1500]
# Train Loss: 1.3061, Train Acc: 0.9685
# Val Loss: 1.5313, Val Acc: 0.7397
# Precision: 0.7530, Recall: 0.7397, F1-score: 0.7372
# --------------------------------------------------
# Epoch [156/1500]
# Train Loss: 1.3043, Train Acc: 0.9711
# Val Loss: 1.5429, Val Acc: 0.7215
# Precision: 0.7431, Recall: 0.7215, F1-score: 0.7218
# --------------------------------------------------
# Epoch [157/1500]
# Train Loss: 1.3027, Train Acc: 0.9737
# Val Loss: 1.5526, Val Acc: 0.7155
# Precision: 0.7562, Recall: 0.7155, F1-score: 0.7182
# --------------------------------------------------
# Epoch [158/1500]
# Train Loss: 1.3062, Train Acc: 0.9677
# Val Loss: 1.4863, Val Acc: 0.7833
# Precision: 0.7852, Recall: 0.7833, F1-score: 0.7812
# --------------------------------------------------
# Epoch [159/1500]
# Train Loss: 1.3051, Train Acc: 0.9702
# Val Loss: 1.5304, Val Acc: 0.7324
# Precision: 0.7393, Recall: 0.7324, F1-score: 0.7327
# --------------------------------------------------
# Epoch [160/1500]
# Train Loss: 1.3026, Train Acc: 0.9734
# Val Loss: 1.5081, Val Acc: 0.7651
# Precision: 0.7765, Recall: 0.7651, F1-score: 0.7667
# --------------------------------------------------
# Epoch [161/1500]
# Train Loss: 1.2973, Train Acc: 0.9768
# Val Loss: 1.5587, Val Acc: 0.7046
# Precision: 0.7072, Recall: 0.7046, F1-score: 0.6972
# --------------------------------------------------
# Epoch [162/1500]
# Train Loss: 1.3038, Train Acc: 0.9708
# Val Loss: 1.4454, Val Acc: 0.8099
# Precision: 0.8108, Recall: 0.8099, F1-score: 0.8088
# --------------------------------------------------
# Epoch [163/1500]
# Train Loss: 1.2982, Train Acc: 0.9774
# Val Loss: 1.5158, Val Acc: 0.7554
# Precision: 0.7680, Recall: 0.7554, F1-score: 0.7575
# --------------------------------------------------
# Epoch [164/1500]
# Train Loss: 1.3032, Train Acc: 0.9714
# Val Loss: 1.4982, Val Acc: 0.7700
# Precision: 0.7722, Recall: 0.7700, F1-score: 0.7696
# --------------------------------------------------
# Epoch [165/1500]
# Train Loss: 1.3099, Train Acc: 0.9657
# Val Loss: 1.6026, Val Acc: 0.6646
# Precision: 0.6787, Recall: 0.6646, F1-score: 0.6601
# --------------------------------------------------
# Epoch [166/1500]
# Train Loss: 1.3069, Train Acc: 0.9682
# Val Loss: 1.5322, Val Acc: 0.7385
# Precision: 0.7463, Recall: 0.7385, F1-score: 0.7370
# --------------------------------------------------
# Epoch [167/1500]
# Train Loss: 1.3119, Train Acc: 0.9642
# Val Loss: 1.5827, Val Acc: 0.6925
# Precision: 0.6984, Recall: 0.6925, F1-score: 0.6928
# --------------------------------------------------
# Epoch [168/1500]
# Train Loss: 1.3103, Train Acc: 0.9659
# Val Loss: 1.6048, Val Acc: 0.6671
# Precision: 0.6736, Recall: 0.6671, F1-score: 0.6625
# --------------------------------------------------
# Epoch [169/1500]
# Train Loss: 1.3052, Train Acc: 0.9705
# Val Loss: 1.6256, Val Acc: 0.6308
# Precision: 0.6555, Recall: 0.6308, F1-score: 0.6228
# --------------------------------------------------
# Epoch [170/1500]
# Train Loss: 1.3046, Train Acc: 0.9708
# Val Loss: 1.5771, Val Acc: 0.6949
# Precision: 0.7317, Recall: 0.6949, F1-score: 0.7028
# --------------------------------------------------
# Epoch [171/1500]
# Train Loss: 1.3026, Train Acc: 0.9714
# Val Loss: 1.5075, Val Acc: 0.7554
# Precision: 0.7630, Recall: 0.7554, F1-score: 0.7519
# --------------------------------------------------
# Epoch [172/1500]
# Train Loss: 1.3018, Train Acc: 0.9722
# Val Loss: 1.5444, Val Acc: 0.7300
# Precision: 0.7348, Recall: 0.7300, F1-score: 0.7290
# --------------------------------------------------
# Epoch [173/1500]
# Train Loss: 1.3025, Train Acc: 0.9734
# Val Loss: 1.5137, Val Acc: 0.7615
# Precision: 0.7800, Recall: 0.7615, F1-score: 0.7641
# --------------------------------------------------
# Epoch [174/1500]
# Train Loss: 1.2953, Train Acc: 0.9788
# Val Loss: 1.5673, Val Acc: 0.6961
# Precision: 0.7256, Recall: 0.6961, F1-score: 0.6973
# --------------------------------------------------
# Epoch [175/1500]
# Train Loss: 1.3024, Train Acc: 0.9740
# Val Loss: 1.5679, Val Acc: 0.6949
# Precision: 0.7193, Recall: 0.6949, F1-score: 0.6890
# --------------------------------------------------
# Epoch [176/1500]
# Train Loss: 1.2962, Train Acc: 0.9794
# Val Loss: 1.4647, Val Acc: 0.8002
# Precision: 0.8066, Recall: 0.8002, F1-score: 0.8013
# --------------------------------------------------
# Epoch [177/1500]
# Train Loss: 1.2976, Train Acc: 0.9768
# Val Loss: 1.4510, Val Acc: 0.8208
# Precision: 0.8210, Recall: 0.8208, F1-score: 0.8200
# --------------------------------------------------
# Epoch [178/1500]
# Train Loss: 1.2975, Train Acc: 0.9777
# Val Loss: 1.4577, Val Acc: 0.8099
# Precision: 0.8146, Recall: 0.8099, F1-score: 0.8107
# --------------------------------------------------
# Epoch [179/1500]
# Train Loss: 1.2946, Train Acc: 0.9803
# Val Loss: 1.5105, Val Acc: 0.7506
# Precision: 0.7500, Recall: 0.7506, F1-score: 0.7448
# --------------------------------------------------
# Epoch [180/1500]
# Train Loss: 1.2964, Train Acc: 0.9785
# Val Loss: 1.4786, Val Acc: 0.7954
# Precision: 0.7994, Recall: 0.7954, F1-score: 0.7949
# --------------------------------------------------
# Epoch [181/1500]
# Train Loss: 1.2929, Train Acc: 0.9817
# Val Loss: 1.4699, Val Acc: 0.7966
# Precision: 0.8082, Recall: 0.7966, F1-score: 0.7983
# --------------------------------------------------
# Epoch [182/1500]
# Train Loss: 1.2932, Train Acc: 0.9808
# Val Loss: 1.4781, Val Acc: 0.7881
# Precision: 0.7899, Recall: 0.7881, F1-score: 0.7870
# --------------------------------------------------
# Epoch [183/1500]
# Train Loss: 1.2906, Train Acc: 0.9840
# Val Loss: 1.4748, Val Acc: 0.7990
# Precision: 0.8104, Recall: 0.7990, F1-score: 0.8006
# --------------------------------------------------
# Epoch [184/1500]
# Train Loss: 1.2942, Train Acc: 0.9805
# Val Loss: 1.4636, Val Acc: 0.7954
# Precision: 0.8110, Recall: 0.7954, F1-score: 0.7982
# --------------------------------------------------
# Epoch [185/1500]
# Train Loss: 1.2973, Train Acc: 0.9780
# Val Loss: 1.4641, Val Acc: 0.8027
# Precision: 0.8169, Recall: 0.8027, F1-score: 0.8056
# --------------------------------------------------
# Epoch [186/1500]
# Train Loss: 1.2960, Train Acc: 0.9791
# Val Loss: 1.5335, Val Acc: 0.7373
# Precision: 0.7582, Recall: 0.7373, F1-score: 0.7356
# --------------------------------------------------
# Epoch [187/1500]
# Train Loss: 1.2966, Train Acc: 0.9782
# Val Loss: 1.5522, Val Acc: 0.7215
# Precision: 0.7404, Recall: 0.7215, F1-score: 0.7187
# --------------------------------------------------
# Epoch [188/1500]
# Train Loss: 1.2937, Train Acc: 0.9811
# Val Loss: 1.4580, Val Acc: 0.8099
# Precision: 0.8137, Recall: 0.8099, F1-score: 0.8095
# --------------------------------------------------
# Epoch [189/1500]
# Train Loss: 1.2908, Train Acc: 0.9840
# Val Loss: 1.4585, Val Acc: 0.8123
# Precision: 0.8198, Recall: 0.8123, F1-score: 0.8137
# --------------------------------------------------
# Epoch [190/1500]
# Train Loss: 1.2895, Train Acc: 0.9854
# Val Loss: 1.4452, Val Acc: 0.8317
# Precision: 0.8394, Recall: 0.8317, F1-score: 0.8312
# --------------------------------------------------
# Epoch [191/1500]
# Train Loss: 1.2894, Train Acc: 0.9848
# Val Loss: 1.4346, Val Acc: 0.8378
# Precision: 0.8420, Recall: 0.8378, F1-score: 0.8373
# --------------------------------------------------
# Epoch [192/1500]
# Train Loss: 1.2905, Train Acc: 0.9845
# Val Loss: 1.4453, Val Acc: 0.8232
# Precision: 0.8293, Recall: 0.8232, F1-score: 0.8219
# --------------------------------------------------
# Epoch [193/1500]
# Train Loss: 1.2937, Train Acc: 0.9805
# Val Loss: 1.4753, Val Acc: 0.7881
# Precision: 0.7934, Recall: 0.7881, F1-score: 0.7892
# --------------------------------------------------
# Epoch [194/1500]
# Train Loss: 1.2960, Train Acc: 0.9785
# Val Loss: 1.4753, Val Acc: 0.7966
# Precision: 0.8026, Recall: 0.7966, F1-score: 0.7960
# --------------------------------------------------
# Epoch [195/1500]
# Train Loss: 1.2921, Train Acc: 0.9825
# Val Loss: 1.4239, Val Acc: 0.8523
# Precision: 0.8568, Recall: 0.8523, F1-score: 0.8528
# --------------------------------------------------
# Epoch [196/1500]
# Train Loss: 1.2930, Train Acc: 0.9820
# Val Loss: 1.4361, Val Acc: 0.8269
# Precision: 0.8337, Recall: 0.8269, F1-score: 0.8272
# --------------------------------------------------
# Epoch [197/1500]
# Train Loss: 1.2925, Train Acc: 0.9823
# Val Loss: 1.4660, Val Acc: 0.8099
# Precision: 0.8133, Recall: 0.8099, F1-score: 0.8097
# --------------------------------------------------
# Epoch [198/1500]
# Train Loss: 1.2912, Train Acc: 0.9831
# Val Loss: 1.4623, Val Acc: 0.7954
# Precision: 0.8126, Recall: 0.7954, F1-score: 0.7970
# --------------------------------------------------
# Epoch [199/1500]
# Train Loss: 1.2948, Train Acc: 0.9794
# Val Loss: 1.6091, Val Acc: 0.6598
# Precision: 0.7016, Recall: 0.6598, F1-score: 0.6564
# --------------------------------------------------
# Epoch [200/1500]
# Train Loss: 1.2928, Train Acc: 0.9825
# Val Loss: 1.4950, Val Acc: 0.7748
# Precision: 0.7921, Recall: 0.7748, F1-score: 0.7768
# --------------------------------------------------
# Epoch [201/1500]
# Train Loss: 1.2977, Train Acc: 0.9762
# Val Loss: 1.4997, Val Acc: 0.7809
# Precision: 0.7971, Recall: 0.7809, F1-score: 0.7803
# --------------------------------------------------
# Epoch [202/1500]
# Train Loss: 1.2935, Train Acc: 0.9811
# Val Loss: 1.5008, Val Acc: 0.7663
# Precision: 0.7916, Recall: 0.7663, F1-score: 0.7706
# --------------------------------------------------
# Epoch [203/1500]
# Train Loss: 1.2939, Train Acc: 0.9808
# Val Loss: 1.4609, Val Acc: 0.8027
# Precision: 0.8113, Recall: 0.8027, F1-score: 0.8023
# --------------------------------------------------
# Epoch [204/1500]
# Train Loss: 1.2948, Train Acc: 0.9805
# Val Loss: 1.5242, Val Acc: 0.7639
# Precision: 0.7757, Recall: 0.7639, F1-score: 0.7651
# --------------------------------------------------
# Epoch [205/1500]
# Train Loss: 1.2925, Train Acc: 0.9817
# Val Loss: 1.4511, Val Acc: 0.8220
# Precision: 0.8263, Recall: 0.8220, F1-score: 0.8227
# --------------------------------------------------
# Epoch [206/1500]
# Train Loss: 1.2926, Train Acc: 0.9820
# Val Loss: 1.4630, Val Acc: 0.8015
# Precision: 0.8031, Recall: 0.8015, F1-score: 0.8002
# --------------------------------------------------
# Epoch [207/1500]
# Train Loss: 1.2908, Train Acc: 0.9837
# Val Loss: 1.5307, Val Acc: 0.7421
# Precision: 0.7505, Recall: 0.7421, F1-score: 0.7406
# --------------------------------------------------
# Epoch [208/1500]
# Train Loss: 1.2971, Train Acc: 0.9774
# Val Loss: 1.5405, Val Acc: 0.7215
# Precision: 0.7437, Recall: 0.7215, F1-score: 0.7229
# --------------------------------------------------
# Epoch [209/1500]
# Train Loss: 1.2989, Train Acc: 0.9762
# Val Loss: 1.5509, Val Acc: 0.7082
# Precision: 0.7244, Recall: 0.7082, F1-score: 0.7076
# --------------------------------------------------
# Epoch [210/1500]
# Train Loss: 1.2980, Train Acc: 0.9768
# Val Loss: 1.5637, Val Acc: 0.7107
# Precision: 0.7545, Recall: 0.7107, F1-score: 0.7157
# --------------------------------------------------
# Epoch [211/1500]
# Train Loss: 1.3003, Train Acc: 0.9740
# Val Loss: 1.5501, Val Acc: 0.7167
# Precision: 0.7455, Recall: 0.7167, F1-score: 0.7206
# --------------------------------------------------
# Epoch [212/1500]
# Train Loss: 1.2996, Train Acc: 0.9745
# Val Loss: 1.4964, Val Acc: 0.7688
# Precision: 0.7885, Recall: 0.7688, F1-score: 0.7707
# --------------------------------------------------
# Epoch [213/1500]
# Train Loss: 1.2933, Train Acc: 0.9817
# Val Loss: 1.5087, Val Acc: 0.7651
# Precision: 0.7752, Recall: 0.7651, F1-score: 0.7644
# --------------------------------------------------
# Epoch [214/1500]
# Train Loss: 1.2944, Train Acc: 0.9811
# Val Loss: 1.4488, Val Acc: 0.8281
# Precision: 0.8293, Recall: 0.8281, F1-score: 0.8277
# --------------------------------------------------
# Epoch [215/1500]
# Train Loss: 1.2935, Train Acc: 0.9805
# Val Loss: 1.4792, Val Acc: 0.7990
# Precision: 0.8031, Recall: 0.7990, F1-score: 0.7991
# --------------------------------------------------
# Epoch [216/1500]
# Train Loss: 1.2934, Train Acc: 0.9820
# Val Loss: 1.5061, Val Acc: 0.7797
# Precision: 0.7936, Recall: 0.7797, F1-score: 0.7830
# --------------------------------------------------
# Epoch [217/1500]
# Train Loss: 1.2943, Train Acc: 0.9794
# Val Loss: 1.4633, Val Acc: 0.8172
# Precision: 0.8215, Recall: 0.8172, F1-score: 0.8176
# --------------------------------------------------
# Epoch [218/1500]
# Train Loss: 1.2947, Train Acc: 0.9791
# Val Loss: 1.5031, Val Acc: 0.7651
# Precision: 0.7702, Recall: 0.7651, F1-score: 0.7633
# --------------------------------------------------
# Epoch [219/1500]
# Train Loss: 1.2936, Train Acc: 0.9814
# Val Loss: 1.4664, Val Acc: 0.8063
# Precision: 0.8132, Recall: 0.8063, F1-score: 0.8072
# --------------------------------------------------
# Epoch [220/1500]
# Train Loss: 1.2933, Train Acc: 0.9825
# Val Loss: 1.4832, Val Acc: 0.7978
# Precision: 0.8086, Recall: 0.7978, F1-score: 0.7978
# --------------------------------------------------
# Epoch [221/1500]
# Train Loss: 1.2912, Train Acc: 0.9828
# Val Loss: 1.4781, Val Acc: 0.7857
# Precision: 0.7978, Recall: 0.7857, F1-score: 0.7882
# --------------------------------------------------
# Epoch [222/1500]
# Train Loss: 1.2902, Train Acc: 0.9843
# Val Loss: 1.4492, Val Acc: 0.8269
# Precision: 0.8326, Recall: 0.8269, F1-score: 0.8278
# --------------------------------------------------
# Epoch [223/1500]
# Train Loss: 1.2909, Train Acc: 0.9845
# Val Loss: 1.4705, Val Acc: 0.8075
# Precision: 0.8160, Recall: 0.8075, F1-score: 0.8074
# --------------------------------------------------
# Epoch [224/1500]
# Train Loss: 1.2919, Train Acc: 0.9828
# Val Loss: 1.5124, Val Acc: 0.7603
# Precision: 0.7791, Recall: 0.7603, F1-score: 0.7639
# --------------------------------------------------
# Epoch [225/1500]
# Train Loss: 1.2948, Train Acc: 0.9803
# Val Loss: 1.5174, Val Acc: 0.7554
# Precision: 0.7677, Recall: 0.7554, F1-score: 0.7581
# --------------------------------------------------
# Epoch [226/1500]
# Train Loss: 1.2980, Train Acc: 0.9774
# Val Loss: 1.5555, Val Acc: 0.7010
# Precision: 0.7204, Recall: 0.7010, F1-score: 0.6940
# --------------------------------------------------
# Epoch [227/1500]
# Train Loss: 1.3025, Train Acc: 0.9722
# Val Loss: 1.5412, Val Acc: 0.7107
# Precision: 0.7185, Recall: 0.7107, F1-score: 0.7065
# --------------------------------------------------
# Epoch [228/1500]
# Train Loss: 1.3017, Train Acc: 0.9734
# Val Loss: 1.5453, Val Acc: 0.7252
# Precision: 0.7499, Recall: 0.7252, F1-score: 0.7256
# --------------------------------------------------
# Epoch [229/1500]
# Train Loss: 1.2988, Train Acc: 0.9768
# Val Loss: 1.4702, Val Acc: 0.7809
# Precision: 0.7872, Recall: 0.7809, F1-score: 0.7807
# --------------------------------------------------
# Epoch [230/1500]
# Train Loss: 1.2971, Train Acc: 0.9782
# Val Loss: 1.5259, Val Acc: 0.7373
# Precision: 0.7446, Recall: 0.7373, F1-score: 0.7362
# --------------------------------------------------
# Epoch [231/1500]
# Train Loss: 1.2969, Train Acc: 0.9765
# Val Loss: 1.4963, Val Acc: 0.7712
# Precision: 0.7938, Recall: 0.7712, F1-score: 0.7726
# --------------------------------------------------
# Epoch [232/1500]
# Train Loss: 1.2939, Train Acc: 0.9805
# Val Loss: 1.4638, Val Acc: 0.8087
# Precision: 0.8153, Recall: 0.8087, F1-score: 0.8098
# --------------------------------------------------
# Epoch [233/1500]
# Train Loss: 1.2925, Train Acc: 0.9820
# Val Loss: 1.4709, Val Acc: 0.7942
# Precision: 0.7958, Recall: 0.7942, F1-score: 0.7936
# --------------------------------------------------
# Epoch [234/1500]
# Train Loss: 1.2952, Train Acc: 0.9797
# Val Loss: 1.4496, Val Acc: 0.8075
# Precision: 0.8090, Recall: 0.8075, F1-score: 0.8066
# --------------------------------------------------
# Epoch [235/1500]
# Train Loss: 1.2967, Train Acc: 0.9782
# Val Loss: 1.4882, Val Acc: 0.7676
# Precision: 0.7833, Recall: 0.7676, F1-score: 0.7701
# --------------------------------------------------
# Epoch [236/1500]
# Train Loss: 1.3021, Train Acc: 0.9722
# Val Loss: 1.5024, Val Acc: 0.7615
# Precision: 0.7711, Recall: 0.7615, F1-score: 0.7613
# --------------------------------------------------
# Epoch [237/1500]
# Train Loss: 1.2983, Train Acc: 0.9762
# Val Loss: 1.4914, Val Acc: 0.7639
# Precision: 0.7740, Recall: 0.7639, F1-score: 0.7598
# --------------------------------------------------
# Epoch [238/1500]
# Train Loss: 1.2979, Train Acc: 0.9768
# Val Loss: 1.4718, Val Acc: 0.7918
# Precision: 0.7981, Recall: 0.7918, F1-score: 0.7923
# --------------------------------------------------
# Epoch [239/1500]
# Train Loss: 1.2951, Train Acc: 0.9785
# Val Loss: 1.4479, Val Acc: 0.8245
# Precision: 0.8252, Recall: 0.8245, F1-score: 0.8228
# --------------------------------------------------
# Epoch [240/1500]
# Train Loss: 1.2973, Train Acc: 0.9762
# Val Loss: 1.4170, Val Acc: 0.8475
# Precision: 0.8479, Recall: 0.8475, F1-score: 0.8476
# --------------------------------------------------
# Epoch [241/1500]
# Train Loss: 1.2904, Train Acc: 0.9837
# Val Loss: 1.4247, Val Acc: 0.8511
# Precision: 0.8543, Recall: 0.8511, F1-score: 0.8513
# --------------------------------------------------
# Epoch [242/1500]
# Train Loss: 1.2890, Train Acc: 0.9854
# Val Loss: 1.4255, Val Acc: 0.8426
# Precision: 0.8459, Recall: 0.8426, F1-score: 0.8431
# --------------------------------------------------
# Epoch [243/1500]
# Train Loss: 1.2891, Train Acc: 0.9845
# Val Loss: 1.4203, Val Acc: 0.8462
# Precision: 0.8489, Recall: 0.8462, F1-score: 0.8455
# --------------------------------------------------
# Epoch [244/1500]
# Train Loss: 1.2889, Train Acc: 0.9851
# Val Loss: 1.4409, Val Acc: 0.8208
# Precision: 0.8227, Recall: 0.8208, F1-score: 0.8187
# --------------------------------------------------
# Epoch [245/1500]
# Train Loss: 1.2918, Train Acc: 0.9825
# Val Loss: 1.4922, Val Acc: 0.7785
# Precision: 0.7846, Recall: 0.7785, F1-score: 0.7773
# --------------------------------------------------
# Epoch [246/1500]
# Train Loss: 1.2930, Train Acc: 0.9817
# Val Loss: 1.4409, Val Acc: 0.8245
# Precision: 0.8275, Recall: 0.8245, F1-score: 0.8253
# --------------------------------------------------
# Epoch [247/1500]
# Train Loss: 1.2937, Train Acc: 0.9805
# Val Loss: 1.4754, Val Acc: 0.7724
# Precision: 0.7809, Recall: 0.7724, F1-score: 0.7739
# --------------------------------------------------
# Epoch [248/1500]
# Train Loss: 1.2938, Train Acc: 0.9817
# Val Loss: 1.5154, Val Acc: 0.7494
# Precision: 0.7611, Recall: 0.7494, F1-score: 0.7489
# --------------------------------------------------
# Epoch [249/1500]
# Train Loss: 1.2977, Train Acc: 0.9771
# Val Loss: 1.4441, Val Acc: 0.8269
# Precision: 0.8298, Recall: 0.8269, F1-score: 0.8264
# --------------------------------------------------
# Epoch [250/1500]
# Train Loss: 1.2974, Train Acc: 0.9782
# Val Loss: 1.5035, Val Acc: 0.7712
# Precision: 0.7854, Recall: 0.7712, F1-score: 0.7722
# --------------------------------------------------
# Epoch [251/1500]
# Train Loss: 1.2998, Train Acc: 0.9754
# Val Loss: 1.5143, Val Acc: 0.7639
# ...
# Val Loss: 1.4365, Val Acc: 0.8257
# Precision: 0.8277, Recall: 0.8257, F1-score: 0.8243
# --------------------------------------------------
# Epoch [1419/1500]
# Train Loss: 1.2782, Train Acc: 0.9963
# Val Loss: 1.4229, Val Acc: 0.8511
# Precision: 0.8538, Recall: 0.8511, F1-score: 0.8514
# --------------------------------------------------
# Epoch [1420/1500]
# Train Loss: 1.2805, Train Acc: 0.9940
# Val Loss: 1.4367, Val Acc: 0.8402
# Precision: 0.8440, Recall: 0.8402, F1-score: 0.8407
# --------------------------------------------------
# Epoch [1421/1500]
# Train Loss: 1.2796, Train Acc: 0.9946
# Val Loss: 1.4375, Val Acc: 0.8402
# Precision: 0.8433, Recall: 0.8402, F1-score: 0.8407
# --------------------------------------------------
# Epoch [1422/1500]
# Train Loss: 1.2803, Train Acc: 0.9940
# Val Loss: 1.4356, Val Acc: 0.8317
# Precision: 0.8372, Recall: 0.8317, F1-score: 0.8332
# --------------------------------------------------
# Epoch [1423/1500]
# Train Loss: 1.2815, Train Acc: 0.9923
# Val Loss: 1.4412, Val Acc: 0.8293
# Precision: 0.8342, Recall: 0.8293, F1-score: 0.8279
# --------------------------------------------------
# Epoch [1424/1500]
# Train Loss: 1.2843, Train Acc: 0.9903
# Val Loss: 1.5183, Val Acc: 0.7397
# Precision: 0.7585, Recall: 0.7397, F1-score: 0.7386
# --------------------------------------------------
# Epoch [1425/1500]
# Train Loss: 1.2831, Train Acc: 0.9906
# Val Loss: 1.4942, Val Acc: 0.7821
# Precision: 0.7859, Recall: 0.7821, F1-score: 0.7799
# --------------------------------------------------
# Epoch [1426/1500]
# Train Loss: 1.2838, Train Acc: 0.9897
# Val Loss: 1.4446, Val Acc: 0.8293
# Precision: 0.8291, Recall: 0.8293, F1-score: 0.8278
# --------------------------------------------------
# Epoch [1427/1500]
# Train Loss: 1.2790, Train Acc: 0.9951
# Val Loss: 1.4390, Val Acc: 0.8305
# Precision: 0.8369, Recall: 0.8305, F1-score: 0.8316
# --------------------------------------------------
# Epoch [1428/1500]
# Train Loss: 1.2796, Train Acc: 0.9943
# Val Loss: 1.4333, Val Acc: 0.8305
# Precision: 0.8392, Recall: 0.8305, F1-score: 0.8316
# --------------------------------------------------
# Epoch [1429/1500]
# Train Loss: 1.2837, Train Acc: 0.9903
# Val Loss: 1.4429, Val Acc: 0.8245
# Precision: 0.8276, Recall: 0.8245, F1-score: 0.8247
# --------------------------------------------------
# Epoch [1430/1500]
# Train Loss: 1.2817, Train Acc: 0.9926
# Val Loss: 1.4952, Val Acc: 0.7712
# Precision: 0.7756, Recall: 0.7712, F1-score: 0.7722
# --------------------------------------------------
# Epoch [1431/1500]
# Train Loss: 1.2837, Train Acc: 0.9903
# Val Loss: 1.4966, Val Acc: 0.7809
# Precision: 0.7840, Recall: 0.7809, F1-score: 0.7775
# --------------------------------------------------
# Epoch [1432/1500]
# Train Loss: 1.2846, Train Acc: 0.9897
# Val Loss: 1.4613, Val Acc: 0.8027
# Precision: 0.8099, Recall: 0.8027, F1-score: 0.8041
# --------------------------------------------------
# Epoch [1433/1500]
# Train Loss: 1.2861, Train Acc: 0.9877
# Val Loss: 1.4526, Val Acc: 0.8220
# Precision: 0.8298, Recall: 0.8220, F1-score: 0.8211
# --------------------------------------------------
# Epoch [1434/1500]
# Train Loss: 1.2807, Train Acc: 0.9934
# Val Loss: 1.4756, Val Acc: 0.7990
# Precision: 0.8032, Recall: 0.7990, F1-score: 0.7996
# --------------------------------------------------
# Epoch [1435/1500]
# Train Loss: 1.2808, Train Acc: 0.9937
# Val Loss: 1.4752, Val Acc: 0.7978
# Precision: 0.8024, Recall: 0.7978, F1-score: 0.7974
# --------------------------------------------------
# Epoch [1436/1500]
# Train Loss: 1.2817, Train Acc: 0.9920
# Val Loss: 1.4717, Val Acc: 0.8148
# Precision: 0.8218, Recall: 0.8148, F1-score: 0.8151
# --------------------------------------------------
# Epoch [1437/1500]
# Train Loss: 1.2795, Train Acc: 0.9951
# Val Loss: 1.5707, Val Acc: 0.6949
# Precision: 0.7211, Recall: 0.6949, F1-score: 0.6985
# --------------------------------------------------
# Epoch [1438/1500]
# Train Loss: 1.2876, Train Acc: 0.9868
# Val Loss: 1.5009, Val Acc: 0.7760
# Precision: 0.7796, Recall: 0.7760, F1-score: 0.7748
# --------------------------------------------------
# Epoch [1439/1500]
# Train Loss: 1.2818, Train Acc: 0.9914
# Val Loss: 1.4329, Val Acc: 0.8438
# Precision: 0.8499, Recall: 0.8438, F1-score: 0.8434
# --------------------------------------------------
# Epoch [1440/1500]
# Train Loss: 1.2795, Train Acc: 0.9946
# Val Loss: 1.4213, Val Acc: 0.8475
# Precision: 0.8490, Recall: 0.8475, F1-score: 0.8473
# --------------------------------------------------
# Epoch [1441/1500]
# Train Loss: 1.2773, Train Acc: 0.9966
# Val Loss: 1.4196, Val Acc: 0.8511
# Precision: 0.8545, Recall: 0.8511, F1-score: 0.8514
# --------------------------------------------------
# Epoch [1442/1500]
# Train Loss: 1.2773, Train Acc: 0.9969
# Val Loss: 1.4313, Val Acc: 0.8438
# Precision: 0.8456, Recall: 0.8438, F1-score: 0.8439
# --------------------------------------------------
# Epoch [1443/1500]
# Train Loss: 1.2778, Train Acc: 0.9966
# Val Loss: 1.4368, Val Acc: 0.8426
# Precision: 0.8453, Recall: 0.8426, F1-score: 0.8427
# --------------------------------------------------
# Epoch [1444/1500]
# Train Loss: 1.2788, Train Acc: 0.9951
# Val Loss: 1.4314, Val Acc: 0.8317
# Precision: 0.8333, Recall: 0.8317, F1-score: 0.8317
# --------------------------------------------------
# Epoch [1445/1500]
# Train Loss: 1.2779, Train Acc: 0.9966
# Val Loss: 1.4352, Val Acc: 0.8378
# Precision: 0.8411, Recall: 0.8378, F1-score: 0.8381
# --------------------------------------------------
# Epoch [1446/1500]
# Train Loss: 1.2788, Train Acc: 0.9954
# Val Loss: 1.4068, Val Acc: 0.8692
# Precision: 0.8699, Recall: 0.8692, F1-score: 0.8687
# --------------------------------------------------
# Epoch [1447/1500]
# Train Loss: 1.2776, Train Acc: 0.9966
# Val Loss: 1.4271, Val Acc: 0.8535
# Precision: 0.8535, Recall: 0.8535, F1-score: 0.8521
# --------------------------------------------------
# Epoch [1448/1500]
# Train Loss: 1.2799, Train Acc: 0.9943
# Val Loss: 1.4165, Val Acc: 0.8523
# Precision: 0.8545, Recall: 0.8523, F1-score: 0.8523
# --------------------------------------------------
# Epoch [1449/1500]
# Train Loss: 1.2830, Train Acc: 0.9917
# Val Loss: 1.4698, Val Acc: 0.8087
# Precision: 0.8154, Recall: 0.8087, F1-score: 0.8094
# --------------------------------------------------
# Epoch [1450/1500]
# Train Loss: 1.2898, Train Acc: 0.9845
# Val Loss: 1.4951, Val Acc: 0.7736
# Precision: 0.7768, Recall: 0.7736, F1-score: 0.7726
# --------------------------------------------------
# Epoch [1451/1500]
# Train Loss: 1.2877, Train Acc: 0.9851
# Val Loss: 1.4527, Val Acc: 0.8136
# Precision: 0.8232, Recall: 0.8136, F1-score: 0.8152
# --------------------------------------------------
# Epoch [1452/1500]
# Train Loss: 1.2830, Train Acc: 0.9917
# Val Loss: 1.4538, Val Acc: 0.8317
# Precision: 0.8321, Recall: 0.8317, F1-score: 0.8311
# --------------------------------------------------
# Epoch [1453/1500]
# Train Loss: 1.2878, Train Acc: 0.9863
# Val Loss: 1.4904, Val Acc: 0.7906
# Precision: 0.7968, Recall: 0.7906, F1-score: 0.7906
# --------------------------------------------------
# Epoch [1454/1500]
# Train Loss: 1.2848, Train Acc: 0.9897
# Val Loss: 1.5158, Val Acc: 0.7724
# Precision: 0.7763, Recall: 0.7724, F1-score: 0.7677
# --------------------------------------------------
# Epoch [1455/1500]
# Train Loss: 1.2844, Train Acc: 0.9903
# Val Loss: 1.4804, Val Acc: 0.7881
# Precision: 0.7946, Recall: 0.7881, F1-score: 0.7884
# --------------------------------------------------
# Epoch [1456/1500]
# Train Loss: 1.2882, Train Acc: 0.9863
# Val Loss: 1.4865, Val Acc: 0.7893
# Precision: 0.7992, Recall: 0.7893, F1-score: 0.7911
# --------------------------------------------------
# Epoch [1457/1500]
# Train Loss: 1.2868, Train Acc: 0.9874
# Val Loss: 1.5017, Val Acc: 0.7700
# Precision: 0.7748, Recall: 0.7700, F1-score: 0.7707
# --------------------------------------------------
# Epoch [1458/1500]
# Train Loss: 1.2856, Train Acc: 0.9886
# Val Loss: 1.4515, Val Acc: 0.8148
# Precision: 0.8254, Recall: 0.8148, F1-score: 0.8157
# --------------------------------------------------
# Epoch [1459/1500]
# Train Loss: 1.2802, Train Acc: 0.9946
# Val Loss: 1.4319, Val Acc: 0.8438
# Precision: 0.8447, Recall: 0.8438, F1-score: 0.8432
# --------------------------------------------------
# Epoch [1460/1500]
# Train Loss: 1.2842, Train Acc: 0.9903
# Val Loss: 1.4580, Val Acc: 0.8208
# Precision: 0.8243, Recall: 0.8208, F1-score: 0.8215
# --------------------------------------------------
# Epoch [1461/1500]
# Train Loss: 1.2802, Train Acc: 0.9934
# Val Loss: 1.4082, Val Acc: 0.8668
# Precision: 0.8672, Recall: 0.8668, F1-score: 0.8662
# --------------------------------------------------
# Epoch [1462/1500]
# Train Loss: 1.2772, Train Acc: 0.9971
# Val Loss: 1.3893, Val Acc: 0.8777
# Precision: 0.8799, Recall: 0.8777, F1-score: 0.8777
# --------------------------------------------------
# Epoch [1463/1500]
# Train Loss: 1.2757, Train Acc: 0.9986
# Val Loss: 1.4255, Val Acc: 0.8462
# Precision: 0.8510, Recall: 0.8462, F1-score: 0.8465
# --------------------------------------------------
# Epoch [1464/1500]
# Train Loss: 1.2784, Train Acc: 0.9957
# Val Loss: 1.4126, Val Acc: 0.8535
# Precision: 0.8538, Recall: 0.8535, F1-score: 0.8531
# --------------------------------------------------
# Epoch [1465/1500]
# Train Loss: 1.2792, Train Acc: 0.9946
# Val Loss: 1.4080, Val Acc: 0.8644
# Precision: 0.8658, Recall: 0.8644, F1-score: 0.8648
# --------------------------------------------------
# Epoch [1466/1500]
# Train Loss: 1.2770, Train Acc: 0.9969
# Val Loss: 1.4323, Val Acc: 0.8402
# Precision: 0.8405, Recall: 0.8402, F1-score: 0.8387
# --------------------------------------------------
# Epoch [1467/1500]
# Train Loss: 1.2775, Train Acc: 0.9969
# Val Loss: 1.4303, Val Acc: 0.8390
# Precision: 0.8442, Recall: 0.8390, F1-score: 0.8389
# --------------------------------------------------
# Epoch [1468/1500]
# Train Loss: 1.2773, Train Acc: 0.9963
# Val Loss: 1.3932, Val Acc: 0.8753
# Precision: 0.8788, Recall: 0.8753, F1-score: 0.8755
# --------------------------------------------------
# Epoch [1469/1500]
# Train Loss: 1.2758, Train Acc: 0.9980
# Val Loss: 1.3989, Val Acc: 0.8608
# Precision: 0.8617, Recall: 0.8608, F1-score: 0.8609
# --------------------------------------------------
# Epoch [1470/1500]
# Train Loss: 1.2768, Train Acc: 0.9971
# Val Loss: 1.4365, Val Acc: 0.8354
# Precision: 0.8364, Recall: 0.8354, F1-score: 0.8339
# --------------------------------------------------
# Epoch [1471/1500]
# Train Loss: 1.2777, Train Acc: 0.9966
# Val Loss: 1.4220, Val Acc: 0.8487
# Precision: 0.8502, Recall: 0.8487, F1-score: 0.8485
# --------------------------------------------------
# Epoch [1472/1500]
# Train Loss: 1.2768, Train Acc: 0.9971
# Val Loss: 1.4382, Val Acc: 0.8414
# Precision: 0.8442, Recall: 0.8414, F1-score: 0.8421
# --------------------------------------------------
# Epoch [1473/1500]
# Train Loss: 1.2760, Train Acc: 0.9983
# Val Loss: 1.4124, Val Acc: 0.8632
# Precision: 0.8662, Recall: 0.8632, F1-score: 0.8639
# --------------------------------------------------
# Epoch [1474/1500]
# Train Loss: 1.2769, Train Acc: 0.9971
# Val Loss: 1.3898, Val Acc: 0.8838
# Precision: 0.8841, Recall: 0.8838, F1-score: 0.8835
# --------------------------------------------------
# Epoch [1475/1500]
# Train Loss: 1.2766, Train Acc: 0.9974
# Val Loss: 1.4239, Val Acc: 0.8390
# Precision: 0.8421, Recall: 0.8390, F1-score: 0.8394
# --------------------------------------------------
# Epoch [1476/1500]
# Train Loss: 1.2780, Train Acc: 0.9963
# Val Loss: 1.4181, Val Acc: 0.8559
# Precision: 0.8570, Recall: 0.8559, F1-score: 0.8559
# --------------------------------------------------
# Epoch [1477/1500]
# Train Loss: 1.2768, Train Acc: 0.9974
# Val Loss: 1.4414, Val Acc: 0.8462
# Precision: 0.8499, Recall: 0.8462, F1-score: 0.8469
# --------------------------------------------------
# Epoch [1478/1500]
# Train Loss: 1.2765, Train Acc: 0.9977
# Val Loss: 1.4657, Val Acc: 0.8184
# Precision: 0.8191, Recall: 0.8184, F1-score: 0.8171
# --------------------------------------------------
# Epoch [1479/1500]
# Train Loss: 1.2772, Train Acc: 0.9966
# Val Loss: 1.4398, Val Acc: 0.8402
# Precision: 0.8430, Recall: 0.8402, F1-score: 0.8395
# --------------------------------------------------
# Epoch [1480/1500]
# Train Loss: 1.2758, Train Acc: 0.9986
# Val Loss: 1.4142, Val Acc: 0.8680
# Precision: 0.8693, Recall: 0.8680, F1-score: 0.8680
# --------------------------------------------------
# Epoch [1481/1500]
# Train Loss: 1.2750, Train Acc: 0.9994
# Val Loss: 1.4053, Val Acc: 0.8680
# Precision: 0.8689, Recall: 0.8680, F1-score: 0.8682
# --------------------------------------------------
# Epoch [1482/1500]
# Train Loss: 1.2756, Train Acc: 0.9986
# Val Loss: 1.3982, Val Acc: 0.8765
# Precision: 0.8788, Recall: 0.8765, F1-score: 0.8770
# --------------------------------------------------
# Epoch [1483/1500]
# Train Loss: 1.2760, Train Acc: 0.9986
# Val Loss: 1.4312, Val Acc: 0.8305
# Precision: 0.8364, Recall: 0.8305, F1-score: 0.8315
# --------------------------------------------------
# Epoch [1484/1500]
# Train Loss: 1.2782, Train Acc: 0.9960
# Val Loss: 1.4040, Val Acc: 0.8705
# Precision: 0.8711, Recall: 0.8705, F1-score: 0.8698
# --------------------------------------------------
# Epoch [1485/1500]
# Train Loss: 1.2783, Train Acc: 0.9954
# Val Loss: 1.4357, Val Acc: 0.8390
# Precision: 0.8432, Recall: 0.8390, F1-score: 0.8386
# --------------------------------------------------
# Epoch [1486/1500]
# Train Loss: 1.2769, Train Acc: 0.9971
# Val Loss: 1.4171, Val Acc: 0.8499
# Precision: 0.8511, Recall: 0.8499, F1-score: 0.8495
# --------------------------------------------------
# Epoch [1487/1500]
# Train Loss: 1.2767, Train Acc: 0.9974
# Val Loss: 1.4150, Val Acc: 0.8571
# Precision: 0.8592, Recall: 0.8571, F1-score: 0.8570
# --------------------------------------------------
# Epoch [1488/1500]
# Train Loss: 1.2760, Train Acc: 0.9980
# Val Loss: 1.4158, Val Acc: 0.8547
# Precision: 0.8558, Recall: 0.8547, F1-score: 0.8545
# --------------------------------------------------
# Epoch [1489/1500]
# Train Loss: 1.2764, Train Acc: 0.9977
# Val Loss: 1.4136, Val Acc: 0.8547
# Precision: 0.8562, Recall: 0.8547, F1-score: 0.8548
# --------------------------------------------------
# Epoch [1490/1500]
# Train Loss: 1.2750, Train Acc: 0.9991
# Val Loss: 1.4165, Val Acc: 0.8584
# Precision: 0.8601, Recall: 0.8584, F1-score: 0.8586
# --------------------------------------------------
# Epoch [1491/1500]
# Train Loss: 1.2752, Train Acc: 0.9989
# Val Loss: 1.4122, Val Acc: 0.8596
# Precision: 0.8690, Recall: 0.8596, F1-score: 0.8613
# --------------------------------------------------
# Epoch [1492/1500]
# Train Loss: 1.2771, Train Acc: 0.9969
# Val Loss: 1.4583, Val Acc: 0.8220
# Precision: 0.8283, Recall: 0.8220, F1-score: 0.8218
# --------------------------------------------------
# Epoch [1493/1500]
# Train Loss: 1.2769, Train Acc: 0.9971
# Val Loss: 1.4351, Val Acc: 0.8402
# Precision: 0.8421, Recall: 0.8402, F1-score: 0.8402
# --------------------------------------------------
# Epoch [1494/1500]
# Train Loss: 1.2780, Train Acc: 0.9960
# Val Loss: 1.4654, Val Acc: 0.8160
# Precision: 0.8219, Recall: 0.8160, F1-score: 0.8168
# --------------------------------------------------
# Epoch [1495/1500]
# Train Loss: 1.2771, Train Acc: 0.9971
# Val Loss: 1.4354, Val Acc: 0.8438
# Precision: 0.8467, Recall: 0.8438, F1-score: 0.8443
# --------------------------------------------------
# Epoch [1496/1500]
# Train Loss: 1.2807, Train Acc: 0.9934
# Val Loss: 1.4431, Val Acc: 0.8232
# Precision: 0.8232, Recall: 0.8232, F1-score: 0.8230
# --------------------------------------------------
# Epoch [1497/1500]
# Train Loss: 1.2806, Train Acc: 0.9937
# Val Loss: 1.4738, Val Acc: 0.7930
# Precision: 0.8029, Recall: 0.7930, F1-score: 0.7942
# --------------------------------------------------
# Epoch [1498/1500]
# Train Loss: 1.2818, Train Acc: 0.9928
# Val Loss: 1.4947, Val Acc: 0.7736
# Precision: 0.7797, Recall: 0.7736, F1-score: 0.7742
# --------------------------------------------------
# Epoch [1499/1500]
# Train Loss: 1.2805, Train Acc: 0.9937
# Val Loss: 1.4945, Val Acc: 0.7712
# Precision: 0.7730, Recall: 0.7712, F1-score: 0.7705
# --------------------------------------------------
# Epoch [1500/1500]
# Train Loss: 1.2862, Train Acc: 0.9880
# Val Loss: 1.4811, Val Acc: 0.7954
# Precision: 0.8067, Recall: 0.7954, F1-score: 0.7954
# --------------------------------------------------

# %%
torch.save(model.state_dict(), "C:/Nini/Capstone/Models/DataAugmentation_Noise_pitch_LSTM_model.pth")
